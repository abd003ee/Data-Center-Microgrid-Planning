# %% [markdown]
# # Solar Configuration

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()


import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_solar_dc"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]*0

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            #print(f"Superficial NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    #plt.plot(df_dispatch["Hour"], df_dispatch["Charge (kW)"], label="Charge", linestyle='-.')
    #plt.plot(df_dispatch["Hour"], df_dispatch["Discharge (kW)"], label="Discharge", linestyle='-.')
    #plt.plot(df_dispatch["Hour"], df_dispatch["Unmet (kW)"], label="Unmet", color="red", linewidth=2)
    #plt.plot(df_dispatch["Hour"], df_dispatch["Curtailment (kW)"], label="Curtailment", linestyle=':')
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        

        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
       # plt.plot(df_dispatch["Hour"], df_dispatch["Charge (kW)"], label="Charge", linestyle='-.')
        #plt.plot(df_dispatch["Hour"], df_dispatch["Discharge (kW)"], label="Discharge", linestyle='-.')
        #plt.plot(df_dispatch["Hour"], df_dispatch["Unmet (kW)"], label="Unmet", color="red", linewidth=2)
        #plt.plot(df_dispatch["Hour"], df_dispatch["Curtailment (kW)"], label="Curtailment", linestyle=':')
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76882153 nonzeros
# Model fingerprint: 0x3a7baa14
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8764 columns (presolve time = 7s)...
# Presolve removed 20261 rows and 20261 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8765 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8765 columns (presolve time = 13s)...
# Presolve removed 8766 rows and 8765 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8766 columns (presolve time = 25s)...
# Presolve removed 8767 rows and 8766 columns
# Presolve time: 25.19s
# Presolved: 70077 rows, 35041 columns, 153302 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35041 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 40788 rows, 18882 columns, 103720 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4791569e+09   1.122083e+07   1.603722e+08     39s
#     6164    1.4791569e+09   2.040223e+06   8.920515e+07     40s
#     7644    9.4521423e+11   0.000000e+00   3.943839e+05     40s
# Concurrent spin time: 0.18s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.278784e+09, 13935 iterations, 2.39 seconds (1.68 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.2788e+09    0    5          - 6.2788e+09      -     -   41s
# H    0     0                    1.408739e+10 6.2788e+09  55.4%     -   43s
# H    0     0                    1.405910e+10 6.2788e+09  55.3%     -   44s
# H    0     0                    1.395605e+10 6.2788e+09  55.0%     -   45s
#      0     2 6.2788e+09    0    5 1.3956e+10 6.2788e+09  55.0%     -   46s
# H    3     8                    1.394137e+10 6.2788e+09  55.0%   4.0   47s
#     23    41 6.2788e+09    5    5 1.3941e+10 6.2788e+09  55.0%  39.3   50s
# H   24    41                    8.811573e+09 6.2788e+09  28.7%  37.7   50s
#    120   304 6.2788e+09   11    5 8.8116e+09 6.2788e+09  28.7%   8.2   58s
#    309   687 6.2788e+09   23    4 8.8116e+09 6.2788e+09  28.7%   3.8   68s
#    692  1139 6.2788e+09   46    5 8.8116e+09 6.2788e+09  28.7%   2.1   80s
# H  700   900                    6.278784e+09 6.2788e+09  0.00%   2.1   80s
#
# Explored 1147 nodes (15741 simplex iterations) in 81.30 seconds (80.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 6.27878e+09 8.81157e+09 1.39414e+10 ... 1.40874e+10
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 6.278783792366e+09, best bound 6.278783792366e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 21992837.72 PV
# Wind Capacity: 0.00 HAWT
# Battery Capacity: 7699642.14 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 7936184258.22 kWh
# Total Energy Generated: 11404891836.03 kWh
# Total Energy Used (along with efficiency losses): 3468707577.81 kWh
# Utilization Percentage: 30.41%
# $36039139.24 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 21992837.72 PV
# Solar Initial Cost:    $2044234266.26
# Wind Initial Capacity: 0.00 HAWT
# Wind Initial Cost:     $0.00
# Battery Initial Capacity: 7699642.14 kWh
# Battery Initial Cost:  $2756471887.30
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -70377.08 PV
# Solar Redundant Cost:    $-6541549.65
# Wind Redundant Capacity: 0.00 HAWT
# Wind Redundant Cost:     $0.00
# Battery Redundant Capacity: 28488.68 kWh
# Battery Redundant Cost:  $10198945.98
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $2037692716.61
# Solar OPEX:         $2225699796.81
# Solar Replacement:  $0.00
# Solar Salvage:     -$592364240.56
# Wind CAPEX:         $0.00
# Wind OPEX:          $0.00
# Wind Replacement:   $0.00
# Wind Salvage:      -$0.00
# Battery CAPEX:      $2766670833.28
# Battery OPEX:       $833507807.00
# Battery Replacement:$457903482.03
# Battery Salvage:   -$1005350839.75
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $6736687274.39
#
# === 2024 Results ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           12 0.4253     0.000031
# discharge         15           36 0.4974     0.000041
# discharge         40           62 0.5523     0.000050
# discharge         68           84 0.4992     0.000042
# discharge         87          109 0.5252     0.000045
# discharge        116          133 0.5584     0.000051
# discharge        138          157 0.5532     0.000050
# discharge        161          180 0.4979     0.000041
# discharge        183          205 0.5399     0.000048
# discharge        208          228 0.5197     0.000045
# discharge        231          253 0.5250     0.000045
# discharge        256          278 0.5449     0.000049
# discharge        281          300 0.4986     0.000041
# discharge        303          324 0.4953     0.000041
# discharge        327          349 0.5526     0.000050
# discharge        354          373 0.5014     0.000042
# discharge        375          396 0.4964     0.000041
# discharge        399          422 0.5385     0.000048
# discharge        428          444 0.5539     0.000050
# discharge        447          468 0.4975     0.000041
# discharge        470          492 0.4972     0.000041
# discharge        495          516 0.4973     0.000041
# discharge        519          542 0.5679     0.000052
# discharge        548          566 0.5685     0.000052
# discharge        572          590 0.5778     0.000054
# discharge        598          613 0.5041     0.000042
# discharge        618          637 0.5235     0.000045
# discharge        645          660 0.5264     0.000046
# discharge        664          684 0.4965     0.000041
# discharge        688          708 0.4985     0.000041
# discharge        712          732 0.4985     0.000041
# discharge        735          756 0.4971     0.000041
# discharge        759          780 0.5175     0.000044
# discharge        783          804 0.4977     0.000041
# discharge        808          830 0.5571     0.000051
# discharge        836          852 0.5334     0.000047
# discharge        856          876 0.4973     0.000041
# discharge        878          900 0.4998     0.000042
# discharge        903          924 0.4997     0.000042
# discharge        927          949 0.5116     0.000043
# discharge        955          973 0.5286     0.000046
# discharge        981          996 0.5231     0.000045
# discharge        999         1021 0.5027     0.000042
# discharge       1025         1044 0.5206     0.000045
# discharge       1047         1068 0.4921     0.000040
# discharge       1070         1092 0.4918     0.000040
# discharge       1095         1116 0.4986     0.000041
# discharge       1123         1140 0.5022     0.000042
# discharge       1143         1164 0.4868     0.000040
# discharge       1166         1188 0.4871     0.000040
# discharge       1190         1212 0.4828     0.000039
# discharge       1214         1236 0.4913     0.000040
# discharge       1239         1260 0.4958     0.000041
# discharge       1266         1284 0.4905     0.000040
# discharge       1287         1308 0.4770     0.000038
# discharge       1310         1332 0.4803     0.000039
# discharge       1335         1356 0.4815     0.000039
# discharge       1359         1380 0.4981     0.000041
# discharge       1383         1405 0.5077     0.000043
# discharge       1408         1428 0.4921     0.000040
# discharge       1431         1452 0.4756     0.000038
# discharge       1455         1476 0.4975     0.000041
# discharge       1480         1500 0.4572     0.000035
# discharge       1502         1524 0.4740     0.000038
# discharge       1527         1548 0.4926     0.000041
# discharge       1553         1572 0.4821     0.000039
# discharge       1575         1596 0.4749     0.000038
# discharge       1600         1620 0.4899     0.000040
# discharge       1627         1644 0.4822     0.000039
# discharge       1648         1667 0.4321     0.000032
# discharge       1670         1691 0.4378     0.000033
# discharge       1694         1715 0.4313     0.000032
# discharge       1718         1740 0.4516     0.000035
# discharge       1743         1764 0.4609     0.000036
# discharge       1767         1788 0.4943     0.000041
# discharge       1795         1811 0.4484     0.000034
# discharge       1814         1835 0.4583     0.000036
# discharge       1839         1859 0.4322     0.000032
# discharge       1862         1883 0.4334     0.000032
# discharge       1886         1907 0.4341     0.000032
# discharge       1910         1931 0.4326     0.000032
# discharge       1934         1956 0.4640     0.000036
# discharge       1962         1979 0.4665     0.000037
# discharge       1982         2004 0.4469     0.000034
# discharge       2008         2028 0.4555     0.000035
# discharge       2032         2052 0.4546     0.000035
# discharge       2055         2075 0.4315     0.000032
# discharge       2078         2099 0.4335     0.000032
# discharge       2102         2123 0.4344     0.000032
# discharge       2126         2147 0.4345     0.000032
# discharge       2150         2172 0.4383     0.000033
# discharge       2175         2196 0.4463     0.000034
# discharge       2200         2220 0.4422     0.000033
# discharge       2224         2243 0.4359     0.000033
# discharge       2246         2267 0.4345     0.000032
# discharge       2270         2291 0.4361     0.000033
# discharge       2294         2315 0.4351     0.000032
# discharge       2319         2339 0.4356     0.000033
# discharge       2342         2363 0.4364     0.000033
# discharge       2367         2388 0.4564     0.000035
# discharge       2393         2411 0.4772     0.000038
# discharge       2418         2435 0.4619     0.000036
# discharge       2440         2459 0.4356     0.000033
# discharge       2462         2483 0.4365     0.000033
# discharge       2486         2507 0.4387     0.000033
# discharge       2510         2531 0.4368     0.000033
# discharge       2534         2555 0.4410     0.000033
# discharge       2558         2579 0.4481     0.000034
# discharge       2584         2603 0.4334     0.000032
# discharge       2606         2627 0.4382     0.000033
# discharge       2630         2651 0.4344     0.000032
# discharge       2655         2675 0.4650     0.000037
# discharge       2678         2699 0.4325     0.000032
# discharge       2702         2723 0.4302     0.000032
# discharge       2726         2747 0.4297     0.000032
# discharge       2750         2771 0.4291     0.000032
# discharge       2774         2796 0.4387     0.000033
# discharge       2799         2819 0.4359     0.000033
# discharge       2823         2843 0.4281     0.000032
# discharge       2846         2868 0.4358     0.000033
# discharge       2873         2891 0.4303     0.000032
# discharge       2894         2915 0.4246     0.000031
# discharge       2918         2939 0.4194     0.000030
# discharge       2942         2963 0.4314     0.000032
# discharge       2966         2987 0.4290     0.000032
# discharge       2991         3011 0.4244     0.000031
# discharge       3016         3035 0.4480     0.000034
# discharge       3038         3059 0.4220     0.000031
# discharge       3062         3083 0.4263     0.000031
# discharge       3087         3107 0.4313     0.000032
# discharge       3110         3131 0.4118     0.000029
# discharge       3134         3155 0.4089     0.000029
# discharge       3158         3179 0.4087     0.000029
# discharge       3182         3204 0.4566     0.000035
# discharge       3209         3227 0.4230     0.000031
# discharge       3230         3251 0.4044     0.000028
# discharge       3254         3275 0.3970     0.000028
# discharge       3278         3299 0.4475     0.000034
# discharge       3303         3323 0.4166     0.000030
# discharge       3328         3347 0.3937     0.000027
# discharge       3350         3371 0.3905     0.000027
# discharge       3374         3395 0.3928     0.000027
# discharge       3398         3419 0.4331     0.000032
# discharge       3424         3444 0.4402     0.000033
# discharge       3448         3468 0.4399     0.000033
# discharge       3473         3491 0.4082     0.000029
# discharge       3494         3515 0.4132     0.000030
# discharge       3519         3539 0.3885     0.000027
# discharge       3542         3563 0.3782     0.000025
# discharge       3566         3587 0.3791     0.000025
# discharge       3590         3611 0.4011     0.000028
# discharge       3614         3635 0.4049     0.000029
# discharge       3640         3659 0.4358     0.000033
# discharge       3663         3683 0.3836     0.000026
# discharge       3686         3707 0.3866     0.000026
# discharge       3710         3731 0.3880     0.000026
# discharge       3734         3755 0.3981     0.000028
# discharge       3758         3779 0.3779     0.000025
# discharge       3782         3803 0.3753     0.000025
# discharge       3806         3826 0.3691     0.000024
# discharge       3830         3851 0.3864     0.000026
# discharge       3854         3875 0.3976     0.000028
# discharge       3878         3899 0.3719     0.000025
# discharge       3902         3923 0.3819     0.000026
# discharge       3926         3947 0.3733     0.000025
# discharge       3950         3970 0.3712     0.000024
# discharge       3974         3995 0.3780     0.000025
# discharge       3998         4019 0.3718     0.000025
# discharge       4022         4043 0.3886     0.000027
# discharge       4048         4067 0.4077     0.000029
# discharge       4071         4091 0.4012     0.000028
# discharge       4095         4114 0.3715     0.000024
# discharge       4118         4139 0.3718     0.000024
# discharge       4142         4162 0.3804     0.000026
# discharge       4166         4187 0.3739     0.000025
# discharge       4190         4211 0.3736     0.000025
# discharge       4214         4234 0.3697     0.000024
# discharge       4238         4259 0.3908     0.000027
# discharge       4262         4283 0.3797     0.000025
# discharge       4286         4307 0.3713     0.000024
# discharge       4310         4331 0.3838     0.000026
# discharge       4334         4355 0.3748     0.000025
# discharge       4358         4379 0.3737     0.000025
# discharge       4382         4403 0.3713     0.000024
# discharge       4406         4427 0.3721     0.000025
# discharge       4430         4451 0.3788     0.000025
# discharge       4454         4475 0.3826     0.000026
# discharge       4479         4499 0.3701     0.000024
# discharge       4502         4523 0.3768     0.000025
# discharge       4526         4547 0.4057     0.000029
# discharge       4551         4571 0.3973     0.000028
# discharge       4574         4595 0.3845     0.000026
# discharge       4598         4619 0.3784     0.000025
# discharge       4622         4643 0.3787     0.000025
# discharge       4646         4667 0.3897     0.000027
# discharge       4670         4691 0.4041     0.000028
# discharge       4694         4715 0.3870     0.000026
# discharge       4718         4739 0.3895     0.000027
# discharge       4742         4764 0.4131     0.000030
# discharge       4769         4787 0.3919     0.000027
# discharge       4790         4811 0.3920     0.000027
# discharge       4814         4835 0.3952     0.000027
# discharge       4838         4859 0.3944     0.000027
# discharge       4862         4883 0.4138     0.000030
# discharge       4886         4908 0.4331     0.000032
# discharge       4915         4931 0.4232     0.000031
# discharge       4936         4955 0.4229     0.000031
# discharge       4960         4979 0.4256     0.000031
# discharge       4984         5003 0.4262     0.000031
# discharge       5008         5027 0.4255     0.000031
# discharge       5031         5051 0.4097     0.000029
# discharge       5054         5075 0.4132     0.000030
# discharge       5078         5099 0.4072     0.000029
# discharge       5102         5123 0.4088     0.000029
# discharge       5126         5147 0.4088     0.000029
# discharge       5150         5171 0.4079     0.000029
# discharge       5174         5195 0.4080     0.000029
# discharge       5198         5219 0.4136     0.000030
# discharge       5222         5243 0.4177     0.000030
# discharge       5246         5267 0.4176     0.000030
# discharge       5270         5291 0.4165     0.000030
# discharge       5294         5315 0.4185     0.000030
# discharge       5318         5339 0.4166     0.000030
# discharge       5342         5363 0.4208     0.000031
# discharge       5366         5387 0.4217     0.000031
# discharge       5390         5411 0.4194     0.000030
# discharge       5414         5435 0.4288     0.000032
# discharge       5438         5459 0.4205     0.000031
# discharge       5462         5483 0.4230     0.000031
# discharge       5486         5507 0.4279     0.000032
# discharge       5511         5531 0.4240     0.000031
# discharge       5534         5555 0.4260     0.000031
# discharge       5558         5579 0.4263     0.000031
# discharge       5582         5603 0.4262     0.000031
# discharge       5606         5627 0.4269     0.000031
# discharge       5630         5651 0.4252     0.000031
# discharge       5654         5675 0.4254     0.000031
# discharge       5678         5699 0.4253     0.000031
# discharge       5702         5723 0.4283     0.000032
# discharge       5726         5747 0.4302     0.000032
# discharge       5750         5771 0.4308     0.000032
# discharge       5774         5795 0.4299     0.000032
# discharge       5799         5819 0.4295     0.000032
# discharge       5823         5843 0.4386     0.000033
# discharge       5847         5868 0.4402     0.000033
# discharge       5872         5891 0.4299     0.000032
# discharge       5894         5915 0.4289     0.000032
# discharge       5919         5940 0.4355     0.000033
# discharge       5944         5963 0.4374     0.000033
# discharge       5966         5987 0.4291     0.000032
# discharge       5991         6011 0.4271     0.000031
# discharge       6014         6035 0.4285     0.000032
# discharge       6038         6059 0.4299     0.000032
# discharge       6062         6083 0.4285     0.000032
# discharge       6086         6107 0.4273     0.000031
# discharge       6110         6132 0.4512     0.000035
# discharge       6139         6155 0.4600     0.000036
# discharge       6160         6180 0.4446     0.000034
# discharge       6183         6204 0.4384     0.000033
# discharge       6208         6229 0.4911     0.000040
# discharge       6234         6251 0.4330     0.000032
# discharge       6254         6275 0.4266     0.000031
# discharge       6278         6299 0.4255     0.000031
# discharge       6302         6323 0.4262     0.000031
# discharge       6326         6348 0.4320     0.000032
# discharge       6352         6372 0.4334     0.000032
# discharge       6375         6396 0.4297     0.000032
# discharge       6399         6420 0.4531     0.000035
# discharge       6424         6444 0.4531     0.000035
# discharge       6447         6467 0.4236     0.000031
# discharge       6470         6492 0.4395     0.000033
# discharge       6496         6516 0.4962     0.000041
# discharge       6520         6540 0.4657     0.000037
# discharge       6543         6564 0.4435     0.000034
# discharge       6567         6587 0.4349     0.000032
# discharge       6590         6611 0.4295     0.000032
# discharge       6614         6635 0.4223     0.000031
# discharge       6638         6660 0.4243     0.000031
# discharge       6662         6684 0.4347     0.000032
# discharge       6686         6708 0.4344     0.000032
# discharge       6710         6732 0.4343     0.000032
# discharge       6734         6755 0.4240     0.000031
# discharge       6758         6780 0.4340     0.000032
# discharge       6782         6804 0.4400     0.000033
# discharge       6806         6828 0.4495     0.000034
# discharge       6830         6852 0.4590     0.000036
# discharge       6855         6876 0.4623     0.000036
# discharge       6879         6900 0.4613     0.000036
# discharge       6902         6924 0.4672     0.000037
# discharge       6927         6948 0.4552     0.000035
# discharge       6950         6972 0.4550     0.000035
# discharge       6974         6996 0.4572     0.000035
# discharge       6998         7020 0.4732     0.000038
# discharge       7023         7044 0.4669     0.000037
# discharge       7046         7068 0.4668     0.000037
# discharge       7070         7092 0.4715     0.000037
# discharge       7095         7116 0.4752     0.000038
# discharge       7119         7140 0.4823     0.000039
# discharge       7143         7164 0.4837     0.000039
# discharge       7167         7188 0.4877     0.000040
# discharge       7192         7212 0.4972     0.000041
# discharge       7215         7236 0.4854     0.000039
# discharge       7239         7260 0.4869     0.000040
# discharge       7263         7284 0.4878     0.000040
# discharge       7287         7308 0.4875     0.000040
# discharge       7312         7332 0.5055     0.000042
# discharge       7335         7356 0.4890     0.000040
# discharge       7360         7380 0.4895     0.000040
# discharge       7384         7405 0.5036     0.000042
# discharge       7408         7428 0.4890     0.000040
# discharge       7431         7452 0.4878     0.000040
# discharge       7457         7476 0.4861     0.000040
# discharge       7480         7500 0.4897     0.000040
# discharge       7503         7524 0.4857     0.000040
# discharge       7530         7549 0.5268     0.000046
# discharge       7554         7572 0.4867     0.000040
# discharge       7575         7596 0.4875     0.000040
# discharge       7599         7621 0.5119     0.000043
# discharge       7629         7644 0.4990     0.000041
# discharge       7647         7668 0.4866     0.000040
# discharge       7671         7693 0.4888     0.000040
# discharge       7696         7716 0.4868     0.000040
# discharge       7719         7740 0.4860     0.000040
# discharge       7744         7764 0.4877     0.000040
# discharge       7767         7788 0.4871     0.000040
# discharge       7791         7812 0.4881     0.000040
# discharge       7815         7836 0.4870     0.000040
# discharge       7839         7860 0.4891     0.000040
# discharge       7864         7884 0.4882     0.000040
# discharge       7887         7908 0.4874     0.000040
# discharge       7911         7932 0.5151     0.000044
# discharge       7935         7957 0.5093     0.000043
# discharge       7963         7980 0.5253     0.000045
# discharge       7983         8004 0.4889     0.000040
# discharge       8007         8028 0.4886     0.000040
# discharge       8031         8053 0.4954     0.000041
# discharge       8057         8076 0.4879     0.000040
# discharge       8079         8100 0.4884     0.000040
# discharge       8103         8124 0.4883     0.000040
# discharge       8127         8148 0.4904     0.000040
# discharge       8151         8172 0.4909     0.000040
# discharge       8175         8196 0.4898     0.000040
# discharge       8199         8221 0.5164     0.000044
# discharge       8228         8245 0.5655     0.000052
# discharge       8249         8269 0.5097     0.000043
# discharge       8272         8292 0.4894     0.000040
# discharge       8295         8316 0.4903     0.000040
# discharge       8319         8342 0.5260     0.000046
# discharge       8347         8365 0.5125     0.000044
# discharge       8367         8388 0.5231     0.000045
# discharge       8392         8413 0.5231     0.000045
# discharge       8420         8437 0.5459     0.000049
# discharge       8441         8462 0.5446     0.000049
# discharge       8468         8484 0.4937     0.000041
# discharge       8487         8508 0.4926     0.000041
# discharge       8511         8532 0.4945     0.000041
# discharge       8535         8556 0.4953     0.000041
# discharge       8559         8580 0.4943     0.000041
# discharge       8583         8605 0.5203     0.000045
# discharge       8609         8630 0.5809     0.000054
# discharge       8635         8653 0.5636     0.000052
# discharge       8658         8677 0.5320     0.000047
# discharge       8680         8700 0.4985     0.000041
# discharge       8708         8725 0.5815     0.000055
# discharge       8728         8749 0.5074     0.000043
#
# Total Estimated Degradation: 0.012859
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_solar_dc\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_solar_dc\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_solar_dc\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_solar_dc\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 1345002.85 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 27726.29 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 1759587.85 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 2414518.24 kWh
# Year 2015: Unmet Load = 5343603.86 kWh
# Year 2014: Unmet Load = 2062333.97 kWh
# Year 2013: Unmet Load = 577891.23 kWh
# Year 2012: Unmet Load = 900692.66 kWh
# Year 2011: Unmet Load = 120507.67 kWh
# Year 2010: Unmet Load = 1322598.97 kWh
# Year 2009: Unmet Load = 1400380.82 kWh
# Year 2008: Unmet Load = 19985.44 kWh
# Year 2007: Unmet Load = 1679440.31 kWh
# Year 2006: Unmet Load = 914844.61 kWh
# Year 2005: Unmet Load = 1439129.90 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 428815.76 kWh
# Year 2002: Unmet Load = 52294.61 kWh
# Year 2001: Unmet Load = 1492694.21 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 2006186.39 kWh
# Year 1998: Unmet Load = 4180006.58 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 1561578.71 kWh
# Year 1995: Unmet Load = 1064282.33 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 2296016.01 kWh
# Year 1992: Unmet Load = 248777.11 kWh
# Year 1991: Unmet Load = 1627006.58 kWh
# Year 1990: Unmet Load = 565421.21 kWh
# Year 1989: Unmet Load = 144812.47 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 5297928.40 kWh
# Year 1986: Unmet Load = 4464097.61 kWh
# Year 1985: Unmet Load = 2880006.48 kWh
# Year 1984: Unmet Load = 323981.91 kWh
# Year 1983: Unmet Load = 1949067.59 kWh
# Year 1982: Unmet Load = 5560513.54 kWh
# Year 1981: Unmet Load = 1123989.55 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 1302127.15 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 5560513.54 kWh (Year 1982)

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar_dc"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                                        # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
         )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1


        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',color='orange', label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year (Solar Configuration)")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")
# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 6.17 hours
# 1980: 0.00 extra training hours
# 1981: 6.13 extra training hours
# 1982: 26.41 extra training hours
# 1983: 9.26 extra training hours
# 1984: 1.32 extra training hours
# 1985: 14.13 extra training hours
# 1986: 20.76 extra training hours
# 1987: 24.74 extra training hours
# 1988: 0.00 extra training hours
# 1989: 0.26 extra training hours
# 1990: 2.62 extra training hours
# 1991: 7.76 extra training hours
# 1992: 1.21 extra training hours
# 1993: 10.77 extra training hours
# 1994: 0.00 extra training hours
# 1995: 4.79 extra training hours
# 1996: 7.32 extra training hours
# 1997: 0.00 extra training hours
# 1998: 20.19 extra training hours
# 1999: 9.59 extra training hours
# 2000: 0.00 extra training hours
# 2001: 7.16 extra training hours
# 2002: 0.09 extra training hours
# 2003: 2.14 extra training hours
# 2004: 0.00 extra training hours
# 2005: 6.53 extra training hours
# 2006: 4.27 extra training hours
# 2007: 8.11 extra training hours
# 2008: 0.05 extra training hours
# 2009: 6.49 extra training hours
# 2010: 5.98 extra training hours
# 2011: 0.20 extra training hours
# 2012: 4.27 extra training hours
# 2013: 2.63 extra training hours
# 2014: 9.61 extra training hours
# 2015: 26.57 extra training hours
# 2016: 11.77 extra training hours
# 2017: 0.00 extra training hours
# 2018: 8.44 extra training hours
# 2019: 0.00 extra training hours
# 2020: 0.05 extra training hours
# 2021: 0.00 extra training hours
# 2022: 6.20 extra training hours
# 2023: 0.00 extra training hours
# 2024: 0.00 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar_dc"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 0 hours with unmet load
# 1981: 8 hours with unmet load
# 1982: 33 hours with unmet load
# 1983: 11 hours with unmet load
# 1984: 4 hours with unmet load
# 1985: 20 hours with unmet load
# 1986: 28 hours with unmet load
# 1987: 33 hours with unmet load
# 1988: 0 hours with unmet load
# 1989: 2 hours with unmet load
# 1990: 5 hours with unmet load
# 1991: 12 hours with unmet load
# 1992: 2 hours with unmet load
# 1993: 16 hours with unmet load
# 1994: 0 hours with unmet load
# 1995: 9 hours with unmet load
# 1996: 11 hours with unmet load
# 1997: 0 hours with unmet load
# 1998: 25 hours with unmet load
# 1999: 13 hours with unmet load
# 2000: 0 hours with unmet load
# 2001: 8 hours with unmet load
# 2002: 1 hours with unmet load
# 2003: 3 hours with unmet load
# 2004: 0 hours with unmet load
# 2005: 9 hours with unmet load
# 2006: 6 hours with unmet load
# 2007: 9 hours with unmet load
# 2008: 1 hours with unmet load
# 2009: 8 hours with unmet load
# 2010: 10 hours with unmet load
# 2011: 2 hours with unmet load
# 2012: 6 hours with unmet load
# 2013: 5 hours with unmet load
# 2014: 12 hours with unmet load
# 2015: 32 hours with unmet load
# 2016: 15 hours with unmet load
# 2017: 0 hours with unmet load
# 2018: 10 hours with unmet load
# 2019: 0 hours with unmet load
# 2020: 1 hours with unmet load
# 2021: 0 hours with unmet load
# 2022: 12 hours with unmet load
# 2023: 0 hours with unmet load
# 2024: 0 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 8.49 hours/year
# Maximum: 33 hours in 1987
# Minimum: 0 hours in 2024

# %% [markdown]
# # Wind

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()


import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_wind_dc"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]*0
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            #print(f"Superficial NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        #model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )


    model.setObjective(
        gp.quicksum(unmet_load[t] for t in range(hours)),
        GRB.MINIMIZE
    )
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    #plt.plot(df_dispatch["Hour"], df_dispatch["Charge (kW)"], label="Charge", linestyle='-.')
    #plt.plot(df_dispatch["Hour"], df_dispatch["Discharge (kW)"], label="Discharge", linestyle='-.')
    #plt.plot(df_dispatch["Hour"], df_dispatch["Unmet (kW)"], label="Unmet", color="red", linewidth=2)
    #plt.plot(df_dispatch["Hour"], df_dispatch["Curtailment (kW)"], label="Curtailment", linestyle=':')
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        

        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
       # plt.plot(df_dispatch["Hour"], df_dispatch["Charge (kW)"], label="Charge", linestyle='-.')
        #plt.plot(df_dispatch["Hour"], df_dispatch["Discharge (kW)"], label="Discharge", linestyle='-.')
        #plt.plot(df_dispatch["Hour"], df_dispatch["Unmet (kW)"], label="Unmet", color="red", linewidth=2)
        #plt.plot(df_dispatch["Hour"], df_dispatch["Curtailment (kW)"], label="Curtailment", linestyle=':')
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76886457 nonzeros
# Model fingerprint: 0x4963e1ec
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8764 columns (presolve time = 8s)...
# Presolve removed 8764 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 17587 rows and 17587 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 3 rows and 8763 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8765 columns (presolve time = 11s)...
# Presolve removed 8766 rows and 8765 columns (presolve time = 19s)...
# Presolve removed 8766 rows and 8765 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8766 columns
# Presolve time: 22.32s
# Presolved: 70077 rows, 35041 columns, 157606 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35041 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52365 rows, 26155 columns, 130976 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.5487013e+08   1.350070e+06   1.600140e+07     43s
#     2667    9.5551172e+13   1.413794e+03   4.169273e+08     45s
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 2.176454e+10, 13816 iterations, 4.98 seconds (2.61 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2.176454e+10 2.1765e+10  0.00%     -   46s
#
# Explored 1 nodes (13816 simplex iterations) in 47.80 seconds (66.91 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.17645e+10
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.176453770902e+10, best bound 2.176453770902e+10, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 0.00 PV
# Wind Capacity: 1267.14 HAWT
# Battery Capacity: 42941440.40 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2901382076.79 kWh
# Total Energy Generated: 5580397248.28 kWh
# Total Energy Used (along with efficiency losses): 2679015171.49 kWh
# Utilization Percentage: 48.01%
# $7558590.37 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 0.00 PV
# Solar Initial Cost:    $0.00
# Wind Initial Capacity: 1267.14 HAWT
# Wind Initial Cost:     $6479922861.07
# Battery Initial Capacity: 42941440.40 kWh
# Battery Initial Cost:  $15373035662.71
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -0.00 PV
# Solar Redundant Cost:    $-0.00
# Wind Redundant Capacity: 111.86 HAWT
# Wind Redundant Cost:     $572047590.18
# Battery Redundant Capacity: 158883.33 kWh
# Battery Redundant Cost:  $56880231.95
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $0.00
# Solar OPEX:         $0.00
# Solar Replacement:  $0.00
# Solar Salvage:     -$0.00
# Wind CAPEX:         $7051970451.25
# Wind OPEX:          $1509374156.74
# Wind Replacement:   $0.00
# Wind Salvage:      -$1281269952.64
# Battery CAPEX:      $15429915894.66
# Battery OPEX:       $4648531081.03
# Battery Replacement:$96037389.43
# Battery Salvage:   -$5606911641.00
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $21860575098.44
#
# === 2024 Results ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0            1 0.0210     0.000000
# discharge          2           77 0.2763     0.000014
# discharge        111          115 0.0191     0.000000
# discharge        119          127 0.0141     0.000000
# discharge        131          132 0.0002     0.000000
# discharge        133          138 0.0093     0.000000
# discharge        142          170 0.0298     0.000000
# discharge        175          200 0.0040     0.000000
# discharge        201          231 0.0020     0.000000
# discharge        233          256 0.0209     0.000000
# discharge        260          305 0.0215     0.000000
# discharge        309          388 0.0268     0.000000
# discharge        397          434 0.0238     0.000000
# discharge        436          439 0.0051     0.000000
# discharge        442          488 0.0023     0.000000
# discharge        491          503 0.0202     0.000000
# discharge        507          578 0.0755     0.000001
# discharge        579          586 0.0384     0.000000
# discharge        591          594 0.0114     0.000000
# discharge        597          599 0.0073     0.000000
# discharge        607          610 0.0017     0.000000
# discharge        611          614 0.0045     0.000000
# discharge        615          621 0.0309     0.000000
# discharge        627          698 0.1385     0.000004
# discharge        708          764 0.1292     0.000004
# discharge        775          794 0.0785     0.000002
# discharge        795          797 0.0043     0.000000
# discharge        806          808 0.0015     0.000000
# discharge        811          879 0.0051     0.000000
# discharge        881          885 0.0072     0.000000
# discharge        888          904 0.0152     0.000000
# discharge        907          909 0.0009     0.000000
# discharge        911          979 0.0135     0.000000
# discharge        982         1021 0.0004     0.000000
# discharge       1022         1056 0.0817     0.000002
# discharge       1067         1074 0.0160     0.000000
# discharge       1080         1106 0.0410     0.000000
# discharge       1117         1174 0.0875     0.000002
# discharge       1185         1194 0.0419     0.000000
# discharge       1196         1197 0.0004     0.000000
# discharge       1209         1225 0.0663     0.000001
# discharge       1231         1286 0.0004     0.000000
# discharge       1287         1320 0.0134     0.000000
# discharge       1323         1487 0.2116     0.000009
# discharge       1504         1547 0.0001     0.000000
# discharge       1548         1561 0.0633     0.000001
# discharge       1563         1564 0.0005     0.000000
# discharge       1570         1584 0.0265     0.000000
# discharge       1590         1606 0.0534     0.000001
# discharge       1615         1636 0.0327     0.000000
# discharge       1640         1670 0.0043     0.000000
# discharge       1673         1685 0.0347     0.000000
# discharge       1693         1701 0.0271     0.000000
# discharge       1709         1719 0.0042     0.000000
# discharge       1720         1808 0.0006     0.000000
# discharge       1809         1825 0.0711     0.000001
# discharge       1836         1885 0.0405     0.000000
# discharge       1891         1911 0.0037     0.000000
# discharge       1912         1919 0.0231     0.000000
# discharge       1921         1925 0.0098     0.000000
# discharge       1929         1946 0.0580     0.000001
# discharge       1957         1966 0.0447     0.000001
# discharge       1973         2041 0.0014     0.000000
# discharge       2042         2047 0.0108     0.000000
# discharge       2049         2082 0.0006     0.000000
# discharge       2084         2116 0.0918     0.000002
# discharge       2124         2126 0.0022     0.000000
# discharge       2127         2303 0.0310     0.000000
# discharge       2306         2325 0.0203     0.000000
# discharge       2328         2366 0.0242     0.000000
# discharge       2368         2371 0.0039     0.000000
# discharge       2375         2405 0.0105     0.000000
# discharge       2407         2420 0.0232     0.000000
# discharge       2423         2428 0.0032     0.000000
# discharge       2429         2488 0.0429     0.000001
# discharge       2494         2590 0.0011     0.000000
# discharge       2592         2711 0.0804     0.000002
# discharge       2717         2748 0.0009     0.000000
# discharge       2749         2758 0.0120     0.000000
# discharge       2761         2869 0.0002     0.000000
# discharge       2870         2905 0.1738     0.000006
# discharge       2914         2929 0.0832     0.000002
# discharge       2947         2956 0.0429     0.000001
# discharge       2959         2992 0.1859     0.000007
# discharge       2997         3027 0.1359     0.000004
# discharge       3036         3040 0.0065     0.000000
# discharge       3062         3114 0.0261     0.000000
# discharge       3120         3154 0.0393     0.000000
# discharge       3155         3158 0.0111     0.000000
# discharge       3165         3170 0.0145     0.000000
# discharge       3179         3192 0.0525     0.000001
# discharge       3199         3202 0.0080     0.000000
# discharge       3209         3228 0.0002     0.000000
# discharge       3229         3253 0.0028     0.000000
# discharge       3257         3269 0.0391     0.000000
# discharge       3272         3288 0.0947     0.000002
# discharge       3290         3291 0.0002     0.000000
# discharge       3295         3316 0.1048     0.000003
# discharge       3323         3363 0.2412     0.000011
# discharge       3371         3383 0.0475     0.000001
# discharge       3411         3441 0.0042     0.000000
# discharge       3443         3456 0.0119     0.000000
# discharge       3461         3489 0.0022     0.000000
# discharge       3491         3493 0.0070     0.000000
# discharge       3497         3503 0.0227     0.000000
# discharge       3508         3544 0.0095     0.000000
# discharge       3547         3567 0.0193     0.000000
# discharge       3573         3598 0.1036     0.000002
# discharge       3608         3621 0.0070     0.000000
# discharge       3624         3666 0.0141     0.000000
# discharge       3668         3699 0.1625     0.000006
# discharge       3705         3712 0.0159     0.000000
# discharge       3731         3736 0.0210     0.000000
# discharge       3740         3778 0.0445     0.000001
# discharge       3779         3790 0.0525     0.000001
# discharge       3800         3806 0.0092     0.000000
# discharge       3807         3821 0.0643     0.000001
# discharge       3828         3832 0.0161     0.000000
# discharge       3839         3860 0.0522     0.000001
# discharge       3864         3883 0.0377     0.000000
# discharge       3890         3902 0.0050     0.000000
# discharge       3905         3912 0.0046     0.000000
# discharge       3914         4010 0.4853     0.000039
# discharge       4019         4022 0.0106     0.000000
# discharge       4067         4073 0.0169     0.000000
# discharge       4095         4099 0.0072     0.000000
# discharge       4115         4129 0.0702     0.000001
# discharge       4137         4170 0.1508     0.000005
# discharge       4175         4179 0.0136     0.000000
# discharge       4200         4242 0.2229     0.000010
# discharge       4244         4247 0.0017     0.000000
# discharge       4250         4252 0.0006     0.000000
# discharge       4278         4320 0.0736     0.000001
# discharge       4337         4344 0.0240     0.000000
# discharge       4350         4364 0.0203     0.000000
# discharge       4368         4420 0.0731     0.000001
# discharge       4428         4429 0.0007     0.000000
# discharge       4430         4440 0.0460     0.000001
# discharge       4451         4452 0.0022     0.000000
# discharge       4455         4464 0.0354     0.000000
# discharge       4470         4476 0.0013     0.000000
# discharge       4477         4483 0.0181     0.000000
# discharge       4487         4489 0.0005     0.000000
# discharge       4491         4493 0.0063     0.000000
# discharge       4496         4500 0.0026     0.000000
# discharge       4501         4512 0.0430     0.000001
# discharge       4521         4545 0.1302     0.000004
# discharge       4547         4559 0.0538     0.000001
# discharge       4572         4597 0.0093     0.000000
# discharge       4598         4658 0.3184     0.000019
# discharge       4664         4704 0.1972     0.000008
# discharge       4715         4716 0.0029     0.000000
# discharge       4718         4722 0.0063     0.000000
# discharge       4725         4731 0.0220     0.000000
# discharge       4771         4775 0.0079     0.000000
# discharge       4787         4788 0.0008     0.000000
# discharge       4791         4796 0.0047     0.000000
# discharge       4832         4849 0.0862     0.000002
# discharge       4852         4871 0.0864     0.000002
# discharge       4878         5033 0.8568     0.000109
# discharge       5037         5040 0.0024     0.000000
# discharge       5087         5090 0.0092     0.000000
# discharge       5099         5100 0.0037     0.000000
# discharge       5103         5105 0.0006     0.000000
# discharge       5123         5124 0.0007     0.000000
# discharge       5147         5149 0.0038     0.000000
# discharge       5168         5184 0.0519     0.000001
# discharge       5192         5206 0.0527     0.000001
# discharge       5218         5232 0.0798     0.000002
# discharge       5237         5256 0.0796     0.000002
# discharge       5307         5344 0.0004     0.000000
# discharge       5345         5376 0.0543     0.000001
# discharge       5378         5381 0.0040     0.000000
# discharge       5387         5425 0.2114     0.000009
# discharge       5429         5448 0.0973     0.000002
# discharge       5455         5472 0.0777     0.000001
# discharge       5493         5502 0.0426     0.000001
# discharge       5506         5512 0.0284     0.000000
# discharge       5520         5534 0.0695     0.000001
# discharge       5582         5639 0.0481     0.000001
# discharge       5644         5664 0.0374     0.000000
# discharge       5670         5687 0.0352     0.000000
# discharge       5693         5716 0.0880     0.000002
# discharge       5722         5789 0.3882     0.000026
# discharge       5791         5802 0.0400     0.000000
# discharge       5809         5855 0.2664     0.000013
# discharge       5858         5885 0.1403     0.000004
# discharge       5918         5925 0.0184     0.000000
# discharge       5936         5939 0.0033     0.000000
# discharge       5943         5952 0.0387     0.000000
# discharge       5964         6003 0.2230     0.000010
# discharge       6045         6062 0.0064     0.000000
# discharge       6063         6071 0.0263     0.000000
# discharge       6074         6098 0.0755     0.000001
# discharge       6106         6112 0.0149     0.000000
# discharge       6122         6178 0.0786     0.000002
# discharge       6179         6181 0.0030     0.000000
# discharge       6195         6262 0.1056     0.000003
# discharge       6268         6340 0.4232     0.000031
# discharge       6348         6366 0.0973     0.000002
# discharge       6372         6379 0.0197     0.000000
# discharge       6380         6388 0.0174     0.000000
# discharge       6394         6411 0.0740     0.000001
# discharge       6416         6423 0.0176     0.000000
# discharge       6432         6433 0.0009     0.000000
# discharge       6440         6454 0.0563     0.000001
# discharge       6468         6470 0.0040     0.000000
# discharge       6498         6528 0.0064     0.000000
# discharge       6531         6545 0.0104     0.000000
# discharge       6549         6557 0.0236     0.000000
# discharge       6562         6590 0.1417     0.000004
# discharge       6606         6631 0.0699     0.000001
# discharge       6634         6650 0.0795     0.000002
# discharge       6659         6673 0.0663     0.000001
# discharge       6681         6722 0.2434     0.000011
# discharge       6751         6758 0.0037     0.000000
# discharge       6759         6783 0.0059     0.000000
# discharge       6786         6816 0.0448     0.000001
# discharge       6818         6844 0.1211     0.000003
# discharge       6853         6855 0.0075     0.000000
# discharge       6868         6879 0.0054     0.000000
# discharge       6880         6916 0.0107     0.000000
# discharge       6919         6929 0.0509     0.000001
# discharge       6933         6949 0.0002     0.000000
# discharge       6950         6987 0.0979     0.000002
# discharge       6997         7008 0.0583     0.000001
# discharge       7020         7036 0.0753     0.000001
# discharge       7039         7082 0.1879     0.000007
# discharge       7094         7095 0.0022     0.000000
# discharge       7107         7127 0.0381     0.000000
# discharge       7133         7151 0.0349     0.000000
# discharge       7156         7167 0.0014     0.000000
# discharge       7168         7183 0.0033     0.000000
# discharge       7185         7222 0.0479     0.000001
# discharge       7229         7324 0.0329     0.000000
# discharge       7330         7342 0.0201     0.000000
# discharge       7345         7366 0.0422     0.000000
# discharge       7371         7463 0.0942     0.000002
# discharge       7480         7530 0.0141     0.000000
# discharge       7531         7533 0.0012     0.000000
# discharge       7536         7551 0.0016     0.000000
# discharge       7553         7563 0.0206     0.000000
# discharge       7566         7581 0.0281     0.000000
# discharge       7590         7623 0.0059     0.000000
# discharge       7625         7666 0.0077     0.000000
# discharge       7669         7677 0.0333     0.000000
# discharge       7683         7703 0.0654     0.000001
# discharge       7709         7720 0.0025     0.000000
# discharge       7721         7725 0.0119     0.000000
# discharge       7728         7779 0.0974     0.000002
# discharge       7786         7873 0.1458     0.000005
# discharge       7885         7945 0.0442     0.000001
# discharge       7953         8006 0.0039     0.000000
# discharge       8009         8031 0.1025     0.000002
# discharge       8044         8071 0.0200     0.000000
# discharge       8077         8082 0.0243     0.000000
# discharge       8088         8114 0.0673     0.000001
# discharge       8120         8194 0.0948     0.000002
# discharge       8197         8199 0.0049     0.000000
# discharge       8209         8264 0.0883     0.000002
# discharge       8276         8314 0.0316     0.000000
# discharge       8318         8319 0.0002     0.000000
# discharge       8320         8349 0.0220     0.000000
# discharge       8352         8392 0.0171     0.000000
# discharge       8394         8395 0.0003     0.000000
# discharge       8399         8439 0.0018     0.000000
# discharge       8440         8451 0.0560     0.000001
# discharge       8455         8496 0.0540     0.000001
# discharge       8501         8541 0.0174     0.000000
# discharge       8549         8556 0.0057     0.000000
# discharge       8557         8568 0.0560     0.000001
# discharge       8574         8608 0.0034     0.000000
# discharge       8609         8614 0.0128     0.000000
# discharge       8616         8706 0.0182     0.000000
# discharge       8709         8750 0.0209     0.000000
#
# Total Estimated Degradation: 0.000490
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_wind_dc\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_wind_dc\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_wind_dc\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_wind_dc\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 3920204.77 kWh
# Year 2022: Unmet Load = 21292686.95 kWh
# Year 2021: Unmet Load = 5273870.95 kWh
# Year 2020: Unmet Load = 34014195.70 kWh
# Year 2019: Unmet Load = 69196772.78 kWh
# Year 2018: Unmet Load = 41026376.76 kWh
# Year 2017: Unmet Load = 27248094.19 kWh
# Year 2016: Unmet Load = 70604596.79 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 62976609.80 kWh
# Year 2010: Unmet Load = 22266656.07 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 25558059.27 kWh
# Year 2007: Unmet Load = 23678362.74 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 23468047.83 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 56351326.70 kWh
# Year 2001: Unmet Load = 18121775.39 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 12046834.07 kWh
# Year 1998: Unmet Load = 23417127.72 kWh
# Year 1997: Unmet Load = 27699697.90 kWh
# Year 1996: Unmet Load = 12412260.85 kWh
# Year 1995: Unmet Load = 4921893.40 kWh
# Year 1994: Unmet Load = 9130706.58 kWh
# Year 1993: Unmet Load = 26527668.50 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 19245460.50 kWh
# Year 1990: Unmet Load = 4270934.67 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 10608704.77 kWh
# Year 1987: Unmet Load = 14469600.52 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 85044474.02 kWh
# Year 1982: Unmet Load = 45115790.03 kWh
# Year 1981: Unmet Load = 4853806.04 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 17883613.25 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 85044474.02 kWh (Year 1983)

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_wind_dc"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                                        # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
         )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1


        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',color='green',label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year (Wind Configuration)")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")
# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 83.21 hours
# 1980: 0.00 extra training hours
# 1981: 22.96 extra training hours
# 1982: 212.23 extra training hours
# 1983: 393.32 extra training hours
# 1984: 0.00 extra training hours
# 1985: 0.00 extra training hours
# 1986: 0.00 extra training hours
# 1987: 68.15 extra training hours
# 1988: 48.49 extra training hours
# 1989: 0.00 extra training hours
# 1990: 19.68 extra training hours
# 1991: 87.13 extra training hours
# 1992: 0.00 extra training hours
# 1993: 123.77 extra training hours
# 1994: 44.21 extra training hours
# 1995: 22.40 extra training hours
# 1996: 56.47 extra training hours
# 1997: 127.84 extra training hours
# 1998: 109.05 extra training hours
# 1999: 54.74 extra training hours
# 2000: 0.00 extra training hours
# 2001: 84.36 extra training hours
# 2002: 257.31 extra training hours
# 2003: 0.00 extra training hours
# 2004: 0.00 extra training hours
# 2005: 108.39 extra training hours
# 2006: 0.00 extra training hours
# 2007: 107.24 extra training hours
# 2008: 120.77 extra training hours
# 2009: 0.00 extra training hours
# 2010: 105.95 extra training hours
# 2011: 295.52 extra training hours
# 2012: 0.00 extra training hours
# 2013: 0.00 extra training hours
# 2014: 0.00 extra training hours
# 2015: 0.00 extra training hours
# 2016: 333.50 extra training hours
# 2017: 131.58 extra training hours
# 2018: 186.95 extra training hours
# 2019: 321.90 extra training hours
# 2020: 161.61 extra training hours
# 2021: 22.62 extra training hours
# 2022: 99.14 extra training hours
# 2023: 17.39 extra training hours
# 2024: 0.00 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_wind_dc"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 0 hours with unmet load
# 1981: 30 hours with unmet load
# 1982: 245 hours with unmet load
# 1983: 446 hours with unmet load
# 1984: 0 hours with unmet load
# 1985: 0 hours with unmet load
# 1986: 0 hours with unmet load
# 1987: 93 hours with unmet load
# 1988: 63 hours with unmet load
# 1989: 0 hours with unmet load
# 1990: 26 hours with unmet load
# 1991: 120 hours with unmet load
# 1992: 0 hours with unmet load
# 1993: 158 hours with unmet load
# 1994: 57 hours with unmet load
# 1995: 32 hours with unmet load
# 1996: 70 hours with unmet load
# 1997: 155 hours with unmet load
# 1998: 155 hours with unmet load
# 1999: 68 hours with unmet load
# 2000: 0 hours with unmet load
# 2001: 112 hours with unmet load
# 2002: 306 hours with unmet load
# 2003: 0 hours with unmet load
# 2004: 0 hours with unmet load
# 2005: 135 hours with unmet load
# 2006: 0 hours with unmet load
# 2007: 137 hours with unmet load
# 2008: 165 hours with unmet load
# 2009: 0 hours with unmet load
# 2010: 134 hours with unmet load
# 2011: 391 hours with unmet load
# 2012: 0 hours with unmet load
# 2013: 0 hours with unmet load
# 2014: 0 hours with unmet load
# 2015: 0 hours with unmet load
# 2016: 420 hours with unmet load
# 2017: 149 hours with unmet load
# 2018: 253 hours with unmet load
# 2019: 418 hours with unmet load
# 2020: 216 hours with unmet load
# 2021: 40 hours with unmet load
# 2022: 127 hours with unmet load
# 2023: 19 hours with unmet load
# 2024: 0 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 105.33 hours/year
# Maximum: 446 hours in 1983
# Minimum: 0 hours in 2024

# %% [markdown]
# # Hybrid Wind Solar

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()


import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_solar-wind_dc"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:
        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        
        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

        # === Save Capacity, Cost, and Utilization Metrics for All Years ===
        print("Starting capacity, cost, and utilization metrics collection...")
        results_by_year = []
        for year in range(2024, 1979, -1):
            print(f"Processing year {year} for capacity, cost, and utilization metrics...")
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                print(f"Year {year}: Skipping due to missing resource data.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                print(f"Year {year}: Dispatch simulation successful, calculating metrics...")
                # Calculate utilization metrics
                total_curtailed = np.sum(dispatch_result["curtailment"])
                solar_gen = solar_resource * opt_results["solar"]
                wind_gen = wind_resource * opt_results["wind"]
                total_generated = np.sum(solar_gen + wind_gen)
                total_power_consumed = total_generated - total_curtailed
                utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

                # Calculate battery replacement cost
                yearly_degradation = dispatch_result["degradation"]
                battery_replacement = calculate_battery_replacement_cost(
                    battery_capex=opt_results["battery_capex"],
                    degradation=yearly_degradation,
                    inf=inf,
                    dis=dis,
                    life_battery=life_battery
                )

                # Calculate total NPC
                total_npc = (
                    opt_results["solar_capex"] +
                    opt_results["solar_opex"] +
                    opt_results["solar_replacement"] -
                    opt_results["solar_salvage"] +
                    opt_results["wind_capex"] +
                    opt_results["wind_opex"] +
                    opt_results["wind_replacement"] -
                    opt_results["wind_salvage"] +
                    opt_results["battery_capex"] +
                    opt_results["battery_opex"] +
                    battery_replacement -
                    opt_results["battery_salvage"] +
                    opt_results["inverter_capex"] +
                    opt_results["inverter_opex"] +
                    opt_results["inverter_replacement"] -
                    opt_results["inverter_salvage"]
                )

                # Store results
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": opt_results["solar"],
                    "Wind_Capacity_HAWT": opt_results["wind"],
                    "Battery_Capacity_kWh": opt_results["battery"],
                    "Inverter_Capacity_kW": inverter_capacity,
                    "Solar_CAPEX": opt_results["solar_capex"],
                    "Solar_OPEX": opt_results["solar_opex"],
                    "Solar_Replacement": opt_results["solar_replacement"],
                    "Solar_Salvage": opt_results["solar_salvage"],
                    "Wind_CAPEX": opt_results["wind_capex"],
                    "Wind_OPEX": opt_results["wind_opex"],
                    "Wind_Replacement": opt_results["wind_replacement"],
                    "Wind_Salvage": opt_results["wind_salvage"],
                    "Battery_CAPEX": opt_results["battery_capex"],
                    "Battery_OPEX": opt_results["battery_opex"],
                    "Battery_Replacement": battery_replacement,
                    "Battery_Salvage": opt_results["battery_salvage"],
                    "Inverter_CAPEX": opt_results["inverter_capex"],
                    "Inverter_OPEX": opt_results["inverter_opex"],
                    "Inverter_Replacement": opt_results["inverter_replacement"],
                    "Inverter_Salvage": opt_results["inverter_salvage"],
                    "Total_NPC": total_npc,
                    "Utilization_Percentage": utilization_percentage,
                    "Total_Curtailed_kWh": total_curtailed,
                    "Total_Generated_kWh": total_generated,
                    "Total_Power_Consumed_kWh": total_power_consumed,
                    "Total_Unmet_kWh": dispatch_result["total_unmet"]
                })
                print(f"Year {year}: Metrics added - Utilization: {utilization_percentage:.2f}%, NPC: {total_npc:.2f}, Unmet: {dispatch_result['total_unmet']:.2f} kWh")
            else:
                print(f"Year {year}: Metrics save failed due to dispatch simulation error.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })

        # Save results to CSV
        try:
            df_results = pd.DataFrame(results_by_year)
            csv_path = os.path.join(output_dir, "capacity_and_costs_by_year.csv")
            df_results.to_csv(csv_path, index=False)
            print(f"Saved capacity, cost, and utilization metrics to {csv_path}")
            print(f"CSV file location: {os.path.abspath(csv_path)}")
        except Exception as e:
            print(f"Error saving CSV: {e}")

        # === Plot NPC Variation Across Years ===
        print("Starting NPC variation plotting...")
        try:
            valid_npc_data = df_results[df_results["Total_NPC"].notna()][["Year", "Total_NPC"]]
            if valid_npc_data.empty:
                print("Error: No valid NPC data found for plotting.")
            else:
                plt.figure(figsize=(15, 8))
                plt.plot(valid_npc_data["Year"], valid_npc_data["Total_NPC"], marker='o', linestyle='-', color='b')
                plt.title("NPC Variation Across Years (1979-2024)")
                plt.xlabel("Year")
                plt.ylabel("Total NPC ($)")
                plt.grid(True)
                plt.gca().invert_xaxis()  # Reverse x-axis to show 2024 to 1979
                plt.tight_layout()
                plot_path = os.path.join(output_dir, "npc_variation_by_year.png")
                plt.savefig(plot_path)
                plt.close()
                print(f"Saved NPC variation plot to {plot_path}")
                print(f"Plot file location: {os.path.abspath(plot_path)}")
        except Exception as e:
            print(f"Error plotting NPC variation: {e}")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0xdd510e10
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17533 rows and 17532 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 24.96s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52506 rows, 26248 columns, 135627 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7746084e+08   5.102861e+05   4.308989e+06     40s
#      866    3.5022488e+14   2.245301e+04   1.435116e+09     40s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.740614e+09, 17303 iterations, 3.90 seconds (2.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.7406e+09    0    1          - 4.7406e+09      -     -   43s
# H    0     0                    4.740614e+09 4.7406e+09  0.00%     -   44s
#      0     0 4.7406e+09    0    1 4.7406e+09 4.7406e+09  0.00%     -   44s
#
# Explored 1 nodes (17303 simplex iterations) in 45.20 seconds (67.66 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.74061e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.740613839056e+09, best bound 4.740613839056e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 10091678.31 PV
# Wind Capacity: 180.13 HAWT
# Battery Capacity: 5959201.57 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3250351341.54 kWh
# Total Energy Generated: 6026555727.62 kWh
# Total Energy Used (along with efficiency losses): 2776204386.08 kWh
# Utilization Percentage: 46.07%
# $19594661.98 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 10091678.31 PV
# Solar Initial Cost:    $938021498.60
# Wind Initial Capacity: 180.13 HAWT
# Wind Initial Cost:     $921156293.49
# Battery Initial Capacity: 5959201.57 kWh
# Battery Initial Cost:  $2133394160.35
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -32293.37 PV
# Solar Redundant Cost:    $-3001668.80
# Wind Redundant Capacity: 15.90 HAWT
# Wind Redundant Cost:     $81319677.59
# Battery Redundant Capacity: 22049.05 kWh
# Battery Redundant Cost:  $7893558.39
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $935019829.81
# Solar OPEX:         $1021289141.51
# Solar Replacement:  $0.00
# Solar Salvage:     -$271813461.80
# Wind CAPEX:         $1002475971.08
# Wind OPEX:          $214565749.24
# Wind Replacement:   $0.00
# Wind Salvage:      -$182139495.46
# Battery CAPEX:      $2141287718.75
# Battery OPEX:       $645100244.36
# Battery Replacement:$248964435.31
# Battery Salvage:   -$778099577.40
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $4989578274.37
#
# === 2024 Results ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           12 0.2765     0.000014
# discharge         15           36 0.5493     0.000049
# discharge         41           62 0.7460     0.000085
# discharge         70           84 0.4953     0.000041
# discharge         89          110 0.3913     0.000027
# discharge        115          133 0.5069     0.000043
# discharge        141          158 0.4127     0.000030
# discharge        162          180 0.3920     0.000027
# discharge        184          202 0.1437     0.000004
# discharge        207          228 0.1420     0.000004
# discharge        230          253 0.1611     0.000005
# discharge        256          263 0.0015     0.000000
# discharge        265          275 0.0369     0.000000
# discharge        280          300 0.1394     0.000004
# discharge        302          324 0.2610     0.000013
# discharge        327          349 0.4251     0.000031
# discharge        355          373 0.3622     0.000023
# discharge        375          396 0.5395     0.000048
# discharge        400          423 0.1645     0.000006
# discharge        427          442 0.5179     0.000044
# discharge        448          468 0.3326     0.000020
# discharge        471          492 0.5097     0.000043
# discharge        496          516 0.3284     0.000020
# discharge        519          529 0.0167     0.000000
# discharge        535          542 0.1202     0.000003
# discharge        546          549 0.0020     0.000000
# discharge        550          555 0.0049     0.000000
# discharge        556          557 0.0001     0.000000
# discharge        560          567 0.1204     0.000003
# discharge        571          590 0.7127     0.000079
# discharge        597          613 0.4840     0.000039
# discharge        619          634 0.2162     0.000009
# discharge        643          660 0.2424     0.000011
# discharge        663          685 0.6250     0.000062
# discharge        689          709 0.3782     0.000025
# discharge        712          732 0.2575     0.000013
# discharge        735          756 0.6233     0.000062
# discharge        761          780 0.3241     0.000019
# discharge        783          804 0.4825     0.000039
# discharge        810          818 0.1185     0.000003
# discharge        820          829 0.0769     0.000001
# discharge        836          852 0.2802     0.000015
# discharge        855          876 0.1640     0.000006
# discharge        878          900 0.3666     0.000024
# discharge        903          924 0.1414     0.000004
# discharge        926          949 0.0742     0.000001
# discharge        952          974 0.1895     0.000007
# discharge        981          996 0.4469     0.000034
# discharge       1000         1021 0.2366     0.000011
# discharge       1025         1044 0.3732     0.000025
# discharge       1047         1068 0.4352     0.000032
# discharge       1071         1092 0.2117     0.000009
# discharge       1094         1117 0.5259     0.000046
# discharge       1125         1127 0.0060     0.000000
# discharge       1137         1140 0.0182     0.000000
# discharge       1141         1164 0.5748     0.000053
# discharge       1167         1188 0.4952     0.000041
# discharge       1191         1212 0.4187     0.000030
# discharge       1215         1236 0.3067     0.000017
# discharge       1239         1284 0.2688     0.000014
# discharge       1287         1303 0.0555     0.000001
# discharge       1306         1308 0.0043     0.000000
# discharge       1309         1332 0.2832     0.000015
# discharge       1335         1356 0.0224     0.000000
# discharge       1357         1428 0.4235     0.000031
# discharge       1431         1452 0.4811     0.000039
# discharge       1456         1477 0.6683     0.000070
# discharge       1481         1500 0.2563     0.000013
# discharge       1502         1524 0.1472     0.000005
# discharge       1526         1549 0.3561     0.000023
# discharge       1555         1572 0.4471     0.000034
# discharge       1576         1596 0.4827     0.000039
# discharge       1601         1620 0.3441     0.000021
# discharge       1627         1644 0.3897     0.000027
# discharge       1649         1668 0.3143     0.000018
# discharge       1671         1692 0.5149     0.000044
# discharge       1695         1716 0.3661     0.000024
# discharge       1719         1739 0.1517     0.000005
# discharge       1742         1764 0.0679     0.000001
# discharge       1766         1783 0.1260     0.000004
# discharge       1785         1788 0.0423     0.000001
# discharge       1793         1812 0.4923     0.000041
# discharge       1815         1836 0.4358     0.000033
# discharge       1840         1859 0.1909     0.000007
# discharge       1862         1884 0.4762     0.000038
# discharge       1887         1907 0.0962     0.000002
# discharge       1910         1932 0.4255     0.000031
# discharge       1936         1956 0.4705     0.000037
# discharge       1964         1973 0.2105     0.000009
# discharge       1983         2004 0.2194     0.000010
# discharge       2007         2018 0.0046     0.000000
# discharge       2019         2025 0.0161     0.000000
# discharge       2029         2042 0.1265     0.000004
# discharge       2043         2052 0.1980     0.000008
# discharge       2055         2075 0.2545     0.000012
# discharge       2078         2099 0.3896     0.000027
# discharge       2103         2123 0.3901     0.000027
# discharge       2127         2147 0.0889     0.000002
# discharge       2149         2171 0.1533     0.000005
# discharge       2174         2195 0.1181     0.000003
# discharge       2199         2209 0.0053     0.000000
# discharge       2213         2243 0.1480     0.000005
# discharge       2245         2267 0.1135     0.000003
# discharge       2269         2291 0.2221     0.000010
# discharge       2294         2315 0.2590     0.000013
# discharge       2319         2339 0.1347     0.000004
# discharge       2341         2363 0.3393     0.000021
# discharge       2367         2388 0.1150     0.000003
# discharge       2391         2411 0.3650     0.000024
# discharge       2423         2435 0.2297     0.000010
# discharge       2439         2459 0.0324     0.000000
# discharge       2461         2483 0.3855     0.000026
# discharge       2487         2507 0.0874     0.000002
# discharge       2509         2531 0.1731     0.000006
# discharge       2534         2555 0.2766     0.000014
# discharge       2558         2579 0.0089     0.000000
# discharge       2581         2603 0.3235     0.000019
# discharge       2607         2627 0.1662     0.000006
# discharge       2630         2651 0.2169     0.000009
# discharge       2655         2675 0.2776     0.000015
# discharge       2678         2699 0.4532     0.000035
# discharge       2703         2723 0.2152     0.000009
# discharge       2726         2747 0.2057     0.000008
# discharge       2750         2771 0.2063     0.000009
# discharge       2774         2796 0.2990     0.000017
# discharge       2799         2819 0.0555     0.000001
# discharge       2822         2834 0.0002     0.000000
# discharge       2835         2843 0.0506     0.000001
# discharge       2845         2868 0.0925     0.000002
# discharge       2871         2891 0.5661     0.000052
# discharge       2896         2915 0.3612     0.000023
# discharge       2919         2939 0.3315     0.000020
# discharge       2943         2963 0.5346     0.000047
# discharge       2969         2988 0.5755     0.000054
# discharge       2994         3011 0.5544     0.000050
# discharge       3021         3035 0.4285     0.000032
# discharge       3039         3059 0.1822     0.000007
# discharge       3062         3083 0.0953     0.000002
# discharge       3086         3107 0.1155     0.000003
# discharge       3110         3131 0.2727     0.000014
# discharge       3134         3155 0.5081     0.000043
# discharge       3159         3179 0.4468     0.000034
# discharge       3184         3205 0.4680     0.000037
# discharge       3210         3227 0.2338     0.000011
# discharge       3230         3251 0.3176     0.000018
# discharge       3254         3275 0.4850     0.000039
# discharge       3280         3300 0.5011     0.000042
# discharge       3305         3324 0.4464     0.000034
# discharge       3330         3347 0.5381     0.000047
# discharge       3351         3371 0.4192     0.000030
# discharge       3375         3395 0.3097     0.000018
# discharge       3398         3419 0.1629     0.000006
# discharge       3423         3444 0.3873     0.000026
# discharge       3448         3468 0.3747     0.000025
# discharge       3474         3491 0.3443     0.000021
# discharge       3495         3515 0.2306     0.000010
# discharge       3519         3539 0.0835     0.000002
# discharge       3541         3563 0.4158     0.000030
# discharge       3567         3587 0.4958     0.000041
# discharge       3591         3611 0.2767     0.000014
# discharge       3614         3636 0.2732     0.000014
# discharge       3640         3649 0.0109     0.000000
# discharge       3651         3660 0.1865     0.000007
# discharge       3663         3683 0.5161     0.000044
# discharge       3687         3707 0.4552     0.000035
# discharge       3713         3731 0.3063     0.000017
# discharge       3735         3755 0.2888     0.000016
# discharge       3759         3779 0.4971     0.000041
# discharge       3783         3803 0.2800     0.000015
# discharge       3806         3826 0.4296     0.000032
# discharge       3831         3851 0.1884     0.000007
# discharge       3855         3875 0.2989     0.000017
# discharge       3878         3899 0.2621     0.000013
# discharge       3902         3923 0.3552     0.000023
# discharge       3927         3947 0.5035     0.000042
# discharge       3951         3971 0.5169     0.000044
# discharge       3976         3995 0.5078     0.000043
# discharge       4000         4019 0.4354     0.000033
# discharge       4023         4043 0.3119     0.000018
# discharge       4049         4067 0.4013     0.000028
# discharge       4073         4091 0.4095     0.000029
# discharge       4096         4115 0.3330     0.000020
# discharge       4119         4139 0.4326     0.000032
# discharge       4143         4163 0.4968     0.000041
# discharge       4167         4187 0.3184     0.000019
# discharge       4191         4211 0.5118     0.000043
# discharge       4216         4235 0.5046     0.000042
# discharge       4240         4259 0.4101     0.000029
# discharge       4263         4283 0.2515     0.000012
# discharge       4286         4307 0.3836     0.000026
# discharge       4311         4331 0.3980     0.000028
# discharge       4335         4355 0.3725     0.000025
# discharge       4360         4379 0.2792     0.000015
# discharge       4382         4403 0.3083     0.000018
# discharge       4407         4427 0.4225     0.000031
# discharge       4431         4451 0.3479     0.000022
# discharge       4455         4475 0.3535     0.000022
# discharge       4480         4499 0.4179     0.000030
# discharge       4504         4523 0.4190     0.000030
# discharge       4527         4547 0.5221     0.000045
# discharge       4553         4571 0.1925     0.000008
# discharge       4574         4595 0.3134     0.000018
# discharge       4599         4619 0.5258     0.000046
# discharge       4624         4643 0.5140     0.000044
# discharge       4648         4667 0.4531     0.000035
# discharge       4672         4691 0.5228     0.000045
# discharge       4696         4715 0.4075     0.000029
# discharge       4719         4739 0.3990     0.000028
# discharge       4743         4764 0.4050     0.000029
# discharge       4770         4787 0.4374     0.000033
# discharge       4792         4811 0.2224     0.000010
# discharge       4814         4835 0.4179     0.000030
# discharge       4839         4859 0.4776     0.000038
# discharge       4864         4883 0.4430     0.000034
# discharge       4888         4909 0.5955     0.000057
# discharge       4918         4932 0.5450     0.000049
# discharge       4942         4956 0.5476     0.000049
# discharge       4964         4980 0.5919     0.000056
# discharge       4990         5004 0.5818     0.000055
# discharge       5013         5028 0.5595     0.000051
# discharge       5034         5051 0.2971     0.000016
# discharge       5054         5075 0.3082     0.000018
# discharge       5079         5099 0.3625     0.000023
# discharge       5103         5123 0.3012     0.000017
# discharge       5127         5147 0.3505     0.000022
# discharge       5151         5171 0.4494     0.000034
# discharge       5175         5195 0.4635     0.000036
# discharge       5199         5219 0.4079     0.000029
# discharge       5223         5243 0.4811     0.000039
# discharge       5247         5267 0.3691     0.000024
# discharge       5271         5291 0.3652     0.000024
# discharge       5295         5315 0.3091     0.000018
# discharge       5318         5339 0.2864     0.000015
# discharge       5342         5363 0.4233     0.000031
# discharge       5367         5387 0.4774     0.000038
# discharge       5391         5411 0.5366     0.000047
# discharge       5416         5435 0.5126     0.000044
# discharge       5440         5459 0.4687     0.000037
# discharge       5464         5483 0.3363     0.000020
# discharge       5487         5508 0.5045     0.000042
# discharge       5513         5531 0.5281     0.000046
# discharge       5536         5555 0.3694     0.000024
# discharge       5559         5579 0.3100     0.000018
# discharge       5583         5603 0.2864     0.000015
# discharge       5606         5627 0.2671     0.000014
# discharge       5630         5651 0.3465     0.000022
# discharge       5655         5675 0.3523     0.000022
# discharge       5679         5699 0.3708     0.000024
# discharge       5703         5723 0.4892     0.000040
# discharge       5727         5747 0.5403     0.000048
# discharge       5752         5771 0.5505     0.000049
# discharge       5776         5795 0.5144     0.000044
# discharge       5800         5820 0.5307     0.000046
# discharge       5825         5844 0.5988     0.000058
# discharge       5849         5868 0.5494     0.000049
# discharge       5875         5891 0.4431     0.000034
# discharge       5895         5915 0.2267     0.000010
# discharge       5919         5940 0.3798     0.000025
# discharge       5945         5963 0.4557     0.000035
# discharge       5967         5988 0.5641     0.000052
# discharge       5992         6011 0.2894     0.000016
# discharge       6014         6035 0.1899     0.000007
# discharge       6038         6059 0.2042     0.000008
# discharge       6062         6083 0.2647     0.000013
# discharge       6087         6107 0.4572     0.000035
# discharge       6111         6132 0.2011     0.000008
# discharge       6137         6156 0.0719     0.000001
# discharge       6158         6180 0.5806     0.000054
# discharge       6186         6204 0.2304     0.000010
# discharge       6208         6228 0.1439     0.000004
# discharge       6232         6252 0.5439     0.000048
# discharge       6256         6276 0.5035     0.000042
# discharge       6280         6300 0.5657     0.000052
# discharge       6304         6324 0.5755     0.000054
# discharge       6328         6348 0.5009     0.000042
# discharge       6355         6372 0.5253     0.000045
# discharge       6376         6396 0.5062     0.000043
# discharge       6401         6420 0.5363     0.000047
# discharge       6425         6445 0.4900     0.000040
# discharge       6448         6468 0.3627     0.000023
# discharge       6471         6491 0.1236     0.000003
# discharge       6494         6516 0.1137     0.000003
# discharge       6519         6540 0.4722     0.000038
# discharge       6544         6564 0.5337     0.000047
# discharge       6568         6588 0.5854     0.000055
# discharge       6592         6611 0.1736     0.000006
# discharge       6614         6636 0.5318     0.000047
# discharge       6639         6660 0.4617     0.000036
# discharge       6663         6684 0.4621     0.000036
# discharge       6688         6708 0.5971     0.000057
# discharge       6712         6732 0.3233     0.000019
# discharge       6735         6756 0.1982     0.000008
# discharge       6758         6780 0.2785     0.000015
# discharge       6783         6804 0.2795     0.000015
# discharge       6807         6828 0.5519     0.000050
# discharge       6832         6852 0.5152     0.000044
# discharge       6856         6876 0.1429     0.000004
# discharge       6878         6900 0.2230     0.000010
# discharge       6902         6924 0.5620     0.000051
# discharge       6928         6948 0.2306     0.000010
# discharge       6950         6972 0.4801     0.000039
# discharge       6975         6996 0.4544     0.000035
# discharge       6999         7020 0.4590     0.000036
# discharge       7024         7044 0.5576     0.000051
# discharge       7048         7068 0.5634     0.000052
# discharge       7072         7092 0.3611     0.000023
# discharge       7095         7116 0.1585     0.000005
# discharge       7118         7140 0.3703     0.000024
# discharge       7143         7164 0.3124     0.000018
# discharge       7167         7188 0.4110     0.000029
# discharge       7193         7212 0.3848     0.000026
# discharge       7215         7236 0.3822     0.000026
# discharge       7239         7248 0.0121     0.000000
# discharge       7250         7260 0.1064     0.000003
# discharge       7262         7273 0.0110     0.000000
# discharge       7275         7284 0.0815     0.000002
# discharge       7286         7299 0.0317     0.000000
# discharge       7304         7307 0.0165     0.000000
# discharge       7310         7332 0.5449     0.000049
# discharge       7337         7357 0.4389     0.000033
# discharge       7361         7380 0.2883     0.000016
# discharge       7384         7400 0.1240     0.000003
# discharge       7403         7404 0.0003     0.000000
# discharge       7407         7415 0.0019     0.000000
# discharge       7417         7427 0.0100     0.000000
# discharge       7429         7453 0.5225     0.000045
# discharge       7460         7476 0.4819     0.000039
# discharge       7481         7500 0.3424     0.000021
# discharge       7504         7525 0.3421     0.000021
# discharge       7532         7550 0.4756     0.000038
# discharge       7555         7572 0.4318     0.000032
# discharge       7576         7596 0.3813     0.000026
# discharge       7599         7621 0.2746     0.000014
# discharge       7628         7644 0.2964     0.000016
# discharge       7647         7668 0.5432     0.000048
# discharge       7672         7693 0.4423     0.000033
# discharge       7696         7716 0.3283     0.000020
# discharge       7720         7740 0.1824     0.000007
# discharge       7743         7765 0.2459     0.000012
# discharge       7767         7788 0.3311     0.000020
# discharge       7791         7812 0.0501     0.000001
# discharge       7813         7836 0.1684     0.000006
# discharge       7838         7861 0.6208     0.000061
# discharge       7865         7884 0.3692     0.000024
# discharge       7887         7908 0.0099     0.000000
# discharge       7909         7918 0.0055     0.000000
# discharge       7920         7932 0.1635     0.000006
# discharge       7934         7957 0.4799     0.000039
# discharge       7964         7972 0.0882     0.000002
# discharge       7974         7980 0.0728     0.000001
# discharge       7983         8004 0.3904     0.000027
# discharge       8007         8028 0.6279     0.000063
# discharge       8032         8053 0.3776     0.000025
# discharge       8058         8076 0.5419     0.000048
# discharge       8080         8100 0.2832     0.000015
# discharge       8103         8124 0.3361     0.000020
# discharge       8127         8148 0.1743     0.000006
# discharge       8150         8172 0.3943     0.000027
# discharge       8175         8196 0.5801     0.000054
# discharge       8200         8222 0.1613     0.000005
# discharge       8225         8245 0.2212     0.000010
# discharge       8248         8269 0.5902     0.000056
# discharge       8274         8292 0.2792     0.000015
# discharge       8295         8316 0.4553     0.000035
# discharge       8320         8342 0.2998     0.000017
# discharge       8347         8364 0.1894     0.000007
# discharge       8367         8389 0.3172     0.000018
# discharge       8392         8409 0.0980     0.000002
# discharge       8415         8437 0.3579     0.000023
# discharge       8442         8455 0.3182     0.000019
# discharge       8457         8461 0.0829     0.000002
# discharge       8469         8484 0.3092     0.000018
# discharge       8487         8508 0.2525     0.000012
# discharge       8511         8532 0.3389     0.000021
# discharge       8535         8556 0.5123     0.000043
# discharge       8560         8580 0.2901     0.000016
# discharge       8583         8605 0.3280     0.000020
# discharge       8609         8630 0.4803     0.000039
# discharge       8636         8653 0.4272     0.000031
# discharge       8661         8669 0.0755     0.000001
# discharge       8679         8701 0.3352     0.000020
# discharge       8708         8710 0.0022     0.000000
# discharge       8713         8725 0.1410     0.000004
# discharge       8728         8749 0.3529     0.000022
#
# Total Estimated Degradation: 0.009068
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 3563994.85 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 274445.38 kWh
# Year 2019: Unmet Load = 4365766.11 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 4651974.49 kWh
# Year 2016: Unmet Load = 4422760.25 kWh
# Year 2015: Unmet Load = 7610891.03 kWh
# Year 2014: Unmet Load = 1781463.63 kWh
# Year 2013: Unmet Load = 2014788.51 kWh
# Year 2012: Unmet Load = 844349.89 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 1785292.25 kWh
# Year 2008: Unmet Load = 1296043.10 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 280692.64 kWh
# Year 2005: Unmet Load = 4335913.46 kWh
# Year 2004: Unmet Load = 4768858.37 kWh
# Year 2003: Unmet Load = 111839.55 kWh
# Year 2002: Unmet Load = 3097449.03 kWh
# Year 2001: Unmet Load = 3926948.77 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 7810983.64 kWh
# Year 1997: Unmet Load = 794268.39 kWh
# Year 1996: Unmet Load = 2935968.31 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 4189524.20 kWh
# Year 1993: Unmet Load = 1704628.40 kWh
# Year 1992: Unmet Load = 2367943.92 kWh
# Year 1991: Unmet Load = 4562843.77 kWh
# Year 1990: Unmet Load = 4106566.66 kWh
# Year 1989: Unmet Load = 1712254.30 kWh
# Year 1988: Unmet Load = 764828.68 kWh
# Year 1987: Unmet Load = 867442.21 kWh
# Year 1986: Unmet Load = 4599046.86 kWh
# Year 1985: Unmet Load = 1273491.35 kWh
# Year 1984: Unmet Load = 2278570.00 kWh
# Year 1983: Unmet Load = 3144966.76 kWh
# Year 1982: Unmet Load = 1933903.53 kWh
# Year 1981: Unmet Load = 1787113.56 kWh
# Year 1980: Unmet Load = 1106507.30 kWh
#
# Average Unmet Load (1979-2024): 2157207.18 kWh
# Min Unmet Load: 0.00 kWh (Year 1995)
# Max Unmet Load: 7810983.64 kWh (Year 1998)
# Starting capacity, cost, and utilization metrics collection...
# Processing year 2024 for capacity, cost, and utilization metrics...
# Year 2024: Dispatch simulation successful, calculating metrics...
# $19594661.98 is the replacement cost each year for degradation
# Year 2024: Metrics added - Utilization: 46.07%, NPC: 4989578274.37, Unmet: 0.00 kWh
# Processing year 2023 for capacity, cost, and utilization metrics...
# Year 2023: Dispatch simulation successful, calculating metrics...
# $20154508.27 is the replacement cost each year for degradation
# Year 2023: Metrics added - Utilization: 46.39%, NPC: 4996691528.69, Unmet: 0.00 kWh
# Processing year 2022 for capacity, cost, and utilization metrics...
# Year 2022: Dispatch simulation successful, calculating metrics...
# $18697845.42 is the replacement cost each year for degradation
# Year 2022: Metrics added - Utilization: 44.37%, NPC: 4978183567.58, Unmet: 3563994.85 kWh
# Processing year 2021 for capacity, cost, and utilization metrics...
# Year 2021: Dispatch simulation successful, calculating metrics...
# $18711993.24 is the replacement cost each year for degradation
# Year 2021: Metrics added - Utilization: 46.16%, NPC: 4978363325.86, Unmet: 0.00 kWh
# Processing year 2020 for capacity, cost, and utilization metrics...
# Year 2020: Dispatch simulation successful, calculating metrics...
# $20398200.09 is the replacement cost each year for degradation
# Year 2020: Metrics added - Utilization: 47.14%, NPC: 4999787810.65, Unmet: 274445.38 kWh
# Processing year 2019 for capacity, cost, and utilization metrics...
# Year 2019: Dispatch simulation successful, calculating metrics...
# $21482073.90 is the replacement cost each year for degradation
# Year 2019: Metrics added - Utilization: 48.00%, NPC: 5013559215.80, Unmet: 4365766.11 kWh
# Processing year 2018 for capacity, cost, and utilization metrics...
# Year 2018: Dispatch simulation successful, calculating metrics...
# $21469462.72 is the replacement cost each year for degradation
# Year 2018: Metrics added - Utilization: 48.13%, NPC: 5013398981.58, Unmet: 0.00 kWh
# Processing year 2017 for capacity, cost, and utilization metrics...
# Year 2017: Dispatch simulation successful, calculating metrics...
# $19754398.63 is the replacement cost each year for degradation
# Year 2017: Metrics added - Utilization: 46.15%, NPC: 4991607844.70, Unmet: 4651974.49 kWh
# Processing year 2016 for capacity, cost, and utilization metrics...
# Year 2016: Dispatch simulation successful, calculating metrics...
# $19901659.35 is the replacement cost each year for degradation
# Year 2016: Metrics added - Utilization: 46.23%, NPC: 4993478899.24, Unmet: 4422760.25 kWh
# Processing year 2015 for capacity, cost, and utilization metrics...
# Year 2015: Dispatch simulation successful, calculating metrics...
# $19368980.92 is the replacement cost each year for degradation
# Year 2015: Metrics added - Utilization: 47.24%, NPC: 4986710832.27, Unmet: 7610891.03 kWh
# Processing year 2014 for capacity, cost, and utilization metrics...
# Year 2014: Dispatch simulation successful, calculating metrics...
# $18907519.10 is the replacement cost each year for degradation
# Year 2014: Metrics added - Utilization: 45.38%, NPC: 4980847624.12, Unmet: 1781463.63 kWh
# Processing year 2013 for capacity, cost, and utilization metrics...
# Year 2013: Dispatch simulation successful, calculating metrics...
# $20199426.24 is the replacement cost each year for degradation
# Year 2013: Metrics added - Utilization: 46.33%, NPC: 4997262244.29, Unmet: 2014788.51 kWh
# Processing year 2012 for capacity, cost, and utilization metrics...
# Year 2012: Dispatch simulation successful, calculating metrics...
# $17867474.07 is the replacement cost each year for degradation
# Year 2012: Metrics added - Utilization: 45.12%, NPC: 4967633095.41, Unmet: 844349.89 kWh
# Processing year 2011 for capacity, cost, and utilization metrics...
# Year 2011: Dispatch simulation successful, calculating metrics...
# $18992044.09 is the replacement cost each year for degradation
# Year 2011: Metrics added - Utilization: 45.46%, NPC: 4981921575.69, Unmet: 0.00 kWh
# Processing year 2010 for capacity, cost, and utilization metrics...
# Year 2010: Dispatch simulation successful, calculating metrics...
# $20153199.10 is the replacement cost each year for degradation
# Year 2010: Metrics added - Utilization: 45.59%, NPC: 4996674894.84, Unmet: 0.00 kWh
# Processing year 2009 for capacity, cost, and utilization metrics...
# Year 2009: Dispatch simulation successful, calculating metrics...
# $19194382.61 is the replacement cost each year for degradation
# Year 2009: Metrics added - Utilization: 46.42%, NPC: 4984492433.73, Unmet: 1785292.25 kWh
# Processing year 2008 for capacity, cost, and utilization metrics...
# Year 2008: Dispatch simulation successful, calculating metrics...
# $18610255.40 is the replacement cost each year for degradation
# Year 2008: Metrics added - Utilization: 44.44%, NPC: 4977070672.61, Unmet: 1296043.10 kWh
# Processing year 2007 for capacity, cost, and utilization metrics...
# Year 2007: Dispatch simulation successful, calculating metrics...
# $20514065.58 is the replacement cost each year for degradation
# Year 2007: Metrics added - Utilization: 45.49%, NPC: 5001259965.91, Unmet: 0.00 kWh
# Processing year 2006 for capacity, cost, and utilization metrics...
# Year 2006: Dispatch simulation successful, calculating metrics...
# $17755772.52 is the replacement cost each year for degradation
# Year 2006: Metrics added - Utilization: 44.43%, NPC: 4966213845.99, Unmet: 280692.64 kWh
# Processing year 2005 for capacity, cost, and utilization metrics...
# Year 2005: Dispatch simulation successful, calculating metrics...
# $19276635.15 is the replacement cost each year for degradation
# Year 2005: Metrics added - Utilization: 44.61%, NPC: 4985537512.11, Unmet: 4335913.46 kWh
# Processing year 2004 for capacity, cost, and utilization metrics...
# Year 2004: Dispatch simulation successful, calculating metrics...
# $17847203.56 is the replacement cost each year for degradation
# Year 2004: Metrics added - Utilization: 45.77%, NPC: 4967375543.89, Unmet: 4768858.37 kWh
# Processing year 2003 for capacity, cost, and utilization metrics...
# Year 2003: Dispatch simulation successful, calculating metrics...
# $19005101.49 is the replacement cost each year for degradation
# Year 2003: Metrics added - Utilization: 45.40%, NPC: 4982087479.45, Unmet: 111839.55 kWh
# Processing year 2002 for capacity, cost, and utilization metrics...
# Year 2002: Dispatch simulation successful, calculating metrics...
# $19512175.57 is the replacement cost each year for degradation
# Year 2002: Metrics added - Utilization: 45.68%, NPC: 4988530224.53, Unmet: 3097449.03 kWh
# Processing year 2001 for capacity, cost, and utilization metrics...
# Year 2001: Dispatch simulation successful, calculating metrics...
# $19625086.80 is the replacement cost each year for degradation
# Year 2001: Metrics added - Utilization: 44.99%, NPC: 4989964843.88, Unmet: 3926948.77 kWh
# Processing year 2000 for capacity, cost, and utilization metrics...
# Year 2000: Dispatch simulation successful, calculating metrics...
# $18847108.94 is the replacement cost each year for degradation
# Year 2000: Metrics added - Utilization: 44.15%, NPC: 4980080069.16, Unmet: 0.00 kWh
# Processing year 1999 for capacity, cost, and utilization metrics...
# Year 1999: Dispatch simulation successful, calculating metrics...
# $16482748.46 is the replacement cost each year for degradation
# Year 1999: Metrics added - Utilization: 43.33%, NPC: 4950039149.17, Unmet: 0.00 kWh
# Processing year 1998 for capacity, cost, and utilization metrics...
# Year 1998: Dispatch simulation successful, calculating metrics...
# $19252309.31 is the replacement cost each year for degradation
# Year 1998: Metrics added - Utilization: 45.58%, NPC: 4985228434.66, Unmet: 7810983.64 kWh
# Processing year 1997 for capacity, cost, and utilization metrics...
# Year 1997: Dispatch simulation successful, calculating metrics...
# $19980164.63 is the replacement cost each year for degradation
# Year 1997: Metrics added - Utilization: 46.05%, NPC: 4994476366.02, Unmet: 794268.39 kWh
# Processing year 1996 for capacity, cost, and utilization metrics...
# Year 1996: Dispatch simulation successful, calculating metrics...
# $17154456.59 is the replacement cost each year for degradation
# Year 1996: Metrics added - Utilization: 44.22%, NPC: 4958573689.69, Unmet: 2935968.31 kWh
# Processing year 1995 for capacity, cost, and utilization metrics...
# Year 1995: Dispatch simulation successful, calculating metrics...
# $17984540.29 is the replacement cost each year for degradation
# Year 1995: Metrics added - Utilization: 44.21%, NPC: 4969120506.88, Unmet: 0.00 kWh
# Processing year 1994 for capacity, cost, and utilization metrics...
# Year 1994: Dispatch simulation successful, calculating metrics...
# $20290801.74 is the replacement cost each year for degradation
# Year 1994: Metrics added - Utilization: 46.97%, NPC: 4998423236.41, Unmet: 4189524.20 kWh
# Processing year 1993 for capacity, cost, and utilization metrics...
# Year 1993: Dispatch simulation successful, calculating metrics...
# $19959827.66 is the replacement cost each year for degradation
# Year 1993: Metrics added - Utilization: 47.78%, NPC: 4994217969.92, Unmet: 1704628.40 kWh
# Processing year 1992 for capacity, cost, and utilization metrics...
# Year 1992: Dispatch simulation successful, calculating metrics...
# $19456244.94 is the replacement cost each year for degradation
# Year 1992: Metrics added - Utilization: 47.23%, NPC: 4987819585.16, Unmet: 2367943.92 kWh
# Processing year 1991 for capacity, cost, and utilization metrics...
# Year 1991: Dispatch simulation successful, calculating metrics...
# $21031249.45 is the replacement cost each year for degradation
# Year 1991: Metrics added - Utilization: 49.64%, NPC: 5007831163.27, Unmet: 4562843.77 kWh
# Processing year 1990 for capacity, cost, and utilization metrics...
# Year 1990: Dispatch simulation successful, calculating metrics...
# $18222012.64 is the replacement cost each year for degradation
# Year 1990: Metrics added - Utilization: 45.59%, NPC: 4972137765.88, Unmet: 4106566.66 kWh
# Processing year 1989 for capacity, cost, and utilization metrics...
# Year 1989: Dispatch simulation successful, calculating metrics...
# $18675917.04 is the replacement cost each year for degradation
# Year 1989: Metrics added - Utilization: 46.48%, NPC: 4977904951.46, Unmet: 1712254.30 kWh
# Processing year 1988 for capacity, cost, and utilization metrics...
# Year 1988: Dispatch simulation successful, calculating metrics...
# $17309676.49 is the replacement cost each year for degradation
# Year 1988: Metrics added - Utilization: 43.47%, NPC: 4960545871.44, Unmet: 764828.68 kWh
# Processing year 1987 for capacity, cost, and utilization metrics...
# Year 1987: Dispatch simulation successful, calculating metrics...
# $20098561.75 is the replacement cost each year for degradation
# Year 1987: Metrics added - Utilization: 46.91%, NPC: 4995980687.46, Unmet: 867442.21 kWh
# Processing year 1986 for capacity, cost, and utilization metrics...
# Year 1986: Dispatch simulation successful, calculating metrics...
# $20234279.42 is the replacement cost each year for degradation
# Year 1986: Metrics added - Utilization: 46.59%, NPC: 4997705079.18, Unmet: 4599046.86 kWh
# Processing year 1985 for capacity, cost, and utilization metrics...
# Year 1985: Dispatch simulation successful, calculating metrics...
# $19013900.08 is the replacement cost each year for degradation
# Year 1985: Metrics added - Utilization: 45.63%, NPC: 4982199271.95, Unmet: 1273491.35 kWh
# Processing year 1984 for capacity, cost, and utilization metrics...
# Year 1984: Dispatch simulation successful, calculating metrics...
# $18377035.58 is the replacement cost each year for degradation
# Year 1984: Metrics added - Utilization: 45.61%, NPC: 4974107445.19, Unmet: 2278570.00 kWh
# Processing year 1983 for capacity, cost, and utilization metrics...
# Year 1983: Dispatch simulation successful, calculating metrics...
# $20794257.96 is the replacement cost each year for degradation
# Year 1983: Metrics added - Utilization: 47.17%, NPC: 5004820014.03, Unmet: 3144966.76 kWh
# Processing year 1982 for capacity, cost, and utilization metrics...
# Year 1982: Dispatch simulation successful, calculating metrics...
# $19472596.43 is the replacement cost each year for degradation
# Year 1982: Metrics added - Utilization: 46.94%, NPC: 4988027342.80, Unmet: 1933903.53 kWh
# Processing year 1981 for capacity, cost, and utilization metrics...
# Year 1981: Dispatch simulation successful, calculating metrics...
# $20952869.23 is the replacement cost each year for degradation
# Year 1981: Metrics added - Utilization: 45.40%, NPC: 5006835285.54, Unmet: 1787113.56 kWh
# Processing year 1980 for capacity, cost, and utilization metrics...
# Year 1980: Dispatch simulation successful, calculating metrics...
# $18517371.66 is the replacement cost each year for degradation
# Year 1980: Metrics added - Utilization: 44.49%, NPC: 4975890517.18, Unmet: 1106507.30 kWh
# Saved capacity, cost, and utilization metrics to dispatch_outputs_solar-wind_dc\capacity_and_costs_by_year.csv
# CSV file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\capacity_and_costs_by_year.csv
# Starting NPC variation plotting...
# Saved NPC variation plot to dispatch_outputs_solar-wind_dc\npc_variation_by_year.png
# Plot file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\npc_variation_by_year.png

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                                        # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
         )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1


        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year (Hybrid Configuration)")
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")
# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 10.13 hours
# 1980: 3.82 extra training hours
# 1981: 4.69 extra training hours
# 1982: 6.50 extra training hours
# 1983: 14.44 extra training hours
# 1984: 11.02 extra training hours
# 1985: 6.58 extra training hours
# 1986: 23.55 extra training hours
# 1987: 4.71 extra training hours
# 1988: 4.28 extra training hours
# 1989: 7.77 extra training hours
# 1990: 21.31 extra training hours
# 1991: 23.18 extra training hours
# 1992: 11.59 extra training hours
# 1993: 9.03 extra training hours
# 1994: 19.36 extra training hours
# 1995: 0.00 extra training hours
# 1996: 12.20 extra training hours
# 1997: 3.73 extra training hours
# 1998: 34.90 extra training hours
# 1999: 0.00 extra training hours
# 2000: 0.00 extra training hours
# 2001: 19.30 extra training hours
# 2002: 17.32 extra training hours
# 2003: 0.19 extra training hours
# 2004: 23.49 extra training hours
# 2005: 20.97 extra training hours
# 2006: 1.26 extra training hours
# 2007: 0.00 extra training hours
# 2008: 6.53 extra training hours
# 2009: 7.66 extra training hours
# 2010: 0.00 extra training hours
# 2011: 0.00 extra training hours
# 2012: 3.37 extra training hours
# 2013: 9.78 extra training hours
# 2014: 7.91 extra training hours
# 2015: 34.39 extra training hours
# 2016: 20.91 extra training hours
# 2017: 21.00 extra training hours
# 2018: 0.00 extra training hours
# 2019: 21.63 extra training hours
# 2020: 0.51 extra training hours
# 2021: 0.00 extra training hours
# 2022: 16.80 extra training hours
# 2023: 0.00 extra training hours
# 2024: 0.00 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 14 hours with unmet load
# 1981: 21 hours with unmet load
# 1982: 24 hours with unmet load
# 1983: 30 hours with unmet load
# 1984: 17 hours with unmet load
# 1985: 10 hours with unmet load
# 1986: 37 hours with unmet load
# 1987: 9 hours with unmet load
# 1988: 7 hours with unmet load
# 1989: 14 hours with unmet load
# 1990: 30 hours with unmet load
# 1991: 34 hours with unmet load
# 1992: 15 hours with unmet load
# 1993: 14 hours with unmet load
# 1994: 33 hours with unmet load
# 1995: 0 hours with unmet load
# 1996: 21 hours with unmet load
# 1997: 7 hours with unmet load
# 1998: 64 hours with unmet load
# 1999: 0 hours with unmet load
# 2000: 0 hours with unmet load
# 2001: 32 hours with unmet load
# 2002: 20 hours with unmet load
# 2003: 2 hours with unmet load
# 2004: 30 hours with unmet load
# 2005: 32 hours with unmet load
# 2006: 3 hours with unmet load
# 2007: 0 hours with unmet load
# 2008: 10 hours with unmet load
# 2009: 15 hours with unmet load
# 2010: 0 hours with unmet load
# 2011: 0 hours with unmet load
# 2012: 10 hours with unmet load
# 2013: 16 hours with unmet load
# 2014: 14 hours with unmet load
# 2015: 65 hours with unmet load
# 2016: 35 hours with unmet load
# 2017: 38 hours with unmet load
# 2018: 0 hours with unmet load
# 2019: 37 hours with unmet load
# 2020: 4 hours with unmet load
# 2021: 0 hours with unmet load
# 2022: 29 hours with unmet load
# 2023: 0 hours with unmet load
# 2024: 0 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 17.62 hours/year
# Maximum: 65 hours in 2015
# Minimum: 0 hours in 2024

# %% [markdown]
# # Total Unmet Load Across the years for different Configurations

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# === Paths for each configuration ===
folders = {
    "Solar": r"C:\Users\Abdullah\dispatch_outputs_solar_dc",
    "Wind": r"C:\Users\Abdullah\dispatch_outputs_wind_dc",
    "Solar-Wind": r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc"
}

# === Years to process ===
years = list(range(2024, 1979, -1))

# === Initialize results ===
unmet_load_by_config = {config: {} for config in folders}

# === Extract unmet load per year for each configuration ===
for config, folder_path in folders.items():
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            total_unmet = df['Unmet (kW)'].sum()
            unmet_load_by_config[config][year] = total_unmet
        except FileNotFoundError:
            unmet_load_by_config[config][year] = None


# Re-plot with 2024 on the right side of the x-axis (standard chronological order)
plt.figure(figsize=(12, 6))
colors = {"Solar": "orange", "Wind": "green", "Solar-Wind": "blue"}

for config, data in unmet_load_by_config.items():
    sorted_years = sorted(data.keys(), reverse=False)  # 1980 to 2024
    unmet_values = [data[y] if data[y] is not None else 0 for y in sorted_years]
    plt.plot(sorted_years, unmet_values, label=config, color=colors[config], marker='o')

plt.title("Total Unmet Load by Year")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Battery Degradation Analysis

# %% [markdown]
# ## Solar Degradation

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar_dc"
years = list(range(2024, 1979, -1))

# === Store Total Degradation Per Year ===
yearly_degradation = {}

for year in years:
    file_path = os.path.join(folder_path, f"cycles_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        if 'degradation' in df.columns:
            total_deg = df['degradation'].sum()
            yearly_degradation[year] = total_deg
        else:
            print(f"'degradation' column missing in {file_path}")
            yearly_degradation[year] = None
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        yearly_degradation[year] = None

# === Plotting ===
years_sorted = sorted(yearly_degradation.keys())
degradation_values = [yearly_degradation[y] if yearly_degradation[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(6, 6))
plt.plot(years_sorted, degradation_values, marker='o', label='Total Battery Degradation', color='red')
plt.title("Solar Total Battery Degradation by Year (1980–2024)")
plt.xlabel("Year")
plt.ylabel("Total Degradation")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# === Average Degradation ===
valid_degs = [v for v in yearly_degradation.values() if v is not None]
avg_deg = np.mean(valid_degs)
print(f"\nAverage Annual Degradation (1980–2024): {avg_deg:.6f}")
# Out:
# Average Annual Degradation (1980–2024): 0.012820

# %% [markdown]
# ## Wind

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_wind_dc"
years = list(range(2024, 1979, -1))

# === Store Total Degradation Per Year ===
yearly_degradation = {}

for year in years:
    file_path = os.path.join(folder_path, f"cycles_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        if 'degradation' in df.columns:
            total_deg = df['degradation'].sum()
            yearly_degradation[year] = total_deg
        else:
            print(f"'degradation' column missing in {file_path}")
            yearly_degradation[year] = None
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        yearly_degradation[year] = None

# === Plotting ===
years_sorted = sorted(yearly_degradation.keys())
degradation_values = [yearly_degradation[y] if yearly_degradation[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(6, 6))
plt.plot(years_sorted, degradation_values, marker='o', label='Total Battery Degradation',color='purple')
plt.title("Wind Total Battery Degradation by Year (1980–2024)")
plt.xlabel("Year")
plt.ylabel("Total Degradation")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# === Average Degradation ===
valid_degs = [v for v in yearly_degradation.values() if v is not None]
avg_deg = np.mean(valid_degs)
print(f"\nAverage Annual Degradation (1980–2024): {avg_deg:.6f}")
# Out:
# Average Annual Degradation (1980–2024): 0.000340

# %% [markdown]
# ## Solar Wind

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc"
years = list(range(2024, 1979, -1))

# === Store Total Degradation Per Year ===
yearly_degradation = {}

for year in years:
    file_path = os.path.join(folder_path, f"cycles_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        if 'degradation' in df.columns:
            total_deg = df['degradation'].sum()
            yearly_degradation[year] = total_deg
        else:
            print(f"'degradation' column missing in {file_path}")
            yearly_degradation[year] = None
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        yearly_degradation[year] = None

# === Plotting ===
years_sorted = sorted(yearly_degradation.keys())
degradation_values = [yearly_degradation[y] if yearly_degradation[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(6, 6))
plt.plot(years_sorted, degradation_values, marker='o', label='Total Battery Degradation',color='crimson')
plt.title(" Solar Wind Hybrid Total Battery Degradation by Year (1980–2024)")
plt.xlabel("Year")
plt.ylabel("Total Degradation")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# === Average Degradation ===
valid_degs = [v for v in yearly_degradation.values() if v is not None]
avg_deg = np.mean(valid_degs)
print(f"\nAverage Annual Degradation (1980–2024): {avg_deg:.6f}")
# Out:
# Average Annual Degradation (1980–2024): 0.008936

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
file_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\capacity_and_costs_by_year.csv"
df = pd.read_csv(file_path)
df_sorted = df.sort_values("Year")

# Plot
plt.figure(figsize=(12, 6))
plt.plot(df_sorted["Year"], df_sorted["Total_NPC"] / 1e9, marker='o', linewidth=2)
plt.title("Total Net Present Cost (NPC) by Year")
plt.xlabel("Year")
plt.ylabel("Total NPC (Billion USD)")
plt.grid(True)
plt.tight_layout()

# Save to your machine
plt.savefig(r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\npc_by_year.png")
plt.show()
