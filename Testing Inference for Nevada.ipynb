# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_100_percent_met_71_percent_inference_Nevada"
dispatch_load_factor = 0.71  # Apply 0.71 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 100% met (Load Factor 0.71)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 100% met (Load Factor 0.71) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 100% met (Load Factor 0.71)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 100% met (Load Factor 0.71) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890599 nonzeros
# Model fingerprint: 0xda0c15fe
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17564 rows and 17563 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 24.78s
# Presolved: 70077 rows, 35042 columns, 161748 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52335 rows, 26136 columns, 135068 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3492248e+08   1.614250e+06   1.865590e+07     40s
#     2759    5.3930050e+15   0.000000e+00   3.578060e+09     41s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.588664e+09, 18450 iterations, 3.76 seconds (2.45 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.5887e+09    0    2          - 4.5887e+09      -     -   43s
# H    0     0                    4.588664e+09 4.5887e+09  0.00%     -   44s
#      0     0 4.5887e+09    0    2 4.5887e+09 4.5887e+09  0.00%     -   44s
#
# Explored 1 nodes (18450 simplex iterations) in 45.64 seconds (67.73 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.58866e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.588664281787e+09, best bound 4.588664281787e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 13781154.12 kW
# Wind Capacity: 0.00 kW
# Battery Capacity: 6751792.37 kWh
# Total NPC: $4588664281.79
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 5984562022.95 kWh
# Total Energy Generated: 8460677728.06 kWh
# Total Energy Used (along with efficiency losses): 2476115705.11 kWh
# Utilization Percentage: 29.27%
# $20797323.13 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 13781154.12 kW
# Solar Initial Cost:    $1280958275.15
# Wind Initial Capacity: 0.00 kW
# Wind Initial Cost:     $0.00
# Battery Initial Capacity: 6751792.37 kWh
# Battery Initial Cost:  $2417141668.18
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -44099.69 kW
# Solar Redundant Cost:    $-4099066.48
# Wind Redundant Capacity: 0.00 kW
# Wind Redundant Cost:     $0.00
# Battery Redundant Capacity: 24981.63 kWh
# Battery Redundant Cost:  $8943424.17
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $1276859208.67
# Solar OPEX:         $1394668223.59
# Solar Replacement:  $0.00
# Solar Salvage:     -$371187338.15
# Wind CAPEX:         $0.00
# Wind OPEX:          $0.00
# Wind Replacement:   $0.00
# Wind Salvage:      -$0.00
# Battery CAPEX:      $2426085092.36
# Battery OPEX:       $730900416.70
# Battery Replacement:$264245120.10
# Battery Salvage:   -$881589040.36
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $4852909401.89
#
# === 2024 Solar Results 100% met (Load Factor 0.71) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.3946     0.000027
# discharge         17           38 0.4149     0.000030
# discharge         41           63 0.4316     0.000032
# discharge         68           86 0.4183     0.000030
# discharge         89          111 0.4288     0.000032
# discharge        114          134 0.4146     0.000030
# discharge        138          158 0.4299     0.000032
# discharge        161          182 0.4099     0.000029
# discharge        185          206 0.4084     0.000029
# discharge        209          230 0.4194     0.000030
# discharge        233          254 0.4065     0.000029
# discharge        257          278 0.4004     0.000028
# discharge        281          302 0.4049     0.000029
# discharge        306          326 0.4043     0.000028
# discharge        329          350 0.4057     0.000029
# discharge        354          374 0.4103     0.000029
# discharge        377          398 0.4005     0.000028
# discharge        402          422 0.4142     0.000030
# discharge        425          447 0.4240     0.000031
# discharge        452          471 0.4409     0.000033
# discharge        474          495 0.4434     0.000034
# discharge        501          518 0.4196     0.000030
# discharge        527          542 0.4240     0.000031
# discharge        546          566 0.4035     0.000028
# discharge        569          590 0.4170     0.000030
# discharge        594          614 0.3918     0.000027
# discharge        617          638 0.3919     0.000027
# discharge        641          662 0.3957     0.000027
# discharge        665          686 0.3931     0.000027
# discharge        689          710 0.3895     0.000027
# discharge        713          734 0.3905     0.000027
# discharge        737          759 0.4323     0.000032
# discharge        766          782 0.4215     0.000031
# discharge        787          806 0.3930     0.000027
# discharge        808          830 0.3927     0.000027
# discharge        834          854 0.3915     0.000027
# discharge        858          878 0.3917     0.000027
# discharge        882          902 0.4081     0.000029
# discharge        906          926 0.3883     0.000026
# discharge        929          950 0.3878     0.000026
# discharge        953          974 0.4123     0.000029
# discharge        977          997 0.3700     0.000024
# discharge       1000         1021 0.3697     0.000024
# discharge       1024         1046 0.3789     0.000025
# discharge       1049         1069 0.3742     0.000025
# discharge       1072         1094 0.3948     0.000027
# discharge       1097         1118 0.3742     0.000025
# discharge       1120         1141 0.3719     0.000025
# discharge       1144         1165 0.3695     0.000024
# discharge       1168         1189 0.3702     0.000024
# discharge       1192         1215 0.4072     0.000029
# discharge       1221         1238 0.4043     0.000028
# discharge       1241         1261 0.3744     0.000025
# discharge       1264         1286 0.3822     0.000026
# discharge       1290         1310 0.3819     0.000026
# discharge       1314         1333 0.3696     0.000024
# discharge       1337         1358 0.3836     0.000026
# discharge       1362         1381 0.3732     0.000025
# discharge       1384         1405 0.3702     0.000024
# discharge       1408         1429 0.3707     0.000024
# discharge       1432         1453 0.3708     0.000024
# discharge       1456         1477 0.3708     0.000024
# discharge       1480         1501 0.3717     0.000024
# discharge       1504         1525 0.3712     0.000024
# discharge       1528         1549 0.3711     0.000024
# discharge       1552         1573 0.3690     0.000024
# discharge       1576         1598 0.3903     0.000027
# discharge       1603         1621 0.3715     0.000024
# discharge       1624         1645 0.3688     0.000024
# discharge       1648         1669 0.3670     0.000024
# discharge       1673         1694 0.3847     0.000026
# discharge       1697         1717 0.3670     0.000024
# discharge       1721         1741 0.3673     0.000024
# discharge       1744         1765 0.3671     0.000024
# discharge       1768         1790 0.3735     0.000025
# discharge       1792         1814 0.3851     0.000026
# discharge       1817         1837 0.3656     0.000024
# discharge       1840         1861 0.3633     0.000024
# discharge       1864         1885 0.3733     0.000025
# discharge       1888         1909 0.3625     0.000023
# discharge       1912         1933 0.3615     0.000023
# discharge       1936         1957 0.3594     0.000023
# discharge       1961         1981 0.3592     0.000023
# discharge       1984         2006 0.3633     0.000024
# discharge       2009         2029 0.3703     0.000024
# discharge       2032         2053 0.3576     0.000023
# discharge       2056         2077 0.3557     0.000023
# discharge       2080         2101 0.3573     0.000023
# discharge       2104         2125 0.3603     0.000023
# discharge       2129         2149 0.3610     0.000023
# discharge       2153         2173 0.3625     0.000023
# discharge       2176         2197 0.3611     0.000023
# discharge       2200         2221 0.3534     0.000022
# discharge       2224         2245 0.3479     0.000022
# discharge       2248         2269 0.3467     0.000022
# discharge       2272         2293 0.3453     0.000021
# discharge       2296         2317 0.3519     0.000022
# discharge       2320         2341 0.3418     0.000021
# discharge       2344         2365 0.3434     0.000021
# discharge       2368         2389 0.3434     0.000021
# discharge       2392         2413 0.3435     0.000021
# discharge       2416         2437 0.3380     0.000021
# discharge       2440         2461 0.3417     0.000021
# discharge       2464         2485 0.3395     0.000021
# discharge       2488         2509 0.3415     0.000021
# discharge       2512         2533 0.3406     0.000021
# discharge       2536         2557 0.3404     0.000021
# discharge       2560         2581 0.3406     0.000021
# discharge       2584         2605 0.3374     0.000021
# discharge       2608         2629 0.3388     0.000021
# discharge       2632         2653 0.3337     0.000020
# discharge       2656         2677 0.3321     0.000020
# discharge       2680         2701 0.3328     0.000020
# discharge       2704         2725 0.3309     0.000020
# discharge       2728         2749 0.3306     0.000020
# discharge       2752         2773 0.3301     0.000020
# discharge       2776         2797 0.3265     0.000019
# discharge       2800         2821 0.3256     0.000019
# discharge       2824         2845 0.3271     0.000019
# discharge       2848         2869 0.3271     0.000019
# discharge       2872         2893 0.3240     0.000019
# discharge       2896         2917 0.3267     0.000019
# discharge       2920         2941 0.3259     0.000019
# discharge       2944         2965 0.3244     0.000019
# discharge       2968         2989 0.3237     0.000019
# discharge       2992         3013 0.3377     0.000021
# discharge       3016         3037 0.3238     0.000019
# discharge       3040         3061 0.3248     0.000019
# discharge       3064         3085 0.3231     0.000019
# discharge       3088         3108 0.3188     0.000019
# discharge       3112         3133 0.3200     0.000019
# discharge       3136         3156 0.3183     0.000019
# discharge       3160         3181 0.3197     0.000019
# discharge       3184         3204 0.3191     0.000019
# discharge       3208         3228 0.3193     0.000019
# discharge       3232         3253 0.3356     0.000020
# discharge       3256         3276 0.3174     0.000018
# discharge       3280         3300 0.3197     0.000019
# discharge       3304         3324 0.3168     0.000018
# discharge       3328         3348 0.3163     0.000018
# discharge       3352         3372 0.3168     0.000018
# discharge       3376         3396 0.3185     0.000019
# discharge       3400         3420 0.3167     0.000018
# discharge       3424         3444 0.3169     0.000018
# discharge       3448         3468 0.3166     0.000018
# discharge       3472         3492 0.3178     0.000019
# discharge       3496         3516 0.3170     0.000018
# discharge       3520         3540 0.3175     0.000018
# discharge       3544         3564 0.3174     0.000018
# discharge       3568         3588 0.3180     0.000019
# discharge       3592         3612 0.3180     0.000019
# discharge       3616         3636 0.3159     0.000018
# discharge       3640         3660 0.3153     0.000018
# discharge       3664         3684 0.3167     0.000018
# discharge       3688         3708 0.3165     0.000018
# discharge       3712         3732 0.3155     0.000018
# discharge       3736         3756 0.3159     0.000018
# discharge       3760         3780 0.3150     0.000018
# discharge       3784         3804 0.3152     0.000018
# discharge       3808         3828 0.3158     0.000018
# discharge       3832         3852 0.3166     0.000018
# discharge       3856         3876 0.3149     0.000018
# discharge       3880         3900 0.3150     0.000018
# discharge       3904         3924 0.3157     0.000018
# discharge       3928         3948 0.3141     0.000018
# discharge       3952         3972 0.3129     0.000018
# discharge       3976         3996 0.3172     0.000018
# discharge       4000         4020 0.3128     0.000018
# discharge       4024         4044 0.3144     0.000018
# discharge       4048         4068 0.3134     0.000018
# discharge       4072         4092 0.3135     0.000018
# discharge       4096         4116 0.3089     0.000018
# discharge       4120         4140 0.3085     0.000018
# discharge       4144         4164 0.3086     0.000018
# discharge       4168         4188 0.3098     0.000018
# discharge       4192         4212 0.3121     0.000018
# discharge       4216         4236 0.3092     0.000018
# discharge       4240         4260 0.3087     0.000018
# discharge       4264         4284 0.3077     0.000017
# discharge       4288         4308 0.3109     0.000018
# discharge       4312         4332 0.3129     0.000018
# discharge       4336         4356 0.3130     0.000018
# discharge       4360         4380 0.3120     0.000018
# discharge       4384         4404 0.3128     0.000018
# discharge       4408         4428 0.3137     0.000018
# discharge       4432         4452 0.3139     0.000018
# discharge       4456         4476 0.3118     0.000018
# discharge       4480         4500 0.3126     0.000018
# discharge       4504         4524 0.3148     0.000018
# discharge       4528         4548 0.3144     0.000018
# discharge       4552         4572 0.3158     0.000018
# discharge       4576         4596 0.3158     0.000018
# discharge       4600         4620 0.3153     0.000018
# discharge       4624         4645 0.3157     0.000018
# discharge       4649         4668 0.3153     0.000018
# discharge       4672         4692 0.3160     0.000018
# discharge       4696         4716 0.3176     0.000018
# discharge       4720         4740 0.3179     0.000019
# discharge       4744         4764 0.3178     0.000018
# discharge       4768         4788 0.3171     0.000018
# discharge       4792         4812 0.3174     0.000018
# discharge       4816         4836 0.3174     0.000018
# discharge       4840         4860 0.3168     0.000018
# discharge       4864         4884 0.3171     0.000018
# discharge       4888         4908 0.3159     0.000018
# discharge       4912         4932 0.3165     0.000018
# discharge       4936         4956 0.3185     0.000019
# discharge       4960         4980 0.3187     0.000019
# discharge       4984         5004 0.3186     0.000019
# discharge       5008         5029 0.3203     0.000019
# discharge       5032         5053 0.3235     0.000019
# discharge       5056         5077 0.3223     0.000019
# discharge       5080         5101 0.3199     0.000019
# discharge       5104         5125 0.3206     0.000019
# discharge       5128         5149 0.3336     0.000020
# discharge       5153         5173 0.3189     0.000019
# discharge       5176         5197 0.3222     0.000019
# discharge       5200         5221 0.3214     0.000019
# discharge       5224         5245 0.3278     0.000020
# discharge       5248         5269 0.3251     0.000019
# discharge       5272         5293 0.3221     0.000019
# discharge       5296         5317 0.3360     0.000020
# discharge       5320         5341 0.3333     0.000020
# discharge       5344         5365 0.3244     0.000019
# discharge       5368         5389 0.3262     0.000019
# discharge       5392         5413 0.3280     0.000020
# discharge       5416         5437 0.3304     0.000020
# discharge       5440         5461 0.3291     0.000020
# discharge       5464         5485 0.3310     0.000020
# discharge       5488         5509 0.3348     0.000020
# discharge       5512         5533 0.3374     0.000021
# discharge       5536         5557 0.3357     0.000020
# discharge       5560         5581 0.3381     0.000021
# discharge       5584         5605 0.3383     0.000021
# discharge       5608         5629 0.3392     0.000021
# discharge       5632         5653 0.3405     0.000021
# discharge       5656         5677 0.3399     0.000021
# discharge       5680         5701 0.3380     0.000021
# discharge       5704         5725 0.3399     0.000021
# discharge       5728         5749 0.3389     0.000021
# discharge       5752         5773 0.3398     0.000021
# discharge       5776         5797 0.3416     0.000021
# discharge       5800         5821 0.3384     0.000021
# discharge       5824         5845 0.3386     0.000021
# discharge       5848         5869 0.3411     0.000021
# discharge       5872         5893 0.3434     0.000021
# discharge       5896         5917 0.3425     0.000021
# discharge       5920         5941 0.3447     0.000021
# discharge       5944         5965 0.3457     0.000022
# discharge       5968         5989 0.3474     0.000022
# discharge       5992         6013 0.3528     0.000022
# discharge       6016         6037 0.3544     0.000022
# discharge       6040         6061 0.3567     0.000023
# discharge       6064         6085 0.3560     0.000023
# discharge       6088         6109 0.3596     0.000023
# discharge       6112         6133 0.3533     0.000022
# discharge       6136         6157 0.3548     0.000023
# discharge       6160         6181 0.3563     0.000023
# discharge       6184         6205 0.3561     0.000023
# discharge       6208         6229 0.3590     0.000023
# discharge       6232         6253 0.3598     0.000023
# discharge       6256         6277 0.3594     0.000023
# discharge       6280         6301 0.3610     0.000023
# discharge       6304         6325 0.3614     0.000023
# discharge       6328         6349 0.3606     0.000023
# discharge       6352         6373 0.3626     0.000023
# discharge       6376         6397 0.3616     0.000023
# discharge       6400         6421 0.3626     0.000023
# discharge       6424         6445 0.3649     0.000024
# discharge       6448         6469 0.3639     0.000024
# discharge       6472         6493 0.3647     0.000024
# discharge       6496         6517 0.3635     0.000024
# discharge       6520         6541 0.3670     0.000024
# discharge       6544         6565 0.3648     0.000024
# discharge       6568         6589 0.3658     0.000024
# discharge       6592         6613 0.3682     0.000024
# discharge       6616         6637 0.3687     0.000024
# discharge       6640         6661 0.3675     0.000024
# discharge       6664         6685 0.3684     0.000024
# discharge       6688         6709 0.3678     0.000024
# discharge       6712         6733 0.3675     0.000024
# discharge       6736         6757 0.3692     0.000024
# discharge       6761         6781 0.3696     0.000024
# discharge       6784         6805 0.3697     0.000024
# discharge       6808         6829 0.3704     0.000024
# discharge       6832         6853 0.3693     0.000024
# discharge       6856         6877 0.3697     0.000024
# discharge       6880         6901 0.3697     0.000024
# discharge       6904         6925 0.3682     0.000024
# discharge       6928         6949 0.3648     0.000024
# discharge       6952         6973 0.3693     0.000024
# discharge       6976         6998 0.3794     0.000025
# discharge       7001         7021 0.3685     0.000024
# discharge       7025         7045 0.3685     0.000024
# discharge       7048         7070 0.3691     0.000024
# discharge       7073         7093 0.3694     0.000024
# discharge       7096         7117 0.3672     0.000024
# discharge       7120         7141 0.3678     0.000024
# discharge       7144         7165 0.3726     0.000025
# discharge       7168         7190 0.3683     0.000024
# discharge       7193         7214 0.3933     0.000027
# discharge       7218         7238 0.3754     0.000025
# discharge       7241         7262 0.3725     0.000025
# discharge       7265         7285 0.3675     0.000024
# discharge       7288         7309 0.3673     0.000024
# discharge       7312         7334 0.3700     0.000024
# discharge       7337         7359 0.3985     0.000028
# discharge       7363         7382 0.3944     0.000027
# discharge       7386         7406 0.3727     0.000025
# discharge       7408         7430 0.3914     0.000027
# discharge       7433         7454 0.3769     0.000025
# discharge       7456         7478 0.3784     0.000025
# discharge       7481         7502 0.3830     0.000026
# discharge       7505         7526 0.3797     0.000025
# discharge       7529         7550 0.3874     0.000026
# discharge       7553         7574 0.3858     0.000026
# discharge       7577         7598 0.3907     0.000027
# discharge       7601         7622 0.3849     0.000026
# discharge       7625         7646 0.3876     0.000026
# discharge       7649         7670 0.3893     0.000027
# discharge       7673         7694 0.3912     0.000027
# discharge       7697         7718 0.3888     0.000027
# discharge       7721         7742 0.3918     0.000027
# discharge       7745         7766 0.3923     0.000027
# discharge       7769         7790 0.3920     0.000027
# discharge       7793         7814 0.3959     0.000027
# discharge       7817         7838 0.3918     0.000027
# discharge       7841         7862 0.3952     0.000027
# discharge       7865         7886 0.4069     0.000029
# discharge       7889         7910 0.4149     0.000030
# discharge       7916         7934 0.4052     0.000029
# discharge       7938         7958 0.4146     0.000030
# discharge       7962         7982 0.3989     0.000028
# discharge       7985         8006 0.3994     0.000028
# discharge       8009         8030 0.4202     0.000031
# discharge       8033         8054 0.4023     0.000028
# discharge       8057         8078 0.4083     0.000029
# discharge       8081         8102 0.4190     0.000030
# discharge       8105         8126 0.4174     0.000030
# discharge       8129         8150 0.4068     0.000029
# discharge       8153         8174 0.4069     0.000029
# discharge       8177         8198 0.4089     0.000029
# discharge       8201         8222 0.4092     0.000029
# discharge       8227         8246 0.4200     0.000030
# discharge       8249         8270 0.4067     0.000029
# discharge       8273         8294 0.4104     0.000029
# discharge       8298         8318 0.4188     0.000030
# discharge       8322         8342 0.4159     0.000030
# discharge       8345         8367 0.4333     0.000032
# discharge       8371         8390 0.4128     0.000030
# discharge       8393         8414 0.4133     0.000030
# discharge       8417         8438 0.4227     0.000031
# discharge       8441         8462 0.4118     0.000029
# discharge       8465         8486 0.4161     0.000030
# discharge       8489         8510 0.4178     0.000030
# discharge       8513         8534 0.4141     0.000030
# discharge       8538         8559 0.4342     0.000032
# discharge       8563         8582 0.4233     0.000031
# discharge       8585         8606 0.4163     0.000030
# discharge       8609         8630 0.4175     0.000030
# discharge       8633         8654 0.4186     0.000030
# discharge       8659         8678 0.4232     0.000031
# discharge       8681         8702 0.4182     0.000030
# discharge       8706         8726 0.4190     0.000030
# discharge       8729         8750 0.4148     0.000030
#
# Total Estimated Degradation: 0.008500
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada\dispatch_profile_1980.png
#
# === Unmet Load Across Years 100% met (Load Factor 0.71) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 739071.11 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 16423.80 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 739071.11 kWh (Year 2010)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_100_percent_met_71_percent_inference_Nevada"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 71% reduction (Case 1) in LP for 100% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_100_percent_met_55_percent_inference_Nevada"
dispatch_load_factor = 0.55  # Apply 0.55 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 100% met (Load Factor 0.55)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 100% met (Load Factor 0.55) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 100% met (Load Factor 0.55)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 100% met (Load Factor 0.55) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890599 nonzeros
# Model fingerprint: 0xda0c15fe
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17564 rows and 17563 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.71s
# Presolved: 70077 rows, 35042 columns, 161748 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52335 rows, 26136 columns, 135068 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3492248e+08   1.614250e+06   1.865590e+07     41s
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.588664e+09, 18450 iterations, 3.72 seconds (2.45 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.5887e+09    0    2          - 4.5887e+09      -     -   44s
# H    0     0                    4.588664e+09 4.5887e+09  0.00%     -   45s
#      0     0 4.5887e+09    0    2 4.5887e+09 4.5887e+09  0.00%     -   45s
#
# Explored 1 nodes (18450 simplex iterations) in 46.59 seconds (67.73 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.58866e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.588664281787e+09, best bound 4.588664281787e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 13781154.12 kW
# Wind Capacity: 0.00 kW
# Battery Capacity: 6751792.37 kWh
# Total NPC: $4588664281.79
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 6357607573.06 kWh
# Total Energy Generated: 8460677728.06 kWh
# Total Energy Used (along with efficiency losses): 2103070155.00 kWh
# Utilization Percentage: 24.86%
# $12945407.37 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 13781154.12 kW
# Solar Initial Cost:    $1280958275.15
# Wind Initial Capacity: 0.00 kW
# Wind Initial Cost:     $0.00
# Battery Initial Capacity: 6751792.37 kWh
# Battery Initial Cost:  $2417141668.18
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -44099.69 kW
# Solar Redundant Cost:    $-4099066.48
# Wind Redundant Capacity: 0.00 kW
# Wind Redundant Cost:     $0.00
# Battery Redundant Capacity: 24981.63 kWh
# Battery Redundant Cost:  $8943424.17
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $1276859208.67
# Solar OPEX:         $1394668223.59
# Solar Replacement:  $0.00
# Solar Salvage:     -$371187338.15
# Wind CAPEX:         $0.00
# Wind OPEX:          $0.00
# Wind Replacement:   $0.00
# Wind Salvage:      -$0.00
# Battery CAPEX:      $2426085092.36
# Battery OPEX:       $730900416.70
# Battery Replacement:$164480818.24
# Battery Salvage:   -$881589040.36
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $4753145100.03
#
# === 2024 Solar Results 100% met (Load Factor 0.55) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.3057     0.000017
# discharge         17           38 0.3193     0.000019
# discharge         41           63 0.3297     0.000020
# discharge         68           86 0.3225     0.000019
# discharge         89          111 0.3265     0.000019
# discharge        114          134 0.3191     0.000019
# discharge        137          158 0.3290     0.000020
# discharge        161          182 0.3145     0.000018
# discharge        184          206 0.3128     0.000018
# discharge        208          230 0.3238     0.000019
# discharge        232          254 0.3113     0.000018
# discharge        256          278 0.3060     0.000017
# discharge        280          302 0.3090     0.000018
# discharge        306          326 0.3091     0.000018
# discharge        328          350 0.3101     0.000018
# discharge        353          374 0.3148     0.000018
# discharge        376          398 0.3063     0.000017
# discharge        401          422 0.3188     0.000019
# discharge        424          447 0.3222     0.000019
# discharge        451          471 0.3389     0.000021
# discharge        474          495 0.3414     0.000021
# discharge        500          518 0.3240     0.000019
# discharge        525          542 0.3284     0.000020
# discharge        546          566 0.3079     0.000017
# discharge        569          590 0.3214     0.000019
# discharge        594          614 0.3025     0.000017
# discharge        616          638 0.3026     0.000017
# discharge        640          662 0.3060     0.000017
# discharge        665          686 0.3040     0.000017
# discharge        689          710 0.3002     0.000017
# discharge        712          734 0.3010     0.000017
# discharge        736          759 0.3303     0.000020
# discharge        766          782 0.3250     0.000019
# discharge        786          806 0.2972     0.000016
# discharge        808          830 0.3031     0.000017
# discharge        834          854 0.3022     0.000017
# discharge        857          878 0.3024     0.000017
# discharge        882          902 0.3120     0.000018
# discharge        905          926 0.2988     0.000017
# discharge        928          950 0.2983     0.000017
# discharge        953          974 0.3163     0.000018
# discharge        976          997 0.2867     0.000015
# discharge       1000         1021 0.2864     0.000015
# discharge       1024         1046 0.2894     0.000016
# discharge       1048         1069 0.2857     0.000015
# discharge       1072         1094 0.3053     0.000017
# discharge       1096         1117 0.2856     0.000015
# discharge       1120         1141 0.2857     0.000015
# discharge       1144         1165 0.2862     0.000015
# discharge       1168         1189 0.2868     0.000015
# discharge       1192         1215 0.3113     0.000018
# discharge       1220         1238 0.3080     0.000017
# discharge       1241         1261 0.2860     0.000015
# discharge       1264         1286 0.2925     0.000016
# discharge       1289         1310 0.2922     0.000016
# discharge       1313         1333 0.2863     0.000015
# discharge       1336         1357 0.2883     0.000016
# discharge       1361         1381 0.2891     0.000016
# discharge       1384         1405 0.2868     0.000015
# discharge       1408         1429 0.2872     0.000015
# discharge       1432         1453 0.2872     0.000015
# discharge       1456         1477 0.2872     0.000015
# discharge       1480         1501 0.2879     0.000016
# discharge       1504         1525 0.2875     0.000015
# discharge       1528         1549 0.2875     0.000015
# discharge       1552         1573 0.2853     0.000015
# discharge       1576         1598 0.2998     0.000017
# discharge       1602         1621 0.2878     0.000015
# discharge       1624         1645 0.2852     0.000015
# discharge       1648         1669 0.2833     0.000015
# discharge       1672         1694 0.2937     0.000016
# discharge       1697         1717 0.2833     0.000015
# discharge       1720         1741 0.2835     0.000015
# discharge       1744         1765 0.2833     0.000015
# discharge       1768         1789 0.2838     0.000015
# discharge       1792         1814 0.2947     0.000016
# discharge       1817         1837 0.2817     0.000015
# discharge       1840         1861 0.2794     0.000015
# discharge       1864         1885 0.2892     0.000016
# discharge       1888         1909 0.2782     0.000015
# discharge       1912         1933 0.2775     0.000015
# discharge       1936         1957 0.2753     0.000014
# discharge       1960         1981 0.2752     0.000014
# discharge       1984         2005 0.2780     0.000015
# discharge       2008         2029 0.2858     0.000015
# discharge       2032         2053 0.2734     0.000014
# discharge       2056         2077 0.2720     0.000014
# discharge       2080         2101 0.2731     0.000014
# discharge       2104         2125 0.2760     0.000014
# discharge       2129         2149 0.2771     0.000014
# discharge       2152         2173 0.2782     0.000015
# discharge       2176         2197 0.2766     0.000014
# discharge       2200         2221 0.2691     0.000014
# discharge       2224         2245 0.2659     0.000013
# discharge       2247         2269 0.2652     0.000013
# discharge       2272         2293 0.2639     0.000013
# discharge       2295         2317 0.2674     0.000014
# discharge       2319         2341 0.2637     0.000013
# discharge       2344         2365 0.2637     0.000013
# discharge       2367         2389 0.2650     0.000013
# discharge       2391         2413 0.2651     0.000013
# discharge       2415         2437 0.2603     0.000013
# discharge       2439         2461 0.2637     0.000013
# discharge       2463         2485 0.2614     0.000013
# discharge       2487         2509 0.2630     0.000013
# discharge       2511         2533 0.2623     0.000013
# discharge       2535         2557 0.2621     0.000013
# discharge       2559         2581 0.2623     0.000013
# discharge       2583         2605 0.2593     0.000013
# discharge       2608         2629 0.2604     0.000013
# discharge       2632         2653 0.2554     0.000013
# discharge       2655         2677 0.2537     0.000012
# discharge       2679         2701 0.2542     0.000012
# discharge       2703         2725 0.2527     0.000012
# discharge       2727         2749 0.2520     0.000012
# discharge       2751         2773 0.2516     0.000012
# discharge       2775         2796 0.2484     0.000012
# discharge       2799         2820 0.2475     0.000012
# discharge       2823         2845 0.2488     0.000012
# discharge       2847         2869 0.2487     0.000012
# discharge       2871         2892 0.2464     0.000012
# discharge       2895         2916 0.2484     0.000012
# discharge       2919         2940 0.2474     0.000012
# discharge       2943         2964 0.2485     0.000012
# discharge       2967         2988 0.2478     0.000012
# discharge       2991         3012 0.2571     0.000013
# discharge       3015         3036 0.2477     0.000012
# discharge       3039         3060 0.2486     0.000012
# discharge       3063         3084 0.2470     0.000012
# discharge       3087         3108 0.2464     0.000012
# discharge       3111         3132 0.2459     0.000012
# discharge       3135         3156 0.2460     0.000012
# discharge       3159         3180 0.2461     0.000012
# discharge       3183         3204 0.2467     0.000012
# discharge       3207         3228 0.2468     0.000012
# discharge       3232         3253 0.2563     0.000013
# discharge       3256         3276 0.2453     0.000012
# discharge       3279         3300 0.2472     0.000012
# discharge       3303         3324 0.2444     0.000012
# discharge       3327         3348 0.2440     0.000012
# discharge       3351         3372 0.2444     0.000012
# discharge       3375         3396 0.2457     0.000012
# discharge       3399         3420 0.2443     0.000012
# discharge       3423         3444 0.2444     0.000012
# discharge       3447         3468 0.2442     0.000012
# discharge       3471         3492 0.2452     0.000012
# discharge       3495         3516 0.2446     0.000012
# discharge       3519         3540 0.2449     0.000012
# discharge       3543         3564 0.2448     0.000012
# discharge       3567         3588 0.2453     0.000012
# discharge       3591         3612 0.2453     0.000012
# discharge       3615         3636 0.2431     0.000011
# discharge       3639         3660 0.2427     0.000011
# discharge       3663         3684 0.2437     0.000012
# discharge       3687         3708 0.2436     0.000011
# discharge       3711         3732 0.2428     0.000011
# discharge       3736         3756 0.2431     0.000011
# discharge       3759         3780 0.2425     0.000011
# discharge       3783         3804 0.2426     0.000011
# discharge       3807         3828 0.2431     0.000011
# discharge       3831         3852 0.2437     0.000012
# discharge       3855         3876 0.2424     0.000011
# discharge       3879         3900 0.2425     0.000011
# discharge       3903         3924 0.2430     0.000011
# discharge       3927         3948 0.2412     0.000011
# discharge       3951         3972 0.2398     0.000011
# discharge       3975         3996 0.2441     0.000012
# discharge       3999         4020 0.2403     0.000011
# discharge       4023         4044 0.2415     0.000011
# discharge       4047         4068 0.2407     0.000011
# discharge       4071         4092 0.2408     0.000011
# discharge       4095         4116 0.2362     0.000011
# discharge       4119         4140 0.2358     0.000011
# discharge       4143         4164 0.2359     0.000011
# discharge       4167         4188 0.2369     0.000011
# discharge       4191         4212 0.2392     0.000011
# discharge       4215         4236 0.2365     0.000011
# discharge       4239         4260 0.2360     0.000011
# discharge       4263         4284 0.2353     0.000011
# discharge       4287         4308 0.2382     0.000011
# discharge       4311         4332 0.2403     0.000011
# discharge       4335         4356 0.2404     0.000011
# discharge       4359         4380 0.2396     0.000011
# discharge       4383         4404 0.2402     0.000011
# discharge       4407         4428 0.2409     0.000011
# discharge       4431         4452 0.2411     0.000011
# discharge       4455         4476 0.2395     0.000011
# discharge       4479         4500 0.2401     0.000011
# discharge       4503         4524 0.2418     0.000011
# discharge       4527         4548 0.2420     0.000011
# discharge       4551         4572 0.2431     0.000011
# discharge       4575         4596 0.2431     0.000011
# discharge       4599         4620 0.2427     0.000011
# discharge       4623         4644 0.2415     0.000011
# discharge       4648         4668 0.2427     0.000011
# discharge       4671         4692 0.2433     0.000011
# discharge       4695         4716 0.2450     0.000012
# discharge       4719         4740 0.2452     0.000012
# discharge       4744         4764 0.2451     0.000012
# discharge       4767         4788 0.2446     0.000012
# discharge       4792         4812 0.2448     0.000012
# discharge       4815         4836 0.2448     0.000012
# discharge       4839         4860 0.2444     0.000012
# discharge       4863         4884 0.2446     0.000012
# discharge       4888         4908 0.2437     0.000012
# discharge       4912         4932 0.2442     0.000012
# discharge       4935         4956 0.2462     0.000012
# discharge       4959         4980 0.2464     0.000012
# discharge       4983         5004 0.2463     0.000012
# discharge       5007         5028 0.2461     0.000012
# discharge       5031         5052 0.2471     0.000012
# discharge       5055         5076 0.2462     0.000012
# discharge       5079         5100 0.2459     0.000012
# discharge       5103         5124 0.2464     0.000012
# discharge       5128         5149 0.2548     0.000012
# discharge       5152         5172 0.2454     0.000012
# discharge       5176         5196 0.2458     0.000012
# discharge       5200         5220 0.2456     0.000012
# discharge       5224         5244 0.2491     0.000012
# discharge       5248         5268 0.2486     0.000012
# discharge       5272         5292 0.2485     0.000012
# discharge       5296         5316 0.2535     0.000012
# discharge       5320         5341 0.2546     0.000012
# discharge       5344         5364 0.2467     0.000012
# discharge       5368         5388 0.2477     0.000012
# discharge       5392         5413 0.2494     0.000012
# discharge       5415         5437 0.2518     0.000012
# discharge       5439         5461 0.2508     0.000012
# discharge       5463         5485 0.2523     0.000012
# discharge       5487         5509 0.2563     0.000013
# discharge       5512         5533 0.2588     0.000013
# discharge       5536         5557 0.2575     0.000013
# discharge       5560         5581 0.2598     0.000013
# discharge       5584         5605 0.2600     0.000013
# discharge       5608         5629 0.2607     0.000013
# discharge       5632         5653 0.2622     0.000013
# discharge       5655         5677 0.2617     0.000013
# discharge       5679         5701 0.2598     0.000013
# discharge       5704         5725 0.2618     0.000013
# discharge       5728         5749 0.2610     0.000013
# discharge       5752         5773 0.2617     0.000013
# discharge       5776         5797 0.2636     0.000013
# discharge       5800         5821 0.2606     0.000013
# discharge       5824         5845 0.2607     0.000013
# discharge       5848         5869 0.2632     0.000013
# discharge       5872         5893 0.2638     0.000013
# discharge       5896         5917 0.2633     0.000013
# discharge       5920         5941 0.2633     0.000013
# discharge       5944         5965 0.2640     0.000013
# discharge       5968         5989 0.2635     0.000013
# discharge       5992         6013 0.2686     0.000014
# discharge       6016         6037 0.2699     0.000014
# discharge       6040         6061 0.2722     0.000014
# discharge       6064         6085 0.2716     0.000014
# discharge       6088         6109 0.2755     0.000014
# discharge       6112         6133 0.2695     0.000014
# discharge       6136         6157 0.2707     0.000014
# discharge       6160         6181 0.2719     0.000014
# discharge       6184         6205 0.2723     0.000014
# discharge       6208         6229 0.2750     0.000014
# discharge       6232         6253 0.2756     0.000014
# discharge       6256         6277 0.2753     0.000014
# discharge       6280         6301 0.2771     0.000014
# discharge       6304         6325 0.2773     0.000015
# discharge       6328         6349 0.2773     0.000014
# discharge       6352         6373 0.2788     0.000015
# discharge       6376         6397 0.2781     0.000015
# discharge       6400         6421 0.2788     0.000015
# discharge       6424         6445 0.2812     0.000015
# discharge       6448         6469 0.2804     0.000015
# discharge       6472         6493 0.2809     0.000015
# discharge       6496         6517 0.2800     0.000015
# discharge       6520         6541 0.2833     0.000015
# discharge       6544         6565 0.2815     0.000015
# discharge       6568         6589 0.2824     0.000015
# discharge       6592         6613 0.2847     0.000015
# discharge       6616         6637 0.2851     0.000015
# discharge       6640         6661 0.2841     0.000015
# discharge       6664         6685 0.2849     0.000015
# discharge       6688         6709 0.2844     0.000015
# discharge       6712         6733 0.2841     0.000015
# discharge       6736         6757 0.2860     0.000015
# discharge       6760         6781 0.2863     0.000015
# discharge       6784         6805 0.2864     0.000015
# discharge       6808         6829 0.2869     0.000015
# discharge       6832         6853 0.2861     0.000015
# discharge       6856         6877 0.2864     0.000015
# discharge       6880         6901 0.2864     0.000015
# discharge       6904         6925 0.2852     0.000015
# discharge       6928         6949 0.2815     0.000015
# discharge       6952         6973 0.2861     0.000015
# discharge       6976         6998 0.2898     0.000016
# discharge       7000         7021 0.2854     0.000015
# discharge       7024         7045 0.2855     0.000015
# discharge       7048         7069 0.2854     0.000015
# discharge       7072         7093 0.2862     0.000015
# discharge       7096         7117 0.2845     0.000015
# discharge       7120         7141 0.2849     0.000015
# discharge       7144         7165 0.2860     0.000015
# discharge       7168         7189 0.2847     0.000015
# discharge       7192         7214 0.3042     0.000017
# discharge       7218         7238 0.2861     0.000015
# discharge       7240         7261 0.2843     0.000015
# discharge       7264         7285 0.2847     0.000015
# discharge       7288         7309 0.2845     0.000015
# discharge       7312         7333 0.2842     0.000015
# discharge       7336         7358 0.3066     0.000017
# discharge       7363         7382 0.3050     0.000017
# discharge       7385         7405 0.2846     0.000015
# discharge       7408         7430 0.3022     0.000017
# discharge       7432         7454 0.2878     0.000015
# discharge       7456         7478 0.2895     0.000016
# discharge       7480         7502 0.2936     0.000016
# discharge       7504         7526 0.2911     0.000016
# discharge       7528         7550 0.2985     0.000017
# discharge       7553         7574 0.2968     0.000016
# discharge       7576         7598 0.2968     0.000016
# discharge       7600         7622 0.2961     0.000016
# discharge       7624         7646 0.2987     0.000017
# discharge       7648         7670 0.3005     0.000017
# discharge       7672         7694 0.3025     0.000017
# discharge       7697         7718 0.3002     0.000017
# discharge       7720         7742 0.3030     0.000017
# discharge       7744         7766 0.3034     0.000017
# discharge       7769         7790 0.3032     0.000017
# discharge       7792         7814 0.3067     0.000017
# discharge       7817         7838 0.3030     0.000017
# discharge       7840         7862 0.3061     0.000017
# discharge       7865         7886 0.3116     0.000018
# discharge       7889         7910 0.3199     0.000019
# discharge       7915         7934 0.3103     0.000018
# discharge       7938         7958 0.3196     0.000019
# discharge       7962         7982 0.3047     0.000017
# discharge       7984         8006 0.3053     0.000017
# discharge       8009         8030 0.3250     0.000019
# discharge       8033         8054 0.3070     0.000017
# discharge       8057         8078 0.3132     0.000018
# discharge       8081         8102 0.3241     0.000019
# discharge       8105         8126 0.3223     0.000019
# discharge       8129         8150 0.3115     0.000018
# discharge       8153         8174 0.3116     0.000018
# discharge       8177         8198 0.3136     0.000018
# discharge       8201         8222 0.3144     0.000018
# discharge       8227         8246 0.3248     0.000019
# discharge       8249         8270 0.3115     0.000018
# discharge       8272         8294 0.3154     0.000018
# discharge       8297         8318 0.3239     0.000019
# discharge       8321         8342 0.3206     0.000019
# discharge       8345         8367 0.3321     0.000020
# discharge       8371         8390 0.3177     0.000018
# discharge       8393         8414 0.3181     0.000019
# discharge       8417         8438 0.3275     0.000020
# discharge       8441         8462 0.3169     0.000018
# discharge       8465         8486 0.3208     0.000019
# discharge       8489         8510 0.3226     0.000019
# discharge       8513         8534 0.3187     0.000019
# discharge       8538         8559 0.3322     0.000020
# discharge       8563         8582 0.3279     0.000020
# discharge       8585         8606 0.3209     0.000019
# discharge       8609         8630 0.3219     0.000019
# discharge       8633         8654 0.3232     0.000019
# discharge       8659         8678 0.3279     0.000020
# discharge       8681         8702 0.3224     0.000019
# discharge       8705         8726 0.3235     0.000019
# discharge       8729         8750 0.3193     0.000019
#
# Total Estimated Degradation: 0.005308
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada\dispatch_profile_1980.png
#
# === Unmet Load Across Years 100% met (Load Factor 0.55) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 0.00 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 0.00 kWh (Year 2024)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_100_percent_met_55_percent_inference_Nevada"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 55% reduction (Case 1) in LP for 100% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_71_percent_inference_Nevada"
dispatch_load_factor = 0.71  # Apply 0.71 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.71)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Load Factor 0.71) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.71)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.71) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890599 nonzeros
# Model fingerprint: 0x186cea13
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 8s)...
# Presolve removed 8764 rows and 8763 columns (presolve time = 10s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 1 rows and 8760 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 11s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 16s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 24s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 28.86s
# Presolved: 70077 rows, 35042 columns, 161748 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 152983 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   2.008805e+06   8.726124e+06     50s
#     2542    6.1688973e+13   8.126956e-02   9.088101e+08     56s
#     3399    3.3206199e+13   5.494590e-01   8.048786e+08     60s
#     4007    2.2054806e+13   3.208257e-01   2.444477e+08     66s
#     4425    1.9471227e+13   1.377645e-01   1.515313e+08     71s
#     4730    1.6038060e+13   8.775847e-02   2.411414e+16     75s
#     5235    1.3714348e+13   2.003817e-03   3.779878e+09     81s
#     5435    1.3247642e+13   1.271044e-02   1.545828e+08     85s
#     5735    1.1985685e+13   2.687559e-03   4.333530e+08     91s
#     6168    9.3844282e+12   0.000000e+00   5.688216e+08     96s
#     6569    7.8434405e+12   5.983494e-04   1.826134e+13    101s
#     7202    4.6387992e+12   0.000000e+00   2.446134e+08    105s
#     8157    2.7737010e+12   2.326598e-05   2.188463e+07    110s
#     9014    1.8693417e+12   0.000000e+00   2.978717e+15    116s
#     9905    1.2599648e+12   0.000000e+00   4.782242e+06    120s
#    10752    8.2585779e+11   0.000000e+00   3.145942e+07    125s
#    11709    4.7917462e+11   0.000000e+00   1.391961e+06    131s
# Concurrent spin time: 7.11s
#
# Solved with dual simplex
#
# Root relaxation: objective 2.692902e+09, 47002 iterations, 88.33 seconds (57.97 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.6929e+09    0   21          - 2.6929e+09      -     -  138s
# H    0     0                    4.622943e+09 2.6929e+09  41.7%     -  144s
# H    0     0                    3.102824e+09 2.6929e+09  13.2%     -  154s
# H    0     0                    2.994402e+09 2.6929e+09  10.1%     -  164s
#      0     2 2.6929e+09    0   21 2.9944e+09 2.6929e+09  10.1%     -  164s
#      3     8 2.6929e+09    2   21 2.9944e+09 2.6929e+09  10.1%  40.0  171s
#     23    40 2.6929e+09    5   21 2.9944e+09 2.6929e+09  10.1%  37.6  178s
#     39    71 2.7191e+09    6   20 2.9944e+09 2.6929e+09  10.1%  24.5  180s
#    168   180 2.7138e+09   14   19 2.9944e+09 2.6929e+09  10.1%  40.9  185s
#    212   229 2.6929e+09   16   20 2.9944e+09 2.6929e+09  10.1%  41.0  210s
# H  215   229                    2.694052e+09 2.6929e+09  0.04%  40.8  210s
#
# Explored 228 nodes (56160 simplex iterations) in 211.82 seconds (186.60 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 2.69405e+09 2.9944e+09 3.10282e+09 4.62294e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.694051831039e+09, best bound 2.692901893783e+09, gap 0.0427%
# Optimal Solution Found!
# Solar Capacity: 7505751.01 kW
# Wind Capacity: 0.00 kW
# Battery Capacity: 4238109.92 kWh
# Total NPC: $2694051831.04
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2504662764.45 kWh
# Total Energy Generated: 4608013221.28 kWh
# Total Energy Used (along with efficiency losses): 2103350456.83 kWh
# Utilization Percentage: 45.65%
# $31756293.57 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 7505751.01 kW
# Solar Initial Cost:    $697659556.07
# Wind Initial Capacity: 0.00 kW
# Wind Initial Cost:     $0.00
# Battery Initial Capacity: 4238109.92 kWh
# Battery Initial Cost:  $1517243351.18
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -24018.40 kW
# Solar Redundant Cost:    $-2232510.58
# Wind Redundant Capacity: 0.00 kW
# Wind Redundant Cost:     $0.00
# Battery Redundant Capacity: 15681.01 kWh
# Battery Redundant Cost:  $5613800.40
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $695427045.49
# Solar OPEX:         $759590404.00
# Solar Replacement:  $0.00
# Solar Salvage:     -$202163020.12
# Wind CAPEX:         $0.00
# Wind OPEX:          $0.00
# Wind Replacement:   $0.00
# Wind Salvage:      -$0.00
# Battery CAPEX:      $1522857151.58
# Battery OPEX:       $458787257.78
# Battery Replacement:$403486812.03
# Battery Salvage:   -$553374726.67
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3097538643.06
#
# === 2024 Solar Results 99% met (Load Factor 0.71) ===
# Total Unmet Load: 2633612.23 kWh
# Hours with Unmet Load: [470, 471, 518, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 776, 777, 778, 779, 780, 781, 782, 1238]
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.6286     0.000063
# discharge         18           38 0.6676     0.000070
# discharge         42           63 0.7025     0.000077
# discharge         71           86 0.6713     0.000071
# discharge         90          111 0.7014     0.000076
# discharge        116          135 0.6782     0.000072
# discharge        139          158 0.7015     0.000076
# discharge        162          182 0.6631     0.000069
# discharge        186          206 0.6624     0.000069
# discharge        210          230 0.6714     0.000071
# discharge        234          254 0.6593     0.000068
# discharge        258          278 0.6546     0.000067
# discharge        282          302 0.6600     0.000068
# discharge        307          326 0.6575     0.000068
# discharge        330          350 0.6596     0.000068
# discharge        356          374 0.6637     0.000069
# discharge        378          399 0.6718     0.000071
# discharge        403          422 0.6666     0.000070
# discharge        426          447 0.6954     0.000075
# discharge        454          471 0.6834     0.000073
# discharge        476          496 0.7339     0.000083
# discharge        503          519 0.6773     0.000072
# discharge        526          543 0.2317     0.000011
# discharge        549          566 0.6578     0.000068
# discharge        571          591 0.6805     0.000072
# discharge        595          614 0.6363     0.000064
# discharge        618          638 0.6387     0.000065
# discharge        642          662 0.6524     0.000067
# discharge        666          686 0.6473     0.000066
# discharge        690          710 0.6392     0.000065
# discharge        714          734 0.6381     0.000064
# discharge        738          760 0.7146     0.000079
# discharge        766          782 0.4577     0.000036
# discharge        791          806 0.6493     0.000066
# discharge        810          830 0.6443     0.000066
# discharge        835          854 0.6365     0.000064
# discharge        860          879 0.6471     0.000066
# discharge        884          902 0.6634     0.000069
# discharge        908          926 0.6410     0.000065
# discharge        930          950 0.6439     0.000065
# discharge        954          974 0.6697     0.000070
# discharge        978          998 0.6087     0.000059
# discharge       1001         1022 0.6082     0.000059
# discharge       1025         1046 0.6170     0.000061
# discharge       1050         1070 0.6322     0.000063
# discharge       1074         1094 0.6461     0.000066
# discharge       1098         1118 0.6128     0.000060
# discharge       1122         1142 0.6267     0.000062
# discharge       1146         1166 0.6007     0.000058
# discharge       1169         1190 0.6030     0.000058
# discharge       1194         1216 0.6691     0.000070
# discharge       1223         1238 0.6478     0.000066
# discharge       1243         1262 0.6183     0.000061
# discharge       1266         1286 0.6206     0.000061
# discharge       1291         1310 0.6296     0.000063
# discharge       1318         1333 0.5901     0.000056
# discharge       1339         1358 0.6427     0.000065
# discharge       1364         1381 0.5945     0.000057
# discharge       1385         1405 0.5897     0.000056
# discharge       1409         1429 0.5906     0.000056
# discharge       1433         1453 0.5907     0.000056
# discharge       1457         1477 0.5907     0.000056
# discharge       1481         1501 0.5922     0.000056
# discharge       1505         1525 0.5913     0.000056
# discharge       1529         1549 0.5912     0.000056
# discharge       1553         1573 0.5894     0.000056
# discharge       1577         1598 0.6301     0.000063
# discharge       1605         1621 0.6039     0.000058
# discharge       1625         1645 0.5892     0.000056
# discharge       1649         1669 0.5880     0.000056
# discharge       1674         1694 0.6444     0.000066
# discharge       1699         1717 0.5881     0.000056
# discharge       1722         1741 0.5884     0.000056
# discharge       1745         1765 0.5882     0.000056
# discharge       1769         1790 0.6150     0.000060
# discharge       1794         1814 0.6306     0.000063
# discharge       1818         1837 0.5875     0.000056
# discharge       1841         1861 0.5855     0.000055
# discharge       1865         1885 0.6049     0.000059
# discharge       1889         1909 0.5858     0.000055
# discharge       1913         1933 0.5843     0.000055
# discharge       1937         1957 0.5826     0.000055
# discharge       1962         1981 0.5823     0.000055
# discharge       1985         2006 0.6071     0.000059
# discharge       2010         2029 0.6052     0.000059
# discharge       2033         2053 0.5814     0.000055
# discharge       2058         2077 0.5784     0.000054
# discharge       2081         2101 0.5808     0.000054
# discharge       2105         2126 0.5864     0.000055
# discharge       2130         2150 0.5997     0.000058
# discharge       2154         2173 0.5941     0.000057
# discharge       2178         2197 0.5853     0.000055
# discharge       2201         2221 0.5780     0.000054
# discharge       2225         2245 0.5742     0.000053
# discharge       2249         2269 0.5723     0.000053
# discharge       2273         2293 0.5718     0.000053
# discharge       2297         2317 0.5772     0.000054
# discharge       2321         2341 0.5680     0.000052
# discharge       2345         2365 0.5703     0.000053
# discharge       2369         2389 0.5691     0.000052
# discharge       2393         2413 0.5689     0.000052
# discharge       2417         2437 0.5613     0.000051
# discharge       2441         2461 0.5660     0.000052
# discharge       2465         2485 0.5640     0.000052
# discharge       2489         2509 0.5656     0.000052
# discharge       2513         2533 0.5657     0.000052
# discharge       2537         2557 0.5617     0.000051
# discharge       2561         2581 0.5622     0.000051
# discharge       2585         2605 0.5587     0.000051
# discharge       2609         2629 0.5607     0.000051
# discharge       2633         2653 0.5558     0.000050
# discharge       2657         2677 0.5588     0.000051
# discharge       2681         2701 0.5537     0.000050
# discharge       2705         2725 0.5509     0.000050
# discharge       2729         2749 0.5504     0.000049
# discharge       2753         2773 0.5477     0.000049
# discharge       2777         2797 0.5455     0.000049
# discharge       2801         2821 0.5559     0.000050
# discharge       2825         2845 0.5442     0.000048
# discharge       2849         2869 0.5444     0.000048
# discharge       2873         2893 0.5408     0.000048
# discharge       2897         2917 0.5456     0.000049
# discharge       2921         2941 0.5419     0.000048
# discharge       2945         2965 0.5418     0.000048
# discharge       2969         2989 0.5381     0.000047
# discharge       2993         3013 0.5680     0.000052
# discharge       3017         3037 0.5392     0.000048
# discharge       3041         3061 0.5387     0.000048
# discharge       3065         3085 0.5396     0.000048
# discharge       3089         3109 0.5342     0.000047
# discharge       3113         3133 0.5357     0.000047
# discharge       3137         3157 0.5302     0.000046
# discharge       3161         3181 0.5333     0.000047
# discharge       3185         3205 0.5336     0.000047
# discharge       3209         3229 0.5297     0.000046
# discharge       3233         3253 0.5463     0.000049
# discharge       3257         3277 0.5279     0.000046
# discharge       3281         3301 0.5322     0.000047
# discharge       3305         3325 0.5261     0.000046
# discharge       3330         3349 0.5265     0.000046
# discharge       3353         3373 0.5276     0.000046
# discharge       3377         3397 0.5293     0.000046
# discharge       3401         3421 0.5275     0.000046
# discharge       3425         3445 0.5245     0.000045
# discharge       3449         3469 0.5270     0.000046
# discharge       3473         3493 0.5267     0.000046
# discharge       3497         3517 0.5270     0.000046
# discharge       3521         3541 0.5288     0.000046
# discharge       3545         3565 0.5273     0.000046
# discharge       3569         3589 0.5311     0.000046
# discharge       3593         3613 0.5277     0.000046
# discharge       3617         3637 0.5230     0.000045
# discharge       3641         3661 0.5255     0.000046
# discharge       3665         3685 0.5259     0.000046
# discharge       3689         3709 0.5238     0.000045
# discharge       3713         3733 0.5263     0.000046
# discharge       3737         3757 0.5248     0.000045
# discharge       3761         3781 0.5233     0.000045
# discharge       3785         3805 0.5238     0.000045
# discharge       3809         3829 0.5208     0.000045
# discharge       3833         3853 0.5202     0.000045
# discharge       3857         3877 0.5254     0.000046
# discharge       3881         3901 0.5256     0.000046
# discharge       3905         3925 0.5273     0.000046
# discharge       3929         3949 0.5237     0.000045
# discharge       3953         3973 0.5190     0.000045
# discharge       3977         3997 0.5295     0.000046
# discharge       4001         4021 0.5237     0.000045
# discharge       4025         4045 0.5242     0.000045
# discharge       4049         4069 0.5226     0.000045
# discharge       4073         4093 0.5236     0.000045
# discharge       4097         4117 0.5194     0.000045
# discharge       4121         4141 0.5183     0.000044
# discharge       4145         4165 0.5189     0.000045
# discharge       4169         4189 0.5164     0.000044
# discharge       4193         4213 0.5211     0.000045
# discharge       4217         4237 0.5172     0.000044
# discharge       4241         4261 0.5168     0.000044
# discharge       4265         4285 0.5175     0.000044
# discharge       4289         4309 0.5240     0.000045
# discharge       4313         4333 0.5259     0.000046
# discharge       4337         4357 0.5266     0.000046
# discharge       4361         4381 0.5227     0.000045
# discharge       4385         4405 0.5217     0.000045
# discharge       4409         4429 0.5246     0.000045
# discharge       4433         4453 0.5253     0.000045
# discharge       4457         4477 0.5244     0.000045
# discharge       4481         4501 0.5240     0.000045
# discharge       4505         4525 0.5289     0.000046
# discharge       4529         4549 0.5249     0.000045
# discharge       4553         4573 0.5247     0.000045
# discharge       4577         4597 0.5269     0.000046
# discharge       4601         4621 0.5213     0.000045
# discharge       4625         4645 0.5279     0.000046
# discharge       4650         4669 0.5221     0.000045
# discharge       4673         4693 0.5235     0.000045
# discharge       4697         4717 0.5352     0.000047
# discharge       4721         4741 0.5247     0.000045
# discharge       4745         4765 0.5242     0.000045
# discharge       4769         4789 0.5239     0.000045
# discharge       4793         4813 0.5258     0.000046
# discharge       4817         4837 0.5255     0.000046
# discharge       4841         4861 0.5251     0.000045
# discharge       4865         4885 0.5256     0.000046
# discharge       4890         4909 0.5236     0.000045
# discharge       4913         4933 0.5245     0.000045
# discharge       4937         4957 0.5280     0.000046
# discharge       4961         4981 0.5285     0.000046
# discharge       4985         5005 0.5300     0.000046
# discharge       5009         5029 0.5319     0.000047
# discharge       5033         5053 0.5353     0.000047
# discharge       5057         5077 0.5334     0.000047
# discharge       5081         5101 0.5312     0.000046
# discharge       5105         5125 0.5324     0.000047
# discharge       5129         5149 0.5499     0.000049
# discharge       5156         5173 0.5297     0.000046
# discharge       5177         5197 0.5336     0.000047
# discharge       5201         5221 0.5326     0.000047
# discharge       5225         5245 0.5390     0.000048
# discharge       5249         5269 0.5369     0.000047
# discharge       5273         5293 0.5372     0.000047
# discharge       5297         5317 0.5698     0.000053
# discharge       5321         5341 0.5451     0.000049
# discharge       5346         5365 0.5377     0.000047
# discharge       5369         5389 0.5408     0.000048
# discharge       5393         5413 0.5419     0.000048
# discharge       5417         5437 0.5465     0.000049
# discharge       5441         5461 0.5449     0.000049
# discharge       5465         5485 0.5469     0.000049
# discharge       5489         5509 0.5520     0.000050
# discharge       5513         5533 0.5538     0.000050
# discharge       5537         5557 0.5515     0.000050
# discharge       5561         5581 0.5555     0.000050
# discharge       5585         5605 0.5556     0.000050
# discharge       5609         5629 0.5591     0.000051
# discharge       5633         5653 0.5595     0.000051
# discharge       5657         5677 0.5592     0.000051
# discharge       5681         5701 0.5594     0.000051
# discharge       5705         5725 0.5628     0.000051
# discharge       5729         5749 0.5616     0.000051
# discharge       5753         5773 0.5629     0.000051
# discharge       5777         5797 0.5651     0.000052
# discharge       5801         5821 0.5627     0.000051
# discharge       5825         5845 0.5645     0.000052
# discharge       5850         5869 0.5675     0.000052
# discharge       5873         5893 0.5704     0.000053
# discharge       5897         5917 0.5689     0.000052
# discharge       5922         5941 0.5707     0.000053
# discharge       5945         5965 0.5724     0.000053
# discharge       5969         5989 0.5735     0.000053
# discharge       5993         6013 0.5770     0.000054
# discharge       6017         6037 0.5796     0.000054
# discharge       6041         6061 0.5816     0.000055
# discharge       6065         6085 0.5805     0.000054
# discharge       6089         6109 0.5829     0.000055
# discharge       6113         6133 0.5761     0.000054
# discharge       6137         6157 0.5785     0.000054
# discharge       6161         6181 0.5810     0.000054
# discharge       6185         6205 0.5790     0.000054
# discharge       6209         6229 0.5819     0.000055
# discharge       6233         6253 0.5832     0.000055
# discharge       6257         6277 0.5825     0.000055
# discharge       6281         6301 0.5835     0.000055
# discharge       6305         6325 0.5840     0.000055
# discharge       6329         6349 0.5812     0.000055
# discharge       6353         6373 0.5843     0.000055
# discharge       6377         6397 0.5828     0.000055
# discharge       6401         6421 0.5843     0.000055
# discharge       6425         6445 0.5864     0.000055
# discharge       6449         6469 0.5848     0.000055
# discharge       6473         6493 0.5860     0.000055
# discharge       6497         6517 0.5841     0.000055
# discharge       6521         6541 0.5880     0.000056
# discharge       6546         6565 0.5844     0.000055
# discharge       6570         6589 0.5862     0.000055
# discharge       6593         6613 0.5883     0.000056
# discharge       6617         6637 0.5891     0.000056
# discharge       6641         6661 0.5871     0.000056
# discharge       6666         6685 0.5886     0.000056
# discharge       6690         6709 0.5877     0.000056
# discharge       6714         6733 0.5871     0.000056
# discharge       6738         6758 0.5919     0.000056
# discharge       6762         6781 0.5887     0.000056
# discharge       6786         6805 0.5890     0.000056
# discharge       6810         6830 0.5915     0.000056
# discharge       6834         6853 0.5884     0.000056
# discharge       6858         6877 0.5890     0.000056
# discharge       6881         6902 0.5901     0.000056
# discharge       6906         6926 0.5882     0.000056
# discharge       6930         6950 0.5921     0.000056
# discharge       6954         6974 0.5976     0.000057
# discharge       6978         6998 0.6178     0.000061
# discharge       7002         7022 0.5997     0.000058
# discharge       7026         7046 0.6024     0.000058
# discharge       7050         7070 0.6079     0.000059
# discharge       7074         7094 0.6018     0.000058
# discharge       7098         7118 0.5987     0.000057
# discharge       7122         7142 0.5988     0.000058
# discharge       7146         7166 0.6268     0.000062
# discharge       7170         7190 0.6067     0.000059
# discharge       7194         7215 0.6398     0.000065
# discharge       7221         7238 0.6130     0.000060
# discharge       7242         7262 0.6100     0.000059
# discharge       7266         7286 0.5988     0.000058
# discharge       7290         7310 0.6040     0.000058
# discharge       7314         7334 0.6077     0.000059
# discharge       7338         7359 0.6684     0.000070
# discharge       7365         7382 0.6429     0.000065
# discharge       7387         7406 0.6104     0.000060
# discharge       7410         7430 0.6269     0.000062
# discharge       7434         7454 0.6185     0.000061
# discharge       7458         7478 0.6145     0.000060
# discharge       7482         7502 0.6202     0.000061
# discharge       7506         7526 0.6149     0.000060
# discharge       7530         7550 0.6221     0.000062
# discharge       7554         7574 0.6306     0.000063
# discharge       7578         7598 0.6457     0.000066
# discharge       7602         7622 0.6228     0.000062
# discharge       7626         7646 0.6224     0.000062
# discharge       7650         7670 0.6386     0.000065
# discharge       7674         7694 0.6379     0.000064
# discharge       7698         7718 0.6380     0.000064
# discharge       7722         7742 0.6329     0.000063
# discharge       7746         7766 0.6379     0.000064
# discharge       7770         7790 0.6353     0.000064
# discharge       7794         7814 0.6394     0.000065
# discharge       7818         7838 0.6347     0.000064
# discharge       7842         7862 0.6430     0.000065
# discharge       7866         7886 0.6598     0.000068
# discharge       7892         7911 0.6895     0.000074
# discharge       7917         7934 0.6572     0.000068
# discharge       7940         7958 0.6655     0.000069
# discharge       7964         7982 0.6522     0.000067
# discharge       7986         8006 0.6529     0.000067
# discharge       8011         8030 0.6712     0.000071
# discharge       8035         8054 0.6559     0.000068
# discharge       8058         8078 0.6604     0.000069
# discharge       8082         8102 0.6692     0.000070
# discharge       8107         8126 0.6682     0.000070
# discharge       8130         8150 0.6597     0.000068
# discharge       8154         8174 0.6600     0.000068
# discharge       8178         8198 0.6614     0.000069
# discharge       8202         8223 0.6631     0.000069
# discharge       8229         8246 0.6707     0.000070
# discharge       8250         8270 0.6596     0.000068
# discharge       8274         8294 0.6622     0.000069
# discharge       8300         8318 0.6689     0.000070
# discharge       8325         8342 0.6675     0.000070
# discharge       8346         8368 0.7216     0.000080
# discharge       8372         8390 0.6642     0.000069
# discharge       8394         8414 0.6651     0.000069
# discharge       8418         8438 0.6735     0.000071
# discharge       8442         8462 0.6627     0.000069
# discharge       8466         8486 0.6679     0.000070
# discharge       8491         8510 0.6689     0.000070
# discharge       8514         8535 0.6692     0.000070
# discharge       8540         8560 0.7096     0.000078
# discharge       8565         8582 0.6930     0.000075
# discharge       8587         8606 0.6682     0.000070
# discharge       8613         8630 0.6702     0.000070
# discharge       8634         8654 0.6702     0.000070
# discharge       8661         8679 0.6899     0.000074
# discharge       8683         8703 0.6722     0.000071
# discharge       8707         8726 0.6708     0.000070
# discharge       8730         8750 0.6675     0.000070
#
# Total Estimated Degradation: 0.020427
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.71) ===
# Year 2024: Unmet Load = 2633612.23 kWh
# Year 2023: Unmet Load = 3327219.20 kWh
# Year 2022: Unmet Load = 2161873.35 kWh
# Year 2021: Unmet Load = 1203475.85 kWh
# Year 2020: Unmet Load = 1317757.62 kWh
# Year 2019: Unmet Load = 6508972.62 kWh
# Year 2018: Unmet Load = 1349785.75 kWh
# Year 2017: Unmet Load = 3871260.03 kWh
# Year 2016: Unmet Load = 5208415.80 kWh
# Year 2015: Unmet Load = 4107225.77 kWh
# Year 2014: Unmet Load = 782724.75 kWh
# Year 2013: Unmet Load = 1168031.54 kWh
# Year 2012: Unmet Load = 753305.03 kWh
# Year 2011: Unmet Load = 813763.67 kWh
# Year 2010: Unmet Load = 11296069.36 kWh
# Year 2009: Unmet Load = 2201146.98 kWh
# Year 2008: Unmet Load = 6704896.01 kWh
# Year 2007: Unmet Load = 1032673.78 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 8252029.31 kWh
# Year 2004: Unmet Load = 362987.39 kWh
# Year 2003: Unmet Load = 2590126.52 kWh
# Year 2002: Unmet Load = 327535.03 kWh
# Year 2001: Unmet Load = 766177.45 kWh
# Year 2000: Unmet Load = 1333804.81 kWh
# Year 1999: Unmet Load = 339310.84 kWh
# Year 1998: Unmet Load = 405076.91 kWh
# Year 1997: Unmet Load = 3039219.25 kWh
# Year 1996: Unmet Load = 1074011.16 kWh
# Year 1995: Unmet Load = 6612133.70 kWh
# Year 1994: Unmet Load = 2677366.61 kWh
# Year 1993: Unmet Load = 4837128.23 kWh
# Year 1992: Unmet Load = 394700.84 kWh
# Year 1991: Unmet Load = 2084482.80 kWh
# Year 1990: Unmet Load = 1473457.56 kWh
# Year 1989: Unmet Load = 1125316.27 kWh
# Year 1988: Unmet Load = 3708786.19 kWh
# Year 1987: Unmet Load = 1357700.28 kWh
# Year 1986: Unmet Load = 2696447.69 kWh
# Year 1985: Unmet Load = 1957573.83 kWh
# Year 1984: Unmet Load = 1609775.52 kWh
# Year 1983: Unmet Load = 3121150.41 kWh
# Year 1982: Unmet Load = 2377215.51 kWh
# Year 1981: Unmet Load = 2636708.62 kWh
# Year 1980: Unmet Load = 5074547.40 kWh
#
# Average Unmet Load (1979-2024): 2637266.21 kWh
# Min Unmet Load: 0.00 kWh (Year 2006)
# Max Unmet Load: 11296069.36 kWh (Year 2010)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_71_percent_inference_Nevada"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 71% reduction (Case 1) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_55_percent_inference_Nevada"
dispatch_load_factor = 0.55  # Apply 0.55 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.55)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Load Factor 0.55) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.55)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.55) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890599 nonzeros
# Model fingerprint: 0x186cea13
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 11s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 26.75s
# Presolved: 70077 rows, 35042 columns, 161748 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 152983 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   2.008805e+06   8.726124e+06     45s
#      326    6.6775258e+14   0.000000e+00   1.168843e+11     45s
#     2542    6.1688973e+13   8.126956e-02   9.088101e+08     50s
#     3599    2.8170762e+13   5.495385e-01   3.477303e+08     56s
#     4107    2.2036780e+13   2.556177e-01   8.470315e+10     61s
#     4527    1.8756536e+13   1.379731e-01   1.500962e+08     65s
#     5035    1.4029180e+13   1.806857e-03   4.172739e+13     71s
#     5435    1.3247642e+13   1.271044e-02   1.545828e+08     76s
#     5735    1.1985685e+13   2.687559e-03   4.333530e+08     81s
#     6168    9.3844282e+12   0.000000e+00   5.688216e+08     86s
#     6569    7.8434405e+12   5.983494e-04   1.826134e+13     90s
#     7510    4.1460852e+12   0.000000e+00   5.063820e+15     96s
#     8471    2.3665786e+12   0.000000e+00   5.102282e+13    100s
#     9346    1.6297486e+12   0.000000e+00   6.761154e+06    105s
#    10424    1.0269607e+12   0.000000e+00   4.070912e+07    110s
#    11369    5.7430325e+11   0.000000e+00   2.306667e+07    115s
# Concurrent spin time: 4.69s
#
# Solved with dual simplex
#
# Root relaxation: objective 2.692902e+09, 47002 iterations, 77.52 seconds (57.97 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.6929e+09    0   21          - 2.6929e+09      -     -  121s
# H    0     0                    4.622943e+09 2.6929e+09  41.7%     -  127s
# H    0     0                    3.102824e+09 2.6929e+09  13.2%     -  136s
# H    0     0                    2.994402e+09 2.6929e+09  10.1%     -  145s
#      0     2 2.6929e+09    0   21 2.9944e+09 2.6929e+09  10.1%     -  145s
#      3     8 2.6929e+09    2   21 2.9944e+09 2.6929e+09  10.1%  40.0  151s
#     23    40 2.6929e+09    5   21 2.9944e+09 2.6929e+09  10.1%  37.6  159s
#     39    71 2.7191e+09    6   20 2.9944e+09 2.6929e+09  10.1%  24.5  160s
#    179   200 2.6929e+09   14   20 2.9944e+09 2.6929e+09  10.1%  42.3  165s
#    212   229 2.6929e+09   16   20 2.9944e+09 2.6929e+09  10.1%  41.0  185s
# H  215   229                    2.694052e+09 2.6929e+09  0.04%  40.8  185s
#
# Explored 228 nodes (56160 simplex iterations) in 186.84 seconds (186.60 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 2.69405e+09 2.9944e+09 3.10282e+09 4.62294e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.694051831039e+09, best bound 2.692901893783e+09, gap 0.0427%
# Optimal Solution Found!
# Solar Capacity: 7505751.01 kW
# Wind Capacity: 0.00 kW
# Battery Capacity: 4238109.92 kWh
# Total NPC: $2694051831.04
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2877071051.97 kWh
# Total Energy Generated: 4608013221.28 kWh
# Total Energy Used (along with efficiency losses): 1730942169.31 kWh
# Utilization Percentage: 37.56%
# $19612110.27 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 7505751.01 kW
# Solar Initial Cost:    $697659556.07
# Wind Initial Capacity: 0.00 kW
# Wind Initial Cost:     $0.00
# Battery Initial Capacity: 4238109.92 kWh
# Battery Initial Cost:  $1517243351.18
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -24018.40 kW
# Solar Redundant Cost:    $-2232510.58
# Wind Redundant Capacity: 0.00 kW
# Wind Redundant Cost:     $0.00
# Battery Redundant Capacity: 15681.01 kWh
# Battery Redundant Cost:  $5613800.40
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $695427045.49
# Solar OPEX:         $759590404.00
# Solar Replacement:  $0.00
# Solar Salvage:     -$202163020.12
# Wind CAPEX:         $0.00
# Wind OPEX:          $0.00
# Wind Replacement:   $0.00
# Wind Salvage:      -$0.00
# Battery CAPEX:      $1522857151.58
# Battery OPEX:       $458787257.78
# Battery Replacement:$249186128.53
# Battery Salvage:   -$553374726.67
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $2943237959.57
#
# === 2024 Solar Results 99% met (Load Factor 0.55) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.4870     0.000040
# discharge         18           38 0.5154     0.000044
# discharge         42           63 0.5402     0.000048
# discharge         69           86 0.5187     0.000044
# discharge         90          111 0.5384     0.000048
# discharge        115          135 0.5160     0.000044
# discharge        138          158 0.5390     0.000048
# discharge        162          182 0.5110     0.000043
# discharge        185          206 0.5100     0.000043
# discharge        209          230 0.5192     0.000045
# discharge        233          254 0.5076     0.000043
# discharge        257          278 0.5026     0.000042
# discharge        281          302 0.5072     0.000043
# discharge        307          326 0.5057     0.000042
# discharge        329          350 0.5074     0.000043
# discharge        355          374 0.5114     0.000043
# discharge        377          399 0.5097     0.000043
# discharge        402          422 0.5146     0.000044
# discharge        426          447 0.5333     0.000047
# discharge        454          471 0.5494     0.000049
# discharge        475          495 0.5516     0.000050
# discharge        503          518 0.5195     0.000045
# discharge        526          543 0.5413     0.000048
# discharge        548          566 0.5055     0.000042
# discharge        570          591 0.5182     0.000044
# discharge        595          614 0.4852     0.000039
# discharge        617          638 0.4863     0.000040
# discharge        641          662 0.4991     0.000042
# discharge        666          686 0.4951     0.000041
# discharge        690          710 0.4866     0.000040
# discharge        713          734 0.4853     0.000039
# discharge        737          759 0.5411     0.000048
# discharge        766          782 0.5319     0.000047
# discharge        790          806 0.4967     0.000041
# discharge        809          830 0.4915     0.000040
# discharge        835          854 0.4848     0.000039
# discharge        859          879 0.4875     0.000040
# discharge        883          902 0.5103     0.000043
# discharge        907          926 0.4880     0.000040
# discharge        929          950 0.4912     0.000040
# discharge        954          974 0.5138     0.000044
# discharge        977          998 0.4657     0.000037
# discharge       1001         1022 0.4653     0.000037
# discharge       1025         1046 0.4744     0.000038
# discharge       1049         1070 0.4794     0.000039
# discharge       1073         1094 0.4933     0.000041
# discharge       1097         1118 0.4702     0.000037
# discharge       1121         1142 0.4738     0.000038
# discharge       1145         1166 0.4577     0.000036
# discharge       1169         1190 0.4599     0.000036
# discharge       1193         1215 0.5092     0.000043
# discharge       1223         1238 0.5073     0.000043
# discharge       1242         1261 0.4704     0.000037
# discharge       1265         1286 0.4776     0.000038
# discharge       1290         1310 0.4772     0.000038
# discharge       1316         1333 0.4561     0.000035
# discharge       1338         1358 0.4893     0.000040
# discharge       1363         1381 0.4605     0.000036
# discharge       1385         1405 0.4568     0.000035
# discharge       1409         1429 0.4575     0.000036
# discharge       1433         1453 0.4576     0.000036
# discharge       1457         1477 0.4576     0.000036
# discharge       1481         1501 0.4587     0.000036
# discharge       1505         1525 0.4581     0.000036
# discharge       1529         1549 0.4580     0.000036
# discharge       1553         1573 0.4562     0.000035
# discharge       1577         1598 0.4859     0.000040
# discharge       1604         1621 0.4602     0.000036
# discharge       1625         1645 0.4560     0.000035
# discharge       1649         1669 0.4546     0.000035
# discharge       1673         1694 0.4907     0.000040
# discharge       1698         1717 0.4547     0.000035
# discharge       1721         1741 0.4549     0.000035
# discharge       1745         1765 0.4547     0.000035
# discharge       1769         1790 0.4710     0.000037
# discharge       1793         1814 0.4812     0.000039
# discharge       1818         1837 0.4537     0.000035
# discharge       1841         1861 0.4517     0.000035
# discharge       1865         1885 0.4607     0.000036
# discharge       1889         1909 0.4515     0.000035
# discharge       1913         1933 0.4504     0.000035
# discharge       1937         1957 0.4486     0.000034
# discharge       1961         1981 0.4484     0.000034
# discharge       1985         2006 0.4626     0.000036
# discharge       2009         2029 0.4603     0.000036
# discharge       2033         2053 0.4472     0.000034
# discharge       2057         2077 0.4449     0.000034
# discharge       2081         2101 0.4468     0.000034
# discharge       2105         2125 0.4497     0.000034
# discharge       2130         2150 0.4556     0.000035
# discharge       2153         2173 0.4515     0.000035
# discharge       2177         2197 0.4507     0.000035
# discharge       2201         2221 0.4437     0.000034
# discharge       2224         2245 0.4394     0.000033
# discharge       2248         2269 0.4380     0.000033
# discharge       2273         2293 0.4371     0.000033
# discharge       2296         2317 0.4426     0.000033
# discharge       2320         2341 0.4333     0.000032
# discharge       2345         2365 0.4355     0.000033
# discharge       2368         2389 0.4337     0.000032
# discharge       2392         2413 0.4335     0.000032
# discharge       2416         2437 0.4272     0.000031
# discharge       2440         2461 0.4313     0.000032
# discharge       2464         2485 0.4293     0.000032
# discharge       2488         2509 0.4301     0.000032
# discharge       2512         2533 0.4306     0.000032
# discharge       2536         2557 0.4266     0.000031
# discharge       2560         2581 0.4270     0.000031
# discharge       2584         2605 0.4238     0.000031
# discharge       2609         2629 0.4254     0.000031
# discharge       2633         2653 0.4207     0.000031
# discharge       2656         2677 0.4235     0.000031
# discharge       2680         2701 0.4182     0.000030
# discharge       2704         2725 0.4160     0.000030
# discharge       2728         2749 0.4147     0.000030
# discharge       2752         2773 0.4141     0.000030
# discharge       2776         2797 0.4113     0.000029
# discharge       2800         2821 0.4203     0.000031
# discharge       2824         2845 0.4113     0.000029
# discharge       2848         2869 0.4112     0.000029
# discharge       2872         2893 0.4083     0.000029
# discharge       2896         2917 0.4116     0.000029
# discharge       2920         2941 0.4106     0.000029
# discharge       2944         2965 0.4096     0.000029
# discharge       2968         2989 0.4087     0.000029
# discharge       2992         3013 0.4319     0.000032
# discharge       3016         3037 0.4088     0.000029
# discharge       3040         3061 0.4101     0.000029
# discharge       3064         3085 0.4088     0.000029
# discharge       3088         3109 0.4043     0.000028
# discharge       3112         3133 0.4058     0.000029
# discharge       3136         3157 0.4036     0.000028
# discharge       3160         3181 0.4055     0.000029
# discharge       3184         3205 0.4047     0.000029
# discharge       3208         3229 0.4029     0.000028
# discharge       3233         3253 0.4200     0.000030
# discharge       3257         3277 0.4026     0.000028
# discharge       3280         3301 0.4035     0.000028
# discharge       3304         3325 0.3991     0.000028
# discharge       3329         3349 0.3997     0.000028
# discharge       3352         3373 0.4008     0.000028
# discharge       3376         3397 0.4028     0.000028
# discharge       3400         3421 0.4005     0.000028
# discharge       3424         3445 0.3987     0.000028
# discharge       3448         3469 0.4010     0.000028
# discharge       3472         3493 0.4004     0.000028
# discharge       3496         3517 0.4010     0.000028
# discharge       3520         3541 0.4016     0.000028
# discharge       3544         3565 0.4013     0.000028
# discharge       3568         3589 0.4040     0.000028
# discharge       3592         3613 0.4007     0.000028
# discharge       3616         3637 0.3966     0.000028
# discharge       3640         3661 0.3994     0.000028
# discharge       3664         3685 0.3993     0.000028
# discharge       3688         3709 0.3973     0.000028
# discharge       3712         3733 0.4000     0.000028
# discharge       3737         3757 0.3985     0.000028
# discharge       3760         3781 0.3973     0.000028
# discharge       3784         3805 0.3977     0.000028
# discharge       3808         3829 0.3945     0.000027
# discharge       3832         3853 0.3936     0.000027
# discharge       3857         3877 0.3994     0.000028
# discharge       3880         3901 0.3995     0.000028
# discharge       3904         3925 0.4008     0.000028
# discharge       3928         3949 0.3971     0.000028
# discharge       3952         3973 0.3922     0.000027
# discharge       3976         3997 0.4026     0.000028
# discharge       4000         4021 0.3976     0.000028
# discharge       4024         4045 0.3976     0.000028
# discharge       4048         4069 0.3963     0.000027
# discharge       4072         4093 0.3971     0.000028
# discharge       4096         4117 0.3929     0.000027
# discharge       4120         4141 0.3921     0.000027
# discharge       4144         4165 0.3926     0.000027
# discharge       4168         4189 0.3897     0.000027
# discharge       4192         4213 0.3943     0.000027
# discharge       4216         4237 0.3908     0.000027
# discharge       4240         4261 0.3904     0.000027
# discharge       4264         4285 0.3915     0.000027
# discharge       4288         4309 0.3978     0.000028
# discharge       4312         4333 0.3998     0.000028
# discharge       4336         4357 0.4003     0.000028
# discharge       4360         4381 0.3968     0.000028
# discharge       4384         4405 0.3956     0.000027
# discharge       4408         4429 0.3983     0.000028
# discharge       4432         4453 0.3989     0.000028
# discharge       4456         4477 0.3986     0.000028
# discharge       4480         4501 0.3978     0.000028
# discharge       4504         4525 0.4021     0.000028
# discharge       4528         4549 0.3990     0.000028
# discharge       4552         4573 0.3984     0.000028
# discharge       4577         4597 0.4005     0.000028
# discharge       4601         4621 0.3953     0.000027
# discharge       4625         4645 0.4022     0.000028
# discharge       4649         4669 0.3959     0.000027
# discharge       4673         4693 0.3970     0.000028
# discharge       4697         4717 0.3985     0.000028
# discharge       4721         4741 0.3984     0.000028
# discharge       4745         4765 0.3980     0.000028
# discharge       4769         4789 0.3978     0.000028
# discharge       4793         4813 0.3996     0.000028
# discharge       4817         4837 0.3995     0.000028
# discharge       4841         4861 0.3991     0.000028
# discharge       4865         4885 0.3995     0.000028
# discharge       4889         4909 0.3979     0.000028
# discharge       4913         4933 0.3987     0.000028
# discharge       4937         4957 0.4023     0.000028
# discharge       4961         4981 0.4027     0.000028
# discharge       4985         5005 0.4043     0.000028
# discharge       5008         5029 0.4062     0.000029
# discharge       5032         5053 0.4093     0.000029
# discharge       5056         5077 0.4078     0.000029
# discharge       5080         5101 0.4057     0.000029
# discharge       5104         5125 0.4066     0.000029
# discharge       5129         5149 0.4176     0.000030
# discharge       5154         5173 0.4045     0.000028
# discharge       5177         5197 0.4077     0.000029
# discharge       5201         5221 0.4067     0.000029
# discharge       5225         5245 0.4129     0.000030
# discharge       5249         5269 0.4104     0.000029
# discharge       5273         5293 0.4076     0.000029
# discharge       5297         5317 0.4306     0.000032
# discharge       5321         5341 0.4172     0.000030
# discharge       5345         5365 0.4088     0.000029
# discharge       5369         5389 0.4110     0.000029
# discharge       5393         5413 0.4123     0.000029
# discharge       5417         5437 0.4145     0.000030
# discharge       5440         5461 0.4129     0.000030
# discharge       5464         5485 0.4152     0.000030
# discharge       5488         5509 0.4183     0.000030
# discharge       5513         5533 0.4206     0.000031
# discharge       5537         5557 0.4185     0.000030
# discharge       5561         5581 0.4206     0.000031
# discharge       5585         5605 0.4208     0.000031
# discharge       5609         5629 0.4237     0.000031
# discharge       5633         5653 0.4244     0.000031
# discharge       5656         5677 0.4242     0.000031
# discharge       5680         5701 0.4244     0.000031
# discharge       5705         5725 0.4279     0.000032
# discharge       5729         5749 0.4270     0.000031
# discharge       5753         5773 0.4280     0.000032
# discharge       5777         5797 0.4306     0.000032
# discharge       5801         5821 0.4283     0.000032
# discharge       5825         5845 0.4301     0.000032
# discharge       5849         5869 0.4329     0.000032
# discharge       5873         5893 0.4356     0.000033
# discharge       5897         5917 0.4344     0.000032
# discharge       5921         5941 0.4363     0.000033
# discharge       5945         5965 0.4376     0.000033
# discharge       5969         5989 0.4388     0.000033
# discharge       5993         6013 0.4429     0.000034
# discharge       6017         6037 0.4450     0.000034
# discharge       6041         6061 0.4469     0.000034
# discharge       6065         6085 0.4461     0.000034
# discharge       6089         6109 0.4488     0.000034
# discharge       6113         6133 0.4427     0.000033
# discharge       6137         6157 0.4446     0.000034
# discharge       6161         6181 0.4465     0.000034
# discharge       6185         6205 0.4454     0.000034
# discharge       6209         6229 0.4481     0.000034
# discharge       6233         6253 0.4491     0.000034
# discharge       6257         6277 0.4486     0.000034
# discharge       6281         6301 0.4498     0.000034
# discharge       6305         6325 0.4502     0.000035
# discharge       6329         6349 0.4484     0.000034
# discharge       6353         6373 0.4508     0.000035
# discharge       6377         6397 0.4497     0.000034
# discharge       6401         6421 0.4509     0.000035
# discharge       6425         6445 0.4529     0.000035
# discharge       6449         6469 0.4516     0.000035
# discharge       6473         6493 0.4526     0.000035
# discharge       6497         6517 0.4511     0.000035
# discharge       6521         6541 0.4546     0.000035
# discharge       6545         6565 0.4518     0.000035
# discharge       6569         6589 0.4532     0.000035
# discharge       6593         6613 0.4553     0.000035
# discharge       6617         6637 0.4559     0.000035
# discharge       6641         6661 0.4543     0.000035
# discharge       6665         6685 0.4555     0.000035
# discharge       6689         6709 0.4548     0.000035
# discharge       6713         6733 0.4543     0.000035
# discharge       6737         6757 0.4556     0.000035
# discharge       6762         6781 0.4561     0.000035
# discharge       6785         6805 0.4563     0.000035
# discharge       6809         6829 0.4571     0.000035
# discharge       6833         6853 0.4558     0.000035
# discharge       6857         6877 0.4563     0.000035
# discharge       6881         6901 0.4562     0.000035
# discharge       6905         6925 0.4544     0.000035
# discharge       6929         6949 0.4518     0.000035
# discharge       6953         6973 0.4557     0.000035
# discharge       6977         6998 0.4750     0.000038
# discharge       7001         7022 0.4573     0.000035
# discharge       7025         7046 0.4599     0.000036
# discharge       7049         7070 0.4655     0.000037
# discharge       7073         7094 0.4590     0.000036
# discharge       7097         7118 0.4566     0.000035
# discharge       7121         7142 0.4567     0.000035
# discharge       7145         7166 0.4739     0.000038
# discharge       7169         7190 0.4646     0.000037
# discharge       7193         7215 0.4875     0.000040
# discharge       7219         7238 0.4708     0.000037
# discharge       7241         7262 0.4681     0.000037
# discharge       7265         7286 0.4567     0.000035
# discharge       7289         7310 0.4621     0.000036
# discharge       7313         7334 0.4658     0.000037
# discharge       7337         7359 0.5061     0.000043
# discharge       7364         7382 0.4904     0.000040
# discharge       7386         7406 0.4684     0.000037
# discharge       7409         7430 0.4847     0.000039
# discharge       7433         7454 0.4719     0.000038
# discharge       7457         7478 0.4728     0.000038
# discharge       7481         7502 0.4777     0.000038
# discharge       7505         7526 0.4737     0.000038
# discharge       7529         7550 0.4806     0.000039
# discharge       7553         7574 0.4795     0.000039
# discharge       7577         7598 0.4939     0.000041
# discharge       7601         7622 0.4783     0.000038
# discharge       7625         7646 0.4808     0.000039
# discharge       7649         7670 0.4871     0.000040
# discharge       7673         7694 0.4865     0.000040
# discharge       7698         7718 0.4866     0.000040
# discharge       7721         7742 0.4844     0.000039
# discharge       7745         7766 0.4861     0.000040
# discharge       7770         7790 0.4847     0.000039
# discharge       7793         7814 0.4885     0.000040
# discharge       7818         7838 0.4843     0.000039
# discharge       7841         7862 0.4909     0.000040
# discharge       7866         7886 0.5080     0.000043
# discharge       7891         7911 0.5191     0.000045
# discharge       7916         7934 0.5060     0.000043
# discharge       7939         7958 0.5142     0.000044
# discharge       7963         7982 0.5007     0.000042
# discharge       7985         8006 0.5013     0.000042
# discharge       8010         8030 0.5195     0.000045
# discharge       8034         8054 0.5041     0.000042
# discharge       8058         8078 0.5089     0.000043
# discharge       8082         8102 0.5179     0.000044
# discharge       8106         8126 0.5167     0.000044
# discharge       8130         8150 0.5079     0.000043
# discharge       8154         8174 0.5081     0.000043
# discharge       8178         8198 0.5096     0.000043
# discharge       8202         8222 0.5092     0.000043
# discharge       8229         8246 0.5191     0.000045
# discharge       8250         8270 0.5078     0.000043
# discharge       8273         8294 0.5107     0.000043
# discharge       8299         8318 0.5177     0.000044
# discharge       8324         8342 0.5158     0.000044
# discharge       8346         8368 0.5500     0.000049
# discharge       8372         8390 0.5127     0.000044
# discharge       8394         8414 0.5134     0.000044
# discharge       8418         8438 0.5217     0.000045
# discharge       8442         8462 0.5115     0.000043
# discharge       8466         8486 0.5160     0.000044
# discharge       8490         8510 0.5173     0.000044
# discharge       8514         8534 0.5144     0.000044
# discharge       8539         8559 0.5425     0.000048
# discharge       8564         8582 0.5310     0.000046
# discharge       8586         8606 0.5163     0.000044
# discharge       8610         8630 0.5178     0.000044
# discharge       8634         8654 0.5182     0.000044
# discharge       8660         8679 0.5277     0.000046
# discharge       8682         8702 0.5186     0.000044
# discharge       8706         8726 0.5187     0.000044
# discharge       8730         8750 0.5153     0.000044
#
# Total Estimated Degradation: 0.012715
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.55) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 99375.65 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 352395.20 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 2893483.87 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 417994.50 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 336673.72 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 947024.04 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 800282.15 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 22850.29 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 514521.58 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 39286.38 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 466028.83 kWh
#
# Average Unmet Load (1979-2024): 153109.25 kWh
# Min Unmet Load: 0.00 kWh (Year 1981)
# Max Unmet Load: 2893483.87 kWh (Year 2010)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_55_percent_inference_Nevada"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 55% reduction (Case 1) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_43_percent_inference_Nevada"
dispatch_load_factor = 0.43  # Apply 0.43 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.43)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Load Factor 0.43) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.43)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.43) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890599 nonzeros
# Model fingerprint: 0x186cea13
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.12s
# Presolved: 70077 rows, 35042 columns, 161748 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 152983 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   2.008805e+06   8.726124e+06     43s
#     1519    4.8356825e+14   0.000000e+00   5.700777e+16     45s
#     2855    4.5249127e+13   1.414735e-01   2.980382e+14     50s
#     3703    2.5647065e+13   2.965233e-01   4.950583e+11     56s
#     4225    2.0507985e+13   2.600268e-01   1.817589e+14     60s
#     4627    1.7789119e+13   8.829914e-02   3.820301e+13     66s
#     5135    1.3949378e+13   8.192758e+03   2.794557e+11     70s
#     5435    1.3247642e+13   1.271044e-02   1.545828e+08     75s
#     5848    1.1633480e+13   2.572031e-03   1.751357e+11     81s
#     6269    8.8485397e+12   1.092173e-04   7.210316e+13     85s
#     6673    6.9550082e+12   2.007801e-04   7.289217e+14     90s
#     7610    3.6129706e+12   0.000000e+00   1.258813e+13     95s
#     8802    2.2007963e+12   0.000000e+00   7.442603e+10    101s
#     9662    1.3358777e+12   0.000000e+00   8.080677e+06    105s
#    10752    8.2585779e+11   0.000000e+00   3.145942e+07    110s
# Concurrent spin time: 5.69s
#
# Solved with dual simplex
#
# Root relaxation: objective 2.692902e+09, 47002 iterations, 78.21 seconds (57.97 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.6929e+09    0   21          - 2.6929e+09      -     -  120s
# H    0     0                    4.622943e+09 2.6929e+09  41.7%     -  126s
# H    0     0                    3.102824e+09 2.6929e+09  13.2%     -  135s
# H    0     0                    2.994402e+09 2.6929e+09  10.1%     -  144s
#      0     2 2.6929e+09    0   21 2.9944e+09 2.6929e+09  10.1%     -  144s
#      3     8 2.6929e+09    2   21 2.9944e+09 2.6929e+09  10.1%  40.0  150s
#     23    40 2.6929e+09    5   21 2.9944e+09 2.6929e+09  10.1%  37.6  157s
#     70    92 2.7166e+09    8   19 2.9944e+09 2.6929e+09  10.1%  39.4  160s
#    199   213 2.7148e+09   16   19 2.9944e+09 2.6929e+09  10.1%  41.5  165s
#    212   229 2.6929e+09   16   20 2.9944e+09 2.6929e+09  10.1%  41.0  184s
# H  215   229                    2.694052e+09 2.6929e+09  0.04%  40.8  184s
#
# Explored 228 nodes (56160 simplex iterations) in 185.36 seconds (186.60 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 2.69405e+09 2.9944e+09 3.10282e+09 4.62294e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.694051831039e+09, best bound 2.692901893783e+09, gap 0.0427%
# Optimal Solution Found!
# Solar Capacity: 7505751.01 kW
# Wind Capacity: 0.00 kW
# Battery Capacity: 4238109.92 kWh
# Total NPC: $2694051831.04
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3158276783.24 kWh
# Total Energy Generated: 4608013221.28 kWh
# Total Energy Used (along with efficiency losses): 1449736438.04 kWh
# Utilization Percentage: 31.46%
# $12318679.08 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 7505751.01 kW
# Solar Initial Cost:    $697659556.07
# Wind Initial Capacity: 0.00 kW
# Wind Initial Cost:     $0.00
# Battery Initial Capacity: 4238109.92 kWh
# Battery Initial Cost:  $1517243351.18
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -24018.40 kW
# Solar Redundant Cost:    $-2232510.58
# Wind Redundant Capacity: 0.00 kW
# Wind Redundant Cost:     $0.00
# Battery Redundant Capacity: 15681.01 kWh
# Battery Redundant Cost:  $5613800.40
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $695427045.49
# Solar OPEX:         $759590404.00
# Solar Replacement:  $0.00
# Solar Salvage:     -$202163020.12
# Wind CAPEX:         $0.00
# Wind OPEX:          $0.00
# Wind Replacement:   $0.00
# Wind Salvage:      -$0.00
# Battery CAPEX:      $1522857151.58
# Battery OPEX:       $458787257.78
# Battery Replacement:$156517779.33
# Battery Salvage:   -$553374726.67
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $2850569610.37
#
# === 2024 Solar Results 99% met (Load Factor 0.43) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.3807     0.000026
# discharge         17           38 0.4012     0.000028
# discharge         41           63 0.4184     0.000030
# discharge         69           86 0.4042     0.000028
# discharge         89          111 0.4162     0.000030
# discharge        115          134 0.4009     0.000028
# discharge        138          158 0.4170     0.000030
# discharge        161          182 0.3969     0.000028
# discharge        185          206 0.3956     0.000027
# discharge        209          230 0.4051     0.000029
# discharge        233          254 0.3938     0.000027
# discharge        257          278 0.3886     0.000027
# discharge        281          302 0.3926     0.000027
# discharge        306          326 0.3919     0.000027
# discharge        329          350 0.3932     0.000027
# discharge        354          374 0.3972     0.000028
# discharge        377          398 0.3887     0.000027
# discharge        402          422 0.4006     0.000028
# discharge        425          447 0.4118     0.000029
# discharge        453          471 0.4265     0.000031
# discharge        474          495 0.4287     0.000032
# discharge        501          518 0.4053     0.000029
# discharge        526          543 0.4119     0.000029
# discharge        547          566 0.3913     0.000027
# discharge        569          590 0.4030     0.000028
# discharge        594          614 0.3785     0.000025
# discharge        617          638 0.3786     0.000025
# discharge        641          662 0.3841     0.000026
# discharge        665          686 0.3810     0.000026
# discharge        689          710 0.3765     0.000025
# discharge        713          734 0.3775     0.000025
# discharge        737          759 0.4192     0.000030
# discharge        766          782 0.4098     0.000029
# discharge        788          806 0.3823     0.000026
# discharge        809          830 0.3793     0.000025
# discharge        834          854 0.3782     0.000025
# discharge        858          878 0.3783     0.000025
# discharge        883          902 0.3955     0.000027
# discharge        906          926 0.3756     0.000025
# discharge        929          950 0.3766     0.000025
# discharge        953          974 0.3991     0.000028
# discharge        977          998 0.3584     0.000023
# discharge       1000         1022 0.3582     0.000023
# discharge       1024         1046 0.3674     0.000024
# discharge       1049         1070 0.3649     0.000024
# discharge       1073         1094 0.3811     0.000026
# discharge       1097         1118 0.3633     0.000024
# discharge       1121         1141 0.3613     0.000023
# discharge       1145         1165 0.3565     0.000023
# discharge       1168         1189 0.3572     0.000023
# discharge       1193         1215 0.3947     0.000027
# discharge       1222         1238 0.3923     0.000027
# discharge       1241         1261 0.3634     0.000024
# discharge       1265         1286 0.3703     0.000024
# discharge       1290         1310 0.3700     0.000024
# discharge       1315         1333 0.3566     0.000023
# discharge       1337         1358 0.3743     0.000025
# discharge       1362         1381 0.3601     0.000023
# discharge       1384         1405 0.3572     0.000023
# discharge       1408         1429 0.3577     0.000023
# discharge       1432         1453 0.3577     0.000023
# discharge       1456         1477 0.3578     0.000023
# discharge       1480         1501 0.3586     0.000023
# discharge       1504         1525 0.3581     0.000023
# discharge       1528         1549 0.3580     0.000023
# discharge       1552         1573 0.3562     0.000023
# discharge       1576         1598 0.3777     0.000025
# discharge       1603         1621 0.3585     0.000023
# discharge       1624         1645 0.3560     0.000023
# discharge       1648         1669 0.3545     0.000023
# discharge       1673         1694 0.3754     0.000025
# discharge       1697         1717 0.3546     0.000023
# discharge       1721         1741 0.3548     0.000023
# discharge       1744         1765 0.3546     0.000023
# discharge       1768         1790 0.3630     0.000023
# discharge       1793         1814 0.3732     0.000025
# discharge       1817         1837 0.3534     0.000022
# discharge       1840         1861 0.3514     0.000022
# discharge       1864         1885 0.3602     0.000023
# discharge       1888         1909 0.3509     0.000022
# discharge       1912         1933 0.3500     0.000022
# discharge       1936         1957 0.3481     0.000022
# discharge       1961         1981 0.3479     0.000022
# discharge       1984         2006 0.3543     0.000022
# discharge       2009         2029 0.3577     0.000023
# discharge       2032         2053 0.3466     0.000022
# discharge       2057         2077 0.3448     0.000021
# discharge       2080         2101 0.3463     0.000022
# discharge       2104         2125 0.3490     0.000022
# discharge       2129         2149 0.3494     0.000022
# discharge       2153         2173 0.3508     0.000022
# discharge       2177         2197 0.3498     0.000022
# discharge       2200         2221 0.3430     0.000021
# discharge       2224         2245 0.3383     0.000021
# discharge       2248         2269 0.3372     0.000021
# discharge       2272         2293 0.3361     0.000020
# discharge       2296         2317 0.3417     0.000021
# discharge       2320         2341 0.3322     0.000020
# discharge       2344         2365 0.3344     0.000020
# discharge       2368         2389 0.3321     0.000020
# discharge       2392         2413 0.3320     0.000020
# discharge       2416         2437 0.3268     0.000019
# discharge       2440         2461 0.3303     0.000020
# discharge       2464         2485 0.3282     0.000020
# discharge       2488         2509 0.3301     0.000020
# discharge       2512         2533 0.3293     0.000020
# discharge       2536         2557 0.3291     0.000020
# discharge       2560         2581 0.3293     0.000020
# discharge       2584         2605 0.3265     0.000019
# discharge       2608         2629 0.3278     0.000020
# discharge       2632         2653 0.3233     0.000019
# discharge       2656         2677 0.3220     0.000019
# discharge       2680         2701 0.3227     0.000019
# discharge       2704         2725 0.3208     0.000019
# discharge       2728         2749 0.3208     0.000019
# discharge       2752         2773 0.3202     0.000019
# discharge       2776         2797 0.3173     0.000018
# discharge       2800         2821 0.3186     0.000019
# discharge       2824         2845 0.3177     0.000018
# discharge       2848         2869 0.3176     0.000018
# discharge       2872         2893 0.3148     0.000018
# discharge       2896         2917 0.3174     0.000018
# discharge       2920         2941 0.3167     0.000018
# discharge       2944         2965 0.3155     0.000018
# discharge       2968         2989 0.3148     0.000018
# discharge       2992         3013 0.3298     0.000020
# discharge       3016         3037 0.3149     0.000018
# discharge       3040         3061 0.3158     0.000018
# discharge       3064         3085 0.3144     0.000018
# discharge       3088         3109 0.3100     0.000018
# discharge       3112         3133 0.3116     0.000018
# discharge       3136         3157 0.3095     0.000018
# discharge       3160         3181 0.3114     0.000018
# discharge       3184         3205 0.3103     0.000018
# discharge       3208         3229 0.3085     0.000018
# discharge       3232         3253 0.3253     0.000019
# discharge       3256         3277 0.3087     0.000018
# discharge       3280         3301 0.3089     0.000018
# discharge       3304         3324 0.3061     0.000017
# discharge       3328         3348 0.3056     0.000017
# discharge       3352         3373 0.3064     0.000017
# discharge       3376         3397 0.3080     0.000017
# discharge       3400         3421 0.3062     0.000017
# discharge       3424         3444 0.3062     0.000017
# discharge       3448         3469 0.3066     0.000017
# discharge       3472         3492 0.3071     0.000017
# discharge       3496         3517 0.3066     0.000017
# discharge       3520         3541 0.3070     0.000017
# discharge       3544         3565 0.3068     0.000017
# discharge       3568         3589 0.3094     0.000018
# discharge       3592         3612 0.3073     0.000017
# discharge       3616         3636 0.3054     0.000017
# discharge       3640         3661 0.3049     0.000017
# discharge       3664         3684 0.3062     0.000017
# discharge       3688         3708 0.3060     0.000017
# discharge       3712         3733 0.3054     0.000017
# discharge       3736         3756 0.3054     0.000017
# discharge       3760         3780 0.3046     0.000017
# discharge       3784         3804 0.3048     0.000017
# discharge       3808         3828 0.3054     0.000017
# discharge       3832         3852 0.3061     0.000017
# discharge       3856         3877 0.3049     0.000017
# discharge       3880         3901 0.3050     0.000017
# discharge       3904         3925 0.3060     0.000017
# discharge       3928         3948 0.3039     0.000017
# discharge       3952         3972 0.3030     0.000017
# discharge       3976         3997 0.3073     0.000017
# discharge       4000         4021 0.3031     0.000017
# discharge       4024         4044 0.3043     0.000017
# discharge       4048         4068 0.3032     0.000017
# discharge       4072         4092 0.3034     0.000017
# discharge       4096         4116 0.2994     0.000017
# discharge       4120         4140 0.2990     0.000017
# discharge       4144         4164 0.2991     0.000017
# discharge       4168         4188 0.3003     0.000017
# discharge       4192         4212 0.3023     0.000017
# discharge       4216         4236 0.2997     0.000017
# discharge       4240         4260 0.2992     0.000017
# discharge       4264         4284 0.2982     0.000017
# discharge       4288         4309 0.3032     0.000017
# discharge       4312         4333 0.3052     0.000017
# discharge       4336         4357 0.3056     0.000017
# discharge       4360         4381 0.3024     0.000017
# discharge       4384         4404 0.3027     0.000017
# discharge       4408         4429 0.3036     0.000017
# discharge       4432         4453 0.3040     0.000017
# discharge       4456         4477 0.3042     0.000017
# discharge       4480         4501 0.3032     0.000017
# discharge       4504         4525 0.3070     0.000017
# discharge       4528         4549 0.3046     0.000017
# discharge       4552         4572 0.3054     0.000017
# discharge       4576         4597 0.3058     0.000017
# discharge       4600         4620 0.3049     0.000017
# discharge       4624         4645 0.3079     0.000017
# discharge       4649         4668 0.3049     0.000017
# discharge       4672         4692 0.3056     0.000017
# discharge       4696         4716 0.3069     0.000017
# discharge       4720         4740 0.3072     0.000017
# discharge       4744         4764 0.3070     0.000017
# discharge       4768         4788 0.3064     0.000017
# discharge       4792         4812 0.3067     0.000017
# discharge       4816         4836 0.3067     0.000017
# discharge       4840         4860 0.3061     0.000017
# discharge       4864         4884 0.3064     0.000017
# discharge       4888         4908 0.3052     0.000017
# discharge       4912         4932 0.3059     0.000017
# discharge       4936         4957 0.3080     0.000017
# discharge       4960         4981 0.3083     0.000018
# discharge       4984         5005 0.3100     0.000018
# discharge       5008         5029 0.3120     0.000018
# discharge       5032         5053 0.3148     0.000018
# discharge       5056         5077 0.3136     0.000018
# discharge       5080         5101 0.3115     0.000018
# discharge       5104         5125 0.3122     0.000018
# discharge       5128         5149 0.3234     0.000019
# discharge       5153         5173 0.3106     0.000018
# discharge       5176         5197 0.3136     0.000018
# discharge       5200         5221 0.3128     0.000018
# discharge       5224         5245 0.3185     0.000019
# discharge       5248         5269 0.3161     0.000018
# discharge       5272         5293 0.3135     0.000018
# discharge       5296         5317 0.3284     0.000020
# discharge       5320         5341 0.3232     0.000019
# discharge       5345         5365 0.3152     0.000018
# discharge       5368         5389 0.3170     0.000018
# discharge       5392         5413 0.3185     0.000019
# discharge       5416         5437 0.3206     0.000019
# discharge       5440         5461 0.3193     0.000019
# discharge       5464         5485 0.3211     0.000019
# discharge       5488         5509 0.3244     0.000019
# discharge       5512         5533 0.3266     0.000019
# discharge       5536         5557 0.3250     0.000019
# discharge       5560         5581 0.3271     0.000019
# discharge       5584         5605 0.3273     0.000020
# discharge       5608         5629 0.3282     0.000020
# discharge       5632         5653 0.3292     0.000020
# discharge       5656         5677 0.3286     0.000020
# discharge       5680         5701 0.3271     0.000019
# discharge       5704         5725 0.3286     0.000020
# discharge       5728         5749 0.3277     0.000020
# discharge       5752         5773 0.3285     0.000020
# discharge       5776         5797 0.3301     0.000020
# discharge       5800         5821 0.3274     0.000020
# discharge       5824         5845 0.3293     0.000020
# discharge       5849         5869 0.3319     0.000020
# discharge       5872         5893 0.3345     0.000020
# discharge       5896         5917 0.3336     0.000020
# discharge       5921         5941 0.3355     0.000020
# discharge       5944         5965 0.3365     0.000020
# discharge       5968         5989 0.3379     0.000021
# discharge       5992         6013 0.3424     0.000021
# discharge       6016         6037 0.3440     0.000021
# discharge       6040         6061 0.3459     0.000022
# discharge       6064         6085 0.3453     0.000021
# discharge       6088         6109 0.3483     0.000022
# discharge       6112         6133 0.3426     0.000021
# discharge       6136         6157 0.3441     0.000021
# discharge       6160         6181 0.3456     0.000021
# discharge       6184         6205 0.3452     0.000021
# discharge       6208         6229 0.3477     0.000022
# discharge       6232         6253 0.3485     0.000022
# discharge       6256         6277 0.3481     0.000022
# discharge       6280         6301 0.3495     0.000022
# discharge       6304         6325 0.3498     0.000022
# discharge       6328         6349 0.3488     0.000022
# discharge       6352         6373 0.3507     0.000022
# discharge       6376         6397 0.3498     0.000022
# discharge       6400         6421 0.3508     0.000022
# discharge       6424         6445 0.3528     0.000022
# discharge       6448         6469 0.3518     0.000022
# discharge       6472         6493 0.3525     0.000022
# discharge       6496         6517 0.3514     0.000022
# discharge       6520         6541 0.3546     0.000023
# discharge       6545         6565 0.3524     0.000022
# discharge       6568         6589 0.3534     0.000022
# discharge       6592         6613 0.3555     0.000023
# discharge       6616         6637 0.3560     0.000023
# discharge       6640         6661 0.3548     0.000023
# discharge       6665         6685 0.3557     0.000023
# discharge       6689         6709 0.3551     0.000023
# discharge       6712         6733 0.3548     0.000023
# discharge       6737         6757 0.3562     0.000023
# discharge       6761         6781 0.3566     0.000023
# discharge       6784         6805 0.3567     0.000023
# discharge       6809         6829 0.3573     0.000023
# discharge       6833         6853 0.3564     0.000023
# discharge       6856         6877 0.3567     0.000023
# discharge       6880         6901 0.3567     0.000023
# discharge       6905         6925 0.3552     0.000023
# discharge       6929         6949 0.3524     0.000022
# discharge       6953         6973 0.3563     0.000023
# discharge       6977         6998 0.3679     0.000024
# discharge       7001         7021 0.3555     0.000023
# discharge       7025         7045 0.3556     0.000023
# discharge       7049         7070 0.3588     0.000023
# discharge       7073         7093 0.3565     0.000023
# discharge       7097         7117 0.3543     0.000022
# discharge       7121         7141 0.3548     0.000023
# discharge       7145         7165 0.3619     0.000023
# discharge       7169         7190 0.3580     0.000023
# discharge       7193         7214 0.3797     0.000025
# discharge       7219         7238 0.3642     0.000024
# discharge       7241         7262 0.3616     0.000023
# discharge       7265         7285 0.3546     0.000023
# discharge       7289         7310 0.3556     0.000023
# discharge       7313         7334 0.3594     0.000023
# discharge       7337         7359 0.3869     0.000026
# discharge       7363         7382 0.3808     0.000026
# discharge       7386         7406 0.3619     0.000023
# discharge       7409         7430 0.3781     0.000025
# discharge       7433         7454 0.3654     0.000024
# discharge       7457         7478 0.3666     0.000024
# discharge       7481         7502 0.3709     0.000024
# discharge       7505         7526 0.3677     0.000024
# discharge       7529         7550 0.3744     0.000025
# discharge       7553         7574 0.3731     0.000025
# discharge       7577         7598 0.3801     0.000025
# discharge       7601         7622 0.3722     0.000025
# discharge       7625         7646 0.3746     0.000025
# discharge       7649         7670 0.3760     0.000025
# discharge       7673         7694 0.3776     0.000025
# discharge       7697         7718 0.3756     0.000025
# discharge       7721         7742 0.3782     0.000025
# discharge       7745         7766 0.3788     0.000025
# discharge       7769         7790 0.3785     0.000025
# discharge       7793         7814 0.3819     0.000026
# discharge       7817         7838 0.3782     0.000025
# discharge       7841         7862 0.3813     0.000026
# discharge       7865         7886 0.3941     0.000027
# discharge       7890         7910 0.4010     0.000028
# discharge       7916         7934 0.3925     0.000027
# discharge       7938         7958 0.4007     0.000028
# discharge       7962         7982 0.3871     0.000026
# discharge       7985         8006 0.3876     0.000026
# discharge       8010         8030 0.4057     0.000029
# discharge       8033         8054 0.3902     0.000027
# discharge       8057         8078 0.3953     0.000027
# discharge       8081         8102 0.4045     0.000028
# discharge       8106         8126 0.4031     0.000028
# discharge       8129         8150 0.3940     0.000027
# discharge       8153         8174 0.3942     0.000027
# discharge       8177         8198 0.3958     0.000027
# discharge       8201         8222 0.3959     0.000027
# discharge       8228         8246 0.4054     0.000029
# discharge       8249         8270 0.3940     0.000027
# discharge       8273         8294 0.3971     0.000028
# discharge       8298         8318 0.4043     0.000028
# discharge       8322         8342 0.4019     0.000028
# discharge       8345         8368 0.4213     0.000031
# discharge       8371         8390 0.3991     0.000028
# discharge       8393         8414 0.3997     0.000028
# discharge       8417         8438 0.4079     0.000029
# discharge       8441         8462 0.3982     0.000028
# discharge       8465         8486 0.4021     0.000028
# discharge       8490         8510 0.4035     0.000028
# discharge       8513         8534 0.4005     0.000028
# discharge       8538         8559 0.4207     0.000031
# discharge       8563         8582 0.4095     0.000029
# discharge       8585         8606 0.4023     0.000028
# discharge       8610         8630 0.4035     0.000028
# discharge       8633         8654 0.4043     0.000028
# discharge       8660         8678 0.4083     0.000029
# discharge       8682         8702 0.4041     0.000028
# discharge       8706         8726 0.4047     0.000029
# discharge       8729         8750 0.4011     0.000028
#
# Total Estimated Degradation: 0.008024
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.43) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 705651.83 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 15681.15 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 705651.83 kWh (Year 2010)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_43_percent_inference_Nevada"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 43% reduction (Case 1) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Local folders for each scenario ===
case_configs = {
    "100% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_71_percent_inference_Nevada",
    "100% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_55_percent_inference_Nevada",
    "99% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_71_percent_inference_Nevada",
    "99% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_55_percent_inference_Nevada",
    "99% / 43% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_43_percent_inference_Nevada",
}

years = list(range(1980, 2025))
case_names = list(case_configs.keys())
heatmap_matrix = []

# === Read unmet load totals from each folder/year ===
for label, folder in case_configs.items():
    yearly_unmet = []
    for year in years:
        file_path = os.path.join(folder, f"hourly_dispatch_{year}.csv")
        if os.path.exists(file_path):
            try:
                df = pd.read_csv(file_path)
                total_unmet = df["Unmet (kW)"].sum()
                yearly_unmet.append(total_unmet)
            except Exception as e:
                print(f"Failed to read {file_path}: {e}")
                yearly_unmet.append(np.nan)
        else:
            print(f"Missing: {file_path}")
            yearly_unmet.append(np.nan)
    heatmap_matrix.append(yearly_unmet)

# === Convert to NumPy array ===
heatmap_matrix = np.array(heatmap_matrix)

# === Plot using binary colormap ===
fig, ax = plt.subplots(figsize=(16, 5))
im = ax.imshow(heatmap_matrix, aspect='auto', cmap='binary', interpolation='nearest')
cbar = plt.colorbar(im, ax=ax, label='Unmet Load (kWh)')
ax.set_title('Unmet Load (kWh) by Year and Inference Reduction Nevada (1980–2024)')
ax.set_xlabel('Year')
ax.set_ylabel('Met Load / Inference Reduction')

# Ticks
ax.set_xticks(np.arange(0, len(years), 5))
ax.set_xticklabels(years[::5], rotation=45)
ax.set_yticks(np.arange(len(case_names)))
ax.set_yticklabels(case_names)

# === Annotate each square with value (4 decimals) and contrast-aware text ===
norm = plt.Normalize(vmin=np.nanmin(heatmap_matrix), vmax=np.nanmax(heatmap_matrix))
cmap = plt.cm.get_cmap('binary')

for i in range(heatmap_matrix.shape[0]):
    for j in range(heatmap_matrix.shape[1]):
        val = heatmap_matrix[i, j]
        if not np.isnan(val):
            rgb = cmap(norm(val))[:3]
            brightness = np.dot(rgb, [0.299, 0.587, 0.114])  # perceived brightness
            text_color = 'black' if brightness > 0.5 else 'white'
            ax.text(j, i, f"{val:.4f}", ha='center', va='center',
                    fontsize=6.5, rotation=90, color=text_color)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_27432\3165736368.py:56: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('binary')

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Local folders for each scenario ===
case_configs = {
    "100% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_71_percent_inference_Nevada",
    "100% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_55_percent_inference_Nevada",
    "99% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_71_percent_inference_Nevada",
    "99% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_55_percent_inference_Nevada",
    "99% / 43% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_43_percent_inference_Nevada",
}

years = list(range(1980, 2025))
case_names = list(case_configs.keys())
heatmap_matrix = []

# === Read unmet load totals from each folder/year ===
for label, folder in case_configs.items():
    yearly_unmet = []
    for year in years:
        file_path = os.path.join(folder, f"hourly_dispatch_{year}.csv")
        if os.path.exists(file_path):
            try:
                df = pd.read_csv(file_path)
                total_unmet = df["Unmet (kW)"].sum()
                yearly_unmet.append(total_unmet)
            except Exception as e:
                print(f"Failed to read {file_path}: {e}")
                yearly_unmet.append(np.nan)
        else:
            print(f"Missing: {file_path}")
            yearly_unmet.append(np.nan)
    heatmap_matrix.append(yearly_unmet)

# === Convert to NumPy array ===
heatmap_matrix = np.array(heatmap_matrix)

# === Plot using binary colormap ===
fig, ax = plt.subplots(figsize=(7, 6))
im = ax.imshow(heatmap_matrix, aspect='auto', cmap='binary', interpolation='nearest')
cbar = plt.colorbar(im, ax=ax, label='Unmet Load (kWh)')
ax.set_title('Unmet Load (kWh) by Year and Inference Reduction Nevada')
ax.set_xlabel('Year')
ax.set_ylabel('Met Load / Inference Reduction')

# Ticks
ax.set_xticks(np.arange(0, len(years), 5))
ax.set_xticklabels(years[::5], rotation=45)
ax.set_yticks(np.arange(len(case_names)))
ax.set_yticklabels(case_names)

# === Annotate each square with value (4 decimals) and contrast-aware text ===
norm = plt.Normalize(vmin=np.nanmin(heatmap_matrix), vmax=np.nanmax(heatmap_matrix))
cmap = plt.cm.get_cmap('binary')

for i in range(heatmap_matrix.shape[0]):
    for j in range(heatmap_matrix.shape[1]):
        val = heatmap_matrix[i, j]
        if not np.isnan(val):
            rgb = cmap(norm(val))[:3]
            brightness = np.dot(rgb, [0.299, 0.587, 0.114])  # perceived brightness
            text_color = 'black' if brightness > 0.5 else 'white'
            ax.text(j, i, f"{val:.4f}", ha='center', va='center',
                    fontsize=6.5, rotation=90, color=text_color)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_27432\1739274328.py:56: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('binary')
