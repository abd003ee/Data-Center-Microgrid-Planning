# %% [markdown]
# # 99 met Capacity Sizing Inference Resilience

# %% [markdown]
# ## 43% of Training Load consumption (Moderate Traffic)

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_43_percent_inference"
dispatch_load_factor = 0.43  # Apply 0.43 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.43)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Dispatch Load Factor 0.43) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.43)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.43) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0x1f48e2d4
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.79s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.227876e+05   3.669944e+06     43s
#     2215    2.2534081e+12   0.000000e+00   2.415393e+09     45s
#     3988    4.9373191e+11   0.000000e+00   2.971831e+13     50s
#     5759    1.6596627e+11   4.271117e-03   2.009910e+13     55s
#     7096    7.5026701e+10   5.278366e-03   4.918827e+13     60s
#     8767    3.8088429e+10   1.342471e-04   1.632913e+11     65s
#    10348    2.8121837e+10   0.000000e+00   4.206445e+07     70s
#    11693    2.2058370e+10   5.036300e-04   2.451564e+11     75s
#    12741    1.7959299e+10   5.517983e-03   2.658828e+11     80s
#    13968    1.4939988e+10   4.436894e-03   3.241235e+11     85s
#    18405   -1.4899207e+10   2.497471e+11   0.000000e+00     90s
#    22779   -1.4487798e+10   2.389563e+11   0.000000e+00     95s
#    24859    4.4440493e+08   7.734861e+11   0.000000e+00    100s
#    26497    7.3621362e+08   2.791783e+09   0.000000e+00    105s
#    28681    8.0740522e+08   2.035515e+09   0.000000e+00    110s
# Concurrent spin time: 19.13s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 3.380229e+09, 45480 iterations, 88.65 seconds (59.54 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.3802e+09    0    4          - 3.3802e+09      -     -  130s
# H    0     0                    3.422278e+09 3.3802e+09  1.23%     -  134s
# H    0     0                    3.411333e+09 3.3802e+09  0.91%     -  148s
#
# Explored 1 nodes (45480 simplex iterations) in 149.22 seconds (137.70 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 3.41133e+09 3.42228e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.411332883332e+09, best bound 3.380228704637e+09, gap 0.9118%
# Optimal Solution Found!
# Solar Capacity: 7946302.29 kW
# Wind Capacity: 134.09 kW
# Battery Capacity: 3862412.64 kWh
# Total NPC: $3411332883.33
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3346668354.75 kWh
# Total Energy Generated: 4711239663.15 kWh
# Total Energy Used (along with efficiency losses): 1364571308.40 kWh
# Utilization Percentage: 28.96%
# $3505235.54 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 7946302.29 kW
# Solar Initial Cost:    $738608797.68
# Wind Initial Capacity: 134.09 kW
# Wind Initial Cost:     $685687101.79
# Battery Initial Capacity: 3862412.64 kWh
# Battery Initial Cost:  $1382743726.26
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -25428.17 kW
# Solar Redundant Cost:    $-2363548.15
# Wind Redundant Capacity: 11.84 kW
# Wind Redundant Cost:     $60532457.35
# Battery Redundant Capacity: 14290.93 kWh
# Battery Redundant Cost:  $5116151.79
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $736245249.53
# Solar OPEX:         $804174686.85
# Solar Replacement:  $0.00
# Solar Salvage:     -$214029011.61
# Wind CAPEX:         $746219559.13
# Wind OPEX:          $159717702.39
# Wind Replacement:   $0.00
# Wind Salvage:      -$135580360.95
# Battery CAPEX:      $1387859878.04
# Battery OPEX:       $418116976.35
# Battery Replacement:$44536567.58
# Battery Salvage:   -$504319515.38
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3455869450.91
#
# === 2024 Solar Results 99% met (Dispatch Load Factor 0.43) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0            1 0.0084     0.000000
# discharge          2           12 0.0874     0.000002
# discharge         14           36 0.3191     0.000019
# discharge         39           62 0.4764     0.000038
# discharge         69           79 0.2346     0.000011
# discharge         81           84 0.0236     0.000000
# discharge         87          109 0.1105     0.000003
# discharge        112          119 0.0043     0.000000
# discharge        120          133 0.2097     0.000009
# discharge        136          143 0.0118     0.000000
# discharge        146          147 0.0010     0.000000
# discharge        148          157 0.0960     0.000002
# discharge        160          175 0.1667     0.000006
# discharge        182          201 0.0610     0.000001
# discharge        205          228 0.0255     0.000000
# discharge        229          253 0.0579     0.000001
# discharge        255          300 0.0384     0.000000
# discharge        301          315 0.0815     0.000002
# discharge        325          348 0.1207     0.000003
# discharge        351          372 0.0910     0.000002
# discharge        374          396 0.3085     0.000018
# discharge        399          421 0.0009     0.000000
# discharge        422          441 0.2954     0.000016
# discharge        446          468 0.0702     0.000001
# discharge        469          492 0.2738     0.000014
# discharge        494          513 0.0803     0.000002
# discharge        517          541 0.0326     0.000000
# discharge        544          566 0.0437     0.000001
# discharge        568          589 0.4208     0.000031
# discharge        598          602 0.0602     0.000001
# discharge        604          613 0.1591     0.000005
# discharge        616          627 0.0307     0.000000
# discharge        628          630 0.0033     0.000000
# discharge        635          658 0.0235     0.000000
# discharge        661          684 0.3851     0.000026
# discharge        688          700 0.1414     0.000004
# discharge        706          708 0.0064     0.000000
# discharge        711          732 0.0368     0.000000
# discharge        733          756 0.4043     0.000028
# discharge        759          769 0.0150     0.000000
# discharge        774          780 0.0356     0.000000
# discharge        781          804 0.2423     0.000011
# discharge        807          816 0.0408     0.000000
# discharge        820          844 0.0367     0.000000
# discharge        852          876 0.0014     0.000000
# discharge        877          900 0.1078     0.000003
# discharge        902          911 0.0032     0.000000
# discharge        913          972 0.0035     0.000000
# discharge        974          996 0.1768     0.000006
# discharge        998         1021 0.0243     0.000000
# discharge       1022         1044 0.1372     0.000004
# discharge       1046         1068 0.1871     0.000007
# discharge       1070         1082 0.0316     0.000000
# discharge       1087         1116 0.2839     0.000015
# discharge       1121         1164 0.3465     0.000022
# discharge       1166         1188 0.2549     0.000012
# discharge       1190         1212 0.1676     0.000006
# discharge       1214         1228 0.1153     0.000003
# discharge       1237         1284 0.0661     0.000001
# discharge       1285         1323 0.0912     0.000002
# discharge       1333         1428 0.1716     0.000006
# discharge       1430         1452 0.2374     0.000011
# discharge       1454         1476 0.4290     0.000032
# discharge       1480         1490 0.0404     0.000000
# discharge       1498         1499 0.0006     0.000000
# discharge       1500         1548 0.1241     0.000003
# discharge       1551         1567 0.1913     0.000007
# discharge       1570         1571 0.0036     0.000000
# discharge       1574         1596 0.2375     0.000011
# discharge       1599         1614 0.1028     0.000002
# discharge       1623         1638 0.1943     0.000008
# discharge       1647         1660 0.0489     0.000001
# discharge       1662         1667 0.0339     0.000000
# discharge       1669         1691 0.2923     0.000016
# discharge       1694         1715 0.1301     0.000004
# discharge       1717         1777 0.0208     0.000000
# discharge       1780         1811 0.2573     0.000013
# discharge       1814         1827 0.1105     0.000003
# discharge       1829         1835 0.1086     0.000003
# discharge       1838         1849 0.0201     0.000000
# discharge       1852         1859 0.0126     0.000000
# discharge       1860         1883 0.2712     0.000014
# discharge       1886         1931 0.1912     0.000007
# discharge       1934         1956 0.2218     0.000010
# discharge       1961         1972 0.0696     0.000001
# discharge       1976         2003 0.0073     0.000000
# discharge       2005         2042 0.0613     0.000001
# discharge       2045         2048 0.0730     0.000001
# discharge       2054         2065 0.0050     0.000000
# discharge       2067         2075 0.0360     0.000000
# discharge       2077         2099 0.1757     0.000006
# discharge       2102         2119 0.1886     0.000007
# discharge       2125         2242 0.0110     0.000000
# discharge       2244         2291 0.0429     0.000001
# discharge       2293         2305 0.0155     0.000000
# discharge       2309         2315 0.0290     0.000000
# discharge       2317         2328 0.0001     0.000000
# discharge       2329         2363 0.1770     0.000006
# discharge       2366         2388 0.0065     0.000000
# discharge       2389         2407 0.1326     0.000004
# discharge       2415         2429 0.0499     0.000001
# discharge       2430         2431 0.0018     0.000000
# discharge       2436         2483 0.1692     0.000006
# discharge       2485         2529 0.0030     0.000000
# discharge       2532         2547 0.0563     0.000001
# discharge       2551         2553 0.0020     0.000000
# discharge       2556         2603 0.0906     0.000002
# discharge       2605         2625 0.0121     0.000000
# discharge       2627         2645 0.0177     0.000000
# discharge       2649         2670 0.0626     0.000001
# discharge       2676         2699 0.2452     0.000012
# discharge       2702         2714 0.0252     0.000000
# discharge       2720         2747 0.0687     0.000001
# discharge       2749         2761 0.0120     0.000000
# discharge       2763         2771 0.0089     0.000000
# discharge       2772         2794 0.0653     0.000001
# discharge       2797         2891 0.3516     0.000022
# discharge       2894         2909 0.0974     0.000002
# discharge       2912         2915 0.0553     0.000001
# discharge       2917         2938 0.1067     0.000003
# discharge       2941         2963 0.3127     0.000018
# discharge       2966         2987 0.3643     0.000024
# discharge       2991         3011 0.3550     0.000023
# discharge       3016         3035 0.1898     0.000007
# discharge       3038         3053 0.0013     0.000000
# discharge       3054         3107 0.0121     0.000000
# discharge       3108         3121 0.0034     0.000000
# discharge       3124         3131 0.0338     0.000000
# discharge       3132         3155 0.3059     0.000017
# discharge       3158         3179 0.2356     0.000011
# discharge       3182         3195 0.0530     0.000001
# discharge       3196         3204 0.1577     0.000005
# discharge       3208         3227 0.0524     0.000001
# discharge       3229         3251 0.0857     0.000002
# discharge       3253         3275 0.2804     0.000015
# discharge       3278         3299 0.2538     0.000012
# discharge       3303         3323 0.2329     0.000011
# discharge       3327         3347 0.3392     0.000021
# discharge       3350         3370 0.2046     0.000008
# discharge       3374         3394 0.0880     0.000002
# discharge       3397         3413 0.0097     0.000000
# discharge       3417         3432 0.0099     0.000000
# discharge       3434         3443 0.1580     0.000005
# discharge       3446         3466 0.1302     0.000004
# discharge       3471         3491 0.1202     0.000003
# discharge       3493         3508 0.0449     0.000001
# discharge       3516         3538 0.0089     0.000000
# discharge       3540         3563 0.2059     0.000009
# discharge       3566         3587 0.2939     0.000016
# discharge       3590         3604 0.0235     0.000000
# discharge       3605         3610 0.0269     0.000000
# discharge       3612         3634 0.0451     0.000001
# discharge       3637         3659 0.0660     0.000001
# discharge       3661         3683 0.3117     0.000018
# discharge       3686         3707 0.2420     0.000011
# discharge       3710         3724 0.0278     0.000000
# discharge       3725         3731 0.0522     0.000001
# discharge       3733         3754 0.0844     0.000002
# discharge       3757         3778 0.2932     0.000016
# discharge       3782         3802 0.0588     0.000001
# discharge       3805         3826 0.2378     0.000011
# discharge       3830         3848 0.0006     0.000000
# discharge       3849         3874 0.1091     0.000003
# discharge       3877         3889 0.0014     0.000000
# discharge       3891         3898 0.0443     0.000001
# discharge       3900         3923 0.1295     0.000004
# discharge       3925         3947 0.2972     0.000016
# discharge       3950         3971 0.3114     0.000018
# discharge       3974         3995 0.3015     0.000017
# discharge       3998         4018 0.2242     0.000010
# discharge       4022         4043 0.0895     0.000002
# discharge       4045         4067 0.1819     0.000007
# discharge       4071         4090 0.1983     0.000008
# discharge       4094         4114 0.1230     0.000003
# discharge       4117         4139 0.2169     0.000009
# discharge       4142         4163 0.2904     0.000016
# discharge       4166         4181 0.1102     0.000003
# discharge       4185         4186 0.0042     0.000000
# discharge       4189         4211 0.3087     0.000018
# discharge       4214         4235 0.2987     0.000017
# discharge       4238         4258 0.2099     0.000009
# discharge       4262         4274 0.0214     0.000000
# discharge       4278         4282 0.0196     0.000000
# discharge       4284         4307 0.1753     0.000006
# discharge       4310         4331 0.1788     0.000007
# discharge       4334         4355 0.1480     0.000005
# discharge       4357         4378 0.0751     0.000001
# discharge       4380         4402 0.0850     0.000002
# discharge       4405         4426 0.2128     0.000009
# discharge       4430         4450 0.1208     0.000003
# discharge       4453         4474 0.1306     0.000004
# discharge       4478         4498 0.2075     0.000009
# discharge       4502         4523 0.2015     0.000008
# discharge       4526         4547 0.3219     0.000019
# discharge       4551         4561 0.0140     0.000000
# discharge       4564         4595 0.1140     0.000003
# discharge       4597         4619 0.3240     0.000019
# discharge       4622         4643 0.3123     0.000018
# discharge       4646         4667 0.2420     0.000011
# discharge       4670         4691 0.3215     0.000019
# discharge       4695         4715 0.1892     0.000007
# discharge       4718         4738 0.1842     0.000007
# discharge       4741         4763 0.1681     0.000006
# discharge       4767         4787 0.2246     0.000010
# discharge       4790         4810 0.0134     0.000000
# discharge       4812         4835 0.2024     0.000008
# discharge       4838         4859 0.2714     0.000014
# discharge       4862         4883 0.2323     0.000011
# discharge       4886         4908 0.3686     0.000024
# discharge       4916         4931 0.3205     0.000019
# discharge       4936         4955 0.3245     0.000019
# discharge       4960         4979 0.3665     0.000024
# discharge       4984         5004 0.3574     0.000023
# discharge       5009         5027 0.3482     0.000022
# discharge       5031         5046 0.0579     0.000001
# discharge       5047         5050 0.0077     0.000000
# discharge       5053         5075 0.0779     0.000001
# discharge       5077         5099 0.1419     0.000004
# discharge       5101         5123 0.0725     0.000001
# discharge       5125         5147 0.1271     0.000004
# discharge       5149         5171 0.2412     0.000011
# discharge       5174         5195 0.2573     0.000013
# discharge       5198         5219 0.1943     0.000008
# discharge       5222         5243 0.2779     0.000015
# discharge       5246         5267 0.1494     0.000005
# discharge       5269         5291 0.1456     0.000005
# discharge       5293         5315 0.0806     0.000002
# discharge       5317         5339 0.0557     0.000001
# discharge       5341         5363 0.2059     0.000009
# discharge       5366         5387 0.2755     0.000014
# discharge       5390         5411 0.3428     0.000021
# discharge       5414         5435 0.3044     0.000017
# discharge       5438         5459 0.2662     0.000013
# discharge       5462         5483 0.1126     0.000003
# discharge       5485         5508 0.2827     0.000015
# discharge       5511         5531 0.3344     0.000020
# discharge       5534         5555 0.1530     0.000005
# discharge       5557         5579 0.0845     0.000002
# discharge       5581         5603 0.0664     0.000001
# discharge       5605         5627 0.0494     0.000001
# discharge       5629         5641 0.0191     0.000000
# discharge       5642         5651 0.1088     0.000003
# discharge       5653         5675 0.1337     0.000004
# discharge       5677         5699 0.1550     0.000005
# discharge       5701         5723 0.2913     0.000016
# discharge       5726         5747 0.3509     0.000022
# discharge       5750         5771 0.3570     0.000023
# discharge       5774         5795 0.3213     0.000019
# discharge       5799         5819 0.3322     0.000020
# discharge       5823         5843 0.3773     0.000025
# discharge       5848         5868 0.3280     0.000020
# discharge       5873         5891 0.2268     0.000010
# discharge       5894         5915 0.0207     0.000000
# discharge       5916         5928 0.0027     0.000000
# discharge       5930         5939 0.1409     0.000004
# discharge       5943         5963 0.2300     0.000010
# discharge       5966         5987 0.3542     0.000022
# discharge       5991         6004 0.1439     0.000004
# discharge       6013         6035 0.0099     0.000000
# discharge       6036         6059 0.0143     0.000000
# discharge       6060         6073 0.0154     0.000000
# discharge       6077         6083 0.0303     0.000000
# discharge       6085         6107 0.2469     0.000012
# discharge       6110         6155 0.0023     0.000000
# discharge       6156         6180 0.3518     0.000022
# discharge       6184         6193 0.0135     0.000000
# discharge       6198         6203 0.0006     0.000000
# discharge       6204         6251 0.3263     0.000019
# discharge       6254         6275 0.2987     0.000017
# discharge       6278         6299 0.3626     0.000023
# discharge       6303         6323 0.3647     0.000024
# discharge       6327         6348 0.2699     0.000014
# discharge       6352         6372 0.2910     0.000016
# discharge       6375         6396 0.2755     0.000014
# discharge       6399         6420 0.2847     0.000015
# discharge       6424         6444 0.2580     0.000013
# discharge       6447         6467 0.1316     0.000004
# discharge       6469         6540 0.2312     0.000010
# discharge       6543         6564 0.3029     0.000017
# discharge       6567         6587 0.3658     0.000024
# discharge       6591         6611 0.0132     0.000000
# discharge       6612         6635 0.3089     0.000018
# discharge       6638         6659 0.2200     0.000010
# discharge       6662         6684 0.2198     0.000010
# discharge       6686         6708 0.3750     0.000025
# discharge       6711         6724 0.1218     0.000003
# discharge       6733         6755 0.0030     0.000000
# discharge       6756         6771 0.0107     0.000000
# discharge       6773         6779 0.0232     0.000000
# discharge       6781         6803 0.0395     0.000000
# discharge       6805         6828 0.3243     0.000019
# discharge       6831         6852 0.2826     0.000015
# discharge       6854         6889 0.0265     0.000000
# discharge       6893         6899 0.0105     0.000000
# discharge       6901         6924 0.3377     0.000021
# discharge       6927         6947 0.0261     0.000000
# discharge       6949         6972 0.2427     0.000011
# discharge       6974         6995 0.2158     0.000009
# discharge       6998         7020 0.2199     0.000010
# discharge       7022         7044 0.3328     0.000020
# discharge       7046         7068 0.3395     0.000021
# discharge       7071         7085 0.1450     0.000005
# discharge       7094         7115 0.0015     0.000000
# discharge       7117         7140 0.1188     0.000003
# discharge       7142         7156 0.0708     0.000001
# discharge       7162         7164 0.0025     0.000000
# discharge       7165         7188 0.1663     0.000006
# discharge       7191         7201 0.0384     0.000000
# discharge       7204         7212 0.0884     0.000002
# discharge       7214         7236 0.1326     0.000004
# discharge       7238         7332 0.2892     0.000016
# discharge       7335         7356 0.1865     0.000007
# discharge       7359         7374 0.0379     0.000000
# discharge       7379         7380 0.0017     0.000000
# discharge       7382         7391 0.0000     0.000000
# discharge       7392         7395 0.0055     0.000000
# discharge       7397         7452 0.2937     0.000016
# discharge       7456         7476 0.2459     0.000012
# discharge       7479         7487 0.0017     0.000000
# discharge       7489         7500 0.0868     0.000002
# discharge       7502         7524 0.0908     0.000002
# discharge       7527         7542 0.1100     0.000003
# discharge       7544         7549 0.0724     0.000001
# discharge       7553         7566 0.1579     0.000005
# discharge       7567         7572 0.0344     0.000000
# discharge       7574         7596 0.1325     0.000004
# discharge       7598         7614 0.0007     0.000000
# discharge       7615         7621 0.0414     0.000000
# discharge       7623         7635 0.0428     0.000001
# discharge       7643         7644 0.0012     0.000000
# discharge       7645         7668 0.3190     0.000019
# discharge       7671         7693 0.1803     0.000007
# discharge       7695         7706 0.0562     0.000001
# discharge       7712         7716 0.0294     0.000000
# discharge       7718         7727 0.0067     0.000000
# discharge       7729         7737 0.0000     0.000000
# discharge       7738         7764 0.1176     0.000003
# discharge       7766         7781 0.1724     0.000006
# discharge       7790         7836 0.0019     0.000000
# discharge       7837         7861 0.3827     0.000026
# discharge       7864         7877 0.1229     0.000003
# discharge       7879         7882 0.0050     0.000000
# discharge       7886         7932 0.0092     0.000000
# discharge       7933         7957 0.2234     0.000010
# discharge       7961         7971 0.0045     0.000000
# discharge       7972         7980 0.0081     0.000000
# discharge       7981         8004 0.1420     0.000004
# discharge       8006         8028 0.4150     0.000030
# discharge       8031         8042 0.0369     0.000000
# discharge       8046         8052 0.0865     0.000002
# discharge       8055         8076 0.3165     0.000018
# discharge       8079         8087 0.0079     0.000000
# discharge       8089         8100 0.0801     0.000002
# discharge       8102         8116 0.1362     0.000004
# discharge       8126         8144 0.0250     0.000000
# discharge       8149         8172 0.1486     0.000005
# discharge       8174         8196 0.3592     0.000023
# discharge       8199         8245 0.0450     0.000001
# discharge       8247         8269 0.3423     0.000021
# discharge       8272         8292 0.0635     0.000001
# discharge       8294         8316 0.2417     0.000011
# discharge       8318         8341 0.0701     0.000001
# discharge       8344         8351 0.0034     0.000000
# discharge       8352         8389 0.1197     0.000003
# discharge       8391         8431 0.0614     0.000001
# discharge       8432         8436 0.0243     0.000000
# discharge       8439         8453 0.1784     0.000007
# discharge       8458         8461 0.0211     0.000000
# discharge       8465         8484 0.0764     0.000001
# discharge       8486         8498 0.0788     0.000002
# discharge       8509         8532 0.0928     0.000002
# discharge       8534         8556 0.2780     0.000015
# discharge       8559         8571 0.0853     0.000002
# discharge       8581         8605 0.1166     0.000003
# discharge       8607         8617 0.0458     0.000001
# discharge       8618         8629 0.1219     0.000003
# discharge       8633         8653 0.1139     0.000003
# discharge       8656         8688 0.0094     0.000000
# discharge       8693         8700 0.0656     0.000001
# discharge       8702         8717 0.0315     0.000000
# discharge       8721         8749 0.1312     0.000004
#
# Total Estimated Degradation: 0.002519
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.43) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 0.00 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 0.00 kWh (Year 2024)

# %% [markdown]
# ## 55% of Training Load consumption (Intense Traffic)

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_55_percent_inference"
dispatch_load_factor = 0.55  # Apply 0.55 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 0)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} met Load 99% (Load Factor 0.55)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Dispatch Load Factor 0.55) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.55)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.55) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Optimal Solution Found!
# Solar Capacity: 7946302.29 kW
# Wind Capacity: 134.09 kW
# Battery Capacity: 3862412.64 kWh
# Total NPC: $3411332883.33
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3075614438.16 kWh
# Total Energy Generated: 4711239663.15 kWh
# Total Energy Used (along with efficiency losses): 1635625224.99 kWh
# Utilization Percentage: 34.72%
# $6987270.51 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 7946302.29 kW
# Solar Initial Cost:    $738608797.68
# Wind Initial Capacity: 134.09 kW
# Wind Initial Cost:     $685687101.79
# Battery Initial Capacity: 3862412.64 kWh
# Battery Initial Cost:  $1382743726.26
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -25428.17 kW
# Solar Redundant Cost:    $-2363548.15
# Wind Redundant Capacity: 11.84 kW
# Wind Redundant Cost:     $60532457.35
# Battery Redundant Capacity: 14290.93 kWh
# Battery Redundant Cost:  $5116151.79
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $736245249.53
# Solar OPEX:         $804174686.85
# Solar Replacement:  $0.00
# Solar Salvage:     -$214029011.61
# Wind CAPEX:         $746219559.13
# Wind OPEX:          $159717702.39
# Wind Replacement:   $0.00
# Wind Salvage:      -$135580360.95
# Battery CAPEX:      $1387859878.04
# Battery OPEX:       $418116976.35
# Battery Replacement:$88778355.01
# Battery Salvage:   -$504319515.38
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3500111238.34
#
# === 2024 Solar Results 99% met (Dispatch Load Factor 0.55) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0            1 0.0024     0.000000
# discharge          2           12 0.1600     0.000005
# discharge         14           36 0.4381     0.000033
# discharge         40           62 0.6208     0.000061
# discharge         70           84 0.3754     0.000025
# discharge         87          109 0.2384     0.000011
# discharge        116          120 0.0265     0.000000
# discharge        121          133 0.3116     0.000018
# discharge        137          157 0.2385     0.000011
# discharge        160          179 0.2576     0.000013
# discharge        183          201 0.0866     0.000002
# discharge        206          228 0.0622     0.000001
# discharge        230          253 0.0938     0.000002
# discharge        255          274 0.0061     0.000000
# discharge        276          300 0.0761     0.000001
# discharge        302          315 0.1236     0.000003
# discharge        322          324 0.0082     0.000000
# discharge        326          349 0.2521     0.000012
# discharge        353          372 0.2099     0.000009
# discharge        375          396 0.4273     0.000031
# discharge        399          407 0.0048     0.000000
# discharge        409          422 0.0169     0.000000
# discharge        424          441 0.4055     0.000029
# discharge        447          468 0.1892     0.000007
# discharge        470          492 0.3927     0.000027
# discharge        495          515 0.1864     0.000007
# discharge        518          542 0.0682     0.000001
# discharge        544          566 0.0691     0.000001
# discharge        569          590 0.5671     0.000052
# discharge        598          613 0.3350     0.000020
# discharge        617          632 0.0949     0.000002
# discharge        638          650 0.0007     0.000000
# discharge        651          660 0.0854     0.000002
# discharge        662          685 0.5100     0.000043
# discharge        688          708 0.2375     0.000011
# discharge        711          732 0.1086     0.000003
# discharge        734          756 0.5232     0.000045
# discharge        760          780 0.1649     0.000006
# discharge        782          804 0.3613     0.000023
# discharge        808          817 0.0682     0.000001
# discharge        830          847 0.1023     0.000002
# discharge        848          852 0.0106     0.000000
# discharge        854          876 0.0306     0.000000
# discharge        877          900 0.2273     0.000010
# discharge        903          913 0.0177     0.000000
# discharge        917          948 0.0063     0.000000
# discharge        949          959 0.0035     0.000000
# discharge        962          973 0.0380     0.000000
# discharge        975          996 0.3050     0.000017
# discharge        999         1008 0.0058     0.000000
# discharge       1011         1012 0.0019     0.000000
# discharge       1014         1021 0.0690     0.000001
# discharge       1023         1044 0.2358     0.000011
# discharge       1047         1068 0.3064     0.000017
# discharge       1070         1083 0.0673     0.000001
# discharge       1089         1091 0.0010     0.000000
# discharge       1093         1116 0.4032     0.000028
# discharge       1123         1164 0.4660     0.000037
# discharge       1167         1188 0.3745     0.000025
# discharge       1191         1212 0.2869     0.000015
# discharge       1214         1229 0.1715     0.000006
# discharge       1238         1275 0.0014     0.000000
# discharge       1276         1284 0.1268     0.000004
# discharge       1286         1297 0.0052     0.000000
# discharge       1299         1325 0.1423     0.000004
# discharge       1334         1428 0.2916     0.000016
# discharge       1431         1452 0.3573     0.000023
# discharge       1455         1476 0.5573     0.000051
# discharge       1481         1492 0.0798     0.000002
# discharge       1495         1499 0.0249     0.000000
# discharge       1501         1523 0.0161     0.000000
# discharge       1525         1548 0.2105     0.000009
# discharge       1553         1572 0.3028     0.000017
# discharge       1575         1596 0.3580     0.000023
# discharge       1600         1620 0.1894     0.000007
# discharge       1625         1638 0.2627     0.000013
# discharge       1642         1644 0.0051     0.000000
# discharge       1647         1667 0.1836     0.000007
# discharge       1670         1691 0.4040     0.000028
# discharge       1695         1715 0.2333     0.000011
# discharge       1718         1731 0.0099     0.000000
# discharge       1732         1734 0.0009     0.000000
# discharge       1740         1778 0.0476     0.000001
# discharge       1781         1782 0.0001     0.000000
# discharge       1786         1788 0.0082     0.000000
# discharge       1789         1811 0.3692     0.000024
# discharge       1815         1827 0.1537     0.000005
# discharge       1829         1835 0.1602     0.000005
# discharge       1839         1850 0.0393     0.000000
# discharge       1855         1859 0.0392     0.000000
# discharge       1861         1883 0.3749     0.000025
# discharge       1886         1907 0.0146     0.000000
# discharge       1909         1931 0.2994     0.000017
# discharge       1934         1956 0.3428     0.000021
# discharge       1963         1972 0.1299     0.000004
# discharge       1981         2004 0.0693     0.000001
# discharge       2006         2042 0.0889     0.000002
# discharge       2044         2051 0.1224     0.000003
# discharge       2054         2075 0.1251     0.000003
# discharge       2077         2099 0.2795     0.000015
# discharge       2102         2123 0.2797     0.000015
# discharge       2126         2136 0.0005     0.000000
# discharge       2137         2171 0.0282     0.000000
# discharge       2173         2190 0.0051     0.000000
# discharge       2194         2243 0.0587     0.000001
# discharge       2245         2259 0.0004     0.000000
# discharge       2260         2267 0.0033     0.000000
# discharge       2268         2291 0.0943     0.000002
# discharge       2293         2315 0.1288     0.000004
# discharge       2318         2328 0.0088     0.000000
# discharge       2331         2333 0.0027     0.000000
# discharge       2336         2363 0.2469     0.000012
# discharge       2366         2385 0.0078     0.000000
# discharge       2386         2388 0.0238     0.000000
# discharge       2389         2411 0.2238     0.000010
# discharge       2417         2433 0.1142     0.000003
# discharge       2437         2483 0.2736     0.000014
# discharge       2486         2531 0.0558     0.000001
# discharge       2533         2555 0.1430     0.000004
# discharge       2557         2603 0.1950     0.000008
# discharge       2606         2620 0.0081     0.000000
# discharge       2622         2625 0.0360     0.000000
# discharge       2628         2647 0.0768     0.000001
# discharge       2649         2651 0.0059     0.000000
# discharge       2653         2671 0.1388     0.000004
# discharge       2673         2675 0.0065     0.000000
# discharge       2677         2699 0.3502     0.000022
# discharge       2702         2723 0.0777     0.000001
# discharge       2725         2747 0.1131     0.000003
# discharge       2749         2762 0.0297     0.000000
# discharge       2766         2771 0.0481     0.000001
# discharge       2773         2795 0.1677     0.000006
# discharge       2798         2842 0.0030     0.000000
# discharge       2844         2867 0.0007     0.000000
# discharge       2868         2891 0.4649     0.000037
# discharge       2895         2915 0.2435     0.000011
# discharge       2918         2939 0.2099     0.000009
# discharge       2942         2963 0.4270     0.000031
# discharge       2967         2987 0.4743     0.000038
# discharge       2992         3011 0.4604     0.000036
# discharge       3017         3035 0.3039     0.000017
# discharge       3038         3055 0.0434     0.000001
# discharge       3057         3058 0.0039     0.000000
# discharge       3060         3107 0.0296     0.000000
# discharge       3109         3131 0.1413     0.000004
# discharge       3133         3155 0.4114     0.000029
# discharge       3158         3179 0.3411     0.000021
# discharge       3183         3204 0.3318     0.000020
# discharge       3209         3216 0.0037     0.000000
# discharge       3217         3218 0.0016     0.000000
# discharge       3219         3220 0.0027     0.000000
# discharge       3222         3227 0.0908     0.000002
# discharge       3229         3251 0.1916     0.000007
# discharge       3254         3275 0.3854     0.000026
# discharge       3279         3300 0.3723     0.000025
# discharge       3304         3323 0.3387     0.000021
# discharge       3328         3347 0.4448     0.000034
# discharge       3351         3371 0.3082     0.000018
# discharge       3374         3394 0.1853     0.000007
# discharge       3397         3416 0.0524     0.000001
# discharge       3421         3443 0.2660     0.000013
# discharge       3447         3467 0.2409     0.000011
# discharge       3472         3491 0.2222     0.000010
# discharge       3494         3512 0.1034     0.000002
# discharge       3517         3539 0.0297     0.000000
# discharge       3540         3563 0.3036     0.000017
# discharge       3566         3587 0.3951     0.000027
# discharge       3590         3610 0.1470     0.000005
# discharge       3613         3635 0.1365     0.000004
# discharge       3639         3659 0.1059     0.000003
# discharge       3662         3683 0.4180     0.000030
# discharge       3687         3707 0.3483     0.000022
# discharge       3711         3731 0.1782     0.000007
# discharge       3734         3754 0.1727     0.000006
# discharge       3758         3779 0.3971     0.000028
# discharge       3782         3803 0.1502     0.000005
# discharge       3805         3826 0.3348     0.000020
# discharge       3830         3849 0.0544     0.000001
# discharge       3853         3875 0.1858     0.000007
# discharge       3877         3899 0.1339     0.000004
# discharge       3901         3923 0.2340     0.000011
# discharge       3926         3947 0.4034     0.000028
# discharge       3950         3971 0.4180     0.000030
# discharge       3975         3995 0.4080     0.000029
# discharge       3999         4019 0.3258     0.000019
# discharge       4022         4043 0.1871     0.000007
# discharge       4047         4067 0.2878     0.000015
# discharge       4072         4091 0.2971     0.000016
# discharge       4095         4114 0.2114     0.000009
# discharge       4118         4139 0.3227     0.000019
# discharge       4142         4163 0.3964     0.000027
# discharge       4167         4186 0.1951     0.000008
# discharge       4189         4211 0.4129     0.000030
# discharge       4215         4235 0.4047     0.000029
# discharge       4239         4258 0.3069     0.000017
# discharge       4262         4282 0.1206     0.000003
# discharge       4285         4307 0.2724     0.000014
# discharge       4310         4331 0.2837     0.000015
# discharge       4334         4355 0.2538     0.000012
# discharge       4358         4378 0.1631     0.000006
# discharge       4381         4403 0.1809     0.000007
# discharge       4406         4427 0.3109     0.000018
# discharge       4430         4451 0.2254     0.000010
# discharge       4454         4475 0.2331     0.000011
# discharge       4479         4499 0.3064     0.000017
# discharge       4502         4523 0.3064     0.000017
# discharge       4526         4547 0.4274     0.000031
# discharge       4552         4570 0.0599     0.000001
# discharge       4572         4595 0.2018     0.000008
# discharge       4598         4619 0.4299     0.000032
# discharge       4623         4643 0.4175     0.000030
# discharge       4647         4667 0.3475     0.000022
# discharge       4671         4691 0.4274     0.000031
# discharge       4695         4715 0.2948     0.000016
# discharge       4718         4739 0.2854     0.000015
# discharge       4742         4764 0.2777     0.000015
# discharge       4768         4787 0.3299     0.000020
# discharge       4790         4811 0.0925     0.000002
# discharge       4813         4835 0.3077     0.000017
# discharge       4838         4859 0.3765     0.000025
# discharge       4863         4883 0.3375     0.000021
# discharge       4887         4908 0.4822     0.000039
# discharge       4919         4932 0.4264     0.000031
# discharge       4937         4955 0.4295     0.000032
# discharge       4961         4980 0.4772     0.000038
# discharge       4985         5004 0.4712     0.000037
# discharge       5010         5027 0.4531     0.000035
# discharge       5032         5051 0.1701     0.000006
# discharge       5053         5075 0.1829     0.000007
# discharge       5078         5099 0.2463     0.000012
# discharge       5102         5123 0.1751     0.000006
# discharge       5126         5147 0.2318     0.000011
# discharge       5150         5171 0.3457     0.000022
# discharge       5174         5195 0.3618     0.000023
# discharge       5198         5219 0.2986     0.000017
# discharge       5222         5243 0.3825     0.000026
# discharge       5247         5267 0.2539     0.000012
# discharge       5270         5291 0.2498     0.000012
# discharge       5294         5315 0.1846     0.000007
# discharge       5318         5339 0.1592     0.000005
# discharge       5341         5363 0.3097     0.000018
# discharge       5366         5387 0.3794     0.000025
# discharge       5391         5411 0.4469     0.000034
# discharge       5415         5435 0.4085     0.000029
# discharge       5439         5459 0.3699     0.000024
# discharge       5463         5483 0.2168     0.000009
# discharge       5486         5508 0.3952     0.000027
# discharge       5512         5531 0.4382     0.000033
# discharge       5535         5555 0.2565     0.000013
# discharge       5558         5579 0.1881     0.000007
# discharge       5582         5603 0.1610     0.000005
# discharge       5605         5627 0.1386     0.000004
# discharge       5629         5651 0.2304     0.000010
# discharge       5654         5675 0.2370     0.000011
# discharge       5678         5699 0.2583     0.000013
# discharge       5702         5723 0.3945     0.000027
# discharge       5727         5747 0.4538     0.000035
# discharge       5751         5771 0.4600     0.000036
# discharge       5775         5795 0.4242     0.000031
# discharge       5799         5819 0.4349     0.000032
# discharge       5824         5844 0.4909     0.000040
# discharge       5848         5868 0.4394     0.000033
# discharge       5873         5891 0.3296     0.000020
# discharge       5894         5915 0.0941     0.000002
# discharge       5917         5940 0.2506     0.000012
# discharge       5943         5963 0.3416     0.000021
# discharge       5966         5988 0.4586     0.000036
# discharge       5991         6005 0.1995     0.000008
# discharge       6013         6024 0.0004     0.000000
# discharge       6026         6035 0.0531     0.000001
# discharge       6037         6049 0.0075     0.000000
# discharge       6051         6059 0.0607     0.000001
# discharge       6061         6083 0.1380     0.000004
# discharge       6086         6107 0.3491     0.000022
# discharge       6111         6121 0.0101     0.000000
# discharge       6122         6131 0.0469     0.000001
# discharge       6134         6155 0.0204     0.000000
# discharge       6157         6180 0.4712     0.000037
# discharge       6184         6203 0.0760     0.000001
# discharge       6206         6221 0.0229     0.000000
# discharge       6227         6251 0.4368     0.000033
# discharge       6255         6275 0.4008     0.000028
# discharge       6279         6299 0.4644     0.000036
# discharge       6303         6323 0.4667     0.000037
# discharge       6327         6348 0.3812     0.000026
# discharge       6353         6372 0.4093     0.000029
# discharge       6375         6396 0.3870     0.000026
# discharge       6400         6420 0.4068     0.000029
# discharge       6424         6444 0.3687     0.000024
# discharge       6447         6467 0.2330     0.000011
# discharge       6470         6489 0.0116     0.000000
# discharge       6492         6516 0.0201     0.000000
# discharge       6517         6540 0.3495     0.000022
# discharge       6543         6564 0.4205     0.000031
# discharge       6567         6588 0.4791     0.000039
# discharge       6591         6611 0.0628     0.000001
# discharge       6613         6635 0.4174     0.000030
# discharge       6639         6660 0.3371     0.000021
# discharge       6663         6684 0.3376     0.000021
# discharge       6687         6708 0.4927     0.000041
# discharge       6711         6731 0.1926     0.000008
# discharge       6734         6755 0.0618     0.000001
# discharge       6757         6779 0.1350     0.000004
# discharge       6782         6803 0.1313     0.000004
# discharge       6806         6828 0.4418     0.000033
# discharge       6831         6852 0.4001     0.000028
# discharge       6855         6864 0.0075     0.000000
# discharge       6866         6876 0.0167     0.000000
# discharge       6877         6890 0.0561     0.000001
# discharge       6895         6900 0.0414     0.000000
# discharge       6901         6924 0.4548     0.000035
# discharge       6927         6948 0.0874     0.000002
# discharge       6949         6972 0.3600     0.000023
# discharge       6975         6996 0.3311     0.000020
# discharge       6998         7020 0.3370     0.000021
# discharge       7023         7044 0.4499     0.000034
# discharge       7047         7068 0.4566     0.000035
# discharge       7071         7091 0.2257     0.000010
# discharge       7094         7104 0.0079     0.000000
# discharge       7106         7116 0.0280     0.000000
# discharge       7117         7140 0.2357     0.000011
# discharge       7142         7164 0.1685     0.000006
# discharge       7166         7188 0.2830     0.000015
# discharge       7191         7212 0.2383     0.000011
# discharge       7215         7236 0.2495     0.000012
# discharge       7239         7260 0.0170     0.000000
# discharge       7261         7284 0.0187     0.000000
# discharge       7285         7295 0.0007     0.000000
# discharge       7296         7332 0.4140     0.000030
# discharge       7336         7356 0.3035     0.000017
# discharge       7360         7380 0.1362     0.000004
# discharge       7383         7396 0.0458     0.000001
# discharge       7402         7453 0.4014     0.000028
# discharge       7457         7476 0.3622     0.000023
# discharge       7480         7500 0.2035     0.000008
# discharge       7503         7524 0.1964     0.000008
# discharge       7529         7549 0.3072     0.000017
# discharge       7554         7572 0.3074     0.000017
# discharge       7575         7596 0.2491     0.000012
# discharge       7599         7607 0.0000     0.000000
# discharge       7608         7621 0.1211     0.000003
# discharge       7625         7644 0.1374     0.000004
# discharge       7646         7668 0.4354     0.000033
# discharge       7671         7693 0.3049     0.000017
# discharge       7696         7716 0.1885     0.000007
# discharge       7719         7728 0.0211     0.000000
# discharge       7735         7738 0.0184     0.000000
# discharge       7739         7740 0.0006     0.000000
# discharge       7741         7764 0.1760     0.000006
# discharge       7767         7782 0.2384     0.000011
# discharge       7790         7836 0.0409     0.000000
# discharge       7837         7861 0.5082     0.000043
# discharge       7864         7884 0.2349     0.000011
# discharge       7886         7932 0.0560     0.000001
# discharge       7933         7957 0.3483     0.000022
# discharge       7962         7971 0.0148     0.000000
# discharge       7974         7980 0.0276     0.000000
# discharge       7982         8004 0.2589     0.000013
# discharge       8007         8028 0.5319     0.000047
# discharge       8031         8052 0.2295     0.000010
# discharge       8056         8076 0.4333     0.000032
# discharge       8079         8088 0.0167     0.000000
# discharge       8092         8100 0.1437     0.000004
# discharge       8102         8123 0.1975     0.000008
# discharge       8126         8146 0.0641     0.000001
# discharge       8149         8172 0.2626     0.000013
# discharge       8175         8196 0.4764     0.000038
# discharge       8199         8207 0.0044     0.000000
# discharge       8208         8215 0.0004     0.000000
# discharge       8216         8221 0.0163     0.000000
# discharge       8223         8238 0.0083     0.000000
# discharge       8239         8245 0.0930     0.000002
# discharge       8247         8269 0.4680     0.000037
# discharge       8272         8280 0.0044     0.000000
# discharge       8282         8292 0.1358     0.000004
# discharge       8294         8316 0.3418     0.000021
# discharge       8319         8328 0.0038     0.000000
# discharge       8330         8342 0.1353     0.000004
# discharge       8345         8351 0.0119     0.000000
# discharge       8353         8360 0.0292     0.000000
# discharge       8362         8363 0.0007     0.000000
# discharge       8366         8389 0.1929     0.000008
# discharge       8391         8404 0.0056     0.000000
# discharge       8406         8437 0.1991     0.000008
# discharge       8440         8453 0.2457     0.000012
# discharge       8458         8461 0.0463     0.000001
# discharge       8466         8484 0.1723     0.000006
# discharge       8486         8499 0.1174     0.000003
# discharge       8504         8506 0.0044     0.000000
# discharge       8510         8532 0.1976     0.000008
# discharge       8534         8556 0.3964     0.000027
# discharge       8559         8580 0.1417     0.000004
# discharge       8582         8605 0.1992     0.000008
# discharge       8608         8630 0.3107     0.000018
# discharge       8634         8653 0.2559     0.000013
# discharge       8657         8700 0.1864     0.000007
# discharge       8705         8718 0.0506     0.000001
# discharge       8726         8749 0.2073     0.000009
#
# Total Estimated Degradation: 0.005009
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.55) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 1285159.88 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 107370.32 kWh
# Year 2004: Unmet Load = 3922.23 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 42190.33 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 31969.84 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 1285159.88 kWh (Year 2015)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_55_percent_inference"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) 55% reduction (Case 2) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 71% Load Factor (Intense Traffic)

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_71_percent_inference"
dispatch_load_factor = 0.71  # Apply 0.71 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.71)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Dispatch Load Factor 0.71) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.71)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.71) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0x1f48e2d4
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.79s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.227876e+05   3.669944e+06     44s
#     1148    2.7792659e+12   0.000000e+00   4.634728e+12     45s
#     3748    5.2379199e+11   0.000000e+00   3.424065e+13     50s
#     5532    1.8996480e+11   2.546641e-03   1.334753e+13     55s
#     7096    7.5026701e+10   5.278366e-03   4.918827e+13     60s
#     8893    3.7894017e+10   1.537264e-04   1.772088e+11     65s
#    10582    2.5861849e+10   4.392039e-04   5.116024e+07     70s
#    12063    1.9976915e+10   1.698774e-04   3.188416e+10     75s
#    13297    1.6131944e+10   5.719932e-04   1.628445e+09     80s
#    15243   -2.8531233e+33   3.989345e+32   2.853123e+03     85s
#    21887   -1.4495469e+10   1.657024e+11   0.000000e+00     90s
#    24251   -1.4450064e+10   4.979946e+11   0.000000e+00     95s
#    26497    7.3621362e+08   2.791783e+09   0.000000e+00    100s
#    28837    8.2373847e+08   1.701001e+10   0.000000e+00    105s
#    31021    9.4069294e+08   1.381978e+09   0.000000e+00    110s
#    32737    1.3401694e+09   6.116962e+11   0.000000e+00    115s
# Concurrent spin time: 12.72s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 3.380229e+09, 45480 iterations, 85.10 seconds (59.54 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.3802e+09    0    4          - 3.3802e+09      -     -  128s
# H    0     0                    3.422278e+09 3.3802e+09  1.23%     -  132s
# H    0     0                    3.411333e+09 3.3802e+09  0.91%     -  143s
#
# Explored 1 nodes (45480 simplex iterations) in 144.75 seconds (137.70 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 3.41133e+09 3.42228e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.411332883332e+09, best bound 3.380228704637e+09, gap 0.9118%
# Optimal Solution Found!
# Solar Capacity: 7946302.29 kW
# Wind Capacity: 134.09 kW
# Battery Capacity: 3862412.64 kWh
# Total NPC: $3411332883.33
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2704219976.59 kWh
# Total Energy Generated: 4711239663.15 kWh
# Total Energy Used (along with efficiency losses): 2007019686.56 kWh
# Utilization Percentage: 42.60%
# $14220636.05 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 7946302.29 kW
# Solar Initial Cost:    $738608797.68
# Wind Initial Capacity: 134.09 kW
# Wind Initial Cost:     $685687101.79
# Battery Initial Capacity: 3862412.64 kWh
# Battery Initial Cost:  $1382743726.26
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -25428.17 kW
# Solar Redundant Cost:    $-2363548.15
# Wind Redundant Capacity: 11.84 kW
# Wind Redundant Cost:     $60532457.35
# Battery Redundant Capacity: 14290.93 kWh
# Battery Redundant Cost:  $5116151.79
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $736245249.53
# Solar OPEX:         $804174686.85
# Solar Replacement:  $0.00
# Solar Salvage:     -$214029011.61
# Wind CAPEX:         $746219559.13
# Wind OPEX:          $159717702.39
# Wind Replacement:   $0.00
# Wind Salvage:      -$135580360.95
# Battery CAPEX:      $1387859878.04
# Battery OPEX:       $418116976.35
# Battery Replacement:$180683526.32
# Battery Salvage:   -$504319515.38
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3592016409.65
#
# === 2024 Solar Results 99% met (Dispatch Load Factor 0.71) ===
# Total Unmet Load: 34849.26 kWh
# Hours with Unmet Load: [612, 613]
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           12 0.2884     0.000016
# discharge         15           36 0.5968     0.000057
# discharge         41           62 0.8134     0.000099
# discharge         70           84 0.5346     0.000047
# discharge         88          109 0.4090     0.000029
# discharge        115          133 0.5348     0.000047
# discharge        141          158 0.4302     0.000032
# discharge        161          180 0.4161     0.000030
# discharge        184          202 0.1504     0.000005
# discharge        206          228 0.1436     0.000004
# discharge        230          253 0.1618     0.000006
# discharge        256          275 0.0327     0.000000
# discharge        280          300 0.1430     0.000004
# discharge        302          324 0.2658     0.000013
# discharge        326          349 0.4448     0.000034
# discharge        354          373 0.3744     0.000025
# discharge        375          396 0.5856     0.000055
# discharge        399          423 0.1449     0.000005
# discharge        428          442 0.5577     0.000051
# discharge        447          468 0.3479     0.000022
# discharge        470          492 0.5513     0.000050
# discharge        495          516 0.3431     0.000021
# discharge        519          528 0.0111     0.000000
# discharge        532          542 0.1247     0.000003
# discharge        545          561 0.0002     0.000000
# discharge        562          567 0.1176     0.000003
# discharge        570          590 0.7708     0.000090
# discharge        597          613 0.5023     0.000042
# discharge        619          633 0.2195     0.000010
# discharge        642          660 0.2413     0.000011
# discharge        663          685 0.6796     0.000072
# discharge        689          708 0.3965     0.000027
# discharge        712          732 0.2616     0.000013
# discharge        734          756 0.6818     0.000073
# discharge        761          780 0.3350     0.000020
# discharge        783          804 0.5200     0.000045
# discharge        809          817 0.1202     0.000003
# discharge        820          829 0.0661     0.000001
# discharge        835          852 0.2817     0.000015
# discharge        855          876 0.1542     0.000005
# discharge        878          900 0.3867     0.000026
# discharge        903          924 0.1241     0.000003
# discharge        926          941 0.0090     0.000000
# discharge        942          949 0.0473     0.000001
# discharge        951          973 0.1769     0.000006
# discharge        978          996 0.4760     0.000038
# discharge        999         1021 0.2338     0.000011
# discharge       1024         1044 0.3945     0.000027
# discharge       1047         1068 0.4654     0.000037
# discharge       1071         1092 0.2088     0.000009
# discharge       1094         1117 0.5659     0.000052
# discharge       1125         1127 0.0029     0.000000
# discharge       1128         1140 0.0135     0.000000
# discharge       1141         1164 0.6254     0.000062
# discharge       1167         1188 0.5340     0.000047
# discharge       1191         1212 0.4460     0.000034
# discharge       1215         1236 0.3175     0.000018
# discharge       1239         1284 0.2740     0.000014
# discharge       1286         1299 0.0452     0.000001
# discharge       1301         1302 0.0001     0.000000
# discharge       1306         1307 0.0005     0.000000
# discharge       1309         1332 0.2902     0.000016
# discharge       1335         1356 0.0155     0.000000
# discharge       1357         1428 0.4516     0.000035
# discharge       1431         1452 0.5171     0.000044
# discharge       1455         1476 0.7284     0.000082
# discharge       1481         1500 0.2582     0.000013
# discharge       1502         1524 0.1334     0.000004
# discharge       1526         1549 0.3699     0.000024
# discharge       1554         1572 0.4742     0.000038
# discharge       1575         1596 0.5187     0.000044
# discharge       1601         1620 0.3554     0.000023
# discharge       1627         1644 0.4124     0.000030
# discharge       1648         1667 0.3237     0.000019
# discharge       1670         1692 0.5540     0.000050
# discharge       1695         1716 0.3825     0.000026
# discharge       1719         1739 0.1416     0.000004
# discharge       1742         1763 0.0482     0.000001
# discharge       1765         1779 0.0947     0.000002
# discharge       1780         1783 0.0256     0.000000
# discharge       1785         1788 0.0409     0.000000
# discharge       1793         1812 0.5281     0.000046
# discharge       1815         1836 0.4641     0.000036
# discharge       1840         1859 0.1850     0.000007
# discharge       1862         1883 0.5131     0.000044
# discharge       1887         1896 0.0035     0.000000
# discharge       1898         1907 0.0784     0.000002
# discharge       1909         1932 0.4505     0.000035
# discharge       1935         1956 0.5041     0.000042
# discharge       1965         1973 0.2153     0.000009
# discharge       1982         2004 0.2190     0.000009
# discharge       2007         2016 0.0018     0.000000
# discharge       2018         2025 0.0064     0.000000
# discharge       2027         2042 0.1346     0.000004
# discharge       2044         2052 0.2046     0.000008
# discharge       2055         2075 0.2628     0.000013
# discharge       2078         2099 0.4177     0.000030
# discharge       2103         2123 0.4182     0.000030
# discharge       2127         2147 0.0723     0.000001
# discharge       2149         2171 0.1463     0.000005
# discharge       2174         2195 0.1057     0.000003
# discharge       2198         2208 0.0014     0.000000
# discharge       2210         2243 0.1475     0.000005
# discharge       2245         2267 0.1005     0.000002
# discharge       2269         2291 0.2252     0.000010
# discharge       2294         2315 0.2676     0.000014
# discharge       2319         2339 0.1249     0.000003
# discharge       2341         2363 0.3598     0.000023
# discharge       2367         2379 0.0154     0.000000
# discharge       2380         2388 0.0858     0.000002
# discharge       2390         2411 0.3830     0.000026
# discharge       2420         2435 0.2340     0.000011
# discharge       2439         2459 0.0242     0.000000
# discharge       2460         2483 0.4129     0.000030
# discharge       2487         2507 0.0703     0.000001
# discharge       2509         2531 0.1688     0.000006
# discharge       2534         2555 0.2840     0.000015
# discharge       2558         2579 0.0067     0.000000
# discharge       2580         2603 0.3367     0.000021
# discharge       2607         2626 0.1616     0.000006
# discharge       2629         2651 0.2190     0.000010
# discharge       2655         2675 0.2860     0.000015
# discharge       2678         2699 0.4902     0.000040
# discharge       2703         2723 0.2170     0.000009
# discharge       2726         2747 0.2057     0.000008
# discharge       2750         2771 0.2064     0.000009
# discharge       2774         2796 0.3092     0.000018
# discharge       2799         2809 0.0106     0.000000
# discharge       2811         2819 0.0267     0.000000
# discharge       2821         2843 0.0439     0.000001
# discharge       2845         2868 0.0723     0.000001
# discharge       2871         2891 0.6159     0.000060
# discharge       2895         2915 0.3840     0.000026
# discharge       2919         2939 0.3499     0.000022
# discharge       2943         2963 0.5793     0.000054
# discharge       2968         2987 0.6259     0.000062
# discharge       2993         3011 0.6009     0.000058
# discharge       3020         3035 0.4560     0.000035
# discharge       3039         3059 0.1782     0.000007
# discharge       3061         3083 0.0815     0.000002
# discharge       3086         3101 0.0401     0.000000
# discharge       3103         3107 0.0642     0.000001
# discharge       3109         3131 0.2818     0.000015
# discharge       3134         3155 0.5521     0.000050
# discharge       3159         3179 0.4817     0.000039
# discharge       3183         3204 0.4965     0.000041
# discharge       3210         3227 0.2374     0.000011
# discharge       3230         3251 0.3329     0.000020
# discharge       3254         3275 0.5254     0.000045
# discharge       3279         3300 0.5371     0.000047
# discharge       3304         3323 0.4798     0.000039
# discharge       3330         3347 0.5858     0.000055
# discharge       3351         3371 0.4491     0.000034
# discharge       3375         3395 0.3233     0.000019
# discharge       3398         3419 0.1592     0.000005
# discharge       3423         3444 0.4105     0.000029
# discharge       3448         3467 0.3936     0.000027
# discharge       3473         3491 0.3637     0.000024
# discharge       3495         3515 0.2334     0.000011
# discharge       3518         3539 0.0803     0.000002
# discharge       3541         3563 0.4447     0.000034
# discharge       3567         3587 0.5365     0.000047
# discharge       3591         3611 0.2857     0.000015
# discharge       3614         3635 0.2779     0.000015
# discharge       3640         3648 0.0078     0.000000
# discharge       3651         3660 0.1894     0.000007
# discharge       3662         3683 0.5598     0.000051
# discharge       3687         3707 0.4900     0.000040
# discharge       3712         3731 0.3194     0.000019
# discharge       3735         3755 0.3003     0.000017
# discharge       3758         3779 0.5381     0.000047
# discharge       3783         3803 0.2886     0.000016
# discharge       3806         3826 0.4641     0.000036
# discharge       3831         3851 0.1837     0.000007
# discharge       3854         3875 0.3123     0.000018
# discharge       3878         3899 0.2679     0.000014
# discharge       3902         3923 0.3752     0.000025
# discharge       3927         3947 0.5450     0.000049
# discharge       3951         3971 0.5601     0.000051
# discharge       3975         3995 0.5501     0.000049
# discharge       4000         4019 0.4669     0.000037
# discharge       4023         4043 0.3253     0.000019
# discharge       4049         4067 0.4291     0.000032
# discharge       4073         4091 0.4383     0.000033
# discharge       4095         4115 0.3492     0.000022
# discharge       4118         4139 0.4638     0.000036
# discharge       4143         4163 0.5377     0.000047
# discharge       4167         4187 0.3324     0.000020
# discharge       4190         4211 0.5546     0.000050
# discharge       4215         4235 0.5461     0.000049
# discharge       4239         4259 0.4387     0.000033
# discharge       4263         4283 0.2562     0.000013
# discharge       4286         4307 0.4074     0.000029
# discharge       4311         4331 0.4245     0.000031
# discharge       4335         4355 0.3948     0.000027
# discharge       4359         4379 0.2878     0.000015
# discharge       4382         4403 0.3210     0.000019
# discharge       4406         4427 0.4522     0.000035
# discharge       4431         4451 0.3667     0.000024
# discharge       4455         4475 0.3736     0.000025
# discharge       4480         4499 0.4470     0.000034
# discharge       4503         4523 0.4481     0.000034
# discharge       4527         4547 0.5680     0.000052
# discharge       4553         4570 0.1892     0.000007
# discharge       4573         4595 0.3310     0.000020
# discharge       4598         4619 0.5710     0.000053
# discharge       4623         4643 0.5577     0.000051
# discharge       4648         4667 0.4881     0.000040
# discharge       4672         4691 0.5685     0.000052
# discharge       4696         4715 0.4356     0.000033
# discharge       4719         4739 0.4260     0.000031
# discharge       4743         4764 0.4299     0.000032
# discharge       4770         4787 0.4703     0.000037
# discharge       4791         4811 0.2234     0.000010
# discharge       4814         4835 0.4480     0.000034
# discharge       4839         4859 0.5167     0.000044
# discharge       4863         4883 0.4776     0.000038
# discharge       4888         4909 0.6418     0.000065
# discharge       4918         4932 0.5858     0.000055
# discharge       4940         4956 0.5886     0.000056
# discharge       4962         4980 0.6402     0.000065
# discharge       4988         5004 0.6284     0.000063
# discharge       5012         5027 0.6040     0.000058
# discharge       5033         5051 0.3100     0.000018
# discharge       5054         5075 0.3229     0.000019
# discharge       5078         5099 0.3853     0.000026
# discharge       5103         5123 0.3148     0.000018
# discharge       5126         5147 0.3714     0.000024
# discharge       5151         5171 0.4850     0.000039
# discharge       5175         5195 0.5012     0.000042
# discharge       5199         5219 0.4377     0.000033
# discharge       5223         5243 0.5219     0.000045
# discharge       5247         5267 0.3932     0.000027
# discharge       5271         5291 0.3888     0.000027
# discharge       5295         5315 0.3242     0.000019
# discharge       5318         5339 0.2983     0.000017
# discharge       5342         5363 0.4513     0.000035
# discharge       5367         5387 0.5180     0.000044
# discharge       5391         5411 0.5858     0.000055
# discharge       5415         5435 0.5538     0.000050
# discharge       5440         5459 0.5081     0.000043
# discharge       5463         5483 0.3559     0.000023
# discharge       5487         5508 0.5452     0.000049
# discharge       5512         5531 0.5765     0.000054
# discharge       5535         5555 0.3944     0.000027
# discharge       5559         5579 0.3261     0.000019
# discharge       5582         5603 0.2990     0.000017
# discharge       5606         5627 0.2769     0.000014
# discharge       5630         5651 0.3681     0.000024
# discharge       5654         5675 0.3747     0.000025
# discharge       5679         5699 0.3960     0.000027
# discharge       5703         5723 0.5322     0.000047
# discharge       5727         5747 0.5910     0.000056
# discharge       5751         5771 0.5975     0.000057
# discharge       5775         5795 0.5613     0.000051
# discharge       5800         5820 0.5735     0.000053
# discharge       5824         5844 0.6504     0.000067
# discharge       5849         5868 0.5934     0.000057
# discharge       5874         5891 0.4747     0.000038
# discharge       5895         5915 0.2309     0.000010
# discharge       5918         5940 0.3988     0.000028
# discharge       5945         5963 0.4903     0.000040
# discharge       5967         5988 0.6088     0.000059
# discharge       5992         6006 0.2811     0.000015
# discharge       6008         6011 0.0186     0.000000
# discharge       6014         6035 0.1888     0.000007
# discharge       6038         6059 0.2051     0.000008
# discharge       6062         6083 0.2746     0.000014
# discharge       6086         6107 0.4910     0.000040
# discharge       6111         6131 0.1954     0.000008
# discharge       6136         6156 0.0665     0.000001
# discharge       6158         6180 0.6304     0.000063
# discharge       6186         6204 0.2282     0.000010
# discharge       6207         6228 0.1306     0.000004
# discharge       6232         6252 0.5869     0.000055
# discharge       6255         6276 0.5408     0.000048
# discharge       6279         6300 0.6110     0.000060
# discharge       6304         6324 0.6224     0.000062
# discharge       6328         6348 0.5384     0.000048
# discharge       6354         6372 0.5670     0.000052
# discharge       6376         6396 0.5446     0.000049
# discharge       6400         6420 0.5760     0.000054
# discharge       6425         6444 0.5265     0.000046
# discharge       6448         6468 0.3790     0.000025
# discharge       6471         6491 0.1129     0.000003
# discharge       6494         6516 0.1070     0.000003
# discharge       6518         6540 0.5073     0.000043
# discharge       6544         6564 0.5773     0.000054
# discharge       6568         6588 0.6362     0.000064
# discharge       6592         6600 0.0067     0.000000
# discharge       6601         6611 0.1621     0.000006
# discharge       6614         6636 0.5735     0.000053
# discharge       6639         6660 0.4939     0.000041
# discharge       6663         6684 0.4947     0.000041
# discharge       6687         6708 0.6497     0.000067
# discharge       6712         6731 0.3384     0.000021
# discharge       6734         6755 0.1963     0.000008
# discharge       6758         6780 0.2838     0.000015
# discharge       6782         6804 0.2853     0.000015
# discharge       6806         6828 0.5985     0.000057
# discharge       6832         6852 0.5567     0.000050
# discharge       6855         6866 0.0359     0.000000
# discharge       6867         6876 0.0950     0.000002
# discharge       6878         6900 0.2214     0.000010
# discharge       6902         6924 0.6110     0.000060
# discharge       6928         6948 0.2327     0.000011
# discharge       6950         6972 0.5164     0.000044
# discharge       6975         6996 0.4871     0.000040
# discharge       6999         7020 0.4930     0.000041
# discharge       7023         7044 0.6059     0.000059
# discharge       7047         7068 0.6126     0.000060
# discharge       7072         7092 0.3803     0.000026
# discharge       7095         7116 0.1480     0.000005
# discharge       7118         7140 0.3916     0.000027
# discharge       7143         7164 0.3249     0.000019
# discharge       7167         7188 0.4385     0.000033
# discharge       7192         7212 0.4051     0.000029
# discharge       7215         7236 0.4054     0.000029
# discharge       7239         7248 0.0092     0.000000
# discharge       7251         7260 0.1007     0.000002
# discharge       7262         7272 0.0077     0.000000
# discharge       7276         7284 0.0723     0.000001
# discharge       7286         7298 0.0244     0.000000
# discharge       7304         7307 0.0118     0.000000
# discharge       7309         7332 0.5851     0.000055
# discharge       7336         7357 0.4663     0.000037
# discharge       7360         7380 0.2928     0.000016
# discharge       7384         7398 0.1217     0.000003
# discharge       7407         7426 0.0024     0.000000
# discharge       7428         7453 0.5624     0.000051
# discharge       7459         7476 0.5172     0.000044
# discharge       7480         7500 0.3596     0.000023
# discharge       7503         7525 0.3557     0.000023
# discharge       7531         7550 0.4983     0.000041
# discharge       7555         7572 0.4626     0.000036
# discharge       7575         7596 0.4046     0.000029
# discharge       7599         7621 0.2793     0.000015
# discharge       7629         7644 0.3037     0.000017
# discharge       7647         7668 0.5906     0.000056
# discharge       7672         7693 0.4710     0.000037
# discharge       7696         7716 0.3437     0.000021
# discharge       7720         7740 0.1762     0.000006
# discharge       7743         7765 0.2586     0.000013
# discharge       7767         7788 0.3469     0.000022
# discharge       7791         7812 0.0359     0.000000
# discharge       7813         7823 0.0040     0.000000
# discharge       7824         7836 0.1564     0.000005
# discharge       7838         7861 0.6754     0.000071
# discharge       7865         7884 0.3906     0.000027
# discharge       7887         7908 0.0066     0.000000
# discharge       7909         7918 0.0037     0.000000
# discharge       7920         7932 0.1592     0.000005
# discharge       7934         7957 0.5149     0.000044
# discharge       7964         7972 0.0809     0.000002
# discharge       7974         7980 0.0694     0.000001
# discharge       7982         8004 0.4148     0.000030
# discharge       8007         8028 0.6877     0.000074
# discharge       8032         8053 0.3967     0.000028
# discharge       8057         8076 0.5889     0.000056
# discharge       8080         8100 0.2917     0.000016
# discharge       8103         8124 0.3526     0.000022
# discharge       8127         8148 0.1695     0.000006
# discharge       8150         8172 0.4192     0.000030
# discharge       8175         8196 0.6326     0.000063
# discharge       8200         8221 0.1471     0.000005
# discharge       8225         8230 0.0012     0.000000
# discharge       8231         8233 0.0048     0.000000
# discharge       8234         8245 0.2134     0.000009
# discharge       8248         8269 0.6362     0.000064
# discharge       8273         8292 0.2871     0.000015
# discharge       8295         8316 0.4893     0.000040
# discharge       8319         8342 0.3044     0.000017
# discharge       8347         8364 0.1839     0.000007
# discharge       8367         8376 0.0154     0.000000
# discharge       8378         8389 0.3088     0.000018
# discharge       8392         8405 0.0801     0.000002
# discharge       8406         8408 0.0054     0.000000
# discharge       8415         8437 0.3718     0.000025
# discharge       8441         8454 0.3425     0.000021
# discharge       8457         8461 0.0854     0.000002
# discharge       8468         8484 0.3212     0.000019
# discharge       8487         8508 0.2562     0.000013
# discharge       8510         8532 0.3553     0.000023
# discharge       8535         8556 0.5544     0.000050
# discharge       8560         8580 0.2993     0.000017
# discharge       8583         8605 0.3400     0.000021
# discharge       8609         8630 0.5044     0.000042
# discharge       8636         8653 0.4479     0.000034
# discharge       8659         8669 0.0667     0.000001
# discharge       8678         8701 0.3464     0.000022
# discharge       8713         8725 0.1326     0.000004
# discharge       8727         8749 0.3678     0.000024
#
# Total Estimated Degradation: 0.010143
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.71) ===
# Year 2024: Unmet Load = 34849.26 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 1863137.57 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 54344.82 kWh
# Year 2019: Unmet Load = 2704321.56 kWh
# Year 2018: Unmet Load = 7938.80 kWh
# Year 2017: Unmet Load = 2839061.18 kWh
# Year 2016: Unmet Load = 3016271.16 kWh
# Year 2015: Unmet Load = 4941501.28 kWh
# Year 2014: Unmet Load = 1540657.08 kWh
# Year 2013: Unmet Load = 1574636.15 kWh
# Year 2012: Unmet Load = 414802.41 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 1217270.34 kWh
# Year 2008: Unmet Load = 882480.31 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 278115.06 kWh
# Year 2005: Unmet Load = 2770204.56 kWh
# Year 2004: Unmet Load = 3233270.51 kWh
# Year 2003: Unmet Load = 159049.54 kWh
# Year 2002: Unmet Load = 1793117.63 kWh
# Year 2001: Unmet Load = 2106016.49 kWh
# Year 2000: Unmet Load = 22721.37 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 4489199.62 kWh
# Year 1997: Unmet Load = 562702.69 kWh
# Year 1996: Unmet Load = 2019987.68 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 2538234.22 kWh
# Year 1993: Unmet Load = 976982.74 kWh
# Year 1992: Unmet Load = 1450397.37 kWh
# Year 1991: Unmet Load = 3234978.59 kWh
# Year 1990: Unmet Load = 2338436.51 kWh
# Year 1989: Unmet Load = 1472016.26 kWh
# Year 1988: Unmet Load = 670134.55 kWh
# Year 1987: Unmet Load = 523419.71 kWh
# Year 1986: Unmet Load = 1427397.73 kWh
# Year 1985: Unmet Load = 1113749.84 kWh
# Year 1984: Unmet Load = 1625193.68 kWh
# Year 1983: Unmet Load = 2019178.53 kWh
# Year 1982: Unmet Load = 1632394.77 kWh
# Year 1981: Unmet Load = 1269768.77 kWh
# Year 1980: Unmet Load = 487389.51 kWh
#
# Average Unmet Load (1979-2024): 1362340.66 kWh
# Min Unmet Load: 0.00 kWh (Year 1995)
# Max Unmet Load: 4941501.28 kWh (Year 2015)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_71_percent_inference"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) 71% reduction (Case 1) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()
