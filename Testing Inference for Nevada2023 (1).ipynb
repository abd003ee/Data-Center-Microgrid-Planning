# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (1).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (1).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023"
dispatch_load_factor = 0.71  # Apply 0.71 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 100% met (Load Factor 0.71)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 100% met (Load Factor 0.71) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 100% met (Load Factor 0.71)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 100% met (Load Factor 0.71) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890649 nonzeros
# Model fingerprint: 0x1849466c
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17528 rows and 17527 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 11s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 26.72s
# Presolved: 70077 rows, 35042 columns, 161798 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52388 rows, 26170 columns, 135219 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3352987e+08   1.405310e+06   1.567416e+07     46s
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.458880e+09, 17896 iterations, 4.37 seconds (2.39 work units)
# Total elapsed time = 50.00s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.4589e+09    0    1          - 4.4589e+09      -     -   50s
# H    0     0                    4.458880e+09 4.4589e+09  0.00%     -   51s
#      0     0 4.4589e+09    0    1 4.4589e+09 4.4589e+09  0.00%     -   51s
#
# Explored 1 nodes (17896 simplex iterations) in 52.18 seconds (67.62 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.45888e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.458879792117e+09, best bound 4.458879792117e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 11998226.30 kW
# Wind Capacity: 38.76 kW
# Battery Capacity: 6588917.32 kWh
# Total NPC: $4458879792.12
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 5137333786.35 kWh
# Total Energy Generated: 7490220411.91 kWh
# Total Energy Used (along with efficiency losses): 2352886625.56 kWh
# Utilization Percentage: 31.41%
# $17703258.50 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 11998226.30 kW
# Solar Initial Cost:    $1115235134.53
# Wind Initial Capacity: 38.76 kW
# Wind Initial Cost:     $198232357.20
# Battery Initial Capacity: 6588917.32 kWh
# Battery Initial Cost:  $2358832401.61
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -38394.32 kW
# Solar Redundant Cost:    $-3568752.43
# Wind Redundant Capacity: 3.42 kW
# Wind Redundant Cost:     $17499952.49
# Battery Redundant Capacity: 24378.99 kWh
# Battery Redundant Cost:  $8727679.89
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $1111666382.10
# Solar OPEX:         $1214233932.62
# Solar Replacement:  $0.00
# Solar Salvage:     -$323165218.59
# Wind CAPEX:         $215732309.70
# Wind OPEX:          $46174438.09
# Wind Replacement:   $0.00
# Wind Salvage:      -$39196325.08
# Battery CAPEX:      $2367560081.50
# Battery OPEX:       $713268737.18
# Battery Replacement:$224932778.08
# Battery Salvage:   -$860322264.38
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $4683812570.20
#
# === 2024 Solar Results 100% met (Load Factor 0.71) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.2998     0.000017
# discharge         17           38 0.3978     0.000028
# discharge         41           62 0.3993     0.000028
# discharge         65           87 0.4531     0.000035
# discharge         93          111 0.4463     0.000034
# discharge        116          134 0.3505     0.000022
# discharge        137          158 0.4133     0.000030
# discharge        161          183 0.4366     0.000033
# discharge        187          207 0.4489     0.000034
# discharge        214          230 0.3431     0.000021
# discharge        237          254 0.3299     0.000020
# discharge        257          278 0.4126     0.000030
# discharge        281          302 0.3942     0.000027
# discharge        305          327 0.4497     0.000034
# discharge        334          350 0.3566     0.000023
# discharge        353          374 0.3798     0.000025
# discharge        378          398 0.3257     0.000019
# discharge        403          422 0.3583     0.000023
# discharge        425          446 0.4113     0.000029
# discharge        449          470 0.3522     0.000022
# discharge        473          494 0.3379     0.000021
# discharge        497          518 0.4050     0.000029
# discharge        521          542 0.2660     0.000013
# discharge        544          566 0.2860     0.000015
# discharge        568          590 0.3690     0.000024
# discharge        593          614 0.3297     0.000020
# discharge        616          638 0.3807     0.000026
# discharge        641          662 0.4029     0.000028
# discharge        665          686 0.3890     0.000027
# discharge        689          710 0.3797     0.000025
# discharge        716          734 0.3124     0.000018
# discharge        736          758 0.2927     0.000016
# discharge        760          782 0.3465     0.000022
# discharge        784          806 0.3736     0.000025
# discharge        809          830 0.3912     0.000027
# discharge        833          854 0.3768     0.000025
# discharge        857          878 0.2820     0.000015
# discharge        880          902 0.2796     0.000015
# discharge        904          926 0.3862     0.000026
# discharge        929          949 0.3314     0.000020
# discharge        952          973 0.3331     0.000020
# discharge        976          998 0.3933     0.000027
# discharge       1003         1022 0.3448     0.000021
# discharge       1025         1046 0.2790     0.000015
# discharge       1048         1070 0.2766     0.000014
# discharge       1072         1093 0.2832     0.000015
# discharge       1096         1117 0.3021     0.000017
# discharge       1120         1142 0.3532     0.000022
# discharge       1145         1166 0.3480     0.000022
# discharge       1169         1189 0.3687     0.000024
# discharge       1192         1213 0.3652     0.000024
# discharge       1216         1237 0.3781     0.000025
# discharge       1241         1262 0.2731     0.000014
# discharge       1264         1285 0.3095     0.000018
# discharge       1289         1310 0.3476     0.000022
# discharge       1314         1334 0.3340     0.000020
# discharge       1337         1357 0.3539     0.000022
# discharge       1360         1381 0.3285     0.000020
# discharge       1384         1405 0.2601     0.000013
# discharge       1408         1429 0.2960     0.000016
# discharge       1434         1453 0.2919     0.000016
# discharge       1456         1477 0.3795     0.000025
# discharge       1480         1501 0.3769     0.000025
# discharge       1505         1525 0.2826     0.000015
# discharge       1528         1549 0.2826     0.000015
# discharge       1553         1573 0.3448     0.000021
# discharge       1576         1597 0.3562     0.000023
# discharge       1602         1621 0.3443     0.000021
# discharge       1626         1646 0.3000     0.000017
# discharge       1649         1669 0.2554     0.000013
# discharge       1672         1693 0.2802     0.000015
# discharge       1696         1717 0.3227     0.000019
# discharge       1720         1741 0.3582     0.000023
# discharge       1745         1766 0.3067     0.000017
# discharge       1769         1789 0.3468     0.000022
# discharge       1792         1813 0.3553     0.000023
# discharge       1816         1837 0.3185     0.000019
# discharge       1840         1862 0.3925     0.000027
# discharge       1867         1886 0.3519     0.000022
# discharge       1891         1910 0.3358     0.000020
# discharge       1913         1933 0.2699     0.000014
# discharge       1936         1957 0.3534     0.000022
# discharge       1960         1981 0.3215     0.000019
# discharge       1984         2005 0.3374     0.000021
# discharge       2009         2029 0.3695     0.000024
# discharge       2032         2053 0.3096     0.000018
# discharge       2056         2077 0.3355     0.000020
# discharge       2080         2101 0.3073     0.000017
# discharge       2105         2125 0.3000     0.000017
# discharge       2128         2149 0.3564     0.000023
# discharge       2152         2173 0.3592     0.000023
# discharge       2176         2197 0.3170     0.000018
# discharge       2200         2221 0.2288     0.000010
# discharge       2224         2245 0.2628     0.000013
# discharge       2248         2269 0.3208     0.000019
# discharge       2272         2293 0.3344     0.000020
# discharge       2296         2317 0.3251     0.000019
# discharge       2321         2341 0.3127     0.000018
# discharge       2344         2365 0.3534     0.000022
# discharge       2368         2389 0.3251     0.000019
# discharge       2392         2413 0.3544     0.000022
# discharge       2416         2437 0.2980     0.000016
# discharge       2440         2461 0.2697     0.000014
# discharge       2464         2485 0.2947     0.000016
# discharge       2488         2509 0.3403     0.000021
# discharge       2512         2533 0.3472     0.000022
# discharge       2536         2557 0.3161     0.000018
# discharge       2560         2581 0.2372     0.000011
# discharge       2583         2605 0.2409     0.000011
# discharge       2607         2629 0.3358     0.000020
# discharge       2632         2653 0.3399     0.000021
# discharge       2656         2677 0.2965     0.000016
# discharge       2680         2701 0.3183     0.000019
# discharge       2704         2725 0.3286     0.000020
# discharge       2728         2749 0.2574     0.000013
# discharge       2752         2773 0.2853     0.000015
# discharge       2776         2797 0.3274     0.000020
# discharge       2800         2821 0.3002     0.000017
# discharge       2824         2845 0.3178     0.000019
# discharge       2848         2869 0.3361     0.000020
# discharge       2872         2893 0.2771     0.000014
# discharge       2896         2917 0.2727     0.000014
# discharge       2920         2941 0.2962     0.000016
# discharge       2944         2965 0.2825     0.000015
# discharge       2968         2989 0.3053     0.000017
# discharge       2992         3013 0.2844     0.000015
# discharge       3016         3037 0.2749     0.000014
# discharge       3040         3061 0.2841     0.000015
# discharge       3064         3085 0.2520     0.000012
# discharge       3088         3108 0.2690     0.000014
# discharge       3112         3133 0.2715     0.000014
# discharge       3136         3157 0.3227     0.000019
# discharge       3160         3180 0.2767     0.000014
# discharge       3184         3204 0.2808     0.000015
# discharge       3208         3229 0.3056     0.000017
# discharge       3232         3252 0.3049     0.000017
# discharge       3256         3276 0.3218     0.000019
# discharge       3280         3300 0.3095     0.000018
# discharge       3304         3324 0.3171     0.000018
# discharge       3328         3348 0.3023     0.000017
# discharge       3352         3372 0.3228     0.000019
# discharge       3376         3396 0.3014     0.000017
# discharge       3400         3421 0.2950     0.000016
# discharge       3424         3444 0.2550     0.000012
# discharge       3448         3468 0.2672     0.000014
# discharge       3472         3492 0.2745     0.000014
# discharge       3496         3516 0.2785     0.000015
# discharge       3520         3541 0.3027     0.000017
# discharge       3544         3564 0.2841     0.000015
# discharge       3568         3588 0.2831     0.000015
# discharge       3592         3612 0.2797     0.000015
# discharge       3616         3636 0.2913     0.000016
# discharge       3640         3660 0.2750     0.000014
# discharge       3664         3684 0.2890     0.000016
# discharge       3688         3708 0.3155     0.000018
# discharge       3712         3732 0.3166     0.000018
# discharge       3736         3756 0.2822     0.000015
# discharge       3760         3781 0.2977     0.000016
# discharge       3785         3804 0.3229     0.000019
# discharge       3808         3828 0.2921     0.000016
# discharge       3832         3853 0.3144     0.000018
# discharge       3857         3876 0.3217     0.000019
# discharge       3881         3900 0.2809     0.000015
# discharge       3904         3924 0.3126     0.000018
# discharge       3928         3948 0.3055     0.000017
# discharge       3952         3972 0.3114     0.000018
# discharge       3976         3996 0.2705     0.000014
# discharge       4000         4020 0.3184     0.000019
# discharge       4024         4044 0.2715     0.000014
# discharge       4048         4068 0.2309     0.000010
# discharge       4071         4093 0.2285     0.000010
# discharge       4095         4117 0.2639     0.000013
# discharge       4120         4140 0.2850     0.000015
# discharge       4144         4164 0.2346     0.000011
# discharge       4167         4189 0.3179     0.000019
# discharge       4192         4213 0.2771     0.000014
# discharge       4216         4236 0.2707     0.000014
# discharge       4240         4261 0.2583     0.000013
# discharge       4264         4284 0.2629     0.000013
# discharge       4288         4308 0.3096     0.000018
# discharge       4312         4332 0.3149     0.000018
# discharge       4336         4356 0.3179     0.000019
# discharge       4360         4380 0.3136     0.000018
# discharge       4384         4404 0.2924     0.000016
# discharge       4408         4429 0.2561     0.000013
# discharge       4432         4453 0.2877     0.000015
# discharge       4456         4477 0.2763     0.000014
# discharge       4480         4501 0.2811     0.000015
# discharge       4504         4525 0.2911     0.000016
# discharge       4528         4549 0.3065     0.000017
# discharge       4552         4573 0.2886     0.000016
# discharge       4576         4596 0.2849     0.000015
# discharge       4600         4620 0.2663     0.000013
# discharge       4624         4644 0.2654     0.000013
# discharge       4648         4669 0.2784     0.000015
# discharge       4672         4692 0.3035     0.000017
# discharge       4696         4716 0.3173     0.000018
# discharge       4720         4740 0.2632     0.000013
# discharge       4744         4764 0.2779     0.000015
# discharge       4768         4789 0.2841     0.000015
# discharge       4792         4813 0.2912     0.000016
# discharge       4816         4837 0.3090     0.000018
# discharge       4840         4861 0.3237     0.000019
# discharge       4864         4884 0.2906     0.000016
# discharge       4888         4909 0.2979     0.000016
# discharge       4912         4933 0.2911     0.000016
# discharge       4936         4957 0.2941     0.000016
# discharge       4960         4981 0.2726     0.000014
# discharge       4984         5005 0.2751     0.000014
# discharge       5008         5029 0.3007     0.000017
# discharge       5032         5053 0.3174     0.000018
# discharge       5056         5077 0.3279     0.000020
# discharge       5081         5101 0.3265     0.000019
# discharge       5104         5125 0.3385     0.000021
# discharge       5129         5149 0.3234     0.000019
# discharge       5152         5173 0.3143     0.000018
# discharge       5176         5197 0.3308     0.000020
# discharge       5200         5221 0.3043     0.000017
# discharge       5224         5245 0.2745     0.000014
# discharge       5248         5269 0.2578     0.000013
# discharge       5272         5293 0.2725     0.000014
# discharge       5298         5317 0.2998     0.000017
# discharge       5320         5341 0.3368     0.000021
# discharge       5344         5365 0.3206     0.000019
# discharge       5368         5389 0.3314     0.000020
# discharge       5392         5413 0.3352     0.000020
# discharge       5416         5437 0.3356     0.000020
# discharge       5440         5461 0.3377     0.000021
# discharge       5465         5485 0.3398     0.000021
# discharge       5488         5509 0.3119     0.000018
# discharge       5512         5533 0.3361     0.000020
# discharge       5536         5557 0.3621     0.000023
# discharge       5563         5581 0.2482     0.000012
# discharge       5584         5605 0.3418     0.000021
# discharge       5608         5629 0.3372     0.000021
# discharge       5632         5653 0.3446     0.000021
# discharge       5656         5677 0.3504     0.000022
# discharge       5680         5701 0.3413     0.000021
# discharge       5704         5725 0.3188     0.000019
# discharge       5728         5749 0.3199     0.000019
# discharge       5752         5773 0.3398     0.000021
# discharge       5776         5797 0.3343     0.000020
# discharge       5800         5821 0.3017     0.000017
# discharge       5824         5846 0.2999     0.000017
# discharge       5850         5869 0.3393     0.000021
# discharge       5872         5893 0.3584     0.000023
# discharge       5896         5917 0.2992     0.000017
# discharge       5920         5941 0.3533     0.000022
# discharge       5944         5965 0.3510     0.000022
# discharge       5968         5989 0.3490     0.000022
# discharge       5992         6013 0.3381     0.000021
# discharge       6016         6037 0.3566     0.000023
# discharge       6040         6062 0.3355     0.000020
# discharge       6066         6085 0.3689     0.000024
# discharge       6088         6109 0.3594     0.000023
# discharge       6112         6133 0.3662     0.000024
# discharge       6136         6157 0.3500     0.000022
# discharge       6160         6181 0.3415     0.000021
# discharge       6184         6205 0.3460     0.000022
# discharge       6208         6229 0.3614     0.000023
# discharge       6232         6253 0.3591     0.000023
# discharge       6256         6277 0.3507     0.000022
# discharge       6280         6301 0.3560     0.000023
# discharge       6304         6325 0.3227     0.000019
# discharge       6328         6349 0.3032     0.000017
# discharge       6352         6373 0.3636     0.000024
# discharge       6377         6397 0.3654     0.000024
# discharge       6400         6421 0.3689     0.000024
# discharge       6424         6445 0.3684     0.000024
# discharge       6448         6469 0.3679     0.000024
# discharge       6472         6493 0.3717     0.000024
# discharge       6496         6517 0.3516     0.000022
# discharge       6520         6542 0.2953     0.000016
# discharge       6547         6565 0.3333     0.000020
# discharge       6568         6589 0.3743     0.000025
# discharge       6593         6613 0.3735     0.000025
# discharge       6616         6637 0.3428     0.000021
# discharge       6640         6661 0.3193     0.000019
# discharge       6664         6685 0.3062     0.000017
# discharge       6688         6709 0.3223     0.000019
# discharge       6712         6733 0.3723     0.000025
# discharge       6737         6757 0.3761     0.000025
# discharge       6761         6781 0.3282     0.000020
# discharge       6784         6805 0.2776     0.000015
# discharge       6808         6829 0.3124     0.000018
# discharge       6832         6853 0.3369     0.000021
# discharge       6857         6877 0.3867     0.000026
# discharge       6881         6901 0.3709     0.000024
# discharge       6904         6925 0.3651     0.000024
# discharge       6928         6949 0.3716     0.000024
# discharge       6953         6973 0.3538     0.000022
# discharge       6977         6997 0.3358     0.000020
# discharge       7000         7021 0.3725     0.000025
# discharge       7025         7045 0.3743     0.000025
# discharge       7049         7069 0.3645     0.000024
# discharge       7073         7093 0.3032     0.000017
# discharge       7096         7117 0.3692     0.000024
# discharge       7121         7141 0.3536     0.000022
# discharge       7145         7166 0.3034     0.000017
# discharge       7168         7190 0.3827     0.000026
# discharge       7193         7214 0.3845     0.000026
# discharge       7217         7237 0.2702     0.000014
# discharge       7240         7261 0.2718     0.000014
# discharge       7264         7285 0.3047     0.000017
# discharge       7288         7309 0.3380     0.000021
# discharge       7312         7334 0.3759     0.000025
# discharge       7337         7358 0.3808     0.000026
# discharge       7361         7382 0.3833     0.000026
# discharge       7385         7406 0.3952     0.000027
# discharge       7409         7430 0.3470     0.000022
# discharge       7433         7454 0.3040     0.000017
# discharge       7457         7478 0.2864     0.000015
# discharge       7480         7502 0.2718     0.000014
# discharge       7504         7526 0.3502     0.000022
# discharge       7529         7550 0.3784     0.000025
# discharge       7553         7574 0.3646     0.000024
# discharge       7577         7598 0.3985     0.000028
# discharge       7601         7622 0.4217     0.000031
# discharge       7625         7646 0.4034     0.000028
# discharge       7650         7670 0.4235     0.000031
# discharge       7673         7694 0.4006     0.000028
# discharge       7697         7718 0.3986     0.000028
# discharge       7721         7742 0.3135     0.000018
# discharge       7745         7766 0.2739     0.000014
# discharge       7768         7790 0.2926     0.000016
# discharge       7792         7814 0.3875     0.000026
# discharge       7817         7839 0.4163     0.000030
# discharge       7844         7862 0.3859     0.000026
# discharge       7865         7886 0.3706     0.000024
# discharge       7889         7910 0.3236     0.000019
# discharge       7913         7934 0.3142     0.000018
# discharge       7937         7958 0.3262     0.000019
# discharge       7961         7982 0.3854     0.000026
# discharge       7987         8006 0.4119     0.000029
# discharge       8009         8030 0.4263     0.000031
# discharge       8033         8054 0.4056     0.000029
# discharge       8057         8078 0.4182     0.000030
# discharge       8081         8102 0.4227     0.000031
# discharge       8106         8126 0.3721     0.000025
# discharge       8129         8150 0.3822     0.000026
# discharge       8153         8174 0.3367     0.000021
# discharge       8179         8198 0.3828     0.000026
# discharge       8201         8222 0.3304     0.000020
# discharge       8225         8246 0.3601     0.000023
# discharge       8249         8270 0.4148     0.000030
# discharge       8273         8294 0.4222     0.000031
# discharge       8297         8318 0.3722     0.000025
# discharge       8321         8342 0.3718     0.000025
# discharge       8345         8366 0.4119     0.000029
# discharge       8369         8390 0.3646     0.000024
# discharge       8394         8414 0.3826     0.000026
# discharge       8417         8438 0.3870     0.000026
# discharge       8442         8462 0.4246     0.000031
# discharge       8467         8486 0.4311     0.000032
# discharge       8490         8511 0.4480     0.000034
# discharge       8516         8535 0.4545     0.000035
# discharge       8541         8558 0.4572     0.000035
# discharge       8562         8582 0.3930     0.000027
# discharge       8585         8606 0.4230     0.000031
# discharge       8609         8630 0.4042     0.000028
# discharge       8633         8654 0.4203     0.000031
# discharge       8658         8678 0.4337     0.000032
# discharge       8682         8702 0.3957     0.000027
# discharge       8706         8726 0.4332     0.000032
# discharge       8729         8750 0.4145     0.000030
#
# Total Estimated Degradation: 0.007422
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1980.png
#
# === Unmet Load Across Years 100% met (Load Factor 0.71) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 0.00 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 0.00 kWh (Year 2024)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 71% reduction (Case 1) in LP for 100% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (1).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (1).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023"
dispatch_load_factor = 0.55  # Apply 0.55 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 100% met (Load Factor 0.55)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 100% met (Load Factor 0.55) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 100% met (Load Factor 0.55)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 100% met (Load Factor 0.55) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890649 nonzeros
# Model fingerprint: 0x1849466c
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17528 rows and 17527 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 26.76s
# Presolved: 70077 rows, 35042 columns, 161798 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52388 rows, 26170 columns, 135219 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3352987e+08   1.405310e+06   1.567416e+07     43s
#     3811    1.1251950e+14   4.377688e-04   4.130497e+08     45s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.458880e+09, 17896 iterations, 4.25 seconds (2.39 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.4589e+09    0    1          - 4.4589e+09      -     -   46s
# H    0     0                    4.458880e+09 4.4589e+09  0.00%     -   48s
#      0     0 4.4589e+09    0    1 4.4589e+09 4.4589e+09  0.00%     -   48s
#
# Explored 1 nodes (17896 simplex iterations) in 48.92 seconds (67.62 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.45888e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.458879792117e+09, best bound 4.458879792117e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 11998226.30 kW
# Wind Capacity: 38.76 kW
# Battery Capacity: 6588917.32 kWh
# Total NPC: $4458879792.12
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 5510472757.83 kWh
# Total Energy Generated: 7490220411.91 kWh
# Total Energy Used (along with efficiency losses): 1979747654.08 kWh
# Utilization Percentage: 26.43%
# $10424705.68 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 11998226.30 kW
# Solar Initial Cost:    $1115235134.53
# Wind Initial Capacity: 38.76 kW
# Wind Initial Cost:     $198232357.20
# Battery Initial Capacity: 6588917.32 kWh
# Battery Initial Cost:  $2358832401.61
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -38394.32 kW
# Solar Redundant Cost:    $-3568752.43
# Wind Redundant Capacity: 3.42 kW
# Wind Redundant Cost:     $17499952.49
# Battery Redundant Capacity: 24378.99 kWh
# Battery Redundant Cost:  $8727679.89
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $1111666382.10
# Solar OPEX:         $1214233932.62
# Solar Replacement:  $0.00
# Solar Salvage:     -$323165218.59
# Wind CAPEX:         $215732309.70
# Wind OPEX:          $46174438.09
# Wind Replacement:   $0.00
# Wind Salvage:      -$39196325.08
# Battery CAPEX:      $2367560081.50
# Battery OPEX:       $713268737.18
# Battery Replacement:$132453469.48
# Battery Salvage:   -$860322264.38
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $4591333261.60
#
# === 2024 Solar Results 100% met (Load Factor 0.55) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.2087     0.000009
# discharge         17           38 0.2998     0.000017
# discharge         41           62 0.3015     0.000017
# discharge         65           87 0.3484     0.000022
# discharge         92          111 0.3414     0.000021
# discharge        115          134 0.2527     0.000012
# discharge        136          158 0.3152     0.000018
# discharge        161          182 0.3338     0.000020
# discharge        186          207 0.3444     0.000021
# discharge        215          230 0.2386     0.000011
# discharge        234          254 0.2269     0.000010
# discharge        257          278 0.3148     0.000018
# discharge        281          302 0.2959     0.000016
# discharge        305          327 0.3456     0.000021
# discharge        333          350 0.2522     0.000012
# discharge        352          374 0.2819     0.000015
# discharge        377          398 0.2281     0.000010
# discharge        402          422 0.2605     0.000013
# discharge        424          446 0.3135     0.000018
# discharge        449          470 0.2542     0.000012
# discharge        472          494 0.2464     0.000012
# discharge        496          518 0.3135     0.000018
# discharge        520          542 0.1745     0.000006
# discharge        544          566 0.1947     0.000008
# discharge        568          590 0.2776     0.000015
# discharge        592          614 0.2382     0.000011
# discharge        616          638 0.2892     0.000016
# discharge        640          662 0.3110     0.000018
# discharge        664          686 0.2977     0.000016
# discharge        688          710 0.2881     0.000016
# discharge        715          734 0.2141     0.000009
# discharge        736          758 0.2013     0.000008
# discharge        760          782 0.2547     0.000012
# discharge        784          806 0.2818     0.000015
# discharge        809          830 0.2929     0.000016
# discharge        832          854 0.2854     0.000015
# discharge        856          877 0.1932     0.000008
# discharge        880          901 0.1901     0.000007
# discharge        904          926 0.2944     0.000016
# discharge        928          949 0.2463     0.000012
# discharge        952          973 0.2478     0.000012
# discharge        976          998 0.3013     0.000017
# discharge       1003         1022 0.2528     0.000012
# discharge       1025         1045 0.1914     0.000007
# discharge       1048         1069 0.1858     0.000007
# discharge       1072         1093 0.1944     0.000008
# discharge       1096         1117 0.2170     0.000009
# discharge       1120         1142 0.2614     0.000013
# discharge       1144         1166 0.2495     0.000012
# discharge       1169         1189 0.2832     0.000015
# discharge       1192         1213 0.2800     0.000015
# discharge       1216         1237 0.2926     0.000016
# discharge       1240         1261 0.1844     0.000007
# discharge       1264         1285 0.2175     0.000009
# discharge       1288         1310 0.2527     0.000012
# discharge       1314         1333 0.2486     0.000012
# discharge       1336         1357 0.2665     0.000013
# discharge       1360         1381 0.2424     0.000011
# discharge       1384         1405 0.1746     0.000006
# discharge       1408         1429 0.2104     0.000009
# discharge       1433         1453 0.2063     0.000009
# discharge       1455         1477 0.2938     0.000016
# discharge       1480         1501 0.2910     0.000016
# discharge       1504         1525 0.1969     0.000008
# discharge       1528         1549 0.1969     0.000008
# discharge       1552         1573 0.2591     0.000013
# discharge       1576         1597 0.2701     0.000014
# discharge       1601         1621 0.2585     0.000013
# discharge       1625         1645 0.2118     0.000009
# discharge       1649         1669 0.1696     0.000006
# discharge       1672         1693 0.1944     0.000008
# discharge       1695         1717 0.2368     0.000011
# discharge       1720         1741 0.2724     0.000014
# discharge       1744         1765 0.2145     0.000009
# discharge       1769         1789 0.2606     0.000013
# discharge       1792         1813 0.2692     0.000014
# discharge       1816         1837 0.2325     0.000011
# discharge       1840         1862 0.2997     0.000017
# discharge       1866         1885 0.2617     0.000013
# discharge       1890         1909 0.2489     0.000012
# discharge       1912         1933 0.1837     0.000007
# discharge       1935         1957 0.2672     0.000014
# discharge       1960         1981 0.2354     0.000011
# discharge       1984         2005 0.2511     0.000012
# discharge       2008         2029 0.2829     0.000015
# discharge       2032         2053 0.2233     0.000010
# discharge       2055         2077 0.2497     0.000012
# discharge       2080         2101 0.2211     0.000010
# discharge       2105         2125 0.2137     0.000009
# discharge       2128         2149 0.2704     0.000014
# discharge       2152         2173 0.2728     0.000014
# discharge       2176         2197 0.2305     0.000010
# discharge       2199         2221 0.1491     0.000005
# discharge       2223         2245 0.1828     0.000007
# discharge       2247         2269 0.2401     0.000011
# discharge       2271         2293 0.2506     0.000012
# discharge       2295         2317 0.2422     0.000011
# discharge       2320         2341 0.2306     0.000010
# discharge       2344         2365 0.2667     0.000014
# discharge       2368         2389 0.2414     0.000011
# discharge       2392         2413 0.2710     0.000014
# discharge       2416         2437 0.2184     0.000009
# discharge       2440         2461 0.1897     0.000007
# discharge       2463         2485 0.2147     0.000009
# discharge       2487         2509 0.2599     0.000013
# discharge       2512         2533 0.2670     0.000014
# discharge       2536         2557 0.2337     0.000011
# discharge       2559         2581 0.1570     0.000005
# discharge       2583         2605 0.1609     0.000005
# discharge       2607         2629 0.2555     0.000013
# discharge       2631         2653 0.2597     0.000013
# discharge       2656         2677 0.2161     0.000009
# discharge       2679         2701 0.2377     0.000011
# discharge       2704         2725 0.2485     0.000012
# discharge       2728         2749 0.1768     0.000006
# discharge       2751         2773 0.2048     0.000008
# discharge       2775         2797 0.2467     0.000012
# discharge       2800         2820 0.2228     0.000010
# discharge       2823         2844 0.2379     0.000011
# discharge       2847         2869 0.2558     0.000013
# discharge       2872         2893 0.1970     0.000008
# discharge       2895         2917 0.1919     0.000008
# discharge       2919         2941 0.2157     0.000009
# discharge       2943         2964 0.2053     0.000008
# discharge       2967         2988 0.2284     0.000010
# discharge       2992         3012 0.2053     0.000008
# discharge       3015         3036 0.1964     0.000008
# discharge       3039         3060 0.2050     0.000008
# discharge       3063         3084 0.1768     0.000006
# discharge       3087         3108 0.1948     0.000008
# discharge       3111         3132 0.1940     0.000008
# discharge       3135         3156 0.2483     0.000012
# discharge       3159         3180 0.2026     0.000008
# discharge       3183         3204 0.2066     0.000009
# discharge       3207         3228 0.2309     0.000010
# discharge       3231         3252 0.2304     0.000010
# discharge       3256         3276 0.2431     0.000011
# discharge       3279         3300 0.2352     0.000011
# discharge       3304         3324 0.2429     0.000011
# discharge       3328         3348 0.2282     0.000010
# discharge       3351         3372 0.2486     0.000012
# discharge       3376         3396 0.2268     0.000010
# discharge       3399         3420 0.2198     0.000010
# discharge       3423         3444 0.1808     0.000007
# discharge       3447         3468 0.1930     0.000008
# discharge       3471         3492 0.2001     0.000008
# discharge       3495         3516 0.2043     0.000008
# discharge       3519         3540 0.2273     0.000010
# discharge       3543         3564 0.2097     0.000009
# discharge       3567         3588 0.2086     0.000009
# discharge       3591         3612 0.2052     0.000008
# discharge       3615         3636 0.2167     0.000009
# discharge       3639         3660 0.2006     0.000008
# discharge       3663         3684 0.2143     0.000009
# discharge       3687         3708 0.2408     0.000011
# discharge       3711         3732 0.2421     0.000011
# discharge       3735         3756 0.2077     0.000009
# discharge       3759         3781 0.2167     0.000009
# discharge       3784         3804 0.2485     0.000012
# discharge       3807         3828 0.2176     0.000009
# discharge       3832         3853 0.2330     0.000011
# discharge       3856         3876 0.2418     0.000011
# discharge       3880         3900 0.2065     0.000009
# discharge       3903         3924 0.2381     0.000011
# discharge       3927         3948 0.2309     0.000010
# discharge       3951         3972 0.2365     0.000011
# discharge       3976         3996 0.1957     0.000008
# discharge       3999         4020 0.2440     0.000012
# discharge       4023         4044 0.1968     0.000008
# discharge       4047         4068 0.1565     0.000005
# discharge       4071         4092 0.1540     0.000005
# discharge       4095         4116 0.1869     0.000007
# discharge       4119         4140 0.2106     0.000009
# discharge       4143         4164 0.1602     0.000005
# discharge       4167         4188 0.2418     0.000011
# discharge       4191         4212 0.2016     0.000008
# discharge       4215         4236 0.1961     0.000008
# discharge       4239         4260 0.1826     0.000007
# discharge       4263         4284 0.1887     0.000007
# discharge       4287         4308 0.2352     0.000011
# discharge       4311         4332 0.2406     0.000011
# discharge       4336         4356 0.2435     0.000011
# discharge       4360         4380 0.2394     0.000011
# discharge       4384         4404 0.2181     0.000009
# discharge       4407         4428 0.1809     0.000007
# discharge       4431         4452 0.2101     0.000009
# discharge       4455         4476 0.2013     0.000008
# discharge       4479         4500 0.2038     0.000008
# discharge       4503         4524 0.2133     0.000009
# discharge       4527         4548 0.2288     0.000010
# discharge       4551         4572 0.2133     0.000009
# discharge       4575         4596 0.2104     0.000009
# discharge       4599         4620 0.1919     0.000007
# discharge       4623         4644 0.1914     0.000007
# discharge       4647         4668 0.2016     0.000008
# discharge       4671         4692 0.2289     0.000010
# discharge       4695         4716 0.2429     0.000011
# discharge       4720         4740 0.1887     0.000007
# discharge       4743         4764 0.2034     0.000008
# discharge       4767         4788 0.2081     0.000009
# discharge       4791         4812 0.2135     0.000009
# discharge       4815         4836 0.2332     0.000011
# discharge       4840         4860 0.2460     0.000012
# discharge       4864         4884 0.2163     0.000009
# discharge       4887         4908 0.2237     0.000010
# discharge       4912         4932 0.2144     0.000009
# discharge       4935         4956 0.2173     0.000009
# discharge       4960         4980 0.1967     0.000008
# discharge       4983         5004 0.1969     0.000008
# discharge       5007         5028 0.2252     0.000010
# discharge       5032         5052 0.2422     0.000011
# discharge       5056         5077 0.2403     0.000011
# discharge       5080         5100 0.2512     0.000012
# discharge       5104         5125 0.2576     0.000013
# discharge       5128         5148 0.2450     0.000012
# discharge       5152         5173 0.2337     0.000011
# discharge       5176         5197 0.2500     0.000012
# discharge       5200         5221 0.2237     0.000010
# discharge       5223         5245 0.1935     0.000008
# discharge       5247         5269 0.1769     0.000006
# discharge       5271         5293 0.1917     0.000007
# discharge       5297         5317 0.2190     0.000010
# discharge       5320         5341 0.2561     0.000013
# discharge       5344         5365 0.2404     0.000011
# discharge       5368         5389 0.2507     0.000012
# discharge       5392         5413 0.2547     0.000012
# discharge       5416         5437 0.2551     0.000012
# discharge       5440         5461 0.2574     0.000013
# discharge       5464         5485 0.2591     0.000013
# discharge       5488         5509 0.2314     0.000010
# discharge       5512         5533 0.2555     0.000013
# discharge       5536         5557 0.2752     0.000014
# discharge       5562         5581 0.1614     0.000005
# discharge       5583         5605 0.2616     0.000013
# discharge       5608         5629 0.2568     0.000013
# discharge       5632         5653 0.2644     0.000013
# discharge       5656         5677 0.2670     0.000014
# discharge       5680         5701 0.2611     0.000013
# discharge       5704         5725 0.2387     0.000011
# discharge       5728         5749 0.2400     0.000011
# discharge       5752         5773 0.2597     0.000013
# discharge       5776         5797 0.2544     0.000012
# discharge       5800         5821 0.2220     0.000010
# discharge       5824         5845 0.2163     0.000009
# discharge       5849         5869 0.2539     0.000012
# discharge       5872         5893 0.2717     0.000014
# discharge       5896         5917 0.2193     0.000010
# discharge       5919         5941 0.2687     0.000014
# discharge       5944         5965 0.2647     0.000013
# discharge       5968         5989 0.2633     0.000013
# discharge       5992         6013 0.2519     0.000012
# discharge       6016         6037 0.2700     0.000014
# discharge       6040         6061 0.2471     0.000012
# discharge       6065         6085 0.2824     0.000015
# discharge       6088         6109 0.2731     0.000014
# discharge       6112         6133 0.2804     0.000015
# discharge       6136         6157 0.2638     0.000013
# discharge       6160         6181 0.2549     0.000012
# discharge       6184         6205 0.2600     0.000013
# discharge       6208         6229 0.2753     0.000014
# discharge       6232         6253 0.2728     0.000014
# discharge       6256         6277 0.2645     0.000013
# discharge       6280         6301 0.2700     0.000014
# discharge       6304         6325 0.2366     0.000011
# discharge       6328         6349 0.2178     0.000009
# discharge       6352         6373 0.2777     0.000015
# discharge       6376         6397 0.2798     0.000015
# discharge       6400         6421 0.2831     0.000015
# discharge       6424         6445 0.2825     0.000015
# discharge       6448         6469 0.2823     0.000015
# discharge       6472         6493 0.2859     0.000015
# discharge       6496         6517 0.2661     0.000013
# discharge       6520         6542 0.2029     0.000008
# discharge       6545         6565 0.2480     0.000012
# discharge       6568         6589 0.2887     0.000016
# discharge       6592         6613 0.2879     0.000016
# discharge       6616         6637 0.2571     0.000013
# discharge       6640         6661 0.2339     0.000011
# discharge       6664         6685 0.2206     0.000010
# discharge       6688         6709 0.2369     0.000011
# discharge       6712         6733 0.2869     0.000015
# discharge       6736         6757 0.2908     0.000016
# discharge       6760         6781 0.2429     0.000011
# discharge       6784         6805 0.1922     0.000008
# discharge       6808         6829 0.2269     0.000010
# discharge       6832         6853 0.2516     0.000012
# discharge       6856         6877 0.2947     0.000016
# discharge       6880         6901 0.2855     0.000015
# discharge       6904         6925 0.2801     0.000015
# discharge       6928         6949 0.2863     0.000015
# discharge       6952         6973 0.2685     0.000014
# discharge       6976         6997 0.2505     0.000012
# discharge       7000         7021 0.2874     0.000015
# discharge       7024         7045 0.2892     0.000016
# discharge       7048         7069 0.2794     0.000015
# discharge       7072         7093 0.2179     0.000009
# discharge       7096         7117 0.2844     0.000015
# discharge       7120         7141 0.2687     0.000014
# discharge       7144         7165 0.2145     0.000009
# discharge       7168         7189 0.2914     0.000016
# discharge       7192         7213 0.2881     0.000016
# discharge       7216         7237 0.1852     0.000007
# discharge       7240         7261 0.1871     0.000007
# discharge       7264         7285 0.2199     0.000010
# discharge       7288         7309 0.2531     0.000012
# discharge       7312         7333 0.2892     0.000016
# discharge       7336         7357 0.2903     0.000016
# discharge       7360         7382 0.2917     0.000016
# discharge       7384         7406 0.2976     0.000016
# discharge       7408         7429 0.2567     0.000013
# discharge       7432         7454 0.2128     0.000009
# discharge       7456         7478 0.1953     0.000008
# discharge       7480         7502 0.1801     0.000007
# discharge       7504         7526 0.2594     0.000013
# discharge       7528         7550 0.2874     0.000015
# discharge       7552         7574 0.2734     0.000014
# discharge       7576         7598 0.3073     0.000017
# discharge       7601         7622 0.3242     0.000019
# discharge       7625         7646 0.3102     0.000018
# discharge       7649         7670 0.3260     0.000019
# discharge       7673         7694 0.3097     0.000018
# discharge       7697         7718 0.3077     0.000017
# discharge       7721         7742 0.2225     0.000010
# discharge       7744         7766 0.1828     0.000007
# discharge       7768         7790 0.2015     0.000008
# discharge       7792         7814 0.2960     0.000016
# discharge       7817         7839 0.3165     0.000018
# discharge       7844         7862 0.2881     0.000016
# discharge       7865         7886 0.2795     0.000015
# discharge       7888         7910 0.2309     0.000010
# discharge       7912         7934 0.2206     0.000010
# discharge       7936         7958 0.2331     0.000011
# discharge       7961         7982 0.2879     0.000016
# discharge       7986         8006 0.3143     0.000018
# discharge       8009         8030 0.3287     0.000020
# discharge       8033         8054 0.3080     0.000017
# discharge       8057         8078 0.3207     0.000019
# discharge       8081         8102 0.3254     0.000019
# discharge       8106         8126 0.2747     0.000014
# discharge       8129         8150 0.2845     0.000015
# discharge       8153         8174 0.2391     0.000011
# discharge       8179         8198 0.2852     0.000015
# discharge       8201         8222 0.2332     0.000011
# discharge       8224         8246 0.2626     0.000013
# discharge       8248         8270 0.3172     0.000018
# discharge       8273         8294 0.3248     0.000019
# discharge       8297         8318 0.2750     0.000014
# discharge       8321         8342 0.2742     0.000014
# discharge       8345         8366 0.3146     0.000018
# discharge       8369         8390 0.2671     0.000014
# discharge       8393         8414 0.2850     0.000015
# discharge       8417         8438 0.2894     0.000016
# discharge       8442         8462 0.3274     0.000020
# discharge       8466         8486 0.3334     0.000020
# discharge       8490         8511 0.3439     0.000021
# discharge       8515         8535 0.3438     0.000021
# discharge       8539         8558 0.3502     0.000022
# discharge       8561         8582 0.2953     0.000016
# discharge       8585         8606 0.3253     0.000019
# discharge       8609         8630 0.3062     0.000017
# discharge       8633         8654 0.3225     0.000019
# discharge       8657         8678 0.3294     0.000020
# discharge       8682         8702 0.2976     0.000016
# discharge       8705         8726 0.3354     0.000020
# discharge       8729         8750 0.3166     0.000018
#
# Total Estimated Degradation: 0.004384
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1980.png
#
# === Unmet Load Across Years 100% met (Load Factor 0.55) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 0.00 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 0.00 kWh (Year 2024)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 55% reduction (Case 1) in LP for 100% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (1).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (1).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023"
dispatch_load_factor = 0.71  # Apply 0.71 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.71)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Load Factor 0.71) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.71)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.71) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890649 nonzeros
# Model fingerprint: 0x28bf85b9
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 13s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.08s
# Presolved: 70077 rows, 35042 columns, 161798 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153033 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   1.497809e+06   7.602528e+06     41s
#     2718    9.8382695e+13   1.038814e-03   5.489758e+16     45s
#     4333    3.2147464e+13   3.140010e-03   2.723974e+15     50s
#     6061    7.8743799e+12   1.247745e-03   5.521839e+12     55s
#     7446    2.2474333e+12   6.978910e-03   1.382859e+08     61s
#     8764    9.4463668e+11   6.670693e-04   6.434681e+14     65s
#    11699   -3.1534328e+33   4.619852e+32   3.153433e+03     70s
#    17863    1.6006282e+09   1.532986e+09   0.000000e+00     75s
#    26755    2.2254851e+09   1.681499e+11   0.000000e+00     80s
#    31497    2.7198362e+09   1.483668e+08   0.000000e+00     85s
#    33154    2.8750634e+09   0.000000e+00   0.000000e+00     87s
#    33154    2.8750634e+09   0.000000e+00   0.000000e+00     87s
# Concurrent spin time: 11.28s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 2.875063e+09, 33154 iterations, 57.98 seconds (45.93 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.8751e+09    0   35          - 2.8751e+09      -     -   98s
# H    0     0                    3.926692e+09 2.8751e+09  26.8%     -  107s
# H    0     0                    3.766989e+09 2.8751e+09  23.7%     -  113s
# H    0     0                    3.513190e+09 2.8751e+09  18.2%     -  123s
#      0     2 2.8751e+09    0   35 3.5132e+09 2.8751e+09  18.2%     -  123s
#      3     8 2.8751e+09    2   35 3.5132e+09 2.8751e+09  18.2%   5.0  131s
#     87   176 2.8751e+09   10   34 3.5132e+09 2.8751e+09  18.2%   5.6  136s
#    179   250 2.8751e+09   16   28 3.5132e+09 2.8751e+09  18.2%   8.7  149s
# H  237   250                    3.267067e+09 2.8751e+09  12.0%  11.1  149s
#    265   332 2.8751e+09   20   28 3.2671e+09 2.8751e+09  12.0%  13.4  157s
#    349   545 2.8751e+09   26   27 3.2671e+09 2.8751e+09  12.0%  45.5  185s
#    576   737 2.8751e+09   40   25 3.2671e+09 2.8751e+09  12.0%  50.4  244s
# H  600   737                    3.164899e+09 2.8751e+09  9.16%  50.4  244s
# H  625   737                    2.905567e+09 2.8751e+09  1.05%  48.6  244s
#    776  1030 2.8751e+09   54   26 2.9056e+09 2.8751e+09  1.05%  49.3  309s
# H  800   954                    2.899606e+09 2.8751e+09  0.85%  48.3  309s
#
# Explored 1105 nodes (86561 simplex iterations) in 310.34 seconds (310.62 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 2.89961e+09 2.90557e+09 3.1649e+09 ... 3.92669e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.899605835401e+09, best bound 2.875063420351e+09, gap 0.8464%
# Optimal Solution Found!
# Solar Capacity: 8409652.85 kW
# Wind Capacity: 9.55 kW
# Battery Capacity: 4237589.85 kWh
# Total NPC: $2899605835.40
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3034994926.79 kWh
# Total Energy Generated: 5187067126.47 kWh
# Total Energy Used (along with efficiency losses): 2152072199.67 kWh
# Utilization Percentage: 41.49%
# $29997914.09 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 8409652.85 kW
# Solar Initial Cost:    $781677232.33
# Wind Initial Capacity: 9.55 kW
# Wind Initial Cost:     $48822017.47
# Battery Initial Capacity: 4237589.85 kWh
# Battery Initial Cost:  $1517057165.09
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -26910.89 kW
# Solar Redundant Cost:    $-2501367.14
# Wind Redundant Capacity: 0.84 kW
# Wind Redundant Cost:     $4310007.70
# Battery Redundant Capacity: 15679.08 kWh
# Battery Redundant Cost:  $5613111.51
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $779175865.19
# Solar OPEX:         $851066282.31
# Solar Replacement:  $0.00
# Solar Salvage:     -$226509088.38
# Wind CAPEX:         $53132025.17
# Wind OPEX:          $11372155.66
# Wind Replacement:   $0.00
# Wind Salvage:      -$9653538.37
# Battery CAPEX:      $1522670276.60
# Battery OPEX:       $458730958.43
# Battery Replacement:$381145321.56
# Battery Salvage:   -$553306820.18
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3280751156.97
#
# === 2024 Solar Results 99% met (Load Factor 0.71) ===
# Total Unmet Load: 1590144.29 kWh
# Hours with Unmet Load: [227, 228, 229, 230, 250, 251, 252, 253, 254, 348, 349, 350, 8556, 8557, 8558]
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.5887     0.000056
# discharge         18           38 0.6587     0.000068
# discharge         42           62 0.6604     0.000069
# discharge         66           88 0.7226     0.000080
# discharge         95          111 0.7031     0.000077
# discharge        119          134 0.6388     0.000065
# discharge        138          158 0.6625     0.000069
# discharge        162          183 0.7066     0.000077
# discharge        187          208 0.7171     0.000079
# discharge        214          230 0.5301     0.000046
# discharge        238          254 0.5042     0.000042
# discharge        259          278 0.6621     0.000069
# discharge        282          302 0.6605     0.000069
# discharge        306          327 0.7050     0.000077
# discharge        333          350 0.5952     0.000057
# discharge        358          374 0.6584     0.000068
# discharge        379          398 0.6245     0.000062
# discharge        405          422 0.6399     0.000065
# discharge        426          446 0.6502     0.000067
# discharge        450          470 0.6413     0.000065
# discharge        474          494 0.6158     0.000060
# discharge        497          518 0.6354     0.000064
# discharge        521          542 0.5762     0.000054
# discharge        545          566 0.5818     0.000055
# discharge        569          590 0.6138     0.000060
# discharge        593          614 0.5994     0.000058
# discharge        617          638 0.6238     0.000062
# discharge        641          662 0.6375     0.000064
# discharge        665          686 0.6266     0.000062
# discharge        689          710 0.6336     0.000064
# discharge        718          734 0.6133     0.000060
# discharge        737          758 0.5791     0.000054
# discharge        761          782 0.6010     0.000058
# discharge        785          806 0.6304     0.000063
# discharge        811          830 0.6364     0.000064
# discharge        833          854 0.6187     0.000061
# discharge        857          878 0.5723     0.000053
# discharge        881          902 0.5739     0.000053
# discharge        905          926 0.6180     0.000061
# discharge        929          950 0.5873     0.000056
# discharge        953          974 0.5853     0.000055
# discharge        977          999 0.6372     0.000064
# discharge       1004         1022 0.6059     0.000059
# discharge       1026         1046 0.5826     0.000055
# discharge       1049         1070 0.5729     0.000053
# discharge       1073         1094 0.5803     0.000054
# discharge       1097         1117 0.5584     0.000051
# discharge       1121         1142 0.6053     0.000059
# discharge       1146         1166 0.6213     0.000061
# discharge       1170         1190 0.5900     0.000056
# discharge       1193         1213 0.5830     0.000055
# discharge       1217         1238 0.5902     0.000056
# discharge       1241         1262 0.5896     0.000056
# discharge       1265         1286 0.5850     0.000055
# discharge       1290         1310 0.6235     0.000062
# discharge       1316         1334 0.6032     0.000058
# discharge       1338         1357 0.6014     0.000058
# discharge       1361         1381 0.5739     0.000053
# discharge       1385         1406 0.5514     0.000050
# discharge       1409         1430 0.5761     0.000054
# discharge       1436         1453 0.5570     0.000051
# discharge       1457         1477 0.5906     0.000056
# discharge       1481         1502 0.5959     0.000057
# discharge       1506         1525 0.5540     0.000050
# discharge       1529         1550 0.5574     0.000051
# discharge       1554         1574 0.5840     0.000055
# discharge       1577         1597 0.5831     0.000055
# discharge       1603         1621 0.5766     0.000054
# discharge       1626         1646 0.5808     0.000054
# discharge       1650         1670 0.5671     0.000052
# discharge       1674         1693 0.5504     0.000049
# discharge       1697         1717 0.5670     0.000052
# discharge       1721         1741 0.5809     0.000054
# discharge       1749         1766 0.5820     0.000055
# discharge       1770         1789 0.5956     0.000057
# discharge       1793         1813 0.5777     0.000054
# discharge       1817         1837 0.5635     0.000052
# discharge       1841         1862 0.6195     0.000061
# discharge       1868         1886 0.5978     0.000057
# discharge       1893         1910 0.5889     0.000056
# discharge       1914         1933 0.5470     0.000049
# discharge       1937         1957 0.5791     0.000054
# discharge       1961         1981 0.5638     0.000052
# discharge       1985         2005 0.5679     0.000052
# discharge       2009         2029 0.5816     0.000055
# discharge       2033         2053 0.5557     0.000050
# discharge       2057         2077 0.5619     0.000051
# discharge       2081         2102 0.5641     0.000052
# discharge       2106         2125 0.5525     0.000050
# discharge       2130         2149 0.5766     0.000054
# discharge       2153         2173 0.5722     0.000053
# discharge       2177         2197 0.5557     0.000050
# discharge       2201         2221 0.5204     0.000045
# discharge       2225         2245 0.5332     0.000047
# discharge       2249         2269 0.5535     0.000050
# discharge       2273         2293 0.5598     0.000051
# discharge       2297         2317 0.5529     0.000050
# discharge       2322         2341 0.5487     0.000049
# discharge       2345         2365 0.5718     0.000053
# discharge       2369         2389 0.5558     0.000050
# discharge       2393         2413 0.5669     0.000052
# discharge       2417         2437 0.5345     0.000047
# discharge       2442         2461 0.5277     0.000046
# discharge       2465         2485 0.5387     0.000048
# discharge       2489         2509 0.5573     0.000051
# discharge       2513         2533 0.5570     0.000051
# discharge       2537         2557 0.5498     0.000049
# discharge       2561         2581 0.5093     0.000043
# discharge       2584         2605 0.5206     0.000045
# discharge       2608         2629 0.5489     0.000049
# discharge       2633         2653 0.5469     0.000049
# discharge       2657         2677 0.5296     0.000046
# discharge       2681         2701 0.5391     0.000048
# discharge       2705         2725 0.5381     0.000047
# discharge       2729         2749 0.5106     0.000043
# discharge       2752         2773 0.5219     0.000045
# discharge       2777         2797 0.5361     0.000047
# discharge       2801         2821 0.5268     0.000046
# discharge       2825         2845 0.5320     0.000047
# discharge       2849         2869 0.5370     0.000047
# discharge       2873         2893 0.5096     0.000043
# discharge       2897         2917 0.5098     0.000043
# discharge       2921         2941 0.5164     0.000044
# discharge       2945         2965 0.5107     0.000043
# discharge       2968         2989 0.5186     0.000044
# discharge       2993         3013 0.5133     0.000044
# discharge       3017         3037 0.5079     0.000043
# discharge       3041         3061 0.5118     0.000043
# discharge       3065         3085 0.4973     0.000041
# discharge       3088         3109 0.5130     0.000044
# discharge       3113         3133 0.5038     0.000042
# discharge       3137         3157 0.5232     0.000045
# discharge       3161         3181 0.5065     0.000043
# discharge       3185         3205 0.5058     0.000043
# discharge       3209         3229 0.5164     0.000044
# discharge       3233         3253 0.5171     0.000044
# discharge       3257         3277 0.5357     0.000047
# discharge       3281         3301 0.5166     0.000044
# discharge       3305         3325 0.5192     0.000045
# discharge       3329         3349 0.5083     0.000043
# discharge       3353         3373 0.5175     0.000044
# discharge       3377         3397 0.5135     0.000044
# discharge       3401         3421 0.5106     0.000043
# discharge       3425         3445 0.4924     0.000041
# discharge       3449         3469 0.4940     0.000041
# discharge       3473         3493 0.5022     0.000042
# discharge       3497         3517 0.5028     0.000042
# discharge       3521         3541 0.5146     0.000044
# discharge       3545         3565 0.5051     0.000042
# discharge       3569         3589 0.4996     0.000042
# discharge       3593         3613 0.5010     0.000042
# discharge       3617         3637 0.5034     0.000042
# discharge       3641         3661 0.4982     0.000041
# discharge       3665         3685 0.5054     0.000042
# discharge       3689         3709 0.5155     0.000044
# discharge       3713         3733 0.5144     0.000044
# discharge       3737         3757 0.5017     0.000042
# discharge       3761         3781 0.5181     0.000044
# discharge       3786         3805 0.5146     0.000044
# discharge       3809         3829 0.4973     0.000041
# discharge       3833         3853 0.5238     0.000045
# discharge       3857         3877 0.5366     0.000047
# discharge       3881         3901 0.4888     0.000040
# discharge       3905         3925 0.5081     0.000043
# discharge       3929         3949 0.5079     0.000043
# discharge       3953         3973 0.5066     0.000043
# discharge       3977         3997 0.4858     0.000040
# discharge       4001         4021 0.5100     0.000043
# discharge       4025         4045 0.4964     0.000041
# discharge       4049         4069 0.4803     0.000039
# discharge       4072         4093 0.4890     0.000040
# discharge       4096         4117 0.4966     0.000041
# discharge       4121         4141 0.4959     0.000041
# discharge       4145         4165 0.4808     0.000039
# discharge       4168         4189 0.5166     0.000044
# discharge       4193         4213 0.5015     0.000042
# discharge       4217         4237 0.4971     0.000041
# discharge       4241         4261 0.4925     0.000041
# discharge       4265         4285 0.4914     0.000040
# discharge       4289         4309 0.5070     0.000043
# discharge       4313         4333 0.5109     0.000043
# discharge       4337         4357 0.5146     0.000044
# discharge       4361         4381 0.5118     0.000043
# discharge       4385         4405 0.5058     0.000043
# discharge       4409         4429 0.4960     0.000041
# discharge       4433         4453 0.5086     0.000043
# discharge       4457         4477 0.5006     0.000042
# discharge       4481         4501 0.5050     0.000042
# discharge       4505         4525 0.5111     0.000043
# discharge       4529         4549 0.5169     0.000044
# discharge       4553         4573 0.5084     0.000043
# discharge       4577         4597 0.5027     0.000042
# discharge       4601         4621 0.4999     0.000042
# discharge       4625         4645 0.4972     0.000041
# discharge       4649         4669 0.5070     0.000043
# discharge       4673         4693 0.5167     0.000044
# discharge       4697         4717 0.5203     0.000045
# discharge       4721         4741 0.4975     0.000041
# discharge       4745         4765 0.5035     0.000042
# discharge       4769         4789 0.5076     0.000043
# discharge       4793         4813 0.5116     0.000043
# discharge       4817         4837 0.5182     0.000044
# discharge       4841         4861 0.5236     0.000045
# discharge       4865         4885 0.5080     0.000043
# discharge       4889         4909 0.5111     0.000043
# discharge       4913         4933 0.5121     0.000043
# discharge       4937         4957 0.5129     0.000044
# discharge       4961         4981 0.5065     0.000043
# discharge       4985         5005 0.5071     0.000043
# discharge       5009         5029 0.5139     0.000044
# discharge       5033         5053 0.5354     0.000047
# discharge       5057         5077 0.5576     0.000051
# discharge       5082         5101 0.5233     0.000045
# discharge       5105         5125 0.5360     0.000047
# discharge       5129         5149 0.5250     0.000045
# discharge       5153         5173 0.5233     0.000045
# discharge       5177         5197 0.5308     0.000046
# discharge       5201         5221 0.5225     0.000045
# discharge       5225         5245 0.5133     0.000044
# discharge       5249         5269 0.5064     0.000043
# discharge       5273         5294 0.5282     0.000046
# discharge       5299         5317 0.5193     0.000045
# discharge       5321         5341 0.5341     0.000047
# discharge       5345         5365 0.5254     0.000046
# discharge       5369         5389 0.5331     0.000047
# discharge       5393         5413 0.5340     0.000047
# discharge       5417         5437 0.5344     0.000047
# discharge       5441         5461 0.5350     0.000047
# discharge       5465         5485 0.5418     0.000048
# discharge       5490         5509 0.5308     0.000046
# discharge       5513         5533 0.5453     0.000049
# discharge       5537         5557 0.5788     0.000054
# discharge       5565         5581 0.5280     0.000046
# discharge       5585         5605 0.5438     0.000048
# discharge       5609         5629 0.5475     0.000049
# discharge       5633         5653 0.5513     0.000050
# discharge       5657         5677 0.5611     0.000051
# discharge       5681         5701 0.5537     0.000050
# discharge       5705         5725 0.5442     0.000048
# discharge       5729         5749 0.5461     0.000049
# discharge       5753         5773 0.5551     0.000050
# discharge       5777         5797 0.5541     0.000050
# discharge       5801         5821 0.5411     0.000048
# discharge       5825         5846 0.5586     0.000051
# discharge       5851         5869 0.5614     0.000051
# discharge       5873         5893 0.5709     0.000053
# discharge       5897         5917 0.5455     0.000049
# discharge       5921         5941 0.5648     0.000052
# discharge       5945         5965 0.5666     0.000052
# discharge       5969         5989 0.5666     0.000052
# discharge       5993         6013 0.5634     0.000052
# discharge       6017         6037 0.5740     0.000053
# discharge       6041         6062 0.5831     0.000055
# discharge       6067         6085 0.5836     0.000055
# discharge       6089         6109 0.5744     0.000053
# discharge       6113         6133 0.5764     0.000054
# discharge       6137         6157 0.5705     0.000053
# discharge       6161         6181 0.5706     0.000053
# discharge       6185         6205 0.5693     0.000053
# discharge       6209         6229 0.5759     0.000054
# discharge       6233         6253 0.5789     0.000054
# discharge       6257         6277 0.5737     0.000053
# discharge       6281         6301 0.5764     0.000054
# discharge       6305         6325 0.5641     0.000052
# discharge       6329         6349 0.5544     0.000050
# discharge       6353         6373 0.5842     0.000055
# discharge       6377         6397 0.5795     0.000054
# discharge       6401         6421 0.5820     0.000055
# discharge       6425         6445 0.5833     0.000055
# discharge       6449         6469 0.5818     0.000055
# discharge       6473         6493 0.5842     0.000055
# discharge       6497         6517 0.5751     0.000053
# discharge       6521         6542 0.5791     0.000054
# discharge       6550         6565 0.5855     0.000055
# discharge       6569         6590 0.5877     0.000056
# discharge       6593         6613 0.5865     0.000055
# discharge       6617         6637 0.5754     0.000054
# discharge       6641         6661 0.5649     0.000052
# discharge       6665         6685 0.5610     0.000051
# discharge       6689         6709 0.5665     0.000052
# discharge       6713         6733 0.5852     0.000055
# discharge       6737         6757 0.5874     0.000056
# discharge       6761         6781 0.5793     0.000054
# discharge       6785         6805 0.5503     0.000049
# discharge       6809         6829 0.5644     0.000052
# discharge       6833         6854 0.5829     0.000055
# discharge       6857         6877 0.6135     0.000060
# discharge       6881         6901 0.5860     0.000055
# discharge       6905         6925 0.5820     0.000055
# discharge       6929         6949 0.5858     0.000055
# discharge       6953         6974 0.5794     0.000054
# discharge       6977         6998 0.5753     0.000054
# discharge       7001         7022 0.5935     0.000057
# discharge       7025         7046 0.5952     0.000057
# discharge       7049         7070 0.5933     0.000057
# discharge       7073         7094 0.5709     0.000053
# discharge       7097         7118 0.5937     0.000057
# discharge       7121         7142 0.5894     0.000056
# discharge       7145         7166 0.5774     0.000054
# discharge       7169         7190 0.6060     0.000059
# discharge       7193         7214 0.6344     0.000064
# discharge       7218         7238 0.5508     0.000050
# discharge       7241         7262 0.5469     0.000049
# discharge       7265         7286 0.5623     0.000051
# discharge       7289         7310 0.5782     0.000054
# discharge       7313         7334 0.5998     0.000058
# discharge       7337         7358 0.6053     0.000059
# discharge       7361         7382 0.6111     0.000060
# discharge       7385         7406 0.6328     0.000063
# discharge       7410         7430 0.6101     0.000059
# discharge       7433         7454 0.5868     0.000055
# discharge       7458         7478 0.5732     0.000053
# discharge       7481         7502 0.5719     0.000053
# discharge       7505         7526 0.5980     0.000057
# discharge       7529         7550 0.6111     0.000060
# discharge       7553         7574 0.6067     0.000059
# discharge       7577         7598 0.6260     0.000062
# discharge       7602         7622 0.6612     0.000069
# discharge       7626         7646 0.6418     0.000065
# discharge       7651         7670 0.6662     0.000070
# discharge       7674         7694 0.6337     0.000064
# discharge       7698         7718 0.6308     0.000063
# discharge       7722         7742 0.6040     0.000058
# discharge       7746         7766 0.5774     0.000054
# discharge       7769         7790 0.5907     0.000056
# discharge       7793         7814 0.6312     0.000063
# discharge       7818         7839 0.6687     0.000070
# discharge       7845         7862 0.6406     0.000065
# discharge       7866         7886 0.6295     0.000063
# discharge       7890         7910 0.6132     0.000060
# discharge       7914         7934 0.6089     0.000059
# discharge       7938         7958 0.6138     0.000060
# discharge       7962         7983 0.6530     0.000067
# discharge       7988         8006 0.6548     0.000067
# discharge       8010         8030 0.6678     0.000070
# discharge       8034         8054 0.6517     0.000067
# discharge       8058         8078 0.6583     0.000068
# discharge       8082         8102 0.6634     0.000069
# discharge       8107         8126 0.6420     0.000065
# discharge       8130         8150 0.6455     0.000066
# discharge       8154         8175 0.6342     0.000064
# discharge       8181         8198 0.6513     0.000067
# discharge       8202         8222 0.6215     0.000061
# discharge       8226         8246 0.6363     0.000064
# discharge       8250         8270 0.6593     0.000068
# discharge       8274         8294 0.6669     0.000070
# discharge       8298         8318 0.6411     0.000065
# discharge       8322         8342 0.6443     0.000066
# discharge       8346         8366 0.6609     0.000069
# discharge       8370         8390 0.6420     0.000065
# discharge       8394         8414 0.6481     0.000066
# discharge       8418         8439 0.6547     0.000067
# discharge       8443         8462 0.6652     0.000069
# discharge       8469         8486 0.6716     0.000071
# discharge       8491         8511 0.7056     0.000077
# discharge       8518         8535 0.7267     0.000081
# discharge       8541         8558 0.6316     0.000063
# discharge       8563         8582 0.6530     0.000067
# discharge       8586         8606 0.6644     0.000069
# discharge       8610         8631 0.6604     0.000069
# discharge       8634         8654 0.6662     0.000070
# discharge       8660         8679 0.7083     0.000078
# discharge       8683         8702 0.6576     0.000068
# discharge       8707         8726 0.6745     0.000071
# discharge       8730         8750 0.6665     0.000070
#
# Total Estimated Degradation: 0.019320
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.71) ===
# Year 2024: Unmet Load = 1551759.72 kWh
# Year 2023: Unmet Load = 1590144.29 kWh
# Year 2022: Unmet Load = 1160709.08 kWh
# Year 2021: Unmet Load = 539208.55 kWh
# Year 2020: Unmet Load = 640175.62 kWh
# Year 2019: Unmet Load = 3841597.15 kWh
# Year 2018: Unmet Load = 728554.42 kWh
# Year 2017: Unmet Load = 1886582.23 kWh
# Year 2016: Unmet Load = 2304954.38 kWh
# Year 2015: Unmet Load = 3124581.62 kWh
# Year 2014: Unmet Load = 195317.60 kWh
# Year 2013: Unmet Load = 754954.09 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 85224.95 kWh
# Year 2010: Unmet Load = 7125884.69 kWh
# Year 2009: Unmet Load = 534790.77 kWh
# Year 2008: Unmet Load = 3819890.44 kWh
# Year 2007: Unmet Load = 843767.08 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 4941539.12 kWh
# Year 2004: Unmet Load = 38530.21 kWh
# Year 2003: Unmet Load = 1101473.46 kWh
# Year 2002: Unmet Load = 74399.85 kWh
# Year 2001: Unmet Load = 165145.16 kWh
# Year 2000: Unmet Load = 971868.26 kWh
# Year 1999: Unmet Load = 41639.36 kWh
# Year 1998: Unmet Load = 170105.77 kWh
# Year 1997: Unmet Load = 1610112.02 kWh
# Year 1996: Unmet Load = 315989.38 kWh
# Year 1995: Unmet Load = 4305370.50 kWh
# Year 1994: Unmet Load = 1434470.09 kWh
# Year 1993: Unmet Load = 3521267.15 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 1239862.86 kWh
# Year 1990: Unmet Load = 869472.70 kWh
# Year 1989: Unmet Load = 822319.23 kWh
# Year 1988: Unmet Load = 2369599.84 kWh
# Year 1987: Unmet Load = 751707.97 kWh
# Year 1986: Unmet Load = 1608665.25 kWh
# Year 1985: Unmet Load = 1062119.70 kWh
# Year 1984: Unmet Load = 891698.05 kWh
# Year 1983: Unmet Load = 1442613.48 kWh
# Year 1982: Unmet Load = 1103200.87 kWh
# Year 1981: Unmet Load = 1407925.40 kWh
# Year 1980: Unmet Load = 2564311.30 kWh
#
# Average Unmet Load (1979-2024): 1456744.53 kWh
# Min Unmet Load: 0.00 kWh (Year 1992)
# Max Unmet Load: 7125884.69 kWh (Year 2010)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 71% reduction (Case 1) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (1).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (1).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023"
dispatch_load_factor = 0.55  # Apply 0.55 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.55)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Load Factor 0.55) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.55)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.55) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890649 nonzeros
# Model fingerprint: 0x28bf85b9
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.34s
# Presolved: 70077 rows, 35042 columns, 161798 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153033 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   1.497809e+06   7.602528e+06     44s
#     1151    2.5299446e+14   0.000000e+00   1.770873e+15     45s
#     3071    7.9959334e+13   1.584477e-03   3.200478e+16     50s
#     4333    3.2147464e+13   3.140010e-03   2.723974e+15     55s
#     5469    1.0982024e+13   1.318887e-03   1.434801e+16     60s
#     6861    3.9295945e+12   0.000000e+00   6.687854e+12     65s
#     7876    1.5982434e+12   0.000000e+00   6.906284e+11     70s
#     9011    7.8828148e+11   0.000000e+00   4.091533e+08     75s
#    11075   -3.4939049e+33   8.160619e+32   3.493905e+03     80s
#    16927    1.4302917e+09   9.464112e+08   0.000000e+00     85s
#    26131    2.1655842e+09   2.292199e+10   0.000000e+00     90s
#    30137    2.5474860e+09   3.603167e+09   0.000000e+00     95s
#    33154    2.8750634e+09   0.000000e+00   0.000000e+00     99s
#    33154    2.8750634e+09   0.000000e+00   0.000000e+00     99s
# Concurrent spin time: 10.05s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 2.875063e+09, 33154 iterations, 65.67 seconds (45.93 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.8751e+09    0   35          - 2.8751e+09      -     -  108s
# H    0     0                    3.926692e+09 2.8751e+09  26.8%     -  116s
# H    0     0                    3.766989e+09 2.8751e+09  23.7%     -  122s
# H    0     0                    3.513190e+09 2.8751e+09  18.2%     -  131s
#      0     2 2.8751e+09    0   35 3.5132e+09 2.8751e+09  18.2%     -  131s
#      3     8 2.8751e+09    2   35 3.5132e+09 2.8751e+09  18.2%   5.0  140s
#     87   176 2.8751e+09   10   34 3.5132e+09 2.8751e+09  18.2%   5.6  145s
#    179   250 2.8751e+09   16   28 3.5132e+09 2.8751e+09  18.2%   8.7  158s
# H  237   250                    3.267067e+09 2.8751e+09  12.0%  11.1  158s
#    265   332 2.8751e+09   20   28 3.2671e+09 2.8751e+09  12.0%  13.4  166s
#    349   545 2.8751e+09   26   27 3.2671e+09 2.8751e+09  12.0%  45.5  194s
#    576   737 2.8751e+09   40   25 3.2671e+09 2.8751e+09  12.0%  50.4  257s
# H  600   737                    3.164899e+09 2.8751e+09  9.16%  50.4  257s
# H  625   737                    2.905567e+09 2.8751e+09  1.05%  48.6  257s
#    776  1030 2.8751e+09   54   26 2.9056e+09 2.8751e+09  1.05%  49.3  327s
# H  800   954                    2.899606e+09 2.8751e+09  0.85%  48.3  327s
#
# Explored 1105 nodes (86561 simplex iterations) in 328.97 seconds (310.62 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 2.89961e+09 2.90557e+09 3.1649e+09 ... 3.92669e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.899605835401e+09, best bound 2.875063420351e+09, gap 0.8464%
# Optimal Solution Found!
# Solar Capacity: 8409652.85 kW
# Wind Capacity: 9.55 kW
# Battery Capacity: 4237589.85 kWh
# Total NPC: $2899605835.40
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3408239970.00 kWh
# Total Energy Generated: 5187067126.47 kWh
# Total Energy Used (along with efficiency losses): 1778827156.47 kWh
# Utilization Percentage: 34.29%
# $18264667.56 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 8409652.85 kW
# Solar Initial Cost:    $781677232.33
# Wind Initial Capacity: 9.55 kW
# Wind Initial Cost:     $48822017.47
# Battery Initial Capacity: 4237589.85 kWh
# Battery Initial Cost:  $1517057165.09
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -26910.89 kW
# Solar Redundant Cost:    $-2501367.14
# Wind Redundant Capacity: 0.84 kW
# Wind Redundant Cost:     $4310007.70
# Battery Redundant Capacity: 15679.08 kWh
# Battery Redundant Cost:  $5613111.51
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $779175865.19
# Solar OPEX:         $851066282.31
# Solar Replacement:  $0.00
# Solar Salvage:     -$226509088.38
# Wind CAPEX:         $53132025.17
# Wind OPEX:          $11372155.66
# Wind Replacement:   $0.00
# Wind Salvage:      -$9653538.37
# Battery CAPEX:      $1522670276.60
# Battery OPEX:       $458730958.43
# Battery Replacement:$232065888.67
# Battery Salvage:   -$553306820.18
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3131671724.07
#
# === 2024 Solar Results 99% met (Load Factor 0.55) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.4470     0.000034
# discharge         18           38 0.5064     0.000043
# discharge         41           62 0.5082     0.000043
# discharge         66           88 0.5496     0.000049
# discharge         93          111 0.5401     0.000048
# discharge        117          134 0.4866     0.000040
# discharge        137          158 0.5100     0.000043
# discharge        161          183 0.5341     0.000047
# discharge        187          208 0.5443     0.000048
# discharge        214          230 0.4992     0.000042
# discharge        238          254 0.4958     0.000041
# discharge        258          278 0.5101     0.000043
# discharge        281          302 0.5077     0.000043
# discharge        305          327 0.5431     0.000048
# discharge        334          350 0.5101     0.000043
# discharge        355          374 0.5010     0.000042
# discharge        379          398 0.4725     0.000038
# discharge        404          422 0.4879     0.000040
# discharge        425          446 0.4982     0.000041
# discharge        449          470 0.4890     0.000040
# discharge        473          494 0.4635     0.000036
# discharge        497          518 0.4884     0.000040
# discharge        521          542 0.4340     0.000032
# discharge        545          566 0.4397     0.000033
# discharge        569          590 0.4716     0.000038
# discharge        593          614 0.4571     0.000035
# discharge        617          638 0.4752     0.000038
# discharge        641          662 0.4864     0.000040
# discharge        665          686 0.4774     0.000038
# discharge        689          710 0.4811     0.000039
# discharge        716          734 0.4605     0.000036
# discharge        737          758 0.4369     0.000033
# discharge        761          782 0.4584     0.000036
# discharge        785          806 0.4778     0.000038
# discharge        810          830 0.4836     0.000039
# discharge        833          854 0.4691     0.000037
# discharge        857          878 0.4300     0.000032
# discharge        881          902 0.4293     0.000032
# discharge        905          926 0.4753     0.000038
# discharge        929          950 0.4448     0.000034
# discharge        953          974 0.4424     0.000033
# discharge        977          998 0.4859     0.000040
# discharge       1003         1022 0.4584     0.000036
# discharge       1025         1046 0.4299     0.000032
# discharge       1049         1070 0.4302     0.000032
# discharge       1073         1093 0.4311     0.000032
# discharge       1097         1117 0.4261     0.000031
# discharge       1120         1142 0.4626     0.000036
# discharge       1145         1166 0.4680     0.000037
# discharge       1169         1189 0.4528     0.000035
# discharge       1193         1213 0.4505     0.000035
# discharge       1217         1237 0.4566     0.000035
# discharge       1241         1262 0.4368     0.000033
# discharge       1265         1285 0.4409     0.000033
# discharge       1289         1310 0.4704     0.000037
# discharge       1315         1334 0.4501     0.000035
# discharge       1337         1357 0.4582     0.000036
# discharge       1361         1381 0.4400     0.000033
# discharge       1384         1405 0.4112     0.000029
# discharge       1408         1430 0.4328     0.000032
# discharge       1435         1453 0.4239     0.000031
# discharge       1456         1477 0.4575     0.000036
# discharge       1481         1501 0.4572     0.000035
# discharge       1505         1525 0.4207     0.000031
# discharge       1528         1549 0.4206     0.000031
# discharge       1553         1573 0.4431     0.000034
# discharge       1577         1597 0.4491     0.000034
# discharge       1602         1621 0.4432     0.000034
# discharge       1626         1646 0.4372     0.000033
# discharge       1650         1669 0.4164     0.000030
# discharge       1673         1693 0.4171     0.000030
# discharge       1696         1717 0.4335     0.000032
# discharge       1720         1741 0.4473     0.000034
# discharge       1746         1766 0.4383     0.000033
# discharge       1770         1789 0.4516     0.000035
# discharge       1792         1813 0.4440     0.000034
# discharge       1816         1837 0.4298     0.000032
# discharge       1841         1862 0.4753     0.000038
# discharge       1867         1886 0.4533     0.000035
# discharge       1892         1910 0.4444     0.000034
# discharge       1913         1933 0.4130     0.000030
# discharge       1936         1957 0.4451     0.000034
# discharge       1961         1981 0.4299     0.000032
# discharge       1984         2005 0.4337     0.000032
# discharge       2009         2029 0.4470     0.000034
# discharge       2032         2053 0.4216     0.000031
# discharge       2056         2077 0.4285     0.000032
# discharge       2080         2102 0.4197     0.000030
# discharge       2105         2125 0.4182     0.000030
# discharge       2129         2149 0.4428     0.000034
# discharge       2152         2173 0.4379     0.000033
# discharge       2176         2197 0.4211     0.000031
# discharge       2200         2221 0.3861     0.000026
# discharge       2224         2245 0.3984     0.000028
# discharge       2248         2269 0.4191     0.000030
# discharge       2272         2293 0.4251     0.000031
# discharge       2296         2317 0.4183     0.000030
# discharge       2321         2341 0.4140     0.000030
# discharge       2344         2365 0.4370     0.000033
# discharge       2368         2389 0.4203     0.000031
# discharge       2392         2413 0.4315     0.000032
# discharge       2416         2437 0.4004     0.000028
# discharge       2441         2461 0.3930     0.000027
# discharge       2464         2485 0.4040     0.000028
# discharge       2488         2509 0.4218     0.000031
# discharge       2512         2533 0.4219     0.000031
# discharge       2536         2557 0.4147     0.000030
# discharge       2560         2581 0.3776     0.000025
# discharge       2584         2605 0.3857     0.000026
# discharge       2608         2629 0.4158     0.000030
# discharge       2632         2653 0.4140     0.000030
# discharge       2656         2677 0.3965     0.000027
# discharge       2680         2701 0.4083     0.000029
# discharge       2704         2725 0.4078     0.000029
# discharge       2729         2749 0.3807     0.000026
# discharge       2752         2773 0.3910     0.000027
# discharge       2776         2797 0.4065     0.000029
# discharge       2800         2821 0.3954     0.000027
# discharge       2824         2845 0.4015     0.000028
# discharge       2848         2869 0.4084     0.000029
# discharge       2872         2893 0.3837     0.000026
# discharge       2896         2917 0.3843     0.000026
# discharge       2920         2941 0.3912     0.000027
# discharge       2944         2965 0.3851     0.000026
# discharge       2968         2989 0.3933     0.000027
# discharge       2992         3013 0.3876     0.000026
# discharge       3016         3037 0.3817     0.000026
# discharge       3040         3061 0.3861     0.000026
# discharge       3064         3085 0.3714     0.000024
# discharge       3088         3109 0.3769     0.000025
# discharge       3112         3133 0.3782     0.000025
# discharge       3136         3157 0.3977     0.000028
# discharge       3160         3181 0.3810     0.000026
# discharge       3184         3205 0.3800     0.000025
# discharge       3208         3229 0.3905     0.000027
# discharge       3232         3253 0.3909     0.000027
# discharge       3256         3277 0.4002     0.000028
# discharge       3280         3301 0.3905     0.000027
# discharge       3304         3325 0.3932     0.000027
# discharge       3328         3348 0.3830     0.000026
# discharge       3352         3373 0.3916     0.000027
# discharge       3376         3397 0.3870     0.000026
# discharge       3400         3421 0.3848     0.000026
# discharge       3424         3445 0.3666     0.000024
# discharge       3448         3468 0.3698     0.000024
# discharge       3472         3493 0.3759     0.000025
# discharge       3496         3517 0.3768     0.000025
# discharge       3520         3541 0.3885     0.000027
# discharge       3544         3565 0.3790     0.000025
# discharge       3568         3588 0.3756     0.000025
# discharge       3592         3613 0.3746     0.000025
# discharge       3616         3636 0.3789     0.000025
# discharge       3640         3660 0.3721     0.000025
# discharge       3664         3685 0.3788     0.000025
# discharge       3688         3709 0.3889     0.000027
# discharge       3712         3732 0.3883     0.000026
# discharge       3736         3756 0.3755     0.000025
# discharge       3760         3781 0.3921     0.000027
# discharge       3785         3804 0.3905     0.000027
# discharge       3808         3828 0.3778     0.000025
# discharge       3832         3853 0.3971     0.000028
# discharge       3857         3877 0.4001     0.000028
# discharge       3881         3900 0.3713     0.000024
# discharge       3904         3924 0.3855     0.000026
# discharge       3928         3948 0.3833     0.000026
# discharge       3952         3972 0.3865     0.000026
# discharge       3977         3996 0.3692     0.000024
# discharge       4001         4020 0.3858     0.000026
# discharge       4024         4044 0.3706     0.000024
# discharge       4048         4068 0.3542     0.000022
# discharge       4072         4093 0.3625     0.000023
# discharge       4096         4117 0.3701     0.000024
# discharge       4120         4140 0.3717     0.000024
# discharge       4144         4165 0.3544     0.000022
# discharge       4168         4189 0.3899     0.000027
# discharge       4192         4213 0.3746     0.000025
# discharge       4216         4237 0.3707     0.000024
# discharge       4240         4261 0.3662     0.000024
# discharge       4264         4285 0.3654     0.000024
# discharge       4288         4308 0.3813     0.000026
# discharge       4312         4333 0.3847     0.000026
# discharge       4336         4357 0.3882     0.000026
# discharge       4360         4381 0.3859     0.000026
# discharge       4384         4405 0.3797     0.000025
# discharge       4408         4429 0.3696     0.000024
# discharge       4432         4453 0.3821     0.000026
# discharge       4456         4477 0.3747     0.000025
# discharge       4480         4501 0.3789     0.000025
# discharge       4504         4525 0.3843     0.000026
# discharge       4528         4549 0.3909     0.000027
# discharge       4552         4573 0.3821     0.000026
# discharge       4576         4596 0.3764     0.000025
# discharge       4600         4621 0.3739     0.000025
# discharge       4624         4645 0.3715     0.000024
# discharge       4648         4669 0.3808     0.000026
# discharge       4672         4693 0.3902     0.000027
# discharge       4696         4717 0.3941     0.000027
# discharge       4720         4741 0.3712     0.000024
# discharge       4744         4765 0.3773     0.000025
# discharge       4768         4789 0.3815     0.000026
# discharge       4792         4813 0.3855     0.000026
# discharge       4816         4837 0.3922     0.000027
# discharge       4840         4861 0.3976     0.000028
# discharge       4864         4885 0.3819     0.000026
# discharge       4888         4909 0.3855     0.000026
# discharge       4912         4933 0.3863     0.000026
# discharge       4936         4957 0.3871     0.000026
# discharge       4960         4981 0.3807     0.000026
# discharge       4984         5005 0.3813     0.000026
# discharge       5008         5029 0.3882     0.000026
# discharge       5032         5053 0.3989     0.000028
# discharge       5057         5077 0.4215     0.000031
# discharge       5081         5101 0.3977     0.000028
# discharge       5104         5125 0.4102     0.000029
# discharge       5129         5149 0.3994     0.000028
# discharge       5152         5173 0.3980     0.000028
# discharge       5176         5197 0.4052     0.000029
# discharge       5200         5221 0.3972     0.000028
# discharge       5224         5245 0.3873     0.000026
# discharge       5248         5269 0.3806     0.000026
# discharge       5272         5294 0.3921     0.000027
# discharge       5298         5317 0.3936     0.000027
# discharge       5320         5341 0.4086     0.000029
# discharge       5344         5365 0.4007     0.000028
# discharge       5368         5389 0.4078     0.000029
# discharge       5392         5413 0.4088     0.000029
# discharge       5416         5437 0.4091     0.000029
# discharge       5441         5461 0.4102     0.000029
# discharge       5465         5485 0.4126     0.000030
# discharge       5489         5509 0.4042     0.000028
# discharge       5513         5533 0.4123     0.000029
# discharge       5537         5557 0.4438     0.000034
# discharge       5564         5581 0.3929     0.000027
# discharge       5584         5605 0.4162     0.000030
# discharge       5608         5629 0.4166     0.000030
# discharge       5632         5653 0.4186     0.000030
# discharge       5656         5677 0.4261     0.000031
# discharge       5680         5701 0.4187     0.000030
# discharge       5704         5725 0.4097     0.000029
# discharge       5728         5749 0.4115     0.000029
# discharge       5752         5773 0.4201     0.000030
# discharge       5776         5797 0.4196     0.000030
# discharge       5800         5821 0.4067     0.000029
# discharge       5824         5846 0.4138     0.000030
# discharge       5850         5869 0.4268     0.000031
# discharge       5873         5893 0.4360     0.000033
# discharge       5896         5917 0.4110     0.000029
# discharge       5920         5941 0.4303     0.000032
# discharge       5944         5965 0.4318     0.000032
# discharge       5968         5989 0.4319     0.000032
# discharge       5992         6013 0.4294     0.000032
# discharge       6016         6037 0.4393     0.000033
# discharge       6040         6062 0.4381     0.000033
# discharge       6066         6085 0.4492     0.000034
# discharge       6089         6109 0.4403     0.000033
# discharge       6113         6133 0.4430     0.000034
# discharge       6137         6157 0.4366     0.000033
# discharge       6161         6181 0.4361     0.000033
# discharge       6184         6205 0.4357     0.000033
# discharge       6208         6229 0.4421     0.000033
# discharge       6232         6253 0.4447     0.000034
# discharge       6256         6277 0.4398     0.000033
# discharge       6280         6301 0.4427     0.000033
# discharge       6305         6325 0.4302     0.000032
# discharge       6328         6349 0.4216     0.000031
# discharge       6353         6373 0.4507     0.000035
# discharge       6377         6397 0.4463     0.000034
# discharge       6400         6421 0.4485     0.000034
# discharge       6424         6445 0.4498     0.000034
# discharge       6448         6469 0.4487     0.000034
# discharge       6472         6493 0.4508     0.000035
# discharge       6497         6517 0.4421     0.000033
# discharge       6521         6542 0.4355     0.000033
# discharge       6548         6565 0.4426     0.000033
# discharge       6569         6589 0.4537     0.000035
# discharge       6593         6613 0.4535     0.000035
# discharge       6617         6637 0.4422     0.000033
# discharge       6641         6661 0.4321     0.000032
# discharge       6665         6685 0.4279     0.000032
# discharge       6689         6709 0.4336     0.000032
# discharge       6713         6733 0.4524     0.000035
# discharge       6737         6757 0.4548     0.000035
# discharge       6761         6781 0.4368     0.000033
# discharge       6785         6805 0.4175     0.000030
# discharge       6809         6829 0.4314     0.000032
# discharge       6832         6854 0.4400     0.000033
# discharge       6857         6877 0.4704     0.000037
# discharge       6881         6901 0.4532     0.000035
# discharge       6905         6925 0.4498     0.000034
# discharge       6929         6949 0.4532     0.000035
# discharge       6953         6973 0.4464     0.000034
# discharge       6977         6997 0.4394     0.000033
# discharge       7001         7021 0.4529     0.000035
# discharge       7025         7045 0.4536     0.000035
# discharge       7049         7070 0.4509     0.000035
# discharge       7073         7094 0.4281     0.000032
# discharge       7097         7118 0.4516     0.000035
# discharge       7121         7142 0.4473     0.000034
# discharge       7145         7166 0.4348     0.000032
# discharge       7169         7190 0.4638     0.000036
# discharge       7193         7214 0.4823     0.000039
# discharge       7217         7237 0.4131     0.000030
# discharge       7241         7261 0.4131     0.000030
# discharge       7265         7285 0.4261     0.000031
# discharge       7289         7309 0.4387     0.000033
# discharge       7313         7334 0.4579     0.000036
# discharge       7337         7358 0.4632     0.000036
# discharge       7361         7382 0.4663     0.000037
# discharge       7385         7406 0.4806     0.000039
# discharge       7409         7430 0.4578     0.000036
# discharge       7433         7454 0.4448     0.000034
# discharge       7457         7478 0.4316     0.000032
# discharge       7481         7502 0.4294     0.000032
# discharge       7505         7526 0.4567     0.000035
# discharge       7529         7550 0.4696     0.000037
# discharge       7553         7574 0.4649     0.000037
# discharge       7577         7598 0.4822     0.000039
# discharge       7602         7622 0.5097     0.000043
# discharge       7625         7646 0.4900     0.000040
# discharge       7650         7670 0.5146     0.000044
# discharge       7673         7694 0.4832     0.000039
# discharge       7697         7718 0.4824     0.000039
# discharge       7721         7742 0.4524     0.000035
# discharge       7745         7766 0.4357     0.000033
# discharge       7769         7790 0.4426     0.000033
# discharge       7793         7814 0.4802     0.000039
# discharge       7817         7839 0.5069     0.000043
# discharge       7845         7862 0.4885     0.000040
# discharge       7865         7886 0.4776     0.000038
# discharge       7889         7910 0.4617     0.000036
# discharge       7913         7934 0.4576     0.000036
# discharge       7937         7958 0.4624     0.000036
# discharge       7962         7983 0.4915     0.000040
# discharge       7987         8006 0.5031     0.000042
# discharge       8009         8030 0.5161     0.000044
# discharge       8034         8054 0.4998     0.000042
# discharge       8057         8078 0.5068     0.000043
# discharge       8081         8102 0.5122     0.000043
# discharge       8106         8126 0.4905     0.000040
# discharge       8129         8150 0.4936     0.000041
# discharge       8153         8174 0.4807     0.000039
# discharge       8180         8198 0.4995     0.000042
# discharge       8201         8222 0.4705     0.000037
# discharge       8225         8246 0.4847     0.000039
# discharge       8249         8270 0.5075     0.000043
# discharge       8273         8294 0.5154     0.000044
# discharge       8297         8318 0.4898     0.000040
# discharge       8321         8342 0.4925     0.000041
# discharge       8345         8366 0.5096     0.000043
# discharge       8370         8390 0.4905     0.000040
# discharge       8394         8414 0.4964     0.000041
# discharge       8418         8438 0.5026     0.000042
# discharge       8442         8462 0.5141     0.000044
# discharge       8468         8486 0.5197     0.000045
# discharge       8490         8511 0.5437     0.000048
# discharge       8516         8535 0.5545     0.000050
# discharge       8541         8558 0.5569     0.000050
# discharge       8562         8582 0.5010     0.000042
# discharge       8585         8606 0.5125     0.000044
# discharge       8610         8630 0.5077     0.000043
# discharge       8634         8654 0.5143     0.000044
# discharge       8658         8679 0.5358     0.000047
# discharge       8682         8702 0.5050     0.000042
# discharge       8706         8726 0.5225     0.000045
# discharge       8730         8750 0.5142     0.000044
#
# Total Estimated Degradation: 0.011853
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.55) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 1925134.54 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 255166.68 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 394887.65 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 83590.22 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 59083.98 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 1925134.54 kWh (Year 2010)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 55% reduction (Case 1) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected (1).csv'
wind_csv_2024 = 'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected (1).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023"
dispatch_load_factor = 0.43  # Apply 0.43 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.07, 1.09, 1.11, 1.08, 1.07]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/SolarNevada/2000s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/2000s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/SolarNevada/1900s/ninja_pv_36.0320_-114.9822_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/WindNevada/1900s/ninja_wind_36.0320_-114.9822_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 99% met (Load Factor 0.43)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 99% met (Load Factor 0.43) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 99% met (Load Factor 0.43)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 99% met (Load Factor 0.43) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890649 nonzeros
# Model fingerprint: 0x28bf85b9
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 16s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 23s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 28.50s
# Presolved: 70077 rows, 35042 columns, 161798 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153033 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   1.497809e+06   7.602528e+06     46s
#     2378    1.2961432e+14   4.080078e-04   7.627851e+14     50s
#     4212    3.4485234e+13   3.058323e-03   1.583526e+09     56s
#     5346    1.1901875e+13   1.530105e-03   8.614284e+14     60s
#     6977    3.6048056e+12   1.845455e-04   1.239983e+15     65s
#     7984    1.4006180e+12   1.780007e-04   1.805147e+14     70s
#     9648    5.9311886e+11   3.574172e-02   1.304744e+14     75s
#    15055   -8.5297578e+10   3.033169e+11   0.000000e+00     80s
#    22387    1.8170265e+09   6.757537e+08   0.000000e+00     85s
#    27995    2.3656664e+09   2.464162e+09   0.000000e+00     90s
#    32397    2.8610252e+09   2.057527e+08   0.000000e+00     95s
#    33154    2.8750634e+09   0.000000e+00   0.000000e+00     96s
#    33154    2.8750634e+09   0.000000e+00   0.000000e+00     96s
# Concurrent spin time: 9.39s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#
# Root relaxation: objective 2.875063e+09, 33154 iterations, 59.69 seconds (45.93 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.8751e+09    0   35          - 2.8751e+09      -     -  105s
# H    0     0                    3.926692e+09 2.8751e+09  26.8%     -  113s
# H    0     0                    3.766989e+09 2.8751e+09  23.7%     -  119s
# H    0     0                    3.513190e+09 2.8751e+09  18.2%     -  128s
#      0     2 2.8751e+09    0   35 3.5132e+09 2.8751e+09  18.2%     -  129s
#      3     8 2.8751e+09    2   35 3.5132e+09 2.8751e+09  18.2%   5.0  137s
#     23    88 2.8751e+09    5   35 3.5132e+09 2.8751e+09  18.2%   4.0  140s
#    179   250 2.8751e+09   16   28 3.5132e+09 2.8751e+09  18.2%   8.7  156s
# H  237   250                    3.267067e+09 2.8751e+09  12.0%  11.1  156s
#    265   332 2.8751e+09   20   28 3.2671e+09 2.8751e+09  12.0%  13.4  164s
#    349   545 2.8751e+09   26   27 3.2671e+09 2.8751e+09  12.0%  45.5  195s
#    576   737 2.8751e+09   40   25 3.2671e+09 2.8751e+09  12.0%  50.4  255s
# H  600   737                    3.164899e+09 2.8751e+09  9.16%  50.4  255s
# H  625   737                    2.905567e+09 2.8751e+09  1.05%  48.6  255s
#    776  1030 2.8751e+09   54   26 2.9056e+09 2.8751e+09  1.05%  49.3  322s
# H  800   954                    2.899606e+09 2.8751e+09  0.85%  48.3  322s
#
# Explored 1105 nodes (86561 simplex iterations) in 323.75 seconds (310.62 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 2.89961e+09 2.90557e+09 3.1649e+09 ... 3.92669e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.899605835401e+09, best bound 2.875063420351e+09, gap 0.8464%
# Optimal Solution Found!
# Solar Capacity: 8409652.85 kW
# Wind Capacity: 9.55 kW
# Battery Capacity: 4237589.85 kWh
# Total NPC: $2899605835.40
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3688774788.76 kWh
# Total Energy Generated: 5187067126.47 kWh
# Total Energy Used (along with efficiency losses): 1498292337.71 kWh
# Utilization Percentage: 28.89%
# $11312772.87 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 8409652.85 kW
# Solar Initial Cost:    $781677232.33
# Wind Initial Capacity: 9.55 kW
# Wind Initial Cost:     $48822017.47
# Battery Initial Capacity: 4237589.85 kWh
# Battery Initial Cost:  $1517057165.09
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -26910.89 kW
# Solar Redundant Cost:    $-2501367.14
# Wind Redundant Capacity: 0.84 kW
# Wind Redundant Cost:     $4310007.70
# Battery Redundant Capacity: 15679.08 kWh
# Battery Redundant Cost:  $5613111.51
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $779175865.19
# Solar OPEX:         $851066282.31
# Solar Replacement:  $0.00
# Solar Salvage:     -$226509088.38
# Wind CAPEX:         $53132025.17
# Wind OPEX:          $11372155.66
# Wind Replacement:   $0.00
# Wind Salvage:      -$9653538.37
# Battery CAPEX:      $1522670276.60
# Battery OPEX:       $458730958.43
# Battery Replacement:$143737009.21
# Battery Salvage:   -$553306820.18
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3043342844.61
#
# === 2024 Solar Results 99% met (Load Factor 0.43) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           14 0.3408     0.000021
# discharge         17           38 0.3922     0.000027
# discharge         41           62 0.3941     0.000027
# discharge         65           87 0.4259     0.000031
# discharge         92          111 0.4178     0.000030
# discharge        116          134 0.3725     0.000025
# discharge        137          158 0.3956     0.000027
# discharge        161          182 0.4087     0.000029
# discharge        186          207 0.4211     0.000031
# discharge        214          230 0.3774     0.000025
# discharge        235          254 0.3744     0.000025
# discharge        257          278 0.3960     0.000027
# discharge        281          302 0.3931     0.000027
# discharge        305          327 0.4217     0.000031
# discharge        334          350 0.3883     0.000026
# discharge        353          374 0.3868     0.000026
# discharge        378          398 0.3585     0.000023
# discharge        403          422 0.3738     0.000025
# discharge        425          446 0.3841     0.000026
# discharge        449          470 0.3748     0.000025
# discharge        473          494 0.3547     0.000023
# discharge        496          518 0.3818     0.000026
# discharge        521          542 0.3273     0.000020
# discharge        544          566 0.3332     0.000020
# discharge        568          590 0.3650     0.000024
# discharge        592          614 0.3503     0.000022
# discharge        616          638 0.3685     0.000024
# discharge        640          662 0.3793     0.000025
# discharge        665          686 0.3710     0.000024
# discharge        689          710 0.3723     0.000025
# discharge        715          734 0.3459     0.000022
# discharge        736          758 0.3302     0.000020
# discharge        760          782 0.3514     0.000022
# discharge        784          806 0.3674     0.000024
# discharge        809          830 0.3689     0.000024
# discharge        832          854 0.3624     0.000023
# discharge        856          878 0.3233     0.000019
# discharge        880          902 0.3221     0.000019
# discharge        904          926 0.3683     0.000024
# discharge        928          950 0.3379     0.000021
# discharge        952          973 0.3390     0.000021
# discharge        976          998 0.3787     0.000025
# discharge       1003         1022 0.3512     0.000022
# discharge       1025         1046 0.3184     0.000019
# discharge       1048         1070 0.3233     0.000019
# discharge       1073         1093 0.3242     0.000019
# discharge       1096         1117 0.3268     0.000019
# discharge       1120         1142 0.3556     0.000023
# discharge       1145         1166 0.3531     0.000022
# discharge       1169         1189 0.3531     0.000022
# discharge       1192         1213 0.3511     0.000022
# discharge       1216         1237 0.3569     0.000023
# discharge       1240         1262 0.3222     0.000019
# discharge       1264         1285 0.3336     0.000020
# discharge       1289         1310 0.3556     0.000023
# discharge       1314         1333 0.3395     0.000021
# discharge       1337         1357 0.3508     0.000022
# discharge       1360         1381 0.3395     0.000021
# discharge       1384         1405 0.3115     0.000018
# discharge       1408         1429 0.3256     0.000019
# discharge       1434         1453 0.3241     0.000019
# discharge       1456         1477 0.3576     0.000023
# discharge       1480         1501 0.3571     0.000023
# discharge       1505         1525 0.3207     0.000019
# discharge       1528         1549 0.3207     0.000019
# discharge       1553         1573 0.3432     0.000021
# discharge       1576         1597 0.3486     0.000022
# discharge       1601         1621 0.3431     0.000021
# discharge       1625         1646 0.3294     0.000020
# discharge       1649         1669 0.3091     0.000018
# discharge       1673         1693 0.3171     0.000018
# discharge       1696         1717 0.3334     0.000020
# discharge       1720         1741 0.3472     0.000022
# discharge       1745         1766 0.3306     0.000020
# discharge       1769         1789 0.3459     0.000022
# discharge       1792         1813 0.3436     0.000021
# discharge       1816         1837 0.3295     0.000020
# discharge       1840         1862 0.3672     0.000024
# discharge       1866         1886 0.3450     0.000021
# discharge       1891         1909 0.3367     0.000021
# discharge       1913         1933 0.3126     0.000018
# discharge       1936         1957 0.3446     0.000021
# discharge       1960         1981 0.3295     0.000020
# discharge       1984         2005 0.3331     0.000020
# discharge       2008         2029 0.3460     0.000022
# discharge       2032         2053 0.3209     0.000019
# discharge       2056         2077 0.3283     0.000020
# discharge       2080         2101 0.3184     0.000019
# discharge       2105         2125 0.3175     0.000018
# discharge       2128         2149 0.3425     0.000021
# discharge       2152         2173 0.3372     0.000021
# discharge       2176         2197 0.3201     0.000019
# discharge       2200         2221 0.2853     0.000015
# discharge       2224         2245 0.2974     0.000016
# discharge       2248         2269 0.3187     0.000019
# discharge       2272         2293 0.3241     0.000019
# discharge       2296         2317 0.3185     0.000019
# discharge       2321         2341 0.3144     0.000018
# discharge       2344         2365 0.3359     0.000020
# discharge       2368         2389 0.3196     0.000019
# discharge       2392         2413 0.3309     0.000020
# discharge       2416         2437 0.3072     0.000017
# discharge       2440         2461 0.2972     0.000016
# discharge       2464         2485 0.3068     0.000017
# discharge       2488         2509 0.3254     0.000019
# discharge       2512         2533 0.3261     0.000019
# discharge       2536         2557 0.3147     0.000018
# discharge       2560         2581 0.2840     0.000015
# discharge       2584         2605 0.2849     0.000015
# discharge       2608         2629 0.3221     0.000019
# discharge       2632         2653 0.3204     0.000019
# discharge       2656         2677 0.3028     0.000017
# discharge       2680         2701 0.3144     0.000018
# discharge       2704         2725 0.3143     0.000018
# discharge       2728         2749 0.2868     0.000015
# discharge       2752         2773 0.2972     0.000016
# discharge       2776         2797 0.3124     0.000018
# discharge       2800         2821 0.3015     0.000017
# discharge       2824         2845 0.3078     0.000017
# discharge       2848         2869 0.3148     0.000018
# discharge       2872         2893 0.2903     0.000016
# discharge       2896         2917 0.2901     0.000016
# discharge       2920         2941 0.2972     0.000016
# discharge       2944         2965 0.2910     0.000016
# discharge       2968         2989 0.2993     0.000017
# discharge       2992         3013 0.2934     0.000016
# discharge       3016         3037 0.2878     0.000015
# discharge       3040         3061 0.2918     0.000016
# discharge       3064         3084 0.2789     0.000015
# discharge       3087         3108 0.2868     0.000015
# discharge       3112         3132 0.2846     0.000015
# discharge       3136         3156 0.3055     0.000017
# discharge       3160         3180 0.2881     0.000016
# discharge       3184         3204 0.2901     0.000016
# discharge       3208         3228 0.2995     0.000017
# discharge       3232         3252 0.2998     0.000017
# discharge       3256         3276 0.3038     0.000017
# discharge       3280         3300 0.3015     0.000017
# discharge       3304         3324 0.3040     0.000017
# discharge       3328         3348 0.2966     0.000016
# discharge       3352         3372 0.3047     0.000017
# discharge       3376         3396 0.2975     0.000016
# discharge       3400         3420 0.2936     0.000016
# discharge       3424         3444 0.2788     0.000015
# discharge       3448         3468 0.2833     0.000015
# discharge       3472         3492 0.2868     0.000015
# discharge       3496         3516 0.2879     0.000016
# discharge       3520         3540 0.2971     0.000016
# discharge       3544         3564 0.2902     0.000016
# discharge       3568         3588 0.2888     0.000016
# discharge       3592         3612 0.2875     0.000015
# discharge       3616         3636 0.2920     0.000016
# discharge       3640         3660 0.2854     0.000015
# discharge       3664         3684 0.2916     0.000016
# discharge       3688         3708 0.3016     0.000017
# discharge       3712         3732 0.3014     0.000017
# discharge       3736         3756 0.2885     0.000016
# discharge       3760         3781 0.2976     0.000016
# discharge       3785         3804 0.3037     0.000017
# discharge       3808         3828 0.2908     0.000016
# discharge       3832         3853 0.3021     0.000017
# discharge       3856         3876 0.3053     0.000017
# discharge       3880         3900 0.2846     0.000015
# discharge       3904         3924 0.2986     0.000017
# discharge       3928         3948 0.2963     0.000016
# discharge       3952         3972 0.2992     0.000017
# discharge       3976         3996 0.2819     0.000015
# discharge       4000         4020 0.2991     0.000017
# discharge       4024         4044 0.2835     0.000015
# discharge       4048         4068 0.2673     0.000014
# discharge       4071         4092 0.2679     0.000014
# discharge       4095         4116 0.2762     0.000014
# discharge       4120         4140 0.2849     0.000015
# discharge       4144         4164 0.2657     0.000013
# discharge       4167         4188 0.2978     0.000016
# discharge       4192         4212 0.2824     0.000015
# discharge       4216         4236 0.2799     0.000015
# discharge       4240         4260 0.2744     0.000014
# discharge       4264         4284 0.2761     0.000014
# discharge       4288         4308 0.2945     0.000016
# discharge       4312         4332 0.2963     0.000016
# discharge       4336         4356 0.2990     0.000017
# discharge       4360         4380 0.2967     0.000016
# discharge       4384         4404 0.2905     0.000016
# discharge       4408         4428 0.2769     0.000014
# discharge       4432         4452 0.2882     0.000016
# discharge       4456         4476 0.2835     0.000015
# discharge       4480         4500 0.2849     0.000015
# discharge       4504         4524 0.2900     0.000016
# discharge       4528         4548 0.2971     0.000016
# discharge       4552         4572 0.2906     0.000016
# discharge       4576         4596 0.2895     0.000016
# discharge       4600         4620 0.2836     0.000015
# discharge       4624         4644 0.2809     0.000015
# discharge       4648         4668 0.2873     0.000015
# discharge       4672         4692 0.2982     0.000017
# discharge       4696         4716 0.3031     0.000017
# discharge       4720         4740 0.2825     0.000015
# discharge       4744         4764 0.2881     0.000016
# discharge       4768         4788 0.2894     0.000016
# discharge       4792         4812 0.2917     0.000016
# discharge       4816         4836 0.2993     0.000017
# discharge       4840         4860 0.3037     0.000017
# discharge       4864         4884 0.2926     0.000016
# discharge       4888         4908 0.2946     0.000016
# discharge       4912         4932 0.2929     0.000016
# discharge       4936         4956 0.2938     0.000016
# discharge       4960         4981 0.2863     0.000015
# discharge       4984         5005 0.2870     0.000015
# discharge       5008         5028 0.2967     0.000016
# discharge       5032         5052 0.3056     0.000017
# discharge       5056         5077 0.3194     0.000019
# discharge       5080         5100 0.3065     0.000017
# discharge       5104         5125 0.3158     0.000018
# discharge       5128         5149 0.3052     0.000017
# discharge       5152         5173 0.3041     0.000017
# discharge       5176         5197 0.3110     0.000018
# discharge       5200         5221 0.3033     0.000017
# discharge       5224         5245 0.2929     0.000016
# discharge       5248         5269 0.2863     0.000015
# discharge       5272         5293 0.2973     0.000016
# discharge       5298         5317 0.2993     0.000017
# discharge       5320         5341 0.3145     0.000018
# discharge       5344         5365 0.3072     0.000017
# discharge       5368         5389 0.3138     0.000018
# discharge       5392         5413 0.3149     0.000018
# discharge       5416         5437 0.3152     0.000018
# discharge       5440         5461 0.3167     0.000018
# discharge       5464         5485 0.3186     0.000019
# discharge       5488         5509 0.3104     0.000018
# discharge       5512         5533 0.3183     0.000019
# discharge       5536         5557 0.3425     0.000021
# discharge       5563         5581 0.2916     0.000016
# discharge       5584         5605 0.3226     0.000019
# discharge       5608         5629 0.3228     0.000019
# discharge       5632         5653 0.3251     0.000019
# discharge       5656         5677 0.3257     0.000019
# discharge       5680         5701 0.3252     0.000019
# discharge       5704         5725 0.3163     0.000018
# discharge       5728         5749 0.3161     0.000018
# discharge       5752         5773 0.3243     0.000019
# discharge       5776         5797 0.3234     0.000019
# discharge       5800         5821 0.3103     0.000018
# discharge       5824         5846 0.3120     0.000018
# discharge       5850         5869 0.3258     0.000019
# discharge       5872         5893 0.3349     0.000020
# discharge       5896         5917 0.3101     0.000018
# discharge       5920         5941 0.3295     0.000020
# discharge       5944         5965 0.3306     0.000020
# discharge       5968         5989 0.3310     0.000020
# discharge       5992         6013 0.3288     0.000020
# discharge       6016         6037 0.3383     0.000021
# discharge       6040         6061 0.3295     0.000020
# discharge       6066         6085 0.3484     0.000022
# discharge       6088         6109 0.3398     0.000021
# discharge       6112         6133 0.3429     0.000021
# discharge       6136         6157 0.3361     0.000020
# discharge       6160         6181 0.3352     0.000020
# discharge       6184         6205 0.3355     0.000020
# discharge       6208         6229 0.3417     0.000021
# discharge       6232         6253 0.3441     0.000021
# discharge       6256         6277 0.3393     0.000021
# discharge       6280         6301 0.3424     0.000021
# discharge       6304         6325 0.3298     0.000020
# discharge       6328         6349 0.3220     0.000019
# discharge       6352         6373 0.3506     0.000022
# discharge       6376         6397 0.3465     0.000022
# discharge       6400         6421 0.3484     0.000022
# discharge       6424         6445 0.3496     0.000022
# discharge       6448         6469 0.3489     0.000022
# discharge       6472         6493 0.3507     0.000022
# discharge       6496         6517 0.3424     0.000021
# discharge       6520         6542 0.3277     0.000020
# discharge       6547         6565 0.3391     0.000021
# discharge       6568         6589 0.3540     0.000022
# discharge       6592         6613 0.3537     0.000022
# discharge       6616         6637 0.3422     0.000021
# discharge       6640         6661 0.3325     0.000020
# discharge       6664         6685 0.3281     0.000020
# discharge       6688         6709 0.3339     0.000020
# discharge       6712         6733 0.3528     0.000022
# discharge       6736         6757 0.3554     0.000023
# discharge       6760         6781 0.3373     0.000021
# discharge       6784         6805 0.3180     0.000019
# discharge       6808         6829 0.3317     0.000020
# discharge       6832         6853 0.3405     0.000021
# discharge       6856         6877 0.3632     0.000023
# discharge       6880         6901 0.3537     0.000022
# discharge       6904         6925 0.3506     0.000022
# discharge       6928         6949 0.3538     0.000022
# discharge       6952         6973 0.3469     0.000022
# discharge       6976         6997 0.3399     0.000021
# discharge       7000         7021 0.3536     0.000022
# discharge       7024         7045 0.3543     0.000022
# discharge       7048         7069 0.3505     0.000022
# discharge       7072         7093 0.3276     0.000020
# discharge       7096         7117 0.3516     0.000022
# discharge       7120         7141 0.3460     0.000022
# discharge       7144         7166 0.3278     0.000020
# discharge       7168         7190 0.3573     0.000023
# discharge       7193         7214 0.3682     0.000024
# discharge       7217         7237 0.3141     0.000018
# discharge       7240         7261 0.3143     0.000018
# discharge       7264         7285 0.3271     0.000019
# discharge       7288         7309 0.3397     0.000021
# discharge       7312         7333 0.3533     0.000022
# discharge       7336         7358 0.3566     0.000023
# discharge       7361         7382 0.3594     0.000023
# discharge       7385         7406 0.3665     0.000024
# discharge       7409         7430 0.3481     0.000022
# discharge       7432         7454 0.3384     0.000021
# discharge       7457         7478 0.3254     0.000019
# discharge       7480         7502 0.3226     0.000019
# discharge       7504         7526 0.3507     0.000022
# discharge       7528         7550 0.3634     0.000024
# discharge       7553         7574 0.3585     0.000023
# discharge       7577         7598 0.3758     0.000025
# discharge       7601         7622 0.3960     0.000027
# discharge       7625         7646 0.3781     0.000025
# discharge       7649         7670 0.4009     0.000028
# discharge       7673         7694 0.3772     0.000025
# discharge       7697         7718 0.3765     0.000025
# discharge       7721         7742 0.3443     0.000021
# discharge       7745         7766 0.3294     0.000020
# discharge       7768         7790 0.3364     0.000020
# discharge       7793         7814 0.3736     0.000025
# discharge       7817         7839 0.3874     0.000026
# discharge       7844         7862 0.3744     0.000025
# discharge       7865         7886 0.3678     0.000024
# discharge       7889         7910 0.3487     0.000022
# discharge       7913         7934 0.3443     0.000021
# discharge       7937         7958 0.3491     0.000022
# discharge       7961         7982 0.3775     0.000025
# discharge       7987         8006 0.3894     0.000027
# discharge       8009         8030 0.4023     0.000028
# discharge       8033         8054 0.3859     0.000026
# discharge       8057         8078 0.3931     0.000027
# discharge       8081         8102 0.3987     0.000028
# discharge       8106         8126 0.3768     0.000025
# discharge       8129         8150 0.3798     0.000025
# discharge       8153         8174 0.3668     0.000024
# discharge       8179         8198 0.3857     0.000026
# discharge       8201         8222 0.3572     0.000023
# discharge       8225         8246 0.3710     0.000024
# discharge       8249         8270 0.3937     0.000027
# discharge       8273         8294 0.4018     0.000028
# discharge       8297         8318 0.3764     0.000025
# discharge       8321         8342 0.3786     0.000025
# discharge       8345         8366 0.3961     0.000027
# discharge       8369         8390 0.3768     0.000025
# discharge       8393         8414 0.3826     0.000026
# discharge       8417         8438 0.3888     0.000027
# discharge       8442         8462 0.4007     0.000028
# discharge       8467         8486 0.4058     0.000029
# discharge       8490         8511 0.4224     0.000031
# discharge       8515         8535 0.4254     0.000031
# discharge       8540         8558 0.4290     0.000032
# discharge       8561         8582 0.3871     0.000026
# discharge       8585         8606 0.3985     0.000028
# discharge       8609         8630 0.3934     0.000027
# discharge       8633         8654 0.4003     0.000028
# discharge       8658         8678 0.4103     0.000029
# discharge       8682         8702 0.3906     0.000027
# discharge       8706         8726 0.4084     0.000029
# discharge       8729         8750 0.4000     0.000028
#
# Total Estimated Degradation: 0.007375
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023\dispatch_profile_1980.png
#
# === Unmet Load Across Years 99% met (Load Factor 0.43) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 0.00 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 0.00 kWh (Year 2024)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) Nevada 43% reduction (Case 1) in LP for 99% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Local folders for each scenario ===
case_configs = {
    "100% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023",
    "100% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023",
    "99% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023",
    "99% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023",
    "99% / 43% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023",
}

years = list(range(1980, 2025))
case_names = list(case_configs.keys())
heatmap_matrix = []

# === Read unmet load totals from each folder/year ===
for label, folder in case_configs.items():
    yearly_unmet = []
    for year in years:
        file_path = os.path.join(folder, f"hourly_dispatch_{year}.csv")
        if os.path.exists(file_path):
            try:
                df = pd.read_csv(file_path)
                total_unmet = df["Unmet (kW)"].sum()
                yearly_unmet.append(total_unmet)
            except Exception as e:
                print(f"Failed to read {file_path}: {e}")
                yearly_unmet.append(np.nan)
        else:
            print(f"Missing: {file_path}")
            yearly_unmet.append(np.nan)
    heatmap_matrix.append(yearly_unmet)

# === Convert to NumPy array ===
heatmap_matrix = np.array(heatmap_matrix)

# === Plot using binary colormap ===
fig, ax = plt.subplots(figsize=(16, 5))
im = ax.imshow(heatmap_matrix, aspect='auto', cmap='binary', interpolation='nearest')
cbar = plt.colorbar(im, ax=ax, label='Unmet Load (kWh)')
ax.set_title('Unmet Load (kWh) by Year and Inference Reduction Nevada (1980–2024)')
ax.set_xlabel('Year')
ax.set_ylabel('Met Load / Inference Reduction')

# Ticks
ax.set_xticks(np.arange(0, len(years), 5))
ax.set_xticklabels(years[::5], rotation=45)
ax.set_yticks(np.arange(len(case_names)))
ax.set_yticklabels(case_names)

# === Annotate each square with value (4 decimals) and contrast-aware text ===
norm = plt.Normalize(vmin=np.nanmin(heatmap_matrix), vmax=np.nanmax(heatmap_matrix))
cmap = plt.cm.get_cmap('binary')

for i in range(heatmap_matrix.shape[0]):
    for j in range(heatmap_matrix.shape[1]):
        val = heatmap_matrix[i, j]
        if not np.isnan(val):
            rgb = cmap(norm(val))[:3]
            brightness = np.dot(rgb, [0.299, 0.587, 0.114])  # perceived brightness
            text_color = 'black' if brightness > 0.5 else 'white'
            ax.text(j, i, f"{val:.4f}", ha='center', va='center',
                    fontsize=6.5, rotation=90, color=text_color)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_18092\1744464895.py:56: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('binary')

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Local folders for each scenario ===
case_configs = {
    "100% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_71_percent_inference_Nevada2023",
    "100% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_100_percent_met_55_percent_inference_Nevada2023",
    "99% / 71% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_71_percent_inference_Nevada2023",
    "99% / 55% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_55_percent_inference_Nevada2023",
    "99% / 43% LP": r"C:\Users\Abdullah\dispatch_outputs_99_percent_met_43_percent_inference_Nevada2023",
}

years = list(range(1980, 2025))
case_names = list(case_configs.keys())
heatmap_matrix = []

# === Read unmet load totals from each folder/year ===
for label, folder in case_configs.items():
    yearly_unmet = []
    for year in years:
        file_path = os.path.join(folder, f"hourly_dispatch_{year}.csv")
        if os.path.exists(file_path):
            try:
                df = pd.read_csv(file_path)
                total_unmet = df["Unmet (kW)"].sum()
                yearly_unmet.append(total_unmet)
            except Exception as e:
                print(f"Failed to read {file_path}: {e}")
                yearly_unmet.append(np.nan)
        else:
            print(f"Missing: {file_path}")
            yearly_unmet.append(np.nan)
    heatmap_matrix.append(yearly_unmet)

# === Convert to NumPy array ===
heatmap_matrix = np.array(heatmap_matrix)

# === Plot using binary colormap ===
fig, ax = plt.subplots(figsize=(7, 6))
im = ax.imshow(heatmap_matrix, aspect='auto', cmap='binary', interpolation='nearest')
cbar = plt.colorbar(im, ax=ax, label='Unmet Load (kWh)')
ax.set_title('Unmet Load (kWh) by Year and Inference Reduction Nevada')
ax.set_xlabel('Year')
ax.set_ylabel('Met Load / Inference Reduction')

# Ticks
ax.set_xticks(np.arange(0, len(years), 5))
ax.set_xticklabels(years[::5], rotation=45)
ax.set_yticks(np.arange(len(case_names)))
ax.set_yticklabels(case_names)

# === Annotate each square with value (4 decimals) and contrast-aware text ===
norm = plt.Normalize(vmin=np.nanmin(heatmap_matrix), vmax=np.nanmax(heatmap_matrix))
cmap = plt.cm.get_cmap('binary')

for i in range(heatmap_matrix.shape[0]):
    for j in range(heatmap_matrix.shape[1]):
        val = heatmap_matrix[i, j]
        if not np.isnan(val):
            rgb = cmap(norm(val))[:3]
            brightness = np.dot(rgb, [0.299, 0.587, 0.114])  # perceived brightness
            text_color = 'black' if brightness > 0.5 else 'white'
            ax.text(j, i, f"{val:.4f}", ha='center', va='center',
                    fontsize=6.5, rotation=90, color=text_color)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_18092\661209623.py:56: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('binary')
