# %% [markdown]
# # 98 met Capacity Sizing Inference Resilience

# %% [markdown]
# ## 43% of Training Load consumption (Moderate Traffic)

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_98_percent_met_43_percent_inference"
dispatch_load_factor = 0.43  # Apply 0.43 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.02 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 98% met (Load Factor 0.43)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 98% met (Dispatch Load Factor 0.43) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 98% met (Load Factor 0.43)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 98% met (Load Factor 0.43) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0x63f944d6
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 4e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 7s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 16s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 24s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 28.54s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.276474e+05   3.669944e+06     47s
#     4301    3.0083266e+11   0.000000e+00   6.015653e+13     50s
#     6305    9.7127922e+10   0.000000e+00   4.608298e+06     55s
#     7963    5.1291073e+10   0.000000e+00   1.941795e+06     60s
#     9450    2.8140022e+10   4.588168e-05   3.663823e+06     65s
#    11626    2.1008820e+10   0.000000e+00   1.013019e+06     70s
#    13507    1.6647719e+10   6.599589e-04   1.004125e+13     75s
#    15103    1.3567199e+10   0.000000e+00   8.505513e+09     80s
#    16358    1.1271485e+10   0.000000e+00   1.716010e+10     85s
#    17611    9.8586269e+09   3.490444e-03   6.045671e+10     90s
#    18967    9.0863476e+09   0.000000e+00   3.829134e+10     96s
#    20947   -1.5368210e+33   4.599807e+32   1.536821e+03    100s
#    27071   -2.8980288e+10   3.404631e+11   0.000000e+00    105s
# Concurrent spin time: 26.74s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 3.104762e+09, 41971 iterations, 89.41 seconds (63.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.1048e+09    0    2          - 3.1048e+09      -     -  135s
# H    0     0                    3.116569e+09 3.1048e+09  0.38%     -  139s
#
# Explored 1 nodes (41971 simplex iterations) in 140.33 seconds (131.40 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.11657e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.116568765102e+09, best bound 3.104761916190e+09, gap 0.3788%
# Optimal Solution Found!
# Solar Capacity: 6791589.11 kW
# Wind Capacity: 132.24 kW
# Battery Capacity: 3591077.97 kWh
# Total NPC: $3116568765.10
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2797765169.67 kWh
# Total Energy Generated: 4104327650.70 kWh
# Total Energy Used (along with efficiency losses): 1306562481.03 kWh
# Utilization Percentage: 31.83%
# $3797467.46 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 6791589.11 kW
# Solar Initial Cost:    $631278207.83
# Wind Initial Capacity: 132.24 kW
# Wind Initial Cost:     $676271055.47
# Battery Initial Capacity: 3591077.97 kWh
# Battery Initial Cost:  $1285605914.11
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -21733.09 kW
# Solar Redundant Cost:    $-2020090.27
# Wind Redundant Capacity: 11.67 kW
# Wind Redundant Cost:     $59701208.78
# Battery Redundant Capacity: 13286.99 kWh
# Battery Redundant Cost:  $4756741.88
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $629258117.57
# Solar OPEX:         $687316420.67
# Solar Replacement:  $0.00
# Solar Salvage:     -$182927486.51
# Wind CAPEX:         $735972264.24
# Wind OPEX:          $157524414.40
# Wind Replacement:   $0.00
# Wind Salvage:      -$133718533.66
# Battery CAPEX:      $1290362655.99
# Battery OPEX:       $388744238.99
# Battery Replacement:$48249586.70
# Battery Salvage:   -$468891045.57
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3164818351.80
#
# === 2024 Solar Results 98% met (Dispatch Load Factor 0.43) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          2           12 0.0963     0.000002
# discharge         14           36 0.3448     0.000021
# discharge         40           62 0.5183     0.000044
# discharge         70           79 0.2529     0.000012
# discharge         87          109 0.1250     0.000003
# discharge        121          133 0.2308     0.000010
# discharge        148          157 0.1063     0.000003
# discharge        160          175 0.1809     0.000007
# discharge        182          201 0.0660     0.000001
# discharge        229          253 0.0638     0.000001
# discharge        301          315 0.0887     0.000002
# discharge        325          348 0.1351     0.000004
# discharge        352          372 0.1028     0.000002
# discharge        374          396 0.3336     0.000020
# discharge        422          441 0.3205     0.000019
# discharge        446          468 0.0807     0.000002
# discharge        469          492 0.2967     0.000016
# discharge        494          514 0.0902     0.000002
# discharge        544          566 0.0513     0.000001
# discharge        569          589 0.4580     0.000036
# discharge        598          602 0.0657     0.000001
# discharge        604          613 0.1758     0.000006
# discharge        661          685 0.4174     0.000030
# discharge        688          700 0.1527     0.000005
# discharge        733          756 0.4352     0.000032
# discharge        781          804 0.2633     0.000013
# discharge        877          900 0.1206     0.000003
# discharge        974          996 0.1957     0.000008
# discharge       1022         1044 0.1501     0.000005
# discharge       1046         1068 0.2055     0.000008
# discharge       1088         1116 0.3075     0.000017
# discharge       1122         1164 0.3752     0.000025
# discharge       1166         1188 0.2781     0.000015
# discharge       1190         1212 0.1858     0.000007
# discharge       1214         1228 0.1256     0.000004
# discharge       1237         1284 0.0740     0.000001
# discharge       1285         1323 0.1003     0.000002
# discharge       1333         1428 0.1893     0.000007
# discharge       1430         1452 0.2607     0.000013
# discharge       1454         1476 0.4661     0.000037
# discharge       1501         1548 0.1356     0.000004
# discharge       1552         1567 0.2103     0.000009
# discharge       1574         1596 0.2613     0.000013
# discharge       1599         1614 0.1130     0.000003
# discharge       1623         1638 0.2113     0.000009
# discharge       1647         1660 0.0541     0.000001
# discharge       1669         1691 0.3190     0.000019
# discharge       1694         1715 0.1435     0.000004
# discharge       1780         1811 0.2809     0.000015
# discharge       1814         1827 0.1205     0.000003
# discharge       1829         1835 0.1179     0.000003
# discharge       1860         1883 0.2932     0.000016
# discharge       1886         1931 0.2088     0.000009
# discharge       1934         1956 0.2460     0.000012
# discharge       1962         1972 0.0809     0.000002
# discharge       2005         2042 0.0664     0.000001
# discharge       2045         2049 0.0792     0.000002
# discharge       2077         2099 0.1919     0.000008
# discharge       2102         2119 0.2037     0.000008
# discharge       2329         2363 0.1915     0.000007
# discharge       2389         2407 0.1439     0.000004
# discharge       2415         2429 0.0543     0.000001
# discharge       2436         2483 0.1850     0.000007
# discharge       2532         2547 0.0616     0.000001
# discharge       2557         2603 0.1020     0.000002
# discharge       2649         2670 0.0711     0.000001
# discharge       2677         2699 0.2663     0.000013
# discharge       2721         2747 0.0755     0.000001
# discharge       2772         2795 0.0744     0.000001
# discharge       2798         2891 0.3835     0.000026
# discharge       2895         2909 0.1070     0.000003
# discharge       2912         2915 0.0607     0.000001
# discharge       2918         2938 0.1192     0.000003
# discharge       2941         2963 0.3427     0.000021
# discharge       2967         2987 0.3945     0.000027
# discharge       2992         3011 0.3838     0.000026
# discharge       3017         3035 0.2103     0.000009
# discharge       3132         3155 0.3334     0.000020
# discharge       3158         3179 0.2588     0.000013
# discharge       3182         3195 0.0626     0.000001
# discharge       3196         3204 0.1729     0.000006
# discharge       3208         3227 0.0591     0.000001
# discharge       3229         3251 0.1004     0.000002
# discharge       3253         3275 0.3073     0.000017
# discharge       3278         3299 0.2786     0.000015
# discharge       3303         3323 0.2553     0.000013
# discharge       3328         3347 0.3703     0.000024
# discharge       3350         3371 0.2256     0.000010
# discharge       3374         3394 0.1011     0.000002
# discharge       3434         3443 0.1718     0.000006
# discharge       3447         3466 0.1472     0.000005
# discharge       3471         3491 0.1339     0.000004
# discharge       3494         3509 0.0521     0.000001
# discharge       3540         3563 0.2268     0.000010
# discharge       3566         3587 0.3202     0.000019
# discharge       3612         3634 0.0525     0.000001
# discharge       3637         3659 0.0722     0.000001
# discharge       3662         3683 0.3424     0.000021
# discharge       3686         3707 0.2682     0.000014
# discharge       3725         3731 0.0604     0.000001
# discharge       3733         3754 0.0942     0.000002
# discharge       3757         3779 0.3212     0.000019
# discharge       3782         3802 0.0670     0.000001
# discharge       3805         3826 0.2613     0.000013
# discharge       3849         3875 0.1213     0.000003
# discharge       3901         3923 0.1476     0.000005
# discharge       3926         3947 0.3281     0.000020
# discharge       3950         3971 0.3438     0.000021
# discharge       3974         3995 0.3323     0.000020
# discharge       3999         4018 0.2465     0.000012
# discharge       4022         4043 0.1021     0.000002
# discharge       4046         4067 0.2021     0.000008
# discharge       4071         4090 0.2168     0.000009
# discharge       4094         4114 0.1351     0.000004
# discharge       4117         4139 0.2429     0.000011
# discharge       4142         4163 0.3202     0.000019
# discharge       4166         4181 0.1231     0.000003
# discharge       4189         4211 0.3381     0.000021
# discharge       4215         4235 0.3303     0.000020
# discharge       4238         4258 0.2298     0.000010
# discharge       4284         4307 0.1947     0.000008
# discharge       4310         4331 0.2003     0.000008
# discharge       4334         4355 0.1694     0.000006
# discharge       4358         4378 0.0843     0.000002
# discharge       4381         4403 0.0978     0.000002
# discharge       4405         4426 0.2345     0.000011
# discharge       4430         4451 0.1389     0.000004
# discharge       4453         4475 0.1470     0.000005
# discharge       4478         4498 0.2272     0.000010
# discharge       4502         4523 0.2248     0.000010
# discharge       4526         4547 0.3506     0.000022
# discharge       4565         4595 0.1284     0.000004
# discharge       4597         4619 0.3558     0.000023
# discharge       4622         4643 0.3431     0.000021
# discharge       4647         4667 0.2675     0.000014
# discharge       4671         4691 0.3506     0.000022
# discharge       4695         4715 0.2118     0.000009
# discharge       4718         4738 0.2031     0.000008
# discharge       4742         4764 0.1861     0.000007
# discharge       4768         4787 0.2487     0.000012
# discharge       4812         4835 0.2248     0.000010
# discharge       4838         4859 0.2981     0.000016
# discharge       4862         4883 0.2546     0.000012
# discharge       4886         4908 0.4013     0.000028
# discharge       4917         4931 0.3472     0.000022
# discharge       4937         4955 0.3514     0.000022
# discharge       4960         4979 0.3970     0.000028
# discharge       4985         5004 0.3907     0.000027
# discharge       5009         5027 0.3762     0.000025
# discharge       5031         5051 0.0776     0.000001
# discharge       5053         5075 0.0909     0.000002
# discharge       5077         5099 0.1590     0.000005
# discharge       5102         5123 0.0833     0.000002
# discharge       5125         5147 0.1433     0.000004
# discharge       5150         5171 0.2643     0.000013
# discharge       5174         5195 0.2814     0.000015
# discharge       5198         5219 0.2139     0.000009
# discharge       5222         5243 0.3023     0.000017
# discharge       5246         5267 0.1659     0.000006
# discharge       5269         5291 0.1619     0.000006
# discharge       5293         5315 0.0922     0.000002
# discharge       5317         5339 0.0658     0.000001
# discharge       5341         5363 0.2252     0.000010
# discharge       5366         5387 0.2991     0.000017
# discharge       5390         5411 0.3708     0.000024
# discharge       5415         5435 0.3290     0.000020
# discharge       5439         5459 0.2892     0.000016
# discharge       5462         5483 0.1262     0.000004
# discharge       5485         5508 0.3108     0.000018
# discharge       5511         5531 0.3612     0.000023
# discharge       5535         5555 0.1685     0.000006
# discharge       5558         5579 0.0958     0.000002
# discharge       5581         5603 0.0744     0.000001
# discharge       5605         5627 0.0559     0.000001
# discharge       5642         5651 0.1198     0.000003
# discharge       5653         5675 0.1479     0.000005
# discharge       5678         5699 0.1706     0.000006
# discharge       5702         5723 0.3148     0.000018
# discharge       5726         5747 0.3777     0.000025
# discharge       5751         5771 0.3841     0.000026
# discharge       5775         5795 0.3463     0.000022
# discharge       5799         5819 0.3578     0.000023
# discharge       5823         5843 0.4088     0.000029
# discharge       5848         5868 0.3564     0.000023
# discharge       5873         5891 0.2460     0.000012
# discharge       5930         5940 0.1566     0.000005
# discharge       5943         5963 0.2529     0.000012
# discharge       5966         5987 0.3812     0.000026
# discharge       5991         6005 0.1563     0.000005
# discharge       6085         6107 0.2673     0.000014
# discharge       6156         6180 0.3850     0.000026
# discharge       6204         6251 0.3550     0.000023
# discharge       6255         6275 0.3223     0.000019
# discharge       6279         6299 0.3901     0.000027
# discharge       6303         6323 0.3923     0.000027
# discharge       6327         6348 0.2948     0.000016
# discharge       6352         6372 0.3212     0.000019
# discharge       6375         6396 0.3009     0.000017
# discharge       6399         6420 0.3128     0.000018
# discharge       6424         6444 0.2801     0.000015
# discharge       6447         6467 0.1450     0.000005
# discharge       6470         6540 0.2545     0.000012
# discharge       6543         6564 0.3324     0.000020
# discharge       6567         6587 0.3961     0.000027
# discharge       6612         6635 0.3367     0.000021
# discharge       6638         6660 0.2460     0.000012
# discharge       6662         6684 0.2453     0.000012
# discharge       6686         6708 0.4099     0.000029
# discharge       6711         6724 0.1345     0.000004
# discharge       6805         6828 0.3545     0.000022
# discharge       6831         6852 0.3093     0.000018
# discharge       6901         6924 0.3667     0.000024
# discharge       6949         6972 0.2673     0.000014
# discharge       6974         6996 0.2365     0.000011
# discharge       6998         7020 0.2411     0.000011
# discharge       7023         7044 0.3615     0.000023
# discharge       7047         7068 0.3687     0.000024
# discharge       7071         7085 0.1579     0.000005
# discharge       7117         7140 0.1329     0.000004
# discharge       7142         7156 0.0781     0.000002
# discharge       7165         7188 0.1826     0.000007
# discharge       7204         7212 0.0973     0.000002
# discharge       7214         7236 0.1472     0.000005
# discharge       7238         7332 0.3150     0.000018
# discharge       7335         7356 0.2040     0.000008
# discharge       7397         7452 0.3169     0.000018
# discharge       7457         7476 0.2670     0.000014
# discharge       7489         7500 0.0970     0.000002
# discharge       7502         7524 0.1012     0.000002
# discharge       7527         7542 0.1226     0.000003
# discharge       7544         7549 0.0799     0.000002
# discharge       7553         7566 0.1710     0.000006
# discharge       7574         7596 0.1467     0.000005
# discharge       7645         7668 0.3445     0.000021
# discharge       7671         7693 0.2011     0.000008
# discharge       7695         7706 0.0614     0.000001
# discharge       7738         7764 0.1278     0.000004
# discharge       7766         7781 0.1860     0.000007
# discharge       7837         7861 0.4169     0.000030
# discharge       7864         7877 0.1335     0.000004
# discharge       7933         7957 0.2449     0.000012
# discharge       7981         8004 0.1568     0.000005
# discharge       8006         8028 0.4464     0.000034
# discharge       8046         8052 0.0944     0.000002
# discharge       8056         8076 0.3420     0.000021
# discharge       8089         8100 0.0880     0.000002
# discharge       8102         8116 0.1471     0.000005
# discharge       8149         8172 0.1634     0.000006
# discharge       8174         8196 0.3873     0.000026
# discharge       8199         8245 0.0509     0.000001
# discharge       8247         8269 0.3714     0.000024
# discharge       8272         8292 0.0710     0.000001
# discharge       8294         8316 0.2612     0.000013
# discharge       8319         8341 0.0778     0.000001
# discharge       8352         8389 0.1341     0.000004
# discharge       8391         8431 0.0687     0.000001
# discharge       8439         8453 0.1941     0.000008
# discharge       8465         8484 0.0856     0.000002
# discharge       8486         8498 0.0853     0.000002
# discharge       8509         8532 0.1034     0.000002
# discharge       8534         8556 0.3011     0.000017
# discharge       8559         8571 0.0927     0.000002
# discharge       8582         8605 0.1283     0.000004
# discharge       8607         8617 0.0507     0.000001
# discharge       8618         8630 0.1360     0.000004
# discharge       8633         8653 0.1302     0.000004
# discharge       8693         8700 0.0728     0.000001
# discharge       8721         8749 0.1449     0.000005
#
# Total Estimated Degradation: 0.002934
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_43_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_43_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_43_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 98% met (Load Factor 0.43) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 0.00 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 0.00 kWh (Year 2024)

# %% [markdown]
# ## 55% of Training Load consumption (Intense Traffic)

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_98_percent_met_55_percent_inference"
dispatch_load_factor = 0.55  # Apply 0.55 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.02 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 0)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} met Load 98% (Load Factor 0.55)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 98% met (Dispatch Load Factor 0.55) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 98% met (Load Factor 0.55)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 98% met (Load Factor 0.55) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Optimal Solution Found!
# Solar Capacity: 6791589.11 kW
# Wind Capacity: 132.24 kW
# Battery Capacity: 3591077.97 kWh
# Total NPC: $3116568765.10
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2525987634.16 kWh
# Total Energy Generated: 4104327650.70 kWh
# Total Energy Used (along with efficiency losses): 1578340016.54 kWh
# Utilization Percentage: 38.46%
# $7612263.59 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 6791589.11 kW
# Solar Initial Cost:    $631278207.83
# Wind Initial Capacity: 132.24 kW
# Wind Initial Cost:     $676271055.47
# Battery Initial Capacity: 3591077.97 kWh
# Battery Initial Cost:  $1285605914.11
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -21733.09 kW
# Solar Redundant Cost:    $-2020090.27
# Wind Redundant Capacity: 11.67 kW
# Wind Redundant Cost:     $59701208.78
# Battery Redundant Capacity: 13286.99 kWh
# Battery Redundant Cost:  $4756741.88
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $629258117.57
# Solar OPEX:         $687316420.67
# Solar Replacement:  $0.00
# Solar Salvage:     -$182927486.51
# Wind CAPEX:         $735972264.24
# Wind OPEX:          $157524414.40
# Wind Replacement:   $0.00
# Wind Salvage:      -$133718533.66
# Battery CAPEX:      $1290362655.99
# Battery OPEX:       $388744238.99
# Battery Replacement:$96719346.74
# Battery Salvage:   -$468891045.57
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3213288111.85
#
# === 2024 Solar Results 98% met (Dispatch Load Factor 0.55) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          2           12 0.1749     0.000006
# discharge         14           36 0.4728     0.000038
# discharge         41           62 0.6736     0.000071
# discharge         70           84 0.4063     0.000029
# discharge         88          109 0.2626     0.000013
# discharge        121          133 0.3404     0.000021
# discharge        138          158 0.2675     0.000014
# discharge        161          180 0.2810     0.000015
# discharge        198          201 0.0935     0.000002
# discharge        206          228 0.0700     0.000001
# discharge        230          253 0.1031     0.000002
# discharge        276          300 0.0836     0.000002
# discharge        302          315 0.1340     0.000004
# discharge        326          349 0.2825     0.000015
# discharge        353          372 0.2308     0.000010
# discharge        375          396 0.4613     0.000036
# discharge        425          441 0.4389     0.000033
# discharge        447          468 0.2087     0.000009
# discharge        470          492 0.4246     0.000031
# discharge        495          515 0.2053     0.000008
# discharge        518          542 0.0784     0.000002
# discharge        545          566 0.0787     0.000002
# discharge        569          590 0.6181     0.000061
# discharge        597          613 0.3700     0.000024
# discharge        618          633 0.1069     0.000003
# discharge        649          660 0.0975     0.000002
# discharge        662          685 0.5542     0.000050
# discharge        689          708 0.2600     0.000013
# discharge        720          732 0.1215     0.000003
# discharge        734          756 0.5631     0.000052
# discharge        760          780 0.1852     0.000007
# discharge        782          804 0.3913     0.000027
# discharge        808          817 0.0753     0.000001
# discharge        831          847 0.1149     0.000003
# discharge        877          900 0.2492     0.000012
# discharge        976          996 0.3336     0.000020
# discharge       1015         1021 0.0799     0.000002
# discharge       1023         1044 0.2582     0.000013
# discharge       1047         1068 0.3337     0.000020
# discharge       1071         1083 0.0746     0.000001
# discharge       1093         1116 0.4358     0.000033
# discharge       1124         1164 0.5037     0.000042
# discharge       1167         1188 0.4067     0.000029
# discharge       1191         1212 0.3141     0.000018
# discharge       1215         1229 0.1866     0.000007
# discharge       1276         1284 0.1398     0.000004
# discharge       1299         1325 0.1563     0.000005
# discharge       1334         1428 0.3184     0.000019
# discharge       1431         1452 0.3897     0.000027
# discharge       1455         1476 0.6041     0.000058
# discharge       1481         1492 0.0907     0.000002
# discharge       1525         1549 0.2328     0.000011
# discharge       1553         1572 0.3365     0.000020
# discharge       1575         1596 0.3909     0.000027
# discharge       1600         1620 0.2112     0.000009
# discharge       1625         1638 0.2850     0.000015
# discharge       1648         1667 0.2018     0.000008
# discharge       1670         1691 0.4390     0.000033
# discharge       1695         1715 0.2545     0.000012
# discharge       1740         1778 0.0531     0.000001
# discharge       1790         1812 0.4051     0.000029
# discharge       1815         1827 0.1669     0.000006
# discharge       1829         1836 0.1746     0.000006
# discharge       1861         1883 0.4047     0.000029
# discharge       1909         1931 0.3294     0.000020
# discharge       1935         1956 0.3761     0.000025
# discharge       1965         1972 0.1458     0.000005
# discharge       1981         2004 0.0834     0.000002
# discharge       2006         2042 0.0989     0.000002
# discharge       2044         2051 0.1340     0.000004
# discharge       2055         2075 0.1397     0.000004
# discharge       2077         2099 0.3035     0.000017
# discharge       2102         2123 0.3037     0.000017
# discharge       2196         2243 0.0660     0.000001
# discharge       2268         2291 0.1050     0.000003
# discharge       2293         2315 0.1437     0.000004
# discharge       2339         2363 0.2672     0.000014
# discharge       2390         2411 0.2457     0.000012
# discharge       2418         2433 0.1264     0.000004
# discharge       2460         2483 0.2973     0.000016
# discharge       2486         2531 0.0638     0.000001
# discharge       2533         2555 0.1588     0.000005
# discharge       2557         2603 0.2143     0.000009
# discharge       2628         2647 0.0865     0.000002
# discharge       2654         2671 0.1535     0.000005
# discharge       2678         2699 0.3792     0.000025
# discharge       2702         2723 0.0901     0.000002
# discharge       2725         2747 0.1239     0.000003
# discharge       2765         2771 0.0545     0.000001
# discharge       2773         2795 0.1853     0.000007
# discharge       2869         2891 0.5054     0.000042
# discharge       2895         2915 0.2670     0.000014
# discharge       2918         2939 0.2318     0.000011
# discharge       2942         2963 0.4656     0.000037
# discharge       2968         2987 0.5167     0.000044
# discharge       2993         3011 0.4971     0.000041
# discharge       3018         3035 0.3330     0.000020
# discharge       3038         3055 0.0518     0.000001
# discharge       3109         3131 0.1599     0.000005
# discharge       3133         3155 0.4468     0.000034
# discharge       3159         3179 0.3722     0.000025
# discharge       3183         3204 0.3669     0.000024
# discharge       3219         3227 0.1048     0.000003
# discharge       3229         3251 0.2144     0.000009
# discharge       3254         3275 0.4202     0.000031
# discharge       3279         3300 0.4112     0.000029
# discharge       3304         3323 0.3691     0.000024
# discharge       3329         3347 0.4839     0.000039
# discharge       3351         3371 0.3393     0.000021
# discharge       3375         3394 0.2058     0.000009
# discharge       3398         3416 0.0592     0.000001
# discharge       3421         3443 0.2900     0.000016
# discharge       3447         3467 0.2685     0.000014
# discharge       3473         3491 0.2465     0.000012
# discharge       3494         3512 0.1170     0.000003
# discharge       3540         3563 0.3357     0.000020
# discharge       3566         3587 0.4329     0.000032
# discharge       3591         3611 0.1647     0.000006
# discharge       3613         3635 0.1559     0.000005
# discharge       3639         3660 0.1176     0.000003
# discharge       3662         3683 0.4568     0.000035
# discharge       3687         3707 0.3825     0.000026
# discharge       3712         3731 0.2017     0.000008
# discharge       3734         3755 0.1896     0.000007
# discharge       3758         3779 0.4349     0.000032
# discharge       3783         3803 0.1704     0.000006
# discharge       3806         3826 0.3656     0.000024
# discharge       3830         3849 0.0631     0.000001
# discharge       3853         3875 0.2067     0.000009
# discharge       3878         3899 0.1522     0.000005
# discharge       3901         3923 0.2616     0.000013
# discharge       3926         3947 0.4423     0.000033
# discharge       3951         3971 0.4584     0.000036
# discharge       3975         3995 0.4469     0.000034
# discharge       3999         4019 0.3600     0.000023
# discharge       4023         4043 0.2080     0.000009
# discharge       4047         4067 0.3161     0.000018
# discharge       4072         4091 0.3266     0.000019
# discharge       4095         4115 0.2350     0.000011
# discharge       4118         4139 0.3567     0.000023
# discharge       4143         4163 0.4342     0.000032
# discharge       4167         4186 0.2172     0.000009
# discharge       4190         4211 0.4524     0.000035
# discharge       4215         4235 0.4443     0.000034
# discharge       4239         4258 0.3341     0.000020
# discharge       4263         4282 0.1371     0.000004
# discharge       4285         4307 0.2991     0.000017
# discharge       4311         4331 0.3140     0.000018
# discharge       4335         4355 0.2832     0.000015
# discharge       4359         4378 0.1789     0.000007
# discharge       4381         4403 0.2053     0.000008
# discharge       4406         4427 0.3442     0.000021
# discharge       4430         4451 0.2528     0.000012
# discharge       4454         4475 0.2603     0.000013
# discharge       4479         4499 0.3393     0.000021
# discharge       4503         4523 0.3391     0.000021
# discharge       4527         4547 0.4641     0.000036
# discharge       4552         4570 0.0717     0.000001
# discharge       4573         4595 0.2239     0.000010
# discharge       4598         4619 0.4697     0.000037
# discharge       4623         4643 0.4562     0.000035
# discharge       4647         4667 0.3810     0.000026
# discharge       4671         4691 0.4644     0.000036
# discharge       4696         4715 0.3254     0.000019
# discharge       4719         4739 0.3151     0.000018
# discharge       4742         4764 0.3089     0.000018
# discharge       4769         4787 0.3620     0.000023
# discharge       4791         4811 0.1070     0.000003
# discharge       4813         4835 0.3381     0.000021
# discharge       4839         4859 0.4111     0.000029
# discharge       4863         4883 0.3677     0.000024
# discharge       4887         4909 0.5265     0.000046
# discharge       4918         4932 0.4696     0.000037
# discharge       4939         4956 0.4729     0.000038
# discharge       4961         4980 0.5262     0.000046
# discharge       4987         5004 0.5137     0.000044
# discharge       5011         5027 0.4946     0.000041
# discharge       5033         5051 0.1905     0.000007
# discharge       5054         5075 0.2038     0.000008
# discharge       5078         5099 0.2712     0.000014
# discharge       5102         5123 0.1958     0.000008
# discharge       5126         5147 0.2559     0.000013
# discharge       5150         5171 0.3767     0.000025
# discharge       5175         5195 0.3938     0.000027
# discharge       5199         5219 0.3261     0.000019
# discharge       5223         5243 0.4148     0.000030
# discharge       5247         5267 0.2783     0.000015
# discharge       5270         5291 0.2740     0.000014
# discharge       5294         5315 0.2049     0.000008
# discharge       5318         5339 0.1779     0.000007
# discharge       5342         5363 0.3368     0.000021
# discharge       5367         5387 0.4109     0.000029
# discharge       5391         5411 0.4828     0.000039
# discharge       5415         5435 0.4425     0.000033
# discharge       5439         5459 0.4007     0.000028
# discharge       5463         5483 0.2384     0.000011
# discharge       5486         5508 0.4318     0.000032
# discharge       5512         5531 0.4728     0.000038
# discharge       5535         5555 0.2797     0.000015
# discharge       5558         5579 0.2071     0.000009
# discharge       5582         5603 0.1784     0.000007
# discharge       5606         5627 0.1547     0.000005
# discharge       5630         5651 0.2521     0.000012
# discharge       5654         5675 0.2590     0.000013
# discharge       5678         5699 0.2817     0.000015
# discharge       5702         5723 0.4258     0.000031
# discharge       5727         5747 0.4883     0.000040
# discharge       5751         5771 0.4949     0.000041
# discharge       5775         5795 0.4569     0.000035
# discharge       5800         5819 0.4683     0.000037
# discharge       5824         5844 0.5367     0.000047
# discharge       5849         5868 0.4763     0.000038
# discharge       5874         5891 0.3593     0.000023
# discharge       5894         5915 0.1068     0.000003
# discharge       5918         5940 0.2763     0.000014
# discharge       5944         5963 0.3728     0.000025
# discharge       5967         5988 0.4992     0.000042
# discharge       5992         6005 0.2205     0.000010
# discharge       6026         6035 0.0611     0.000001
# discharge       6037         6059 0.0791     0.000002
# discharge       6061         6083 0.1533     0.000005
# discharge       6086         6107 0.3781     0.000025
# discharge       6111         6131 0.0672     0.000001
# discharge       6157         6180 0.5135     0.000044
# discharge       6185         6204 0.0884     0.000002
# discharge       6227         6251 0.4738     0.000038
# discharge       6255         6275 0.4321     0.000032
# discharge       6279         6300 0.5008     0.000042
# discharge       6303         6324 0.5114     0.000043
# discharge       6327         6348 0.4202     0.000031
# discharge       6354         6372 0.4484     0.000034
# discharge       6376         6396 0.4260     0.000031
# discharge       6400         6420 0.4493     0.000034
# discharge       6425         6444 0.4037     0.000028
# discharge       6448         6467 0.2576     0.000013
# discharge       6517         6540 0.3817     0.000026
# discharge       6544         6564 0.4589     0.000036
# discharge       6567         6588 0.5224     0.000045
# discharge       6591         6611 0.0712     0.000001
# discharge       6613         6636 0.4586     0.000036
# discharge       6639         6660 0.3725     0.000025
# discharge       6663         6684 0.3720     0.000025
# discharge       6687         6708 0.5365     0.000047
# discharge       6711         6731 0.2144     0.000009
# discharge       6734         6755 0.0724     0.000001
# discharge       6757         6779 0.1532     0.000005
# discharge       6782         6804 0.1496     0.000005
# discharge       6806         6828 0.4809     0.000039
# discharge       6831         6852 0.4356     0.000033
# discharge       6877         6890 0.0627     0.000001
# discharge       6901         6924 0.4927     0.000041
# discharge       6927         6948 0.1024     0.000002
# discharge       6949         6972 0.3934     0.000027
# discharge       6975         6996 0.3624     0.000023
# discharge       6999         7020 0.3670     0.000024
# discharge       7023         7044 0.4874     0.000040
# discharge       7047         7068 0.4946     0.000041
# discharge       7071         7091 0.2478     0.000012
# discharge       7117         7140 0.2586     0.000013
# discharge       7143         7164 0.1874     0.000007
# discharge       7166         7188 0.3081     0.000018
# discharge       7192         7212 0.2639     0.000013
# discharge       7215         7236 0.2729     0.000014
# discharge       7296         7332 0.4492     0.000034
# discharge       7336         7357 0.3309     0.000020
# discharge       7360         7380 0.1525     0.000005
# discharge       7383         7396 0.0520     0.000001
# discharge       7403         7453 0.4386     0.000033
# discharge       7458         7476 0.3921     0.000027
# discharge       7480         7500 0.2238     0.000010
# discharge       7503         7524 0.2162     0.000009
# discharge       7529         7549 0.3421     0.000021
# discharge       7554         7572 0.3339     0.000020
# discharge       7575         7596 0.2721     0.000014
# discharge       7608         7621 0.1356     0.000004
# discharge       7625         7644 0.1565     0.000005
# discharge       7646         7668 0.4697     0.000037
# discharge       7672         7693 0.3351     0.000020
# discharge       7696         7716 0.2078     0.000009
# discharge       7742         7764 0.1907     0.000007
# discharge       7767         7782 0.2574     0.000013
# discharge       7837         7861 0.5518     0.000050
# discharge       7865         7884 0.2570     0.000013
# discharge       7887         7932 0.0639     0.000001
# discharge       7934         7957 0.3793     0.000025
# discharge       7982         8004 0.2826     0.000015
# discharge       8007         8028 0.5721     0.000053
# discharge       8032         8053 0.2548     0.000012
# discharge       8057         8076 0.4675     0.000037
# discharge       8092         8100 0.1570     0.000005
# discharge       8102         8123 0.2168     0.000009
# discharge       8126         8146 0.0720     0.000001
# discharge       8150         8172 0.2865     0.000015
# discharge       8175         8196 0.5133     0.000044
# discharge       8239         8245 0.1030     0.000002
# discharge       8247         8269 0.5066     0.000043
# discharge       8282         8292 0.1498     0.000005
# discharge       8294         8316 0.3694     0.000024
# discharge       8331         8342 0.1528     0.000005
# discharge       8366         8389 0.2134     0.000009
# discharge       8406         8437 0.2217     0.000010
# discharge       8440         8453 0.2665     0.000014
# discharge       8458         8461 0.0514     0.000001
# discharge       8467         8484 0.1897     0.000007
# discharge       8486         8499 0.1274     0.000004
# discharge       8510         8532 0.2176     0.000009
# discharge       8535         8556 0.4286     0.000032
# discharge       8559         8580 0.1583     0.000005
# discharge       8582         8605 0.2186     0.000009
# discharge       8608         8630 0.3417     0.000021
# discharge       8635         8653 0.2851     0.000015
# discharge       8667         8700 0.2058     0.000008
# discharge       8707         8718 0.0557     0.000001
# discharge       8736         8749 0.2283     0.000010
#
# Total Estimated Degradation: 0.005865
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_55_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_55_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_55_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 98% met (Load Factor 0.55) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 95443.48 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 106698.77 kWh
# Year 2016: Unmet Load = 506372.59 kWh
# Year 2015: Unmet Load = 2035217.42 kWh
# Year 2014: Unmet Load = 237817.12 kWh
# Year 2013: Unmet Load = 304828.81 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 438138.91 kWh
# Year 2004: Unmet Load = 898319.79 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 211888.32 kWh
# Year 2001: Unmet Load = 106167.15 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 3691.36 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 114630.44 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 350885.31 kWh
# Year 1991: Unmet Load = 261677.75 kWh
# Year 1990: Unmet Load = 26021.27 kWh
# Year 1989: Unmet Load = 192702.34 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 424301.95 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 140328.95 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 2035217.42 kWh (Year 2015)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_98_percent_met_55_percent_inference"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) 55% reduction (Case 2) in LP for 98% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 71% Load Factor (Intense Traffic)

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_98_percent_met_71_percent_inference"
dispatch_load_factor = 0.71  # Apply 0.71 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.02 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 98% met (Load Factor 0.71)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 98% met (Dispatch Load Factor 0.71) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 98% met (Load Factor 0.71)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 98% met (Load Factor 0.71) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0x63f944d6
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 4e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 11s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 27s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 26.78s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.276474e+05   3.669944e+06     44s
#      559    1.8116293e+12   0.000000e+00   7.304501e+07     45s
#     5532    1.6946928e+11   0.000000e+00   1.954417e+12     50s
#     7408    6.6850176e+10   2.782285e-03   1.838337e+12     55s
#     8962    3.4394978e+10   3.919835e-03   1.119004e+12     60s
#    10866    2.3843277e+10   1.377520e-03   3.313309e+12     65s
#    12470    1.9501913e+10   6.472504e-04   1.578143e+13     70s
#    14166    1.4397925e+10   8.283712e-04   6.094263e+06     75s
#    15688    1.2386109e+10   0.000000e+00   1.222664e+09     81s
#    17047    1.0768616e+10   2.418125e-03   3.507255e+11     85s
#    18581    9.3220522e+09   4.024979e-05   6.266955e+09     90s
#    19951    8.4232200e+09   1.590244e-03   1.364126e+10     95s
#    26915   -2.8980748e+10   3.439261e+11   0.000000e+00    100s
#    29341   -2.7979266e+10   7.998830e+11   0.000000e+00    105s
# Concurrent spin time: 24.65s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 3.104762e+09, 41971 iterations, 85.82 seconds (63.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.1048e+09    0    2          - 3.1048e+09      -     -  129s
# H    0     0                    3.116569e+09 3.1048e+09  0.38%     -  133s
#
# Explored 1 nodes (41971 simplex iterations) in 134.11 seconds (131.40 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.11657e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.116568765102e+09, best bound 3.104761916190e+09, gap 0.3788%
# Optimal Solution Found!
# Solar Capacity: 6791589.11 kW
# Wind Capacity: 132.24 kW
# Battery Capacity: 3591077.97 kWh
# Total NPC: $3116568765.10
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2154775856.21 kWh
# Total Energy Generated: 4104327650.70 kWh
# Total Energy Used (along with efficiency losses): 1949551794.49 kWh
# Utilization Percentage: 47.50%
# $15464273.25 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 6791589.11 kW
# Solar Initial Cost:    $631278207.83
# Wind Initial Capacity: 132.24 kW
# Wind Initial Cost:     $676271055.47
# Battery Initial Capacity: 3591077.97 kWh
# Battery Initial Cost:  $1285605914.11
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -21733.09 kW
# Solar Redundant Cost:    $-2020090.27
# Wind Redundant Capacity: 11.67 kW
# Wind Redundant Cost:     $59701208.78
# Battery Redundant Capacity: 13286.99 kWh
# Battery Redundant Cost:  $4756741.88
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $629258117.57
# Solar OPEX:         $687316420.67
# Solar Replacement:  $0.00
# Solar Salvage:     -$182927486.51
# Wind CAPEX:         $735972264.24
# Wind OPEX:          $157524414.40
# Wind Replacement:   $0.00
# Wind Salvage:      -$133718533.66
# Battery CAPEX:      $1290362655.99
# Battery OPEX:       $388744238.99
# Battery Replacement:$196484841.72
# Battery Salvage:   -$468891045.57
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3313053606.83
#
# === 2024 Solar Results 98% met (Dispatch Load Factor 0.71) ===
# Total Unmet Load: 938885.08 kWh
# Hours with Unmet Load: [82, 83, 84, 608, 609, 610, 611, 612, 613, 4930, 4931, 4932]
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           12 0.3148     0.000018
# discharge         15           36 0.6434     0.000065
# discharge         41           62 0.8807     0.000115
# discharge         69           84 0.5051     0.000042
# discharge         89          110 0.4508     0.000035
# discharge        115          133 0.5898     0.000056
# discharge        141          158 0.4749     0.000038
# discharge        162          180 0.4518     0.000035
# discharge        184          202 0.1640     0.000006
# discharge        207          228 0.1583     0.000005
# discharge        230          253 0.1782     0.000007
# discharge        280          300 0.1569     0.000005
# discharge        302          324 0.2923     0.000016
# discharge        327          349 0.4896     0.000040
# discharge        355          373 0.4159     0.000030
# discharge        375          396 0.6316     0.000063
# discharge        400          423 0.1735     0.000006
# discharge        427          442 0.6083     0.000059
# discharge        448          468 0.3794     0.000025
# discharge        471          492 0.5952     0.000057
# discharge        496          516 0.3743     0.000025
# discharge        533          542 0.1392     0.000004
# discharge        554          567 0.1398     0.000004
# discharge        571          590 0.8412     0.000106
# discharge        597          613 0.3789     0.000025
# discharge        619          634 0.2413     0.000011
# discharge        642          660 0.2682     0.000014
# discharge        663          685 0.7366     0.000083
# discharge        689          709 0.4360     0.000033
# discharge        712          732 0.2879     0.000016
# discharge        735          756 0.7336     0.000083
# discharge        761          780 0.3682     0.000024
# discharge        783          805 0.5628     0.000051
# discharge        810          818 0.1362     0.000004
# discharge        820          829 0.0775     0.000001
# discharge        836          852 0.3141     0.000018
# discharge        855          876 0.1740     0.000006
# discharge        878          900 0.4207     0.000031
# discharge        904          924 0.1470     0.000005
# discharge        942          949 0.0580     0.000001
# discharge        952          974 0.2057     0.000008
# discharge        981          996 0.5174     0.000044
# discharge       1000         1021 0.2625     0.000013
# discharge       1025         1044 0.4289     0.000032
# discharge       1047         1068 0.5047     0.000042
# discharge       1071         1092 0.2325     0.000011
# discharge       1094         1117 0.6154     0.000060
# discharge       1141         1164 0.6751     0.000071
# discharge       1167         1188 0.5782     0.000054
# discharge       1191         1212 0.4852     0.000039
# discharge       1215         1236 0.3483     0.000022
# discharge       1239         1284 0.3021     0.000017
# discharge       1287         1299 0.0530     0.000001
# discharge       1309         1332 0.3203     0.000019
# discharge       1357         1428 0.4906     0.000040
# discharge       1432         1452 0.5617     0.000051
# discharge       1456         1477 0.7918     0.000095
# discharge       1482         1500 0.2890     0.000016
# discharge       1502         1524 0.1550     0.000005
# discharge       1526         1549 0.4092     0.000029
# discharge       1555         1572 0.5208     0.000045
# discharge       1576         1596 0.5637     0.000052
# discharge       1601         1620 0.3958     0.000027
# discharge       1628         1644 0.4500     0.000034
# discharge       1649         1668 0.3619     0.000023
# discharge       1671         1692 0.6057     0.000059
# discharge       1695         1716 0.4251     0.000031
# discharge       1719         1739 0.1616     0.000006
# discharge       1742         1763 0.0602     0.000001
# discharge       1766         1779 0.1095     0.000003
# discharge       1793         1812 0.5779     0.000054
# discharge       1815         1836 0.5077     0.000043
# discharge       1840         1859 0.2116     0.000009
# discharge       1862         1884 0.5601     0.000051
# discharge       1897         1907 0.0906     0.000002
# discharge       1909         1932 0.4976     0.000041
# discharge       1936         1956 0.5496     0.000049
# discharge       1964         1973 0.2462     0.000012
# discharge       1983         2004 0.2444     0.000012
# discharge       2028         2042 0.1481     0.000005
# discharge       2043         2052 0.2261     0.000010
# discharge       2055         2075 0.2877     0.000015
# discharge       2078         2099 0.4522     0.000035
# discharge       2103         2123 0.4531     0.000035
# discharge       2127         2147 0.0858     0.000002
# discharge       2149         2171 0.1643     0.000006
# discharge       2174         2195 0.1213     0.000003
# discharge       2211         2243 0.1633     0.000006
# discharge       2245         2267 0.1157     0.000003
# discharge       2269         2291 0.2480     0.000012
# discharge       2294         2316 0.2942     0.000016
# discharge       2319         2339 0.1416     0.000004
# discharge       2341         2363 0.3908     0.000027
# discharge       2380         2388 0.0994     0.000002
# discharge       2391         2411 0.4202     0.000031
# discharge       2423         2435 0.2573     0.000013
# discharge       2460         2483 0.4471     0.000034
# discharge       2487         2507 0.0837     0.000002
# discharge       2509         2531 0.1882     0.000007
# discharge       2534         2555 0.3144     0.000018
# discharge       2581         2603 0.3733     0.000025
# discharge       2607         2627 0.1798     0.000007
# discharge       2630         2651 0.2418     0.000011
# discharge       2655         2675 0.3148     0.000018
# discharge       2678         2699 0.5298     0.000046
# discharge       2703         2723 0.2399     0.000011
# discharge       2726         2747 0.2284     0.000010
# discharge       2750         2771 0.2291     0.000010
# discharge       2774         2796 0.3419     0.000021
# discharge       2821         2843 0.0510     0.000001
# discharge       2845         2868 0.0905     0.000002
# discharge       2871         2891 0.6678     0.000070
# discharge       2896         2915 0.4182     0.000030
# discharge       2919         2939 0.3823     0.000026
# discharge       2943         2963 0.6294     0.000063
# discharge       2969         2988 0.6829     0.000073
# discharge       2994         3012 0.6562     0.000068
# discharge       3021         3035 0.5013     0.000042
# discharge       3039         3059 0.2002     0.000008
# discharge       3062         3083 0.0953     0.000002
# discharge       3103         3107 0.0715     0.000001
# discharge       3110         3131 0.3111     0.000018
# discharge       3134         3155 0.5981     0.000057
# discharge       3159         3179 0.5234     0.000045
# discharge       3184         3205 0.5491     0.000049
# discharge       3211         3227 0.2630     0.000013
# discharge       3230         3251 0.3663     0.000024
# discharge       3255         3275 0.5707     0.000053
# discharge       3280         3300 0.5884     0.000056
# discharge       3305         3324 0.5248     0.000045
# discharge       3331         3347 0.6355     0.000064
# discharge       3352         3371 0.4909     0.000040
# discharge       3375         3395 0.3574     0.000023
# discharge       3398         3419 0.1777     0.000007
# discharge       3423         3444 0.4511     0.000035
# discharge       3449         3468 0.4346     0.000032
# discharge       3474         3491 0.3986     0.000028
# discharge       3495         3515 0.2598     0.000013
# discharge       3519         3539 0.0920     0.000002
# discharge       3541         3563 0.4875     0.000040
# discharge       3567         3587 0.5849     0.000055
# discharge       3592         3611 0.3166     0.000018
# discharge       3614         3636 0.3126     0.000018
# discharge       3651         3660 0.2131     0.000009
# discharge       3663         3683 0.6093     0.000059
# discharge       3688         3707 0.5350     0.000047
# discharge       3713         3731 0.3536     0.000022
# discharge       3735         3755 0.3316     0.000020
# discharge       3759         3779 0.5866     0.000055
# discharge       3783         3803 0.3222     0.000019
# discharge       3806         3826 0.5047     0.000042
# discharge       3832         3851 0.2100     0.000009
# discharge       3855         3875 0.3439     0.000021
# discharge       3878         3899 0.3007     0.000017
# discharge       3902         3923 0.4135     0.000030
# discharge       3927         3947 0.5946     0.000057
# discharge       3952         3971 0.6113     0.000060
# discharge       3976         3995 0.5997     0.000058
# discharge       4000         4019 0.5118     0.000043
# discharge       4023         4043 0.3606     0.000023
# discharge       4049         4067 0.4681     0.000037
# discharge       4073         4091 0.4785     0.000038
# discharge       4096         4115 0.3872     0.000026
# discharge       4119         4139 0.5084     0.000043
# discharge       4143         4163 0.5862     0.000055
# discharge       4168         4187 0.3691     0.000024
# discharge       4191         4211 0.6047     0.000059
# discharge       4216         4235 0.5964     0.000057
# discharge       4240         4259 0.4798     0.000039
# discharge       4263         4283 0.2872     0.000015
# discharge       4286         4307 0.4486     0.000034
# discharge       4311         4331 0.4654     0.000037
# discharge       4335         4355 0.4349     0.000032
# discharge       4360         4379 0.3213     0.000019
# discharge       4382         4403 0.3569     0.000023
# discharge       4407         4427 0.4961     0.000041
# discharge       4431         4451 0.4048     0.000029
# discharge       4455         4475 0.4114     0.000029
# discharge       4480         4499 0.4905     0.000040
# discharge       4504         4523 0.4915     0.000040
# discharge       4527         4547 0.6154     0.000060
# discharge       4553         4571 0.2169     0.000009
# discharge       4574         4595 0.3628     0.000023
# discharge       4599         4619 0.6215     0.000061
# discharge       4624         4643 0.6070     0.000059
# discharge       4648         4667 0.5323     0.000047
# discharge       4672         4691 0.6163     0.000061
# discharge       4696         4715 0.4769     0.000038
# discharge       4720         4739 0.4663     0.000037
# discharge       4743         4764 0.4726     0.000038
# discharge       4770         4787 0.5130     0.000044
# discharge       4792         4811 0.2511     0.000012
# discharge       4814         4835 0.4891     0.000040
# discharge       4840         4859 0.5619     0.000051
# discharge       4864         4883 0.5185     0.000044
# discharge       4888         4909 0.7077     0.000078
# discharge       4918         4932 0.5788     0.000054
# discharge       4942         4956 0.6485     0.000066
# discharge       4965         4980 0.7016     0.000076
# discharge       4990         5004 0.6894     0.000074
# discharge       5014         5028 0.6636     0.000069
# discharge       5035         5051 0.3409     0.000021
# discharge       5054         5075 0.3543     0.000022
# discharge       5079         5099 0.4208     0.000031
# discharge       5103         5123 0.3460     0.000022
# discharge       5127         5147 0.4061     0.000029
# discharge       5151         5171 0.5266     0.000046
# discharge       5175         5195 0.5437     0.000048
# discharge       5200         5219 0.4757     0.000038
# discharge       5223         5243 0.5647     0.000052
# discharge       5248         5267 0.4282     0.000032
# discharge       5271         5291 0.4235     0.000031
# discharge       5295         5315 0.3550     0.000023
# discharge       5319         5339 0.3275     0.000020
# discharge       5343         5363 0.4954     0.000041
# discharge       5367         5387 0.5599     0.000051
# discharge       5392         5411 0.6322     0.000063
# discharge       5416         5435 0.6042     0.000058
# discharge       5440         5459 0.5493     0.000049
# discharge       5464         5483 0.3879     0.000026
# discharge       5487         5508 0.5931     0.000057
# discharge       5513         5531 0.6216     0.000061
# discharge       5536         5555 0.4281     0.000032
# discharge       5559         5579 0.3556     0.000023
# discharge       5583         5603 0.3268     0.000019
# discharge       5606         5627 0.3034     0.000017
# discharge       5630         5651 0.4002     0.000028
# discharge       5655         5675 0.4072     0.000029
# discharge       5679         5699 0.4298     0.000032
# discharge       5703         5723 0.5739     0.000053
# discharge       5728         5747 0.6359     0.000064
# discharge       5752         5771 0.6508     0.000067
# discharge       5776         5795 0.6044     0.000058
# discharge       5800         5820 0.6270     0.000062
# discharge       5825         5844 0.7083     0.000078
# discharge       5850         5868 0.6481     0.000066
# discharge       5875         5891 0.5191     0.000045
# discharge       5895         5915 0.2539     0.000012
# discharge       5919         5940 0.4417     0.000033
# discharge       5945         5963 0.5337     0.000047
# discharge       5967         5988 0.6684     0.000070
# discharge       5993         6006 0.3091     0.000018
# discharge       6014         6035 0.2092     0.000009
# discharge       6038         6059 0.2265     0.000010
# discharge       6062         6083 0.3024     0.000017
# discharge       6087         6108 0.5374     0.000047
# discharge       6112         6132 0.2222     0.000010
# discharge       6137         6156 0.0789     0.000002
# discharge       6158         6180 0.6847     0.000073
# discharge       6187         6204 0.2586     0.000013
# discharge       6208         6228 0.1503     0.000005
# discharge       6232         6252 0.6425     0.000065
# discharge       6256         6276 0.5952     0.000057
# discharge       6280         6300 0.6709     0.000070
# discharge       6304         6324 0.6821     0.000073
# discharge       6328         6348 0.5893     0.000056
# discharge       6355         6372 0.6180     0.000061
# discharge       6377         6396 0.5956     0.000057
# discharge       6401         6420 0.6313     0.000063
# discharge       6425         6445 0.5765     0.000054
# discharge       6448         6468 0.4218     0.000031
# discharge       6471         6491 0.1286     0.000004
# discharge       6494         6516 0.1207     0.000003
# discharge       6519         6540 0.5514     0.000050
# discharge       6545         6564 0.6276     0.000063
# discharge       6568         6588 0.6914     0.000074
# discharge       6592         6611 0.1895     0.000007
# discharge       6614         6636 0.6278     0.000063
# discharge       6640         6660 0.5411     0.000048
# discharge       6664         6684 0.5410     0.000048
# discharge       6688         6708 0.7054     0.000077
# discharge       6712         6732 0.3719     0.000025
# discharge       6735         6756 0.2203     0.000010
# discharge       6758         6780 0.3172     0.000018
# discharge       6783         6804 0.3182     0.000019
# discharge       6807         6828 0.6494     0.000066
# discharge       6832         6852 0.6041     0.000058
# discharge       6867         6876 0.1087     0.000003
# discharge       6878         6900 0.2481     0.000012
# discharge       6902         6924 0.6606     0.000069
# discharge       6928         6948 0.2587     0.000013
# discharge       6950         6972 0.5617     0.000051
# discharge       6975         6996 0.5302     0.000046
# discharge       6999         7020 0.5348     0.000047
# discharge       7024         7044 0.6553     0.000068
# discharge       7048         7068 0.6624     0.000069
# discharge       7072         7092 0.4157     0.000030
# discharge       7095         7116 0.1685     0.000006
# discharge       7118         7140 0.4262     0.000031
# discharge       7143         7164 0.3555     0.000023
# discharge       7167         7188 0.4754     0.000038
# discharge       7193         7212 0.4433     0.000034
# discharge       7216         7236 0.4405     0.000033
# discharge       7251         7260 0.1133     0.000003
# discharge       7275         7284 0.0831     0.000002
# discharge       7309         7332 0.6391     0.000065
# discharge       7337         7357 0.5105     0.000043
# discharge       7361         7380 0.3277     0.000020
# discharge       7384         7398 0.1350     0.000004
# discharge       7429         7453 0.6124     0.000060
# discharge       7461         7476 0.5644     0.000052
# discharge       7481         7500 0.3917     0.000027
# discharge       7504         7525 0.3921     0.000027
# discharge       7532         7550 0.5548     0.000050
# discharge       7556         7572 0.5009     0.000042
# discharge       7576         7596 0.4393     0.000033
# discharge       7599         7622 0.3087     0.000018
# discharge       7628         7644 0.3367     0.000021
# discharge       7647         7668 0.6366     0.000064
# discharge       7672         7693 0.5138     0.000044
# discharge       7696         7716 0.3748     0.000025
# discharge       7720         7740 0.1971     0.000008
# discharge       7743         7765 0.2870     0.000015
# discharge       7767         7788 0.3782     0.000025
# discharge       7813         7836 0.1799     0.000007
# discharge       7838         7861 0.7317     0.000082
# discharge       7865         7884 0.4245     0.000031
# discharge       7920         7932 0.1776     0.000007
# discharge       7934         7957 0.5584     0.000051
# discharge       7964         7972 0.0949     0.000002
# discharge       7974         7980 0.0780     0.000001
# discharge       7983         8004 0.4503     0.000035
# discharge       8007         8028 0.7397     0.000084
# discharge       8032         8053 0.4347     0.000032
# discharge       8058         8076 0.6349     0.000064
# discharge       8080         8100 0.3197     0.000019
# discharge       8103         8124 0.3842     0.000026
# discharge       8127         8148 0.1888     0.000007
# discharge       8150         8172 0.4549     0.000035
# discharge       8175         8196 0.6813     0.000072
# discharge       8200         8222 0.1707     0.000006
# discharge       8234         8245 0.2354     0.000011
# discharge       8248         8269 0.6951     0.000075
# discharge       8274         8292 0.3148     0.000018
# discharge       8295         8316 0.5293     0.000046
# discharge       8320         8342 0.3383     0.000021
# discharge       8347         8364 0.2054     0.000008
# discharge       8367         8389 0.3601     0.000023
# discharge       8392         8405 0.0928     0.000002
# discharge       8415         8437 0.4081     0.000029
# discharge       8442         8454 0.3712     0.000024
# discharge       8457         8461 0.0941     0.000002
# discharge       8469         8484 0.3511     0.000022
# discharge       8487         8508 0.2821     0.000015
# discharge       8511         8532 0.3872     0.000026
# discharge       8535         8556 0.5985     0.000057
# discharge       8560         8580 0.3278     0.000020
# discharge       8583         8605 0.3727     0.000025
# discharge       8609         8630 0.5572     0.000051
# discharge       8636         8653 0.4916     0.000040
# discharge       8661         8669 0.0780     0.000001
# discharge       8679         8701 0.3838     0.000026
# discharge       8713         8725 0.1502     0.000005
# discharge       8728         8749 0.4039     0.000028
#
# Total Estimated Degradation: 0.011843
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_98_percent_met_71_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_98_percent_met_71_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_98_percent_met_71_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 98% met (Load Factor 0.71) ===
# Year 2024: Unmet Load = 938885.08 kWh
# Year 2023: Unmet Load = 360098.75 kWh
# Year 2022: Unmet Load = 3540059.57 kWh
# Year 2021: Unmet Load = 64430.12 kWh
# Year 2020: Unmet Load = 1648829.38 kWh
# Year 2019: Unmet Load = 5447021.44 kWh
# Year 2018: Unmet Load = 613481.96 kWh
# Year 2017: Unmet Load = 5752124.26 kWh
# Year 2016: Unmet Load = 4244543.71 kWh
# Year 2015: Unmet Load = 7934394.93 kWh
# Year 2014: Unmet Load = 2737565.88 kWh
# Year 2013: Unmet Load = 3266056.43 kWh
# Year 2012: Unmet Load = 1287876.81 kWh
# Year 2011: Unmet Load = 1051717.82 kWh
# Year 2010: Unmet Load = 14951.30 kWh
# Year 2009: Unmet Load = 1908713.91 kWh
# Year 2008: Unmet Load = 2076271.25 kWh
# Year 2007: Unmet Load = 565061.21 kWh
# Year 2006: Unmet Load = 1210017.01 kWh
# Year 2005: Unmet Load = 5283320.63 kWh
# Year 2004: Unmet Load = 4598264.47 kWh
# Year 2003: Unmet Load = 895092.69 kWh
# Year 2002: Unmet Load = 3019853.50 kWh
# Year 2001: Unmet Load = 4729640.85 kWh
# Year 2000: Unmet Load = 595328.33 kWh
# Year 1999: Unmet Load = 248503.11 kWh
# Year 1998: Unmet Load = 7945341.61 kWh
# Year 1997: Unmet Load = 2034309.07 kWh
# Year 1996: Unmet Load = 3664635.12 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 4805428.38 kWh
# Year 1993: Unmet Load = 2681217.07 kWh
# Year 1992: Unmet Load = 2890830.72 kWh
# Year 1991: Unmet Load = 5940652.93 kWh
# Year 1990: Unmet Load = 4751463.40 kWh
# Year 1989: Unmet Load = 3131949.48 kWh
# Year 1988: Unmet Load = 1097724.05 kWh
# Year 1987: Unmet Load = 2345108.38 kWh
# Year 1986: Unmet Load = 5831031.90 kWh
# Year 1985: Unmet Load = 2605712.17 kWh
# Year 1984: Unmet Load = 2429603.31 kWh
# Year 1983: Unmet Load = 5227954.23 kWh
# Year 1982: Unmet Load = 3005120.11 kWh
# Year 1981: Unmet Load = 4549323.28 kWh
# Year 1980: Unmet Load = 2725257.29 kWh
#
# Average Unmet Load (1979-2024): 2926550.38 kWh
# Min Unmet Load: 0.00 kWh (Year 1995)
# Max Unmet Load: 7945341.61 kWh (Year 1998)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_98_percent_met_71_percent_inference"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) 71% reduction (Case 1) in LP for 98% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 100% met Capacity

# %% [markdown]
# # 71% Load Factor (Intense Traffic)

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_100_percent_met_71_percent_inference"
dispatch_load_factor = 0.71  # Apply 0.71 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 100% met load sizing (Load Factor 0.71)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results 100% met (Dispatch Load Factor 0.71) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        #with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
        #    for _, row in df_dispatch.iterrows():
        #        print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
        #              f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
        #              f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile 100% met (Load Factor 0.71)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 100% met (Load Factor 0.71) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0xdd510e10
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17533 rows and 17532 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.05s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52506 rows, 26248 columns, 135627 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7746084e+08   5.102861e+05   4.308989e+06     41s
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.740614e+09, 17303 iterations, 3.88 seconds (2.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.7406e+09    0    1          - 4.7406e+09      -     -   44s
# H    0     0                    4.740614e+09 4.7406e+09  0.00%     -   45s
#      0     0 4.7406e+09    0    1 4.7406e+09 4.7406e+09  0.00%     -   45s
#
# Explored 1 nodes (17303 simplex iterations) in 46.02 seconds (67.66 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.74061e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.740613839056e+09, best bound 4.740613839056e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 10091678.31 kW
# Wind Capacity: 180.13 kW
# Battery Capacity: 5959201.57 kWh
# Total NPC: $4740613839.06
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 3924325031.17 kWh
# Total Energy Generated: 6026555727.62 kWh
# Total Energy Used (along with efficiency losses): 2102230696.45 kWh
# Utilization Percentage: 34.88%
# $7524181.62 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 10091678.31 kW
# Solar Initial Cost:    $938021498.60
# Wind Initial Capacity: 180.13 kW
# Wind Initial Cost:     $921156293.49
# Battery Initial Capacity: 5959201.57 kWh
# Battery Initial Cost:  $2133394160.35
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -32293.37 kW
# Solar Redundant Cost:    $-3001668.80
# Wind Redundant Capacity: 15.90 kW
# Wind Redundant Cost:     $81319677.59
# Battery Redundant Capacity: 22049.05 kWh
# Battery Redundant Cost:  $7893558.39
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $935019829.81
# Solar OPEX:         $1021289141.51
# Solar Replacement:  $0.00
# Solar Salvage:     -$271813461.80
# Wind CAPEX:         $1002475971.08
# Wind OPEX:          $214565749.24
# Wind Replacement:   $0.00
# Wind Salvage:      -$182139495.46
# Battery CAPEX:      $2141287718.75
# Battery OPEX:       $645100244.36
# Battery Replacement:$95600201.24
# Battery Salvage:   -$778099577.40
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $4836214040.29
#
# === 2024 Solar Results 100% met (Dispatch Load Factor 0.71) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          2           12 0.1274     0.000004
# discharge         14           36 0.3629     0.000023
# discharge         40           62 0.5198     0.000045
# discharge         70           84 0.3082     0.000018
# discharge         87          109 0.1880     0.000007
# discharge        121          133 0.2564     0.000013
# discharge        137          157 0.1870     0.000007
# discharge        160          178 0.2076     0.000009
# discharge        183          201 0.0714     0.000001
# discharge        230          253 0.0753     0.000001
# discharge        275          300 0.0596     0.000001
# discharge        301          315 0.1011     0.000002
# discharge        326          349 0.1988     0.000008
# discharge        353          372 0.1642     0.000006
# discharge        375          396 0.3535     0.000022
# discharge        424          441 0.3363     0.000020
# discharge        447          468 0.1462     0.000005
# discharge        470          492 0.3234     0.000019
# discharge        495          515 0.1451     0.000005
# discharge        518          542 0.0538     0.000001
# discharge        544          566 0.0574     0.000001
# discharge        569          590 0.4721     0.000038
# discharge        598          613 0.2728     0.000014
# discharge        624          632 0.0670     0.000001
# discharge        638          660 0.0623     0.000001
# discharge        662          685 0.4258     0.000031
# discharge        688          703 0.1668     0.000006
# discharge        711          732 0.0802     0.000002
# discharge        734          756 0.4370     0.000033
# discharge        760          780 0.1242     0.000003
# discharge        782          804 0.2960     0.000016
# discharge        808          817 0.0543     0.000001
# discharge        829          846 0.0766     0.000001
# discharge        877          900 0.1793     0.000007
# discharge        975          996 0.2460     0.000012
# discharge       1013         1021 0.0532     0.000001
# discharge       1023         1044 0.1870     0.000007
# discharge       1046         1068 0.2484     0.000012
# discharge       1070         1083 0.0521     0.000001
# discharge       1093         1116 0.3325     0.000020
# discharge       1123         1164 0.3876     0.000026
# discharge       1167         1188 0.3079     0.000017
# discharge       1191         1212 0.2318     0.000011
# discharge       1214         1229 0.1402     0.000004
# discharge       1238         1284 0.1005     0.000002
# discharge       1298         1324 0.1154     0.000003
# discharge       1334         1428 0.2355     0.000011
# discharge       1431         1452 0.2933     0.000016
# discharge       1455         1476 0.4667     0.000037
# discharge       1481         1491 0.0630     0.000001
# discharge       1525         1548 0.1673     0.000006
# discharge       1553         1572 0.2458     0.000012
# discharge       1575         1596 0.2939     0.000016
# discharge       1600         1615 0.1411     0.000004
# discharge       1625         1638 0.2186     0.000009
# discharge       1647         1667 0.1438     0.000004
# discharge       1670         1691 0.3353     0.000020
# discharge       1695         1715 0.1870     0.000007
# discharge       1789         1811 0.3047     0.000017
# discharge       1815         1827 0.1274     0.000004
# discharge       1829         1835 0.1314     0.000004
# discharge       1861         1883 0.3103     0.000018
# discharge       1908         1931 0.2446     0.000012
# discharge       1934         1956 0.2811     0.000015
# discharge       1963         1972 0.1050     0.000003
# discharge       2006         2042 0.0728     0.000001
# discharge       2044         2051 0.0971     0.000002
# discharge       2054         2075 0.0928     0.000002
# discharge       2077         2099 0.2272     0.000010
# discharge       2102         2123 0.2273     0.000010
# discharge       2268         2291 0.0712     0.000001
# discharge       2293         2315 0.0959     0.000002
# discharge       2334         2363 0.2038     0.000008
# discharge       2389         2410 0.1782     0.000007
# discharge       2417         2433 0.0872     0.000002
# discharge       2437         2483 0.2220     0.000010
# discharge       2533         2549 0.0829     0.000002
# discharge       2557         2603 0.1537     0.000005
# discharge       2628         2646 0.0574     0.000001
# discharge       2653         2671 0.1089     0.000003
# discharge       2677         2699 0.2888     0.000016
# discharge       2725         2747 0.0912     0.000002
# discharge       2773         2795 0.1297     0.000004
# discharge       2843         2891 0.3886     0.000027
# discharge       2895         2910 0.1247     0.000003
# discharge       2911         2915 0.0722     0.000001
# discharge       2918         2939 0.1671     0.000006
# discharge       2942         2963 0.3556     0.000023
# discharge       2967         2987 0.3973     0.000028
# discharge       2992         3011 0.3850     0.000026
# discharge       3017         3035 0.2478     0.000012
# discharge       3109         3131 0.1076     0.000003
# discharge       3133         3155 0.3429     0.000021
# discharge       3158         3179 0.2816     0.000015
# discharge       3183         3204 0.2719     0.000014
# discharge       3221         3227 0.0728     0.000001
# discharge       3229         3251 0.1517     0.000005
# discharge       3253         3275 0.3206     0.000019
# discharge       3279         3300 0.3076     0.000017
# discharge       3304         3323 0.2793     0.000015
# discharge       3328         3347 0.3725     0.000025
# discharge       3351         3371 0.2536     0.000012
# discharge       3374         3394 0.1471     0.000005
# discharge       3421         3443 0.2154     0.000009
# discharge       3447         3467 0.1937     0.000008
# discharge       3472         3491 0.1781     0.000007
# discharge       3494         3510 0.0794     0.000002
# discharge       3540         3563 0.2500     0.000012
# discharge       3566         3587 0.3297     0.000020
# discharge       3591         3610 0.1132     0.000003
# discharge       3613         3635 0.1036     0.000002
# discharge       3639         3659 0.0855     0.000002
# discharge       3662         3683 0.3495     0.000022
# discharge       3687         3707 0.2887     0.000016
# discharge       3711         3731 0.1405     0.000004
# discharge       3734         3754 0.1366     0.000004
# discharge       3758         3779 0.3315     0.000020
# discharge       3782         3803 0.1167     0.000003
# discharge       3805         3826 0.2777     0.000015
# discharge       3852         3875 0.1498     0.000005
# discharge       3877         3899 0.1026     0.000002
# discharge       3901         3923 0.1893     0.000007
# discharge       3926         3947 0.3371     0.000021
# discharge       3950         3971 0.3500     0.000022
# discharge       3975         3995 0.3409     0.000021
# discharge       3999         4019 0.2696     0.000014
# discharge       4022         4043 0.1483     0.000005
# discharge       4047         4067 0.2353     0.000011
# discharge       4072         4091 0.2436     0.000011
# discharge       4095         4114 0.1703     0.000006
# discharge       4118         4139 0.2669     0.000014
# discharge       4142         4163 0.3308     0.000020
# discharge       4167         4186 0.1559     0.000005
# discharge       4189         4211 0.3454     0.000021
# discharge       4215         4235 0.3385     0.000021
# discharge       4239         4258 0.2528     0.000012
# discharge       4262         4282 0.0908     0.000002
# discharge       4285         4307 0.2232     0.000010
# discharge       4310         4331 0.2325     0.000011
# discharge       4334         4355 0.2068     0.000009
# discharge       4358         4378 0.1283     0.000004
# discharge       4381         4403 0.1436     0.000004
# discharge       4406         4427 0.2567     0.000013
# discharge       4430         4451 0.1819     0.000007
# discharge       4454         4475 0.1885     0.000007
# discharge       4479         4499 0.2528     0.000012
# discharge       4502         4523 0.2526     0.000012
# discharge       4526         4547 0.3569     0.000023
# discharge       4572         4595 0.1623     0.000006
# discharge       4598         4619 0.3600     0.000023
# discharge       4623         4643 0.3492     0.000022
# discharge       4647         4667 0.2878     0.000015
# discharge       4671         4691 0.3569     0.000023
# discharge       4695         4715 0.2421     0.000011
# discharge       4718         4739 0.2338     0.000011
# discharge       4742         4764 0.2262     0.000010
# discharge       4768         4787 0.2725     0.000014
# discharge       4790         4811 0.0663     0.000001
# discharge       4813         4835 0.2530     0.000012
# discharge       4838         4859 0.3130     0.000018
# discharge       4863         4883 0.2783     0.000015
# discharge       4887         4908 0.4036     0.000028
# discharge       4919         4932 0.3559     0.000023
# discharge       4937         4956 0.3585     0.000023
# discharge       4961         4980 0.4004     0.000028
# discharge       4985         5004 0.3944     0.000027
# discharge       5010         5027 0.3786     0.000025
# discharge       5032         5051 0.1327     0.000004
# discharge       5053         5075 0.1438     0.000004
# discharge       5078         5099 0.1991     0.000008
# discharge       5102         5123 0.1372     0.000004
# discharge       5126         5147 0.1865     0.000007
# discharge       5150         5171 0.2857     0.000015
# discharge       5174         5195 0.2997     0.000017
# discharge       5198         5219 0.2445     0.000012
# discharge       5222         5243 0.3174     0.000018
# discharge       5247         5267 0.2054     0.000008
# discharge       5270         5291 0.2019     0.000008
# discharge       5294         5315 0.1451     0.000005
# discharge       5317         5339 0.1231     0.000003
# discharge       5341         5363 0.2539     0.000012
# discharge       5366         5387 0.3146     0.000018
# discharge       5391         5411 0.3735     0.000025
# discharge       5415         5435 0.3397     0.000021
# discharge       5439         5459 0.3063     0.000017
# discharge       5463         5483 0.1730     0.000006
# discharge       5486         5508 0.3283     0.000020
# discharge       5512         5531 0.3657     0.000024
# discharge       5535         5555 0.2074     0.000009
# discharge       5558         5579 0.1478     0.000005
# discharge       5582         5603 0.1243     0.000003
# discharge       5605         5627 0.1048     0.000003
# discharge       5629         5651 0.1847     0.000007
# discharge       5654         5675 0.1905     0.000007
# discharge       5678         5699 0.2090     0.000009
# discharge       5702         5723 0.3275     0.000020
# discharge       5727         5747 0.3791     0.000025
# discharge       5751         5771 0.3845     0.000026
# discharge       5775         5795 0.3533     0.000022
# discharge       5799         5819 0.3627     0.000023
# discharge       5824         5844 0.4114     0.000029
# discharge       5848         5868 0.3661     0.000024
# discharge       5873         5891 0.2710     0.000014
# discharge       5894         5915 0.0659     0.000001
# discharge       5917         5940 0.2019     0.000008
# discharge       5943         5963 0.2810     0.000015
# discharge       5966         5988 0.3837     0.000026
# discharge       5991         6005 0.1660     0.000006
# discharge       6061         6083 0.1041     0.000003
# discharge       6085         6107 0.2880     0.000016
# discharge       6157         6180 0.3935     0.000027
# discharge       6185         6203 0.0503     0.000001
# discharge       6225         6251 0.3641     0.000024
# discharge       6255         6275 0.3331     0.000020
# discharge       6279         6299 0.3885     0.000027
# discharge       6303         6324 0.3906     0.000027
# discharge       6327         6348 0.3161     0.000018
# discharge       6353         6372 0.3400     0.000021
# discharge       6375         6396 0.3211     0.000019
# discharge       6400         6420 0.3375     0.000021
# discharge       6424         6444 0.3041     0.000017
# discharge       6447         6467 0.1870     0.000007
# discharge       6517         6540 0.2869     0.000015
# discharge       6543         6564 0.3494     0.000022
# discharge       6567         6588 0.4009     0.000028
# discharge       6613         6635 0.3478     0.000022
# discharge       6639         6660 0.2775     0.000015
# discharge       6663         6684 0.2776     0.000015
# discharge       6687         6708 0.4126     0.000030
# discharge       6711         6731 0.1516     0.000005
# discharge       6757         6779 0.1014     0.000002
# discharge       6782         6803 0.0986     0.000002
# discharge       6806         6828 0.3678     0.000024
# discharge       6831         6852 0.3312     0.000020
# discharge       6901         6924 0.3785     0.000025
# discharge       6938         6948 0.0621     0.000001
# discharge       6949         6972 0.2964     0.000016
# discharge       6975         6996 0.2711     0.000014
# discharge       6998         7020 0.2757     0.000014
# discharge       7023         7044 0.3742     0.000025
# discharge       7047         7068 0.3801     0.000025
# discharge       7071         7087 0.1729     0.000006
# discharge       7117         7140 0.1872     0.000007
# discharge       7142         7164 0.1287     0.000004
# discharge       7166         7188 0.2282     0.000010
# discharge       7191         7202 0.0616     0.000001
# discharge       7203         7212 0.1274     0.000004
# discharge       7214         7236 0.1991     0.000008
# discharge       7285         7332 0.3416     0.000021
# discharge       7336         7356 0.2460     0.000012
# discharge       7360         7380 0.1004     0.000002
# discharge       7401         7453 0.3330     0.000020
# discharge       7457         7476 0.2972     0.000016
# discharge       7480         7500 0.1589     0.000005
# discharge       7503         7524 0.1528     0.000005
# discharge       7529         7549 0.2478     0.000012
# discharge       7554         7572 0.2495     0.000012
# discharge       7575         7596 0.1987     0.000008
# discharge       7598         7621 0.0915     0.000002
# discharge       7625         7636 0.0766     0.000001
# discharge       7646         7668 0.3609     0.000023
# discharge       7671         7693 0.2472     0.000012
# discharge       7696         7716 0.1459     0.000005
# discharge       7741         7764 0.1442     0.000004
# discharge       7767         7782 0.1972     0.000008
# discharge       7837         7861 0.4243     0.000031
# discharge       7864         7884 0.1863     0.000007
# discharge       7933         7957 0.2843     0.000015
# discharge       7981         8004 0.2072     0.000009
# discharge       8006         8028 0.4449     0.000034
# discharge       8032         8052 0.1816     0.000007
# discharge       8056         8076 0.3591     0.000023
# discharge       8091         8100 0.1147     0.000003
# discharge       8102         8117 0.1562     0.000005
# discharge       8149         8172 0.2103     0.000009
# discharge       8175         8196 0.3965     0.000027
# discharge       8239         8245 0.0735     0.000001
# discharge       8247         8269 0.3885     0.000027
# discharge       8281         8292 0.1064     0.000003
# discharge       8294         8316 0.2819     0.000015
# discharge       8329         8342 0.1068     0.000003
# discharge       8365         8389 0.1574     0.000005
# discharge       8405         8437 0.1556     0.000005
# discharge       8440         8453 0.2039     0.000008
# discharge       8466         8484 0.1343     0.000004
# discharge       8486         8499 0.0957     0.000002
# discharge       8510         8532 0.1536     0.000005
# discharge       8534         8556 0.3267     0.000019
# discharge       8559         8572 0.1060     0.000003
# discharge       8582         8605 0.1597     0.000005
# discharge       8608         8630 0.2488     0.000012
# discharge       8634         8653 0.2016     0.000008
# discharge       8657         8700 0.1437     0.000004
# discharge       8726         8749 0.1681     0.000006
#
# Total Estimated Degradation: 0.003502
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_71_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_71_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_71_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 100% met (Load Factor 0.71) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 841821.84 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 18707.15 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 841821.84 kWh (Year 2015)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_100_percent_met_71_percent_inference"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) 71% reduction (Case 1) in LP for 100% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 55% Load Factor

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_100_percent_met_55_percent_inference"
dispatch_load_factor = 0.55  # Apply 0.55 load factor only for dispatch simulations

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
# Original load profile for optimization
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)
# Adjusted load profile for dispatch simulations
load_profile_dispatch = load_profile * dispatch_load_factor

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5

# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} kW")
            print(f"Wind Capacity: {wind_capacity.x:.2f} kW")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            print(f"Total NPC: ${model.objVal:.2f}")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0.05):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year} 100% met (Load Factor 0.55)")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 with Original Load Profile ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile_dispatch,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:

        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0
        

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min - 1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity

        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        total_npc = opt_results["cost"] + battery_replacement

        print("\nInitial Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} kW")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} kW")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} kW")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} kW")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Solar Results Unmet 100% met (Load Factor 0.55) ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile_dispatch,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

       # with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.6f}'.format):
       #     for _, row in df_dispatch.iterrows():
       #         print(f"Hour {int(row['Hour'])}: Load={row['Load (kW)']:.2f} | Solar={row['Solar (kW)']:.2f} | "
       #               f"Wind={row['Wind (kW)']:.2f} | Charge={row['Charge (kW)']:.2f} | Discharge={row['Discharge (kW)']:.2f} | "
       #               f"SOC={row['SOC (kWh)']:.2f} | Unmet={row['Unmet (kW)']:.2f} | Curtailment={row['Curtailment (kW)']:.2f}")

        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Solar Dispatch Profile for 100% met (Load Factor 0.55)")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile_dispatch,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile_dispatch,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        print("\n=== Unmet Load Across Years 100% met (Load Factor 0.55) ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0xdd510e10
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 5e+06]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17533 rows and 17532 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 13s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 20s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 24.35s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52506 rows, 26248 columns, 135627 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7746084e+08   5.102861e+05   4.308989e+06     39s
#      976    1.3595104e+14   7.188104e+05   1.474628e+21     40s
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 4.740614e+09, 17303 iterations, 3.92 seconds (2.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.7406e+09    0    1          - 4.7406e+09      -     -   43s
# H    0     0                    4.740614e+09 4.7406e+09  0.00%     -   44s
#      0     0 4.7406e+09    0    1 4.7406e+09 4.7406e+09  0.00%     -   44s
#
# Explored 1 nodes (17303 simplex iterations) in 45.03 seconds (67.66 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.74061e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.740613839056e+09, best bound 4.740613839056e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 10091678.31 kW
# Wind Capacity: 180.13 kW
# Battery Capacity: 5959201.57 kWh
# Total NPC: $4740613839.06
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 4284231116.59 kWh
# Total Energy Generated: 6026555727.62 kWh
# Total Energy Used (along with efficiency losses): 1742324611.03 kWh
# Utilization Percentage: 28.91%
# $3648929.21 is the replacement cost each year for degradation
#
# Initial Capacities and Costs:
# Solar Initial Capacity: 10091678.31 kW
# Solar Initial Cost:    $938021498.60
# Wind Initial Capacity: 180.13 kW
# Wind Initial Cost:     $921156293.49
# Battery Initial Capacity: 5959201.57 kWh
# Battery Initial Cost:  $2133394160.35
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -32293.37 kW
# Solar Redundant Cost:    $-3001668.80
# Wind Redundant Capacity: 15.90 kW
# Wind Redundant Cost:     $81319677.59
# Battery Redundant Capacity: 22049.05 kWh
# Battery Redundant Cost:  $7893558.39
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $935019829.81
# Solar OPEX:         $1021289141.51
# Solar Replacement:  $0.00
# Solar Salvage:     -$271813461.80
# Wind CAPEX:         $1002475971.08
# Wind OPEX:          $214565749.24
# Wind Replacement:   $0.00
# Wind Salvage:      -$182139495.46
# Battery CAPEX:      $2141287718.75
# Battery OPEX:       $645100244.36
# Battery Replacement:$46362300.22
# Battery Salvage:   -$778099577.40
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $4786976139.28
#
# === 2024 Solar Results Unmet 100% met (Load Factor 0.55) ===
# Total Unmet Load: 0.00 kWh
# Hours with Unmet Load: []
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          2           12 0.0659     0.000001
# discharge         14           36 0.2601     0.000013
# discharge         39           62 0.3950     0.000027
# discharge         69           79 0.1928     0.000008
# discharge        100          109 0.0595     0.000001
# discharge        120          133 0.1690     0.000006
# discharge        149          157 0.0728     0.000001
# discharge        160          174 0.1337     0.000004
# discharge        301          315 0.0647     0.000001
# discharge        324          348 0.0861     0.000002
# discharge        351          372 0.0614     0.000001
# discharge        374          396 0.2509     0.000012
# discharge        399          441 0.2412     0.000011
# discharge        469          492 0.2206     0.000010
# discharge        494          507 0.0556     0.000001
# discharge        568          589 0.3462     0.000022
# discharge        604          613 0.1281     0.000004
# discharge        661          684 0.3175     0.000018
# discharge        688          700 0.1154     0.000003
# discharge        733          756 0.3343     0.000020
# discharge        781          804 0.1932     0.000008
# discharge        849          900 0.0760     0.000001
# discharge        973          996 0.1353     0.000004
# discharge       1022         1044 0.1068     0.000003
# discharge       1046         1068 0.1453     0.000005
# discharge       1086         1116 0.2294     0.000010
# discharge       1121         1164 0.2843     0.000015
# discharge       1166         1188 0.2045     0.000008
# discharge       1190         1212 0.1287     0.000004
# discharge       1214         1228 0.0929     0.000002
# discharge       1285         1323 0.0734     0.000001
# discharge       1333         1428 0.1318     0.000004
# discharge       1443         1452 0.1687     0.000006
# discharge       1454         1476 0.3558     0.000023
# discharge       1496         1548 0.0979     0.000002
# discharge       1551         1566 0.1552     0.000005
# discharge       1574         1596 0.1898     0.000007
# discharge       1599         1613 0.0795     0.000002
# discharge       1622         1638 0.1595     0.000005
# discharge       1669         1691 0.2389     0.000011
# discharge       1694         1715 0.0979     0.000002
# discharge       1779         1811 0.2080     0.000009
# discharge       1814         1827 0.0901     0.000002
# discharge       1829         1835 0.0868     0.000002
# discharge       1860         1883 0.2207     0.000010
# discharge       1886         1928 0.1419     0.000004
# discharge       1934         1956 0.1765     0.000006
# discharge       1961         1972 0.0529     0.000001
# discharge       2045         2048 0.0597     0.000001
# discharge       2077         2099 0.1375     0.000004
# discharge       2101         2119 0.1539     0.000005
# discharge       2317         2363 0.1438     0.000004
# discharge       2389         2407 0.1063     0.000003
# discharge       2436         2483 0.1317     0.000004
# discharge       2556         2603 0.0634     0.000001
# discharge       2676         2699 0.1980     0.000008
# discharge       2718         2747 0.0545     0.000001
# discharge       2797         2891 0.2907     0.000016
# discharge       2894         2908 0.0776     0.000001
# discharge       2917         2933 0.0767     0.000001
# discharge       2941         2963 0.2569     0.000013
# discharge       2966         2987 0.3018     0.000017
# discharge       2991         3011 0.2939     0.000016
# discharge       3016         3035 0.1492     0.000005
# discharge       3132         3155 0.2517     0.000012
# discharge       3158         3179 0.1905     0.000007
# discharge       3196         3204 0.1274     0.000004
# discharge       3229         3251 0.0601     0.000001
# discharge       3253         3275 0.2299     0.000010
# discharge       3278         3299 0.2050     0.000008
# discharge       3303         3323 0.1879     0.000007
# discharge       3327         3347 0.2812     0.000015
# discharge       3350         3370 0.1646     0.000006
# discharge       3374         3394 0.0629     0.000001
# discharge       3434         3443 0.1257     0.000004
# discharge       3446         3466 0.0991     0.000002
# discharge       3470         3491 0.0905     0.000002
# discharge       3540         3563 0.1659     0.000006
# discharge       3566         3587 0.2425     0.000011
# discharge       3637         3659 0.0524     0.000001
# discharge       3661         3683 0.2576     0.000013
# discharge       3686         3707 0.1968     0.000008
# discharge       3733         3754 0.0603     0.000001
# discharge       3757         3778 0.2418     0.000011
# discharge       3804         3826 0.1939     0.000008
# discharge       3829         3874 0.0857     0.000002
# discharge       3900         3923 0.0991     0.000002
# discharge       3925         3947 0.2454     0.000012
# discharge       3950         3971 0.2579     0.000013
# discharge       3974         3995 0.2489     0.000012
# discharge       3998         4018 0.1819     0.000007
# discharge       4022         4043 0.0640     0.000001
# discharge       4045         4067 0.1437     0.000004
# discharge       4070         4090 0.1586     0.000005
# discharge       4094         4114 0.0939     0.000002
# discharge       4117         4139 0.1754     0.000006
# discharge       4142         4163 0.2392     0.000011
# discharge       4166         4181 0.0893     0.000002
# discharge       4189         4211 0.2554     0.000013
# discharge       4214         4235 0.2469     0.000012
# discharge       4238         4258 0.1689     0.000006
# discharge       4284         4307 0.1393     0.000004
# discharge       4309         4331 0.1420     0.000004
# discharge       4334         4355 0.1153     0.000003
# discharge       4357         4378 0.0522     0.000001
# discharge       4380         4402 0.0609     0.000001
# discharge       4405         4426 0.1720     0.000006
# discharge       4430         4450 0.0918     0.000002
# discharge       4453         4474 0.1002     0.000002
# discharge       4478         4498 0.1675     0.000006
# discharge       4502         4523 0.1620     0.000006
# discharge       4526         4547 0.2657     0.000013
# discharge       4564         4595 0.0885     0.000002
# discharge       4597         4619 0.2685     0.000014
# discharge       4622         4643 0.2583     0.000013
# discharge       4646         4667 0.1967     0.000008
# discharge       4670         4691 0.2654     0.000013
# discharge       4695         4715 0.1508     0.000005
# discharge       4718         4738 0.1468     0.000005
# discharge       4741         4763 0.1321     0.000004
# discharge       4767         4787 0.1815     0.000007
# discharge       4812         4835 0.1620     0.000006
# discharge       4838         4859 0.2222     0.000010
# discharge       4862         4883 0.1875     0.000007
# discharge       4886         4908 0.3054     0.000017
# discharge       4916         4931 0.2639     0.000013
# discharge       4936         4955 0.2674     0.000014
# discharge       4960         4979 0.3039     0.000017
# discharge       4984         5004 0.2961     0.000016
# discharge       5009         5027 0.2880     0.000016
# discharge       5077         5093 0.0772     0.000001
# discharge       5125         5147 0.0960     0.000002
# discharge       5149         5171 0.1954     0.000008
# discharge       5174         5195 0.2094     0.000009
# discharge       5198         5219 0.1544     0.000005
# discharge       5222         5243 0.2270     0.000010
# discharge       5246         5267 0.1151     0.000003
# discharge       5269         5291 0.1121     0.000003
# discharge       5293         5315 0.0561     0.000001
# discharge       5340         5363 0.1642     0.000006
# discharge       5366         5387 0.2248     0.000010
# discharge       5390         5411 0.2834     0.000015
# discharge       5414         5435 0.2497     0.000012
# discharge       5438         5459 0.2168     0.000009
# discharge       5462         5476 0.0522     0.000001
# discharge       5485         5508 0.2310     0.000010
# discharge       5511         5531 0.2760     0.000014
# discharge       5534         5555 0.1180     0.000003
# discharge       5557         5579 0.0584     0.000001
# discharge       5642         5651 0.0832     0.000002
# discharge       5653         5675 0.1012     0.000002
# discharge       5677         5699 0.1198     0.000003
# discharge       5701         5723 0.2383     0.000011
# discharge       5726         5747 0.2901     0.000016
# discharge       5750         5771 0.2954     0.000016
# discharge       5774         5795 0.2644     0.000013
# discharge       5799         5819 0.2739     0.000014
# discharge       5823         5843 0.3128     0.000018
# discharge       5848         5868 0.2698     0.000014
# discharge       5873         5891 0.1821     0.000007
# discharge       5929         5939 0.1111     0.000003
# discharge       5942         5963 0.1846     0.000007
# discharge       5966         5987 0.2931     0.000016
# discharge       5991         6004 0.1189     0.000003
# discharge       6084         6107 0.1997     0.000008
# discharge       6156         6180 0.2903     0.000016
# discharge       6196         6251 0.2686     0.000014
# discharge       6254         6275 0.2449     0.000012
# discharge       6278         6299 0.3005     0.000017
# discharge       6303         6323 0.3023     0.000017
# discharge       6327         6348 0.2196     0.000010
# discharge       6352         6372 0.2378     0.000011
# discharge       6375         6396 0.2244     0.000010
# discharge       6399         6420 0.2316     0.000011
# discharge       6424         6444 0.2084     0.000009
# discharge       6447         6467 0.0995     0.000002
# discharge       6469         6540 0.1847     0.000007
# discharge       6543         6564 0.2478     0.000012
# discharge       6567         6587 0.3030     0.000017
# discharge       6612         6635 0.2539     0.000012
# discharge       6638         6659 0.1765     0.000006
# discharge       6662         6684 0.1758     0.000006
# discharge       6686         6708 0.3109     0.000018
# discharge       6711         6724 0.0994     0.000002
# discharge       6805         6828 0.2662     0.000013
# discharge       6831         6852 0.2296     0.000010
# discharge       6901         6924 0.2773     0.000014
# discharge       6949         6972 0.1950     0.000008
# discharge       6974         6995 0.1722     0.000006
# discharge       6998         7020 0.1745     0.000006
# discharge       7022         7044 0.2731     0.000014
# discharge       7046         7068 0.2789     0.000015
# discharge       7071         7085 0.1178     0.000003
# discharge       7116         7134 0.0734     0.000001
# discharge       7142         7155 0.0554     0.000001
# discharge       7165         7188 0.1274     0.000004
# discharge       7204         7212 0.0670     0.000001
# discharge       7214         7236 0.0981     0.000002
# discharge       7238         7332 0.2337     0.000011
# discharge       7335         7356 0.1449     0.000005
# discharge       7397         7452 0.2408     0.000011
# discharge       7456         7476 0.1968     0.000008
# discharge       7488         7500 0.0630     0.000001
# discharge       7502         7524 0.0654     0.000001
# discharge       7527         7542 0.0853     0.000002
# discharge       7544         7549 0.0571     0.000001
# discharge       7553         7565 0.1282     0.000004
# discharge       7574         7591 0.0984     0.000002
# discharge       7645         7668 0.2603     0.000013
# discharge       7671         7693 0.1395     0.000004
# discharge       7729         7764 0.0944     0.000002
# discharge       7766         7781 0.1414     0.000004
# discharge       7837         7861 0.3159     0.000018
# discharge       7864         7876 0.0985     0.000002
# discharge       7933         7957 0.1763     0.000006
# discharge       7981         8004 0.1061     0.000003
# discharge       8006         8028 0.3439     0.000021
# discharge       8046         8052 0.0679     0.000001
# discharge       8055         8076 0.2582     0.000013
# discharge       8088         8100 0.0610     0.000001
# discharge       8102         8116 0.1111     0.000003
# discharge       8148         8172 0.1151     0.000003
# discharge       8174         8196 0.2953     0.000016
# discharge       8247         8269 0.2798     0.000015
# discharge       8293         8316 0.1966     0.000008
# discharge       8318         8341 0.0524     0.000001
# discharge       8352         8389 0.0954     0.000002
# discharge       8439         8452 0.1469     0.000005
# discharge       8465         8484 0.0540     0.000001
# discharge       8486         8498 0.0636     0.000001
# discharge       8508         8532 0.0669     0.000001
# discharge       8534         8556 0.2243     0.000010
# discharge       8559         8571 0.0680     0.000001
# discharge       8581         8605 0.0918     0.000002
# discharge       8619         8629 0.0929     0.000002
# discharge       8720         8749 0.1062     0.000003
#
# Total Estimated Degradation: 0.001701
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_100_percent_met_55_percent_inference\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_100_percent_met_55_percent_inference\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_100_percent_met_55_percent_inference\dispatch_profile_1980.png
#
# === Unmet Load Across Years 100% met (Load Factor 0.55) ===
# Year 2024: Unmet Load = 0.00 kWh
# Year 2023: Unmet Load = 0.00 kWh
# Year 2022: Unmet Load = 0.00 kWh
# Year 2021: Unmet Load = 0.00 kWh
# Year 2020: Unmet Load = 0.00 kWh
# Year 2019: Unmet Load = 0.00 kWh
# Year 2018: Unmet Load = 0.00 kWh
# Year 2017: Unmet Load = 0.00 kWh
# Year 2016: Unmet Load = 0.00 kWh
# Year 2015: Unmet Load = 0.00 kWh
# Year 2014: Unmet Load = 0.00 kWh
# Year 2013: Unmet Load = 0.00 kWh
# Year 2012: Unmet Load = 0.00 kWh
# Year 2011: Unmet Load = 0.00 kWh
# Year 2010: Unmet Load = 0.00 kWh
# Year 2009: Unmet Load = 0.00 kWh
# Year 2008: Unmet Load = 0.00 kWh
# Year 2007: Unmet Load = 0.00 kWh
# Year 2006: Unmet Load = 0.00 kWh
# Year 2005: Unmet Load = 0.00 kWh
# Year 2004: Unmet Load = 0.00 kWh
# Year 2003: Unmet Load = 0.00 kWh
# Year 2002: Unmet Load = 0.00 kWh
# Year 2001: Unmet Load = 0.00 kWh
# Year 2000: Unmet Load = 0.00 kWh
# Year 1999: Unmet Load = 0.00 kWh
# Year 1998: Unmet Load = 0.00 kWh
# Year 1997: Unmet Load = 0.00 kWh
# Year 1996: Unmet Load = 0.00 kWh
# Year 1995: Unmet Load = 0.00 kWh
# Year 1994: Unmet Load = 0.00 kWh
# Year 1993: Unmet Load = 0.00 kWh
# Year 1992: Unmet Load = 0.00 kWh
# Year 1991: Unmet Load = 0.00 kWh
# Year 1990: Unmet Load = 0.00 kWh
# Year 1989: Unmet Load = 0.00 kWh
# Year 1988: Unmet Load = 0.00 kWh
# Year 1987: Unmet Load = 0.00 kWh
# Year 1986: Unmet Load = 0.00 kWh
# Year 1985: Unmet Load = 0.00 kWh
# Year 1984: Unmet Load = 0.00 kWh
# Year 1983: Unmet Load = 0.00 kWh
# Year 1982: Unmet Load = 0.00 kWh
# Year 1981: Unmet Load = 0.00 kWh
# Year 1980: Unmet Load = 0.00 kWh
#
# Average Unmet Load (1979-2024): 0.00 kWh
# Min Unmet Load: 0.00 kWh (Year 1980)
# Max Unmet Load: 0.00 kWh (Year 2024)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set your local directory
directory = r"dispatch_outputs_100_percent_met_55_percent_inference"

# Prepare to store results
unmet_loads = {}

# Loop through each year
for year in range(1980, 2025):
    filename = f"hourly_dispatch_{year}.csv"
    file_path = os.path.join(directory, filename)
    
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
        unmet_total = df["Unmet (kW)"].sum()
        unmet_loads[year] = unmet_total
    else:
        print(f"File not found for year {year}")

# Convert to DataFrame
unmet_df = pd.DataFrame(list(unmet_loads.items()), columns=["Year", "Unmet Load (kWh)"])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(unmet_df["Year"], unmet_df["Unmet Load (kWh)"], marker='o')
plt.title("Unmet Load by Year (1980–2024) 55% reduction in LP for 100% met Sizing")
plt.xlabel("Year")
plt.ylabel("Unmet Load (kWh)")
plt.grid(True)
plt.tight_layout()
plt.show()
