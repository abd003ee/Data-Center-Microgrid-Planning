# %% [markdown]
# # 99% met Load sizing

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.01 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5


# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:
        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        
        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

        # === Save Capacity, Cost, and Utilization Metrics for All Years ===
        print("Starting capacity, cost, and utilization metrics collection...")
        results_by_year = []
        for year in range(2024, 1979, -1):
            print(f"Processing year {year} for capacity, cost, and utilization metrics...")
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                print(f"Year {year}: Skipping due to missing resource data.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                print(f"Year {year}: Dispatch simulation successful, calculating metrics...")
                # Calculate utilization metrics
                total_curtailed = np.sum(dispatch_result["curtailment"])
                solar_gen = solar_resource * opt_results["solar"]
                wind_gen = wind_resource * opt_results["wind"]
                total_generated = np.sum(solar_gen + wind_gen)
                total_power_consumed = total_generated - total_curtailed
                utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

                # Calculate battery replacement cost
                yearly_degradation = dispatch_result["degradation"]
                battery_replacement = calculate_battery_replacement_cost(
                    battery_capex=opt_results["battery_capex"],
                    degradation=yearly_degradation,
                    inf=inf,
                    dis=dis,
                    life_battery=life_battery
                )

                # Calculate total NPC
                total_npc = (
                    opt_results["solar_capex"] +
                    opt_results["solar_opex"] +
                    opt_results["solar_replacement"] -
                    opt_results["solar_salvage"] +
                    opt_results["wind_capex"] +
                    opt_results["wind_opex"] +
                    opt_results["wind_replacement"] -
                    opt_results["wind_salvage"] +
                    opt_results["battery_capex"] +
                    opt_results["battery_opex"] +
                    battery_replacement -
                    opt_results["battery_salvage"] +
                    opt_results["inverter_capex"] +
                    opt_results["inverter_opex"] +
                    opt_results["inverter_replacement"] -
                    opt_results["inverter_salvage"]
                )

                # Store results
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": opt_results["solar"],
                    "Wind_Capacity_HAWT": opt_results["wind"],
                    "Battery_Capacity_kWh": opt_results["battery"],
                    "Inverter_Capacity_kW": inverter_capacity,
                    "Solar_CAPEX": opt_results["solar_capex"],
                    "Solar_OPEX": opt_results["solar_opex"],
                    "Solar_Replacement": opt_results["solar_replacement"],
                    "Solar_Salvage": opt_results["solar_salvage"],
                    "Wind_CAPEX": opt_results["wind_capex"],
                    "Wind_OPEX": opt_results["wind_opex"],
                    "Wind_Replacement": opt_results["wind_replacement"],
                    "Wind_Salvage": opt_results["wind_salvage"],
                    "Battery_CAPEX": opt_results["battery_capex"],
                    "Battery_OPEX": opt_results["battery_opex"],
                    "Battery_Replacement": battery_replacement,
                    "Battery_Salvage": opt_results["battery_salvage"],
                    "Inverter_CAPEX": opt_results["inverter_capex"],
                    "Inverter_OPEX": opt_results["inverter_opex"],
                    "Inverter_Replacement": opt_results["inverter_replacement"],
                    "Inverter_Salvage": opt_results["inverter_salvage"],
                    "Total_NPC": total_npc,
                    "Utilization_Percentage": utilization_percentage,
                    "Total_Curtailed_kWh": total_curtailed,
                    "Total_Generated_kWh": total_generated,
                    "Total_Power_Consumed_kWh": total_power_consumed,
                    "Total_Unmet_kWh": dispatch_result["total_unmet"]
                })
                print(f"Year {year}: Metrics added - Utilization: {utilization_percentage:.2f}%, NPC: {total_npc:.2f}, Unmet: {dispatch_result['total_unmet']:.2f} kWh")
            else:
                print(f"Year {year}: Metrics save failed due to dispatch simulation error.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })

        # Save results to CSV
        try:
            df_results = pd.DataFrame(results_by_year)
            csv_path = os.path.join(output_dir, "capacity_and_costs_by_year.csv")
            df_results.to_csv(csv_path, index=False)
            print(f"Saved capacity, cost, and utilization metrics to {csv_path}")
            print(f"CSV file location: {os.path.abspath(csv_path)}")
        except Exception as e:
            print(f"Error saving CSV: {e}")

        # === Plot NPC Variation Across Years ===
        print("Starting NPC variation plotting...")
        try:
            valid_npc_data = df_results[df_results["Total_NPC"].notna()][["Year", "Total_NPC"]]
            if valid_npc_data.empty:
                print("Error: No valid NPC data found for plotting.")
            else:
                plt.figure(figsize=(15, 8))
                plt.plot(valid_npc_data["Year"], valid_npc_data["Total_NPC"], marker='o', linestyle='-', color='b')
                plt.title("NPC Variation Across Years (1979-2024)")
                plt.xlabel("Year")
                plt.ylabel("Total NPC ($)")
                plt.grid(True)
                plt.gca().invert_xaxis()  # Reverse x-axis to show 2024 to 1979
                plt.tight_layout()
                plot_path = os.path.join(output_dir, "npc_variation_by_year.png")
                plt.savefig(plot_path)
                plt.close()
                print(f"Saved NPC variation plot to {plot_path}")
                print(f"Plot file location: {os.path.abspath(plot_path)}")
        except Exception as e:
            print(f"Error plotting NPC variation: {e}")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2667226
# Academic license - for non-commercial use only - expires 2026-05-16
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0x1f48e2d4
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 7s)...
# Presolve removed 17524 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 7s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 15s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 22s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 26s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.84s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.227876e+05   3.669944e+06     46s
#     3173    8.9605641e+11   0.000000e+00   3.497662e+14     50s
#     5285    2.1365137e+11   3.333054e-03   1.930181e+13     55s
#     7304    6.6722528e+10   1.368650e-02   4.404374e+13     60s
#     9331    3.4712912e+10   5.847669e+04   2.294194e+13     65s
#    11135    2.3568691e+10   5.586634e-05   3.637454e+07     70s
#    12634    1.8791354e+10   2.083304e-03   3.238526e+11     75s
#    14082    1.4880535e+10   4.413896e-03   1.284194e+11     80s
#    21205   -1.4497796e+10   1.085718e+11   0.000000e+00     85s
#    24711   -1.4372956e+10   4.903397e+12   0.000000e+00     90s
#    26965    7.5508974e+08   7.856178e+09   0.000000e+00     95s
#    29929    8.6008473e+08   1.348551e+09   0.000000e+00    100s
# Concurrent spin time: 18.21s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 3.380229e+09, 45480 iterations, 72.88 seconds (59.54 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.3802e+09    0    4          - 3.3802e+09      -     -  118s
# H    0     0                    3.422278e+09 3.3802e+09  1.23%     -  121s
# H    0     0                    3.411333e+09 3.3802e+09  0.91%     -  133s
#
# Explored 1 nodes (45480 simplex iterations) in 133.91 seconds (137.70 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 3.41133e+09 3.42228e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.411332883332e+09, best bound 3.380228704637e+09, gap 0.9118%
# Optimal Solution Found!
# Solar Capacity: 7946302.29 PV
# Wind Capacity: 134.09 HAWT
# Battery Capacity: 3862412.64 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 2040258740.78 kWh
# Total Energy Generated: 4711239663.15 kWh
# Total Energy Used (along with efficiency losses): 2670980922.37 kWh
# Utilization Percentage: 56.69%
# $34597326.88 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 7946302.29 PV
# Solar Initial Cost:    $738608797.68
# Wind Initial Capacity: 134.09 HAWT
# Wind Initial Cost:     $685687101.79
# Battery Initial Capacity: 3862412.64 kWh
# Battery Initial Cost:  $1382743726.26
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -25428.17 PV
# Solar Redundant Cost:    $-2363548.15
# Wind Redundant Capacity: 11.84 HAWT
# Wind Redundant Cost:     $60532457.35
# Battery Redundant Capacity: 14290.93 kWh
# Battery Redundant Cost:  $5116151.79
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $736245249.53
# Solar OPEX:         $804174686.85
# Solar Replacement:  $0.00
# Solar Salvage:     -$214029011.61
# Wind CAPEX:         $746219559.13
# Wind OPEX:          $159717702.39
# Wind Replacement:   $0.00
# Wind Salvage:      -$135580360.95
# Battery CAPEX:      $1387859878.04
# Battery OPEX:       $418116976.35
# Battery Replacement:$439584207.07
# Battery Salvage:   -$504319515.38
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3850917090.40
#
# === 2024 Results ===
# Total Unmet Load: 18165054.87 kWh
# Hours with Unmet Load: [59, 60, 61, 62, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 155, 156, 157, 158, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 548, 549, 550, 551, 553, 554, 555, 556, 557, 559, 560, 561, 562, 563, 564, 572, 585, 586, 587, 588, 589, 590, 591, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 684, 685, 756, 846, 847, 848, 849, 850, 851, 852, 992, 993, 994, 995, 996, 1475, 1476, 1477, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 2987, 3034, 3035, 4895, 4896, 4897, 4898, 4899, 4900, 4901, 4902, 4919, 4930, 4931, 4932, 4955, 4956, 4978, 4979, 4980, 4999, 5000, 5001, 5002, 5003, 5004, 5005, 5023, 5024, 5025, 5026, 5027, 5028, 7474, 7475, 7476, 7545, 7546, 7547, 7548, 7549, 7550, 7572, 7643, 7644, 7861, 8028, 8645, 8646, 8647, 8648, 8649, 8650, 8651, 8652, 8653, 8654, 8725]
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           12 0.5343     0.000047
# discharge         16           37 0.8877     0.000116
# discharge         42           63 0.9977     0.000143
# discharge         69           85 0.3653     0.000024
# discharge         89          110 0.7376     0.000084
# discharge        114          133 0.3385     0.000021
# discharge        141          158 0.6517     0.000067
# discharge        163          180 0.7039     0.000077
# discharge        186          204 0.3977     0.000028
# discharge        208          228 0.3775     0.000025
# discharge        231          254 0.4627     0.000036
# discharge        257          279 0.2815     0.000015
# discharge        281          300 0.3813     0.000026
# discharge        303          324 0.5522     0.000050
# discharge        328          349 0.7939     0.000095
# discharge        357          373 0.7032     0.000077
# discharge        376          396 0.8725     0.000113
# discharge        400          424 0.4974     0.000041
# discharge        426          444 0.5244     0.000045
# discharge        448          468 0.6355     0.000064
# discharge        471          492 0.8387     0.000105
# discharge        496          516 0.6306     0.000063
# discharge        520          543 0.1982     0.000008
# discharge        547          567 0.1722     0.000006
# discharge        571          591 0.9098     0.000122
# discharge        597          613 0.1887     0.000007
# discharge        619          637 0.5043     0.000042
# discharge        645          660 0.5512     0.000050
# discharge        665          685 0.9731     0.000137
# discharge        690          709 0.7046     0.000077
# discharge        713          732 0.5498     0.000049
# discharge        736          756 0.9534     0.000132
# discharge        762          780 0.6435     0.000065
# discharge        784          805 0.8270     0.000102
# discharge        812          830 0.5344     0.000047
# discharge        836          852 0.4318     0.000032
# discharge        857          876 0.4417     0.000033
# discharge        879          901 0.6797     0.000072
# discharge        904          924 0.4333     0.000032
# discharge        927          949 0.3483     0.000022
# discharge        956          974 0.5224     0.000045
# discharge        980          996 0.6186     0.000061
# discharge       1001         1021 0.5479     0.000049
# discharge       1028         1044 0.7096     0.000078
# discharge       1048         1068 0.7536     0.000087
# discharge       1072         1092 0.4968     0.000041
# discharge       1095         1117 0.8747     0.000113
# discharge       1125         1140 0.2401     0.000011
# discharge       1144         1164 0.9142     0.000123
# discharge       1168         1188 0.8230     0.000102
# discharge       1192         1212 0.7344     0.000083
# discharge       1216         1236 0.6071     0.000059
# discharge       1240         1260 0.2122     0.000009
# discharge       1264         1284 0.5631     0.000052
# discharge       1287         1308 0.3197     0.000019
# discharge       1310         1332 0.5790     0.000054
# discharge       1336         1356 0.2249     0.000010
# discharge       1358         1380 0.1604     0.000005
# discharge       1382         1404 0.1755     0.000006
# discharge       1407         1428 0.7417     0.000084
# discharge       1432         1452 0.8069     0.000098
# discharge       1457         1477 0.9893     0.000141
# discharge       1482         1500 0.5485     0.000049
# discharge       1503         1524 0.4242     0.000031
# discharge       1527         1549 0.6810     0.000072
# discharge       1557         1572 0.7847     0.000093
# discharge       1577         1597 0.8195     0.000101
# discharge       1603         1621 0.6700     0.000070
# discharge       1630         1644 0.7023     0.000076
# discharge       1650         1668 0.6141     0.000060
# discharge       1671         1692 0.8445     0.000106
# discharge       1696         1716 0.6735     0.000071
# discharge       1720         1740 0.4181     0.000030
# discharge       1743         1764 0.3284     0.000020
# discharge       1767         1789 0.4691     0.000037
# discharge       1798         1812 0.8194     0.000101
# discharge       1816         1836 0.7555     0.000087
# discharge       1842         1860 0.4618     0.000036
# discharge       1863         1884 0.7850     0.000093
# discharge       1888         1908 0.3446     0.000021
# discharge       1911         1932 0.7426     0.000085
# discharge       1937         1957 0.8100     0.000099
# discharge       1964         1979 0.4024     0.000028
# discharge       1984         2004 0.4903     0.000040
# discharge       2009         2027 0.2408     0.000011
# discharge       2031         2052 0.6222     0.000062
# discharge       2056         2076 0.5141     0.000044
# discharge       2079         2100 0.6907     0.000074
# discharge       2104         2123 0.6822     0.000073
# discharge       2127         2147 0.3380     0.000021
# discharge       2150         2172 0.4127     0.000030
# discharge       2175         2196 0.3741     0.000025
# discharge       2201         2219 0.1802     0.000007
# discharge       2223         2243 0.3825     0.000026
# discharge       2246         2267 0.3517     0.000022
# discharge       2270         2291 0.4773     0.000038
# discharge       2295         2316 0.5350     0.000047
# discharge       2320         2339 0.3767     0.000025
# discharge       2342         2364 0.6198     0.000061
# discharge       2369         2388 0.3871     0.000026
# discharge       2395         2411 0.6925     0.000075
# discharge       2420         2435 0.5176     0.000044
# discharge       2442         2459 0.2418     0.000011
# discharge       2462         2483 0.6652     0.000069
# discharge       2488         2507 0.3239     0.000019
# discharge       2510         2531 0.4213     0.000031
# discharge       2535         2555 0.5575     0.000051
# discharge       2559         2580 0.2047     0.000008
# discharge       2583         2603 0.6102     0.000059
# discharge       2608         2627 0.4142     0.000030
# discharge       2631         2652 0.4783     0.000038
# discharge       2656         2675 0.5770     0.000054
# discharge       2679         2699 0.7439     0.000085
# discharge       2704         2723 0.4694     0.000037
# discharge       2727         2748 0.4725     0.000038
# discharge       2751         2771 0.4601     0.000036
# discharge       2775         2796 0.5962     0.000057
# discharge       2800         2820 0.2912     0.000016
# discharge       2823         2843 0.2769     0.000014
# discharge       2846         2868 0.3465     0.000022
# discharge       2873         2891 0.9011     0.000120
# discharge       2896         2915 0.6387     0.000065
# discharge       2920         2939 0.6035     0.000058
# discharge       2944         2963 0.8555     0.000109
# discharge       2973         2988 0.9152     0.000123
# discharge       2997         3012 0.8900     0.000117
# discharge       3021         3035 0.7105     0.000078
# discharge       3041         3059 0.4333     0.000032
# discharge       3063         3084 0.3428     0.000021
# discharge       3087         3108 0.3683     0.000024
# discharge       3111         3131 0.5366     0.000047
# discharge       3135         3155 0.8070     0.000098
# discharge       3160         3179 0.7365     0.000083
# discharge       3185         3205 0.8241     0.000102
# discharge       3214         3227 0.5058     0.000043
# discharge       3231         3251 0.5889     0.000056
# discharge       3255         3275 0.7790     0.000092
# discharge       3280         3300 0.8358     0.000104
# discharge       3305         3324 0.7530     0.000087
# discharge       3332         3347 0.8412     0.000106
# discharge       3352         3371 0.7046     0.000077
# discharge       3376         3395 0.5800     0.000054
# discharge       3399         3420 0.4133     0.000030
# discharge       3425         3444 0.7033     0.000077
# discharge       3452         3468 0.6908     0.000074
# discharge       3475         3491 0.6200     0.000061
# discharge       3496         3515 0.4890     0.000040
# discharge       3520         3539 0.2990     0.000017
# discharge       3542         3563 0.7004     0.000076
# discharge       3568         3587 0.7928     0.000095
# discharge       3592         3611 0.5423     0.000048
# discharge       3615         3636 0.5558     0.000050
# discharge       3641         3660 0.4807     0.000039
# discharge       3664         3683 0.8168     0.000100
# discharge       3688         3707 0.7469     0.000085
# discharge       3715         3731 0.5752     0.000054
# discharge       3736         3755 0.5557     0.000050
# discharge       3760         3779 0.7937     0.000095
# discharge       3784         3803 0.5445     0.000049
# discharge       3807         3827 0.7134     0.000079
# discharge       3834         3851 0.4405     0.000033
# discharge       3857         3875 0.5670     0.000052
# discharge       3879         3899 0.5237     0.000045
# discharge       3903         3923 0.6313     0.000063
# discharge       3928         3947 0.8016     0.000097
# discharge       3952         3971 0.8176     0.000100
# discharge       3977         3995 0.8075     0.000098
# discharge       4001         4019 0.7227     0.000081
# discharge       4024         4043 0.5826     0.000055
# discharge       4051         4068 0.6964     0.000075
# discharge       4075         4091 0.7037     0.000077
# discharge       4097         4115 0.6056     0.000059
# discharge       4120         4139 0.7195     0.000080
# discharge       4144         4163 0.8060     0.000098
# discharge       4168         4187 0.5894     0.000056
# discharge       4191         4211 0.8113     0.000099
# discharge       4217         4235 0.8023     0.000097
# discharge       4241         4259 0.7075     0.000078
# discharge       4264         4283 0.5110     0.000043
# discharge       4287         4307 0.6629     0.000069
# discharge       4312         4331 0.6798     0.000072
# discharge       4336         4355 0.6505     0.000067
# discharge       4361         4379 0.5428     0.000048
# discharge       4383         4403 0.5765     0.000054
# discharge       4408         4427 0.7081     0.000078
# discharge       4432         4451 0.6228     0.000062
# discharge       4456         4475 0.6281     0.000063
# discharge       4481         4499 0.7018     0.000076
# discharge       4505         4523 0.7049     0.000077
# discharge       4528         4547 0.8308     0.000103
# discharge       4555         4571 0.4606     0.000036
# discharge       4575         4595 0.5774     0.000054
# discharge       4599         4619 0.8269     0.000102
# discharge       4624         4643 0.8119     0.000099
# discharge       4649         4667 0.7431     0.000085
# discharge       4673         4691 0.8244     0.000102
# discharge       4697         4715 0.6909     0.000074
# discharge       4721         4739 0.6809     0.000072
# discharge       4744         4765 0.7062     0.000077
# discharge       4772         4787 0.7247     0.000081
# discharge       4793         4811 0.4779     0.000038
# discharge       4815         4835 0.7025     0.000077
# discharge       4840         4859 0.7707     0.000090
# discharge       4864         4883 0.7317     0.000082
# discharge       4889         4910 0.4427     0.000033
# discharge       4918         4932 0.7852     0.000093
# discharge       4942         4956 0.8414     0.000106
# discharge       4966         4980 0.8228     0.000102
# discharge       4990         5005 0.6162     0.000061
# discharge       5014         5028 0.6270     0.000062
# discharge       5037         5051 0.5720     0.000053
# discharge       5055         5075 0.5766     0.000054
# discharge       5080         5099 0.6374     0.000064
# discharge       5104         5123 0.5678     0.000052
# discharge       5127         5147 0.6244     0.000062
# discharge       5152         5171 0.7375     0.000084
# discharge       5176         5195 0.7538     0.000087
# discharge       5200         5219 0.6898     0.000074
# discharge       5224         5243 0.7745     0.000091
# discharge       5248         5267 0.6457     0.000066
# discharge       5272         5291 0.6407     0.000065
# discharge       5296         5315 0.5773     0.000054
# discharge       5319         5339 0.5502     0.000049
# discharge       5343         5363 0.7228     0.000081
# discharge       5368         5387 0.7692     0.000090
# discharge       5392         5411 0.8471     0.000107
# discharge       5417         5436 0.8382     0.000105
# discharge       5441         5459 0.7617     0.000088
# discharge       5464         5483 0.6148     0.000060
# discharge       5488         5508 0.8278     0.000103
# discharge       5513         5531 0.8271     0.000103
# discharge       5536         5555 0.6444     0.000066
# discharge       5560         5579 0.5762     0.000054
# discharge       5583         5603 0.5491     0.000049
# discharge       5607         5627 0.5274     0.000046
# discharge       5631         5651 0.6176     0.000061
# discharge       5656         5675 0.6245     0.000062
# discharge       5680         5699 0.6456     0.000066
# discharge       5704         5723 0.7821     0.000093
# discharge       5728         5748 0.8503     0.000108
# discharge       5753         5772 0.8698     0.000112
# discharge       5777         5796 0.8279     0.000103
# discharge       5801         5820 0.8608     0.000110
# discharge       5826         5844 0.9505     0.000131
# discharge       5851         5869 0.8895     0.000117
# discharge       5877         5891 0.7440     0.000085
# discharge       5896         5916 0.4815     0.000039
# discharge       5919         5940 0.6879     0.000074
# discharge       5948         5964 0.7740     0.000091
# discharge       5968         5988 0.8983     0.000119
# discharge       5993         6011 0.5666     0.000052
# discharge       6015         6035 0.4365     0.000033
# discharge       6039         6059 0.4536     0.000035
# discharge       6063         6084 0.5438     0.000048
# discharge       6088         6108 0.7721     0.000091
# discharge       6112         6132 0.4821     0.000039
# discharge       6140         6156 0.3007     0.000017
# discharge       6161         6180 0.9289     0.000126
# discharge       6189         6204 0.5153     0.000044
# discharge       6209         6229 0.4366     0.000033
# discharge       6237         6252 0.8743     0.000113
# discharge       6257         6276 0.8269     0.000102
# discharge       6280         6300 0.8977     0.000119
# discharge       6305         6324 0.9100     0.000122
# discharge       6329         6348 0.8235     0.000102
# discharge       6357         6372 0.8528     0.000108
# discharge       6377         6396 0.8302     0.000103
# discharge       6404         6420 0.8827     0.000115
# discharge       6426         6445 0.8284     0.000103
# discharge       6449         6468 0.6647     0.000069
# discharge       6472         6492 0.3660     0.000024
# discharge       6496         6516 0.3655     0.000024
# discharge       6520         6540 0.7964     0.000096
# discharge       6546         6564 0.8616     0.000110
# discharge       6569         6588 0.9210     0.000124
# discharge       6593         6612 0.4445     0.000034
# discharge       6615         6636 0.8585     0.000110
# discharge       6640         6660 0.7781     0.000092
# discharge       6664         6684 0.7794     0.000092
# discharge       6688         6708 0.9342     0.000127
# discharge       6713         6732 0.6198     0.000061
# discharge       6736         6756 0.4751     0.000038
# discharge       6759         6780 0.5681     0.000052
# discharge       6783         6804 0.5694     0.000053
# discharge       6807         6828 0.8825     0.000115
# discharge       6833         6852 0.8407     0.000106
# discharge       6856         6876 0.4133     0.000030
# discharge       6879         6900 0.5048     0.000042
# discharge       6903         6924 0.8940     0.000118
# discharge       6929         6948 0.5084     0.000043
# discharge       6951         6972 0.7999     0.000097
# discharge       6976         6996 0.7700     0.000090
# discharge       7000         7020 0.7758     0.000091
# discharge       7024         7044 0.8888     0.000117
# discharge       7048         7068 0.8955     0.000118
# discharge       7073         7092 0.6640     0.000069
# discharge       7096         7116 0.4302     0.000032
# discharge       7119         7140 0.6741     0.000071
# discharge       7144         7164 0.6082     0.000059
# discharge       7168         7188 0.7205     0.000080
# discharge       7194         7212 0.7074     0.000077
# discharge       7216         7236 0.6878     0.000074
# discharge       7240         7260 0.3831     0.000026
# discharge       7263         7284 0.3541     0.000022
# discharge       7287         7308 0.2891     0.000016
# discharge       7311         7332 0.9068     0.000121
# discharge       7338         7357 0.7689     0.000090
# discharge       7362         7381 0.6046     0.000059
# discharge       7385         7405 0.3951     0.000027
# discharge       7408         7428 0.2408     0.000011
# discharge       7431         7453 0.8643     0.000111
# discharge       7461         7476 0.7447     0.000085
# discharge       7482         7500 0.6427     0.000065
# discharge       7505         7525 0.6564     0.000068
# discharge       7532         7550 0.6375     0.000064
# discharge       7557         7572 0.7353     0.000083
# discharge       7577         7596 0.6864     0.000073
# discharge       7600         7622 0.5936     0.000057
# discharge       7628         7644 0.5730     0.000053
# discharge       7649         7668 0.8719     0.000113
# discharge       7673         7693 0.7721     0.000091
# discharge       7697         7716 0.6251     0.000062
# discharge       7721         7740 0.4606     0.000036
# discharge       7744         7765 0.5022     0.000042
# discharge       7768         7788 0.6285     0.000063
# discharge       7792         7812 0.2995     0.000017
# discharge       7815         7836 0.4415     0.000033
# discharge       7839         7861 0.9709     0.000137
# discharge       7866         7884 0.6728     0.000071
# discharge       7888         7908 0.2000     0.000008
# discharge       7911         7932 0.4567     0.000035
# discharge       7935         7958 0.8278     0.000103
# discharge       7964         7980 0.4648     0.000037
# discharge       7985         8004 0.6975     0.000076
# discharge       8008         8028 0.9534     0.000132
# discharge       8033         8053 0.7118     0.000078
# discharge       8058         8076 0.8710     0.000112
# discharge       8081         8100 0.5741     0.000053
# discharge       8104         8124 0.6348     0.000064
# discharge       8128         8148 0.4482     0.000034
# discharge       8151         8172 0.7030     0.000077
# discharge       8176         8196 0.9158     0.000123
# discharge       8201         8222 0.4672     0.000037
# discharge       8228         8245 0.5497     0.000049
# discharge       8250         8269 0.9603     0.000134
# discharge       8275         8292 0.5812     0.000055
# discharge       8296         8316 0.7728     0.000091
# discharge       8320         8343 0.6374     0.000064
# discharge       8348         8365 0.4843     0.000039
# discharge       8368         8389 0.6486     0.000066
# discharge       8394         8413 0.3755     0.000025
# discharge       8420         8437 0.6974     0.000076
# discharge       8444         8462 0.7524     0.000087
# discharge       8470         8484 0.6067     0.000059
# discharge       8489         8508 0.5410     0.000048
# discharge       8511         8532 0.6412     0.000065
# discharge       8536         8556 0.8407     0.000106
# discharge       8561         8580 0.5851     0.000055
# discharge       8584         8605 0.6463     0.000066
# discharge       8611         8630 0.8739     0.000113
# discharge       8636         8654 0.4503     0.000035
# discharge       8661         8677 0.3210     0.000019
# discharge       8681         8701 0.6552     0.000068
# discharge       8704         8705 0.0006     0.000000
# discharge       8707         8725 0.4547     0.000035
# discharge       8730         8749 0.6760     0.000071
#
# Total Estimated Degradation: 0.024322
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 18165054.87 kWh
# Year 2023: Unmet Load = 14484044.83 kWh
# Year 2022: Unmet Load = 19374198.10 kWh
# Year 2021: Unmet Load = 9270965.09 kWh
# Year 2020: Unmet Load = 25611424.16 kWh
# Year 2019: Unmet Load = 33988118.88 kWh
# Year 2018: Unmet Load = 21220717.13 kWh
# Year 2017: Unmet Load = 28700851.07 kWh
# Year 2016: Unmet Load = 26515239.23 kWh
# Year 2015: Unmet Load = 36142619.26 kWh
# Year 2014: Unmet Load = 25667693.62 kWh
# Year 2013: Unmet Load = 23089849.43 kWh
# Year 2012: Unmet Load = 17657215.51 kWh
# Year 2011: Unmet Load = 22329766.16 kWh
# Year 2010: Unmet Load = 12299017.39 kWh
# Year 2009: Unmet Load = 21581660.37 kWh
# Year 2008: Unmet Load = 16145351.22 kWh
# Year 2007: Unmet Load = 22317215.48 kWh
# Year 2006: Unmet Load = 20271259.83 kWh
# Year 2005: Unmet Load = 21056813.28 kWh
# Year 2004: Unmet Load = 20761855.18 kWh
# Year 2003: Unmet Load = 21398632.13 kWh
# Year 2002: Unmet Load = 21255388.51 kWh
# Year 2001: Unmet Load = 27679524.80 kWh
# Year 2000: Unmet Load = 16106959.37 kWh
# Year 1999: Unmet Load = 12687462.94 kWh
# Year 1998: Unmet Load = 34987278.62 kWh
# Year 1997: Unmet Load = 21168666.03 kWh
# Year 1996: Unmet Load = 24812878.61 kWh
# Year 1995: Unmet Load = 7232512.58 kWh
# Year 1994: Unmet Load = 32723402.58 kWh
# Year 1993: Unmet Load = 31008006.88 kWh
# Year 1992: Unmet Load = 31124388.74 kWh
# Year 1991: Unmet Load = 32735783.14 kWh
# Year 1990: Unmet Load = 23395060.98 kWh
# Year 1989: Unmet Load = 24996850.32 kWh
# Year 1988: Unmet Load = 9695515.26 kWh
# Year 1987: Unmet Load = 25903286.36 kWh
# Year 1986: Unmet Load = 40104950.20 kWh
# Year 1985: Unmet Load = 25117060.27 kWh
# Year 1984: Unmet Load = 16018152.71 kWh
# Year 1983: Unmet Load = 36299877.25 kWh
# Year 1982: Unmet Load = 22639139.42 kWh
# Year 1981: Unmet Load = 26332400.14 kWh
# Year 1980: Unmet Load = 28599501.72 kWh
#
# Average Unmet Load (1979-2024): 23348302.44 kWh
# Min Unmet Load: 7232512.58 kWh (Year 1995)
# Max Unmet Load: 40104950.20 kWh (Year 1986)
# Starting capacity, cost, and utilization metrics collection...
# Processing year 2024 for capacity, cost, and utilization metrics...
# Year 2024: Dispatch simulation successful, calculating metrics...
# $34597326.88 is the replacement cost each year for degradation
# Year 2024: Metrics added - Utilization: 56.69%, NPC: 3850917090.40, Unmet: 18165054.87 kWh
# Processing year 2023 for capacity, cost, and utilization metrics...
# Year 2023: Dispatch simulation successful, calculating metrics...
# $35543188.72 is the replacement cost each year for degradation
# Year 2023: Metrics added - Utilization: 57.17%, NPC: 3862934953.16, Unmet: 14484044.83 kWh
# Processing year 2022 for capacity, cost, and utilization metrics...
# Year 2022: Dispatch simulation successful, calculating metrics...
# $33362312.54 is the replacement cost each year for degradation
# Year 2022: Metrics added - Utilization: 54.58%, NPC: 3835225334.83, Unmet: 19374198.10 kWh
# Processing year 2021 for capacity, cost, and utilization metrics...
# Year 2021: Dispatch simulation successful, calculating metrics...
# $34100841.58 is the replacement cost each year for degradation
# Year 2021: Metrics added - Utilization: 57.13%, NPC: 3844608883.51, Unmet: 9270965.09 kWh
# Processing year 2020 for capacity, cost, and utilization metrics...
# Year 2020: Dispatch simulation successful, calculating metrics...
# $35155226.50 is the replacement cost each year for degradation
# Year 2020: Metrics added - Utilization: 57.85%, NPC: 3858005610.97, Unmet: 25611424.16 kWh
# Processing year 2019 for capacity, cost, and utilization metrics...
# Year 2019: Dispatch simulation successful, calculating metrics...
# $36315615.19 is the replacement cost each year for degradation
# Year 2019: Metrics added - Utilization: 58.76%, NPC: 3872749193.44, Unmet: 33988118.88 kWh
# Processing year 2018 for capacity, cost, and utilization metrics...
# Year 2018: Dispatch simulation successful, calculating metrics...
# $36690248.19 is the replacement cost each year for degradation
# Year 2018: Metrics added - Utilization: 59.17%, NPC: 3877509178.24, Unmet: 21220717.13 kWh
# Processing year 2017 for capacity, cost, and utilization metrics...
# Year 2017: Dispatch simulation successful, calculating metrics...
# $34116978.06 is the replacement cost each year for degradation
# Year 2017: Metrics added - Utilization: 56.63%, NPC: 3844813909.21, Unmet: 28700851.07 kWh
# Processing year 2016 for capacity, cost, and utilization metrics...
# Year 2016: Dispatch simulation successful, calculating metrics...
# $34698182.98 is the replacement cost each year for degradation
# Year 2016: Metrics added - Utilization: 56.76%, NPC: 3852198540.52, Unmet: 26515239.23 kWh
# Processing year 2015 for capacity, cost, and utilization metrics...
# Year 2015: Dispatch simulation successful, calculating metrics...
# $33789558.68 is the replacement cost each year for degradation
# Year 2015: Metrics added - Utilization: 57.90%, NPC: 3840653807.78, Unmet: 36142619.26 kWh
# Processing year 2014 for capacity, cost, and utilization metrics...
# Year 2014: Dispatch simulation successful, calculating metrics...
# $33093966.92 is the replacement cost each year for degradation
# Year 2014: Metrics added - Utilization: 55.69%, NPC: 3831815808.38, Unmet: 25667693.62 kWh
# Processing year 2013 for capacity, cost, and utilization metrics...
# Year 2013: Dispatch simulation successful, calculating metrics...
# $35197012.08 is the replacement cost each year for degradation
# Year 2013: Metrics added - Utilization: 56.91%, NPC: 3858536527.11, Unmet: 23089849.43 kWh
# Processing year 2012 for capacity, cost, and utilization metrics...
# Year 2012: Dispatch simulation successful, calculating metrics...
# $32384617.25 is the replacement cost each year for degradation
# Year 2012: Metrics added - Utilization: 55.58%, NPC: 3822803004.90, Unmet: 17657215.51 kWh
# Processing year 2011 for capacity, cost, and utilization metrics...
# Year 2011: Dispatch simulation successful, calculating metrics...
# $33046845.56 is the replacement cost each year for degradation
# Year 2011: Metrics added - Utilization: 55.84%, NPC: 3831217097.23, Unmet: 22329766.16 kWh
# Processing year 2010 for capacity, cost, and utilization metrics...
# Year 2010: Dispatch simulation successful, calculating metrics...
# $35615678.62 is the replacement cost each year for degradation
# Year 2010: Metrics added - Utilization: 56.19%, NPC: 3863855990.12, Unmet: 12299017.39 kWh
# Processing year 2009 for capacity, cost, and utilization metrics...
# Year 2009: Dispatch simulation successful, calculating metrics...
# $33863559.96 is the replacement cost each year for degradation
# Year 2009: Metrics added - Utilization: 57.15%, NPC: 3841594047.82, Unmet: 21581660.37 kWh
# Processing year 2008 for capacity, cost, and utilization metrics...
# Year 2008: Dispatch simulation successful, calculating metrics...
# $32768757.56 is the replacement cost each year for degradation
# Year 2008: Metrics added - Utilization: 54.70%, NPC: 3827683786.93, Unmet: 16145351.22 kWh
# Processing year 2007 for capacity, cost, and utilization metrics...
# Year 2007: Dispatch simulation successful, calculating metrics...
# $35432567.12 is the replacement cost each year for degradation
# Year 2007: Metrics added - Utilization: 55.75%, NPC: 3861529425.34, Unmet: 22317215.48 kWh
# Processing year 2006 for capacity, cost, and utilization metrics...
# Year 2006: Dispatch simulation successful, calculating metrics...
# $31865210.73 is the replacement cost each year for degradation
# Year 2006: Metrics added - Utilization: 54.59%, NPC: 3816203567.18, Unmet: 20271259.83 kWh
# Processing year 2005 for capacity, cost, and utilization metrics...
# Year 2005: Dispatch simulation successful, calculating metrics...
# $34149360.16 is the replacement cost each year for degradation
# Year 2005: Metrics added - Utilization: 54.81%, NPC: 3845225347.29, Unmet: 21056813.28 kWh
# Processing year 2004 for capacity, cost, and utilization metrics...
# Year 2004: Dispatch simulation successful, calculating metrics...
# $32563739.13 is the replacement cost each year for degradation
# Year 2004: Metrics added - Utilization: 56.46%, NPC: 3825078878.61, Unmet: 20761855.18 kWh
# Processing year 2003 for capacity, cost, and utilization metrics...
# Year 2003: Dispatch simulation successful, calculating metrics...
# $33198447.32 is the replacement cost each year for degradation
# Year 2003: Metrics added - Utilization: 55.76%, NPC: 3833143307.88, Unmet: 21398632.13 kWh
# Processing year 2002 for capacity, cost, and utilization metrics...
# Year 2002: Dispatch simulation successful, calculating metrics...
# $34020962.25 is the replacement cost each year for degradation
# Year 2002: Metrics added - Utilization: 56.16%, NPC: 3843593958.47, Unmet: 21255388.51 kWh
# Processing year 2001 for capacity, cost, and utilization metrics...
# Year 2001: Dispatch simulation successful, calculating metrics...
# $34202801.34 is the replacement cost each year for degradation
# Year 2001: Metrics added - Utilization: 55.11%, NPC: 3845904356.38, Unmet: 27679524.80 kWh
# Processing year 2000 for capacity, cost, and utilization metrics...
# Year 2000: Dispatch simulation successful, calculating metrics...
# $33666582.67 is the replacement cost each year for degradation
# Year 2000: Metrics added - Utilization: 54.28%, NPC: 3839091308.08, Unmet: 16106959.37 kWh
# Processing year 1999 for capacity, cost, and utilization metrics...
# Year 1999: Dispatch simulation successful, calculating metrics...
# $30702984.95 is the replacement cost each year for degradation
# Year 1999: Metrics added - Utilization: 53.43%, NPC: 3801436643.13, Unmet: 12687462.94 kWh
# Processing year 1998 for capacity, cost, and utilization metrics...
# Year 1998: Dispatch simulation successful, calculating metrics...
# $33135704.21 is the replacement cost each year for degradation
# Year 1998: Metrics added - Utilization: 55.82%, NPC: 3832346111.09, Unmet: 34987278.62 kWh
# Processing year 1997 for capacity, cost, and utilization metrics...
# Year 1997: Dispatch simulation successful, calculating metrics...
# $35087675.85 is the replacement cost each year for degradation
# Year 1997: Metrics added - Utilization: 56.58%, NPC: 3857147330.73, Unmet: 21168666.03 kWh
# Processing year 1996 for capacity, cost, and utilization metrics...
# Year 1996: Dispatch simulation successful, calculating metrics...
# $30739881.36 is the replacement cost each year for degradation
# Year 1996: Metrics added - Utilization: 54.30%, NPC: 3801905438.79, Unmet: 24812878.61 kWh
# Processing year 1995 for capacity, cost, and utilization metrics...
# Year 1995: Dispatch simulation successful, calculating metrics...
# $33113379.60 is the replacement cost each year for degradation
# Year 1995: Metrics added - Utilization: 54.65%, NPC: 3832062460.65, Unmet: 7232512.58 kWh
# Processing year 1994 for capacity, cost, and utilization metrics...
# Year 1994: Dispatch simulation successful, calculating metrics...
# $34725464.29 is the replacement cost each year for degradation
# Year 1994: Metrics added - Utilization: 57.54%, NPC: 3852545169.47, Unmet: 32723402.58 kWh
# Processing year 1993 for capacity, cost, and utilization metrics...
# Year 1993: Dispatch simulation successful, calculating metrics...
# $34533140.59 is the replacement cost each year for degradation
# Year 1993: Metrics added - Utilization: 58.58%, NPC: 3850101556.88, Unmet: 31008006.88 kWh
# Processing year 1992 for capacity, cost, and utilization metrics...
# Year 1992: Dispatch simulation successful, calculating metrics...
# $33794730.53 is the replacement cost each year for degradation
# Year 1992: Metrics added - Utilization: 57.92%, NPC: 3840719519.88, Unmet: 31124388.74 kWh
# Processing year 1991 for capacity, cost, and utilization metrics...
# Year 1991: Dispatch simulation successful, calculating metrics...
# $35939674.05 is the replacement cost each year for degradation
# Year 1991: Metrics added - Utilization: 60.96%, NPC: 3867972587.69, Unmet: 32735783.14 kWh
# Processing year 1990 for capacity, cost, and utilization metrics...
# Year 1990: Dispatch simulation successful, calculating metrics...
# $32693730.83 is the replacement cost each year for degradation
# Year 1990: Metrics added - Utilization: 56.11%, NPC: 3826730517.75, Unmet: 23395060.98 kWh
# Processing year 1989 for capacity, cost, and utilization metrics...
# Year 1989: Dispatch simulation successful, calculating metrics...
# $32969169.24 is the replacement cost each year for degradation
# Year 1989: Metrics added - Utilization: 57.14%, NPC: 3830230163.13, Unmet: 24996850.32 kWh
# Processing year 1988 for capacity, cost, and utilization metrics...
# Year 1988: Dispatch simulation successful, calculating metrics...
# $32114588.28 is the replacement cost each year for degradation
# Year 1988: Metrics added - Utilization: 53.65%, NPC: 3819372090.34, Unmet: 9695515.26 kWh
# Processing year 1987 for capacity, cost, and utilization metrics...
# Year 1987: Dispatch simulation successful, calculating metrics...
# $34953463.62 is the replacement cost each year for degradation
# Year 1987: Metrics added - Utilization: 57.51%, NPC: 3855442066.81, Unmet: 25903286.36 kWh
# Processing year 1986 for capacity, cost, and utilization metrics...
# Year 1986: Dispatch simulation successful, calculating metrics...
# $34236177.39 is the replacement cost each year for degradation
# Year 1986: Metrics added - Utilization: 56.78%, NPC: 3846328423.46, Unmet: 40104950.20 kWh
# Processing year 1985 for capacity, cost, and utilization metrics...
# Year 1985: Dispatch simulation successful, calculating metrics...
# $33298638.23 is the replacement cost each year for degradation
# Year 1985: Metrics added - Utilization: 56.00%, NPC: 3834416306.32, Unmet: 25117060.27 kWh
# Processing year 1984 for capacity, cost, and utilization metrics...
# Year 1984: Dispatch simulation successful, calculating metrics...
# $33340417.91 is the replacement cost each year for degradation
# Year 1984: Metrics added - Utilization: 56.31%, NPC: 3834947147.58, Unmet: 16018152.71 kWh
# Processing year 1983 for capacity, cost, and utilization metrics...
# Year 1983: Dispatch simulation successful, calculating metrics...
# $34905729.35 is the replacement cost each year for degradation
# Year 1983: Metrics added - Utilization: 57.61%, NPC: 3854835568.14, Unmet: 36299877.25 kWh
# Processing year 1982 for capacity, cost, and utilization metrics...
# Year 1982: Dispatch simulation successful, calculating metrics...
# $34305490.91 is the replacement cost each year for degradation
# Year 1982: Metrics added - Utilization: 57.77%, NPC: 3847209102.06, Unmet: 22639139.42 kWh
# Processing year 1981 for capacity, cost, and utilization metrics...
# Year 1981: Dispatch simulation successful, calculating metrics...
# $35648848.21 is the replacement cost each year for degradation
# Year 1981: Metrics added - Utilization: 55.57%, NPC: 3864277433.94, Unmet: 26332400.14 kWh
# Processing year 1980 for capacity, cost, and utilization metrics...
# Year 1980: Dispatch simulation successful, calculating metrics...
# $32513149.46 is the replacement cost each year for degradation
# Year 1980: Metrics added - Utilization: 54.42%, NPC: 3824436100.10, Unmet: 28599501.72 kWh
# Saved capacity, cost, and utilization metrics to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\capacity_and_costs_by_year.csv
# CSV file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\capacity_and_costs_by_year.csv
# Starting NPC variation plotting...
# Saved NPC variation plot to dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\npc_variation_by_year.png
# Plot file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment\npc_variation_by_year.png

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
        )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year 99% met Load Sizing (Hybrid Configuration)")
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")

# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 108.71 hours
# 1980: 136.37 extra training hours
# 1981: 134.15 extra training hours
# 1982: 105.66 extra training hours
# 1983: 177.88 extra training hours
# 1984: 74.93 extra training hours
# 1985: 122.07 extra training hours
# 1986: 194.21 extra training hours
# 1987: 115.34 extra training hours
# 1988: 41.67 extra training hours
# 1989: 118.88 extra training hours
# 1990: 109.85 extra training hours
# 1991: 146.27 extra training hours
# 1992: 149.19 extra training hours
# 1993: 148.59 extra training hours
# 1994: 155.93 extra training hours
# 1995: 26.34 extra training hours
# 1996: 118.58 extra training hours
# 1997: 95.28 extra training hours
# 1998: 169.99 extra training hours
# 1999: 58.16 extra training hours
# 2000: 76.38 extra training hours
# 2001: 129.51 extra training hours
# 2002: 98.90 extra training hours
# 2003: 107.32 extra training hours
# 2004: 97.20 extra training hours
# 2005: 93.26 extra training hours
# 2006: 96.40 extra training hours
# 2007: 103.69 extra training hours
# 2008: 78.33 extra training hours
# 2009: 100.09 extra training hours
# 2010: 52.29 extra training hours
# 2011: 104.17 extra training hours
# 2012: 78.50 extra training hours
# 2013: 104.69 extra training hours
# 2014: 117.96 extra training hours
# 2015: 155.52 extra training hours
# 2016: 124.49 extra training hours
# 2017: 131.08 extra training hours
# 2018: 90.94 extra training hours
# 2019: 157.95 extra training hours
# 2020: 117.97 extra training hours
# 2021: 43.31 extra training hours
# 2022: 88.40 extra training hours
# 2023: 65.51 extra training hours
# 2024: 78.92 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 235 hours with unmet load
# 1981: 196 hours with unmet load
# 1982: 189 hours with unmet load
# 1983: 269 hours with unmet load
# 1984: 128 hours with unmet load
# 1985: 193 hours with unmet load
# 1986: 307 hours with unmet load
# 1987: 220 hours with unmet load
# 1988: 94 hours with unmet load
# 1989: 200 hours with unmet load
# 1990: 188 hours with unmet load
# 1991: 267 hours with unmet load
# 1992: 242 hours with unmet load
# 1993: 264 hours with unmet load
# 1994: 261 hours with unmet load
# 1995: 83 hours with unmet load
# 1996: 198 hours with unmet load
# 1997: 169 hours with unmet load
# 1998: 261 hours with unmet load
# 1999: 115 hours with unmet load
# 2000: 133 hours with unmet load
# 2001: 225 hours with unmet load
# 2002: 168 hours with unmet load
# 2003: 164 hours with unmet load
# 2004: 156 hours with unmet load
# 2005: 159 hours with unmet load
# 2006: 165 hours with unmet load
# 2007: 194 hours with unmet load
# 2008: 109 hours with unmet load
# 2009: 197 hours with unmet load
# 2010: 128 hours with unmet load
# 2011: 193 hours with unmet load
# 2012: 155 hours with unmet load
# 2013: 186 hours with unmet load
# 2014: 206 hours with unmet load
# 2015: 299 hours with unmet load
# 2016: 221 hours with unmet load
# 2017: 231 hours with unmet load
# 2018: 197 hours with unmet load
# 2019: 267 hours with unmet load
# 2020: 207 hours with unmet load
# 2021: 77 hours with unmet load
# 2022: 157 hours with unmet load
# 2023: 121 hours with unmet load
# 2024: 174 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 190.40 hours/year
# Maximum: 307 hours in 1986
# Minimum: 77 hours in 2021

# %% [markdown]
# # 98% met Load sizing

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.02 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5


# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:
        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        
        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

        # === Save Capacity, Cost, and Utilization Metrics for All Years ===
        print("Starting capacity, cost, and utilization metrics collection...")
        results_by_year = []
        for year in range(2024, 1979, -1):
            print(f"Processing year {year} for capacity, cost, and utilization metrics...")
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                print(f"Year {year}: Skipping due to missing resource data.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                print(f"Year {year}: Dispatch simulation successful, calculating metrics...")
                # Calculate utilization metrics
                total_curtailed = np.sum(dispatch_result["curtailment"])
                solar_gen = solar_resource * opt_results["solar"]
                wind_gen = wind_resource * opt_results["wind"]
                total_generated = np.sum(solar_gen + wind_gen)
                total_power_consumed = total_generated - total_curtailed
                utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

                # Calculate battery replacement cost
                yearly_degradation = dispatch_result["degradation"]
                battery_replacement = calculate_battery_replacement_cost(
                    battery_capex=opt_results["battery_capex"],
                    degradation=yearly_degradation,
                    inf=inf,
                    dis=dis,
                    life_battery=life_battery
                )

                # Calculate total NPC
                total_npc = (
                    opt_results["solar_capex"] +
                    opt_results["solar_opex"] +
                    opt_results["solar_replacement"] -
                    opt_results["solar_salvage"] +
                    opt_results["wind_capex"] +
                    opt_results["wind_opex"] +
                    opt_results["wind_replacement"] -
                    opt_results["wind_salvage"] +
                    opt_results["battery_capex"] +
                    opt_results["battery_opex"] +
                    battery_replacement -
                    opt_results["battery_salvage"] +
                    opt_results["inverter_capex"] +
                    opt_results["inverter_opex"] +
                    opt_results["inverter_replacement"] -
                    opt_results["inverter_salvage"]
                )

                # Store results
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": opt_results["solar"],
                    "Wind_Capacity_HAWT": opt_results["wind"],
                    "Battery_Capacity_kWh": opt_results["battery"],
                    "Inverter_Capacity_kW": inverter_capacity,
                    "Solar_CAPEX": opt_results["solar_capex"],
                    "Solar_OPEX": opt_results["solar_opex"],
                    "Solar_Replacement": opt_results["solar_replacement"],
                    "Solar_Salvage": opt_results["solar_salvage"],
                    "Wind_CAPEX": opt_results["wind_capex"],
                    "Wind_OPEX": opt_results["wind_opex"],
                    "Wind_Replacement": opt_results["wind_replacement"],
                    "Wind_Salvage": opt_results["wind_salvage"],
                    "Battery_CAPEX": opt_results["battery_capex"],
                    "Battery_OPEX": opt_results["battery_opex"],
                    "Battery_Replacement": battery_replacement,
                    "Battery_Salvage": opt_results["battery_salvage"],
                    "Inverter_CAPEX": opt_results["inverter_capex"],
                    "Inverter_OPEX": opt_results["inverter_opex"],
                    "Inverter_Replacement": opt_results["inverter_replacement"],
                    "Inverter_Salvage": opt_results["inverter_salvage"],
                    "Total_NPC": total_npc,
                    "Utilization_Percentage": utilization_percentage,
                    "Total_Curtailed_kWh": total_curtailed,
                    "Total_Generated_kWh": total_generated,
                    "Total_Power_Consumed_kWh": total_power_consumed,
                    "Total_Unmet_kWh": dispatch_result["total_unmet"]
                })
                print(f"Year {year}: Metrics added - Utilization: {utilization_percentage:.2f}%, NPC: {total_npc:.2f}, Unmet: {dispatch_result['total_unmet']:.2f} kWh")
            else:
                print(f"Year {year}: Metrics save failed due to dispatch simulation error.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })

        # Save results to CSV
        try:
            df_results = pd.DataFrame(results_by_year)
            csv_path = os.path.join(output_dir, "capacity_and_costs_by_year.csv")
            df_results.to_csv(csv_path, index=False)
            print(f"Saved capacity, cost, and utilization metrics to {csv_path}")
            print(f"CSV file location: {os.path.abspath(csv_path)}")
        except Exception as e:
            print(f"Error saving CSV: {e}")

        # === Plot NPC Variation Across Years ===
        print("Starting NPC variation plotting...")
        try:
            valid_npc_data = df_results[df_results["Total_NPC"].notna()][["Year", "Total_NPC"]]
            if valid_npc_data.empty:
                print("Error: No valid NPC data found for plotting.")
            else:
                plt.figure(figsize=(15, 8))
                plt.plot(valid_npc_data["Year"], valid_npc_data["Total_NPC"], marker='o', linestyle='-', color='b')
                plt.title("NPC Variation Across Years (1979-2024)")
                plt.xlabel("Year")
                plt.ylabel("Total NPC ($)")
                plt.grid(True)
                plt.gca().invert_xaxis()  # Reverse x-axis to show 2024 to 1979
                plt.tight_layout()
                plot_path = os.path.join(output_dir, "npc_variation_by_year.png")
                plt.savefig(plot_path)
                plt.close()
                print(f"Saved NPC variation plot to {plot_path}")
                print(f"Plot file location: {os.path.abspath(plot_path)}")
        except Exception as e:
            print(f"Error plotting NPC variation: {e}")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0x63f944d6
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 4e+07]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 24.66s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.276474e+05   3.669944e+06     41s
#     5194    2.2078554e+11   0.000000e+00   4.996408e+13     45s
#     7084    8.0316978e+10   3.101063e-05   3.433544e+12     50s
#     8846    3.7484794e+10   3.695638e-03   2.215983e+07     55s
#    11212    2.1710836e+10   7.428928e-03   8.836081e+10     60s
#    13284    1.6930262e+10   1.039651e-03   8.718165e+12     65s
#    14849    1.3670697e+10   0.000000e+00   3.538398e+04     70s
#    16458    1.1223331e+10   0.000000e+00   2.350292e+10     75s
#    18081    9.4171222e+09   0.000000e+00   7.463740e+10     80s
#    19635    8.5449169e+09   2.350389e-03   2.918822e+10     85s
#    26759   -2.8981570e+10   4.185697e+12   0.000000e+00     90s
# Concurrent spin time: 20.71s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 3.104762e+09, 41971 iterations, 74.71 seconds (63.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.1048e+09    0    2          - 3.1048e+09      -     -  115s
# H    0     0                    3.116569e+09 3.1048e+09  0.38%     -  118s
#
# Explored 1 nodes (41971 simplex iterations) in 119.49 seconds (131.40 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.11657e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.116568765102e+09, best bound 3.104761916190e+09, gap 0.3788%
# Optimal Solution Found!
# Solar Capacity: 6791589.11 PV
# Wind Capacity: 132.24 HAWT
# Battery Capacity: 3591077.97 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 1515059316.93 kWh
# Total Energy Generated: 4104327650.70 kWh
# Total Energy Used (along with efficiency losses): 2589268333.77 kWh
# Utilization Percentage: 63.09%
# $36218863.38 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 6791589.11 PV
# Solar Initial Cost:    $631278207.83
# Wind Initial Capacity: 132.24 HAWT
# Wind Initial Cost:     $676271055.47
# Battery Initial Capacity: 3591077.97 kWh
# Battery Initial Cost:  $1285605914.11
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -21733.09 PV
# Solar Redundant Cost:    $-2020090.27
# Wind Redundant Capacity: 11.67 HAWT
# Wind Redundant Cost:     $59701208.78
# Battery Redundant Capacity: 13286.99 kWh
# Battery Redundant Cost:  $4756741.88
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $629258117.57
# Solar OPEX:         $687316420.67
# Solar Replacement:  $0.00
# Solar Salvage:     -$182927486.51
# Wind CAPEX:         $735972264.24
# Wind OPEX:          $157524414.40
# Wind Replacement:   $0.00
# Wind Salvage:      -$133718533.66
# Battery CAPEX:      $1290362655.99
# Battery OPEX:       $388744238.99
# Battery Replacement:$460187007.97
# Battery Salvage:   -$468891045.57
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3576755773.07
#
# === 2024 Results ===
# Total Unmet Load: 37755172.49 kWh
# Hours with Unmet Load: [36, 57, 58, 59, 60, 61, 62, 63, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 152, 153, 154, 155, 156, 157, 158, 371, 372, 373, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 571, 572, 573, 574, 578, 579, 588, 589, 590, 591, 592, 593, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 683, 684, 685, 755, 756, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 988, 989, 990, 991, 992, 993, 994, 995, 996, 1164, 1474, 1475, 1476, 1477, 1567, 1568, 1569, 1570, 1571, 1572, 1643, 1644, 1809, 1810, 1811, 1812, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 2430, 2431, 2432, 2433, 2434, 2435, 2891, 2983, 2984, 2985, 2986, 2987, 2988, 3010, 3011, 3012, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035, 4895, 4896, 4897, 4898, 4899, 4900, 4901, 4902, 4903, 4904, 4905, 4919, 4920, 4921, 4943, 4944, 4945, 4946, 4966, 4967, 4968, 4969, 4978, 4979, 4980, 4996, 4997, 4998, 4999, 5000, 5001, 5002, 5003, 5004, 5005, 5021, 5022, 5023, 5024, 5025, 5026, 5027, 5028, 5771, 5842, 5843, 5844, 5868, 5963, 5987, 5988, 6179, 6180, 6250, 6251, 6252, 6299, 6300, 6323, 6324, 6370, 6371, 6372, 6418, 6419, 6420, 6422, 6587, 6588, 6707, 6708, 6828, 6924, 7044, 7068, 7332, 7470, 7471, 7472, 7473, 7474, 7475, 7476, 7477, 7541, 7542, 7543, 7544, 7545, 7546, 7547, 7548, 7549, 7550, 7569, 7570, 7571, 7572, 7639, 7640, 7641, 7642, 7643, 7644, 7859, 7860, 7861, 7979, 7980, 8027, 8028, 8196, 8245, 8268, 8269, 8461, 8479, 8480, 8481, 8482, 8483, 8484, 8629, 8630, 8641, 8642, 8643, 8644, 8645, 8646, 8647, 8648, 8649, 8650, 8651, 8652, 8653, 8654, 8718, 8719, 8720, 8721, 8722, 8723, 8724, 8725]
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           12 0.5793     0.000054
# discharge         16           37 0.9561     0.000133
# discharge         44           63 0.9471     0.000131
# discharge         69           85 0.2869     0.000015
# discharge         89          110 0.8054     0.000098
# discharge        112          133 0.2459     0.000012
# discharge        140          158 0.5469     0.000049
# discharge        163          180 0.7613     0.000088
# discharge        186          204 0.4375     0.000033
# discharge        208          228 0.4175     0.000030
# discharge        231          254 0.5166     0.000044
# discharge        257          279 0.3275     0.000020
# discharge        281          300 0.4192     0.000030
# discharge        303          324 0.6003     0.000058
# discharge        328          349 0.8725     0.000113
# discharge        357          373 0.7048     0.000077
# discharge        377          396 0.9402     0.000129
# discharge        401          424 0.5611     0.000051
# discharge        426          444 0.4453     0.000034
# discharge        448          468 0.6887     0.000074
# discharge        472          492 0.9044     0.000120
# discharge        497          516 0.6836     0.000073
# discharge        521          543 0.1745     0.000006
# discharge        547          568 0.0886     0.000002
# discharge        570          593 0.9452     0.000130
# discharge        597          613 0.1397     0.000004
# discharge        619          637 0.5517     0.000050
# discharge        639          640 0.0034     0.000000
# discharge        645          661 0.6034     0.000058
# discharge        666          685 0.9864     0.000141
# discharge        690          709 0.7680     0.000090
# discharge        713          732 0.5979     0.000057
# discharge        736          756 0.9767     0.000138
# discharge        763          780 0.7061     0.000077
# discharge        784          805 0.9091     0.000121
# discharge        812          830 0.5949     0.000057
# discharge        836          852 0.1567     0.000005
# discharge        857          876 0.4832     0.000039
# discharge        879          901 0.7443     0.000085
# discharge        905          924 0.4797     0.000039
# discharge        927          949 0.3878     0.000026
# discharge        957          974 0.5824     0.000055
# discharge        979          996 0.4331     0.000032
# discharge       1001         1021 0.6061     0.000059
# discharge       1028         1044 0.7744     0.000091
# discharge       1049         1068 0.8147     0.000100
# discharge       1072         1092 0.5423     0.000048
# discharge       1096         1117 0.9557     0.000133
# discharge       1125         1140 0.2737     0.000014
# discharge       1144         1164 0.9604     0.000134
# discharge       1168         1188 0.8891     0.000117
# discharge       1192         1212 0.7954     0.000096
# discharge       1216         1236 0.6598     0.000068
# discharge       1240         1260 0.2401     0.000011
# discharge       1265         1284 0.6131     0.000060
# discharge       1288         1308 0.3561     0.000023
# discharge       1311         1332 0.6309     0.000063
# discharge       1337         1356 0.2553     0.000013
# discharge       1358         1380 0.1857     0.000007
# discharge       1383         1404 0.2009     0.000008
# discharge       1407         1428 0.8026     0.000097
# discharge       1433         1452 0.8733     0.000113
# discharge       1458         1477 0.9948     0.000143
# discharge       1482         1500 0.6012     0.000058
# discharge       1504         1524 0.4677     0.000037
# discharge       1528         1550 0.7454     0.000085
# discharge       1557         1572 0.6750     0.000071
# discharge       1578         1597 0.8963     0.000118
# discharge       1605         1621 0.7417     0.000084
# discharge       1630         1644 0.7208     0.000080
# discharge       1652         1668 0.6748     0.000071
# discharge       1672         1692 0.9182     0.000124
# discharge       1697         1716 0.7380     0.000084
# discharge       1720         1740 0.4636     0.000036
# discharge       1743         1764 0.3675     0.000024
# discharge       1768         1790 0.5276     0.000046
# discharge       1797         1812 0.7543     0.000087
# discharge       1817         1836 0.8289     0.000103
# discharge       1843         1860 0.5171     0.000044
# discharge       1863         1884 0.8616     0.000110
# discharge       1888         1908 0.3836     0.000026
# discharge       1911         1932 0.8118     0.000099
# discharge       1939         1957 0.8853     0.000116
# discharge       1963         1979 0.2576     0.000013
# discharge       1984         2004 0.5362     0.000047
# discharge       2009         2028 0.2724     0.000014
# discharge       2032         2052 0.6802     0.000072
# discharge       2056         2076 0.5673     0.000052
# discharge       2079         2100 0.7617     0.000088
# discharge       2104         2123 0.7457     0.000085
# discharge       2128         2147 0.3759     0.000025
# discharge       2151         2172 0.4549     0.000035
# discharge       2176         2196 0.4161     0.000030
# discharge       2201         2219 0.2083     0.000009
# discharge       2223         2243 0.4186     0.000030
# discharge       2247         2267 0.3859     0.000026
# discharge       2271         2292 0.5296     0.000046
# discharge       2295         2316 0.5937     0.000057
# discharge       2320         2339 0.4144     0.000030
# discharge       2343         2364 0.6795     0.000072
# discharge       2369         2388 0.4313     0.000032
# discharge       2396         2412 0.7641     0.000089
# discharge       2420         2435 0.4073     0.000029
# discharge       2442         2459 0.2693     0.000014
# discharge       2462         2484 0.7280     0.000082
# discharge       2488         2507 0.3565     0.000023
# discharge       2511         2531 0.4598     0.000036
# discharge       2535         2555 0.6086     0.000059
# discharge       2560         2580 0.2353     0.000011
# discharge       2584         2604 0.6709     0.000070
# discharge       2608         2627 0.4523     0.000035
# discharge       2631         2652 0.5299     0.000046
# discharge       2656         2676 0.6336     0.000064
# discharge       2680         2699 0.8027     0.000097
# discharge       2704         2723 0.5114     0.000043
# discharge       2727         2748 0.5237     0.000045
# discharge       2752         2771 0.5019     0.000042
# discharge       2776         2796 0.6583     0.000068
# discharge       2800         2820 0.3275     0.000020
# discharge       2824         2843 0.3076     0.000017
# discharge       2846         2869 0.3943     0.000027
# discharge       2874         2891 0.9581     0.000133
# discharge       2897         2916 0.6932     0.000075
# discharge       2920         2939 0.6614     0.000069
# discharge       2944         2964 0.9299     0.000126
# discharge       2973         2988 0.7335     0.000083
# discharge       2998         3012 0.8721     0.000113
# discharge       3021         3035 0.5034     0.000042
# discharge       3041         3059 0.4746     0.000038
# discharge       3063         3084 0.3836     0.000026
# discharge       3088         3108 0.4136     0.000030
# discharge       3111         3131 0.5851     0.000055
# discharge       3135         3155 0.8723     0.000113
# discharge       3160         3180 0.8040     0.000097
# discharge       3185         3205 0.9132     0.000122
# discharge       3214         3227 0.5581     0.000051
# discharge       3232         3251 0.6417     0.000065
# discharge       3256         3275 0.8435     0.000106
# discharge       3281         3300 0.9096     0.000122
# discharge       3306         3324 0.8276     0.000103
# discharge       3334         3347 0.9102     0.000122
# discharge       3353         3371 0.7657     0.000089
# discharge       3377         3395 0.6336     0.000064
# discharge       3400         3420 0.4581     0.000036
# discharge       3427         3444 0.7717     0.000091
# discharge       3453         3468 0.7671     0.000090
# discharge       3478         3492 0.6844     0.000073
# discharge       3496         3515 0.5347     0.000047
# discharge       3520         3539 0.3353     0.000020
# discharge       3543         3563 0.7626     0.000089
# discharge       3568         3587 0.8606     0.000110
# discharge       3593         3611 0.6028     0.000058
# discharge       3616         3636 0.6116     0.000060
# discharge       3642         3660 0.5410     0.000048
# discharge       3664         3683 0.8858     0.000116
# discharge       3689         3707 0.8113     0.000099
# discharge       3717         3732 0.6335     0.000064
# discharge       3736         3755 0.6071     0.000059
# discharge       3760         3779 0.8615     0.000110
# discharge       3785         3803 0.5975     0.000057
# discharge       3808         3827 0.7776     0.000092
# discharge       3835         3851 0.4862     0.000040
# discharge       3857         3875 0.6209     0.000061
# discharge       3880         3899 0.5758     0.000054
# discharge       3904         3924 0.6943     0.000075
# discharge       3929         3947 0.8706     0.000112
# discharge       3953         3971 0.8882     0.000116
# discharge       3977         3995 0.8766     0.000114
# discharge       4002         4019 0.7868     0.000094
# discharge       4025         4044 0.6414     0.000065
# discharge       4052         4068 0.7685     0.000090
# discharge       4077         4091 0.7715     0.000090
# discharge       4098         4115 0.6630     0.000069
# discharge       4120         4139 0.7835     0.000093
# discharge       4145         4163 0.8845     0.000116
# discharge       4169         4187 0.6455     0.000066
# discharge       4192         4211 0.8809     0.000115
# discharge       4217         4235 0.8720     0.000113
# discharge       4241         4259 0.7773     0.000092
# discharge       4265         4283 0.5612     0.000051
# discharge       4287         4307 0.7234     0.000081
# discharge       4313         4331 0.7400     0.000084
# discharge       4337         4355 0.7099     0.000078
# discharge       4362         4379 0.5956     0.000057
# discharge       4384         4403 0.6317     0.000063
# discharge       4408         4427 0.7714     0.000090
# discharge       4433         4451 0.6802     0.000072
# discharge       4456         4475 0.6851     0.000073
# discharge       4481         4499 0.7646     0.000089
# discharge       4505         4523 0.7677     0.000090
# discharge       4529         4548 0.9181     0.000124
# discharge       4558         4571 0.5148     0.000044
# discharge       4575         4595 0.6314     0.000063
# discharge       4600         4619 0.8968     0.000118
# discharge       4625         4643 0.8805     0.000115
# discharge       4649         4668 0.8090     0.000099
# discharge       4674         4692 0.9008     0.000119
# discharge       4698         4715 0.7514     0.000086
# discharge       4721         4739 0.7405     0.000084
# discharge       4745         4765 0.7789     0.000092
# discharge       4773         4787 0.7866     0.000094
# discharge       4793         4811 0.5248     0.000045
# discharge       4816         4835 0.7627     0.000089
# discharge       4841         4860 0.8381     0.000105
# discharge       4865         4884 0.8005     0.000097
# discharge       4889         4910 0.2632     0.000013
# discharge       4918         4932 0.7754     0.000091
# discharge       4942         4956 0.7082     0.000078
# discharge       4965         4980 0.7688     0.000090
# discharge       4990         5005 0.4866     0.000040
# discharge       5014         5028 0.5050     0.000042
# discharge       5038         5051 0.6319     0.000063
# discharge       5056         5075 0.6299     0.000063
# discharge       5080         5100 0.6972     0.000075
# discharge       5104         5123 0.6181     0.000061
# discharge       5128         5147 0.6782     0.000072
# discharge       5152         5171 0.7982     0.000096
# discharge       5177         5195 0.8154     0.000100
# discharge       5201         5220 0.7500     0.000086
# discharge       5225         5244 0.8405     0.000106
# discharge       5249         5267 0.6998     0.000076
# discharge       5272         5291 0.6944     0.000075
# discharge       5296         5315 0.6272     0.000062
# discharge       5320         5339 0.5985     0.000057
# discharge       5344         5363 0.7875     0.000094
# discharge       5369         5387 0.8362     0.000105
# discharge       5393         5412 0.9250     0.000125
# discharge       5417         5436 0.9191     0.000124
# discharge       5442         5460 0.8380     0.000105
# discharge       5465         5483 0.6762     0.000071
# discharge       5489         5508 0.9061     0.000121
# discharge       5514         5532 0.9004     0.000119
# discharge       5537         5555 0.6969     0.000075
# discharge       5560         5579 0.6246     0.000062
# discharge       5584         5603 0.5958     0.000057
# discharge       5608         5627 0.5729     0.000053
# discharge       5632         5651 0.6752     0.000071
# discharge       5656         5676 0.6948     0.000075
# discharge       5681         5700 0.7078     0.000078
# discharge       5704         5724 0.8626     0.000111
# discharge       5729         5748 0.9354     0.000128
# discharge       5753         5772 0.9507     0.000132
# discharge       5777         5796 0.9100     0.000122
# discharge       5802         5820 0.9387     0.000129
# discharge       5829         5844 0.9219     0.000125
# discharge       5851         5869 0.9696     0.000136
# discharge       5878         5892 0.8101     0.000099
# discharge       5897         5916 0.5320     0.000047
# discharge       5920         5940 0.7527     0.000087
# discharge       5949         5964 0.8292     0.000103
# discharge       5969         5988 0.9692     0.000136
# discharge       5994         6011 0.6195     0.000061
# discharge       6016         6035 0.4756     0.000038
# discharge       6039         6059 0.4938     0.000041
# discharge       6063         6084 0.6060     0.000059
# discharge       6088         6108 0.8472     0.000107
# discharge       6113         6132 0.5309     0.000046
# discharge       6142         6156 0.3383     0.000021
# discharge       6162         6180 0.9778     0.000138
# discharge       6190         6204 0.5674     0.000052
# discharge       6213         6229 0.4888     0.000040
# discharge       6238         6252 0.8537     0.000108
# discharge       6257         6276 0.9046     0.000120
# discharge       6281         6300 0.9709     0.000137
# discharge       6305         6324 0.9722     0.000137
# discharge       6329         6349 0.8992     0.000119
# discharge       6358         6372 0.8122     0.000099
# discharge       6378         6396 0.9028     0.000120
# discharge       6405         6420 0.8448     0.000106
# discharge       6421         6422 0.0046     0.000000
# discharge       6427         6445 0.9061     0.000121
# discharge       6449         6468 0.7291     0.000082
# discharge       6472         6492 0.4091     0.000029
# discharge       6496         6516 0.4029     0.000028
# discharge       6520         6540 0.8722     0.000113
# discharge       6547         6564 0.9333     0.000127
# discharge       6569         6588 0.9745     0.000137
# discharge       6593         6612 0.4945     0.000041
# discharge       6615         6636 0.9344     0.000128
# discharge       6641         6660 0.8468     0.000107
# discharge       6665         6684 0.8472     0.000107
# discharge       6689         6708 0.9740     0.000137
# discharge       6713         6732 0.6778     0.000072
# discharge       6736         6756 0.5257     0.000046
# discharge       6759         6780 0.6230     0.000062
# discharge       6784         6804 0.6237     0.000062
# discharge       6808         6828 0.9516     0.000132
# discharge       6833         6852 0.9095     0.000122
# discharge       6857         6876 0.4558     0.000035
# discharge       6880         6900 0.5528     0.000050
# discharge       6904         6924 0.9517     0.000132
# discharge       6929         6948 0.5574     0.000051
# discharge       6951         6972 0.8665     0.000111
# discharge       6976         6996 0.8344     0.000104
# discharge       7000         7020 0.8390     0.000105
# discharge       7025         7044 0.9519     0.000132
# discharge       7049         7068 0.9544     0.000132
# discharge       7073         7092 0.7208     0.000080
# discharge       7096         7116 0.4720     0.000038
# discharge       7120         7140 0.7301     0.000082
# discharge       7145         7164 0.6603     0.000069
# discharge       7168         7188 0.7786     0.000092
# discharge       7196         7212 0.7727     0.000091
# discharge       7217         7236 0.7444     0.000085
# discharge       7241         7260 0.4207     0.000031
# discharge       7263         7284 0.3900     0.000027
# discharge       7287         7308 0.3210     0.000019
# discharge       7312         7332 0.9689     0.000136
# discharge       7338         7357 0.8359     0.000104
# discharge       7362         7381 0.6696     0.000070
# discharge       7386         7405 0.4428     0.000033
# discharge       7409         7428 0.2698     0.000014
# discharge       7431         7453 0.9371     0.000128
# discharge       7461         7477 0.5691     0.000053
# discharge       7482         7501 0.6970     0.000075
# discharge       7505         7525 0.7155     0.000079
# discharge       7531         7550 0.5062     0.000043
# discharge       7557         7572 0.6608     0.000069
# discharge       7577         7596 0.7424     0.000084
# discharge       7601         7623 0.6594     0.000068
# discharge       7627         7644 0.4721     0.000038
# discharge       7649         7668 0.9392     0.000129
# discharge       7673         7693 0.8377     0.000105
# discharge       7698         7717 0.6844     0.000073
# discharge       7722         7740 0.5118     0.000043
# discharge       7745         7765 0.5543     0.000050
# discharge       7768         7788 0.6810     0.000072
# discharge       7792         7812 0.3321     0.000020
# discharge       7815         7836 0.4827     0.000039
# discharge       7840         7861 0.9855     0.000140
# discharge       7866         7884 0.7281     0.000082
# discharge       7888         7908 0.2265     0.000010
# discharge       7911         7932 0.5004     0.000042
# discharge       7936         7958 0.9020     0.000120
# discharge       7964         7981 0.4681     0.000037
# discharge       7985         8004 0.7543     0.000087
# discharge       8008         8028 0.9766     0.000138
# discharge       8033         8053 0.7804     0.000092
# discharge       8059         8076 0.9383     0.000128
# discharge       8081         8100 0.6233     0.000062
# discharge       8104         8124 0.6878     0.000074
# discharge       8129         8148 0.4899     0.000040
# discharge       8151         8172 0.7602     0.000088
# discharge       8177         8196 0.9652     0.000135
# discharge       8201         8222 0.5173     0.000044
# discharge       8227         8246 0.6032     0.000058
# discharge       8251         8269 0.9866     0.000141
# discharge       8276         8292 0.6362     0.000064
# discharge       8296         8316 0.8342     0.000104
# discharge       8321         8343 0.7048     0.000077
# discharge       8349         8365 0.5390     0.000048
# discharge       8368         8389 0.7091     0.000078
# discharge       8394         8413 0.4188     0.000030
# discharge       8420         8437 0.7626     0.000089
# discharge       8445         8462 0.8097     0.000099
# discharge       8470         8484 0.3924     0.000027
# discharge       8489         8508 0.5884     0.000056
# discharge       8512         8532 0.6947     0.000075
# discharge       8536         8556 0.9064     0.000121
# discharge       8561         8580 0.6446     0.000066
# discharge       8584         8606 0.7070     0.000077
# discharge       8612         8631 0.9382     0.000128
# discharge       8636         8654 0.2786     0.000015
# discharge       8661         8677 0.3608     0.000023
# discharge       8682         8701 0.7168     0.000079
# discharge       8703         8706 0.0246     0.000000
# discharge       8707         8725 0.3461     0.000022
# discharge       8730         8749 0.7354     0.000083
#
# Total Estimated Degradation: 0.027302
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 37755172.49 kWh
# Year 2023: Unmet Load = 30499031.70 kWh
# Year 2022: Unmet Load = 33345648.25 kWh
# Year 2021: Unmet Load = 23463641.67 kWh
# Year 2020: Unmet Load = 43818419.15 kWh
# Year 2019: Unmet Load = 56871941.53 kWh
# Year 2018: Unmet Load = 44565875.72 kWh
# Year 2017: Unmet Load = 46850270.57 kWh
# Year 2016: Unmet Load = 43252108.48 kWh
# Year 2015: Unmet Load = 55440646.59 kWh
# Year 2014: Unmet Load = 39632688.54 kWh
# Year 2013: Unmet Load = 43068089.49 kWh
# Year 2012: Unmet Load = 33486687.08 kWh
# Year 2011: Unmet Load = 40162654.92 kWh
# Year 2010: Unmet Load = 26736534.91 kWh
# Year 2009: Unmet Load = 41850103.05 kWh
# Year 2008: Unmet Load = 25543215.34 kWh
# Year 2007: Unmet Load = 42185069.59 kWh
# Year 2006: Unmet Load = 34920637.07 kWh
# Year 2005: Unmet Load = 30829455.29 kWh
# Year 2004: Unmet Load = 35209804.08 kWh
# Year 2003: Unmet Load = 36800576.28 kWh
# Year 2002: Unmet Load = 39431547.75 kWh
# Year 2001: Unmet Load = 43697419.39 kWh
# Year 2000: Unmet Load = 31236922.17 kWh
# Year 1999: Unmet Load = 20075438.10 kWh
# Year 1998: Unmet Load = 53704334.54 kWh
# Year 1997: Unmet Load = 36499553.52 kWh
# Year 1996: Unmet Load = 37046072.58 kWh
# Year 1995: Unmet Load = 19238065.79 kWh
# Year 1994: Unmet Load = 50333385.63 kWh
# Year 1993: Unmet Load = 50995936.96 kWh
# Year 1992: Unmet Load = 54426765.38 kWh
# Year 1991: Unmet Load = 57511491.61 kWh
# Year 1990: Unmet Load = 40277919.99 kWh
# Year 1989: Unmet Load = 44288284.13 kWh
# Year 1988: Unmet Load = 19175175.35 kWh
# Year 1987: Unmet Load = 44128153.44 kWh
# Year 1986: Unmet Load = 62525906.76 kWh
# Year 1985: Unmet Load = 39683054.02 kWh
# Year 1984: Unmet Load = 25596202.11 kWh
# Year 1983: Unmet Load = 54943752.02 kWh
# Year 1982: Unmet Load = 37188974.12 kWh
# Year 1981: Unmet Load = 45370708.73 kWh
# Year 1980: Unmet Load = 44147907.77 kWh
#
# Average Unmet Load (1979-2024): 39951360.97 kWh
# Min Unmet Load: 19175175.35 kWh (Year 1988)
# Max Unmet Load: 62525906.76 kWh (Year 1986)
# Starting capacity, cost, and utilization metrics collection...
# Processing year 2024 for capacity, cost, and utilization metrics...
# Year 2024: Dispatch simulation successful, calculating metrics...
# $36218863.38 is the replacement cost each year for degradation
# Year 2024: Metrics added - Utilization: 63.09%, NPC: 3576755773.07, Unmet: 37755172.49 kWh
# Processing year 2023 for capacity, cost, and utilization metrics...
# Year 2023: Dispatch simulation successful, calculating metrics...
# $37577047.22 is the replacement cost each year for degradation
# Year 2023: Metrics added - Utilization: 63.80%, NPC: 3594012486.80, Unmet: 30499031.70 kWh
# Processing year 2022 for capacity, cost, and utilization metrics...
# Year 2022: Dispatch simulation successful, calculating metrics...
# $35260993.38 is the replacement cost each year for degradation
# Year 2022: Metrics added - Utilization: 60.86%, NPC: 3564585337.83, Unmet: 33345648.25 kWh
# Processing year 2021 for capacity, cost, and utilization metrics...
# Year 2021: Dispatch simulation successful, calculating metrics...
# $36144639.22 is the replacement cost each year for degradation
# Year 2021: Metrics added - Utilization: 63.72%, NPC: 3575812701.11, Unmet: 23463641.67 kWh
# Processing year 2020 for capacity, cost, and utilization metrics...
# Year 2020: Dispatch simulation successful, calculating metrics...
# $36997459.22 is the replacement cost each year for degradation
# Year 2020: Metrics added - Utilization: 64.43%, NPC: 3586648399.68, Unmet: 43818419.15 kWh
# Processing year 2019 for capacity, cost, and utilization metrics...
# Year 2019: Dispatch simulation successful, calculating metrics...
# $37848819.32 is the replacement cost each year for degradation
# Year 2019: Metrics added - Utilization: 65.35%, NPC: 3597465549.00, Unmet: 56871941.53 kWh
# Processing year 2018 for capacity, cost, and utilization metrics...
# Year 2018: Dispatch simulation successful, calculating metrics...
# $38023980.01 is the replacement cost each year for degradation
# Year 2018: Metrics added - Utilization: 65.77%, NPC: 3599691093.10, Unmet: 44565875.72 kWh
# Processing year 2017 for capacity, cost, and utilization metrics...
# Year 2017: Dispatch simulation successful, calculating metrics...
# $35838588.62 is the replacement cost each year for degradation
# Year 2017: Metrics added - Utilization: 63.04%, NPC: 3571924105.59, Unmet: 46850270.57 kWh
# Processing year 2016 for capacity, cost, and utilization metrics...
# Year 2016: Dispatch simulation successful, calculating metrics...
# $36636188.70 is the replacement cost each year for degradation
# Year 2016: Metrics added - Utilization: 63.28%, NPC: 3582058194.89, Unmet: 43252108.48 kWh
# Processing year 2015 for capacity, cost, and utilization metrics...
# Year 2015: Dispatch simulation successful, calculating metrics...
# $35474486.56 is the replacement cost each year for degradation
# Year 2015: Metrics added - Utilization: 64.43%, NPC: 3567297924.09, Unmet: 55440646.59 kWh
# Processing year 2014 for capacity, cost, and utilization metrics...
# Year 2014: Dispatch simulation successful, calculating metrics...
# $35136579.33 is the replacement cost each year for degradation
# Year 2014: Metrics added - Utilization: 62.07%, NPC: 3563004566.85, Unmet: 39632688.54 kWh
# Processing year 2013 for capacity, cost, and utilization metrics...
# Year 2013: Dispatch simulation successful, calculating metrics...
# $36692551.96 is the replacement cost each year for degradation
# Year 2013: Metrics added - Utilization: 63.34%, NPC: 3582774331.13, Unmet: 43068089.49 kWh
# Processing year 2012 for capacity, cost, and utilization metrics...
# Year 2012: Dispatch simulation successful, calculating metrics...
# $34218569.10 is the replacement cost each year for degradation
# Year 2012: Metrics added - Utilization: 61.89%, NPC: 3551340579.01, Unmet: 33486687.08 kWh
# Processing year 2011 for capacity, cost, and utilization metrics...
# Year 2011: Dispatch simulation successful, calculating metrics...
# $34618055.38 is the replacement cost each year for degradation
# Year 2011: Metrics added - Utilization: 62.09%, NPC: 3556416342.89, Unmet: 40162654.92 kWh
# Processing year 2010 for capacity, cost, and utilization metrics...
# Year 2010: Dispatch simulation successful, calculating metrics...
# $37765107.28 is the replacement cost each year for degradation
# Year 2010: Metrics added - Utilization: 62.74%, NPC: 3596401926.62, Unmet: 26736534.91 kWh
# Processing year 2009 for capacity, cost, and utilization metrics...
# Year 2009: Dispatch simulation successful, calculating metrics...
# $35367916.04 is the replacement cost each year for degradation
# Year 2009: Metrics added - Utilization: 63.51%, NPC: 3565943868.02, Unmet: 41850103.05 kWh
# Processing year 2008 for capacity, cost, and utilization metrics...
# Year 2008: Dispatch simulation successful, calculating metrics...
# $35133137.84 is the replacement cost each year for degradation
# Year 2008: Metrics added - Utilization: 61.09%, NPC: 3562960840.16, Unmet: 25543215.34 kWh
# Processing year 2007 for capacity, cost, and utilization metrics...
# Year 2007: Dispatch simulation successful, calculating metrics...
# $37017828.81 is the replacement cost each year for degradation
# Year 2007: Metrics added - Utilization: 62.07%, NPC: 3586907210.11, Unmet: 42185069.59 kWh
# Processing year 2006 for capacity, cost, and utilization metrics...
# Year 2006: Dispatch simulation successful, calculating metrics...
# $33833171.00 is the replacement cost each year for degradation
# Year 2006: Metrics added - Utilization: 60.81%, NPC: 3546443815.77, Unmet: 34920637.07 kWh
# Processing year 2005 for capacity, cost, and utilization metrics...
# Year 2005: Dispatch simulation successful, calculating metrics...
# $36533933.25 is the replacement cost each year for degradation
# Year 2005: Metrics added - Utilization: 61.29%, NPC: 3580758964.98, Unmet: 30829455.29 kWh
# Processing year 2004 for capacity, cost, and utilization metrics...
# Year 2004: Dispatch simulation successful, calculating metrics...
# $34526771.13 is the replacement cost each year for degradation
# Year 2004: Metrics added - Utilization: 62.92%, NPC: 3555256510.04, Unmet: 35209804.08 kWh
# Processing year 2003 for capacity, cost, and utilization metrics...
# Year 2003: Dispatch simulation successful, calculating metrics...
# $35091459.69 is the replacement cost each year for degradation
# Year 2003: Metrics added - Utilization: 62.15%, NPC: 3562431289.04, Unmet: 36800576.28 kWh
# Processing year 2002 for capacity, cost, and utilization metrics...
# Year 2002: Dispatch simulation successful, calculating metrics...
# $35611348.97 is the replacement cost each year for degradation
# Year 2002: Metrics added - Utilization: 62.50%, NPC: 3569036860.51, Unmet: 39431547.75 kWh
# Processing year 2001 for capacity, cost, and utilization metrics...
# Year 2001: Dispatch simulation successful, calculating metrics...
# $36093635.89 is the replacement cost each year for degradation
# Year 2001: Metrics added - Utilization: 61.46%, NPC: 3575164666.73, Unmet: 43697419.39 kWh
# Processing year 2000 for capacity, cost, and utilization metrics...
# Year 2000: Dispatch simulation successful, calculating metrics...
# $35611372.51 is the replacement cost each year for degradation
# Year 2000: Metrics added - Utilization: 60.48%, NPC: 3569037159.66, Unmet: 31236922.17 kWh
# Processing year 1999 for capacity, cost, and utilization metrics...
# Year 1999: Dispatch simulation successful, calculating metrics...
# $33014157.86 is the replacement cost each year for degradation
# Year 1999: Metrics added - Utilization: 59.70%, NPC: 3536037658.09, Unmet: 20075438.10 kWh
# Processing year 1998 for capacity, cost, and utilization metrics...
# Year 1998: Dispatch simulation successful, calculating metrics...
# $34745667.98 is the replacement cost each year for degradation
# Year 1998: Metrics added - Utilization: 62.07%, NPC: 3558037753.73, Unmet: 53704334.54 kWh
# Processing year 1997 for capacity, cost, and utilization metrics...
# Year 1997: Dispatch simulation successful, calculating metrics...
# $37189782.67 is the replacement cost each year for degradation
# Year 1997: Metrics added - Utilization: 63.13%, NPC: 3589092008.91, Unmet: 36499553.52 kWh
# Processing year 1996 for capacity, cost, and utilization metrics...
# Year 1996: Dispatch simulation successful, calculating metrics...
# $32856343.37 is the replacement cost each year for degradation
# Year 1996: Metrics added - Utilization: 60.48%, NPC: 3534032510.15, Unmet: 37046072.58 kWh
# Processing year 1995 for capacity, cost, and utilization metrics...
# Year 1995: Dispatch simulation successful, calculating metrics...
# $35181497.94 is the replacement cost each year for degradation
# Year 1995: Metrics added - Utilization: 60.94%, NPC: 3563575290.45, Unmet: 19238065.79 kWh
# Processing year 1994 for capacity, cost, and utilization metrics...
# Year 1994: Dispatch simulation successful, calculating metrics...
# $36622263.24 is the replacement cost each year for degradation
# Year 1994: Metrics added - Utilization: 64.14%, NPC: 3581881261.81, Unmet: 50333385.63 kWh
# Processing year 1993 for capacity, cost, and utilization metrics...
# Year 1993: Dispatch simulation successful, calculating metrics...
# $36278593.41 is the replacement cost each year for degradation
# Year 1993: Metrics added - Utilization: 65.17%, NPC: 3577514686.61, Unmet: 50995936.96 kWh
# Processing year 1992 for capacity, cost, and utilization metrics...
# Year 1992: Dispatch simulation successful, calculating metrics...
# $35084884.01 is the replacement cost each year for degradation
# Year 1992: Metrics added - Utilization: 64.31%, NPC: 3562347740.16, Unmet: 54426765.38 kWh
# Processing year 1991 for capacity, cost, and utilization metrics...
# Year 1991: Dispatch simulation successful, calculating metrics...
# $37372225.10 is the replacement cost each year for degradation
# Year 1991: Metrics added - Utilization: 67.71%, NPC: 3591410072.77, Unmet: 57511491.61 kWh
# Processing year 1990 for capacity, cost, and utilization metrics...
# Year 1990: Dispatch simulation successful, calculating metrics...
# $34439541.00 is the replacement cost each year for degradation
# Year 1990: Metrics added - Utilization: 62.46%, NPC: 3554148187.84, Unmet: 40277919.99 kWh
# Processing year 1989 for capacity, cost, and utilization metrics...
# Year 1989: Dispatch simulation successful, calculating metrics...
# $34474687.88 is the replacement cost each year for degradation
# Year 1989: Metrics added - Utilization: 63.53%, NPC: 3554594754.43, Unmet: 44288284.13 kWh
# Processing year 1988 for capacity, cost, and utilization metrics...
# Year 1988: Dispatch simulation successful, calculating metrics...
# $34317881.57 is the replacement cost each year for degradation
# Year 1988: Metrics added - Utilization: 59.93%, NPC: 3552602416.28, Unmet: 19175175.35 kWh
# Processing year 1987 for capacity, cost, and utilization metrics...
# Year 1987: Dispatch simulation successful, calculating metrics...
# $36855517.86 is the replacement cost each year for degradation
# Year 1987: Metrics added - Utilization: 64.09%, NPC: 3584844931.34, Unmet: 44128153.44 kWh
# Processing year 1986 for capacity, cost, and utilization metrics...
# Year 1986: Dispatch simulation successful, calculating metrics...
# $35692040.51 is the replacement cost each year for degradation
# Year 1986: Metrics added - Utilization: 63.09%, NPC: 3570062105.28, Unmet: 62525906.76 kWh
# Processing year 1985 for capacity, cost, and utilization metrics...
# Year 1985: Dispatch simulation successful, calculating metrics...
# $35257692.86 is the replacement cost each year for degradation
# Year 1985: Metrics added - Utilization: 62.40%, NPC: 3564543402.31, Unmet: 39683054.02 kWh
# Processing year 1984 for capacity, cost, and utilization metrics...
# Year 1984: Dispatch simulation successful, calculating metrics...
# $35640181.37 is the replacement cost each year for degradation
# Year 1984: Metrics added - Utilization: 62.90%, NPC: 3569403197.18, Unmet: 25596202.11 kWh
# Processing year 1983 for capacity, cost, and utilization metrics...
# Year 1983: Dispatch simulation successful, calculating metrics...
# $36847734.94 is the replacement cost each year for degradation
# Year 1983: Metrics added - Utilization: 64.16%, NPC: 3584746043.70, Unmet: 54943752.02 kWh
# Processing year 1982 for capacity, cost, and utilization metrics...
# Year 1982: Dispatch simulation successful, calculating metrics...
# $36400874.08 is the replacement cost each year for degradation
# Year 1982: Metrics added - Utilization: 64.40%, NPC: 3579068351.39, Unmet: 37188974.12 kWh
# Processing year 1981 for capacity, cost, and utilization metrics...
# Year 1981: Dispatch simulation successful, calculating metrics...
# $37298769.02 is the replacement cost each year for degradation
# Year 1981: Metrics added - Utilization: 61.87%, NPC: 3590476759.84, Unmet: 45370708.73 kWh
# Processing year 1980 for capacity, cost, and utilization metrics...
# Year 1980: Dispatch simulation successful, calculating metrics...
# $34386574.01 is the replacement cost each year for degradation
# Year 1980: Metrics added - Utilization: 60.61%, NPC: 3553475203.64, Unmet: 44147907.77 kWh
# Saved capacity, cost, and utilization metrics to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\capacity_and_costs_by_year.csv
# CSV file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\capacity_and_costs_by_year.csv
# Starting NPC variation plotting...
# Saved NPC variation plot to dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\npc_variation_by_year.png
# Plot file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment\npc_variation_by_year.png

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
        )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year 98% met Load Sizing (Hybrid Configuration)")
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")

# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 185.18 hours
# 1980: 206.89 extra training hours
# 1981: 222.17 extra training hours
# 1982: 175.48 extra training hours
# 1983: 264.22 extra training hours
# 1984: 122.15 extra training hours
# 1985: 188.39 extra training hours
# 1986: 308.01 extra training hours
# 1987: 197.96 extra training hours
# 1988: 92.01 extra training hours
# 1989: 210.59 extra training hours
# 1990: 189.30 extra training hours
# 1991: 258.91 extra training hours
# 1992: 264.75 extra training hours
# 1993: 244.75 extra training hours
# 1994: 241.66 extra training hours
# 1995: 81.85 extra training hours
# 1996: 165.87 extra training hours
# 1997: 166.41 extra training hours
# 1998: 255.08 extra training hours
# 1999: 87.23 extra training hours
# 2000: 140.63 extra training hours
# 2001: 201.96 extra training hours
# 2002: 180.03 extra training hours
# 2003: 174.46 extra training hours
# 2004: 166.54 extra training hours
# 2005: 134.83 extra training hours
# 2006: 159.09 extra training hours
# 2007: 202.07 extra training hours
# 2008: 119.07 extra training hours
# 2009: 193.47 extra training hours
# 2010: 118.09 extra training hours
# 2011: 185.80 extra training hours
# 2012: 149.44 extra training hours
# 2013: 200.49 extra training hours
# 2014: 183.24 extra training hours
# 2015: 246.92 extra training hours
# 2016: 203.06 extra training hours
# 2017: 216.58 extra training hours
# 2018: 202.38 extra training hours
# 2019: 263.58 extra training hours
# 2020: 195.08 extra training hours
# 2021: 101.04 extra training hours
# 2022: 152.96 extra training hours
# 2023: 136.71 extra training hours
# 2024: 161.72 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 356 hours with unmet load
# 1981: 357 hours with unmet load
# 1982: 320 hours with unmet load
# 1983: 419 hours with unmet load
# 1984: 229 hours with unmet load
# 1985: 335 hours with unmet load
# 1986: 469 hours with unmet load
# 1987: 394 hours with unmet load
# 1988: 163 hours with unmet load
# 1989: 349 hours with unmet load
# 1990: 322 hours with unmet load
# 1991: 486 hours with unmet load
# 1992: 419 hours with unmet load
# 1993: 424 hours with unmet load
# 1994: 392 hours with unmet load
# 1995: 203 hours with unmet load
# 1996: 302 hours with unmet load
# 1997: 308 hours with unmet load
# 1998: 417 hours with unmet load
# 1999: 188 hours with unmet load
# 2000: 274 hours with unmet load
# 2001: 354 hours with unmet load
# 2002: 315 hours with unmet load
# 2003: 287 hours with unmet load
# 2004: 284 hours with unmet load
# 2005: 243 hours with unmet load
# 2006: 292 hours with unmet load
# 2007: 360 hours with unmet load
# 2008: 193 hours with unmet load
# 2009: 365 hours with unmet load
# 2010: 252 hours with unmet load
# 2011: 359 hours with unmet load
# 2012: 303 hours with unmet load
# 2013: 335 hours with unmet load
# 2014: 325 hours with unmet load
# 2015: 451 hours with unmet load
# 2016: 359 hours with unmet load
# 2017: 375 hours with unmet load
# 2018: 410 hours with unmet load
# 2019: 461 hours with unmet load
# 2020: 365 hours with unmet load
# 2021: 210 hours with unmet load
# 2022: 264 hours with unmet load
# 2023: 268 hours with unmet load
# 2024: 344 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 331.11 hours/year
# Maximum: 486 hours in 1991
# Minimum: 163 hours in 1988

# %% [markdown]
# # 95% met Load sizing

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.05 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5


# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:
        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        
        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

        # === Save Capacity, Cost, and Utilization Metrics for All Years ===
        print("Starting capacity, cost, and utilization metrics collection...")
        results_by_year = []
        for year in range(2024, 1979, -1):
            print(f"Processing year {year} for capacity, cost, and utilization metrics...")
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                print(f"Year {year}: Skipping due to missing resource data.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                print(f"Year {year}: Dispatch simulation successful, calculating metrics...")
                # Calculate utilization metrics
                total_curtailed = np.sum(dispatch_result["curtailment"])
                solar_gen = solar_resource * opt_results["solar"]
                wind_gen = wind_resource * opt_results["wind"]
                total_generated = np.sum(solar_gen + wind_gen)
                total_power_consumed = total_generated - total_curtailed
                utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

                # Calculate battery replacement cost
                yearly_degradation = dispatch_result["degradation"]
                battery_replacement = calculate_battery_replacement_cost(
                    battery_capex=opt_results["battery_capex"],
                    degradation=yearly_degradation,
                    inf=inf,
                    dis=dis,
                    life_battery=life_battery
                )

                # Calculate total NPC
                total_npc = (
                    opt_results["solar_capex"] +
                    opt_results["solar_opex"] +
                    opt_results["solar_replacement"] -
                    opt_results["solar_salvage"] +
                    opt_results["wind_capex"] +
                    opt_results["wind_opex"] +
                    opt_results["wind_replacement"] -
                    opt_results["wind_salvage"] +
                    opt_results["battery_capex"] +
                    opt_results["battery_opex"] +
                    battery_replacement -
                    opt_results["battery_salvage"] +
                    opt_results["inverter_capex"] +
                    opt_results["inverter_opex"] +
                    opt_results["inverter_replacement"] -
                    opt_results["inverter_salvage"]
                )

                # Store results
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": opt_results["solar"],
                    "Wind_Capacity_HAWT": opt_results["wind"],
                    "Battery_Capacity_kWh": opt_results["battery"],
                    "Inverter_Capacity_kW": inverter_capacity,
                    "Solar_CAPEX": opt_results["solar_capex"],
                    "Solar_OPEX": opt_results["solar_opex"],
                    "Solar_Replacement": opt_results["solar_replacement"],
                    "Solar_Salvage": opt_results["solar_salvage"],
                    "Wind_CAPEX": opt_results["wind_capex"],
                    "Wind_OPEX": opt_results["wind_opex"],
                    "Wind_Replacement": opt_results["wind_replacement"],
                    "Wind_Salvage": opt_results["wind_salvage"],
                    "Battery_CAPEX": opt_results["battery_capex"],
                    "Battery_OPEX": opt_results["battery_opex"],
                    "Battery_Replacement": battery_replacement,
                    "Battery_Salvage": opt_results["battery_salvage"],
                    "Inverter_CAPEX": opt_results["inverter_capex"],
                    "Inverter_OPEX": opt_results["inverter_opex"],
                    "Inverter_Replacement": opt_results["inverter_replacement"],
                    "Inverter_Salvage": opt_results["inverter_salvage"],
                    "Total_NPC": total_npc,
                    "Utilization_Percentage": utilization_percentage,
                    "Total_Curtailed_kWh": total_curtailed,
                    "Total_Generated_kWh": total_generated,
                    "Total_Power_Consumed_kWh": total_power_consumed,
                    "Total_Unmet_kWh": dispatch_result["total_unmet"]
                })
                print(f"Year {year}: Metrics added - Utilization: {utilization_percentage:.2f}%, NPC: {total_npc:.2f}, Unmet: {dispatch_result['total_unmet']:.2f} kWh")
            else:
                print(f"Year {year}: Metrics save failed due to dispatch simulation error.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })

        # Save results to CSV
        try:
            df_results = pd.DataFrame(results_by_year)
            csv_path = os.path.join(output_dir, "capacity_and_costs_by_year.csv")
            df_results.to_csv(csv_path, index=False)
            print(f"Saved capacity, cost, and utilization metrics to {csv_path}")
            print(f"CSV file location: {os.path.abspath(csv_path)}")
        except Exception as e:
            print(f"Error saving CSV: {e}")

        # === Plot NPC Variation Across Years ===
        print("Starting NPC variation plotting...")
        try:
            valid_npc_data = df_results[df_results["Total_NPC"].notna()][["Year", "Total_NPC"]]
            if valid_npc_data.empty:
                print("Error: No valid NPC data found for plotting.")
            else:
                plt.figure(figsize=(15, 8))
                plt.plot(valid_npc_data["Year"], valid_npc_data["Total_NPC"], marker='o', linestyle='-', color='b')
                plt.title("NPC Variation Across Years (1979-2024)")
                plt.xlabel("Year")
                plt.ylabel("Total NPC ($)")
                plt.grid(True)
                plt.gca().invert_xaxis()  # Reverse x-axis to show 2024 to 1979
                plt.tight_layout()
                plot_path = os.path.join(output_dir, "npc_variation_by_year.png")
                plt.savefig(plot_path)
                plt.close()
                print(f"Saved NPC variation plot to {plot_path}")
                print(f"Plot file location: {os.path.abspath(plot_path)}")
        except Exception as e:
            print(f"Error plotting NPC variation: {e}")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0xdde3b526
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 1e+08]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 10s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 21s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 25.16s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.422268e+05   3.669944e+06     42s
#     3683    4.0610248e+10   0.000000e+00   8.173010e+09     45s
#     8457    2.8110144e+10   0.000000e+00   1.016788e+13     50s
#     9722    1.6968165e+10   6.542089e-04   3.127533e+11     55s
#    11924    1.4445499e+10   2.580385e-05   5.936130e+12     60s
#    13082    1.1177189e+10   3.126523e-04   1.990648e+06     65s
#    14669    1.0082533e+10   1.334753e-03   5.839278e+10     70s
#    15842    8.6168431e+09   4.478051e-02   5.732322e+10     75s
#    17367    7.8092446e+09   0.000000e+00   5.367952e+05     80s
#    18361    7.0501922e+09   1.515122e-02   2.362060e+08     85s
#    19733    6.5790022e+09   2.088858e-04   7.364053e+09     90s
#    20710    6.2824185e+09   4.855455e-04   4.799813e+06     95s
#    21866    5.8528487e+09   2.903349e-03   9.047387e+07    100s
# Concurrent spin time: 24.69s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 2.697730e+09, 41669 iterations, 79.12 seconds (65.33 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2.697730e+09 2.6977e+09  0.00%     -  120s
#
# Explored 1 nodes (41669 simplex iterations) in 121.55 seconds (130.46 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.69773e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.697730092283e+09, best bound 2.697730092283e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 6262414.12 PV
# Wind Capacity: 84.50 HAWT
# Battery Capacity: 3424291.04 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 1108938036.57 kWh
# Total Energy Generated: 3619651835.85 kWh
# Total Energy Used (along with efficiency losses): 2510713799.28 kWh
# Utilization Percentage: 69.36%
# $44241883.06 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 6262414.12 PV
# Solar Initial Cost:    $582091392.33
# Wind Initial Capacity: 84.50 HAWT
# Wind Initial Cost:     $432118496.52
# Battery Initial Capacity: 3424291.04 kWh
# Battery Initial Cost:  $1225896192.31
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -20039.73 PV
# Solar Redundant Cost:    $-1862692.46
# Wind Redundant Capacity: 7.46 HAWT
# Wind Redundant Cost:     $38147420.87
# Battery Redundant Capacity: 12669.88 kWh
# Battery Redundant Cost:  $4535815.91
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $580228699.88
# Solar OPEX:         $633763319.12
# Solar Replacement:  $0.00
# Solar Salvage:     -$168674467.13
# Wind CAPEX:         $470265917.39
# Wind OPEX:          $100653743.15
# Wind Replacement:   $0.00
# Wind Salvage:      -$85442443.91
# Battery CAPEX:      $1230432008.23
# Battery OPEX:       $370689086.86
# Battery Replacement:$562125309.63
# Battery Salvage:   -$447113490.28
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $3259855401.91
#
# === 2024 Results ===
# Total Unmet Load: 97196103.64 kWh
# Hours with Unmet Load: [23, 25, 27, 45, 57, 58, 59, 60, 61, 62, 63, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 95, 96, 97, 98, 100, 101, 102, 103, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 347, 348, 349, 365, 366, 367, 368, 369, 370, 371, 372, 373, 395, 396, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 491, 492, 502, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 572, 573, 574, 575, 576, 577, 578, 589, 590, 591, 592, 593, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 683, 684, 685, 754, 755, 756, 791, 792, 794, 796, 812, 813, 814, 829, 830, 831, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 934, 939, 940, 941, 970, 971, 972, 973, 974, 975, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1068, 1115, 1116, 1117, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1163, 1164, 1188, 1428, 1452, 1473, 1474, 1475, 1476, 1477, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1596, 1597, 1617, 1618, 1619, 1620, 1621, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1691, 1692, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1836, 1955, 1956, 1957, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 2375, 2376, 2406, 2407, 2408, 2409, 2410, 2411, 2412, 2413, 2424, 2425, 2426, 2427, 2428, 2429, 2430, 2431, 2432, 2433, 2434, 2435, 2436, 2890, 2891, 2950, 2951, 2952, 2983, 2984, 2985, 2986, 2987, 2988, 3008, 3009, 3010, 3011, 3012, 3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035, 3036, 3203, 3204, 3205, 3225, 3226, 3227, 3299, 3300, 3345, 3346, 3347, 3442, 3443, 3444, 3461, 3462, 3463, 3464, 3465, 3466, 3467, 3468, 3469, 3490, 3491, 3492, 4067, 4068, 4088, 4089, 4090, 4091, 4163, 4547, 4619, 4691, 4786, 4787, 4895, 4896, 4897, 4898, 4899, 4900, 4901, 4902, 4903, 4904, 4905, 4907, 4918, 4919, 4920, 4921, 4922, 4923, 4943, 4944, 4945, 4946, 4947, 4948, 4966, 4967, 4968, 4969, 4979, 4980, 4996, 4997, 4998, 4999, 5000, 5001, 5002, 5003, 5004, 5005, 5020, 5021, 5022, 5023, 5024, 5025, 5026, 5027, 5028, 5411, 5435, 5436, 5507, 5508, 5531, 5747, 5771, 5795, 5819, 5820, 5840, 5841, 5842, 5843, 5844, 5867, 5868, 5869, 5889, 5890, 5891, 5892, 5958, 5959, 5960, 5961, 5962, 5963, 5964, 5987, 5988, 6119, 6121, 6122, 6123, 6124, 6125, 6126, 6143, 6144, 6145, 6166, 6168, 6169, 6170, 6180, 6203, 6204, 6224, 6225, 6226, 6227, 6228, 6229, 6230, 6242, 6243, 6244, 6245, 6246, 6247, 6248, 6249, 6250, 6251, 6252, 6275, 6276, 6299, 6300, 6323, 6324, 6348, 6367, 6368, 6369, 6370, 6371, 6372, 6396, 6415, 6416, 6417, 6418, 6419, 6420, 6421, 6422, 6444, 6445, 6540, 6563, 6564, 6586, 6587, 6588, 6635, 6636, 6684, 6707, 6708, 6827, 6828, 6851, 6852, 6923, 6924, 6972, 7020, 7043, 7044, 7067, 7068, 7209, 7210, 7211, 7212, 7327, 7328, 7329, 7330, 7331, 7332, 7333, 7357, 7452, 7453, 7468, 7469, 7470, 7471, 7472, 7473, 7474, 7475, 7476, 7477, 7511, 7512, 7538, 7539, 7540, 7541, 7542, 7543, 7544, 7545, 7546, 7547, 7548, 7549, 7550, 7551, 7566, 7567, 7568, 7569, 7570, 7571, 7572, 7631, 7632, 7633, 7634, 7635, 7636, 7637, 7638, 7639, 7640, 7641, 7642, 7643, 7644, 7667, 7668, 7693, 7859, 7860, 7861, 7956, 7957, 7958, 7970, 7971, 7972, 7973, 7974, 7975, 7976, 7977, 7978, 7979, 7980, 7981, 8026, 8027, 8028, 8053, 8075, 8076, 8195, 8196, 8235, 8236, 8237, 8238, 8239, 8240, 8241, 8242, 8243, 8244, 8245, 8246, 8266, 8267, 8268, 8269, 8316, 8327, 8328, 8329, 8330, 8350, 8351, 8352, 8353, 8373, 8388, 8389, 8398, 8399, 8400, 8401, 8402, 8403, 8404, 8405, 8406, 8407, 8420, 8421, 8422, 8423, 8424, 8454, 8455, 8456, 8457, 8458, 8459, 8460, 8461, 8462, 8463, 8464, 8 ...
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           12 0.7334     0.000083
# discharge         17           37 0.8513     0.000108
# discharge         44           63 0.9908     0.000142
# discharge         69           85 0.2504     0.000012
# discharge         89          111 0.5041     0.000042
# discharge        112          133 0.5394     0.000048
# discharge        140          158 0.4879     0.000040
# discharge        163          181 0.9292     0.000126
# discharge        188          205 0.7619     0.000089
# discharge        213          228 0.7096     0.000078
# discharge        233          254 0.7885     0.000094
# discharge        258          279 0.7109     0.000078
# discharge        283          300 0.6857     0.000073
# discharge        304          324 0.8044     0.000098
# discharge        330          350 0.9910     0.000142
# discharge        357          373 0.4921     0.000040
# discharge        377          396 0.9776     0.000138
# discharge        401          444 1.0000     0.000144
# discharge        449          468 0.8654     0.000111
# discharge        472          492 0.9708     0.000137
# discharge        497          516 0.8618     0.000110
# discharge        524          543 0.1437     0.000004
# discharge        547          568 0.1044     0.000003
# discharge        570          593 0.8850     0.000116
# discharge        597          614 0.1076     0.000003
# discharge        620          637 0.8061     0.000098
# discharge        639          641 0.0186     0.000000
# discharge        645          661 0.3232     0.000019
# discharge        667          685 0.9925     0.000142
# discharge        690          709 0.9386     0.000129
# discharge        714          732 0.8053     0.000098
# discharge        737          756 0.9861     0.000140
# discharge        763          780 0.9139     0.000123
# discharge        785          805 0.7292     0.000082
# discharge        811          831 0.7679     0.000090
# discharge        834          853 0.0365     0.000000
# discharge        858          876 0.7275     0.000081
# discharge        880          901 0.9190     0.000124
# discharge        906          924 0.7475     0.000086
# discharge        929          950 0.5597     0.000051
# discharge        957          975 0.6666     0.000070
# discharge        978          996 0.0635     0.000001
# discharge       1002         1021 0.8536     0.000108
# discharge       1027         1044 0.5156     0.000044
# discharge       1049         1068 0.9433     0.000130
# discharge       1073         1092 0.7666     0.000089
# discharge       1097         1118 0.9912     0.000142
# discharge       1125         1140 0.2855     0.000015
# discharge       1145         1164 0.9803     0.000139
# discharge       1169         1188 0.9636     0.000135
# discharge       1193         1212 0.9348     0.000128
# discharge       1217         1236 0.8469     0.000107
# discharge       1241         1261 0.5817     0.000055
# discharge       1269         1284 0.8280     0.000103
# discharge       1289         1308 0.6397     0.000065
# discharge       1312         1332 0.8245     0.000102
# discharge       1338         1356 0.5738     0.000053
# discharge       1360         1380 0.5342     0.000047
# discharge       1384         1405 0.5767     0.000054
# discharge       1409         1429 0.9440     0.000130
# discharge       1434         1452 0.9640     0.000135
# discharge       1459         1477 0.9968     0.000143
# discharge       1483         1500 0.8016     0.000097
# discharge       1504         1524 0.7160     0.000079
# discharge       1529         1550 0.9413     0.000129
# discharge       1557         1572 0.4332     0.000032
# discharge       1578         1597 0.9819     0.000139
# discharge       1605         1621 0.7813     0.000093
# discharge       1630         1645 0.4355     0.000033
# discharge       1653         1668 0.8443     0.000106
# discharge       1672         1692 0.9778     0.000138
# discharge       1697         1716 0.8860     0.000116
# discharge       1721         1740 0.7088     0.000078
# discharge       1744         1764 0.6461     0.000066
# discharge       1770         1791 0.8099     0.000099
# discharge       1797         1812 0.3895     0.000027
# discharge       1817         1836 0.9615     0.000134
# discharge       1844         1860 0.7322     0.000082
# discharge       1864         1884 0.9601     0.000134
# discharge       1889         1908 0.6421     0.000065
# discharge       1912         1932 0.9364     0.000128
# discharge       1942         1957 0.9655     0.000135
# discharge       1963         1980 0.1200     0.000003
# discharge       1985         2005 0.7608     0.000088
# discharge       2010         2028 0.5839     0.000055
# discharge       2033         2052 0.8612     0.000110
# discharge       2057         2076 0.7557     0.000087
# discharge       2080         2100 0.8940     0.000118
# discharge       2105         2124 0.8712     0.000113
# discharge       2129         2148 0.6312     0.000063
# discharge       2152         2172 0.6949     0.000075
# discharge       2177         2196 0.6784     0.000072
# discharge       2205         2221 0.5357     0.000047
# discharge       2226         2244 0.6378     0.000064
# discharge       2248         2267 0.6113     0.000060
# discharge       2271         2292 0.7191     0.000080
# discharge       2296         2316 0.7796     0.000092
# discharge       2321         2340 0.6502     0.000067
# discharge       2344         2364 0.8344     0.000104
# discharge       2370         2389 0.6120     0.000060
# discharge       2396         2413 0.6851     0.000073
# discharge       2420         2436 0.1657     0.000006
# discharge       2443         2459 0.5340     0.000047
# discharge       2463         2484 0.8526     0.000108
# discharge       2489         2507 0.5950     0.000057
# discharge       2512         2532 0.6659     0.000070
# discharge       2536         2555 0.7884     0.000094
# discharge       2560         2580 0.5563     0.000050
# discharge       2586         2604 0.8321     0.000104
# discharge       2609         2627 0.6711     0.000071
# discharge       2632         2652 0.7409     0.000084
# discharge       2658         2676 0.8447     0.000106
# discharge       2680         2700 0.8947     0.000118
# discharge       2705         2723 0.6999     0.000076
# discharge       2728         2748 0.7207     0.000080
# discharge       2754         2772 0.6924     0.000075
# discharge       2778         2796 0.8600     0.000110
# discharge       2801         2820 0.5971     0.000057
# discharge       2825         2843 0.5596     0.000051
# discharge       2847         2869 0.6530     0.000067
# discharge       2876         2892 0.9797     0.000139
# discharge       2897         2916 0.8319     0.000104
# discharge       2921         2939 0.8042     0.000097
# discharge       2946         2964 0.8687     0.000112
# discharge       2973         2988 0.7311     0.000082
# discharge       2998         3013 0.7875     0.000094
# discharge       3021         3036 0.4347     0.000032
# discharge       3041         3059 0.6809     0.000072
# discharge       3064         3084 0.6348     0.000064
# discharge       3089         3108 0.6495     0.000067
# discharge       3112         3131 0.7441     0.000085
# discharge       3136         3155 0.9362     0.000128
# discharge       3161         3180 0.8999     0.000119
# discharge       3186         3205 0.9866     0.000141
# discharge       3214         3227 0.6187     0.000061
# discharge       3233         3251 0.7819     0.000093
# discharge       3256         3276 0.9137     0.000123
# discharge       3281         3300 0.9751     0.000138
# discharge       3306         3324 0.9325     0.000127
# discharge       3335         3347 0.8280     0.000103
# discharge       3353         3371 0.8617     0.000110
# discharge       3378         3395 0.7750     0.000091
# discharge       3400         3420 0.6852     0.000073
# discharge       3430         3444 0.8271     0.000103
# discharge       3453         3469 0.5474     0.000049
# discharge       3478         3492 0.7694     0.000090
# discharge       3498         3516 0.7322     0.000082
# discharge       3521         3539 0.5736     0.000053
# discharge       3544         3563 0.8575     0.000109
# discharge       3569         3587 0.9239     0.000125
# discharge       3593         3611 0.7677     0.000090
# discharge       3616         3637 0.7910     0.000095
# discharge       3643         3660 0.7775     0.000092
# discharge       3665         3683 0.9425     0.000130
# discharge       3689         3707 0.8930     0.000118
# discharge       3719         3732 0.7823     0.000093
# discharge       3737         3755 0.7576     0.000088
# discharge       3761         3779 0.9236     0.000125
# discharge       3785         3803 0.7465     0.000085
# discharge       3808         3827 0.8652     0.000111
# discharge       3836         3852 0.6768     0.000072
# discharge       3859         3875 0.7866     0.000094
# discharge       3881         3899 0.7312     0.000082
# discharge       3904         3924 0.8216     0.000101
# discharge       3929         3947 0.9299     0.000126
# discharge       3953         3971 0.9417     0.000129
# discharge       3978         3995 0.9357     0.000128
# discharge       4002         4019 0.8725     0.000113
# discharge       4025         4044 0.7913     0.000095
# discharge       4054         4068 0.8573     0.000109
# discharge       4078         4091 0.7256     0.000081
# discharge       4099         4115 0.7899     0.000094
# discharge       4121         4139 0.8702     0.000112
# discharge       4145         4163 0.9510     0.000132
# discharge       4169         4187 0.7833     0.000093
# discharge       4193         4211 0.9370     0.000128
# discharge       4218         4235 0.9290     0.000126
# discharge       4242         4259 0.8851     0.000116
# discharge       4266         4283 0.7266     0.000081
# discharge       4288         4307 0.8296     0.000103
# discharge       4314         4332 0.8501     0.000108
# discharge       4337         4355 0.8215     0.000101
# discharge       4363         4379 0.7439     0.000085
# discharge       4385         4403 0.7682     0.000090
# discharge       4409         4427 0.8624     0.000110
# discharge       4433         4451 0.8028     0.000097
# discharge       4457         4476 0.8075     0.000098
# discharge       4482         4499 0.8563     0.000109
# discharge       4506         4523 0.8618     0.000110
# discharge       4529         4548 0.9732     0.000137
# discharge       4558         4571 0.7105     0.000078
# discharge       4577         4595 0.7707     0.000090
# discharge       4601         4619 0.9455     0.000130
# discharge       4625         4644 0.9353     0.000128
# discharge       4650         4668 0.9018     0.000120
# discharge       4674         4692 0.9590     0.000134
# discharge       4698         4716 0.8528     0.000108
# discharge       4722         4739 0.8440     0.000106
# discharge       4745         4765 0.9107     0.000122
# discharge       4774         4787 0.8052     0.000098
# discharge       4794         4811 0.6995     0.000076
# discharge       4816         4836 0.8617     0.000110
# discharge       4842         4860 0.9169     0.000123
# discharge       4866         4884 0.9051     0.000120
# discharge       4890         4911 0.2119     0.000009
# discharge       4917         4933 0.6772     0.000072
# discharge       4942         4956 0.6024     0.000058
# discharge       4965         4980 0.8356     0.000104
# discharge       4989         5005 0.4490     0.000034
# discharge       5013         5028 0.4490     0.000034
# discharge       5038         5051 0.7876     0.000094
# discharge       5057         5075 0.7862     0.000094
# discharge       5081         5100 0.8246     0.000102
# discharge       5105         5124 0.7661     0.000089
# discharge       5129         5148 0.8114     0.000099
# discharge       5153         5172 0.8902     0.000117
# discharge       5177         5196 0.9019     0.000120
# discharge       5201         5220 0.8596     0.000110
# discharge       5225         5244 0.9239     0.000125
# discharge       5249         5267 0.8218     0.000101
# discharge       5273         5292 0.8169     0.000100
# discharge       5297         5315 0.7719     0.000091
# discharge       5321         5339 0.7510     0.000086
# discharge       5345         5364 0.8999     0.000119
# discharge       5369         5388 0.9270     0.000126
# discharge       5394         5412 0.9638     0.000135
# discharge       5418         5436 0.9763     0.000138
# discharge       5442         5460 0.9303     0.000127
# discharge       5466         5484 0.8216     0.000101
# discharge       5490         5508 0.9697     0.000136
# discharge       5514         5532 0.9545     0.000132
# discharge       5537         5556 0.8232     0.000102
# discharge       5561         5580 0.7763     0.000092
# discharge       5584         5604 0.7540     0.000087
# discharge       5608         5628 0.7415     0.000084
# discharge       5632         5652 0.8160     0.000100
# discharge       5657         5676 0.8380     0.000105
# discharge       5681         5700 0.8430     0.000106
# discharge       5705         5724 0.9470     0.000131
# discharge       5729         5748 0.9735     0.000137
# discharge       5753         5772 0.9807     0.000139
# discharge       5778         5796 0.9705     0.000136
# discharge       5803         5820 0.9774     0.000138
# discharge       5829         5844 0.8198     0.000101
# discharge       5852         5869 0.9885     0.000141
# discharge       5878         5892 0.8187     0.000101
# discharge       5897         5916 0.7196     0.000080
# discharge       5921         5941 0.9000     0.000119
# discharge       5948         5964 0.6393     0.000065
# discharge       5970         5988 0.9804     0.000139
# discharge       5994         6012 0.7843     0.000093
# discharge       6016         6036 0.6745     0.000071
# discharge       6040         6060 0.6991     0.000076
# discharge       6064         6084 0.7841     0.000093
# discharge       6089         6108 0.9462     0.000130
# discharge       6113         6133 0.4012     0.000028
# discharge       6141         6156 0.5252     0.000045
# discharge       6165         6180 0.8616     0.000110
# discharge       6190         6205 0.7508     0.000086
# discharge       6213         6230 0.5829     0.000055
# discharge       6237         6252 0.2796     0.000015
# discharge       6257         6276 0.9706     0.000137
# discharge       6281         6300 0.9812     0.000139
# discharge       6305         6324 0.9824     0.000139
# discharge       6330         6349 0.9778     0.000138
# discharge       6358         6372 0.6739     0.000071
# discharge       6378         6396 0.9684     0.000136
# discharge       6404         6422 0.7187     0.000080
# discharge       6427         6445 0.9799     0.000139
# discharge       6450         6468 0.8715     0.000113
# discharge       6473         6492 0.6635     0.000069
# discharge       6499         6517 0.6998     0.000076
# discharge       6522         6540 0.9677     0.000136
# discharge       6548         6564 0.9764     0.000138
# discharge       6570         6588 0.9847     0.000140
# discharge       6593         6612 0.7157     0.000079
# discharge       6616         6636 0.9755     0.000138
# discharge       6641         6660 0.9533     0.000132
# discharge       6665         6684 0.9520     0.000132
# discharge       6689         6708 0.9843     0.000140
# discharge       6713         6732 0.8423     0.000106
# discharge       6737         6756 0.7371     0.000083
# discharge       6760         6780 0.8053     0.000098
# discharge       6785         6804 0.8067     0.000098
# discharge       6809         6828 0.9758     0.000138
# discharge       6833         6852 0.9721     0.000137
# discharge       6857         6876 0.6985     0.000076
# discharge       6881         6900 0.7627     0.000089
# discharge       6904         6924 0.9756     0.000138
# discharge       6929         6948 0.7647     0.000089
# discharge       6952         6972 0.9557     0.000133
# discharge       6977         6996 0.9500     0.000131
# discharge       7001         7020 0.9463     0.000130
# discharge       7025         7044 0.9763     0.000138
# discharge       7049         7068 0.9770     0.000138
# discharge       7073         7092 0.8776     0.000114
# discharge       7097         7116 0.7099     0.000078
# discharge       7121         7140 0.8847     0.000116
# discharge       7145         7164 0.8391     0.000105
# discharge       7169         7189 0.9232     0.000125
# discharge       7196         7212 0.7547     0.000087
# discharge       7218         7236 0.8948     0.000118
# discharge       7241         7260 0.6771     0.000072
# discharge       7264         7284 0.6573     0.000068
# discharge       7288         7308 0.6108     0.000060
# discharge       7315         7333 0.8356     0.000104
# discharge       7339         7357 0.9690     0.000136
# discharge       7363         7381 0.8796     0.000114
# discharge       7387         7405 0.7352     0.000083
# discharge       7410         7428 0.5777     0.000054
# discharge       7432         7453 0.9833     0.000140
# discharge       7461         7477 0.4712     0.000037
# discharge       7483         7501 0.8761     0.000114
# discharge       7506         7525 0.7874     0.000094
# discharge       7531         7551 0.3942     0.000027
# discharge       7557         7572 0.5946     0.000057
# discharge       7578         7596 0.8932     0.000118
# discharge       7601         7623 0.8861     0.000116
# discharge       7627         7644 0.2076     0.000009
# discharge       7649         7668 0.9737     0.000137
# discharge       7673         7693 0.9630     0.000135
# discharge       7698         7717 0.8671     0.000112
# discharge       7723         7741 0.7645     0.000089
# discharge       7746         7765 0.7835     0.000093
# discharge       7769         7788 0.8518     0.000108
# discharge       7793         7812 0.6187     0.000061
# discharge       7816         7836 0.7187     0.000080
# discharge       7841         7861 0.9914     0.000142
# discharge       7866         7884 0.8842     0.000116
# discharge       7889         7908 0.5475     0.000049
# discharge       7912         7932 0.7575     0.000088
# discharge       7937         7958 0.9885     0.000141
# discharge       7964         7981 0.3162     0.000018
# discharge       7986         8004 0.9023     0.000120
# discharge       8009         8028 0.9855     0.000140
# discharge       8033         8054 0.9669     0.000136
# discharge       8060         8076 0.9751     0.000138
# discharge       8082         8100 0.8234     0.000102
# discharge       8105         8124 0.8573     0.000109
# discharge       8130         8148 0.7378     0.000084
# discharge       8152         8172 0.9079     0.000121
# discharge       8177         8196 0.9819     0.000139
# discharge       8202         8222 0.7890     0.000094
# discharge       8226         8246 0.3271     0.000019
# discharge       8251         8269 0.9938     0.000142
# discharge       8276         8292 0.8438     0.000106
# discharge       8297         8316 0.9505     0.000131
# discharge       8321         8343 0.7309     0.000082
# discharge       8349         8365 0.6153     0.000060
# discharge       8372         8389 0.9045     0.000120
# discharge       8397         8413 0.2383     0.000011
# discharge       8419         8437 0.8340     0.000104
# discharge       8444         8464 0.6624     0.000069
# discharge       8469         8484 0.2817     0.000015
# discharge       8490         8508 0.8008     0.000097
# discharge       8513         8532 0.8670     0.000112
# discharge       8537         8556 0.9697     0.000136
# discharge       8561         8580 0.8425     0.000106
# discharge       8585         8606 0.6166     0.000061
# discharge       8612         8631 0.7437     0.000085
# discharge       8635         8654 0.4643     0.000036
# discharge       8661         8677 0.4230     0.000031
# discharge       8683         8701 0.9189     0.000124
# discharge       8703         8706 0.0441     0.000001
# discharge       8707         8725 0.1019     0.000002
# discharge       8731         8749 0.9300     0.000126
#
# Total Estimated Degradation: 0.034708
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1983.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1982.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1982.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1982.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1982.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1981.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1981.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1981.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1981.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_data_1980.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 97196103.64 kWh
# Year 2023: Unmet Load = 78100373.69 kWh
# Year 2022: Unmet Load = 75035215.70 kWh
# Year 2021: Unmet Load = 70482316.09 kWh
# Year 2020: Unmet Load = 97869327.74 kWh
# Year 2019: Unmet Load = 120886816.58 kWh
# Year 2018: Unmet Load = 109917905.21 kWh
# Year 2017: Unmet Load = 96353799.98 kWh
# Year 2016: Unmet Load = 88681872.73 kWh
# Year 2015: Unmet Load = 109152516.46 kWh
# Year 2014: Unmet Load = 83806774.42 kWh
# Year 2013: Unmet Load = 102246707.47 kWh
# Year 2012: Unmet Load = 80037069.56 kWh
# Year 2011: Unmet Load = 86660189.91 kWh
# Year 2010: Unmet Load = 75186204.70 kWh
# Year 2009: Unmet Load = 99034074.42 kWh
# Year 2008: Unmet Load = 62644524.07 kWh
# Year 2007: Unmet Load = 87826392.09 kWh
# Year 2006: Unmet Load = 77426426.30 kWh
# Year 2005: Unmet Load = 68753510.66 kWh
# Year 2004: Unmet Load = 84915785.62 kWh
# Year 2003: Unmet Load = 83630717.17 kWh
# Year 2002: Unmet Load = 94577420.37 kWh
# Year 2001: Unmet Load = 87813570.90 kWh
# Year 2000: Unmet Load = 78735337.85 kWh
# Year 1999: Unmet Load = 57561713.42 kWh
# Year 1998: Unmet Load = 104012114.80 kWh
# Year 1997: Unmet Load = 87491786.43 kWh
# Year 1996: Unmet Load = 75786788.09 kWh
# Year 1995: Unmet Load = 62049127.11 kWh
# Year 1994: Unmet Load = 113913618.93 kWh
# Year 1993: Unmet Load = 115422470.96 kWh
# Year 1992: Unmet Load = 112354200.74 kWh
# Year 1991: Unmet Load = 127334073.24 kWh
# Year 1990: Unmet Load = 91813452.99 kWh
# Year 1989: Unmet Load = 92437615.68 kWh
# Year 1988: Unmet Load = 57459337.97 kWh
# Year 1987: Unmet Load = 103043827.91 kWh
# Year 1986: Unmet Load = 114487357.88 kWh
# Year 1985: Unmet Load = 87573320.79 kWh
# Year 1984: Unmet Load = 72445022.36 kWh
# Year 1983: Unmet Load = 102023222.37 kWh
# Year 1982: Unmet Load = 95545236.04 kWh
# Year 1981: Unmet Load = 89377548.21 kWh
# Year 1980: Unmet Load = 87127083.66 kWh
#
# Average Unmet Load (1979-2024): 89916219.40 kWh
# Min Unmet Load: 57459337.97 kWh (Year 1988)
# Max Unmet Load: 127334073.24 kWh (Year 1991)
# Starting capacity, cost, and utilization metrics collection...
# Processing year 2024 for capacity, cost, and utilization metrics...
# Year 2024: Dispatch simulation successful, calculating metrics...
# $44241883.06 is the replacement cost each year for degradation
# Year 2024: Metrics added - Utilization: 69.36%, NPC: 3259855401.91, Unmet: 97196103.64 kWh
# Processing year 2023 for capacity, cost, and utilization metrics...
# Year 2023: Dispatch simulation successful, calculating metrics...
# $46406548.52 is the replacement cost each year for degradation
# Year 2023: Metrics added - Utilization: 70.45%, NPC: 3287359051.30, Unmet: 78100373.69 kWh
# Processing year 2022 for capacity, cost, and utilization metrics...
# Year 2022: Dispatch simulation successful, calculating metrics...
# $44989937.65 is the replacement cost each year for degradation
# Year 2022: Metrics added - Utilization: 67.60%, NPC: 3269359979.66, Unmet: 75035215.70 kWh
# Processing year 2021 for capacity, cost, and utilization metrics...
# Year 2021: Dispatch simulation successful, calculating metrics...
# $45680538.70 is the replacement cost each year for degradation
# Year 2021: Metrics added - Utilization: 70.74%, NPC: 3278134568.43, Unmet: 70482316.09 kWh
# Processing year 2020 for capacity, cost, and utilization metrics...
# Year 2020: Dispatch simulation successful, calculating metrics...
# $45164314.39 is the replacement cost each year for degradation
# Year 2020: Metrics added - Utilization: 71.08%, NPC: 3271575563.03, Unmet: 97869327.74 kWh
# Processing year 2019 for capacity, cost, and utilization metrics...
# Year 2019: Dispatch simulation successful, calculating metrics...
# $45097709.83 is the replacement cost each year for degradation
# Year 2019: Metrics added - Utilization: 71.54%, NPC: 3270729303.58, Unmet: 120886816.58 kWh
# Processing year 2018 for capacity, cost, and utilization metrics...
# Year 2018: Dispatch simulation successful, calculating metrics...
# $44964783.85 is the replacement cost each year for degradation
# Year 2018: Metrics added - Utilization: 72.05%, NPC: 3269040382.33, Unmet: 109917905.21 kWh
# Processing year 2017 for capacity, cost, and utilization metrics...
# Year 2017: Dispatch simulation successful, calculating metrics...
# $44481424.55 is the replacement cost each year for degradation
# Year 2017: Metrics added - Utilization: 69.77%, NPC: 3262898950.81, Unmet: 96353799.98 kWh
# Processing year 2016 for capacity, cost, and utilization metrics...
# Year 2016: Dispatch simulation successful, calculating metrics...
# $45628021.66 is the replacement cost each year for degradation
# Year 2016: Metrics added - Utilization: 70.07%, NPC: 3277467301.18, Unmet: 88681872.73 kWh
# Processing year 2015 for capacity, cost, and utilization metrics...
# Year 2015: Dispatch simulation successful, calculating metrics...
# $44218232.96 is the replacement cost each year for degradation
# Year 2015: Metrics added - Utilization: 71.17%, NPC: 3259554910.22, Unmet: 109152516.46 kWh
# Processing year 2014 for capacity, cost, and utilization metrics...
# Year 2014: Dispatch simulation successful, calculating metrics...
# $44575097.88 is the replacement cost each year for degradation
# Year 2014: Metrics added - Utilization: 69.01%, NPC: 3264089138.62, Unmet: 83806774.42 kWh
# Processing year 2013 for capacity, cost, and utilization metrics...
# Year 2013: Dispatch simulation successful, calculating metrics...
# $44549605.17 is the replacement cost each year for degradation
# Year 2013: Metrics added - Utilization: 69.57%, NPC: 3263765235.13, Unmet: 102246707.47 kWh
# Processing year 2012 for capacity, cost, and utilization metrics...
# Year 2012: Dispatch simulation successful, calculating metrics...
# $43901986.88 is the replacement cost each year for degradation
# Year 2012: Metrics added - Utilization: 68.75%, NPC: 3255536773.67, Unmet: 80037069.56 kWh
# Processing year 2011 for capacity, cost, and utilization metrics...
# Year 2011: Dispatch simulation successful, calculating metrics...
# $43799319.96 is the replacement cost each year for degradation
# Year 2011: Metrics added - Utilization: 69.02%, NPC: 3254232315.78, Unmet: 86660189.91 kWh
# Processing year 2010 for capacity, cost, and utilization metrics...
# Year 2010: Dispatch simulation successful, calculating metrics...
# $46479240.90 is the replacement cost each year for degradation
# Year 2010: Metrics added - Utilization: 69.21%, NPC: 3288282660.93, Unmet: 75186204.70 kWh
# Processing year 2009 for capacity, cost, and utilization metrics...
# Year 2009: Dispatch simulation successful, calculating metrics...
# $43772541.44 is the replacement cost each year for degradation
# Year 2009: Metrics added - Utilization: 70.17%, NPC: 3253892075.19, Unmet: 99034074.42 kWh
# Processing year 2008 for capacity, cost, and utilization metrics...
# Year 2008: Dispatch simulation successful, calculating metrics...
# $45271744.25 is the replacement cost each year for degradation
# Year 2008: Metrics added - Utilization: 68.20%, NPC: 3272940537.55, Unmet: 62644524.07 kWh
# Processing year 2007 for capacity, cost, and utilization metrics...
# Year 2007: Dispatch simulation successful, calculating metrics...
# $45759494.03 is the replacement cost each year for degradation
# Year 2007: Metrics added - Utilization: 68.51%, NPC: 3279137753.32, Unmet: 87826392.09 kWh
# Processing year 2006 for capacity, cost, and utilization metrics...
# Year 2006: Dispatch simulation successful, calculating metrics...
# $44075246.50 is the replacement cost each year for degradation
# Year 2006: Metrics added - Utilization: 67.69%, NPC: 3257738163.20, Unmet: 77426426.30 kWh
# Processing year 2005 for capacity, cost, and utilization metrics...
# Year 2005: Dispatch simulation successful, calculating metrics...
# $46310262.30 is the replacement cost each year for degradation
# Year 2005: Metrics added - Utilization: 68.03%, NPC: 3286135664.81, Unmet: 68753510.66 kWh
# Processing year 2004 for capacity, cost, and utilization metrics...
# Year 2004: Dispatch simulation successful, calculating metrics...
# $43995086.92 is the replacement cost each year for degradation
# Year 2004: Metrics added - Utilization: 69.84%, NPC: 3256719677.41, Unmet: 84915785.62 kWh
# Processing year 2003 for capacity, cost, and utilization metrics...
# Year 2003: Dispatch simulation successful, calculating metrics...
# $44336157.62 is the replacement cost each year for degradation
# Year 2003: Metrics added - Utilization: 68.89%, NPC: 3261053228.75, Unmet: 83630717.17 kWh
# Processing year 2002 for capacity, cost, and utilization metrics...
# Year 2002: Dispatch simulation successful, calculating metrics...
# $43697671.11 is the replacement cost each year for degradation
# Year 2002: Metrics added - Utilization: 68.91%, NPC: 3252940793.12, Unmet: 94577420.37 kWh
# Processing year 2001 for capacity, cost, and utilization metrics...
# Year 2001: Dispatch simulation successful, calculating metrics...
# $45148556.37 is the replacement cost each year for degradation
# Year 2001: Metrics added - Utilization: 67.92%, NPC: 3271375345.95, Unmet: 87813570.90 kWh
# Processing year 2000 for capacity, cost, and utilization metrics...
# Year 2000: Dispatch simulation successful, calculating metrics...
# $44605801.17 is the replacement cost each year for degradation
# Year 2000: Metrics added - Utilization: 66.94%, NPC: 3264479246.22, Unmet: 78735337.85 kWh
# Processing year 1999 for capacity, cost, and utilization metrics...
# Year 1999: Dispatch simulation successful, calculating metrics...
# $43689556.57 is the replacement cost each year for degradation
# Year 1999: Metrics added - Utilization: 66.67%, NPC: 3252837692.01, Unmet: 57561713.42 kWh
# Processing year 1998 for capacity, cost, and utilization metrics...
# Year 1998: Dispatch simulation successful, calculating metrics...
# $43462708.15 is the replacement cost each year for degradation
# Year 1998: Metrics added - Utilization: 68.69%, NPC: 3249955417.82, Unmet: 104012114.80 kWh
# Processing year 1997 for capacity, cost, and utilization metrics...
# Year 1997: Dispatch simulation successful, calculating metrics...
# $45711198.21 is the replacement cost each year for degradation
# Year 1997: Metrics added - Utilization: 69.64%, NPC: 3278524119.85, Unmet: 87491786.43 kWh
# Processing year 1996 for capacity, cost, and utilization metrics...
# Year 1996: Dispatch simulation successful, calculating metrics...
# $43218504.65 is the replacement cost each year for degradation
# Year 1996: Metrics added - Utilization: 67.70%, NPC: 3246852634.75, Unmet: 75786788.09 kWh
# Processing year 1995 for capacity, cost, and utilization metrics...
# Year 1995: Dispatch simulation successful, calculating metrics...
# $45107719.63 is the replacement cost each year for degradation
# Year 1995: Metrics added - Utilization: 67.82%, NPC: 3270856485.41, Unmet: 62049127.11 kWh
# Processing year 1994 for capacity, cost, and utilization metrics...
# Year 1994: Dispatch simulation successful, calculating metrics...
# $44406615.05 is the replacement cost each year for degradation
# Year 1994: Metrics added - Utilization: 70.30%, NPC: 3261948441.64, Unmet: 113913618.93 kWh
# Processing year 1993 for capacity, cost, and utilization metrics...
# Year 1993: Dispatch simulation successful, calculating metrics...
# $43953833.23 is the replacement cost each year for degradation
# Year 1993: Metrics added - Utilization: 71.61%, NPC: 3256195519.22, Unmet: 115422470.96 kWh
# Processing year 1992 for capacity, cost, and utilization metrics...
# Year 1992: Dispatch simulation successful, calculating metrics...
# $43518266.54 is the replacement cost each year for degradation
# Year 1992: Metrics added - Utilization: 70.91%, NPC: 3250661327.60, Unmet: 112354200.74 kWh
# Processing year 1991 for capacity, cost, and utilization metrics...
# Year 1991: Dispatch simulation successful, calculating metrics...
# $44104963.28 is the replacement cost each year for degradation
# Year 1991: Metrics added - Utilization: 74.18%, NPC: 3258115736.49, Unmet: 127334073.24 kWh
# Processing year 1990 for capacity, cost, and utilization metrics...
# Year 1990: Dispatch simulation successful, calculating metrics...
# $43529468.05 is the replacement cost each year for degradation
# Year 1990: Metrics added - Utilization: 69.22%, NPC: 3250803650.93, Unmet: 91813452.99 kWh
# Processing year 1989 for capacity, cost, and utilization metrics...
# Year 1989: Dispatch simulation successful, calculating metrics...
# $43860705.29 is the replacement cost each year for degradation
# Year 1989: Metrics added - Utilization: 70.55%, NPC: 3255012261.03, Unmet: 92437615.68 kWh
# Processing year 1988 for capacity, cost, and utilization metrics...
# Year 1988: Dispatch simulation successful, calculating metrics...
# $44739029.07 is the replacement cost each year for degradation
# Year 1988: Metrics added - Utilization: 66.78%, NPC: 3266172003.62, Unmet: 57459337.97 kWh
# Processing year 1987 for capacity, cost, and utilization metrics...
# Year 1987: Dispatch simulation successful, calculating metrics...
# $45156066.29 is the replacement cost each year for degradation
# Year 1987: Metrics added - Utilization: 70.39%, NPC: 3271470764.87, Unmet: 103043827.91 kWh
# Processing year 1986 for capacity, cost, and utilization metrics...
# Year 1986: Dispatch simulation successful, calculating metrics...
# $44090546.58 is the replacement cost each year for degradation
# Year 1986: Metrics added - Utilization: 69.54%, NPC: 3257932561.83, Unmet: 114487357.88 kWh
# Processing year 1985 for capacity, cost, and utilization metrics...
# Year 1985: Dispatch simulation successful, calculating metrics...
# $44578268.29 is the replacement cost each year for degradation
# Year 1985: Metrics added - Utilization: 69.23%, NPC: 3264129420.93, Unmet: 87573320.79 kWh
# Processing year 1984 for capacity, cost, and utilization metrics...
# Year 1984: Dispatch simulation successful, calculating metrics...
# $45121665.25 is the replacement cost each year for degradation
# Year 1984: Metrics added - Utilization: 69.95%, NPC: 3271033674.64, Unmet: 72445022.36 kWh
# Processing year 1983 for capacity, cost, and utilization metrics...
# Year 1983: Dispatch simulation successful, calculating metrics...
# $45510732.51 is the replacement cost each year for degradation
# Year 1983: Metrics added - Utilization: 71.00%, NPC: 3275977057.21, Unmet: 102023222.37 kWh
# Processing year 1982 for capacity, cost, and utilization metrics...
# Year 1982: Dispatch simulation successful, calculating metrics...
# $45005443.86 is the replacement cost each year for degradation
# Year 1982: Metrics added - Utilization: 71.11%, NPC: 3269556997.41, Unmet: 95545236.04 kWh
# Processing year 1981 for capacity, cost, and utilization metrics...
# Year 1981: Dispatch simulation successful, calculating metrics...
# $46146595.23 is the replacement cost each year for degradation
# Year 1981: Metrics added - Utilization: 68.33%, NPC: 3284056155.63, Unmet: 89377548.21 kWh
# Processing year 1980 for capacity, cost, and utilization metrics...
# Year 1980: Dispatch simulation successful, calculating metrics...
# $44163375.95 is the replacement cost each year for degradation
# Year 1980: Metrics added - Utilization: 67.30%, NPC: 3258857912.00, Unmet: 87127083.66 kWh
# Saved capacity, cost, and utilization metrics to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\capacity_and_costs_by_year.csv
# CSV file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\capacity_and_costs_by_year.csv
# Starting NPC variation plotting...
# Saved NPC variation plot to dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\npc_variation_by_year.png
# Plot file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment\npc_variation_by_year.png

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
        )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year 95% met Load Sizing (Hybrid Configuration)")
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")

# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 428.77 hours
# 1980: 438.51 extra training hours
# 1981: 434.57 extra training hours
# 1982: 434.02 extra training hours
# 1983: 495.85 extra training hours
# 1984: 333.94 extra training hours
# 1985: 421.47 extra training hours
# 1986: 564.60 extra training hours
# 1987: 479.03 extra training hours
# 1988: 263.28 extra training hours
# 1989: 429.04 extra training hours
# 1990: 438.33 extra training hours
# 1991: 616.96 extra training hours
# 1992: 535.07 extra training hours
# 1993: 562.80 extra training hours
# 1994: 547.70 extra training hours
# 1995: 287.24 extra training hours
# 1996: 362.79 extra training hours
# 1997: 425.97 extra training hours
# 1998: 514.97 extra training hours
# 1999: 283.78 extra training hours
# 2000: 368.61 extra training hours
# 2001: 415.05 extra training hours
# 2002: 454.64 extra training hours
# 2003: 400.10 extra training hours
# 2004: 396.23 extra training hours
# 2005: 324.77 extra training hours
# 2006: 368.38 extra training hours
# 2007: 417.21 extra training hours
# 2008: 269.75 extra training hours
# 2009: 483.29 extra training hours
# 2010: 345.31 extra training hours
# 2011: 440.39 extra training hours
# 2012: 395.85 extra training hours
# 2013: 490.26 extra training hours
# 2014: 404.19 extra training hours
# 2015: 530.22 extra training hours
# 2016: 431.62 extra training hours
# 2017: 451.41 extra training hours
# 2018: 508.49 extra training hours
# 2019: 580.16 extra training hours
# 2020: 463.46 extra training hours
# 2021: 327.78 extra training hours
# 2022: 342.88 extra training hours
# 2023: 352.14 extra training hours
# 2024: 462.51 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 660 hours with unmet load
# 1981: 681 hours with unmet load
# 1982: 792 hours with unmet load
# 1983: 780 hours with unmet load
# 1984: 600 hours with unmet load
# 1985: 672 hours with unmet load
# 1986: 842 hours with unmet load
# 1987: 811 hours with unmet load
# 1988: 481 hours with unmet load
# 1989: 717 hours with unmet load
# 1990: 707 hours with unmet load
# 1991: 990 hours with unmet load
# 1992: 843 hours with unmet load
# 1993: 895 hours with unmet load
# 1994: 867 hours with unmet load
# 1995: 544 hours with unmet load
# 1996: 580 hours with unmet load
# 1997: 710 hours with unmet load
# 1998: 767 hours with unmet load
# 1999: 462 hours with unmet load
# 2000: 634 hours with unmet load
# 2001: 664 hours with unmet load
# 2002: 742 hours with unmet load
# 2003: 649 hours with unmet load
# 2004: 679 hours with unmet load
# 2005: 541 hours with unmet load
# 2006: 622 hours with unmet load
# 2007: 687 hours with unmet load
# 2008: 535 hours with unmet load
# 2009: 776 hours with unmet load
# 2010: 648 hours with unmet load
# 2011: 683 hours with unmet load
# 2012: 657 hours with unmet load
# 2013: 789 hours with unmet load
# 2014: 662 hours with unmet load
# 2015: 826 hours with unmet load
# 2016: 686 hours with unmet load
# 2017: 732 hours with unmet load
# 2018: 874 hours with unmet load
# 2019: 926 hours with unmet load
# 2020: 763 hours with unmet load
# 2021: 576 hours with unmet load
# 2022: 601 hours with unmet load
# 2023: 654 hours with unmet load
# 2024: 768 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 706.11 hours/year
# Maximum: 990 hours in 1991
# Minimum: 462 hours in 1999

# %% [markdown]
# # 90% met Load sizing

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.1 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5


# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 1000)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:
        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        
        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

        # === Save Capacity, Cost, and Utilization Metrics for All Years ===
        print("Starting capacity, cost, and utilization metrics collection...")
        results_by_year = []
        for year in range(2024, 1979, -1):
            print(f"Processing year {year} for capacity, cost, and utilization metrics...")
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                print(f"Year {year}: Skipping due to missing resource data.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                print(f"Year {year}: Dispatch simulation successful, calculating metrics...")
                # Calculate utilization metrics
                total_curtailed = np.sum(dispatch_result["curtailment"])
                solar_gen = solar_resource * opt_results["solar"]
                wind_gen = wind_resource * opt_results["wind"]
                total_generated = np.sum(solar_gen + wind_gen)
                total_power_consumed = total_generated - total_curtailed
                utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

                # Calculate battery replacement cost
                yearly_degradation = dispatch_result["degradation"]
                battery_replacement = calculate_battery_replacement_cost(
                    battery_capex=opt_results["battery_capex"],
                    degradation=yearly_degradation,
                    inf=inf,
                    dis=dis,
                    life_battery=life_battery
                )

                # Calculate total NPC
                total_npc = (
                    opt_results["solar_capex"] +
                    opt_results["solar_opex"] +
                    opt_results["solar_replacement"] -
                    opt_results["solar_salvage"] +
                    opt_results["wind_capex"] +
                    opt_results["wind_opex"] +
                    opt_results["wind_replacement"] -
                    opt_results["wind_salvage"] +
                    opt_results["battery_capex"] +
                    opt_results["battery_opex"] +
                    battery_replacement -
                    opt_results["battery_salvage"] +
                    opt_results["inverter_capex"] +
                    opt_results["inverter_opex"] +
                    opt_results["inverter_replacement"] -
                    opt_results["inverter_salvage"]
                )

                # Store results
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": opt_results["solar"],
                    "Wind_Capacity_HAWT": opt_results["wind"],
                    "Battery_Capacity_kWh": opt_results["battery"],
                    "Inverter_Capacity_kW": inverter_capacity,
                    "Solar_CAPEX": opt_results["solar_capex"],
                    "Solar_OPEX": opt_results["solar_opex"],
                    "Solar_Replacement": opt_results["solar_replacement"],
                    "Solar_Salvage": opt_results["solar_salvage"],
                    "Wind_CAPEX": opt_results["wind_capex"],
                    "Wind_OPEX": opt_results["wind_opex"],
                    "Wind_Replacement": opt_results["wind_replacement"],
                    "Wind_Salvage": opt_results["wind_salvage"],
                    "Battery_CAPEX": opt_results["battery_capex"],
                    "Battery_OPEX": opt_results["battery_opex"],
                    "Battery_Replacement": battery_replacement,
                    "Battery_Salvage": opt_results["battery_salvage"],
                    "Inverter_CAPEX": opt_results["inverter_capex"],
                    "Inverter_OPEX": opt_results["inverter_opex"],
                    "Inverter_Replacement": opt_results["inverter_replacement"],
                    "Inverter_Salvage": opt_results["inverter_salvage"],
                    "Total_NPC": total_npc,
                    "Utilization_Percentage": utilization_percentage,
                    "Total_Curtailed_kWh": total_curtailed,
                    "Total_Generated_kWh": total_generated,
                    "Total_Power_Consumed_kWh": total_power_consumed,
                    "Total_Unmet_kWh": dispatch_result["total_unmet"]
                })
                print(f"Year {year}: Metrics added - Utilization: {utilization_percentage:.2f}%, NPC: {total_npc:.2f}, Unmet: {dispatch_result['total_unmet']:.2f} kWh")
            else:
                print(f"Year {year}: Metrics save failed due to dispatch simulation error.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })

        # Save results to CSV
        try:
            df_results = pd.DataFrame(results_by_year)
            csv_path = os.path.join(output_dir, "capacity_and_costs_by_year.csv")
            df_results.to_csv(csv_path, index=False)
            print(f"Saved capacity, cost, and utilization metrics to {csv_path}")
            print(f"CSV file location: {os.path.abspath(csv_path)}")
        except Exception as e:
            print(f"Error saving CSV: {e}")

        # === Plot NPC Variation Across Years ===
        print("Starting NPC variation plotting...")
        try:
            valid_npc_data = df_results[df_results["Total_NPC"].notna()][["Year", "Total_NPC"]]
            if valid_npc_data.empty:
                print("Error: No valid NPC data found for plotting.")
            else:
                plt.figure(figsize=(15, 8))
                plt.plot(valid_npc_data["Year"], valid_npc_data["Total_NPC"], marker='o', linestyle='-', color='b')
                plt.title("NPC Variation Across Years (1979-2024)")
                plt.xlabel("Year")
                plt.ylabel("Total NPC ($)")
                plt.grid(True)
                plt.gca().invert_xaxis()  # Reverse x-axis to show 2024 to 1979
                plt.tight_layout()
                plot_path = os.path.join(output_dir, "npc_variation_by_year.png")
                plt.savefig(plot_path)
                plt.close()
                print(f"Saved NPC variation plot to {plot_path}")
                print(f"Plot file location: {os.path.abspath(plot_path)}")
        except Exception as e:
            print(f"Error plotting NPC variation: {e}")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 1000
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  1000
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0x1ff42b6a
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 2e+08]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 5s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 13s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 20s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 24.35s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   4.665258e+05   3.669944e+06     40s
#     5381    8.7222262e+09   0.000000e+00   4.569474e+08     45s
#    12166    8.3056186e+09   0.000000e+00   3.290455e+11     50s
#    13977    6.7573545e+09   0.000000e+00   2.671335e+10     55s
#    15581    6.2128695e+09   0.000000e+00   1.592277e+08     60s
#    17025    5.9633828e+09   4.679403e-03   3.415396e+11     65s
#    18120    5.6791194e+09   0.000000e+00   1.487050e+04     71s
#    18909    5.5183808e+09   0.000000e+00   9.694973e+03     75s
# Warning: 1 variables dropped from basis
#    19847    5.3910186e+09   0.000000e+00   2.292717e+05     80s
#    20863    5.2593503e+09   0.000000e+00   5.875743e+12     85s
# Warning: 1 variables dropped from basis
#    21789    5.0599917e+09   0.000000e+00   1.313358e+11     90s
# Warning: 1 variables dropped from basis
#    24020    1.2527534e+09   1.319617e+08   7.724890e+09     95s
#    30446    1.4509679e+10   2.126206e+07   2.003343e+09    100s
#    34991    7.1102212e+09   0.000000e+00   2.296856e+08    105s
#    36951    7.0133264e+09   0.000000e+00   5.709393e+04    110s
#    38659    6.8788916e+09   0.000000e+00   5.401326e+04    116s
#    40184    6.6821124e+09   0.000000e+00   2.678446e+09    120s
#    41979    6.5120103e+09   0.000000e+00   3.908760e+04    125s
#    43475    6.3919327e+09   0.000000e+00   4.695149e+09    130s
# Warning: 1 variables dropped from basis
#    44940    6.2251780e+09   0.000000e+00   2.985918e+10    135s
#    46171    6.0912214e+09   2.735944e-05   2.799708e+06    140s
#    47205    5.7881416e+09   0.000000e+00   2.069575e+06    145s
#    47901    5.5317379e+09   0.000000e+00   4.348972e+11    151s
#    48737    5.3560039e+09   0.000000e+00   2.111886e+05    156s
#    49603    5.1577461e+09   0.000000e+00   3.974291e+07    160s
#    50534    5.0284629e+09   0.000000e+00   2.557807e+05    165s
# Concurrent spin time: 4.51s
#
# Solved with primal simplex
#
# Root relaxation: objective 2.295370e+09, 37264 iterations, 131.71 seconds (92.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.2954e+09    0  106          - 2.2954e+09      -     -  171s
# H    0     0                    4.687909e+09 2.2954e+09  51.0%     -  190s
# H    0     0                    4.085236e+09 2.2954e+09  43.8%     -  208s
# H    0     0                    4.012407e+09 2.2954e+09  42.8%     -  222s
# H    0     0                    3.904476e+09 2.2954e+09  41.2%     -  295s
#      0     2 2.2954e+09    0  106 3.9045e+09 2.2954e+09  41.2%     -  295s
#      7    16 2.2954e+09    3  106 3.9045e+09 2.2954e+09  41.2%  34.1  301s
#     23    51 2.2954e+09    5  105 3.9045e+09 2.2954e+09  41.2%   148  308s
#     50    59 2.2989e+09    8  101 3.9045e+09 2.2954e+09  41.2%   173  318s
#     58    84 2.2954e+09    8  105 3.9045e+09 2.2954e+09  41.2%   318  322s
#     83    95 2.2964e+09   11  100 3.9045e+09 2.2954e+09  41.2%   255  329s
#     94   120 2.2954e+09   11  103 3.9045e+09 2.2954e+09  41.2%   283  333s
#    119   135 2.2973e+09   14   95 3.9045e+09 2.2954e+09  41.2%   245  339s
#    134   170 2.2954e+09   14  103 3.9045e+09 2.2954e+09  41.2%   250  346s
#    169   221 2.2954e+09   18  103 3.9045e+09 2.2954e+09  41.2%   231  355s
#    220   258 2.2954e+09   22  102 3.9045e+09 2.2954e+09  41.2%   204  366s
#    257   345 2.2954e+09   25  101 3.9045e+09 2.2954e+09  41.2%   206  380s
#    344   380 2.2954e+09   32   96 3.9045e+09 2.2954e+09  41.2%   177  401s
#    379   431 2.2954e+09   34   96 3.9045e+09 2.2954e+09  41.2%   202  423s
#    430   492 2.2954e+09   36   96 3.9045e+09 2.2954e+09  41.2%   232  443s
#    491   552 2.2963e+09   38   92 3.9045e+09 2.2954e+09  41.2%   231  481s
# H  543   505                    2.296117e+09 2.2954e+09  0.03%   241  481s
#
# Explored 551 nodes (171218 simplex iterations) in 482.57 seconds (526.64 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 2.29612e+09 3.90448e+09 4.01241e+09 ... 4.68791e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.296117357134e+09, best bound 2.295369969707e+09, gap 0.0326%
# Optimal Solution Found!
# Solar Capacity: 5303453.26 PV
# Wind Capacity: 48.02 HAWT
# Battery Capacity: 3329406.71 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 605668976.42 kWh
# Total Energy Generated: 2961721128.75 kWh
# Total Energy Used (along with efficiency losses): 2356052152.34 kWh
# Utilization Percentage: 79.55%
# $48368599.98 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 5303453.26 PV
# Solar Initial Cost:    $492955980.97
# Wind Initial Capacity: 48.02 HAWT
# Wind Initial Cost:     $245584899.77
# Battery Initial Capacity: 3329406.71 kWh
# Battery Initial Cost:  $1191927601.60
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -16971.05 PV
# Solar Redundant Cost:    $-1577459.14
# Wind Redundant Capacity: 4.24 HAWT
# Wind Redundant Cost:     $21680234.95
# Battery Redundant Capacity: 12318.80 kWh
# Battery Redundant Cost:  $4410132.13
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $491378521.83
# Solar OPEX:         $536715407.22
# Solar Replacement:  $0.00
# Solar Salvage:     -$142845416.55
# Wind CAPEX:         $267265134.72
# Wind OPEX:          $57204307.67
# Wind Replacement:   $0.00
# Wind Salvage:      -$48559305.36
# Battery CAPEX:      $1196337733.72
# Battery OPEX:       $360417592.46
# Battery Replacement:$614558250.16
# Battery Salvage:   -$434724337.55
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $2910675607.30
#
# === 2024 Results ===
# Total Unmet Load: 194150250.27 kWh
# Hours with Unmet Load: [22, 23, 24, 25, 26, 27, 28, 45, 46, 58, 59, 60, 61, 62, 63, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 106, 107, 109, 113, 114, 115, 116, 117, 127, 128, 129, 130, 131, 132, 133, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 179, 180, 181, 199, 200, 201, 202, 203, 204, 205, 221, 222, 223, 224, 225, 226, 227, 228, 253, 254, 278, 279, 300, 310, 311, 312, 343, 344, 345, 346, 347, 348, 349, 350, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 394, 395, 396, 407, 408, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 468, 490, 491, 492, 502, 503, 504, 505, 506, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 591, 592, 593, 594, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 622, 637, 640, 641, 643, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 682, 683, 684, 685, 707, 708, 709, 732, 754, 755, 756, 778, 779, 780, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 812, 813, 814, 815, 817, 831, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 887, 890, 909, 924, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 957, 958, 959, 973, 974, 975, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 1020, 1021, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1067, 1068, 1092, 1114, 1115, 1116, 1117, 1118, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1162, 1163, 1164, 1187, 1188, 1211, 1212, 1236, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1332, 1427, 1428, 1429, 1450, 1451, 1452, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1500, 1547, 1548, 1549, 1550, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1583, 1584, 1585, 1586, 1607, 1608, 1609, 1610, 1620, 1621, 1622, 1623, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1665, 1666, 1667, 1668, 1690, 1691, 1692, 1715, 1716, 1751, 1752, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1834, 1835, 1836, 1883, 1884, 1919, 1920, 1921, 1922, 1954, 1955, 1956, 1957, 1958, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 2051, 2052, 2099, 2100, 2123, 2215, 2216, 2217, 2218, 2219, 2220, 2221, 2363, 2375, 2376, 2377, 2378, 2379, 2381, 2382, 2383, 2384, 2396, 2399, 2400, 2401, 2410, 2411, 2412, 2413, 2414, 2415, 2422, 2423, 2424, 2425, 2426, 2427, 2428, 2429, 2430, 2431, 2432, 2433, 2434, 2435, 2436, 2483, 2555, 2600, 2601, 2602, 2603, 2604, 2673, 2674, 2675, 2676, 2699, 2792, 2793, 2794, 2795, 2796, 2797, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892, 2915, 2927, 2950, 2951, 2952, 2953, 2954, 2955, 2956, 2958, 2973, 2974, 2975, 2976, 2977, 2978, 3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013, 3025, 3026, 3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035, 3036, 3155, 3179, 3202, 3203, 3204, 3205, 3206, 3220, 3221, 3222, 3223, 3224, 3225, 3226, 3227, 3228, 3275, 3298, 3299, 3300, 3301, 3323, 3324, 3342, 3343, 3344, 3345, 3346, 3347, 3348, 3371, 3407, 3408, 3409, 3410, 3411, 3412, 3414, 3431, 3432, 3443, 3444, 3458, 3459, 3460, 3461, 3462, 3463, 3464, 3465, 3466, 3467, 3468, 3469, 3486, 3487, 3488, 3489, 3490, 3491, 3492, 3587, 3657, 3658, 3659, 3660, 3683, 3707, 3728, 3729, 3730, 3731, 3732, 3779, 3850, 3851, 3852, 3871, 3872, 3873, 3874, 3875, 3876, 3947, 3970, 3971, 3995, 4061, 4062, 4063, 4064, 4065, 4066, 4067, 4068, 4085, 4086, 4087, 4088, 4089, 4090, 4091, 4092, 4139, 4162, 416 ...
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           13 0.8591     0.000110
# discharge         18           37 0.6750     0.000071
# discharge         44           63 0.9951     0.000143
# discharge         69           85 0.1643     0.000006
# discharge         90          111 0.2202     0.000010
# discharge        112          133 0.8073     0.000098
# discharge        140          158 0.3564     0.000023
# discharge        164          181 0.9910     0.000142
# discharge        188          205 0.6933     0.000075
# discharge        212          228 0.5262     0.000046
# discharge        234          254 0.9773     0.000138
# discharge        260          279 0.9858     0.000140
# discharge        285          300 0.8945     0.000118
# discharge        305          324 0.8115     0.000099
# discharge        331          350 0.8606     0.000110
# discharge        357          373 0.3317     0.000020
# discharge        378          396 0.9880     0.000141
# discharge        401          444 1.0000     0.000144
# discharge        449          468 0.9662     0.000135
# discharge        473          492 0.9848     0.000140
# discharge        498          516 0.6941     0.000075
# discharge        523          543 0.0367     0.000000
# discharge        547          568 0.0651     0.000001
# discharge        570          594 0.8998     0.000119
# discharge        597          614 0.0577     0.000001
# discharge        621          637 0.9740     0.000137
# discharge        638          641 0.0503     0.000001
# discharge        642          643 0.0072     0.000000
# discharge        644          661 0.0202     0.000000
# discharge        668          685 0.9948     0.000143
# discharge        691          710 0.9892     0.000141
# discharge        715          732 0.9499     0.000131
# discharge        738          756 0.9892     0.000141
# discharge        764          780 0.9736     0.000137
# discharge        786          805 0.4026     0.000028
# discharge        811          853 0.9725     0.000137
# discharge        858          876 0.9216     0.000124
# discharge        881          901 0.9098     0.000122
# discharge        908          924 0.9363     0.000128
# discharge        933          950 0.1494     0.000005
# discharge        956          975 0.9410     0.000129
# discharge        978          997 0.0356     0.000000
# discharge       1002         1022 0.9876     0.000141
# discharge       1027         1045 0.2579     0.000013
# discharge       1050         1068 0.9777     0.000138
# discharge       1073         1092 0.9433     0.000130
# discharge       1098         1118 0.9974     0.000143
# discharge       1125         1140 0.1469     0.000005
# discharge       1145         1164 0.9872     0.000141
# discharge       1169         1188 0.9820     0.000139
# discharge       1193         1212 0.9745     0.000137
# discharge       1218         1236 0.9667     0.000136
# discharge       1243         1262 0.8756     0.000114
# discharge       1269         1284 0.4413     0.000033
# discharge       1290         1308 0.8684     0.000112
# discharge       1313         1333 0.9632     0.000135
# discharge       1340         1356 0.8318     0.000104
# discharge       1361         1380 0.8396     0.000105
# discharge       1386         1405 0.9044     0.000120
# discharge       1411         1429 0.9913     0.000142
# discharge       1437         1452 0.9498     0.000131
# discharge       1460         1477 0.8491     0.000107
# discharge       1483         1500 0.9533     0.000132
# discharge       1506         1524 0.9153     0.000123
# discharge       1531         1550 0.9943     0.000143
# discharge       1556         1572 0.2723     0.000014
# discharge       1579         1597 0.8064     0.000098
# discharge       1605         1623 0.7836     0.000093
# discharge       1630         1645 0.2809     0.000015
# discharge       1654         1668 0.8371     0.000105
# discharge       1673         1692 0.9868     0.000141
# discharge       1698         1716 0.9722     0.000137
# discharge       1722         1740 0.9211     0.000124
# discharge       1746         1764 0.7558     0.000087
# discharge       1773         1791 0.8159     0.000100
# discharge       1796         1812 0.1022     0.000002
# discharge       1818         1836 0.9855     0.000140
# discharge       1845         1860 0.9093     0.000121
# discharge       1865         1884 0.9809     0.000139
# discharge       1889         1908 0.8613     0.000110
# discharge       1913         1932 0.7345     0.000083
# discharge       1942         1958 0.9651     0.000135
# discharge       1962         1980 0.0514     0.000001
# discharge       1985         2005 0.9503     0.000131
# discharge       2012         2029 0.8673     0.000112
# discharge       2036         2052 0.9772     0.000138
# discharge       2058         2076 0.9157     0.000123
# discharge       2081         2100 0.9750     0.000138
# discharge       2105         2124 0.9730     0.000137
# discharge       2129         2148 0.8544     0.000109
# discharge       2153         2172 0.8956     0.000118
# discharge       2179         2197 0.9092     0.000121
# discharge       2205         2221 0.5719     0.000053
# discharge       2230         2244 0.8411     0.000106
# discharge       2249         2268 0.8312     0.000103
# discharge       2273         2292 0.8885     0.000117
# discharge       2297         2316 0.9341     0.000127
# discharge       2322         2340 0.8597     0.000110
# discharge       2346         2364 0.9668     0.000136
# discharge       2372         2389 0.3540     0.000022
# discharge       2395         2415 0.8208     0.000101
# discharge       2420         2436 0.0889     0.000002
# discharge       2446         2460 0.7580     0.000088
# discharge       2464         2484 0.9591     0.000134
# discharge       2490         2508 0.8139     0.000100
# discharge       2513         2532 0.8499     0.000108
# discharge       2538         2556 0.9599     0.000134
# discharge       2562         2580 0.8306     0.000103
# discharge       2590         2604 0.7719     0.000091
# discharge       2611         2628 0.8712     0.000113
# discharge       2634         2652 0.9162     0.000123
# discharge       2660         2676 0.8501     0.000108
# discharge       2682         2700 0.9608     0.000134
# discharge       2705         2724 0.8644     0.000111
# discharge       2729         2748 0.8829     0.000115
# discharge       2756         2772 0.8744     0.000113
# discharge       2780         2797 0.8209     0.000101
# discharge       2804         2820 0.8266     0.000102
# discharge       2829         2844 0.7867     0.000094
# discharge       2849         2870 0.8862     0.000116
# discharge       2876         2892 0.6354     0.000064
# discharge       2898         2916 0.9516     0.000132
# discharge       2922         2940 0.9118     0.000122
# discharge       2949         2964 0.5123     0.000043
# discharge       2972         2988 0.8497     0.000108
# discharge       2997         3013 0.6202     0.000061
# discharge       3021         3036 0.2996     0.000017
# discharge       3042         3060 0.8590     0.000110
# discharge       3066         3085 0.8500     0.000108
# discharge       3091         3108 0.8621     0.000110
# discharge       3114         3132 0.8848     0.000116
# discharge       3137         3156 0.9722     0.000137
# discharge       3162         3180 0.9740     0.000137
# discharge       3187         3206 0.9972     0.000143
# discharge       3213         3228 0.4456     0.000034
# discharge       3234         3252 0.9065     0.000121
# discharge       3258         3276 0.9674     0.000136
# discharge       3282         3301 0.9937     0.000142
# discharge       3307         3325 0.9798     0.000139
# discharge       3334         3348 0.5991     0.000058
# discharge       3354         3372 0.9496     0.000131
# discharge       3379         3396 0.8962     0.000118
# discharge       3401         3421 0.4634     0.000036
# discharge       3429         3445 0.8608     0.000110
# discharge       3452         3469 0.3776     0.000025
# discharge       3478         3492 0.5644     0.000052
# discharge       3499         3516 0.9041     0.000120
# discharge       3522         3540 0.7725     0.000091
# discharge       3545         3564 0.9374     0.000128
# discharge       3570         3588 0.9603     0.000134
# discharge       3594         3611 0.9038     0.000120
# discharge       3618         3637 0.9495     0.000131
# discharge       3645         3660 0.7770     0.000092
# discharge       3667         3684 0.9660     0.000135
# discharge       3690         3708 0.9625     0.000134
# discharge       3718         3732 0.6832     0.000073
# discharge       3739         3756 0.8936     0.000118
# discharge       3762         3780 0.9676     0.000136
# discharge       3786         3804 0.8718     0.000113
# discharge       3809         3827 0.9426     0.000130
# discharge       3838         3852 0.8057     0.000098
# discharge       3861         3876 0.6537     0.000067
# discharge       3882         3900 0.8592     0.000110
# discharge       3905         3924 0.9385     0.000129
# discharge       3931         3948 0.9643     0.000135
# discharge       3954         3972 0.9704     0.000136
# discharge       3979         3996 0.9752     0.000138
# discharge       4004         4020 0.9502     0.000131
# discharge       4026         4044 0.9166     0.000123
# discharge       4054         4068 0.5416     0.000048
# discharge       4077         4092 0.5165     0.000044
# discharge       4101         4116 0.8933     0.000118
# discharge       4122         4140 0.9485     0.000131
# discharge       4147         4164 0.9740     0.000137
# discharge       4170         4188 0.9069     0.000121
# discharge       4194         4212 0.9728     0.000137
# discharge       4219         4236 0.9655     0.000135
# discharge       4244         4260 0.9707     0.000137
# discharge       4268         4283 0.8704     0.000112
# discharge       4290         4308 0.9226     0.000125
# discharge       4315         4332 0.9498     0.000131
# discharge       4339         4356 0.9279     0.000126
# discharge       4364         4379 0.8648     0.000111
# discharge       4386         4404 0.8853     0.000116
# discharge       4410         4428 0.9437     0.000130
# discharge       4434         4452 0.9184     0.000124
# discharge       4458         4476 0.9295     0.000126
# discharge       4484         4500 0.9346     0.000128
# discharge       4507         4524 0.9453     0.000130
# discharge       4530         4548 0.9864     0.000141
# discharge       4557         4571 0.5621     0.000051
# discharge       4579         4596 0.8907     0.000117
# discharge       4602         4620 0.9721     0.000137
# discharge       4626         4644 0.9715     0.000137
# discharge       4651         4668 0.9724     0.000137
# discharge       4676         4692 0.9854     0.000140
# discharge       4699         4716 0.9522     0.000132
# discharge       4724         4740 0.9484     0.000131
# discharge       4746         4765 0.9847     0.000140
# discharge       4774         4788 0.5481     0.000049
# discharge       4795         4812 0.8507     0.000108
# discharge       4818         4836 0.9532     0.000132
# discharge       4843         4860 0.9723     0.000137
# discharge       4867         4884 0.9741     0.000137
# discharge       4892         4911 0.0464     0.000001
# discharge       4917         4933 0.4810     0.000039
# discharge       4941         4957 0.4772     0.000038
# discharge       4965         4981 0.3153     0.000018
# discharge       4989         5005 0.9398     0.000129
# discharge       5013         5028 0.3211     0.000019
# discharge       5038         5052 0.6297     0.000063
# discharge       5058         5076 0.9268     0.000126
# discharge       5082         5100 0.9438     0.000130
# discharge       5106         5124 0.9002     0.000119
# discharge       5130         5148 0.9301     0.000126
# discharge       5154         5172 0.9641     0.000135
# discharge       5178         5196 0.9674     0.000136
# discharge       5202         5220 0.9570     0.000133
# discharge       5226         5244 0.9758     0.000138
# discharge       5250         5268 0.9402     0.000129
# discharge       5274         5292 0.9306     0.000127
# discharge       5298         5316 0.9040     0.000120
# discharge       5322         5340 0.8934     0.000118
# discharge       5346         5364 0.9732     0.000137
# discharge       5371         5388 0.9777     0.000138
# discharge       5397         5412 0.9000     0.000119
# discharge       5419         5436 0.9855     0.000140
# discharge       5443         5460 0.9795     0.000139
# discharge       5467         5484 0.9489     0.000131
# discharge       5492         5509 0.9916     0.000142
# discharge       5515         5532 0.9823     0.000139
# discharge       5538         5556 0.9401     0.000129
# discharge       5562         5580 0.9116     0.000122
# discharge       5586         5604 0.8962     0.000118
# discharge       5609         5628 0.8936     0.000118
# discharge       5634         5652 0.9417     0.000129
# discharge       5658         5676 0.9586     0.000134
# discharge       5683         5700 0.9581     0.000133
# discharge       5706         5724 0.9804     0.000139
# discharge       5730         5748 0.9851     0.000140
# discharge       5754         5772 0.9866     0.000141
# discharge       5778         5796 0.9281     0.000126
# discharge       5805         5820 0.9594     0.000134
# discharge       5828         5845 0.6514     0.000067
# discharge       5854         5869 0.9387     0.000129
# discharge       5878         5892 0.6297     0.000063
# discharge       5898         5916 0.8900     0.000117
# discharge       5922         5941 0.9859     0.000140
# discharge       5948         5964 0.4167     0.000030
# discharge       5970         5988 0.9860     0.000140
# discharge       5995         6012 0.9334     0.000127
# discharge       6017         6036 0.8560     0.000109
# discharge       6041         6060 0.8769     0.000114
# discharge       6065         6084 0.9314     0.000127
# discharge       6090         6108 0.9792     0.000139
# discharge       6114         6134 0.2465     0.000012
# discharge       6140         6157 0.4539     0.000035
# discharge       6164         6180 0.4630     0.000036
# discharge       6190         6205 0.6181     0.000061
# discharge       6212         6230 0.6529     0.000067
# discharge       6237         6252 0.1617     0.000006
# discharge       6258         6276 0.9826     0.000140
# discharge       6282         6300 0.9860     0.000140
# discharge       6306         6324 0.9866     0.000141
# discharge       6330         6349 0.9911     0.000142
# discharge       6358         6372 0.4951     0.000041
# discharge       6379         6397 0.9913     0.000142
# discharge       6404         6422 0.5401     0.000048
# discharge       6429         6445 0.9898     0.000141
# discharge       6451         6468 0.9698     0.000136
# discharge       6474         6492 0.8703     0.000112
# discharge       6500         6517 0.6033     0.000058
# discharge       6525         6541 0.8021     0.000097
# discharge       6549         6564 0.8415     0.000106
# discharge       6570         6588 0.9876     0.000141
# discharge       6594         6612 0.8957     0.000118
# discharge       6617         6636 0.9850     0.000140
# discharge       6642         6660 0.9774     0.000138
# discharge       6666         6684 0.9771     0.000138
# discharge       6690         6708 0.9873     0.000141
# discharge       6714         6732 0.9634     0.000135
# discharge       6738         6756 0.9082     0.000121
# discharge       6761         6780 0.9510     0.000132
# discharge       6786         6804 0.9510     0.000132
# discharge       6810         6828 0.9850     0.000140
# discharge       6834         6852 0.9842     0.000140
# discharge       6858         6876 0.8934     0.000118
# discharge       6882         6900 0.9298     0.000126
# discharge       6905         6924 0.9850     0.000140
# discharge       6930         6948 0.9302     0.000127
# discharge       6953         6972 0.9782     0.000138
# discharge       6978         6996 0.9784     0.000138
# discharge       7002         7020 0.9762     0.000138
# discharge       7026         7044 0.9855     0.000140
# discharge       7050         7068 0.9856     0.000140
# discharge       7074         7092 0.9706     0.000137
# discharge       7098         7116 0.8998     0.000119
# discharge       7122         7140 0.9683     0.000136
# discharge       7146         7164 0.9578     0.000133
# discharge       7170         7189 0.9885     0.000141
# discharge       7196         7212 0.5231     0.000045
# discharge       7218         7236 0.9704     0.000136
# discharge       7242         7260 0.8818     0.000115
# discharge       7266         7284 0.8712     0.000112
# discharge       7290         7309 0.8510     0.000108
# discharge       7314         7333 0.4416     0.000033
# discharge       7340         7357 0.9882     0.000141
# discharge       7365         7381 0.9676     0.000136
# discharge       7389         7406 0.9717     0.000137
# discharge       7412         7429 0.8290     0.000103
# discharge       7434         7453 0.9930     0.000142
# discharge       7461         7477 0.3322     0.000020
# discharge       7484         7501 0.9824     0.000139
# discharge       7507         7525 0.4135     0.000030
# discharge       7531         7551 0.6874     0.000074
# discharge       7557         7572 0.4535     0.000035
# discharge       7578         7597 0.9739     0.000137
# discharge       7602         7624 0.9957     0.000143
# discharge       7626         7644 0.0438     0.000001
# discharge       7650         7669 0.9928     0.000142
# discharge       7674         7693 0.9859     0.000140
# discharge       7699         7717 0.9799     0.000139
# discharge       7725         7741 0.9734     0.000137
# discharge       7748         7765 0.9635     0.000135
# discharge       7770         7788 0.9638     0.000135
# discharge       7794         7812 0.8490     0.000107
# discharge       7817         7837 0.9065     0.000121
# discharge       7842         7861 0.9938     0.000142
# discharge       7867         7884 0.9712     0.000137
# discharge       7890         7909 0.8378     0.000105
# discharge       7916         7932 0.9578     0.000133
# discharge       7938         7959 0.9976     0.000143
# discharge       7964         7981 0.2028     0.000008
# discharge       7986         8005 0.9697     0.000136
# discharge       8010         8029 0.9944     0.000143
# discharge       8034         8054 0.9948     0.000143
# discharge       8061         8077 0.9935     0.000142
# discharge       8082         8100 0.9592     0.000134
# discharge       8106         8125 0.9775     0.000138
# discharge       8131         8148 0.9455     0.000130
# discharge       8154         8173 0.9739     0.000137
# discharge       8178         8197 0.9943     0.000143
# discharge       8202         8223 0.9796     0.000139
# discharge       8225         8246 0.0792     0.000002
# discharge       8253         8269 0.9959     0.000143
# discharge       8277         8293 0.8521     0.000108
# discharge       8298         8316 0.9782     0.000138
# discharge       8322         8344 0.6145     0.000060
# discharge       8349         8365 0.4418     0.000033
# discharge       8368         8370 0.0200     0.000000
# discharge       8372         8389 0.6573     0.000068
# discharge       8396         8414 0.1109     0.000003
# discharge       8418         8438 0.4913     0.000040
# discharge       8444         8464 0.8911     0.000117
# discharge       8469         8485 0.1732     0.000006
# discharge       8490         8509 0.9600     0.000134
# discharge       8514         8533 0.9844     0.000140
# discharge       8538         8557 0.9934     0.000142
# discharge       8562         8581 0.9861     0.000140
# discharge       8586         8606 0.4823     0.000039
# discharge       8611         8631 0.3215     0.000019
# discharge       8635         8654 0.8158     0.000100
# discharge       8661         8677 0.2869     0.000015
# discharge       8684         8701 0.9678     0.000136
# discharge       8703         8725 0.0678     0.000001
# discharge       8732         8749 0.9858     0.000140
#
# Total Estimated Degradation: 0.038859
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_data_1986.csv
# ...
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 194150250.27 kWh
# Year 2023: Unmet Load = 182782703.63 kWh
# Year 2022: Unmet Load = 160370609.04 kWh
# Year 2021: Unmet Load = 170264935.57 kWh
# Year 2020: Unmet Load = 205252435.60 kWh
# Year 2019: Unmet Load = 238176080.97 kWh
# Year 2018: Unmet Load = 224094820.35 kWh
# Year 2017: Unmet Load = 194428235.94 kWh
# Year 2016: Unmet Load = 182579646.65 kWh
# Year 2015: Unmet Load = 215205758.97 kWh
# Year 2014: Unmet Load = 178533507.48 kWh
# Year 2013: Unmet Load = 199307613.61 kWh
# Year 2012: Unmet Load = 173114411.91 kWh
# Year 2011: Unmet Load = 176107359.95 kWh
# Year 2010: Unmet Load = 167974804.78 kWh
# Year 2009: Unmet Load = 200903391.70 kWh
# Year 2008: Unmet Load = 161585281.48 kWh
# Year 2007: Unmet Load = 170434351.96 kWh
# Year 2006: Unmet Load = 162054229.13 kWh
# Year 2005: Unmet Load = 150395167.48 kWh
# Year 2004: Unmet Load = 188200183.29 kWh
# Year 2003: Unmet Load = 179659479.22 kWh
# Year 2002: Unmet Load = 191009628.38 kWh
# Year 2001: Unmet Load = 171662961.99 kWh
# Year 2000: Unmet Load = 163984820.19 kWh
# Year 1999: Unmet Load = 136895669.87 kWh
# Year 1998: Unmet Load = 193874745.26 kWh
# Year 1997: Unmet Load = 188739328.50 kWh
# Year 1996: Unmet Load = 161076236.72 kWh
# Year 1995: Unmet Load = 147163219.88 kWh
# Year 1994: Unmet Load = 223953657.28 kWh
# Year 1993: Unmet Load = 226184307.87 kWh
# Year 1992: Unmet Load = 220889315.82 kWh
# Year 1991: Unmet Load = 263644404.63 kWh
# Year 1990: Unmet Load = 193397450.80 kWh
# Year 1989: Unmet Load = 201640040.66 kWh
# Year 1988: Unmet Load = 143717359.69 kWh
# Year 1987: Unmet Load = 207439094.66 kWh
# Year 1986: Unmet Load = 209521689.97 kWh
# Year 1985: Unmet Load = 181784198.74 kWh
# Year 1984: Unmet Load = 172222526.29 kWh
# Year 1983: Unmet Load = 202171950.56 kWh
# Year 1982: Unmet Load = 206439306.24 kWh
# Year 1981: Unmet Load = 170301395.19 kWh
# Year 1980: Unmet Load = 169397440.26 kWh
#
# Average Unmet Load (1979-2024): 187170800.19 kWh
# Min Unmet Load: 136895669.87 kWh (Year 1999)
# Max Unmet Load: 263644404.63 kWh (Year 1991)
# Starting capacity, cost, and utilization metrics collection...
# Processing year 2024 for capacity, cost, and utilization metrics...
# Year 2024: Dispatch simulation successful, calculating metrics...
# $48368599.98 is the replacement cost each year for degradation
# Year 2024: Metrics added - Utilization: 79.55%, NPC: 2910675607.30, Unmet: 194150250.27 kWh
# Processing year 2023 for capacity, cost, and utilization metrics...
# Year 2023: Dispatch simulation successful, calculating metrics...
# $49088505.99 is the replacement cost each year for degradation
# Year 2023: Metrics added - Utilization: 80.31%, NPC: 2919822536.93, Unmet: 182782703.63 kWh
# Processing year 2022 for capacity, cost, and utilization metrics...
# Year 2022: Dispatch simulation successful, calculating metrics...
# $50256973.75 is the replacement cost each year for degradation
# Year 2022: Metrics added - Utilization: 78.10%, NPC: 2934668769.87, Unmet: 160370609.04 kWh
# Processing year 2021 for capacity, cost, and utilization metrics...
# Year 2021: Dispatch simulation successful, calculating metrics...
# $49700345.04 is the replacement cost each year for degradation
# Year 2021: Metrics added - Utilization: 81.24%, NPC: 2927596397.12, Unmet: 170264935.57 kWh
# Processing year 2020 for capacity, cost, and utilization metrics...
# Year 2020: Dispatch simulation successful, calculating metrics...
# $47973671.75 is the replacement cost each year for degradation
# Year 2020: Metrics added - Utilization: 81.04%, NPC: 2905657756.83, Unmet: 205252435.60 kWh
# Processing year 2019 for capacity, cost, and utilization metrics...
# Year 2019: Dispatch simulation successful, calculating metrics...
# $46792901.58 is the replacement cost each year for degradation
# Year 2019: Metrics added - Utilization: 80.92%, NPC: 2890655212.94, Unmet: 238176080.97 kWh
# Processing year 2018 for capacity, cost, and utilization metrics...
# Year 2018: Dispatch simulation successful, calculating metrics...
# $46745677.85 is the replacement cost each year for degradation
# Year 2018: Metrics added - Utilization: 81.78%, NPC: 2890055201.07, Unmet: 224094820.35 kWh
# Processing year 2017 for capacity, cost, and utilization metrics...
# Year 2017: Dispatch simulation successful, calculating metrics...
# $48480476.32 is the replacement cost each year for degradation
# Year 2017: Metrics added - Utilization: 80.05%, NPC: 2912097077.62, Unmet: 194428235.94 kWh
# Processing year 2016 for capacity, cost, and utilization metrics...
# Year 2016: Dispatch simulation successful, calculating metrics...
# $49309388.57 is the replacement cost each year for degradation
# Year 2016: Metrics added - Utilization: 80.47%, NPC: 2922629010.80, Unmet: 182579646.65 kWh
# Processing year 2015 for capacity, cost, and utilization metrics...
# Year 2015: Dispatch simulation successful, calculating metrics...
# $47351742.16 is the replacement cost each year for degradation
# Year 2015: Metrics added - Utilization: 81.26%, NPC: 2897755689.05, Unmet: 215205758.97 kWh
# Processing year 2014 for capacity, cost, and utilization metrics...
# Year 2014: Dispatch simulation successful, calculating metrics...
# $49242475.21 is the replacement cost each year for degradation
# Year 2014: Metrics added - Utilization: 79.44%, NPC: 2921778827.92, Unmet: 178533507.48 kWh
# Processing year 2013 for capacity, cost, and utilization metrics...
# Year 2013: Dispatch simulation successful, calculating metrics...
# $48254997.25 is the replacement cost each year for degradation
# Year 2013: Metrics added - Utilization: 79.69%, NPC: 2909232202.09, Unmet: 199307613.61 kWh
# Processing year 2012 for capacity, cost, and utilization metrics...
# Year 2012: Dispatch simulation successful, calculating metrics...
# $48647459.88 is the replacement cost each year for degradation
# Year 2012: Metrics added - Utilization: 79.26%, NPC: 2914218725.27, Unmet: 173114411.91 kWh
# Processing year 2011 for capacity, cost, and utilization metrics...
# Year 2011: Dispatch simulation successful, calculating metrics...
# $48434667.41 is the replacement cost each year for degradation
# Year 2011: Metrics added - Utilization: 79.77%, NPC: 2911515042.09, Unmet: 176107359.95 kWh
# Processing year 2010 for capacity, cost, and utilization metrics...
# Year 2010: Dispatch simulation successful, calculating metrics...
# $50209031.68 is the replacement cost each year for degradation
# Year 2010: Metrics added - Utilization: 79.40%, NPC: 2934059631.05, Unmet: 167974804.78 kWh
# Processing year 2009 for capacity, cost, and utilization metrics...
# Year 2009: Dispatch simulation successful, calculating metrics...
# $47751768.19 is the replacement cost each year for degradation
# Year 2009: Metrics added - Utilization: 80.46%, NPC: 2902838310.68, Unmet: 200903391.70 kWh
# Processing year 2008 for capacity, cost, and utilization metrics...
# Year 2008: Dispatch simulation successful, calculating metrics...
# $49486586.28 is the replacement cost each year for degradation
# Year 2008: Metrics added - Utilization: 78.38%, NPC: 2924880436.65, Unmet: 161585281.48 kWh
# Processing year 2007 for capacity, cost, and utilization metrics...
# Year 2007: Dispatch simulation successful, calculating metrics...
# $50539993.62 is the replacement cost each year for degradation
# Year 2007: Metrics added - Utilization: 79.00%, NPC: 2938264743.18, Unmet: 170434351.96 kWh
# Processing year 2006 for capacity, cost, and utilization metrics...
# Year 2006: Dispatch simulation successful, calculating metrics...
# $49857884.25 is the replacement cost each year for degradation
# Year 2006: Metrics added - Utilization: 78.39%, NPC: 2929598047.44, Unmet: 162054229.13 kWh
# Processing year 2005 for capacity, cost, and utilization metrics...
# Year 2005: Dispatch simulation successful, calculating metrics...
# $51757909.17 is the replacement cost each year for degradation
# Year 2005: Metrics added - Utilization: 78.60%, NPC: 2953739246.30, Unmet: 150395167.48 kWh
# Processing year 2004 for capacity, cost, and utilization metrics...
# Year 2004: Dispatch simulation successful, calculating metrics...
# $47910922.55 is the replacement cost each year for degradation
# Year 2004: Metrics added - Utilization: 80.05%, NPC: 2904860482.64, Unmet: 188200183.29 kWh
# Processing year 2003 for capacity, cost, and utilization metrics...
# Year 2003: Dispatch simulation successful, calculating metrics...
# $48561846.07 is the replacement cost each year for degradation
# Year 2003: Metrics added - Utilization: 79.14%, NPC: 2913130939.53, Unmet: 179659479.22 kWh
# Processing year 2002 for capacity, cost, and utilization metrics...
# Year 2002: Dispatch simulation successful, calculating metrics...
# $48162671.07 is the replacement cost each year for degradation
# Year 2002: Metrics added - Utilization: 79.13%, NPC: 2908059130.71, Unmet: 191009628.38 kWh
# Processing year 2001 for capacity, cost, and utilization metrics...
# Year 2001: Dispatch simulation successful, calculating metrics...
# $50137984.68 is the replacement cost each year for degradation
# Year 2001: Metrics added - Utilization: 78.27%, NPC: 2933156927.18, Unmet: 171662961.99 kWh
# Processing year 2000 for capacity, cost, and utilization metrics...
# Year 2000: Dispatch simulation successful, calculating metrics...
# $49509667.62 is the replacement cost each year for degradation
# Year 2000: Metrics added - Utilization: 77.31%, NPC: 2925173701.84, Unmet: 163984820.19 kWh
# Processing year 1999 for capacity, cost, and utilization metrics...
# Year 1999: Dispatch simulation successful, calculating metrics...
# $50519606.57 is the replacement cost each year for degradation
# Year 1999: Metrics added - Utilization: 77.51%, NPC: 2938005710.94, Unmet: 136895669.87 kWh
# Processing year 1998 for capacity, cost, and utilization metrics...
# Year 1998: Dispatch simulation successful, calculating metrics...
# $47840065.65 is the replacement cost each year for degradation
# Year 1998: Metrics added - Utilization: 79.20%, NPC: 2903960194.22, Unmet: 193874745.26 kWh
# Processing year 1997 for capacity, cost, and utilization metrics...
# Year 1997: Dispatch simulation successful, calculating metrics...
# $49155416.79 is the replacement cost each year for degradation
# Year 1997: Metrics added - Utilization: 79.60%, NPC: 2920672687.34, Unmet: 188739328.50 kWh
# Processing year 1996 for capacity, cost, and utilization metrics...
# Year 1996: Dispatch simulation successful, calculating metrics...
# $49672023.78 is the replacement cost each year for degradation
# Year 1996: Metrics added - Utilization: 78.61%, NPC: 2927236554.93, Unmet: 161076236.72 kWh
# Processing year 1995 for capacity, cost, and utilization metrics...
# Year 1995: Dispatch simulation successful, calculating metrics...
# $50854024.62 is the replacement cost each year for degradation
# Year 1995: Metrics added - Utilization: 78.54%, NPC: 2942254735.50, Unmet: 147163219.88 kWh
# Processing year 1994 for capacity, cost, and utilization metrics...
# Year 1994: Dispatch simulation successful, calculating metrics...
# $47042969.96 is the replacement cost each year for degradation
# Year 1994: Metrics added - Utilization: 79.93%, NPC: 2893832513.52, Unmet: 223953657.28 kWh
# Processing year 1993 for capacity, cost, and utilization metrics...
# Year 1993: Dispatch simulation successful, calculating metrics...
# $46694609.42 is the replacement cost each year for degradation
# Year 1993: Metrics added - Utilization: 81.60%, NPC: 2889406339.54, Unmet: 226184307.87 kWh
# Processing year 1992 for capacity, cost, and utilization metrics...
# Year 1992: Dispatch simulation successful, calculating metrics...
# $46511188.74 is the replacement cost each year for degradation
# Year 1992: Metrics added - Utilization: 80.86%, NPC: 2887075846.31, Unmet: 220889315.82 kWh
# Processing year 1991 for capacity, cost, and utilization metrics...
# Year 1991: Dispatch simulation successful, calculating metrics...
# $44150559.41 is the replacement cost each year for degradation
# Year 1991: Metrics added - Utilization: 83.20%, NPC: 2857082333.39, Unmet: 263644404.63 kWh
# Processing year 1990 for capacity, cost, and utilization metrics...
# Year 1990: Dispatch simulation successful, calculating metrics...
# $47539803.90 is the replacement cost each year for degradation
# Year 1990: Metrics added - Utilization: 79.40%, NPC: 2900145150.28, Unmet: 193397450.80 kWh
# Processing year 1989 for capacity, cost, and utilization metrics...
# Year 1989: Dispatch simulation successful, calculating metrics...
# $46953212.07 is the replacement cost each year for degradation
# Year 1989: Metrics added - Utilization: 80.58%, NPC: 2892692074.35, Unmet: 201640040.66 kWh
# Processing year 1988 for capacity, cost, and utilization metrics...
# Year 1988: Dispatch simulation successful, calculating metrics...
# $50591958.70 is the replacement cost each year for degradation
# Year 1988: Metrics added - Utilization: 77.20%, NPC: 2938924997.36, Unmet: 143717359.69 kWh
# Processing year 1987 for capacity, cost, and utilization metrics...
# Year 1987: Dispatch simulation successful, calculating metrics...
# $48087046.63 is the replacement cost each year for degradation
# Year 1987: Metrics added - Utilization: 80.31%, NPC: 2907098267.16, Unmet: 207439094.66 kWh
# Processing year 1986 for capacity, cost, and utilization metrics...
# Year 1986: Dispatch simulation successful, calculating metrics...
# $47843992.72 is the replacement cost each year for degradation
# Year 1986: Metrics added - Utilization: 79.72%, NPC: 2904010090.48, Unmet: 209521689.97 kWh
# Processing year 1985 for capacity, cost, and utilization metrics...
# Year 1985: Dispatch simulation successful, calculating metrics...
# $49297332.15 is the replacement cost each year for degradation
# Year 1985: Metrics added - Utilization: 79.70%, NPC: 2922475825.23, Unmet: 181784199.17 kWh
# Processing year 1984 for capacity, cost, and utilization metrics...
# Year 1984: Dispatch simulation successful, calculating metrics...
# $49420796.34 is the replacement cost each year for degradation
# Year 1984: Metrics added - Utilization: 80.41%, NPC: 2924044527.58, Unmet: 172222526.29 kWh
# Processing year 1983 for capacity, cost, and utilization metrics...
# Year 1983: Dispatch simulation successful, calculating metrics...
# $48757473.35 is the replacement cost each year for degradation
# Year 1983: Metrics added - Utilization: 81.28%, NPC: 2915616526.43, Unmet: 202171950.56 kWh
# Processing year 1982 for capacity, cost, and utilization metrics...
# Year 1982: Dispatch simulation successful, calculating metrics...
# $47943636.51 is the replacement cost each year for degradation
# Year 1982: Metrics added - Utilization: 81.13%, NPC: 2905276137.36, Unmet: 206439306.24 kWh
# Processing year 1981 for capacity, cost, and utilization metrics...
# Year 1981: Dispatch simulation successful, calculating metrics...
# $50861546.26 is the replacement cost each year for degradation
# Year 1981: Metrics added - Utilization: 78.84%, NPC: 2942350303.40, Unmet: 170301395.19 kWh
# Processing year 1980 for capacity, cost, and utilization metrics...
# Year 1980: Dispatch simulation successful, calculating metrics...
# $49873246.47 is the replacement cost each year for degradation
# Year 1980: Metrics added - Utilization: 77.89%, NPC: 2929793235.62, Unmet: 169397440.26 kWh
# Saved capacity, cost, and utilization metrics to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\capacity_and_costs_by_year.csv
# CSV file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\capacity_and_costs_by_year.csv
# Starting NPC variation plotting...
# Saved NPC variation plot to dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\npc_variation_by_year.png
# Plot file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment\npc_variation_by_year.png

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
        )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year 90% met Load Sizing (Hybrid Configuration)")
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")

# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 911.65 hours
# 1980: 824.65 extra training hours
# 1981: 820.77 extra training hours
# 1982: 1024.02 extra training hours
# 1983: 968.28 extra training hours
# 1984: 848.51 extra training hours
# 1985: 883.72 extra training hours
# 1986: 1015.21 extra training hours
# 1987: 1010.70 extra training hours
# 1988: 698.06 extra training hours
# 1989: 974.79 extra training hours
# 1990: 955.14 extra training hours
# 1991: 1298.92 extra training hours
# 1992: 1067.75 extra training hours
# 1993: 1111.84 extra training hours
# 1994: 1093.60 extra training hours
# 1995: 720.85 extra training hours
# 1996: 778.93 extra training hours
# 1997: 919.87 extra training hours
# 1998: 950.00 extra training hours
# 1999: 666.26 extra training hours
# 2000: 795.35 extra training hours
# 2001: 827.58 extra training hours
# 2002: 933.94 extra training hours
# 2003: 877.02 extra training hours
# 2004: 918.74 extra training hours
# 2005: 722.25 extra training hours
# 2006: 786.90 extra training hours
# 2007: 818.90 extra training hours
# 2008: 776.95 extra training hours
# 2009: 984.36 extra training hours
# 2010: 814.24 extra training hours
# 2011: 866.27 extra training hours
# 2012: 860.42 extra training hours
# 2013: 972.49 extra training hours
# 2014: 869.45 extra training hours
# 2015: 1055.52 extra training hours
# 2016: 876.44 extra training hours
# 2017: 944.11 extra training hours
# 2018: 1113.88 extra training hours
# 2019: 1163.08 extra training hours
# 2020: 989.29 extra training hours
# 2021: 816.34 extra training hours
# 2022: 771.09 extra training hours
# 2023: 885.69 extra training hours
# 2024: 952.26 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 1250 hours with unmet load
# 1981: 1254 hours with unmet load
# 1982: 1531 hours with unmet load
# 1983: 1479 hours with unmet load
# 1984: 1293 hours with unmet load
# 1985: 1354 hours with unmet load
# 1986: 1464 hours with unmet load
# 1987: 1524 hours with unmet load
# 1988: 1104 hours with unmet load
# 1989: 1443 hours with unmet load
# 1990: 1401 hours with unmet load
# 1991: 1821 hours with unmet load
# 1992: 1542 hours with unmet load
# 1993: 1612 hours with unmet load
# 1994: 1592 hours with unmet load
# 1995: 1162 hours with unmet load
# 1996: 1230 hours with unmet load
# 1997: 1392 hours with unmet load
# 1998: 1378 hours with unmet load
# 1999: 1048 hours with unmet load
# 2000: 1202 hours with unmet load
# 2001: 1261 hours with unmet load
# 2002: 1375 hours with unmet load
# 2003: 1322 hours with unmet load
# 2004: 1364 hours with unmet load
# 2005: 1162 hours with unmet load
# 2006: 1206 hours with unmet load
# 2007: 1282 hours with unmet load
# 2008: 1240 hours with unmet load
# 2009: 1446 hours with unmet load
# 2010: 1269 hours with unmet load
# 2011: 1273 hours with unmet load
# 2012: 1281 hours with unmet load
# 2013: 1456 hours with unmet load
# 2014: 1341 hours with unmet load
# 2015: 1543 hours with unmet load
# 2016: 1346 hours with unmet load
# 2017: 1404 hours with unmet load
# 2018: 1600 hours with unmet load
# 2019: 1708 hours with unmet load
# 2020: 1495 hours with unmet load
# 2021: 1293 hours with unmet load
# 2022: 1219 hours with unmet load
# 2023: 1374 hours with unmet load
# 2024: 1405 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 1372.02 hours/year
# Maximum: 1821 hours in 1991
# Minimum: 1048 hours in 1999

# %% [markdown]
# # 80% met Load sizing

# %%
# Clear all user-defined variables
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

import gc
gc.collect()

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import os

# === CONFIGURE ===
hours = 8760
base_power_csv = 'Desktop/base_power_profile.csv'
solar_csv_2024 = 'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected (0).csv'
wind_csv_2024 = 'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected (0).csv'
battery_efficiency = 0.89
dc_series_efficiency = 0.97 * 0.93
life_project = 15
output_dir = "dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment"  # Directory to save plots and CSVs

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === Load and Preprocess 2024 Data ===
try:
    df_base = pd.read_csv(base_power_csv)
    base_power = df_base['Power_W'].to_numpy()
except FileNotFoundError:
    print("Error: base_power_profile.csv not found.")
    exit(1)

# PUE profile
quarter_midpoints = np.linspace(0, hours, 5)
pue_targets = [1.09, 1.11, 1.13, 1.08, 1.09]
hourly_pue = make_interp_spline(quarter_midpoints, pue_targets, k=3)(np.arange(hours))
dc_ac_conversion_efficiency = 0.975
load_profile = (base_power[:hours] / 1000) * 200000 * 1.405 * (hourly_pue / dc_ac_conversion_efficiency)

# 2024 Solar and wind resources
df_solar = pd.read_csv(solar_csv_2024, skiprows=3)
df_wind = pd.read_csv(wind_csv_2024, skiprows=3)
solar_vector = df_solar['electricity']
wind_vector = df_wind['electricity']
solar_resource_2024 = solar_vector[:hours]
wind_resource_2024 = wind_vector[:hours]

# === Optimization Parameters ===
inverter_capacity = (750 / 1000) * 200000 * 1.405 * (0.15 / dc_ac_conversion_efficiency)
cost_solar = 67.6 * 1.1 * 1.25
cost_wind = 5113800
cost_battery = 358
cost_inverter = 165 * 1.1 * 1.0795

om_solar = 7.965
om_wind = 93750
om_battery = 8.52
om_inverter = cost_inverter * 0.05

life_solar = 25
life_wind = 20
life_battery = 10
life_inverter = 10

unmet_load_penalty = 0
total_demand = sum(load_profile)
allowed_unmet = 0.2 * total_demand

inf = 0.023
dis = 0.045
timval = (1 + inf) / (1 + dis)

required_uptime = 0.99671
R_s = 0.99677
R_w = 0.994769
R_b = 0.99664
R_i = 0.997265

Ns_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_s) * 1e5) / 1e5
Nw_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_w) * 1e5) / 1e5
Nb_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_b) * 1e5) / 1e5
Ni_min = np.ceil(np.log(1 - required_uptime) / np.log(1 - R_i) * 1e5) / 1e5


# === Optimization Function ===
def run_linear_milp_optimization_gurobipy(load_profile, solar_resource, wind_resource,
                                         cost_solar, cost_wind, cost_battery,
                                         unmet_load_penalty, battery_efficiency,
                                         Ns_min, Nw_min, Nb_min):
    try:
        model = gp.Model("EnergySystem")
        
        # Variables
        solar_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="solar_capacity")
        wind_capacity = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="wind_capacity")
        battery_capacity = model.addVar(lb=1000, vtype=GRB.CONTINUOUS, name="battery_capacity")
        battery_charge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_charge")
        battery_discharge = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_discharge")
        battery_soc = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="battery_soc")
        unmet_load = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="unmet_load")
        curtailment = model.addVars(hours, lb=0, vtype=GRB.CONTINUOUS, name="curtailment")

        # NPC Calculations
        discount_factor = (1 - (timval)**life_project) / (1 - timval)
        solar_capex = cost_solar * solar_capacity * Ns_min
        wind_capex = cost_wind * wind_capacity * Nw_min
        battery_capex = cost_battery * battery_capacity * Nb_min
        inverter_capex = cost_inverter * inverter_capacity * Ni_min

        solar_opex = om_solar * solar_capacity * timval * discount_factor
        wind_opex = om_wind * wind_capacity * timval * discount_factor
        battery_opex = om_battery * battery_capacity * timval * discount_factor
        inverter_opex = om_inverter * inverter_capacity * timval * discount_factor

        solar_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="solar_replacement")
        wind_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="wind_replacement")
        inverter_replacement = model.addVar(vtype=GRB.CONTINUOUS, name="inverter_replacement")

        if life_solar >= life_project:
            model.addConstr(solar_replacement == 0)
        else:
            model.addConstr(solar_replacement == (solar_capex * (1 + inf)**life_solar) / ((1 + dis)**life_solar))

        if life_wind >= life_project:
            model.addConstr(wind_replacement == 0)
        else:
            model.addConstr(wind_replacement == (wind_capex * (1 + inf)**life_wind) / ((1 + dis)**life_wind))

        if life_inverter >= life_project:
            model.addConstr(inverter_replacement == 0)
        else:
            model.addConstr(inverter_replacement == (inverter_capex * (1 + inf)**life_inverter) / ((1 + dis)**life_inverter))

        solar_salvage = solar_capex * (life_solar - (life_project % life_solar)) / life_solar * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        wind_salvage = wind_capex * (life_wind - (life_project % life_wind)) / life_wind * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        battery_salvage = battery_capex * (life_battery - (life_project % life_battery)) / life_battery * ((1 + inf)**life_project) / ((1 + dis)**life_project)
        inverter_salvage = inverter_capex * (life_inverter - (life_project % life_inverter)) / life_inverter * ((1 + inf)**life_project) / ((1 + dis)**life_project)

        solar_npc = solar_capex + solar_replacement - solar_salvage + solar_opex
        wind_npc = wind_capex + wind_replacement - wind_salvage + wind_opex
        battery_npc = battery_capex - battery_salvage + battery_opex
        inverter_npc = inverter_capex + inverter_replacement - inverter_salvage + inverter_opex

        # Objective
        total_cost = (
            solar_npc +
            wind_npc +
            battery_npc +
            inverter_npc +
            unmet_load_penalty * gp.quicksum(unmet_load[t] for t in range(hours))
        )
        model.setObjective(total_cost, GRB.MINIMIZE)

        # Constraints
        model.addConstr(battery_soc[0] == battery_capacity, name="initial_soc")
        for t in range(hours):
            solar_gen = solar_resource[t] * solar_capacity * dc_series_efficiency
            wind_gen = wind_resource[t] * wind_capacity * dc_series_efficiency
            net_gen = solar_gen + wind_gen
            model.addConstr(battery_soc[t] <= battery_capacity, name=f"soc_upper_{t}")
            model.addConstr(battery_charge[t] <= battery_capacity, name=f"charge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_capacity, name=f"discharge_upper_{t}")
            model.addConstr(battery_discharge[t] <= battery_soc[t], name=f"discharge_limit_{t}")
            model.addConstr(
                net_gen + battery_discharge[t] * dc_series_efficiency -
                battery_charge[t] / battery_efficiency - curtailment[t] -
                load_profile[t] + unmet_load[t] == 0,
                name=f"energy_balance_{t}"
            )
            model.addConstr(gp.quicksum(unmet_load[t] for t in range(hours)) <= allowed_unmet, name="unmet_load_limit")
            model.addConstr(battery_charge[t] * battery_discharge[t] <= 0, name=f"no_simul_charge_discharge_{t}")
            if t > 0:
                model.addConstr(
                    battery_soc[t] == battery_soc[t-1] +
                    battery_charge[t] -
                    battery_discharge[t] / battery_efficiency,
                    name=f"soc_update_{t}"
                )
        model.addConstr(battery_soc[hours-1] >= 0 * battery_capacity, name="min_final_soc")

        model.setParam("TimeLimit", 400)
        model.setParam("MIPGap", 0.01)
        model.setParam("NumericFocus", 3)
        model.setParam("OutputFlag", 1)
        model.setParam("MIPFocus", 1)

        model.optimize()

        if model.status == GRB.OPTIMAL:
            print("Optimal Solution Found!")
            print(f"Solar Capacity: {solar_capacity.x:.2f} PV")
            print(f"Wind Capacity: {wind_capacity.x:.2f} HAWT")
            print(f"Battery Capacity: {battery_capacity.x:.2f} kWh")
            return {
                "solar": solar_capacity.x,
                "wind": wind_capacity.x,
                "battery": battery_capacity.x,
                "cost": model.objVal,
                "solar_capex": solar_capex.getValue(),
                "solar_opex": solar_opex.getValue(),
                "solar_replacement": solar_replacement.x,
                "solar_salvage": solar_salvage.getValue(),
                "wind_capex": wind_capex.getValue(),
                "wind_opex": wind_opex.getValue(),
                "wind_replacement": wind_replacement.x,
                "wind_salvage": wind_salvage.getValue(),
                "battery_capex": battery_capex.getValue(),
                "battery_opex": battery_opex.getValue(),
                "battery_salvage": battery_salvage.getValue(),
                "inverter_capex": inverter_capex,
                "inverter_opex": inverter_opex,
                "inverter_replacement": inverter_replacement.x,
                "inverter_salvage": inverter_salvage
            }
        else:
            print(f"Optimization Failed. Status: {model.status}")
            if model.status == GRB.INFEASIBLE:
                model.computeIIS()
                model.write("conflict.ilp")
                print("IIS written to conflict.ilp")
            return {"status": model.status}

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return {"status": "error"}
    except Exception as e:
        print(f"Error: {e}")
        return {"status": "error"}

# === Degradation Function ===
def calculate_rainflow_degradation_verbose(soc_series, capacity, A=0.000144, beta=1.79, dod_threshold=0):
    soc_series = np.array(soc_series)
    total_degradation = 0.0
    cycle_info = []
    peak = soc_series[0]
    valley = peak
    direction = None
    peak_hour = 0
    valley_hour = 0

    for i in range(1, len(soc_series)):
        if soc_series[i] > soc_series[i - 1]:
            if direction == 'down':
                dod = (peak - valley) / capacity if capacity > 0 else 0
                if dod >= dod_threshold:
                    degradation = A * (dod ** beta)
                    total_degradation += degradation
                    cycle_info.append({
                        "type": "discharge",
                        "peak_hour": peak_hour,
                        "valley_hour": valley_hour,
                        "DoD": round(dod, 4),
                        "degradation": round(degradation, 6)
                    })
                peak = soc_series[i]
                peak_hour = i
                direction = 'up'
            else:
                peak = max(peak, soc_series[i])
                if peak == soc_series[i]:
                    peak_hour = i
                direction = 'up'
        elif soc_series[i] < soc_series[i - 1]:
            if direction == 'up':
                valley = soc_series[i]
                valley_hour = i
                direction = 'down'
            else:
                valley = min(valley, soc_series[i])
                if valley == soc_series[i]:
                    valley_hour = i
                direction = 'down'

    return cycle_info, total_degradation

# === Function to Calculate Battery Replacement Cost ===
def calculate_battery_replacement_cost(battery_capex, degradation, inf, dis, life_battery):
    if degradation < 1:
        replacement_yearly = (battery_capex / (1 - degradation)) - battery_capex
        print(f"${replacement_yearly:.2f} is the replacement cost each year for degradation")
    else:
        replacement_yearly = 0

    battery_replacement_npc = 0
    for t in range(1, life_project + 1):
        battery_replacement_npc += replacement_yearly * ((1 + inf) ** t) / ((1 + dis) ** t)

    return battery_replacement_npc

# === Dispatch Simulation ===
def simulate_dispatch_fixed_capacities(load_profile, solar_resource, wind_resource,
                                      fixed_solar, fixed_wind, fixed_battery,
                                      battery_efficiency=0.89, initial_soc=0):
    hours = len(load_profile)
    model = gp.Model("fixed_dispatch")
    model.Params.OutputFlag = 0
    model.Params.TimeLimit = 300

    battery_charge = model.addVars(hours, lb=0, name="charge")
    battery_discharge = model.addVars(hours, lb=0, name="discharge")
    battery_soc = model.addVars(hours, lb=0, ub=fixed_battery, name="soc")
    unmet_load = model.addVars(hours, lb=0, name="unmet")
    curtailment = model.addVars(hours, lb=0, name="curtailment")

    model.addConstr(battery_soc[0] == initial_soc)

    for t in range(hours):
        solar_gen = solar_resource[t] * fixed_solar * dc_series_efficiency
        wind_gen = wind_resource[t] * fixed_wind * dc_series_efficiency
        net_gen = solar_gen + wind_gen

        model.addConstr(battery_soc[t] <= fixed_battery)
        model.addConstr(battery_discharge[t] <= battery_soc[t])

        if t > 0:
            model.addConstr(
                battery_soc[t] == battery_soc[t - 1] +
                battery_charge[t] -
                battery_discharge[t] / battery_efficiency
            )

        model.addConstr(
            net_gen + battery_discharge[t] * dc_series_efficiency -
            battery_charge[t] / battery_efficiency - curtailment[t] -
            load_profile[t] + unmet_load[t] == 0
        )

    model.setObjective(gp.quicksum(unmet_load[t] for t in range(hours)), GRB.MINIMIZE)
    model.optimize()

    if model.status == GRB.OPTIMAL:
        battery_soc_vals = np.array([battery_soc[t].X for t in range(hours)])
        battery_charge_vals = np.array([battery_charge[t].X for t in range(hours)])
        battery_discharge_vals = np.array([battery_discharge[t].X for t in range(hours)])
        cycles, degradation = calculate_rainflow_degradation_verbose(battery_soc_vals, fixed_battery)

        return {
            "total_unmet": sum(unmet_load[t].X for t in range(hours)),
            "unmet_hours": [t for t in range(hours) if unmet_load[t].X > 1e-3],
            "unmet_profile": np.array([unmet_load[t].X for t in range(hours)]),
            "battery_soc": battery_soc_vals,
            "battery_charge": battery_charge_vals,
            "battery_discharge": battery_discharge_vals,
            "curtailment": np.array([curtailment[t].X for t in range(hours)]),
            "cycles": cycles,
            "degradation": degradation
        }
    else:
        return None

# === Function to Load Yearly Resources ===
def load_yearly_resources(year):
    try:
        if year >= 2000:
            idx = 2024 - year
            solar_csv = f'Desktop/Solar/2000s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/2000s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'
        else:
            idx = year - 1900
            solar_csv = f'Desktop/Solar/1900s/ninja_pv_35.1460_-90.0518_uncorrected ({idx}).csv'
            wind_csv = f'Desktop/Wind/1900s/ninja_wind_35.1460_-90.0518_uncorrected ({idx}).csv'

        df_solar = pd.read_csv(solar_csv, skiprows=3)
        df_wind = pd.read_csv(wind_csv, skiprows=3)
        solar_vector = df_solar['electricity']
        wind_vector = df_wind['electricity']
        return solar_vector[:hours], wind_vector[:hours]
    except FileNotFoundError:
        print(f"Error: Resource files for year {year} not found.")
        return None, None

# === Function to Save Plot, CSVs, and Dispatch Text ===
def save_dispatch_output(year, dispatch_result, load_profile, solar_resource, wind_resource, fixed_solar, fixed_wind):
    df_dispatch = pd.DataFrame({
        "Hour": np.arange(hours),
        "Load (kW)": load_profile,
        "Solar (kW)": solar_resource * fixed_solar,
        "Wind (kW)": wind_resource * fixed_wind,
        "SOC (kWh)": dispatch_result["battery_soc"],
        "Charge (kW)": dispatch_result["battery_charge"],
        "Discharge (kW)": dispatch_result["battery_discharge"],
        "Unmet (kW)": dispatch_result["unmet_profile"],
        "Curtailment (kW)": dispatch_result["curtailment"]
    })

    # Save dispatch data CSV
    csv_path = os.path.join(output_dir, f"dispatch_data_{year}.csv")
    df_dispatch.to_csv(csv_path, index=False)
    print(f"Saved dispatch data to {csv_path}")

    # Save hourly dispatch table CSV
    dispatch_table_path = os.path.join(output_dir, f"hourly_dispatch_{year}.csv")
    df_dispatch.to_csv(dispatch_table_path, index=False)
    print(f"Saved hourly dispatch table to {dispatch_table_path}")

    # Save cycles CSV
    df_cycles = pd.DataFrame(dispatch_result["cycles"])
    cycles_path = os.path.join(output_dir, f"cycles_{year}.csv")
    df_cycles.to_csv(cycles_path, index=False)
    print(f"Saved battery cycles to {cycles_path}")

    # Save Plot
    plt.figure(figsize=(15, 8))
    plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
    plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
    plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
    plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
    plt.xlim(0, 8760)
    plt.legend()
    plt.grid(True)
    plt.title(f"Dispatch Profile for {year}")
    plt.xlabel("Hour")
    plt.ylabel("Power (kW) / Energy (kWh)")
    plt.tight_layout()
    plot_path = os.path.join(output_dir, f"dispatch_profile_{year}.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved dispatch plot to {plot_path}")

    return df_dispatch, df_cycles

# === Run Optimization for 2024 ===
opt_results = run_linear_milp_optimization_gurobipy(
    load_profile, solar_resource_2024, wind_resource_2024,
    cost_solar, cost_wind, cost_battery,
    unmet_load_penalty, battery_efficiency,
    Ns_min, Nw_min, Nb_min
)

# === Process Results ===
if isinstance(opt_results, dict) and "status" not in opt_results:
    # Run dispatch simulation for 2024 (full output)
    dispatch_result = simulate_dispatch_fixed_capacities(
        load_profile=load_profile,
        solar_resource=solar_resource_2024,
        wind_resource=wind_resource_2024,
        fixed_solar=opt_results["solar"],
        fixed_wind=opt_results["wind"],
        fixed_battery=opt_results["battery"],
        initial_soc=opt_results["battery"]
    )

    if dispatch_result:
        # Calculate curtailment, generation, and percentage
        total_curtailed = np.sum(dispatch_result["curtailment"])
        solar_gen = solar_resource_2024 * opt_results["solar"] 
        wind_gen = wind_resource_2024 * opt_results["wind"] 
        total_generated = np.sum(solar_gen + wind_gen)
        total_power_consumed = total_generated-total_curtailed
        utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

        # Print results
        print("\n=== 2024 Curtailment and Generation Metrics ===")
        print(f"Total Energy Curtailed: {total_curtailed:.2f} kWh")
        print(f"Total Energy Generated: {total_generated:.2f} kWh")
        print(f"Total Energy Used (along with efficiency losses): {total_power_consumed:.2f} kWh")
        print(f"Utilization Percentage: {utilization_percentage:.2f}%")
        
        # Calculate redundant capacities and costs
        solar_initial_capacity = opt_results["solar"]
        wind_initial_capacity = opt_results["wind"]
        battery_initial_capacity = opt_results["battery"]
        inverter_initial_capacity = inverter_capacity

        solar_initial_cost = cost_solar * solar_initial_capacity
        wind_initial_cost = cost_wind * wind_initial_capacity
        battery_initial_cost = cost_battery * battery_initial_capacity
        inverter_initial_cost = cost_inverter * inverter_initial_capacity

        solar_redundant_capacity = (Ns_min - 1) * opt_results["solar"]
        wind_redundant_capacity = (Nw_min - 1) * opt_results["wind"]
        battery_redundant_capacity = (Nb_min - 1) * opt_results["battery"]
        inverter_redundant_capacity = inverter_capacity * (Ni_min-1)

        solar_redundant_cost = cost_solar * solar_redundant_capacity
        wind_redundant_cost = cost_wind * wind_redundant_capacity
        battery_redundant_cost = cost_battery * battery_redundant_capacity
        inverter_redundant_cost = cost_inverter * inverter_redundant_capacity
        
        # Calculate battery replacement cost
        yearly_degradation = dispatch_result["degradation"]
        battery_replacement = calculate_battery_replacement_cost(
            battery_capex=opt_results["battery_capex"],
            degradation=yearly_degradation,
            inf=inf,
            dis=dis,
            life_battery=life_battery
        )

        # Update total NPC
        total_npc = opt_results["cost"] + battery_replacement

        # Display initial capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Initial Capacity: {solar_initial_capacity:.2f} PV")
        print(f"Solar Initial Cost:    ${solar_initial_cost:.2f}")
        print(f"Wind Initial Capacity: {wind_initial_capacity:.2f} HAWT")
        print(f"Wind Initial Cost:     ${wind_initial_cost:.2f}")
        print(f"Battery Initial Capacity: {battery_initial_capacity:.2f} kWh")
        print(f"Battery Initial Cost:  ${battery_initial_cost:.2f}")
        print(f"Inverter Initial Capacity: {inverter_initial_capacity:.2f} kW")
        print(f"Inverter Initial Cost:  ${inverter_initial_cost:.2f}")

        # Display redundant capacities and costs
        print("\nRedundant Capacities and Costs:")
        print(f"Solar Redundant Capacity: {solar_redundant_capacity:.2f} PV")
        print(f"Solar Redundant Cost:    ${solar_redundant_cost:.2f}")
        print(f"Wind Redundant Capacity: {wind_redundant_capacity:.2f} HAWT")
        print(f"Wind Redundant Cost:     ${wind_redundant_cost:.2f}")
        print(f"Battery Redundant Capacity: {battery_redundant_capacity:.2f} kWh")
        print(f"Battery Redundant Cost:  ${battery_redundant_cost:.2f}")
        print(f"Inverter Redundant Capacity: {inverter_redundant_capacity:.2f} kW")
        print(f"Inverter Redundant Cost:  ${inverter_redundant_cost:.2f}")

        # Display cost breakdown
        print("\nCost Breakdown:")
        print(f"Solar CAPEX:        ${opt_results['solar_capex']:.2f}")
        print(f"Solar OPEX:         ${opt_results['solar_opex']:.2f}")
        print(f"Solar Replacement:  ${opt_results['solar_replacement']:.2f}")
        print(f"Solar Salvage:     -${opt_results['solar_salvage']:.2f}")
        print(f"Wind CAPEX:         ${opt_results['wind_capex']:.2f}")
        print(f"Wind OPEX:          ${opt_results['wind_opex']:.2f}")
        print(f"Wind Replacement:   ${opt_results['wind_replacement']:.2f}")
        print(f"Wind Salvage:      -${opt_results['wind_salvage']:.2f}")
        print(f"Battery CAPEX:      ${opt_results['battery_capex']:.2f}")
        print(f"Battery OPEX:       ${opt_results['battery_opex']:.2f}")
        print(f"Battery Replacement:${battery_replacement:.2f}")
        print(f"Battery Salvage:   -${opt_results['battery_salvage']:.2f}")
        print(f"Inverter CAPEX:     ${opt_results['inverter_capex']:.2f}")
        print(f"Inverter OPEX:      ${opt_results['inverter_opex']:.2f}")
        print(f"Inverter Replacement:${opt_results['inverter_replacement']:.2f}")
        print(f"Inverter Salvage:   -${opt_results['inverter_salvage']:.2f}")
        print(f"Total NPC:          ${total_npc:.2f}")

        print("\n=== 2024 Results ===")
        print(f"Total Unmet Load: {dispatch_result['total_unmet']:.2f} kWh")
        print(f"Hours with Unmet Load: {dispatch_result['unmet_hours']}")
        print("\nDetected Battery Cycles:")
        df_cycles = pd.DataFrame(dispatch_result["cycles"])
        print(df_cycles.to_string(index=False))
        print(f"\nTotal Estimated Degradation: {dispatch_result['degradation']:.6f}")

        df_dispatch, df_cycles = save_dispatch_output(
            year=2024,
            dispatch_result=dispatch_result,
            load_profile=load_profile,
            solar_resource=solar_resource_2024,
            wind_resource=wind_resource_2024,
            fixed_solar=opt_results["solar"],
            fixed_wind=opt_results["wind"]
        )

        # Display plot for 2024
        plt.figure(figsize=(15, 8))
        plt.plot(df_dispatch["Hour"], df_dispatch["Load (kW)"], label="Load", linestyle='--')
        plt.plot(df_dispatch["Hour"], df_dispatch["Solar (kW)"], label="Solar")
        plt.plot(df_dispatch["Hour"], df_dispatch["Wind (kW)"], label="Wind")
        plt.plot(df_dispatch["Hour"], df_dispatch["SOC (kWh)"], label="SOC", alpha=0.7)
        plt.xlim(0, 8760)
        plt.legend()
        plt.grid(True)
        plt.title("2024 Dispatch Profile")
        plt.xlabel("Hour")
        plt.ylabel("Power (kW) / Energy (kWh)")
        plt.tight_layout()
        plt.show()

        # === Evaluate Unmet Load for All Years ===
        unmet_loads = {}
        for year in range(2024, 1979, -1):
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                unmet_loads[year] = None
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                unmet_loads[year] = dispatch_result["total_unmet"]
                save_dispatch_output(
                    year=year,
                    dispatch_result=dispatch_result,
                    load_profile=load_profile,
                    solar_resource=solar_resource,
                    wind_resource=wind_resource,
                    fixed_solar=opt_results["solar"],
                    fixed_wind=opt_results["wind"]
                )
            else:
                unmet_loads[year] = None

        # === Display Unmet Load Results ===
        print("\n=== Unmet Load Across Years ===")
        valid_unmet_loads = []
        for year in range(2024, 1979, -1):
            if unmet_loads[year] is not None:
                print(f"Year {year}: Unmet Load = {unmet_loads[year]:.2f} kWh")
                valid_unmet_loads.append(unmet_loads[year])
            else:
                print(f"Year {year}: Unmet Load = Failed (missing data or optimization error)")

        if valid_unmet_loads:
            avg_unmet = np.mean(valid_unmet_loads)
            print(f"\nAverage Unmet Load (1979-2024): {avg_unmet:.2f} kWh")
            print(f"Min Unmet Load: {min(valid_unmet_loads):.2f} kWh (Year {min((year for year, val in unmet_loads.items() if val == min(valid_unmet_loads)), default='N/A')})")
            print(f"Max Unmet Load: {max(valid_unmet_loads):.2f} kWh (Year {max((year for year, val in unmet_loads.items() if val == max(valid_unmet_loads)), default='N/A')})")
        else:
            print("\nNo valid unmet load data available.")

        # === Save Capacity, Cost, and Utilization Metrics for All Years ===
        print("Starting capacity, cost, and utilization metrics collection...")
        results_by_year = []
        for year in range(2024, 1979, -1):
            print(f"Processing year {year} for capacity, cost, and utilization metrics...")
            solar_resource, wind_resource = load_yearly_resources(year)
            if solar_resource is None or wind_resource is None:
                print(f"Year {year}: Skipping due to missing resource data.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })
                continue

            dispatch_result = simulate_dispatch_fixed_capacities(
                load_profile=load_profile,
                solar_resource=solar_resource,
                wind_resource=wind_resource,
                fixed_solar=opt_results["solar"],
                fixed_wind=opt_results["wind"],
                fixed_battery=opt_results["battery"],
                initial_soc=opt_results["battery"]
            )

            if dispatch_result:
                print(f"Year {year}: Dispatch simulation successful, calculating metrics...")
                # Calculate utilization metrics
                total_curtailed = np.sum(dispatch_result["curtailment"])
                solar_gen = solar_resource * opt_results["solar"]
                wind_gen = wind_resource * opt_results["wind"]
                total_generated = np.sum(solar_gen + wind_gen)
                total_power_consumed = total_generated - total_curtailed
                utilization_percentage = (total_power_consumed / total_generated * 100) if total_generated > 0 else 0

                # Calculate battery replacement cost
                yearly_degradation = dispatch_result["degradation"]
                battery_replacement = calculate_battery_replacement_cost(
                    battery_capex=opt_results["battery_capex"],
                    degradation=yearly_degradation,
                    inf=inf,
                    dis=dis,
                    life_battery=life_battery
                )

                # Calculate total NPC
                total_npc = (
                    opt_results["solar_capex"] +
                    opt_results["solar_opex"] +
                    opt_results["solar_replacement"] -
                    opt_results["solar_salvage"] +
                    opt_results["wind_capex"] +
                    opt_results["wind_opex"] +
                    opt_results["wind_replacement"] -
                    opt_results["wind_salvage"] +
                    opt_results["battery_capex"] +
                    opt_results["battery_opex"] +
                    battery_replacement -
                    opt_results["battery_salvage"] +
                    opt_results["inverter_capex"] +
                    opt_results["inverter_opex"] +
                    opt_results["inverter_replacement"] -
                    opt_results["inverter_salvage"]
                )

                # Store results
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": opt_results["solar"],
                    "Wind_Capacity_HAWT": opt_results["wind"],
                    "Battery_Capacity_kWh": opt_results["battery"],
                    "Inverter_Capacity_kW": inverter_capacity,
                    "Solar_CAPEX": opt_results["solar_capex"],
                    "Solar_OPEX": opt_results["solar_opex"],
                    "Solar_Replacement": opt_results["solar_replacement"],
                    "Solar_Salvage": opt_results["solar_salvage"],
                    "Wind_CAPEX": opt_results["wind_capex"],
                    "Wind_OPEX": opt_results["wind_opex"],
                    "Wind_Replacement": opt_results["wind_replacement"],
                    "Wind_Salvage": opt_results["wind_salvage"],
                    "Battery_CAPEX": opt_results["battery_capex"],
                    "Battery_OPEX": opt_results["battery_opex"],
                    "Battery_Replacement": battery_replacement,
                    "Battery_Salvage": opt_results["battery_salvage"],
                    "Inverter_CAPEX": opt_results["inverter_capex"],
                    "Inverter_OPEX": opt_results["inverter_opex"],
                    "Inverter_Replacement": opt_results["inverter_replacement"],
                    "Inverter_Salvage": opt_results["inverter_salvage"],
                    "Total_NPC": total_npc,
                    "Utilization_Percentage": utilization_percentage,
                    "Total_Curtailed_kWh": total_curtailed,
                    "Total_Generated_kWh": total_generated,
                    "Total_Power_Consumed_kWh": total_power_consumed,
                    "Total_Unmet_kWh": dispatch_result["total_unmet"]
                })
                print(f"Year {year}: Metrics added - Utilization: {utilization_percentage:.2f}%, NPC: {total_npc:.2f}, Unmet: {dispatch_result['total_unmet']:.2f} kWh")
            else:
                print(f"Year {year}: Metrics save failed due to dispatch simulation error.")
                results_by_year.append({
                    "Year": year,
                    "Solar_Capacity_PV": None,
                    "Wind_Capacity_HAWT": None,
                    "Battery_Capacity_kWh": None,
                    "Inverter_Capacity_kW": None,
                    "Solar_CAPEX": None,
                    "Solar_OPEX": None,
                    "Solar_Replacement": None,
                    "Solar_Salvage": None,
                    "Wind_CAPEX": None,
                    "Wind_OPEX": None,
                    "Wind_Replacement": None,
                    "Wind_Salvage": None,
                    "Battery_CAPEX": None,
                    "Battery_OPEX": None,
                    "Battery_Replacement": None,
                    "Battery_Salvage": None,
                    "Inverter_CAPEX": None,
                    "Inverter_OPEX": None,
                    "Inverter_Replacement": None,
                    "Inverter_Salvage": None,
                    "Total_NPC": None,
                    "Utilization_Percentage": None,
                    "Total_Curtailed_kWh": None,
                    "Total_Generated_kWh": None,
                    "Total_Power_Consumed_kWh": None,
                    "Total_Unmet_kWh": None
                })

        # Save results to CSV
        try:
            df_results = pd.DataFrame(results_by_year)
            csv_path = os.path.join(output_dir, "capacity_and_costs_by_year.csv")
            df_results.to_csv(csv_path, index=False)
            print(f"Saved capacity, cost, and utilization metrics to {csv_path}")
            print(f"CSV file location: {os.path.abspath(csv_path)}")
        except Exception as e:
            print(f"Error saving CSV: {e}")

        # === Plot NPC Variation Across Years ===
        print("Starting NPC variation plotting...")
        try:
            valid_npc_data = df_results[df_results["Total_NPC"].notna()][["Year", "Total_NPC"]]
            if valid_npc_data.empty:
                print("Error: No valid NPC data found for plotting.")
            else:
                plt.figure(figsize=(15, 8))
                plt.plot(valid_npc_data["Year"], valid_npc_data["Total_NPC"], marker='o', linestyle='-', color='b')
                plt.title("NPC Variation Across Years (1979-2024)")
                plt.xlabel("Year")
                plt.ylabel("Total NPC ($)")
                plt.grid(True)
                plt.gca().invert_xaxis()  # Reverse x-axis to show 2024 to 1979
                plt.tight_layout()
                plot_path = os.path.join(output_dir, "npc_variation_by_year.png")
                plt.savefig(plot_path)
                plt.close()
                print(f"Saved NPC variation plot to {plot_path}")
                print(f"Plot file location: {os.path.abspath(plot_path)}")
        except Exception as e:
            print(f"Error plotting NPC variation: {e}")

    else:
        print("Dispatch simulation for 2024 failed.")
else:
    print("Optimization for 2024 failed.")
# Out:
# Set parameter TimeLimit to value 400
# Set parameter MIPGap to value 0.01
# Set parameter NumericFocus to value 3
# Set parameter OutputFlag to value 1
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  400
# MIPGap  0.01
# MIPFocus  1
# NumericFocus  3
#
# Optimize a model with 61324 rows, 43806 columns and 76890848 nonzeros
# Model fingerprint: 0xfcd9e909
# Model has 8760 quadratic constraints
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 6e+06]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [2e+05, 4e+08]
# Presolve removed 4 rows and 8763 columns (presolve time = 6s)...
# Presolve removed 17525 rows and 8764 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 5 rows and 8764 columns (presolve time = 6s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 11s)...
# Presolve removed 6 rows and 8764 columns (presolve time = 16s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 23s)...
# Presolve removed 8766 rows and 8764 columns (presolve time = 25s)...
# Presolve removed 8767 rows and 8765 columns
# Presolve time: 27.65s
# Presolved: 70077 rows, 35042 columns, 161997 nonzeros
# Presolved model has 8760 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 35042 continuous, 0 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 52555 rows, 35039 columns, 153232 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3264725e+07   5.151239e+05   3.669944e+06     44s
#      859    5.0153457e+11   0.000000e+00   2.107341e+07     45s
#     6178    5.3108760e+09   0.000000e+00   3.078352e+05     50s
#    11291    3.0415175e+09   0.000000e+00   2.666119e+07     55s
#    16583    2.9631795e+09   0.000000e+00   2.337701e+07     60s
#    19703    2.9231259e+09   0.000000e+00   3.572771e+05     65s
#    20951    2.8534349e+09   0.000000e+00   2.421408e+09     70s
#    21990    2.8152331e+09   1.934423e-03   5.759510e+09     75s
#    23051    2.7758604e+09   4.001028e-03   5.800195e+09     82s
#    23418    2.7541050e+09   5.783812e-03   3.228660e+09     85s
#    24492    2.7203602e+09   0.000000e+00   2.761967e+09     90s
#    25006    2.7039606e+09   2.769910e-04   2.241257e+08    103s
#    25114    2.6990499e+09   4.051409e-04   2.136389e+09    106s
#    25592    2.6893683e+09   0.000000e+00   6.293938e+06    111s
#    26081    2.6795063e+09   0.000000e+00   1.269172e+09    116s
#    26366    2.6735085e+09   0.000000e+00   1.580309e+06    121s
#    26770    2.6613147e+09   2.026850e-05   3.804879e+09    128s
#    26938    2.6527015e+09   7.771545e-05   2.016638e+09    130s
#    27546    2.6060898e+09   1.413707e-04   5.071001e+06    136s
#    28386    2.5363499e+09   0.000000e+00   2.323320e+04    141s
#    29023    2.5099284e+09   7.969844e-06   1.373244e+09    146s
#    29542    2.4900396e+09   7.138062e-05   2.402006e+07    151s
#    29873    2.4726908e+09   0.000000e+00   2.483055e+04    157s
# Warning: 1 variables dropped from basis
#    30369    2.4639915e+09   0.000000e+00   7.129196e+03    160s
# Warning: 1 variables dropped from basis
#    31247    2.4506199e+09   0.000000e+00   1.903265e+03    166s
#    31826    2.4403278e+09   0.000000e+00   2.521990e+03    170s
#    32536    2.4252817e+09   0.000000e+00   2.522278e+03    176s
#    33117    2.4142963e+09   0.000000e+00   5.951664e+03    180s
# Concurrent spin time: 3.45s
#
# Solved with dual simplex
#
# Root relaxation: objective 1.865314e+09, 39515 iterations, 140.81 seconds (101.73 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.865314e+09 1.8653e+09  0.00%     -  184s
#
# Explored 1 nodes (39515 simplex iterations) in 185.55 seconds (166.87 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.86531e+09
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.865313675225e+09, best bound 1.865313675225e+09, gap 0.0000%
# Optimal Solution Found!
# Solar Capacity: 4262887.32 PV
# Wind Capacity: 32.84 HAWT
# Battery Capacity: 2825364.12 kWh
#
# === 2024 Curtailment and Generation Metrics ===
# Total Energy Curtailed: 304138535.07 kWh
# Total Energy Generated: 2355233757.30 kWh
# Total Energy Used (along with efficiency losses): 2051095222.22 kWh
# Utilization Percentage: 87.09%
# $41488260.30 is the replacement cost each year for degradation
#
# Redundant Capacities and Costs:
# Solar Initial Capacity: 4262887.32 PV
# Solar Initial Cost:    $396235376.58
# Wind Initial Capacity: 32.84 HAWT
# Wind Initial Cost:     $167926614.95
# Battery Initial Capacity: 2825364.12 kWh
# Battery Initial Cost:  $1011480355.02
# Inverter Initial Capacity: 32423.08 kW
# Inverter Initial Cost:  $6352629.14
#
# Redundant Capacities and Costs:
# Solar Redundant Capacity: -13641.24 PV
# Solar Redundant Cost:    $-1267953.21
# Wind Redundant Capacity: 2.90 HAWT
# Wind Redundant Cost:     $14824561.57
# Battery Redundant Capacity: 10453.85 kWh
# Battery Redundant Cost:  $3742477.31
# Inverter Redundant Capacity: -1014.84 kW
# Inverter Redundant Cost:  $-198837.29
#
# Cost Breakdown:
# Solar CAPEX:        $394967423.38
# Solar OPEX:         $431408968.97
# Solar Replacement:  $0.00
# Solar Salvage:     -$114818380.56
# Wind CAPEX:         $182751176.52
# Wind OPEX:          $39115294.78
# Wind Replacement:   $0.00
# Wind Salvage:      -$33203994.96
# Battery CAPEX:      $1015222832.34
# Battery OPEX:       $305853571.89
# Battery Replacement:$527138529.28
# Battery Salvage:   -$368910936.11
# Inverter CAPEX:     $6153791.85
# Inverter OPEX:      $4035738.74
# Inverter Replacement:$4974348.81
# Inverter Salvage:   -$2236160.42
# Total NPC:          $2392452204.50
#
# === 2024 Results ===
# Total Unmet Load: 388784414.51 kWh
# Hours with Unmet Load: [11, 12, 13, 22, 23, 24, 25, 26, 27, 28, 29, 30, 44, 46, 47, 48, 49, 50, 59, 60, 61, 62, 63, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 113, 114, 115, 116, 117, 118, 119, 120, 121, 131, 132, 133, 134, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 166, 167, 168, 169, 170, 171, 174, 188, 198, 199, 200, 201, 202, 203, 204, 205, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 250, 251, 252, 253, 254, 274, 275, 276, 277, 278, 279, 295, 296, 297, 298, 299, 300, 310, 311, 312, 313, 314, 315, 316, 317, 331, 332, 333, 334, 335, 336, 346, 347, 348, 349, 350, 351, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 392, 393, 394, 395, 396, 397, 406, 408, 409, 410, 411, 412, 413, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 465, 466, 467, 468, 488, 489, 490, 491, 492, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 597, 598, 599, 600, 601, 602, 603, 613, 614, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661, 679, 680, 681, 682, 683, 684, 685, 704, 705, 706, 707, 708, 709, 710, 729, 730, 731, 732, 752, 753, 754, 755, 756, 757, 774, 775, 776, 777, 778, 779, 780, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 812, 813, 814, 815, 816, 817, 818, 819, 820, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 874, 875, 876, 887, 888, 889, 890, 891, 892, 908, 909, 910, 911, 912, 913, 914, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 956, 957, 958, 959, 960, 961, 962, 963, 964, 975, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 1006, 1007, 1008, 1019, 1020, 1021, 1022, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1065, 1066, 1067, 1068, 1089, 1090, 1091, 1092, 1102, 1103, 1104, 1114, 1115, 1116, 1117, 1118, 1119, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1160, 1161, 1162, 1163, 1164, 1184, 1185, 1186, 1187, 1188, 1209, 1210, 1211, 1212, 1233, 1234, 1235, 1236, 1258, 1259, 1260, 1261, 1262, 1263, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1306, 1307, 1308, 1329, 1330, 1331, 1332, 1333, 1353, 1354, 1355, 1356, 1378, 1379, 1380, 1381, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1414, 1415, 1426, 1427, 1428, 1429, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1497, 1498, 1499, 1500, 1511, 1512, 1513, 1514, 1533, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1688, 1689, 1690, 1691, 1692, 1713, 1714, 1715, 1716, 1737, 1738, 1739, 1740, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1773, 1774, 1775, 1787, 1788, 1789, 1790, 1791, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1832, 1833, 1834, 1835, 1836, 1856, 1857, 1858, 1859, 1860, 1881, 1882, 1883, 1884, 1906, 1907, 1908, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1945, 1946, 1947, 1948, 1950, 1957, 1958, 1959, 1963, 1964, 1965, 1966,  ...
#
# Detected Battery Cycles:
#      type  peak_hour  valley_hour    DoD  degradation
# discharge          0           13 0.9866     0.000141
# discharge         18           37 0.6206     0.000061
# discharge         43           63 0.9191     0.000124
# discharge         69           85 0.0753     0.000001
# discharge         90          111 0.0422     0.000000
# discharge        112          134 0.9641     0.000135
# discharge        139          159 0.2583     0.000013
# discharge        165          181 0.7456     0.000085
# discharge        187          205 0.8035     0.000097
# discharge        212          229 0.3879     0.000026
# discharge        234          254 0.9975     0.000143
# discharge        260          279 0.9991     0.000144
# discharge        285          300 0.7985     0.000096
# discharge        306          325 0.5932     0.000057
# discharge        330          351 0.9575     0.000133
# discharge        356          373 0.2216     0.000010
# discharge        378          397 0.9988     0.000144
# discharge        402          444 1.0000     0.000144
# discharge        450          468 0.9948     0.000143
# discharge        474          492 0.9965     0.000143
# discharge        499          517 0.5152     0.000044
# discharge        522          544 0.0066     0.000000
# discharge        545          568 0.0370     0.000000
# discharge        570          594 0.0279     0.000000
# discharge        596          614 0.9297     0.000126
# discharge        621          637 0.4806     0.000039
# discharge        638          661 0.4617     0.000036
# discharge        669          685 0.9662     0.000135
# discharge        691          710 0.9992     0.000144
# discharge        716          733 0.9953     0.000143
# discharge        738          757 0.9986     0.000144
# discharge        764          780 0.8219     0.000101
# discharge        787          805 0.3294     0.000020
# discharge        810          853 0.9486     0.000131
# discharge        859          876 0.9908     0.000142
# discharge        882          901 0.7682     0.000090
# discharge        907          924 0.8221     0.000101
# discharge        933          951 0.0677     0.000001
# discharge        955          976 0.8628     0.000111
# discharge        977          997 0.0147     0.000000
# discharge       1003         1022 0.9927     0.000142
# discharge       1026         1045 0.1746     0.000006
# discharge       1050         1068 0.9957     0.000143
# discharge       1074         1092 0.9929     0.000142
# discharge       1098         1119 0.9982     0.000144
# discharge       1121         1123 0.0085     0.000000
# discharge       1125         1140 0.0345     0.000000
# discharge       1146         1164 0.9966     0.000143
# discharge       1170         1188 0.9960     0.000143
# discharge       1194         1212 0.9950     0.000143
# discharge       1218         1236 0.9949     0.000143
# discharge       1244         1263 0.9988     0.000144
# discharge       1268         1284 0.1999     0.000008
# discharge       1290         1308 0.9887     0.000141
# discharge       1314         1333 0.9973     0.000143
# discharge       1342         1356 0.9101     0.000122
# discharge       1363         1381 0.9952     0.000143
# discharge       1388         1406 0.8575     0.000109
# discharge       1412         1429 0.9957     0.000143
# discharge       1436         1452 0.7981     0.000096
# discharge       1460         1477 0.6851     0.000073
# discharge       1484         1500 0.9934     0.000142
# discharge       1506         1525 0.8465     0.000107
# discharge       1532         1550 0.9866     0.000141
# discharge       1556         1572 0.1710     0.000006
# discharge       1579         1597 0.6065     0.000059
# discharge       1604         1624 0.7373     0.000083
# discharge       1629         1645 0.2911     0.000016
# discharge       1654         1668 0.6659     0.000070
# discharge       1674         1692 0.9966     0.000143
# discharge       1698         1716 0.9946     0.000143
# discharge       1722         1740 0.9939     0.000142
# discharge       1747         1765 0.4238     0.000031
# discharge       1772         1791 0.9974     0.000143
# discharge       1795         1812 0.0359     0.000000
# discharge       1818         1837 0.9974     0.000143
# discharge       1846         1860 0.8477     0.000107
# discharge       1866         1884 0.9955     0.000143
# discharge       1890         1908 0.9875     0.000141
# discharge       1914         1932 0.6081     0.000059
# discharge       1942         1959 0.9083     0.000121
# discharge       1961         1980 0.0135     0.000000
# discharge       1986         2005 0.9958     0.000143
# discharge       2013         2029 0.8612     0.000110
# discharge       2037         2053 0.8797     0.000114
# discharge       2059         2076 0.9919     0.000142
# discharge       2082         2100 0.9948     0.000143
# discharge       2106         2124 0.9957     0.000143
# discharge       2130         2148 0.9903     0.000142
# discharge       2154         2173 0.9947     0.000143
# discharge       2180         2197 0.9924     0.000142
# discharge       2204         2221 0.3401     0.000021
# discharge       2230         2244 0.8086     0.000098
# discharge       2250         2268 0.9880     0.000141
# discharge       2274         2292 0.9898     0.000141
# discharge       2298         2316 0.9923     0.000142
# discharge       2323         2340 0.9895     0.000141
# discharge       2347         2364 0.9932     0.000142
# discharge       2373         2389 0.2078     0.000009
# discharge       2395         2416 0.8397     0.000105
# discharge       2419         2437 0.0599     0.000001
# discharge       2446         2460 0.8534     0.000108
# discharge       2466         2484 0.9933     0.000142
# discharge       2490         2508 0.9871     0.000141
# discharge       2515         2532 0.9885     0.000141
# discharge       2539         2556 0.9963     0.000143
# discharge       2563         2581 0.9949     0.000143
# discharge       2589         2604 0.4519     0.000035
# discharge       2612         2628 0.9917     0.000142
# discharge       2635         2653 0.9964     0.000143
# discharge       2660         2676 0.6162     0.000061
# discharge       2682         2700 0.9944     0.000143
# discharge       2706         2724 0.9915     0.000142
# discharge       2730         2748 0.9592     0.000134
# discharge       2758         2772 0.9112     0.000122
# discharge       2779         2797 0.5885     0.000056
# discharge       2806         2821 0.9811     0.000139
# discharge       2830         2844 0.6987     0.000076
# discharge       2850         2870 0.9970     0.000143
# discharge       2876         2892 0.4107     0.000029
# discharge       2898         2916 0.9935     0.000142
# discharge       2924         2940 0.7007     0.000076
# discharge       2949         2964 0.3321     0.000020
# discharge       2971         2988 0.4532     0.000035
# discharge       2997         3014 0.9448     0.000130
# discharge       3021         3036 0.1753     0.000006
# discharge       3043         3060 0.9918     0.000142
# discharge       3067         3085 0.9936     0.000142
# discharge       3094         3108 0.9160     0.000123
# discharge       3115         3132 0.9921     0.000142
# discharge       3138         3156 0.9958     0.000143
# discharge       3162         3180 0.9701     0.000136
# discharge       3188         3206 0.9929     0.000142
# discharge       3213         3228 0.3168     0.000018
# discharge       3235         3252 0.9927     0.000142
# discharge       3258         3276 0.9949     0.000143
# discharge       3283         3301 0.9986     0.000144
# discharge       3309         3325 0.9979     0.000143
# discharge       3334         3348 0.4243     0.000031
# discharge       3355         3372 0.9947     0.000143
# discharge       3381         3396 0.9930     0.000142
# discharge       3403         3421 0.2623     0.000013
# discharge       3428         3445 0.4928     0.000041
# discharge       3452         3470 0.6845     0.000073
# discharge       3478         3492 0.4121     0.000029
# discharge       3500         3516 0.9927     0.000142
# discharge       3524         3540 0.9835     0.000140
# discharge       3547         3564 0.9937     0.000142
# discharge       3571         3588 0.9951     0.000143
# discharge       3595         3612 0.9936     0.000142
# discharge       3619         3638 0.9982     0.000144
# discharge       3644         3661 0.5865     0.000055
# discharge       3668         3684 0.9954     0.000143
# discharge       3691         3708 0.9948     0.000143
# discharge       3718         3732 0.4728     0.000038
# discharge       3740         3756 0.9919     0.000142
# discharge       3764         3780 0.9956     0.000143
# discharge       3787         3804 0.9917     0.000142
# discharge       3811         3828 0.9881     0.000141
# discharge       3838         3852 0.5807     0.000054
# discharge       3860         3876 0.4839     0.000039
# discharge       3883         3900 0.9907     0.000142
# discharge       3907         3924 0.9930     0.000142
# discharge       3932         3948 0.9950     0.000143
# discharge       3955         3972 0.9957     0.000143
# discharge       3979         3996 0.9956     0.000143
# discharge       4006         4020 0.9945     0.000143
# discharge       4027         4046 0.3308     0.000020
# discharge       4054         4069 0.9569     0.000133
# discharge       4077         4092 0.3730     0.000025
# discharge       4102         4116 0.8761     0.000114
# discharge       4123         4140 0.9942     0.000143
# discharge       4148         4164 0.9965     0.000143
# discharge       4172         4188 0.9941     0.000142
# discharge       4196         4212 0.9955     0.000143
# discharge       4220         4236 0.9955     0.000143
# discharge       4245         4260 0.8115     0.000099
# discharge       4270         4284 0.9140     0.000123
# discharge       4291         4308 0.9928     0.000142
# discharge       4318         4332 0.9935     0.000142
# discharge       4340         4356 0.9933     0.000142
# discharge       4366         4380 0.8880     0.000116
# discharge       4387         4404 0.9917     0.000142
# discharge       4411         4428 0.9942     0.000143
# discharge       4435         4452 0.9931     0.000142
# discharge       4460         4477 0.9969     0.000143
# discharge       4486         4500 0.9938     0.000142
# discharge       4510         4524 0.9938     0.000142
# discharge       4531         4548 0.9964     0.000143
# discharge       4557         4572 0.3958     0.000027
# discharge       4580         4596 0.9920     0.000142
# discharge       4603         4620 0.9954     0.000143
# discharge       4627         4644 0.9952     0.000143
# discharge       4652         4668 0.9949     0.000143
# discharge       4677         4692 0.9961     0.000143
# discharge       4700         4716 0.9941     0.000142
# discharge       4726         4740 0.9943     0.000143
# discharge       4748         4766 0.9986     0.000144
# discharge       4774         4788 0.3859     0.000026
# discharge       4796         4812 0.9898     0.000141
# discharge       4819         4836 0.9936     0.000142
# discharge       4845         4860 0.9946     0.000143
# discharge       4868         4884 0.9067     0.000121
# discharge       4892         4933 0.4962     0.000041
# discharge       4941         4957 0.3915     0.000027
# discharge       4965         4981 0.1974     0.000008
# discharge       4988         5006 0.4421     0.000033
# discharge       5012         5028 0.4445     0.000034
# discharge       5037         5052 0.4656     0.000037
# discharge       5059         5076 0.9933     0.000142
# discharge       5083         5100 0.9932     0.000142
# discharge       5107         5124 0.9918     0.000142
# discharge       5131         5148 0.9929     0.000142
# discharge       5155         5172 0.9943     0.000143
# discharge       5179         5196 0.9945     0.000143
# discharge       5203         5220 0.9937     0.000142
# discharge       5227         5244 0.9948     0.000143
# discharge       5251         5268 0.9936     0.000142
# discharge       5275         5292 0.9928     0.000142
# discharge       5299         5316 0.9921     0.000142
# discharge       5323         5340 0.9919     0.000142
# discharge       5348         5364 0.9960     0.000143
# discharge       5372         5388 0.9954     0.000143
# discharge       5396         5412 0.7232     0.000081
# discharge       5420         5436 0.9965     0.000143
# discharge       5444         5460 0.9953     0.000143
# discharge       5468         5484 0.9938     0.000142
# discharge       5494         5509 0.9496     0.000131
# discharge       5516         5532 0.9956     0.000143
# discharge       5539         5556 0.9933     0.000142
# discharge       5563         5580 0.9920     0.000142
# discharge       5586         5604 0.9915     0.000142
# discharge       5610         5628 0.9911     0.000142
# discharge       5635         5652 0.9933     0.000142
# discharge       5659         5676 0.9937     0.000142
# discharge       5684         5700 0.9937     0.000142
# discharge       5707         5724 0.9955     0.000143
# discharge       5731         5748 0.9961     0.000143
# discharge       5755         5772 0.9963     0.000143
# discharge       5779         5796 0.8204     0.000101
# discharge       5805         5820 0.5482     0.000049
# discharge       5828         5845 0.8351     0.000104
# discharge       5853         5870 0.7934     0.000095
# discharge       5878         5892 0.4800     0.000039
# discharge       5899         5916 0.9899     0.000141
# discharge       5923         5941 0.9970     0.000143
# discharge       5947         5964 0.2966     0.000016
# discharge       5971         5988 0.9963     0.000143
# discharge       5996         6012 0.9942     0.000143
# discharge       6018         6036 0.9882     0.000141
# discharge       6042         6060 0.9897     0.000141
# discharge       6066         6084 0.9924     0.000142
# discharge       6091         6108 0.9953     0.000143
# discharge       6115         6135 0.1038     0.000002
# discharge       6140         6157 0.2707     0.000014
# discharge       6164         6181 0.4703     0.000037
# discharge       6189         6205 0.2880     0.000016
# discharge       6211         6231 0.8151     0.000100
# discharge       6236         6252 0.0653     0.000001
# discharge       6259         6276 0.9957     0.000143
# discharge       6283         6300 0.9962     0.000143
# discharge       6307         6324 0.9963     0.000143
# discharge       6331         6349 0.9980     0.000143
# discharge       6357         6373 0.3532     0.000022
# discharge       6380         6397 0.9815     0.000139
# discharge       6404         6422 0.4261     0.000031
# discharge       6430         6445 0.9225     0.000125
# discharge       6451         6468 0.9940     0.000142
# discharge       6474         6493 0.3323     0.000020
# discharge       6500         6517 0.9886     0.000141
# discharge       6525         6541 0.6561     0.000068
# discharge       6549         6564 0.6885     0.000074
# discharge       6571         6588 0.9967     0.000143
# discharge       6595         6612 0.9899     0.000141
# discharge       6618         6636 0.9961     0.000143
# discharge       6642         6660 0.9952     0.000143
# discharge       6667         6684 0.9950     0.000143
# discharge       6691         6708 0.9965     0.000143
# discharge       6715         6732 0.9942     0.000143
# discharge       6738         6756 0.9906     0.000142
# discharge       6762         6780 0.9928     0.000142
# discharge       6786         6804 0.9925     0.000142
# discharge       6810         6828 0.9961     0.000143
# discharge       6835         6852 0.9962     0.000143
# discharge       6859         6876 0.9888     0.000141
# discharge       6883         6900 0.9914     0.000142
# discharge       6906         6924 0.9961     0.000143
# discharge       6930         6948 0.9913     0.000142
# discharge       6954         6972 0.9951     0.000143
# discharge       6978         6996 0.9957     0.000143
# discharge       7002         7021 0.9976     0.000143
# discharge       7027         7044 0.9962     0.000143
# discharge       7050         7068 0.9962     0.000143
# discharge       7075         7092 0.9948     0.000143
# discharge       7098         7116 0.9888     0.000141
# discharge       7123         7140 0.9942     0.000143
# discharge       7147         7164 0.9937     0.000142
# discharge       7171         7189 0.9981     0.000144
# discharge       7195         7213 0.3950     0.000027
# discharge       7219         7237 0.9972     0.000143
# discharge       7243         7260 0.9879     0.000141
# discharge       7267         7284 0.9864     0.000141
# discharge       7291         7309 0.2661     0.000013
# discharge       7314         7333 0.9288     0.000126
# discharge       7341         7357 0.9945     0.000143
# discharge       7365         7381 0.8107     0.000099
# discharge       7389         7406 0.8174     0.000100
# discharge       7413         7429 0.9847     0.000140
# discharge       7437         7454 0.9841     0.000140
# discharge       7460         7477 0.2178     0.000009
# discharge       7485         7501 0.9972     0.000143
# discharge       7509         7528 0.0944     0.000002
# discharge       7531         7551 0.9384     0.000129
# discharge       7557         7573 0.3466     0.000022
# discharge       7579         7597 0.9975     0.000143
# discharge       7603         7624 0.9892     0.000141
# discharge       7625         7645 0.0208     0.000000
# discharge       7651         7669 0.9982     0.000144
# discharge       7675         7694 0.9986     0.000144
# discharge       7699         7717 0.9968     0.000143
# discharge       7725         7741 0.8833     0.000115
# discharge       7749         7765 0.9857     0.000140
# discharge       7771         7789 0.9968     0.000143
# discharge       7794         7813 0.9880     0.000141
# discharge       7818         7837 0.9949     0.000143
# discharge       7843         7862 0.9992     0.000144
# discharge       7868         7885 0.9978     0.000143
# discharge       7891         7909 0.9935     0.000142
# discharge       7916         7933 0.6920     0.000074
# discharge       7938         7960 0.9945     0.000143
# discharge       7963         7981 0.1402     0.000004
# discharge       7987         8005 0.9974     0.000143
# discharge       8010         8029 0.9985     0.000144
# discharge       8035         8054 0.9992     0.000144
# discharge       8061         8077 0.8510     0.000108
# discharge       8083         8101 0.9973     0.000143
# discharge       8106         8125 0.9979     0.000143
# discharge       8133         8149 0.9973     0.000143
# discharge       8154         8173 0.9972     0.000143
# discharge       8178         8197 0.9986     0.000144
# discharge       8203         8223 0.0864     0.000002
# discharge       8225         8246 0.9349     0.000128
# discharge       8253         8270 0.9279     0.000126
# discharge       8277         8293 0.6974     0.000076
# discharge       8299         8317 0.9979     0.000143
# discharge       8323         8344 0.5170     0.000044
# discharge       8349         8365 0.3180     0.000019
# discharge       8368         8370 0.0614     0.000001
# discharge       8371         8389 0.6269     0.000062
# discharge       8396         8414 0.0939     0.000002
# discharge       8417         8438 0.3669     0.000024
# discharge       8444         8465 0.7601     0.000088
# discharge       8469         8485 0.1002     0.000002
# discharge       8491         8509 0.9976     0.000143
# discharge       8514         8533 0.9978     0.000143
# discharge       8539         8557 0.9986     0.000144
# discharge       8563         8581 0.9982     0.000144
# discharge       8587         8606 0.4128     0.000030
# discharge       8611         8632 0.1364     0.000004
# discharge       8635         8654 0.2374     0.000011
# discharge       8660         8678 0.8520     0.000108
# discharge       8685         8701 0.8553     0.000109
# discharge       8702         8726 0.1389     0.000004
# discharge       8733         8750 0.9989     0.000144
#
# Total Estimated Degradation: 0.039262
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2024.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2024.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2024.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2024.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2023.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2023.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2023.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2023.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2022.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2022.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2022.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2022.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2021.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2021.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2021.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2021.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2020.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2020.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2020.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2020.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2019.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2019.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2019.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2019.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2018.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2018.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2018.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2018.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2017.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2017.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2017.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2017.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2016.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2016.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2016.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2016.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2015.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2015.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2015.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2015.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2014.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2014.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2014.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2014.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2013.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2013.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2013.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2013.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2012.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2012.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2012.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2012.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2011.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2011.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2011.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2011.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2010.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2010.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2010.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2010.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2009.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2009.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2009.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2009.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2008.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2008.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2008.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2008.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2007.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2007.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2007.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2007.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2006.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2006.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2006.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2006.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2005.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2005.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2005.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2005.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2004.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2004.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2004.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2004.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2003.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2003.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2003.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2003.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2002.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2002.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2002.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2002.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2001.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2001.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2001.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2001.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_2000.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_2000.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_2000.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_2000.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1999.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1999.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1999.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1999.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1998.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1998.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1998.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1998.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1997.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1997.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1997.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1997.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1996.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1996.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1996.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1996.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1995.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1995.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1995.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1995.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1994.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1994.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1994.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1994.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1993.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1993.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1993.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1993.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1992.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1992.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1992.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1992.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1991.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1991.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1991.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1991.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1990.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1990.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1990.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1990.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1989.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1989.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1989.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1989.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1988.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1988.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1988.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1988.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1987.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1987.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1987.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1987.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1986.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1986.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1986.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1986.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1985.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1985.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1985.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1985.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1984.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1984.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1984.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1984.png
# Saved dispatch data to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_data_1983.csv
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1983.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1983.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1983.png
# ...
# Saved hourly dispatch table to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\hourly_dispatch_1980.csv
# Saved battery cycles to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\cycles_1980.csv
# Saved dispatch plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\dispatch_profile_1980.png
#
# === Unmet Load Across Years ===
# Year 2024: Unmet Load = 388784414.51 kWh
# Year 2023: Unmet Load = 386200688.43 kWh
# Year 2022: Unmet Load = 354203036.13 kWh
# Year 2021: Unmet Load = 380100480.35 kWh
# Year 2020: Unmet Load = 412237247.79 kWh
# Year 2019: Unmet Load = 442133911.09 kWh
# Year 2018: Unmet Load = 430925832.88 kWh
# Year 2017: Unmet Load = 396320521.37 kWh
# Year 2016: Unmet Load = 383892934.80 kWh
# Year 2015: Unmet Load = 421420419.92 kWh
# Year 2014: Unmet Load = 377857710.74 kWh
# Year 2013: Unmet Load = 395731801.97 kWh
# Year 2012: Unmet Load = 369868557.21 kWh
# Year 2011: Unmet Load = 370301036.48 kWh
# Year 2010: Unmet Load = 361152121.56 kWh
# Year 2009: Unmet Load = 402414009.42 kWh
# Year 2008: Unmet Load = 360140467.50 kWh
# Year 2007: Unmet Load = 363592290.87 kWh
# Year 2006: Unmet Load = 353465815.13 kWh
# Year 2005: Unmet Load = 343597180.22 kWh
# Year 2004: Unmet Load = 391603510.53 kWh
# Year 2003: Unmet Load = 379390080.57 kWh
# Year 2002: Unmet Load = 385224142.00 kWh
# Year 2001: Unmet Load = 364742925.20 kWh
# Year 2000: Unmet Load = 345701258.73 kWh
# Year 1999: Unmet Load = 328973767.18 kWh
# Year 1998: Unmet Load = 380619267.74 kWh
# Year 1997: Unmet Load = 388133067.42 kWh
# Year 1996: Unmet Load = 353256066.16 kWh
# Year 1995: Unmet Load = 343151573.21 kWh
# Year 1994: Unmet Load = 425525658.73 kWh
# Year 1993: Unmet Load = 429176358.33 kWh
# Year 1992: Unmet Load = 422599772.60 kWh
# Year 1991: Unmet Load = 478203724.51 kWh
# Year 1990: Unmet Load = 391397460.18 kWh
# Year 1989: Unmet Load = 405048897.56 kWh
# Year 1988: Unmet Load = 334246468.57 kWh
# Year 1987: Unmet Load = 410889670.76 kWh
# Year 1986: Unmet Load = 403977761.54 kWh
# Year 1985: Unmet Load = 380622841.35 kWh
# Year 1984: Unmet Load = 376032012.11 kWh
# Year 1983: Unmet Load = 407967653.16 kWh
# Year 1982: Unmet Load = 414705594.20 kWh
# Year 1981: Unmet Load = 365394141.97 kWh
# Year 1980: Unmet Load = 357573374.96 kWh
#
# Average Unmet Load (1979-2024): 385744389.50 kWh
# Min Unmet Load: 328973767.18 kWh (Year 1999)
# Max Unmet Load: 478203724.51 kWh (Year 1991)
# Starting capacity, cost, and utilization metrics collection...
# Processing year 2024 for capacity, cost, and utilization metrics...
# Year 2024: Dispatch simulation successful, calculating metrics...
# $41488260.30 is the replacement cost each year for degradation
# Year 2024: Metrics added - Utilization: 87.09%, NPC: 2392452204.50, Unmet: 388784414.51 kWh
# Processing year 2023 for capacity, cost, and utilization metrics...
# Year 2023: Dispatch simulation successful, calculating metrics...
# $41026481.73 is the replacement cost each year for degradation
# Year 2023: Metrics added - Utilization: 87.38%, NPC: 2386584971.84, Unmet: 386200688.43 kWh
# Processing year 2022 for capacity, cost, and utilization metrics...
# Year 2022: Dispatch simulation successful, calculating metrics...
# $43265348.27 is the replacement cost each year for degradation
# Year 2022: Metrics added - Utilization: 85.71%, NPC: 2415031399.89, Unmet: 354203036.13 kWh
# Processing year 2021 for capacity, cost, and utilization metrics...
# Year 2021: Dispatch simulation successful, calculating metrics...
# $41147687.14 is the replacement cost each year for degradation
# Year 2021: Metrics added - Utilization: 88.24%, NPC: 2388124974.70, Unmet: 380100480.35 kWh
# Processing year 2020 for capacity, cost, and utilization metrics...
# Year 2020: Dispatch simulation successful, calculating metrics...
# $39753065.00 is the replacement cost each year for degradation
# Year 2020: Metrics added - Utilization: 87.91%, NPC: 2370405285.84, Unmet: 412237247.79 kWh
# Processing year 2019 for capacity, cost, and utilization metrics...
# Year 2019: Dispatch simulation successful, calculating metrics...
# $38696989.33 is the replacement cost each year for degradation
# Year 2019: Metrics added - Utilization: 87.70%, NPC: 2356987076.21, Unmet: 442133911.09 kWh
# Processing year 2018 for capacity, cost, and utilization metrics...
# Year 2018: Dispatch simulation successful, calculating metrics...
# $38453856.35 is the replacement cost each year for degradation
# Year 2018: Metrics added - Utilization: 88.59%, NPC: 2353897894.77, Unmet: 430925832.88 kWh
# Processing year 2017 for capacity, cost, and utilization metrics...
# Year 2017: Dispatch simulation successful, calculating metrics...
# $40843557.12 is the replacement cost each year for degradation
# Year 2017: Metrics added - Utilization: 87.23%, NPC: 2384260781.51, Unmet: 396320521.37 kWh
# Processing year 2016 for capacity, cost, and utilization metrics...
# Year 2016: Dispatch simulation successful, calculating metrics...
# $41505127.24 is the replacement cost each year for degradation
# Year 2016: Metrics added - Utilization: 87.74%, NPC: 2392666511.16, Unmet: 383892934.80 kWh
# Processing year 2015 for capacity, cost, and utilization metrics...
# Year 2015: Dispatch simulation successful, calculating metrics...
# $39215128.55 is the replacement cost each year for degradation
# Year 2015: Metrics added - Utilization: 88.15%, NPC: 2363570411.97, Unmet: 421420419.92 kWh
# Processing year 2014 for capacity, cost, and utilization metrics...
# Year 2014: Dispatch simulation successful, calculating metrics...
# $41740033.26 is the replacement cost each year for degradation
# Year 2014: Metrics added - Utilization: 86.83%, NPC: 2395651163.02, Unmet: 377857710.74 kWh
# Processing year 2013 for capacity, cost, and utilization metrics...
# Year 2013: Dispatch simulation successful, calculating metrics...
# $41334620.03 is the replacement cost each year for degradation
# Year 2013: Metrics added - Utilization: 87.08%, NPC: 2390500093.07, Unmet: 395731801.97 kWh
# Processing year 2012 for capacity, cost, and utilization metrics...
# Year 2012: Dispatch simulation successful, calculating metrics...
# $41734234.24 is the replacement cost each year for degradation
# Year 2012: Metrics added - Utilization: 86.85%, NPC: 2395577482.37, Unmet: 369868557.21 kWh
# Processing year 2011 for capacity, cost, and utilization metrics...
# Year 2011: Dispatch simulation successful, calculating metrics...
# $42030747.02 is the replacement cost each year for degradation
# Year 2011: Metrics added - Utilization: 87.56%, NPC: 2399344892.84, Unmet: 370301036.48 kWh
# Processing year 2010 for capacity, cost, and utilization metrics...
# Year 2010: Dispatch simulation successful, calculating metrics...
# $42942120.54 is the replacement cost each year for degradation
# Year 2010: Metrics added - Utilization: 87.06%, NPC: 2410924556.52, Unmet: 361152121.56 kWh
# Processing year 2009 for capacity, cost, and utilization metrics...
# Year 2009: Dispatch simulation successful, calculating metrics...
# $40207665.09 is the replacement cost each year for degradation
# Year 2009: Metrics added - Utilization: 87.71%, NPC: 2376181310.73, Unmet: 402414009.42 kWh
# Processing year 2008 for capacity, cost, and utilization metrics...
# Year 2008: Dispatch simulation successful, calculating metrics...
# $42307709.93 is the replacement cost each year for degradation
# Year 2008: Metrics added - Utilization: 85.82%, NPC: 2402863908.09, Unmet: 360140467.50 kWh
# Processing year 2007 for capacity, cost, and utilization metrics...
# Year 2007: Dispatch simulation successful, calculating metrics...
# $43229903.55 is the replacement cost each year for degradation
# Year 2007: Metrics added - Utilization: 86.59%, NPC: 2414581048.98, Unmet: 363592290.87 kWh
# Processing year 2006 for capacity, cost, and utilization metrics...
# Year 2006: Dispatch simulation successful, calculating metrics...
# $43481965.66 is the replacement cost each year for degradation
# Year 2006: Metrics added - Utilization: 86.25%, NPC: 2417783681.40, Unmet: 353465815.13 kWh
# Processing year 2005 for capacity, cost, and utilization metrics...
# Year 2005: Dispatch simulation successful, calculating metrics...
# $44451385.10 is the replacement cost each year for degradation
# Year 2005: Metrics added - Utilization: 86.31%, NPC: 2430100860.74, Unmet: 343597180.22 kWh
# Processing year 2004 for capacity, cost, and utilization metrics...
# Year 2004: Dispatch simulation successful, calculating metrics...
# $40311194.07 is the replacement cost each year for degradation
# Year 2004: Metrics added - Utilization: 87.25%, NPC: 2377496721.72, Unmet: 391603510.53 kWh
# Processing year 2003 for capacity, cost, and utilization metrics...
# Year 2003: Dispatch simulation successful, calculating metrics...
# $41437640.54 is the replacement cost each year for degradation
# Year 2003: Metrics added - Utilization: 86.45%, NPC: 2391809043.58, Unmet: 379390080.57 kWh
# Processing year 2002 for capacity, cost, and utilization metrics...
# Year 2002: Dispatch simulation successful, calculating metrics...
# $41352325.62 is the replacement cost each year for degradation
# Year 2002: Metrics added - Utilization: 86.69%, NPC: 2390725055.50, Unmet: 385224142.00 kWh
# Processing year 2001 for capacity, cost, and utilization metrics...
# Year 2001: Dispatch simulation successful, calculating metrics...
# $42940342.34 is the replacement cost each year for degradation
# Year 2001: Metrics added - Utilization: 85.81%, NPC: 2410901963.17, Unmet: 364742925.20 kWh
# Processing year 2000 for capacity, cost, and utilization metrics...
# Year 2000: Dispatch simulation successful, calculating metrics...
# $43996148.35 is the replacement cost each year for degradation
# Year 2000: Metrics added - Utilization: 85.50%, NPC: 2424316746.62, Unmet: 345701258.73 kWh
# Processing year 1999 for capacity, cost, and utilization metrics...
# Year 1999: Dispatch simulation successful, calculating metrics...
# $44396651.89 is the replacement cost each year for degradation
# Year 1999: Metrics added - Utilization: 85.38%, NPC: 2429405435.47, Unmet: 328973767.18 kWh
# Processing year 1998 for capacity, cost, and utilization metrics...
# Year 1998: Dispatch simulation successful, calculating metrics...
# $41911163.42 is the replacement cost each year for degradation
# Year 1998: Metrics added - Utilization: 87.21%, NPC: 2397825496.28, Unmet: 380619267.74 kWh
# Processing year 1997 for capacity, cost, and utilization metrics...
# Year 1997: Dispatch simulation successful, calculating metrics...
# $41422600.91 is the replacement cost each year for degradation
# Year 1997: Metrics added - Utilization: 86.86%, NPC: 2391617954.12, Unmet: 388133067.42 kWh
# Processing year 1996 for capacity, cost, and utilization metrics...
# Year 1996: Dispatch simulation successful, calculating metrics...
# $43414025.50 is the replacement cost each year for degradation
# Year 1996: Metrics added - Utilization: 86.56%, NPC: 2416920452.34, Unmet: 353256066.16 kWh
# Processing year 1995 for capacity, cost, and utilization metrics...
# Year 1995: Dispatch simulation successful, calculating metrics...
# $43859818.66 is the replacement cost each year for degradation
# Year 1995: Metrics added - Utilization: 86.25%, NPC: 2422584578.75, Unmet: 343151573.21 kWh
# Processing year 1994 for capacity, cost, and utilization metrics...
# Year 1994: Dispatch simulation successful, calculating metrics...
# $39364441.12 is the replacement cost each year for degradation
# Year 1994: Metrics added - Utilization: 86.89%, NPC: 2365467536.79, Unmet: 425525658.73 kWh
# Processing year 1993 for capacity, cost, and utilization metrics...
# Year 1993: Dispatch simulation successful, calculating metrics...
# $38804879.62 is the replacement cost each year for degradation
# Year 1993: Metrics added - Utilization: 88.68%, NPC: 2358357900.82, Unmet: 429176358.33 kWh
# Processing year 1992 for capacity, cost, and utilization metrics...
# Year 1992: Dispatch simulation successful, calculating metrics...
# $38778992.19 is the replacement cost each year for degradation
# Year 1992: Metrics added - Utilization: 87.94%, NPC: 2358028982.18, Unmet: 422599772.60 kWh
# Processing year 1991 for capacity, cost, and utilization metrics...
# Year 1991: Dispatch simulation successful, calculating metrics...
# $35215199.51 is the replacement cost each year for degradation
# Year 1991: Metrics added - Utilization: 89.38%, NPC: 2312748403.55, Unmet: 478203724.51 kWh
# Processing year 1990 for capacity, cost, and utilization metrics...
# Year 1990: Dispatch simulation successful, calculating metrics...
# $40780364.60 is the replacement cost each year for degradation
# Year 1990: Metrics added - Utilization: 86.82%, NPC: 2383457874.66, Unmet: 391397460.18 kWh
# Processing year 1989 for capacity, cost, and utilization metrics...
# Year 1989: Dispatch simulation successful, calculating metrics...
# $39567120.51 is the replacement cost each year for degradation
# Year 1989: Metrics added - Utilization: 87.74%, NPC: 2368042725.77, Unmet: 405048897.56 kWh
# Processing year 1988 for capacity, cost, and utilization metrics...
# Year 1988: Dispatch simulation successful, calculating metrics...
# $44291820.18 is the replacement cost each year for degradation
# Year 1988: Metrics added - Utilization: 85.07%, NPC: 2428073472.23, Unmet: 334246468.57 kWh
# Processing year 1987 for capacity, cost, and utilization metrics...
# Year 1987: Dispatch simulation successful, calculating metrics...
# $39951233.21 is the replacement cost each year for degradation
# Year 1987: Metrics added - Utilization: 87.28%, NPC: 2372923157.17, Unmet: 410889670.76 kWh
# Processing year 1986 for capacity, cost, and utilization metrics...
# Year 1986: Dispatch simulation successful, calculating metrics...
# $40924817.75 is the replacement cost each year for degradation
# Year 1986: Metrics added - Utilization: 87.17%, NPC: 2385293256.99, Unmet: 403977761.54 kWh
# Processing year 1985 for capacity, cost, and utilization metrics...
# Year 1985: Dispatch simulation successful, calculating metrics...
# $42047375.00 is the replacement cost each year for degradation
# Year 1985: Metrics added - Utilization: 87.16%, NPC: 2399556163.47, Unmet: 380622841.35 kWh
# Processing year 1984 for capacity, cost, and utilization metrics...
# Year 1984: Dispatch simulation successful, calculating metrics...
# $41811100.09 is the replacement cost each year for degradation
# Year 1984: Metrics added - Utilization: 87.75%, NPC: 2396554118.86, Unmet: 376032012.11 kWh
# Processing year 1983 for capacity, cost, and utilization metrics...
# Year 1983: Dispatch simulation successful, calculating metrics...
# $40484267.60 is the replacement cost each year for degradation
# Year 1983: Metrics added - Utilization: 88.28%, NPC: 2379695746.86, Unmet: 407967653.16 kWh
# Processing year 1982 for capacity, cost, and utilization metrics...
# Year 1982: Dispatch simulation successful, calculating metrics...
# $39715451.39 is the replacement cost each year for degradation
# Year 1982: Metrics added - Utilization: 87.99%, NPC: 2369927377.63, Unmet: 414705594.20 kWh
# Processing year 1981 for capacity, cost, and utilization metrics...
# Year 1981: Dispatch simulation successful, calculating metrics...
# $43534759.71 is the replacement cost each year for degradation
# Year 1981: Metrics added - Utilization: 86.33%, NPC: 2418454468.23, Unmet: 365394141.97 kWh
# Processing year 1980 for capacity, cost, and utilization metrics...
# Year 1980: Dispatch simulation successful, calculating metrics...
# $43730189.64 is the replacement cost each year for degradation
# Year 1980: Metrics added - Utilization: 85.80%, NPC: 2420937547.68, Unmet: 357573374.96 kWh
# Saved capacity, cost, and utilization metrics to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\capacity_and_costs_by_year.csv
# CSV file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\capacity_and_costs_by_year.csv
# Starting NPC variation plotting...
# Saved NPC variation plot to dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\npc_variation_by_year.png
# Plot file location: C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment\npc_variation_by_year.png

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === File Directory Configuration ===
folder_path = r"dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250

interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

# === Helper Function ===
def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Results Storage ===
yearly_extension_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0].copy()

        if unmet_rows.empty:
            yearly_extension_hours[year] = 0
            continue

        unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
        unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                # Apply training extension rule
        unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
            lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
        )
        unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

        columns_to_save = [
            'Hour', 'Load (kW)', 'Unmet (kW)', 'Unmet (%)',
            'Power Available (%)', 'Training Time Extension (×)', 'Extra Training Hours'
        ]
        result = unmet_rows[columns_to_save]

        # Save CSV
        save_path = os.path.join(folder_path, f"training_extension_{year}.csv")
        result.to_csv(save_path, index=False)

        # Total extra training hours
        total_extra = result['Extra Training Hours'].sum()
        yearly_extension_hours[year] = total_extra

    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_extension_hours[year] = None

# === Plotting ===
years_sorted = sorted(yearly_extension_hours.keys())
extension_values = [yearly_extension_hours[y] if yearly_extension_hours[y] is not None else 0 for y in years_sorted]

plt.figure(figsize=(12, 6))
plt.plot(years_sorted, extension_values, marker='o',label='Extended Training Time')
plt.title("Estimated Training Time Extension by Year 80% met Load Sizing (Hybrid Configuration)")
plt.xlabel("Year")
plt.ylabel("Extra Training Hours")
plt.axhline(0, color='red', linestyle='--', label='Baseline (8760h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
average_extension = np.mean([v for v in yearly_extension_hours.values() if v is not None])
print(f"\nAverage Extra Training Time (1980–2024): {average_extension:.2f} hours")

# === Print Extension Summary ===
for year in years_sorted:
    if yearly_extension_hours[year] is not None:
        print(f"{year}: {yearly_extension_hours[year]:.2f} extra training hours")
    else:
        print(f"{year}: File missing")
# Out:
# Average Extra Training Time (1980–2024): 1871.39 hours
# 1980: 1730.99 extra training hours
# 1981: 1756.87 extra training hours
# 1982: 2035.64 extra training hours
# 1983: 1964.98 extra training hours
# 1984: 1835.45 extra training hours
# 1985: 1843.53 extra training hours
# 1986: 1948.84 extra training hours
# 1987: 1987.50 extra training hours
# 1988: 1628.50 extra training hours
# 1989: 1958.55 extra training hours
# 1990: 1900.43 extra training hours
# 1991: 2321.60 extra training hours
# 1992: 2033.17 extra training hours
# 1993: 2083.80 extra training hours
# 1994: 2059.49 extra training hours
# 1995: 1673.74 extra training hours
# 1996: 1728.46 extra training hours
# 1997: 1880.22 extra training hours
# 1998: 1829.09 extra training hours
# 1999: 1600.56 extra training hours
# 2000: 1664.47 extra training hours
# 2001: 1756.48 extra training hours
# 2002: 1862.56 extra training hours
# 2003: 1836.60 extra training hours
# 2004: 1896.21 extra training hours
# 2005: 1667.46 extra training hours
# 2006: 1734.17 extra training hours
# 2007: 1765.73 extra training hours
# 2008: 1755.25 extra training hours
# 2009: 1964.08 extra training hours
# 2010: 1747.90 extra training hours
# 2011: 1807.29 extra training hours
# 2012: 1787.98 extra training hours
# 2013: 1921.55 extra training hours
# 2014: 1836.33 extra training hours
# 2015: 2045.46 extra training hours
# 2016: 1850.89 extra training hours
# 2017: 1921.04 extra training hours
# 2018: 2099.58 extra training hours
# 2019: 2138.68 extra training hours
# 2020: 2001.51 extra training hours
# 2021: 1846.45 extra training hours
# 2022: 1724.66 extra training hours
# 2023: 1881.06 extra training hours
# 2024: 1897.77 extra training hours

# %%
import os
import pandas as pd
import numpy as np

# === File Directory Configuration ===
folder_path = r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment"
years = list(range(2024, 1979, -1))

# === Results Storage ===
yearly_unmet_hours = {}

# === Process Each Year ===
for year in years:
    file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
    try:
        df = pd.read_csv(file_path)
        unmet_rows = df[df['Unmet (kW)'] > 0.00000001]
        yearly_unmet_hours[year] = len(unmet_rows)
    except FileNotFoundError:
        print(f"File not found for year {year}")
        yearly_unmet_hours[year] = None

# === Print Hourly Unmet Load Summary ===
print("\n--- Hours with Unmet Load ---")
for year in sorted(yearly_unmet_hours.keys()):
    if yearly_unmet_hours[year] is not None:
        print(f"{year}: {yearly_unmet_hours[year]} hours with unmet load")
    else:
        print(f"{year}: File missing")

# === Compute and print summary statistics for unmet load hours ===
filtered_unmet = {k: v for k, v in yearly_unmet_hours.items() if v is not None}

if filtered_unmet:
    avg_unmet = np.mean(list(filtered_unmet.values()))
    max_unmet_year = max(filtered_unmet, key=filtered_unmet.get)
    min_unmet_year = min(filtered_unmet, key=filtered_unmet.get)
    max_unmet_value = filtered_unmet[max_unmet_year]
    min_unmet_value = filtered_unmet[min_unmet_year]

    print(f"\n--- Unmet Load Summary (1980–2024) ---")
    print(f"Average Hours with Unmet Load: {avg_unmet:.2f} hours/year")
    print(f"Maximum: {max_unmet_value} hours in {max_unmet_year}")
    print(f"Minimum: {min_unmet_value} hours in {min_unmet_year}")
else:
    print("No valid data found for unmet load hours.")
# Out:
# --- Hours with Unmet Load ---
# 1980: 2460 hours with unmet load
# 1981: 2480 hours with unmet load
# 1982: 2757 hours with unmet load
# 1983: 2715 hours with unmet load
# 1984: 2559 hours with unmet load
# 1985: 2584 hours with unmet load
# 1986: 2672 hours with unmet load
# 1987: 2681 hours with unmet load
# 1988: 2334 hours with unmet load
# 1989: 2685 hours with unmet load
# 1990: 2622 hours with unmet load
# 1991: 3004 hours with unmet load
# 1992: 2739 hours with unmet load
# 1993: 2783 hours with unmet load
# 1994: 2770 hours with unmet load
# 1995: 2388 hours with unmet load
# 1996: 2442 hours with unmet load
# 1997: 2569 hours with unmet load
# 1998: 2562 hours with unmet load
# 1999: 2329 hours with unmet load
# 2000: 2360 hours with unmet load
# 2001: 2464 hours with unmet load
# 2002: 2595 hours with unmet load
# 2003: 2542 hours with unmet load
# 2004: 2604 hours with unmet load
# 2005: 2358 hours with unmet load
# 2006: 2440 hours with unmet load
# 2007: 2468 hours with unmet load
# 2008: 2465 hours with unmet load
# 2009: 2661 hours with unmet load
# 2010: 2454 hours with unmet load
# 2011: 2513 hours with unmet load
# 2012: 2497 hours with unmet load
# 2013: 2662 hours with unmet load
# 2014: 2551 hours with unmet load
# 2015: 2769 hours with unmet load
# 2016: 2581 hours with unmet load
# 2017: 2628 hours with unmet load
# 2018: 2784 hours with unmet load
# 2019: 2854 hours with unmet load
# 2020: 2705 hours with unmet load
# 2021: 2551 hours with unmet load
# 2022: 2428 hours with unmet load
# 2023: 2582 hours with unmet load
# 2024: 2604 hours with unmet load
#
# --- Unmet Load Summary (1980–2024) ---
# Average Hours with Unmet Load: 2583.44 hours/year
# Maximum: 3004 hours in 1991
# Minimum: 2329 hours in 1999

# %% [markdown]
# # Plotting the costs

# %%
import matplotlib.pyplot as plt

# === Data ===
met_load_percentages = [100, 99, 98, 95, 90, 80]
npc_values = [
    4989512449.57,
    3850917085.71,
    3576752238.55,
    3259837958.77,
    2910640043.20,
    2392421785.30
]

# === Plot ===
plt.figure(figsize=(8, 6))
plt.plot(met_load_percentages, npc_values, marker='o', linewidth=2)
plt.grid(True)
plt.title("Met Load Sizing (%) vs Net Present Cost (NPC)")
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Net Present Cost (USD)")
plt.gca().invert_xaxis()  # Optional: makes higher reliability appear left-to-right
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Folder structure for each met load level ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}

# === Years to analyze
years = list(range(1980, 2025))

# === Collect NPC values from each folder
npc_stats = {}  # met_load: [npc_1980, ..., npc_2024]

for met, folder_path in folders.items():
    file_path = os.path.join(folder_path, "capacity_and_costs_by_year.csv")
    try:
        df = pd.read_csv(file_path)
        df = df[df["Year"].isin(years)]  # Filter to only 1980–2024
        df = df.sort_values("Year")
        npc_stats[met] = df["Total_NPC"].to_numpy() / 1e9  # Convert to billion USD
    except Exception as e:
        print(f"{met}% folder error: {e}")
        npc_stats[met] = [None] * len(years)

# === Compute avg / min / max
met_levels = sorted(npc_stats.keys(), reverse=False)
avg_npc, min_npc, max_npc = [], [], []

for met in met_levels:
    data = [v for v in npc_stats[met] if v is not None]
    avg_npc.append(np.mean(data))
    min_npc.append(np.min(data))
    max_npc.append(np.max(data))

# === Plot
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_npc, marker='o', label='Average NPC', linewidth=2, color='darkblue')
plt.fill_between(met_levels, min_npc, max_npc, alpha=0.3, label='Min–Max Range')
plt.grid(True)
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Total Net Present Cost (Billion USD)")
plt.title("Total NPC vs. Met Load Sizing (1980–2024)")
plt.legend()
plt.gca().invert_xaxis()
plt.tight_layout()

# Optional: Save it
plt.savefig(r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\npc_vs_metload_all_sizings.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# === Data ===
utilization_percentages = [87.09, 79.55, 69.36, 63.09, 56.69, 46.07]  # Inverted
met_load_percentages = [80, 90, 95, 98, 99, 100]  # Y-axis values

# === Plot ===
plt.figure(figsize=(8, 6))
plt.plot(met_load_percentages,utilization_percentages, marker='o', linewidth=2, color='g')
plt.grid(True)
plt.title("Utilization vs Met Load Sizing Percentage")
plt.xlabel("Met Load Sizing Percentage (%)")
plt.ylabel("Utilization Percentage (%)")
plt.gca().invert_xaxis()  # Optional: makes higher reliability appear left-to-right
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Folder paths for each met load level ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}

# === Years to include
years = list(range(1980, 2025))

# === Gather GPU Utilization across years and folders
utilization_stats = {}  # met_load: [util_1980, ..., util_2024]

for met, folder_path in folders.items():
    file_path = os.path.join(folder_path, "capacity_and_costs_by_year.csv")
    try:
        df = pd.read_csv(file_path)
        df = df[df["Year"].isin(years)].sort_values("Year")
        utilization_stats[met] = df["Utilization_Percentage"].to_numpy()
    except Exception as e:
        print(f"{met}% folder error: {e}")
        utilization_stats[met] = [None] * len(years)

# === Compute avg / min / max
met_levels = sorted(utilization_stats.keys(), reverse=False)
avg_util, min_util, max_util = [], [], []

for met in met_levels:
    data = [v for v in utilization_stats[met] if v is not None]
    avg_util.append(np.mean(data))
    min_util.append(np.min(data))
    max_util.append(np.max(data))

# === Plotting
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_util, marker='o', label='Average Utilization', linewidth=2, color='darkgreen')
plt.fill_between(met_levels, min_util, max_util, alpha=0.3, label='Min–Max Range',color='green')
plt.grid(True)
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("GPU Utilization (%)")
plt.title("GPU Utilization vs. Met Load Sizing (1980–2024)")
plt.legend()
plt.gca().invert_xaxis()
plt.tight_layout()

# Optional: Save it
plt.savefig(r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\utilization_vs_metload_all_sizings.png")
plt.show()

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250
interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Collect training extension results ===
extension_stats = {}  # {met_load: [yearly_extension_hours]}

for met, folder_path in folders.items():
    yearly_extension_hours = []
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            unmet_rows = df[df['Unmet (kW)'] > 0].copy()
            if unmet_rows.empty:
                yearly_extension_hours.append(0)
                continue

            unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
            unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                            # Apply training extension rule
            unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
                lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
            )
            unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

            total_extra = unmet_rows['Extra Training Hours'].sum()
            yearly_extension_hours.append(total_extra)
        except Exception as e:
            print(f"{year} in {met}% folder: {e}")
            yearly_extension_hours.append(None)

    extension_stats[met] = yearly_extension_hours

# === Calculate average, min, max ===
met_levels = sorted(extension_stats.keys(), reverse=False)
avg_hours = []
min_hours = []
max_hours = []

for met in met_levels:
    data = [v for v in extension_stats[met] if v is not None]
    avg_hours.append(np.mean(data))
    min_hours.append(np.min(data))
    max_hours.append(np.max(data))

# === Plot ===
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_hours, marker='o', label='Average', linewidth=2, color='orange')
plt.fill_between(met_levels, min_hours, max_hours, alpha=0.3, label='Min-Max Range')
plt.grid(True)
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Extra Training Time (Hours)")
plt.title("Training Time Extension vs Met Load Sizing")
plt.legend()
plt.tight_layout()
plt.gca().invert_xaxis()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250
interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Collect uptime percentage results ===
uptime_stats = {}  # {met_load: [yearly_uptime_percentage]}

for met, folder_path in folders.items():
    yearly_uptime_percentages = []
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            unmet_rows = df[df['Unmet (kW)'] > 0].copy()
            if unmet_rows.empty:
                yearly_uptime_percentages.append(100.0)
                continue

            unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
            unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']

            unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
                lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
            )
            unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

            total_extra = unmet_rows['Extra Training Hours'].sum()
            uptime_percentage = (1 - total_extra / 8760) * 100
            yearly_uptime_percentages.append(uptime_percentage)
        except Exception as e:
            print(f"{year} in {met}% folder: {e}")
            yearly_uptime_percentages.append(None)

    uptime_stats[met] = yearly_uptime_percentages

# === Calculate average, min, max ===
met_levels = sorted(uptime_stats.keys(), reverse=False)
avg_uptime = []
min_uptime = []
max_uptime = []

for met in met_levels:
    data = [v for v in uptime_stats[met] if v is not None]
    avg_uptime.append(np.mean(data))
    min_uptime.append(np.min(data))
    max_uptime.append(np.max(data))

# === Plot ===
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_uptime, marker='o', label='Average', linewidth=2, color='orange')
plt.fill_between(met_levels, min_uptime, max_uptime, alpha=0.3, label='Min-Max Range')
plt.grid(True)
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Uptime (%)")
plt.title("AI Training Power Uptime vs Met Load Sizing")
plt.legend()
plt.tight_layout()
plt.gca().invert_xaxis()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250
interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Collect uptime percentage results ===
uptime_stats = {}  # {met_load: [yearly_uptime_percentage]}

for met, folder_path in folders.items():
    yearly_uptime_percentages = []
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            unmet_rows = df[df['Unmet (kW)'] > 0].copy()
            if unmet_rows.empty:
                yearly_uptime_percentages.append(100.0)
                continue

            unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
            unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']

            unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
                lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
            )
            unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

            total_extra = unmet_rows['Extra Training Hours'].sum()
            uptime_percentage = (1 - total_extra / 8760) * 100
            yearly_uptime_percentages.append(uptime_percentage)
        except Exception as e:
            print(f"{year} in {met}% folder: {e}")
            yearly_uptime_percentages.append(None)

    uptime_stats[met] = yearly_uptime_percentages

# === Calculate average, min, max ===
met_levels = sorted(uptime_stats.keys(), reverse=False)
avg_uptime = []
min_uptime = []
max_uptime = []

for met in met_levels:
    data = [v for v in uptime_stats[met] if v is not None]
    avg_uptime.append(np.mean(data))
    min_uptime.append(np.min(data))
    max_uptime.append(np.max(data))

# === Compute net uptimes with combined multiplier (0.99 × 0.99671 = 0.986743) ===
combined_factor = 0.99 * 0.99671  # ≈ 0.986743
avg_uptime_combined = [u * combined_factor for u in avg_uptime]
min_uptime_combined = [u * combined_factor for u in min_uptime]
max_uptime_combined = [u * combined_factor for u in max_uptime]

# === Plot ===
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_uptime, marker='o', label='Raw Avg Uptime', linewidth=2, color='orange')
plt.plot(met_levels, avg_uptime_combined, marker='^', label='Net Uptime (×0.99 × 0.99671)', linestyle='--', color='blue')
plt.fill_between(met_levels, min_uptime_combined, max_uptime_combined, alpha=0.25, color='blue', label='Net Min-Max Range')
plt.fill_between(met_levels, min_uptime, max_uptime, alpha=0.3, color='orange', label='Raw Min-Max Range')
plt.grid(True)
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Uptime (%)")
plt.title("AI Training Power Uptime vs Met Load Sizing (Raw and Net Adjusted)")
plt.legend()
plt.tight_layout()
plt.gca().invert_xaxis()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))

# === Training Extension Interpolation Setup ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250
interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Collect uptime percentage results ===
uptime_stats = {}  # {met_load: [yearly_uptime_percentage]}

for met, folder_path in folders.items():
    yearly_uptime_percentages = []
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            unmet_rows = df[df['Unmet (kW)'] > 0].copy()
            if unmet_rows.empty:
                yearly_uptime_percentages.append(100.0)
                continue

            unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
            unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']

            unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
                lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
            )
            unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1

            total_extra = unmet_rows['Extra Training Hours'].sum()
            uptime_percentage = (1 - total_extra / 8760) * 100
            yearly_uptime_percentages.append(uptime_percentage)
        except Exception as e:
            print(f"{year} in {met}% folder: {e}")
            yearly_uptime_percentages.append(None)

    uptime_stats[met] = yearly_uptime_percentages

# === Calculate average, min, max ===
met_levels = sorted(uptime_stats.keys(), reverse=False)
avg_uptime = []
min_uptime = []
max_uptime = []

for met in met_levels:
    data = [v for v in uptime_stats[met] if v is not None]
    avg_uptime.append(np.mean(data))
    min_uptime.append(np.min(data))
    max_uptime.append(np.max(data))

# === Compute net uptimes (×0.99 × 0.99671 = 0.986743) ===
combined_factor = 0.99 * 0.99671
avg_uptime_combined = [u * combined_factor for u in avg_uptime]
min_uptime_combined = [u * combined_factor for u in min_uptime]
max_uptime_combined = [u * combined_factor for u in max_uptime]

# === Convert uptimes to training extension hours ===
def uptime_to_extension_hours(uptime_percent):
    return (1 - uptime_percent / 100) * 8760

raw_extension_avg = [uptime_to_extension_hours(u) for u in avg_uptime]
raw_extension_min = [uptime_to_extension_hours(u) for u in max_uptime]  # Max uptime = min extension
raw_extension_max = [uptime_to_extension_hours(u) for u in min_uptime]  # Min uptime = max extension

combined_extension_avg = [uptime_to_extension_hours(u) for u in avg_uptime_combined]
combined_extension_min = [uptime_to_extension_hours(u) for u in max_uptime_combined]
combined_extension_max = [uptime_to_extension_hours(u) for u in min_uptime_combined]

# === Plot ===
plt.figure(figsize=(10, 6))
plt.plot(met_levels, raw_extension_avg, marker='o', label='Raw Avg Extension Hours', color='orange')
plt.plot(met_levels, combined_extension_avg, marker='^', linestyle='--', label='Net Avg Extension Hours (×0.99×0.99671)', color='blue')

plt.fill_between(met_levels, raw_extension_min, raw_extension_max, alpha=0.3, color='orange', label='Raw Min-Max Range')
plt.fill_between(met_levels, combined_extension_min, combined_extension_max, alpha=0.25, color='blue', label='Net Min-Max Range')

plt.grid(True)
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Training Extension Hours")
plt.title("Training Extension Hours vs Met Load Sizing (with Min-Max Ranges)")
plt.legend()
plt.tight_layout()
plt.gca().invert_xaxis()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))

# === Collect unmet hour results ===
unmet_stats = {}  # {met_load: [yearly_unmet_hours]}

for met, folder_path in folders.items():
    yearly_unmet_hours = []
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            hours_with_unmet = (df['Unmet (kW)'] > 0.00000001).sum()
            yearly_unmet_hours.append(hours_with_unmet)
        except Exception as e:
            print(f"{year} in {met}% folder: {e}")
            yearly_unmet_hours.append(None)

    unmet_stats[met] = yearly_unmet_hours

# === Calculate average, min, max ===
met_levels = sorted(unmet_stats.keys(), reverse=False)
avg_unmet = []
min_unmet = []
max_unmet = []

for met in met_levels:
    data = [v for v in unmet_stats[met] if v is not None]
    avg_unmet.append(np.mean(data))
    min_unmet.append(np.min(data))
    max_unmet.append(np.max(data))

# === Plot ===
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_unmet, marker='o', label='Average', linewidth=2, color='green')
plt.fill_between(met_levels, min_unmet, max_unmet, alpha=0.3, label='Min–Max Range', color='crimson')
plt.grid(True)

plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Hours with Unmet Load")
plt.title("Unmet Hours vs Met Load Sizing")
plt.legend()
plt.gca().invert_xaxis()  # 100 → 80
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))

# === Collect unmet hours and compute uptimes ===
uptime_stats = {}

for met, folder_path in folders.items():
    uptime_yearly = []
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            unmet_hours = (df['Unmet (kW)'] > 0.00000001).sum()
            uptime = (1 - (unmet_hours / 8760)) * 100
            uptime_yearly.append(uptime)
        except Exception as e:
            print(f"{year} in {met}% folder: {e}")
            uptime_yearly.append(None)

    uptime_stats[met] = uptime_yearly

# === Aggregate statistics ===
met_levels = sorted(uptime_stats.keys(), reverse=False)
avg_uptime = []
min_uptime = []
max_uptime = []

for met in met_levels:
    data = [v for v in uptime_stats[met] if v is not None]
    avg_uptime.append(np.mean(data))
    min_uptime.append(np.min(data))
    max_uptime.append(np.max(data))

# === Plot ===
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_uptime, marker='o', label='Average', linewidth=2, color='crimson')
plt.fill_between(met_levels, min_uptime, max_uptime, alpha=0.3, label='Min–Max Range', color='green')
plt.grid(True)

plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Renewable Uptime (%)")
plt.title("Renewable Uptime vs Met Load Sizing")
plt.legend()
plt.gca().invert_xaxis()
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))

# === Collect unmet hours and compute uptimes ===
uptime_stats = {}

for met, folder_path in folders.items():
    uptime_yearly = []
    for year in years:
        file_path = os.path.join(folder_path, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)
            unmet_hours = (df['Unmet (kW)'] > 0.00000001).sum()
            uptime = (1 - (unmet_hours / 8760)) * 100
            uptime_yearly.append(uptime)
        except Exception as e:
            print(f"{year} in {met}% folder: {e}")
            uptime_yearly.append(None)

    uptime_stats[met] = uptime_yearly

# === Aggregate statistics ===
met_levels = sorted(uptime_stats.keys(), reverse=False)
avg_uptime = []
min_uptime = []
max_uptime = []

for met in met_levels:
    data = [v for v in uptime_stats[met] if v is not None]
    avg_uptime.append(np.mean(data))
    min_uptime.append(np.min(data))
    max_uptime.append(np.max(data))

# === Reliability-adjusted uptime (× 0.9867429)
adjustment_factor = 0.99 * 0.99671  # = 0.9867429
avg_uptime_adj = [u * adjustment_factor for u in avg_uptime]
min_uptime_adj = [u * adjustment_factor for u in min_uptime]
max_uptime_adj = [u * adjustment_factor for u in max_uptime]

# === Plot ===
plt.figure(figsize=(10, 6))

# Original uptime
plt.plot(met_levels, avg_uptime, marker='o', label='Renewable Uptime – Avg', linewidth=2, color='crimson')
plt.fill_between(met_levels, min_uptime, max_uptime, alpha=0.3, label='Renewable Uptime – Min–Max', color='green')

# Adjusted uptime
plt.plot(met_levels, avg_uptime_adj, marker='s', linestyle='--', linewidth=2,
         label='Adjusted Uptime (×0.9867)', color='blue')
plt.fill_between(met_levels, min_uptime_adj, max_uptime_adj, alpha=0.2,
                 label='Adjusted Min–Max', color='blue')

plt.grid(True)
plt.xlabel("Met Load Sizing (%)")
plt.ylabel("Renewable Uptime (%)")
plt.title("Renewable Uptime vs Met Load Sizing (Raw vs Adjusted)")
plt.legend()
plt.gca().invert_xaxis()
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# === Directory setup ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}
years = list(range(1980, 2025))
met_order = sorted(folders.keys(), reverse=True)

# === Interpolator for training extension ===
power_watts = np.array([250, 225, 200, 175, 150, 125, 100, 50, 0])
training_times = np.array([40000, 42000, 42500, 45000, 46000, 50000, 58000, 70000, 80000])
baseline_time = training_times[0]
extension_factors = training_times / baseline_time
power_missing_fraction = (250 - power_watts) / 250
interpolator = interp1d(power_missing_fraction, extension_factors, kind='cubic', fill_value='extrapolate')

def get_training_extension(power_percent):
    power_percent = np.clip(power_percent, 0, 100)
    missing_fraction = 1 - (power_percent / 100)
    return interpolator(missing_fraction)

# === Initialize DataFrames ===
unmet_df = pd.DataFrame(index=years)
uptime_df = pd.DataFrame(index=years)
extension_df = pd.DataFrame(index=years)

# === Main loop ===
for met, folder in folders.items():
    unmet_list = []
    extension_list = []

    for year in years:
        file_path = os.path.join(folder, f"dispatch_data_{year}.csv")
        try:
            df = pd.read_csv(file_path)

            # Count hours with unmet load
            unmet_hours = (df['Unmet (kW)'] > 0.00000001).sum()
            unmet_list.append(unmet_hours)

            # Training extension calculation
            unmet_rows = df[df['Unmet (kW)'] > 0].copy()
            if unmet_rows.empty:
                extension_list.append(0)
            else:
                unmet_rows['Unmet (%)'] = (unmet_rows['Unmet (kW)'] / unmet_rows['Load (kW)']) * 100
                unmet_rows['Power Available (%)'] = 100 - unmet_rows['Unmet (%)']
                                # Apply training extension rule
                unmet_rows['Training Time Extension (×)'] = unmet_rows['Power Available (%)'].apply(
                    lambda p: 2.0 if p < (100 / 250 * 100) else get_training_extension(p)
                )
                unmet_rows['Extra Training Hours'] = unmet_rows['Training Time Extension (×)'] - 1
                extension_list.append(unmet_rows['Extra Training Hours'].sum())

        except Exception as e:
            print(f"Failed for {year} in {met}% folder: {e}")
            unmet_list.append(np.nan)
            extension_list.append(np.nan)

    unmet_df[met] = unmet_list
    extension_df[met] = extension_list
    uptime_df[met] = 100 * (1 - unmet_df[met] / 8760)

# === Helper function for contrast-aware text ===
def annotate_with_contrast(ax, data, cmap_name, fmt="{:.1f}"):
    norm = plt.Normalize(vmin=np.nanmin(data), vmax=np.nanmax(data))
    cmap = plt.cm.get_cmap(cmap_name)

    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            val = data[i, j]
            if not np.isnan(val):
                color_rgb = cmap(norm(val))[:3]
                brightness = np.dot(color_rgb, [0.299, 0.587, 0.114])
                text_color = 'black' if brightness > 0.5 else 'white'
                ax.text(j, i, fmt.format(val), ha='center', va='center',
                        fontsize=6.5, rotation=90, color=text_color)

# === Plot 1: Unmet Load Hours ===
plt.figure(figsize=(6, 6))
data1 = unmet_df[met_order].T.values
ax1 = plt.gca()
im1 = ax1.imshow(data1, aspect='auto', cmap='plasma', interpolation='nearest')
ax1.set_title('Unmet Load Hours (1980–2024)')
ax1.set_ylabel('Met Load Sizing')
ax1.set_yticks(np.arange(len(met_order)))
ax1.set_yticklabels([f"{ml}%" for ml in met_order])
ax1.set_xticks(np.arange(0, len(years), 5))
ax1.set_xticklabels(years[::5], rotation=45)
plt.colorbar(im1, ax=ax1, label='Hours')
annotate_with_contrast(ax1, data1, cmap_name='plasma', fmt="{:.0f}")
plt.tight_layout()
plt.show()

# === Plot 2: Renewable Uptime (%) ===
plt.figure(figsize=(6, 6))
data2 = uptime_df[met_order].T.values
ax2 = plt.gca()
im2 = ax2.imshow(data2, aspect='auto', cmap='viridis', interpolation='nearest')
ax2.set_title('Renewable Uptime (%) (1980–2024)')
ax2.set_ylabel('Met Load Sizing')
ax2.set_yticks(np.arange(len(met_order)))
ax2.set_yticklabels([f"{ml}%" for ml in met_order])
ax2.set_xticks(np.arange(0, len(years), 5))
ax2.set_xticklabels(years[::5], rotation=45)
plt.colorbar(im2, ax=ax2, label='%')
annotate_with_contrast(ax2, data2, cmap_name='viridis', fmt="{:.3f}")
plt.tight_layout()
plt.show()

# === Plot 3: Training Time Extension ===
plt.figure(figsize=(6, 6))
data3 = extension_df[met_order].T.values
ax3 = plt.gca()
im3 = ax3.imshow(data3, aspect='auto', cmap='inferno', interpolation='nearest')
ax3.set_title('Training Time Extension (hrs) (1980–2024)')
ax3.set_ylabel('Met Load Sizing')
ax3.set_yticks(np.arange(len(met_order)))
ax3.set_yticklabels([f"{ml}%" for ml in met_order])
ax3.set_xticks(np.arange(0, len(years), 5))
ax3.set_xticklabels(years[::5], rotation=45)
plt.colorbar(im3, ax=ax3, label='Hours')
annotate_with_contrast(ax3, data3, cmap_name='inferno', fmt="{:.3f}")
plt.tight_layout()
plt.show()

# === Compute Uptime from Training Extension ===
uptime_from_extension_df = 100 * (1 - extension_df / 8760)

# === Plot: Uptime from Training Extension (%) ===
plt.figure(figsize=(6, 6))
data4 = uptime_from_extension_df[met_order].T.values
ax4 = plt.gca()
im4 = ax4.imshow(data4, aspect='auto', cmap='cividis', interpolation='nearest')
ax4.set_title('Uptime from Training Extension (%) (1980–2024)')
ax4.set_ylabel('Met Load Sizing')
ax4.set_yticks(np.arange(len(met_order)))
ax4.set_yticklabels([f"{ml}%" for ml in met_order])
ax4.set_xticks(np.arange(0, len(years), 5))
ax4.set_xticklabels(years[::5], rotation=45)
plt.colorbar(im4, ax=ax4, label='%')
annotate_with_contrast(ax4, data4, cmap_name='cividis', fmt="{:.3f}")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_4196\2451240223.py:77: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(cmap_name)
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_4196\2451240223.py:77: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(cmap_name)
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_4196\2451240223.py:77: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(cmap_name)
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_4196\2451240223.py:77: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(cmap_name)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# === Your sizing folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}

# === Collect annual degradation from each folder ===
battery_degradation = []
for met, folder in folders.items():
    try:
        df = pd.read_csv(os.path.join(folder, "cycles_2024.csv"))
        total_deg = df["degradation"].sum()
        battery_degradation.append(total_deg)
    except Exception as e:
        print(f"Error reading {met}%: {e}")
        battery_degradation.append(None)

# === Filter out None values and corresponding sizing percentages
sizing_percentages = list(folders.keys())
valid_data = [(s, d) for s, d in zip(sizing_percentages, battery_degradation) if d is not None]
sizing_percentages, battery_degradation = zip(*valid_data)

# === Calculate compounded degradation over 10 years
years = 10
remaining_capacity = [(1 - d) ** years for d in battery_degradation]

# Convert to percentage for plotting
battery_degradation_percent = [d * 100 for d in battery_degradation]
remaining_capacity_percent = [rc * 100 for rc in remaining_capacity]

# === Plotting ===
plt.figure(figsize=(10, 6))
plt.plot(sizing_percentages, battery_degradation_percent, marker='o', label='Annual Degradation (%)', linewidth=2)
plt.plot(sizing_percentages, remaining_capacity_percent, marker='s', label='Remaining Capacity After 10 Years (%)', linewidth=2)

plt.xlabel('System Sizing (% of Load Met)')
plt.ylabel('Percentage (%)')
plt.title('Battery Degradation vs. Remaining Capacity After 10 Years')
plt.ylim(0, 100)
plt.yticks(range(0, 101, 5))
plt.grid(True)
plt.legend()
plt.gca().invert_xaxis()
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}

years = list(range(1980, 2025))
battery_lifetime_years = 10

# === Store remaining capacities for each sizing
remaining_capacity_stats = {}  # met_load: [remaining_1980, ..., remaining_2024]

for met, folder in folders.items():
    remaining_by_year = []

    for year in years:
        try:
            file_path = os.path.join(folder, f"cycles_{year}.csv")
            df = pd.read_csv(file_path)
            total_degradation = df['degradation'].sum()

            # Remaining capacity after 10 years at that year's degradation rate
            remaining = (1 - total_degradation) ** battery_lifetime_years
            remaining_by_year.append(remaining * 100)  # convert to %
        except Exception as e:
            print(f"{met}% - {year} missing or error: {e}")
            continue

    remaining_capacity_stats[met] = remaining_by_year

# === Compute min / avg / max across years
met_levels = sorted(remaining_capacity_stats.keys(), reverse=False)
avg_remaining, min_remaining, max_remaining = [], [], []

for met in met_levels:
    data = [v for v in remaining_capacity_stats[met] if v is not None]
    avg_remaining.append(np.mean(data))
    min_remaining.append(np.min(data))
    max_remaining.append(np.max(data))

# === Plotting
plt.figure(figsize=(10, 6))
plt.plot(met_levels, avg_remaining, marker='o', label='Average Remaining Capacity (%)', linewidth=2, color='darkorange')
plt.fill_between(met_levels, min_remaining, max_remaining, alpha=0.3, label='Min–Max Range', color='gray')
plt.xlabel('System Sizing (% of Load Met)')
plt.ylabel('Remaining Capacity After 10 Years (%)')
plt.title('Battery Lifetime Capacity vs. Met Load Sizing (1980–2024)')
plt.grid(True)
plt.legend()
plt.gca().invert_xaxis()
plt.tight_layout()

# Save plot
plt.savefig(r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\battery_lifetime_vs_sizing.png")
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}

years = list(range(1980, 2025))
sizings = sorted(folders.keys(), reverse=True)

# === Build 2D degradation matrix: rows = sizings, cols = years
degradation_matrix = []

for met in sizings:
    folder = folders[met]
    row = []
    for year in years:
        try:
            file_path = os.path.join(folder, f"cycles_{year}.csv")
            df = pd.read_csv(file_path)
            total_deg = df["degradation"].sum()
            row.append(total_deg * 100)  # convert to %
        except Exception as e:
            print(f"{met}% in {year}: {e}")
            row.append(np.nan)
    degradation_matrix.append(row)

degradation_matrix = np.array(degradation_matrix)

# === Plot heatmap
plt.figure(figsize=(16, 5))
im = plt.imshow(degradation_matrix, aspect='auto', cmap='Reds', interpolation='nearest')

plt.colorbar(im, label='Annual Battery Degradation (%)')
plt.title('Annual Battery Degradation Heatmap (1980–2024)')
plt.xlabel('Year')
plt.ylabel('System Sizing (% of Load Met)')

# === Set x/y ticks
plt.xticks(np.arange(len(years))[::5], years[::5], rotation=45)
plt.yticks(np.arange(len(sizings)), [f"{s}%" for s in sizings])

plt.tight_layout()
plt.savefig(r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\degradation_heatmap.png")
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Your met load folders ===
folders = {
    100: r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc",
    99:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_99metLoadCostCurtailment",
    98:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_98metLoadCostCurtailment",
    95:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_95metLoadCostCurtailment",
    90:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_90metLoadCostCurtailment",
    80:  r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc_80metLoadCostCurtailment",
}

years = list(range(1980, 2025))
sizings = sorted(folders.keys(), reverse=True)

# === Build 2D degradation matrix: rows = sizings, cols = years
degradation_matrix = []

for met in sizings:
    folder = folders[met]
    row = []
    for year in years:
        try:
            file_path = os.path.join(folder, f"cycles_{year}.csv")
            df = pd.read_csv(file_path)
            total_deg = df["degradation"].sum()
            row.append(total_deg * 100)  # convert to %
        except Exception as e:
            print(f"{met}% in {year}: {e}")
            row.append(np.nan)
    degradation_matrix.append(row)

degradation_matrix = np.array(degradation_matrix)

# === Plot heatmap
fig, ax = plt.subplots(figsize=(16, 5))
im = ax.imshow(degradation_matrix, aspect='auto', cmap='Reds', interpolation='nearest')
cbar = plt.colorbar(im, ax=ax, label='Annual Battery Degradation (%)')
ax.set_title('Annual Battery Degradation Heatmap (1980–2024)')
ax.set_xlabel('Year')
ax.set_ylabel('System Sizing (% of Load Met)')

# === Set x/y ticks
ax.set_xticks(np.arange(len(years))[::5])
ax.set_xticklabels(years[::5], rotation=45)
ax.set_yticks(np.arange(len(sizings)))
ax.set_yticklabels([f"{s}%" for s in sizings])

# === Annotate each cell with 4 decimal values and contrast-aware text
norm = plt.Normalize(vmin=np.nanmin(degradation_matrix), vmax=np.nanmax(degradation_matrix))
cmap = plt.cm.get_cmap('Reds')

for i in range(degradation_matrix.shape[0]):
    for j in range(degradation_matrix.shape[1]):
        val = degradation_matrix[i, j]
        if not np.isnan(val):
            rgb = cmap(norm(val))[:3]
            brightness = np.dot(rgb, [0.299, 0.587, 0.114])
            text_color = 'black' if brightness > 0.5 else 'white'
            ax.text(j, i, f"{val:.4f}", ha='center', va='center',
                    fontsize=6.5, rotation=90, color=text_color)

plt.tight_layout()
plt.savefig(r"C:\Users\Abdullah\dispatch_outputs_solar-wind_dc\degradation_heatmap.png", dpi=300)
plt.show()
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_4196\2524822225.py:54: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('Reds')
